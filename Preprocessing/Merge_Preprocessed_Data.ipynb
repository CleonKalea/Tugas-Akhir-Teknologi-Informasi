# %%
import pandas as pd
import numpy as np
import pickle
import ast
import re

# %%
# df_bangli = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Bangli_FINAL.csv')
# df_gianyar = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Gianyar_FINAL.csv')
# df_klungkung = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Klungkung_FINAL.csv')
# df_tabanan = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Tabanan_FINAL.csv')
# df_jembrana = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Jembrana_FINAL.csv')
# df_karangasem = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Karangasem_FINAL.csv')
# df_singaraja = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Buleleng_FINAL.csv')
# df_jakarta_timur = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Jakarta_Timur_FINAL.csv')
# df_jakarta_utara = pd.read_csv('../Data/STAGE 1 PREPROCESSING/STAGE_1_PREPROCESSING_Jakarta_Utara_FINAL.csv')

df_bangli = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Bangli_FINAL.csv')
df_gianyar = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Gianyar_FINAL.csv')
df_klungkung = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Klungkung_FINAL.csv')
df_tabanan = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Tabanan_FINAL.csv')
df_jembrana = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Jembrana_FINAL.csv')
df_karangasem = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Karangasem_FINAL.csv')
df_buleleng = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Buleleng_FINAL.csv')
df_jakarta_timur = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Jakarta_Timur_FINAL.csv')
df_jakarta_utara = pd.read_csv('../Data/STAGE 3 PREPROCESSING/STAGE_3_PREPROCESSING_Jakarta_Utara_FINAL.csv')

# %%
dfs = [df_bangli, df_gianyar, df_klungkung, df_tabanan, df_jembrana, df_karangasem, df_buleleng, df_jakarta_timur, df_jakarta_utara]

columns = dfs[0].columns
all_same_columns = all(df.columns.equals(columns) for df in dfs)

print("Columns Match:", all_same_columns)
# Out:
# Columns Match: True

# %%
print("df_bangli:", len(df_bangli))
print("df_gianyar:", len(df_gianyar))
print("df_klungkung:", len(df_klungkung))
print("df_tabanan:", len(df_tabanan))
print("df_jembrana:", len(df_jembrana))
print("df_karangasem:", len(df_karangasem))
print("df_singaraja:", len(df_buleleng))
print("df_jakarta_timur:", len(df_jakarta_timur))
print("df_jakarta_utara:", len(df_jakarta_utara))
# Out:
# df_bangli: 67
# df_gianyar: 1062
# df_klungkung: 301
# df_tabanan: 536
# df_jembrana: 339
# df_karangasem: 146
# df_singaraja: 1091
# df_jakarta_timur: 620
# df_jakarta_utara: 2210

# %%
df_merged = pd.concat(dfs, ignore_index=True)

# %%
df_merged
# Out:
#                     nomor_perkara                         klasifikasi_perkara  \
# 0       29/Pid.Sus-LH/2024/PN Bli                             Kebakaran Hutan
# 1       30/Pid.Sus-LH/2024/PN Bli                             Kebakaran Hutan
# 2            27/Pid.B/2024/PN Bli                                   Pencurian
# 3            20/Pid.B/2024/PN Bli                                    Penipuan
# 4            18/Pid.B/2024/PN Bli                                   Pencurian
# ...                           ...                                         ...
# 6367  764/Pid.Sus/2023/PN Jkt.Utr  Tindak Pidana Senjata Api atau Benda Tajam
# 6368    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
# 6369    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
# 6370    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
# 6371    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
#
# ...

# %%
def leftover_cleaning(text):
    text = re.sub(r'\[.*?\]', '', str(text))
    text = re.sub(r'\s*\(\s*(nol koma|satu|dua|tiga|empat|lima|enam|tujuh|delapan|sembilan|sepuluh|sebelas|dua belas|tiga belas|empat belas|lima belas|enam belas|tujuh belas|delapan belas|sembilan belas|dua puluh)\s*\)\s*', ' ', text)
    text = re.sub(r'\*\*', '', text)
    text = re.sub(r';', ',', text)

    return text

df_merged['cleaned_barang_bukti'] = df_merged['cleaned_barang_bukti'].apply(leftover_cleaning)

# %%
df_merged
# Out:
#                     nomor_perkara                         klasifikasi_perkara  \
# 0       29/Pid.Sus-LH/2024/PN Bli                             Kebakaran Hutan
# 1       30/Pid.Sus-LH/2024/PN Bli                             Kebakaran Hutan
# 2            27/Pid.B/2024/PN Bli                                   Pencurian
# 3            20/Pid.B/2024/PN Bli                                    Penipuan
# 4            18/Pid.B/2024/PN Bli                                   Pencurian
# ...                           ...                                         ...
# 6367  764/Pid.Sus/2023/PN Jkt.Utr  Tindak Pidana Senjata Api atau Benda Tajam
# 6368    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
# 6369    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
# 6370    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
# 6371    738/Pid.B/2023/PN Jkt.Utr                                   Pencurian
#
# ...

# %% [markdown]
# ## Klasifikasi Perkara

# %%
jenis_klasifikasi_perkara = df_merged['klasifikasi_perkara'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")

klasifikasi_perkara_values = df_merged['klasifikasi_perkara'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 47
# klasifikasi_perkara
# Pencurian                                                                                               2162
# Narkotika                                                                                               2047
# Penggelapan                                                                                              403
# Kejahatan Perjudian                                                                                      275
# Penipuan                                                                                                 257
# Penganiayaan                                                                                             209
# Lain-Lain                                                                                                193
# Tindak Pidana Senjata Api atau Benda Tajam                                                               125
# ...

# %% [markdown]
# ### 5 Klasifikasi Terbanyak

# %%
klasifikasi_perkara_terbanyak = klasifikasi_perkara_values.head(5).index
df_merged_filtered = df_merged[df_merged['klasifikasi_perkara'].isin(klasifikasi_perkara_terbanyak)]

# %%
jenis_klasifikasi_perkara = df_merged_filtered['klasifikasi_perkara'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")

klasifikasi_perkara_values = df_merged_filtered['klasifikasi_perkara'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# klasifikasi_perkara
# Pencurian              2162
# Narkotika              2047
# Penggelapan             403
# Kejahatan Perjudian     275
# Penipuan                257
# Name: count, dtype: int64

# %%
df_merged_filtered = df_merged_filtered[
    df_merged_filtered['summarized_dakwaan'].notna() & 
    (df_merged_filtered['summarized_dakwaan'].apply(lambda x: len(str(x)) >= 10))
].reset_index(drop=True)

# %%
unique_klasifikasi_perkara_values = df_merged_filtered['klasifikasi_perkara'].unique()
num_unique_klasifikasi_perkara = len(unique_klasifikasi_perkara_values)
unique_klasifikasi_counts = df_merged_filtered['klasifikasi_perkara'].value_counts()

print(f"Number of unique values in 'status_perkara': {num_unique_klasifikasi_perkara}")
print(unique_klasifikasi_counts)
# Out:
# Number of unique values in 'status_perkara': 5
# klasifikasi_perkara
# Pencurian              1979
# Narkotika              1802
# Penggelapan             348
# Kejahatan Perjudian     250
# Penipuan                203
# Name: count, dtype: int64

# %%
df_merged_filtered
# Out:
#                     nomor_perkara klasifikasi_perkara  \
# 0            27/Pid.B/2024/PN Bli           Pencurian
# 1            20/Pid.B/2024/PN Bli            Penipuan
# 2            18/Pid.B/2024/PN Bli           Pencurian
# 3          17/Pid.Sus/2024/PN Bli           Narkotika
# 4          17/Pid.Sus/2024/PN Bli           Narkotika
# ...                           ...                 ...
# 4577  763/Pid.Sus/2023/PN Jkt.Utr           Narkotika
# 4578    738/Pid.B/2023/PN Jkt.Utr           Pencurian
# 4579    738/Pid.B/2023/PN Jkt.Utr           Pencurian
# 4580    738/Pid.B/2023/PN Jkt.Utr           Pencurian
# 4581    738/Pid.B/2023/PN Jkt.Utr           Pencurian
#
#                     penuntut_umum                          hakim  \
# 0     NI PUTU DIAH LAKSMINI, S.H.  ANAK AGUNG AYU DIAH INDRAWATI
# 1         FEBRI EKA PRADANA, S.H.          RATIH KUSUMA WARDHANI
# 2     NI PUTU DIAH LAKSMINI, S.H.                AMIROTUL AZIZAH
# ...

# %%
df_selected = df_merged_filtered[['klasifikasi_perkara', 'penuntut_umum', 'hakim', 'jumlah_saksi', 'summarized_dakwaan', 'cleaned_barang_bukti', 'extracted_pasal', 'terdakwa', 'total_pidana_penjara_bulan']].copy()

# %%
df_selected
# Out:
#      klasifikasi_perkara                penuntut_umum  \
# 0              Pencurian  NI PUTU DIAH LAKSMINI, S.H.
# 1               Penipuan      FEBRI EKA PRADANA, S.H.
# 2              Pencurian  NI PUTU DIAH LAKSMINI, S.H.
# 3              Narkotika               Gde Doni, S.H.
# 4              Narkotika   I Gde Doni Hendrawan, S.H.
# ...                  ...                          ...
# 4577           Narkotika     ERNI PRAMOTI, S.H., M.H.
# 4578           Pencurian         RACHMAN RAJASA, S.H.
# 4579           Pencurian       TRI NURANDI SINAGA, SH
# 4580           Pencurian         RACHMAN RAJASA, S.H.
# 4581           Pencurian       TRI NURANDI SINAGA, SH
#
#                               hakim  jumlah_saksi  \
# 0     ANAK AGUNG AYU DIAH INDRAWATI             6
# 1             RATIH KUSUMA WARDHANI             4
# 2                   AMIROTUL AZIZAH             6
# 3             RATIH KUSUMA WARDHANI             2
# 4             RATIH KUSUMA WARDHANI             2
# ...

# %%
df_selected.to_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL.csv', index=False)

# %% [markdown]
# # Map Encoding

# %% [markdown]
# ## Encoding: Klasifikasi Perkara

# %%
klasifikasi_perkara_unique_names = df_selected['klasifikasi_perkara'].unique()
klasifikasi_perkara_mapping = {name: i for i, name in enumerate(klasifikasi_perkara_unique_names)}

df_selected['klasifikasi_perkara_encoded'] = df_selected['klasifikasi_perkara'].map(klasifikasi_perkara_mapping)

with open('../Mapping/klasifikasi_perkara_mapping.pkl', 'wb') as f:
    pickle.dump(klasifikasi_perkara_mapping, f)
    
for name, code in klasifikasi_perkara_mapping.items():
    print(f"{code} <- {name} ")
# Out:
# 0 <- Pencurian
# 1 <- Penipuan
# 2 <- Narkotika
# 3 <- Penggelapan
# 4 <- Kejahatan Perjudian

# %% [markdown]
# ## Encoding: Penuntut Umum

# %%
penuntut_umum_unique_names = df_selected['penuntut_umum'].unique()
penuntut_umum_mapping = {name: i for i, name in enumerate(penuntut_umum_unique_names)}
penuntut_umum_mapping['Lainnya'] = len(penuntut_umum_mapping)

df_selected['penuntut_umum_encoded'] = df_selected['penuntut_umum'].map(penuntut_umum_mapping)

with open('../Mapping/penuntut_umum_mapping.pkl', 'wb') as f:
    pickle.dump(penuntut_umum_mapping, f)
    
for name, code in penuntut_umum_mapping.items():
    print(f"{code} <- {name} ")
# Out:
# 0 <- NI PUTU DIAH LAKSMINI, S.H.
# 1 <- FEBRI EKA PRADANA, S.H.
# 2 <- Gde Doni, S.H.
# 3 <- I Gde Doni Hendrawan, S.H.
# 4 <- Brilian Capera
# 5 <- NI MADE ARYANI, S.H.
# 6 <- DEWA MADE KRISNANDIKA, S.H.
# 7 <- DEWA KADEK DWI NARO SIGITO, S.H.
# 8 <- Dewa Gde Ari Wicaksana, S,H.
# 9 <- INDAH NOVITASARI, SH
# 10 <- I NYOMAN CARIKYASA, S.H.
# 11 <- NI LUH KHRISNA SHANTI KUSUMA DEVI, S.H
# 12 <- NGURAH WAHYU RESTA, S.H., M.Kn.
# 13 <- SIFRA WINANDITA, S.H
# 14 <- I KETUT DENI ASTIKA, S.H.
# 15 <- MICHELE MORENO, S.H.
# 16 <- FEBRI EKA PRADANA
# 17 <- I KETUT DENI ASTIKA, SH
# 18 <- GADHIS ARIZA,SH
# 19 <- I Putu Wahyu Pradiptha Wirjana, SH.MH.
# 20 <- Ni Putu Diah Laksmini, SH
# 21 <- M. Matulessy, SH
# 22 <- Iswati Septyarini, SH
# 23 <- I KETUT KARTIKA WIDNYANA SH
# 24 <- Ni Ketut Cahaya Listiani, SH
# 25 <- Julius Anthony, S.H.
# 26 <- Gede Wisnu Yoga Mandala, S.H.
# 27 <- Dewa Ayu Sekar Vikanaswari, S.H.
# 28 <- Ni Luh Putu Wiwin Sutariyanti, S.H.
# ...

# %% [markdown]
# ## Encoding: Hakim

# %%
hakim_unique_names = df_selected['hakim'].unique()
hakim_mapping = {name: i for i, name in enumerate(hakim_unique_names)}
hakim_mapping['Lainnya'] = len(hakim_mapping)

df_selected['hakim_encoded'] = df_selected['hakim'].map(hakim_mapping)

with open('../Mapping/hakim_mapping.pkl', 'wb') as f:
    pickle.dump(hakim_mapping, f)
    
for name, code in hakim_mapping.items():
    print(f"{code} <- {name} ")
# Out:
# 0 <- ANAK AGUNG AYU DIAH INDRAWATI
# 1 <- RATIH KUSUMA WARDHANI
# 2 <- AMIROTUL AZIZAH
# 3 <- EDO KRISTANTO UTOYO
# 4 <- HJ. NUR AMALIA ABBAS
# 5 <- I GUSTI AYU KADE ARI WULANDARI
# 6 <- REDITE IKA SEPTINA
# 7 <- MADE HERMAYANTI MULIARTHA
# 8 <- AGUS CAKRA NUGRAHA
# 9 <- Putu Endru Sonata
# 10 <- Anak Agung Putu Putra Ariyana
# 11 <- Made Adicandra Purnawan
# 12 <- Martaria Yudith Kusuma
# 13 <- Kukuh Kurniawan
# 14 <- Erwin Harlond Palyama
# 15 <- Sonny Alfian Blegoer Laoemoery
# 16 <- Aline Oktavia Kurnia
# 17 <- Putu Gde Hariadi
# 18 <- Ida Ayu Sri Adriyanthi Astuti Widja
# 19 <- Ni Luh Putu Partiwi
# 20 <- Diah Astuti
# 21 <- Dori Melfin
# 22 <- Akhmad Fazrinoor Sosilo Dewantoro
# 23 <- Ida Bagus Made Ari Suamba
# 24 <- VALERIA FLOSSIE AVILA SANTI, S.H., M.H.
# 25 <- MULYADI ARIBOWO
# 26 <- A.A. SAGUNG YUNI WULANTRISNA
# 27 <- JELIKA PRATIWI
# 28 <- DWI ASRI MUKAROMAH, S.H.
# 29 <- HANIFA FERI KURNIA, S.H.
# 30 <- NI MADE DEWI SUKRANI
# 31 <- Anak Agung Ayu Dharma Yanthi
# ...

# %% [markdown]
# ## Encoding: Pasal

# %%
df_selected
# Out:
#      klasifikasi_perkara                penuntut_umum  \
# 0              Pencurian  NI PUTU DIAH LAKSMINI, S.H.
# 1               Penipuan      FEBRI EKA PRADANA, S.H.
# 2              Pencurian  NI PUTU DIAH LAKSMINI, S.H.
# 3              Narkotika               Gde Doni, S.H.
# 4              Narkotika   I Gde Doni Hendrawan, S.H.
# ...                  ...                          ...
# 4577           Narkotika     ERNI PRAMOTI, S.H., M.H.
# 4578           Pencurian         RACHMAN RAJASA, S.H.
# 4579           Pencurian       TRI NURANDI SINAGA, SH
# 4580           Pencurian         RACHMAN RAJASA, S.H.
# 4581           Pencurian       TRI NURANDI SINAGA, SH
#
#                               hakim  jumlah_saksi  \
# 0     ANAK AGUNG AYU DIAH INDRAWATI             6
# 1             RATIH KUSUMA WARDHANI             4
# 2                   AMIROTUL AZIZAH             6
# 3             RATIH KUSUMA WARDHANI             2
# 4             RATIH KUSUMA WARDHANI             2
# ...

# %%
df_selected['extracted_pasal'] = df_selected['extracted_pasal'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
df_selected['extracted_pasal'] = df_selected['extracted_pasal'].apply(lambda x: [pasal.strip() for pasal in x] if isinstance(x, list) else x)

# %%
x = [item for sublist in df_selected['extracted_pasal'] for item in sublist]
y = sorted(list(set(x)))
y
# Out:
# ['-',
#  '0',
#  '379a KUHP Jo. Pasal 64 Ayat (1) ke-1 KUHP',
#  'Pasal 1 jo. Pasal 132 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika',
#  'Pasal 1 jo. Pasal 2 Ayat (1) UU No. 7 Tahun 1974',
#  'Pasal 111 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika',
#  'Pasal 111 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika jo. Pasal 132 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika',
#  'Pasal 111 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika jo. Pasal 55 Ayat (1) ke-1 KUHP',
#  'Pasal 111 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika jo. Pasal 55 Ayat (1) ke-1 KUHP.',
#  'Pasal 111 Ayat (2) UU RI No. 35 Tahun 2009 Tentang Narkotika',
#  'Pasal 111 Ayat (2) UU RI No. 35 Tahun 2009 Tentang Narkotika jo. Pasal 132 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika',
#  'Pasal 111 Ayat (2) UU RI No. 35 Tahun 2009 Tentang Narkotika jo. Pasal 55 Ayat (1) ke-1 KUHP',
#  'Pasal 112 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika',
# ...

# %%
# for row, key in df_selected.iterrows():
#     for i in range (len(key['mapped_pasal'])):
#         if key['mapped_pasal'][i] == 'Unknown':
#             print(f"Row {row}: {key['extracted_pasal']}")
#             print(f"Row {row}: {key['mapped_pasal']}\n")

# %%
lama_kurungan_pasal_mapping = {
'Pasal 112 Ayat (1) UU No. 35 Tahun 2009 tentang Narkotika': 144, #<- denda maks 8 miliar min 800jt
'Pasal 112 Ayat (1) UU No. 35 Tahun 2009 tentang Narkotika jo. Pasal 55 Ayat (1) ke-1 KUHP': 144,
'Pasal 114 Ayat (1) UU No. 35 Tahun 2009 tentang Narkotika': 240,
'Pasal 127 Ayat (1) UU No. 35 Tahun 2009 tentang Narkotika': 4, #<- narkotika pergolongan beda-beda
'Pasal 263 Ayat (2) KUHP': 72,
'Pasal 362 KUHP': 60,
'Pasal 362 jo. Pasal 56 Ke-2 KUHP': 60, #penyertaan sebagai pembantu kejahatan
'Pasal 362 jo. Pasal 65 Ayat (1) KUHP': 80, #hal yang dilakukan perbarengan hanya dijatuhkan 1 pidana yang sama atau paling berat ditambah sepertiga
'Pasal 363 Ayat (1) KUHP': 84,
'Pasal 363 Ayat (1) ke-1 KUHP': 84,
'Pasal 363 Ayat (1) ke-3 KUHP': 84,
'Pasal 363 Ayat (1) ke-3 KUHP jo. Pasal 53 Ayat (1) KUHP': 56, #percobaan kejahatan dikurangi sepertiga dari pidana pokok
'Pasal 363 Ayat (1) ke-3 KUHP jo. Pasal 65 Ayat (1) KUHP': 112, #hal yang dilakukan perbarengan hanya dijatuhkan 1 pidana yang sama atau paling berat ditambah sepertiga
'Pasal 363 Ayat (1) ke-3 dan ke-4 KUHP': 108,
'Pasal 363 Ayat (1) ke-3 dan ke-5 KUHP': 108,
'Pasal 363 Ayat (1) ke-3 dan ke-5 KUHP jo. Pasal 65 Ayat (1)': 144, #hal yang dilakukan perbarengan hanya dijatuhkan 1 pidana yang sama atau paling berat ditambah sepertiga
'Pasal 363 Ayat (1) ke-4 KUHP': 84,
'Pasal 363 Ayat (1) ke-4 KUHP dan Pasal 363 Ayat (1) ke-5 KUHP jo. Pasal 65 Ayat (1) KUHP': 144, #<- hal yang dilakukan perbarengan hanya dijatuhkan 1 pidana yang sama atau paling berat ditambah sepertiga
'Pasal 363 Ayat (1) ke-4 KUHP jo. Pasal 64 ayat (1) KUHP': 84, #<-
'Pasal 363 Ayat (1) ke-4 KUHP jo. Pasal 65 Ayat (1) KUHP': 112, #hal yang dilakukan perbarengan hanya dijatuhkan 1 pidana yang sama atau paling berat ditambah sepertiga
'Pasal 363 Ayat (1) ke-4 dan ke-5 KUHP': 84,
'Pasal 363 Ayat (1) ke-4 dan ke-5 KUHP jo. Pasal 53 Ayat (1) KUHP': 56,
'Pasal 363 Ayat (1) ke-4 dan ke-5 KUHP jo. Pasal 65 Ayat (1) KUHP': 112,
'Pasal 363 Ayat (1) ke-5 KUHP': 84,
'Pasal 363 Ayat (1) ke-5 KUHP jo. Pasal 53 Ayat (1) KUHP': 56,
'Pasal 363 Ayat (1) ke-5 KUHP jo. Pasal 65 Ayat (1) KUHP': 112,
'Pasal 363 Ayat (2) KUHP': 108,
'Pasal 363 Ayat (2) KUHP jo. Pasal 65 Ayat (1) KUHP': 144, #ditambah sepertiga
'Pasal 365 Ayat (1) KUHP': 108,
'Pasal 365 Ayat (2) ke-1 KUHP': 144,
'Pasal 365 Ayat (2) ke-2 KUHP': 144,
'Pasal 368 Ayat (1) KUHP': 108,
'Pasal 372 KUHP': 48,
'Pasal 372 KUHP jo. Pasal 55 Ayat (1) ke-1 KUHP jo. Pasal 64 Ayat (1) KUHP': 48,
'Pasal 374 KUHP': 60,
'Pasal 378 KUHP': 48,
'Pasal 480 Ayat (2) KUHP': 48,
'Pasal 480 ke-1 KUHP': 48,
}

# %%
df_selected['maks_penjara_berdasarkan_pasal'] = df_selected['extracted_pasal'].apply(lambda lst: [lama_kurungan_pasal_mapping.get(item, 'Unknown') for item in lst])

# %%
df_selected
# Out:
#      klasifikasi_perkara                penuntut_umum  \
# 0              Pencurian  NI PUTU DIAH LAKSMINI, S.H.
# 1               Penipuan      FEBRI EKA PRADANA, S.H.
# 2              Pencurian  NI PUTU DIAH LAKSMINI, S.H.
# 3              Narkotika               Gde Doni, S.H.
# 4              Narkotika   I Gde Doni Hendrawan, S.H.
# ...                  ...                          ...
# 4577           Narkotika     ERNI PRAMOTI, S.H., M.H.
# 4578           Pencurian         RACHMAN RAJASA, S.H.
# 4579           Pencurian       TRI NURANDI SINAGA, SH
# 4580           Pencurian         RACHMAN RAJASA, S.H.
# 4581           Pencurian       TRI NURANDI SINAGA, SH
#
#                               hakim  jumlah_saksi  \
# 0     ANAK AGUNG AYU DIAH INDRAWATI             6
# 1             RATIH KUSUMA WARDHANI             4
# 2                   AMIROTUL AZIZAH             6
# 3             RATIH KUSUMA WARDHANI             2
# 4             RATIH KUSUMA WARDHANI             2
# ...

# %%
df_selected['maks_penjara_berdasarkan_pasal'] = df_selected['maks_penjara_berdasarkan_pasal'].apply(
    lambda x: max(x) if isinstance(x, list) and len(x) > 0 else None
)

# %%
for row, key in df_selected.iterrows():
    for i in range (len(key['maks_penjara_berdasarkan_pasal'])):
        if key['maks_penjara_berdasarkan_pasal'][i] == 'Unknown':
            print(f"Row {row}: {key['extracted_pasal']}")
            print(f"Row {row}: {key['maks_penjara_berdasarkan_pasal']}\n")
# Out:
# Row 0: ['Pasal 362 KUHP jo. Pasal 65 Ayat (1) KUHP']
# Row 0: ['Unknown']
#
# Row 1: ['Pasal 372 jo. 64 Ayat (1) KUHP', 'Pasal 378 jo. 64 Ayat (1) KUHP']
# Row 1: ['Unknown', 'Unknown']
#
# Row 1: ['Pasal 372 jo. 64 Ayat (1) KUHP', 'Pasal 378 jo. 64 Ayat (1) KUHP']
# Row 1: ['Unknown', 'Unknown']
#
# Row 3: ['Pasal 112 Ayat (1) UU RI No. 35 Tahun 2009 tentang Narkotika', 'Pasal 127 Ayat (1) huruf a Undang-Undang RI No. 35 Tahun 2009 Tentang Narkotika']
# Row 3: ['Unknown', 'Unknown']
#
# Row 3: ['Pasal 112 Ayat (1) UU RI No. 35 Tahun 2009 tentang Narkotika', 'Pasal 127 Ayat (1) huruf a Undang-Undang RI No. 35 Tahun 2009 Tentang Narkotika']
# Row 3: ['Unknown', 'Unknown']
#
# Row 4: ['Pasal 112 Ayat (1) UU RI No. 35 Tahun 2009 tentang Narkotika', 'Pasal 127 Ayat (1) huruf a Undang-Undang RI No. 35 Tahun 2009 Tentang Narkotika']
# Row 4: ['Unknown', 'Unknown']
#
# ...

# %%
with open('../Mapping/pasal_mapping.pkl', 'wb') as f:
    pickle.dump(lama_kurungan_pasal_mapping, f)
    
for name, code in lama_kurungan_pasal_mapping.items():
    print(f"{code} <- {name} ")

# %% [markdown]
# ## Load Saved Mapping

# %%
with open('../Mapping/klasifikasi_perkara_mapping.pkl', 'rb') as f:
    klasifikasi_perkara_mapping = pickle.load(f)

print(klasifikasi_perkara_mapping)

with open('../Mapping/penuntut_umum_mapping.pkl', 'rb') as f:
    penuntut_umum_mapping = pickle.load(f)

print(penuntut_umum_mapping)

with open('../Mapping/hakim_mapping.pkl', 'rb') as f:
    hakim_mapping = pickle.load(f)

print(hakim_mapping)

with open('../Mapping/pasal_mapping.pkl', 'rb') as f:
    pasal_mapping = pickle.load(f)

print(pasal_mapping)
# Out:
# {'Pencurian': 0, 'Penipuan': 1, 'Narkotika': 2, 'Penggelapan': 3, 'Kejahatan Perjudian': 4}
# ...

# %% [markdown]
# ## Drop Non-encoded columns

# %%
df_encoded = df_selected[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'cleaned_barang_bukti', 'summarized_dakwaan', 'extracted_pasal', 'terdakwa', 'total_pidana_penjara_bulan']].copy()

# %%
df_encoded
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4577                            2                    373            134
# 4578                            0                    387            123
# 4579                            0                    389            123
# 4580                            0                    387            123
# 4581                            0                    389            123
#
#       jumlah_saksi                               cleaned_barang_bukti  \
# ...

# %%
df_encoded = df_encoded[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'cleaned_barang_bukti', 'summarized_dakwaan', 'extracted_pasal', 'terdakwa', 'total_pidana_penjara_bulan', 'maks_penjara_berdasarkan_pasal']].copy()

# %%
df_encoded.to_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv', index=False)

# %% [markdown]
# # TEMP

# %%
df_bangli = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Bangli_SUMMARIZED.csv')
df_gianyar = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Gianyar_SUMMARIZED.csv')
df_klungkung = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Klungkung_SUMMARIZED.csv')
df_tabanan = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Tabanan_SUMMARIZED.csv')
df_jembrana = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Jembrana_SUMMARIZED.csv')
df_karangasem = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Karangasem_SUMMARIZED.csv')
df_buleleng = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Buleleng_SUMMARIZED.csv')
df_jakarta_timur = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Jakarta_Timur_SUMMARIZED.csv')
df_jakarta_utara = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Jakarta_Utara_SUMMARIZED.csv')

# %%
df_merged = pd.concat([df_bangli, df_gianyar, df_klungkung, df_tabanan, df_jembrana, df_karangasem, df_buleleng, df_jakarta_timur, df_jakarta_utara], ignore_index=True)

# %%
df_jakarta_utara
# Out:
#                    nomor_perkara  \
# 0      734/Pid.B/2024/PN Jkt.Utr
# 1      712/Pid.B/2024/PN Jkt.Utr
# 2      707/Pid.B/2024/PN Jkt.Utr
# 3      708/Pid.B/2024/PN Jkt.Utr
# 4      697/Pid.B/2024/PN Jkt.Utr
# ..                           ...
# 968    761/Pid.B/2023/PN Jkt.Utr
# 969  763/Pid.Sus/2023/PN Jkt.Utr
# 970    762/Pid.B/2023/PN Jkt.Utr
# 971  764/Pid.Sus/2023/PN Jkt.Utr
# 972    738/Pid.B/2023/PN Jkt.Utr
#
#                                    klasifikasi_perkara  \
# 0                                            Pencurian
# 1                                            Pencurian
# 2                Penadahan, Penerbitan, dan Pencetakan
# 3                Penadahan, Penerbitan, dan Pencetakan
# 4                                             Penipuan
# ..                                                 ...
# 968                                          Pencurian
# 969                                          Narkotika
# 970  Pengeroyokan yang menyebabkan luka ringan, luk...
# ...

# %%
df_klungkung['extracted_pasal'] = df_klungkung['extracted_pasal'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
df_buleleng['extracted_pasal'] = df_buleleng['extracted_pasal'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

for index, row in df_buleleng.iterrows():
    pasal = row['extracted_pasal']
    if isinstance(pasal, (str, list)):
        # print(f"Bangli - Index: {index} -> \t Pasal: {len(pasal)}")
        if len(pasal) == 1:
            print(f" - Index: {index} -> \t Pasal: {pasal}")
    else:
        print(f" - Index: {index} -> \t Pasal: 0 (invalid or missing)")
# Out:
#  - Index: 3 -> 	 Pasal: ['0']
#  - Index: 8 -> 	 Pasal: ['Pasal 362 KUHP']
#  - Index: 10 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-4 dan ke-5 KUHP']
#  - Index: 11 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-3 KUHP']
#  - Index: 12 -> 	 Pasal: ['Pasal 362 KUHP']
#  - Index: 17 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-3 KUHP']
#  - Index: 20 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-3 dan ke-5 KUHP']
#  - Index: 22 -> 	 Pasal: ['Pasal 362 KUHP']
#  - Index: 23 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-4 KUHP']
#  - Index: 28 -> 	 Pasal: ['Pasal 362 KUHP jo. Pasal 64 Ayat (1) KUHP']
#  - Index: 31 -> 	 Pasal: ['Pasal 362 KUHP']
#  - Index: 33 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-4 KUHP jo. Pasal 64 Ayat (1) KUHP']
#  - Index: 36 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-4 KUHP']
#  - Index: 38 -> 	 Pasal: ['Pasal 362 KUHP']
#  - Index: 39 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-5 KUHP']
#  - Index: 44 -> 	 Pasal: ['Pasal 363 Ayat (1) ke-5 KUHP']
# ...

# %%
2491

# %%
df_merged.iloc[2491]
# Out:
# nomor_perkara                                       237/Pid.B/2017/PN Sgr
# klasifikasi_perkara                                           Penggelapan
# terdakwa                                          ['Ayu Putu Erlyandani']
# penuntut_umum                                  ['IMAM EKA SETYAWAN, SH.']
# hakim                                                Ni Made Dewi Sukrani
# jumlah_saksi                                                            4
# putusan_hukuman         ['Ayu Putu Erlyandani~Pidana Penjara Waktu Ter...
# cleaned_barang_bukti    1 (satu) buah Buku Simpanan atau Tabungan Kopr...
# cleaned_dakwaan         Kesatu. Primair. - Bahwa terdakwa AYU PUTU ERL...
# summarized_dakwaan      Terdakwa AYU PUTU ERLYANDANI, yang bekerja seb...
# extracted_pasal                                         [Pasal 374 KUHP\]
# keterangan                                                              0
# Name: 2491, dtype: object

# %%
# wrong_data_index = 932
# # # df_jakarta_utara.at[wrong_data_index, 'summarized_dakwaan'] = np.nan
# df_buleleng.at[wrong_data_index, 'extracted_pasal'] = ['Pasal 374 KUHP']
# # # df_jakarta_utara.at[wrong_data_index, 'keterangan'] = 0

# %%
df_buleleng.to_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Buleleng_SUMMARIZED.csv', index=False)

# %%
# berdasarkan Pasal 111 Ayat (1) UU RI No. 35 Tahun 2009 Tentang Narkotika', 'dan dakwaan kedua berdasarkan Pasal 127 Ayat (1) huruf a UU RI No. 35 Tahun 2009 Tentang Narkotika.'
