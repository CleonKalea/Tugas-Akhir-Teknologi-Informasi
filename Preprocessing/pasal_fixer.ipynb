# %%
import pandas as pd
import numpy as np
import pickle
import ast
import re

# %%
df_bangli = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Bangli_SUMMARIZED.csv')
df_gianyar = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Gianyar_SUMMARIZED.csv')
df_klungkung = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Klungkung_SUMMARIZED.csv')
df_tabanan = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Tabanan_SUMMARIZED.csv')
df_jembrana = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Jembrana_SUMMARIZED.csv')
df_karangasem = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Karangasem_SUMMARIZED.csv')
df_buleleng = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Buleleng_SUMMARIZED.csv')
df_jakarta_timur = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Jakarta_Timur_SUMMARIZED.csv')
df_jakarta_utara = pd.read_csv('../Data/STAGE 2 PREPROCESSING/Summarized/STAGE_2_PREPROCESSING_Jakarta_Utara_SUMMARIZED.csv')

# %%
df_merged = pd.concat([df_bangli, df_gianyar, df_klungkung, df_tabanan, df_jembrana, df_karangasem, df_buleleng, df_jakarta_timur, df_jakarta_utara], ignore_index=True)

# %%
df_merged['extracted_pasal'] = df_merged['extracted_pasal'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# %%
df_merged
# Out:
#                     nomor_perkara  \
# 0       29/Pid.Sus-LH/2024/PN Bli
# 1       30/Pid.Sus-LH/2024/PN Bli
# 2            27/Pid.B/2024/PN Bli
# 3            20/Pid.B/2024/PN Bli
# 4            18/Pid.B/2024/PN Bli
# ...                           ...
# 3985    761/Pid.B/2023/PN Jkt.Utr
# 3986  763/Pid.Sus/2023/PN Jkt.Utr
# 3987    762/Pid.B/2023/PN Jkt.Utr
# 3988  764/Pid.Sus/2023/PN Jkt.Utr
# 3989    738/Pid.B/2023/PN Jkt.Utr
#
#                                     klasifikasi_perkara  \
# 0                                       Kebakaran Hutan
# 1                                       Kebakaran Hutan
# 2                                             Pencurian
# 3                                              Penipuan
# 4                                             Pencurian
# ...                                                 ...
# 3985                                          Pencurian
# 3986                                          Narkotika
# ...

# %%
for index, row in df_merged.iterrows():
    try:
        for pasal in row['extracted_pasal']:
            if pasal == '-':
                print(pasal)s
                print(row['nomor_perkara'])

    except Exception as e:
        # print(f"Error at index {index}: {e}")
        continue
# Out:
# -
# 74/Pid.B/2024/PN Gin
# -
# 37/Pid.B/2024/PN Gin
# -
# 9/Pid.B/2024/PN Gin
# -
# 99/Pid.Sus/2023/PN Gin
# -
# 74/Pid.Sus/2023/PN Gin
# -
# 59/Pid.Sus/2023/PN Gin
# -
# 60/Pid.Sus/2023/PN Gin
# -
# 51/Pid.B/2023/PN Gin
# -
# 6/Pid.B/2023/PN Gin
# -
# 148/Pid.B/2022/PN Gin
# -
# 111/Pid.B/2022/PN Gin
# -
# 82/Pid.B/2022/PN Gin
# -
# 65/Pid.B/2022/PN Gin
# -
# 60/Pid.Sus/2022/PN Gin
# -
# 48/Pid.B/2022/PN Gin
# -
# 141/Pid.B/2021/PN Gin
# -
# 57/Pid.B/2021/PN Gin
# -
# 19/Pid.Sus/2021/PN Gin
# -
# 11/Pid.B/2021/PN Gin
# -
# 176/Pid.Sus/2020/PN Gin
# -
# 112/Pid.B/2020/PN Gin
# -
# 103/Pid.Sus/2020/PN Gin
# -
# 76/Pid.B/2020/PN Gin
# -
# 47/Pid.Sus/2020/PN Gin
# -
# 217/Pid.B/2019/PN Gin
# -
# 214/Pid.Sus/2019/PN Gin
# -
# 137/Pid.B/2019/PN Gin
# -
# 102/Pid.Sus/2019/PN Gin
# -
# 23/Pid.Sus/2019/PN Gin
# -
# 170/Pid.Sus/2018/PN Gin
# -
# 138/Pid.B/2018/PN Gin
# -
# 126/Pid.B/2018/PN Gin
# -
# 118/Pid.Sus/2018/PN Gin
# -
# 62/Pid.B/2018/PN Gin
# -
# 50/Pid.B/2018/PN Gin
# -
# ...

# %%
for index, row in df_merged.iterrows():
    try:
        if "Pasal 330" in row['cleaned_dakwaan']:
            print(index)


    except Exception as e:
        # print(f"Error at index {index}: {e}")
        continue
