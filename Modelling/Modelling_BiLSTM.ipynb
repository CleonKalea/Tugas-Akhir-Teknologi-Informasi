# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_27752\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([pooled_lstm, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['bidirectional[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['bidirectional_1[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['bidirectional_2[0][0]']
#  xPooling1D)
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['global_max_pooling1d[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,018,529
# Trainable params: 4,018,337
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 35s 287ms/step - loss: 17.5444 - mean_absolute_error: 17.9545 - root_mean_squared_error: 28.3914 - mean_absolute_percentage_error: 72.1026 - val_loss: 11.7499 - val_mean_absolute_error: 12.1604 - val_root_mean_squared_error: 18.2437 - val_mean_absolute_percentage_error: 72.3155
# Epoch 2/100
# 103/103 [==============================] - 28s 273ms/step - loss: 9.7355 - mean_absolute_error: 10.1404 - root_mean_squared_error: 15.7043 - mean_absolute_percentage_error: 53.1800 - val_loss: 12.2365 - val_mean_absolute_error: 12.6473 - val_root_mean_squared_error: 18.8292 - val_mean_absolute_percentage_error: 58.5596
# Epoch 3/100
# 103/103 [==============================] - 28s 271ms/step - loss: 8.7003 - mean_absolute_error: 9.1040 - root_mean_squared_error: 14.5278 - mean_absolute_percentage_error: 44.3703 - val_loss: 8.9688 - val_mean_absolute_error: 9.3805 - val_root_mean_squared_error: 14.9320 - val_mean_absolute_percentage_error: 52.4882
# Epoch 4/100
# 103/103 [==============================] - 28s 274ms/step - loss: 7.2399 - mean_absolute_error: 7.6407 - root_mean_squared_error: 12.0563 - mean_absolute_percentage_error: 38.1916 - val_loss: 9.4946 - val_mean_absolute_error: 9.9021 - val_root_mean_squared_error: 15.6426 - val_mean_absolute_percentage_error: 40.4919
# Epoch 5/100
# 103/103 [==============================] - 28s 274ms/step - loss: 6.6867 - mean_absolute_error: 7.0859 - root_mean_squared_error: 11.6159 - mean_absolute_percentage_error: 33.7498 - val_loss: 8.9275 - val_mean_absolute_error: 9.3386 - val_root_mean_squared_error: 14.8282 - val_mean_absolute_percentage_error: 38.2990
# Epoch 6/100
# 103/103 [==============================] - 28s 276ms/step - loss: 6.3505 - mean_absolute_error: 6.7465 - root_mean_squared_error: 10.8392 - mean_absolute_percentage_error: 29.5763 - val_loss: 6.8321 - val_mean_absolute_error: 7.2237 - val_root_mean_squared_error: 12.6728 - val_mean_absolute_percentage_error: 38.7404
# Epoch 7/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.4945 - mean_absolute_error: 5.8866 - root_mean_squared_error: 9.7117 - mean_absolute_percentage_error: 24.3575 - val_loss: 11.7338 - val_mean_absolute_error: 12.1433 - val_root_mean_squared_error: 17.9943 - val_mean_absolute_percentage_error: 63.6372
# Epoch 8/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.3519 - mean_absolute_error: 5.7425 - root_mean_squared_error: 9.3770 - mean_absolute_percentage_error: 23.9519 - val_loss: 6.6900 - val_mean_absolute_error: 7.0817 - val_root_mean_squared_error: 12.7465 - val_mean_absolute_percentage_error: 36.3560
# Epoch 9/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.9718 - mean_absolute_error: 5.3604 - root_mean_squared_error: 8.7843 - mean_absolute_percentage_error: 21.5936 - val_loss: 6.5220 - val_mean_absolute_error: 6.9159 - val_root_mean_squared_error: 11.9864 - val_mean_absolute_percentage_error: 39.2541
# Epoch 10/100
# 103/103 [==============================] - 33s 324ms/step - loss: 4.9901 - mean_absolute_error: 5.3803 - root_mean_squared_error: 8.8971 - mean_absolute_percentage_error: 21.5256 - val_loss: 8.5126 - val_mean_absolute_error: 8.9282 - val_root_mean_squared_error: 13.3278 - val_mean_absolute_percentage_error: 59.7090
# Epoch 11/100
# 103/103 [==============================] - 37s 357ms/step - loss: 4.5010 - mean_absolute_error: 4.8886 - root_mean_squared_error: 8.1009 - mean_absolute_percentage_error: 19.7401 - val_loss: 7.6523 - val_mean_absolute_error: 8.0501 - val_root_mean_squared_error: 13.0057 - val_mean_absolute_percentage_error: 41.0733
# Epoch 12/100
# 103/103 [==============================] - 38s 365ms/step - loss: 4.7342 - mean_absolute_error: 5.1214 - root_mean_squared_error: 8.2729 - mean_absolute_percentage_error: 19.8678 - val_loss: 11.9312 - val_mean_absolute_error: 12.3458 - val_root_mean_squared_error: 17.7592 - val_mean_absolute_percentage_error: 58.9950
# Epoch 13/100
# 103/103 [==============================] - 39s 377ms/step - loss: 4.4748 - mean_absolute_error: 4.8575 - root_mean_squared_error: 8.0381 - mean_absolute_percentage_error: 19.4722 - val_loss: 7.1183 - val_mean_absolute_error: 7.5162 - val_root_mean_squared_error: 12.4000 - val_mean_absolute_percentage_error: 44.7197
# Epoch 14/100
# 103/103 [==============================] - 38s 367ms/step - loss: 4.3633 - mean_absolute_error: 4.7465 - root_mean_squared_error: 7.7190 - mean_absolute_percentage_error: 18.8837 - val_loss: 7.6552 - val_mean_absolute_error: 8.0641 - val_root_mean_squared_error: 12.9785 - val_mean_absolute_percentage_error: 52.1844
# Epoch 15/100
# 103/103 [==============================] - 36s 352ms/step - loss: 4.2227 - mean_absolute_error: 4.6027 - root_mean_squared_error: 7.5980 - mean_absolute_percentage_error: 18.1032 - val_loss: 7.1847 - val_mean_absolute_error: 7.5958 - val_root_mean_squared_error: 12.0534 - val_mean_absolute_percentage_error: 55.2669
# Epoch 16/100
# 103/103 [==============================] - 41s 394ms/step - loss: 4.1190 - mean_absolute_error: 4.5025 - root_mean_squared_error: 7.4436 - mean_absolute_percentage_error: 17.7352 - val_loss: 6.3138 - val_mean_absolute_error: 6.7022 - val_root_mean_squared_error: 11.5903 - val_mean_absolute_percentage_error: 38.2569
# Epoch 17/100
# 103/103 [==============================] - 40s 391ms/step - loss: 4.0012 - mean_absolute_error: 4.3851 - root_mean_squared_error: 7.3139 - mean_absolute_percentage_error: 17.5025 - val_loss: 6.4752 - val_mean_absolute_error: 6.8719 - val_root_mean_squared_error: 11.6206 - val_mean_absolute_percentage_error: 33.7407
# Epoch 18/100
# 103/103 [==============================] - 39s 377ms/step - loss: 3.9763 - mean_absolute_error: 4.3589 - root_mean_squared_error: 7.3299 - mean_absolute_percentage_error: 16.9671 - val_loss: 12.4761 - val_mean_absolute_error: 12.8926 - val_root_mean_squared_error: 17.3420 - val_mean_absolute_percentage_error: 47.3191
# Epoch 19/100
# 103/103 [==============================] - 37s 363ms/step - loss: 4.1429 - mean_absolute_error: 4.5277 - root_mean_squared_error: 7.3631 - mean_absolute_percentage_error: 17.9266 - val_loss: 9.1037 - val_mean_absolute_error: 9.5171 - val_root_mean_squared_error: 13.8752 - val_mean_absolute_percentage_error: 39.6584
# Epoch 20/100
# 103/103 [==============================] - 33s 319ms/step - loss: 3.9360 - mean_absolute_error: 4.3180 - root_mean_squared_error: 7.2340 - mean_absolute_percentage_error: 16.7506 - val_loss: 8.3891 - val_mean_absolute_error: 8.7849 - val_root_mean_squared_error: 13.6281 - val_mean_absolute_percentage_error: 42.6538
# Epoch 21/100
# 103/103 [==============================] - 28s 270ms/step - loss: 3.7788 - mean_absolute_error: 4.1614 - root_mean_squared_error: 6.9703 - mean_absolute_percentage_error: 15.9750 - val_loss: 5.7780 - val_mean_absolute_error: 6.1684 - val_root_mean_squared_error: 10.9486 - val_mean_absolute_percentage_error: 32.7883
# Epoch 22/100
# 103/103 [==============================] - 31s 297ms/step - loss: 3.5029 - mean_absolute_error: 3.8825 - root_mean_squared_error: 6.3657 - mean_absolute_percentage_error: 15.0873 - val_loss: 5.4845 - val_mean_absolute_error: 5.8614 - val_root_mean_squared_error: 10.9412 - val_mean_absolute_percentage_error: 32.6051
# Epoch 23/100
# 103/103 [==============================] - 33s 320ms/step - loss: 3.9852 - mean_absolute_error: 4.3638 - root_mean_squared_error: 7.3934 - mean_absolute_percentage_error: 15.8628 - val_loss: 7.1770 - val_mean_absolute_error: 7.5618 - val_root_mean_squared_error: 13.0369 - val_mean_absolute_percentage_error: 41.5489
# Epoch 24/100
# 103/103 [==============================] - 33s 320ms/step - loss: 3.4321 - mean_absolute_error: 3.8102 - root_mean_squared_error: 6.3765 - mean_absolute_percentage_error: 14.5606 - val_loss: 5.9904 - val_mean_absolute_error: 6.3888 - val_root_mean_squared_error: 11.4158 - val_mean_absolute_percentage_error: 34.4244
# Epoch 25/100
# 103/103 [==============================] - 33s 320ms/step - loss: 3.7230 - mean_absolute_error: 4.0988 - root_mean_squared_error: 7.0170 - mean_absolute_percentage_error: 14.6816 - val_loss: 7.4860 - val_mean_absolute_error: 7.8961 - val_root_mean_squared_error: 12.3191 - val_mean_absolute_percentage_error: 39.2768
# Epoch 26/100
# 103/103 [==============================] - 33s 321ms/step - loss: 3.4816 - mean_absolute_error: 3.8599 - root_mean_squared_error: 6.3713 - mean_absolute_percentage_error: 14.3163 - val_loss: 7.2358 - val_mean_absolute_error: 7.6387 - val_root_mean_squared_error: 12.3538 - val_mean_absolute_percentage_error: 46.2666
# Epoch 27/100
# 103/103 [==============================] - 32s 316ms/step - loss: 3.3484 - mean_absolute_error: 3.7227 - root_mean_squared_error: 6.1096 - mean_absolute_percentage_error: 14.3029 - val_loss: 6.6827 - val_mean_absolute_error: 7.0807 - val_root_mean_squared_error: 11.9830 - val_mean_absolute_percentage_error: 37.5601
# Epoch 28/100
# 103/103 [==============================] - 32s 315ms/step - loss: 3.4605 - mean_absolute_error: 3.8395 - root_mean_squared_error: 6.2266 - mean_absolute_percentage_error: 14.6732 - val_loss: 5.8258 - val_mean_absolute_error: 6.2061 - val_root_mean_squared_error: 11.3726 - val_mean_absolute_percentage_error: 34.3590
# Epoch 29/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.2943 - mean_absolute_error: 3.6699 - root_mean_squared_error: 5.9845 - mean_absolute_percentage_error: 14.3764 - val_loss: 5.9264 - val_mean_absolute_error: 6.3235 - val_root_mean_squared_error: 10.9934 - val_mean_absolute_percentage_error: 32.8963
# Epoch 30/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.1648 - mean_absolute_error: 3.5410 - root_mean_squared_error: 5.8874 - mean_absolute_percentage_error: 13.8742 - val_loss: 5.8989 - val_mean_absolute_error: 6.2772 - val_root_mean_squared_error: 11.4942 - val_mean_absolute_percentage_error: 35.5395
# Epoch 31/100
# 103/103 [==============================] - 33s 316ms/step - loss: 3.0823 - mean_absolute_error: 3.4586 - root_mean_squared_error: 5.6570 - mean_absolute_percentage_error: 13.6420 - val_loss: 9.6566 - val_mean_absolute_error: 10.0666 - val_root_mean_squared_error: 14.9111 - val_mean_absolute_percentage_error: 49.3104
# Epoch 32/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.3871 - mean_absolute_error: 3.7598 - root_mean_squared_error: 6.3633 - mean_absolute_percentage_error: 13.4513 - val_loss: 6.1833 - val_mean_absolute_error: 6.5809 - val_root_mean_squared_error: 11.5196 - val_mean_absolute_percentage_error: 32.4862
# Epoch 33/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.3046 - mean_absolute_error: 3.6800 - root_mean_squared_error: 6.0616 - mean_absolute_percentage_error: 13.6014 - val_loss: 7.0752 - val_mean_absolute_error: 7.4812 - val_root_mean_squared_error: 12.2347 - val_mean_absolute_percentage_error: 42.9752
# Epoch 34/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.2390 - mean_absolute_error: 3.6070 - root_mean_squared_error: 5.9984 - mean_absolute_percentage_error: 13.8967 - val_loss: 8.7946 - val_mean_absolute_error: 9.2177 - val_root_mean_squared_error: 12.8604 - val_mean_absolute_percentage_error: 58.9286
# Epoch 35/100
# 103/103 [==============================] - 32s 315ms/step - loss: 3.1568 - mean_absolute_error: 3.5322 - root_mean_squared_error: 5.8824 - mean_absolute_percentage_error: 13.2667 - val_loss: 9.3514 - val_mean_absolute_error: 9.7617 - val_root_mean_squared_error: 14.9022 - val_mean_absolute_percentage_error: 52.4704
# Epoch 36/100
# 103/103 [==============================] - 33s 319ms/step - loss: 3.0083 - mean_absolute_error: 3.3842 - root_mean_squared_error: 5.4960 - mean_absolute_percentage_error: 13.4887 - val_loss: 6.2976 - val_mean_absolute_error: 6.6752 - val_root_mean_squared_error: 11.7528 - val_mean_absolute_percentage_error: 34.3405
# Epoch 37/100
# 103/103 [==============================] - 33s 325ms/step - loss: 2.9812 - mean_absolute_error: 3.3488 - root_mean_squared_error: 5.5761 - mean_absolute_percentage_error: 12.2487 - val_loss: 6.2527 - val_mean_absolute_error: 6.6474 - val_root_mean_squared_error: 11.7510 - val_mean_absolute_percentage_error: 33.6059
# Epoch 38/100
# 103/103 [==============================] - 33s 323ms/step - loss: 2.8479 - mean_absolute_error: 3.2185 - root_mean_squared_error: 5.2337 - mean_absolute_percentage_error: 12.2402 - val_loss: 5.9053 - val_mean_absolute_error: 6.2795 - val_root_mean_squared_error: 11.3183 - val_mean_absolute_percentage_error: 35.0892
# Epoch 39/100
# 103/103 [==============================] - 33s 323ms/step - loss: 2.8536 - mean_absolute_error: 3.2255 - root_mean_squared_error: 5.3503 - mean_absolute_percentage_error: 12.0253 - val_loss: 7.6912 - val_mean_absolute_error: 8.0795 - val_root_mean_squared_error: 13.0687 - val_mean_absolute_percentage_error: 41.3126
# Epoch 40/100
# 103/103 [==============================] - 33s 319ms/step - loss: 2.9325 - mean_absolute_error: 3.3022 - root_mean_squared_error: 5.4798 - mean_absolute_percentage_error: 12.2105 - val_loss: 7.6216 - val_mean_absolute_error: 8.0364 - val_root_mean_squared_error: 12.4372 - val_mean_absolute_percentage_error: 35.2110
# Epoch 41/100
# 103/103 [==============================] - 33s 321ms/step - loss: 2.9494 - mean_absolute_error: 3.3167 - root_mean_squared_error: 5.4509 - mean_absolute_percentage_error: 12.4003 - val_loss: 10.9006 - val_mean_absolute_error: 11.3189 - val_root_mean_squared_error: 15.8339 - val_mean_absolute_percentage_error: 39.8923
# Epoch 42/100
# 103/103 [==============================] - 33s 320ms/step - loss: 2.8758 - mean_absolute_error: 3.2460 - root_mean_squared_error: 5.2733 - mean_absolute_percentage_error: 12.7048 - val_loss: 6.4388 - val_mean_absolute_error: 6.8236 - val_root_mean_squared_error: 12.2638 - val_mean_absolute_percentage_error: 36.6177
# Epoch 43/100
# 103/103 [==============================] - 33s 323ms/step - loss: 2.8142 - mean_absolute_error: 3.1855 - root_mean_squared_error: 5.3408 - mean_absolute_percentage_error: 12.7917 - val_loss: 5.9466 - val_mean_absolute_error: 6.3491 - val_root_mean_squared_error: 11.2750 - val_mean_absolute_percentage_error: 40.5421
# Epoch 44/100
# 103/103 [==============================] - 33s 320ms/step - loss: 2.6950 - mean_absolute_error: 3.0640 - root_mean_squared_error: 4.9205 - mean_absolute_percentage_error: 11.9363 - val_loss: 5.6974 - val_mean_absolute_error: 6.0908 - val_root_mean_squared_error: 11.3902 - val_mean_absolute_percentage_error: 35.7537
# Epoch 45/100
# 103/103 [==============================] - 33s 324ms/step - loss: 2.6947 - mean_absolute_error: 3.0609 - root_mean_squared_error: 4.9390 - mean_absolute_percentage_error: 11.7676 - val_loss: 6.3883 - val_mean_absolute_error: 6.7889 - val_root_mean_squared_error: 11.4783 - val_mean_absolute_percentage_error: 42.6725
# Epoch 46/100
# 103/103 [==============================] - 32s 309ms/step - loss: 2.7406 - mean_absolute_error: 3.1081 - root_mean_squared_error: 5.2139 - mean_absolute_percentage_error: 11.5584 - val_loss: 5.7659 - val_mean_absolute_error: 6.1442 - val_root_mean_squared_error: 11.6567 - val_mean_absolute_percentage_error: 34.6255
# Epoch 47/100
# 103/103 [==============================] - 33s 321ms/step - loss: 2.7517 - mean_absolute_error: 3.1194 - root_mean_squared_error: 5.1077 - mean_absolute_percentage_error: 11.9350 - val_loss: 10.9336 - val_mean_absolute_error: 11.3532 - val_root_mean_squared_error: 15.9648 - val_mean_absolute_percentage_error: 59.2792
# Epoch 48/100
# 103/103 [==============================] - 33s 321ms/step - loss: 2.5349 - mean_absolute_error: 2.9025 - root_mean_squared_error: 4.6782 - mean_absolute_percentage_error: 11.5659 - val_loss: 5.7328 - val_mean_absolute_error: 6.1220 - val_root_mean_squared_error: 11.6788 - val_mean_absolute_percentage_error: 34.1165
# Epoch 49/100
# 103/103 [==============================] - 33s 322ms/step - loss: 2.5456 - mean_absolute_error: 2.9133 - root_mean_squared_error: 4.6405 - mean_absolute_percentage_error: 11.4199 - val_loss: 10.1523 - val_mean_absolute_error: 10.5695 - val_root_mean_squared_error: 15.3743 - val_mean_absolute_percentage_error: 57.4682
# Epoch 50/100
# 103/103 [==============================] - 33s 319ms/step - loss: 2.6435 - mean_absolute_error: 3.0051 - root_mean_squared_error: 5.0341 - mean_absolute_percentage_error: 11.1959 - val_loss: 6.2823 - val_mean_absolute_error: 6.6718 - val_root_mean_squared_error: 12.1850 - val_mean_absolute_percentage_error: 37.6281
# Epoch 51/100
# 103/103 [==============================] - 33s 320ms/step - loss: 2.5687 - mean_absolute_error: 2.9364 - root_mean_squared_error: 4.7665 - mean_absolute_percentage_error: 11.1805 - val_loss: 10.1218 - val_mean_absolute_error: 10.5151 - val_root_mean_squared_error: 16.3163 - val_mean_absolute_percentage_error: 49.7367
# Epoch 52/100
# 103/103 [==============================] - 34s 328ms/step - loss: 2.6248 - mean_absolute_error: 2.9880 - root_mean_squared_error: 4.9128 - mean_absolute_percentage_error: 11.2920 - val_loss: 6.0161 - val_mean_absolute_error: 6.3971 - val_root_mean_squared_error: 11.3910 - val_mean_absolute_percentage_error: 33.4014
# Epoch 53/100
# 103/103 [==============================] - 32s 309ms/step - loss: 2.5921 - mean_absolute_error: 2.9545 - root_mean_squared_error: 4.9189 - mean_absolute_percentage_error: 10.9283 - val_loss: 8.6683 - val_mean_absolute_error: 9.0878 - val_root_mean_squared_error: 13.4689 - val_mean_absolute_percentage_error: 51.2284
# Epoch 54/100
# 103/103 [==============================] - 27s 266ms/step - loss: 2.5623 - mean_absolute_error: 2.9270 - root_mean_squared_error: 4.7483 - mean_absolute_percentage_error: 11.1807 - val_loss: 7.2027 - val_mean_absolute_error: 7.6007 - val_root_mean_squared_error: 12.7363 - val_mean_absolute_percentage_error: 43.6953
# Epoch 55/100
# 103/103 [==============================] - 27s 267ms/step - loss: 2.4731 - mean_absolute_error: 2.8362 - root_mean_squared_error: 4.5915 - mean_absolute_percentage_error: 10.9302 - val_loss: 6.8454 - val_mean_absolute_error: 7.2554 - val_root_mean_squared_error: 12.1692 - val_mean_absolute_percentage_error: 43.3099
# Epoch 56/100
# 103/103 [==============================] - 28s 268ms/step - loss: 2.5790 - mean_absolute_error: 2.9455 - root_mean_squared_error: 4.7802 - mean_absolute_percentage_error: 11.0930 - val_loss: 6.8763 - val_mean_absolute_error: 7.2916 - val_root_mean_squared_error: 12.0445 - val_mean_absolute_percentage_error: 36.1035
# Epoch 57/100
# 103/103 [==============================] - 27s 265ms/step - loss: 2.4926 - mean_absolute_error: 2.8570 - root_mean_squared_error: 4.7172 - mean_absolute_percentage_error: 10.4509 - val_loss: 6.1149 - val_mean_absolute_error: 6.4978 - val_root_mean_squared_error: 11.4989 - val_mean_absolute_percentage_error: 32.1856
# Epoch 58/100
# 103/103 [==============================] - 28s 269ms/step - loss: 2.3759 - mean_absolute_error: 2.7348 - root_mean_squared_error: 4.4651 - mean_absolute_percentage_error: 10.2526 - val_loss: 10.0023 - val_mean_absolute_error: 10.4204 - val_root_mean_squared_error: 15.5331 - val_mean_absolute_percentage_error: 35.7619
# Epoch 59/100
# 103/103 [==============================] - 28s 269ms/step - loss: 2.3915 - mean_absolute_error: 2.7516 - root_mean_squared_error: 4.6284 - mean_absolute_percentage_error: 10.0598 - val_loss: 8.2919 - val_mean_absolute_error: 8.7003 - val_root_mean_squared_error: 13.2338 - val_mean_absolute_percentage_error: 34.5220
# Epoch 60/100
# 103/103 [==============================] - 27s 267ms/step - loss: 2.3129 - mean_absolute_error: 2.6707 - root_mean_squared_error: 4.3560 - mean_absolute_percentage_error: 10.2234 - val_loss: 8.3299 - val_mean_absolute_error: 8.7440 - val_root_mean_squared_error: 13.0209 - val_mean_absolute_percentage_error: 36.4486
# Epoch 61/100
# 103/103 [==============================] - 27s 266ms/step - loss: 2.5646 - mean_absolute_error: 2.9258 - root_mean_squared_error: 4.8890 - mean_absolute_percentage_error: 10.9566 - val_loss: 5.4832 - val_mean_absolute_error: 5.8507 - val_root_mean_squared_error: 11.2814 - val_mean_absolute_percentage_error: 33.1018
# Epoch 62/100
# 103/103 [==============================] - 28s 271ms/step - loss: 2.3838 - mean_absolute_error: 2.7448 - root_mean_squared_error: 4.4403 - mean_absolute_percentage_error: 10.4488 - val_loss: 5.6464 - val_mean_absolute_error: 6.0261 - val_root_mean_squared_error: 11.4725 - val_mean_absolute_percentage_error: 34.2527
# Epoch 63/100
# 103/103 [==============================] - 27s 266ms/step - loss: 2.2159 - mean_absolute_error: 2.5737 - root_mean_squared_error: 4.1871 - mean_absolute_percentage_error: 10.0051 - val_loss: 5.5887 - val_mean_absolute_error: 5.9643 - val_root_mean_squared_error: 11.4977 - val_mean_absolute_percentage_error: 33.6253
# Epoch 64/100
# 103/103 [==============================] - 28s 269ms/step - loss: 2.4547 - mean_absolute_error: 2.8177 - root_mean_squared_error: 4.8620 - mean_absolute_percentage_error: 10.4604 - val_loss: 6.1551 - val_mean_absolute_error: 6.5546 - val_root_mean_squared_error: 11.5691 - val_mean_absolute_percentage_error: 33.0093
# Epoch 65/100
# 103/103 [==============================] - 27s 267ms/step - loss: 2.3399 - mean_absolute_error: 2.7001 - root_mean_squared_error: 4.4822 - mean_absolute_percentage_error: 10.4098 - val_loss: 9.1659 - val_mean_absolute_error: 9.5831 - val_root_mean_squared_error: 14.1923 - val_mean_absolute_percentage_error: 36.8929
# Epoch 66/100
# 103/103 [==============================] - 27s 267ms/step - loss: 2.3873 - mean_absolute_error: 2.7449 - root_mean_squared_error: 4.6153 - mean_absolute_percentage_error: 9.7388 - val_loss: 7.5622 - val_mean_absolute_error: 7.9497 - val_root_mean_squared_error: 12.9988 - val_mean_absolute_percentage_error: 39.7055
# Epoch 67/100
# 103/103 [==============================] - 27s 266ms/step - loss: 2.2760 - mean_absolute_error: 2.6345 - root_mean_squared_error: 4.3738 - mean_absolute_percentage_error: 9.9246 - val_loss: 5.6826 - val_mean_absolute_error: 6.0644 - val_root_mean_squared_error: 11.3022 - val_mean_absolute_percentage_error: 34.2345
# Epoch 68/100
# 103/103 [==============================] - 28s 268ms/step - loss: 2.2581 - mean_absolute_error: 2.6136 - root_mean_squared_error: 4.4342 - mean_absolute_percentage_error: 9.7021 - val_loss: 6.1428 - val_mean_absolute_error: 6.5369 - val_root_mean_squared_error: 11.6706 - val_mean_absolute_percentage_error: 39.0398
# Epoch 69/100
# 103/103 [==============================] - 28s 269ms/step - loss: 2.2167 - mean_absolute_error: 2.5751 - root_mean_squared_error: 4.1312 - mean_absolute_percentage_error: 10.1275 - val_loss: 10.0687 - val_mean_absolute_error: 10.4842 - val_root_mean_squared_error: 15.4087 - val_mean_absolute_percentage_error: 37.3823
# Epoch 70/100
# 103/103 [==============================] - 27s 266ms/step - loss: 2.4523 - mean_absolute_error: 2.8106 - root_mean_squared_error: 4.7065 - mean_absolute_percentage_error: 10.2070 - val_loss: 12.9974 - val_mean_absolute_error: 13.4216 - val_root_mean_squared_error: 17.7251 - val_mean_absolute_percentage_error: 70.8942
# Epoch 71/100
# 103/103 [==============================] - 27s 265ms/step - loss: 2.0153 - mean_absolute_error: 2.3706 - root_mean_squared_error: 3.7553 - mean_absolute_percentage_error: 9.2681 - val_loss: 10.2757 - val_mean_absolute_error: 10.6817 - val_root_mean_squared_error: 15.5373 - val_mean_absolute_percentage_error: 53.2400
# Epoch 72/100
# 103/103 [==============================] - 28s 268ms/step - loss: 2.1183 - mean_absolute_error: 2.4751 - root_mean_squared_error: 3.9929 - mean_absolute_percentage_error: 9.8230 - val_loss: 7.8518 - val_mean_absolute_error: 8.2569 - val_root_mean_squared_error: 12.9211 - val_mean_absolute_percentage_error: 46.8267
# Epoch 73/100
# 103/103 [==============================] - 28s 267ms/step - loss: 2.1735 - mean_absolute_error: 2.5315 - root_mean_squared_error: 4.0234 - mean_absolute_percentage_error: 9.9938 - val_loss: 5.5916 - val_mean_absolute_error: 5.9578 - val_root_mean_squared_error: 11.6638 - val_mean_absolute_percentage_error: 33.4386
# Epoch 74/100
# 103/103 [==============================] - 27s 267ms/step - loss: 2.1950 - mean_absolute_error: 2.5500 - root_mean_squared_error: 4.2087 - mean_absolute_percentage_error: 9.5484 - val_loss: 6.4174 - val_mean_absolute_error: 6.8156 - val_root_mean_squared_error: 12.1102 - val_mean_absolute_percentage_error: 34.6715
# Epoch 75/100
# 103/103 [==============================] - 27s 267ms/step - loss: 2.1441 - mean_absolute_error: 2.4996 - root_mean_squared_error: 4.0865 - mean_absolute_percentage_error: 10.0191 - val_loss: 7.0055 - val_mean_absolute_error: 7.3944 - val_root_mean_squared_error: 12.5771 - val_mean_absolute_percentage_error: 40.6282
# Epoch 76/100
# 103/103 [==============================] - 27s 262ms/step - loss: 2.1471 - mean_absolute_error: 2.5029 - root_mean_squared_error: 4.0437 - mean_absolute_percentage_error: 9.6604 - val_loss: 5.6457 - val_mean_absolute_error: 6.0076 - val_root_mean_squared_error: 11.6038 - val_mean_absolute_percentage_error: 33.6387
# Epoch 77/100
# 103/103 [==============================] - 27s 262ms/step - loss: 2.1075 - mean_absolute_error: 2.4622 - root_mean_squared_error: 4.0839 - mean_absolute_percentage_error: 9.3416 - val_loss: 5.6972 - val_mean_absolute_error: 6.0612 - val_root_mean_squared_error: 11.9242 - val_mean_absolute_percentage_error: 36.2324
# Epoch 78/100
# 103/103 [==============================] - 28s 275ms/step - loss: 2.1120 - mean_absolute_error: 2.4634 - root_mean_squared_error: 4.0199 - mean_absolute_percentage_error: 9.3854 - val_loss: 7.5586 - val_mean_absolute_error: 7.9597 - val_root_mean_squared_error: 13.2207 - val_mean_absolute_percentage_error: 42.1243
# Epoch 79/100
# 103/103 [==============================] - 28s 268ms/step - loss: 2.1218 - mean_absolute_error: 2.4709 - root_mean_squared_error: 4.0226 - mean_absolute_percentage_error: 9.3437 - val_loss: 6.3034 - val_mean_absolute_error: 6.6957 - val_root_mean_squared_error: 11.9575 - val_mean_absolute_percentage_error: 33.8658
# Epoch 80/100
# 103/103 [==============================] - 28s 274ms/step - loss: 2.0783 - mean_absolute_error: 2.4287 - root_mean_squared_error: 3.9879 - mean_absolute_percentage_error: 9.1561 - val_loss: 5.6388 - val_mean_absolute_error: 6.0058 - val_root_mean_squared_error: 11.6597 - val_mean_absolute_percentage_error: 34.8476
# Epoch 81/100
# 103/103 [==============================] - 39s 380ms/step - loss: 2.1057 - mean_absolute_error: 2.4589 - root_mean_squared_error: 4.0237 - mean_absolute_percentage_error: 9.4442 - val_loss: 7.5647 - val_mean_absolute_error: 7.9737 - val_root_mean_squared_error: 12.7847 - val_mean_absolute_percentage_error: 35.8185
# Epoch 82/100
# 103/103 [==============================] - 35s 342ms/step - loss: 2.1352 - mean_absolute_error: 2.4873 - root_mean_squared_error: 4.1444 - mean_absolute_percentage_error: 9.4503 - val_loss: 5.9093 - val_mean_absolute_error: 6.3075 - val_root_mean_squared_error: 11.5026 - val_mean_absolute_percentage_error: 38.4427
# Epoch 83/100
# 103/103 [==============================] - 35s 345ms/step - loss: 1.9677 - mean_absolute_error: 2.3262 - root_mean_squared_error: 3.6967 - mean_absolute_percentage_error: 9.6689 - val_loss: 6.0897 - val_mean_absolute_error: 6.4639 - val_root_mean_squared_error: 11.7521 - val_mean_absolute_percentage_error: 34.5272
# Epoch 84/100
# 103/103 [==============================] - 36s 353ms/step - loss: 2.0379 - mean_absolute_error: 2.3894 - root_mean_squared_error: 4.0939 - mean_absolute_percentage_error: 9.1079 - val_loss: 5.5490 - val_mean_absolute_error: 5.9110 - val_root_mean_squared_error: 11.7039 - val_mean_absolute_percentage_error: 35.2510
# Epoch 85/100
# 103/103 [==============================] - 37s 358ms/step - loss: 2.0634 - mean_absolute_error: 2.4135 - root_mean_squared_error: 3.9547 - mean_absolute_percentage_error: 9.2700 - val_loss: 6.5611 - val_mean_absolute_error: 6.9330 - val_root_mean_squared_error: 12.7275 - val_mean_absolute_percentage_error: 34.6755
# Epoch 86/100
# 103/103 [==============================] - 37s 355ms/step - loss: 1.9682 - mean_absolute_error: 2.3151 - root_mean_squared_error: 3.8408 - mean_absolute_percentage_error: 8.7512 - val_loss: 6.1085 - val_mean_absolute_error: 6.5139 - val_root_mean_squared_error: 12.1283 - val_mean_absolute_percentage_error: 33.6808
# Epoch 87/100
# 103/103 [==============================] - 33s 316ms/step - loss: 2.0407 - mean_absolute_error: 2.3941 - root_mean_squared_error: 3.8691 - mean_absolute_percentage_error: 9.3763 - val_loss: 7.8396 - val_mean_absolute_error: 8.2340 - val_root_mean_squared_error: 13.6735 - val_mean_absolute_percentage_error: 44.4917
# Epoch 88/100
# 103/103 [==============================] - 34s 326ms/step - loss: 2.1283 - mean_absolute_error: 2.4832 - root_mean_squared_error: 4.0193 - mean_absolute_percentage_error: 9.5555 - val_loss: 5.7299 - val_mean_absolute_error: 6.0909 - val_root_mean_squared_error: 11.8781 - val_mean_absolute_percentage_error: 34.7265
# Epoch 89/100
# 103/103 [==============================] - 33s 324ms/step - loss: 2.0961 - mean_absolute_error: 2.4519 - root_mean_squared_error: 3.9333 - mean_absolute_percentage_error: 9.6366 - val_loss: 7.8922 - val_mean_absolute_error: 8.2885 - val_root_mean_squared_error: 13.5791 - val_mean_absolute_percentage_error: 43.3422
# Epoch 90/100
# 103/103 [==============================] - 32s 308ms/step - loss: 1.9834 - mean_absolute_error: 2.3366 - root_mean_squared_error: 3.7569 - mean_absolute_percentage_error: 8.9946 - val_loss: 6.6220 - val_mean_absolute_error: 6.9970 - val_root_mean_squared_error: 12.6534 - val_mean_absolute_percentage_error: 38.4263
# Epoch 91/100
# 103/103 [==============================] - 33s 317ms/step - loss: 2.1203 - mean_absolute_error: 2.4681 - root_mean_squared_error: 4.0339 - mean_absolute_percentage_error: 8.6943 - val_loss: 7.4635 - val_mean_absolute_error: 7.8695 - val_root_mean_squared_error: 12.8054 - val_mean_absolute_percentage_error: 34.3225
# Epoch 92/100
# 103/103 [==============================] - 33s 318ms/step - loss: 1.9497 - mean_absolute_error: 2.2969 - root_mean_squared_error: 3.8004 - mean_absolute_percentage_error: 8.6019 - val_loss: 6.1157 - val_mean_absolute_error: 6.5135 - val_root_mean_squared_error: 11.8106 - val_mean_absolute_percentage_error: 32.6723
# Epoch 93/100
# 103/103 [==============================] - 28s 268ms/step - loss: 1.9651 - mean_absolute_error: 2.3144 - root_mean_squared_error: 3.7534 - mean_absolute_percentage_error: 9.1922 - val_loss: 5.2764 - val_mean_absolute_error: 5.6365 - val_root_mean_squared_error: 11.4849 - val_mean_absolute_percentage_error: 32.0719
# Epoch 94/100
# 103/103 [==============================] - 27s 264ms/step - loss: 1.9407 - mean_absolute_error: 2.2844 - root_mean_squared_error: 3.7962 - mean_absolute_percentage_error: 8.3390 - val_loss: 7.5474 - val_mean_absolute_error: 7.9607 - val_root_mean_squared_error: 12.7124 - val_mean_absolute_percentage_error: 36.1723
# Epoch 95/100
# 103/103 [==============================] - 27s 267ms/step - loss: 1.9477 - mean_absolute_error: 2.2960 - root_mean_squared_error: 3.9433 - mean_absolute_percentage_error: 8.4071 - val_loss: 5.7884 - val_mean_absolute_error: 6.1493 - val_root_mean_squared_error: 12.4521 - val_mean_absolute_percentage_error: 34.2648
# Epoch 96/100
# 103/103 [==============================] - 27s 266ms/step - loss: 1.9032 - mean_absolute_error: 2.2490 - root_mean_squared_error: 3.6583 - mean_absolute_percentage_error: 8.2904 - val_loss: 7.0543 - val_mean_absolute_error: 7.4453 - val_root_mean_squared_error: 12.6734 - val_mean_absolute_percentage_error: 34.2034
# Epoch 97/100
# 103/103 [==============================] - 27s 265ms/step - loss: 1.9764 - mean_absolute_error: 2.3287 - root_mean_squared_error: 3.8621 - mean_absolute_percentage_error: 9.0283 - val_loss: 6.9956 - val_mean_absolute_error: 7.3674 - val_root_mean_squared_error: 13.6069 - val_mean_absolute_percentage_error: 36.5405
# Epoch 98/100
# 103/103 [==============================] - 27s 266ms/step - loss: 1.8791 - mean_absolute_error: 2.2197 - root_mean_squared_error: 3.8825 - mean_absolute_percentage_error: 8.2472 - val_loss: 8.9580 - val_mean_absolute_error: 9.3515 - val_root_mean_squared_error: 15.0235 - val_mean_absolute_percentage_error: 47.1628
# Epoch 99/100
# 103/103 [==============================] - 27s 263ms/step - loss: 1.8593 - mean_absolute_error: 2.2069 - root_mean_squared_error: 3.6164 - mean_absolute_percentage_error: 8.6615 - val_loss: 6.2308 - val_mean_absolute_error: 6.5968 - val_root_mean_squared_error: 12.4822 - val_mean_absolute_percentage_error: 39.5412
# Epoch 100/100
# 103/103 [==============================] - 27s 264ms/step - loss: 2.0483 - mean_absolute_error: 2.3992 - root_mean_squared_error: 3.9997 - mean_absolute_percentage_error: 8.7909 - val_loss: 5.9910 - val_mean_absolute_error: 6.3682 - val_root_mean_squared_error: 12.2427 - val_mean_absolute_percentage_error: 38.1405

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 117ms/step - loss: 5.9910 - mean_absolute_error: 6.3682 - root_mean_squared_error: 12.2427 - mean_absolute_percentage_error: 38.1405
# Model Loss: [5.990980625152588, 6.36824893951416, 12.242688179016113, 38.14048767089844]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [15.49377]

# %%
model_scenario_name = "BiLSTM_9"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_9\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_9\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_9"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [15.49377]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
