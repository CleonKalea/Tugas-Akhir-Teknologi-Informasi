# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_35752\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=128 
)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(embedding_layer)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(64, activation='relu')(numerical_input)

combined = tf.keras.layers.Concatenate()([lstm_output, numerical_dense])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 128)    2344704     ['text_input[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional (Bidirectional)  (None, 128)          98816       ['embedding[0][0]']
#
#  dense (Dense)                  (None, 64)           384         ['numerical_input[0][0]']
#
#  concatenate (Concatenate)      (None, 192)          0           ['bidirectional[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            193         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2,444,097
# Trainable params: 2,444,097
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 12s 93ms/step - loss: 15.2507 - mean_absolute_error: 15.7419 - root_mean_squared_error: 22.7677 - mean_absolute_percentage_error: 109.3155 - val_loss: 14.2657 - val_mean_absolute_error: 14.7595 - val_root_mean_squared_error: 20.7752 - val_mean_absolute_percentage_error: 116.7133
# Epoch 2/100
# 103/103 [==============================] - 9s 86ms/step - loss: 12.6968 - mean_absolute_error: 13.1869 - root_mean_squared_error: 18.6730 - mean_absolute_percentage_error: 109.2985 - val_loss: 12.6633 - val_mean_absolute_error: 13.1539 - val_root_mean_squared_error: 19.6035 - val_mean_absolute_percentage_error: 100.6222
# Epoch 3/100
# 103/103 [==============================] - 9s 87ms/step - loss: 11.7974 - mean_absolute_error: 12.2841 - root_mean_squared_error: 17.9533 - mean_absolute_percentage_error: 94.7939 - val_loss: 11.6858 - val_mean_absolute_error: 12.1707 - val_root_mean_squared_error: 18.8105 - val_mean_absolute_percentage_error: 89.6884
# Epoch 4/100
# 103/103 [==============================] - 9s 88ms/step - loss: 11.2479 - mean_absolute_error: 11.7343 - root_mean_squared_error: 17.3886 - mean_absolute_percentage_error: 86.7507 - val_loss: 12.2546 - val_mean_absolute_error: 12.7451 - val_root_mean_squared_error: 19.1408 - val_mean_absolute_percentage_error: 90.7246
# Epoch 5/100
# 103/103 [==============================] - 10s 97ms/step - loss: 11.6334 - mean_absolute_error: 12.1207 - root_mean_squared_error: 17.7690 - mean_absolute_percentage_error: 98.7232 - val_loss: 11.4051 - val_mean_absolute_error: 11.8902 - val_root_mean_squared_error: 18.4255 - val_mean_absolute_percentage_error: 93.1026
# Epoch 6/100
# 103/103 [==============================] - 11s 106ms/step - loss: 9.5862 - mean_absolute_error: 10.0678 - root_mean_squared_error: 15.8840 - mean_absolute_percentage_error: 74.6702 - val_loss: 10.5439 - val_mean_absolute_error: 11.0299 - val_root_mean_squared_error: 17.1942 - val_mean_absolute_percentage_error: 84.4810
# Epoch 7/100
# 103/103 [==============================] - 11s 108ms/step - loss: 8.0793 - mean_absolute_error: 8.5595 - root_mean_squared_error: 13.9821 - mean_absolute_percentage_error: 60.7416 - val_loss: 9.7057 - val_mean_absolute_error: 10.1886 - val_root_mean_squared_error: 16.5544 - val_mean_absolute_percentage_error: 68.5389
# Epoch 8/100
# 103/103 [==============================] - 12s 113ms/step - loss: 6.7845 - mean_absolute_error: 7.2583 - root_mean_squared_error: 12.6738 - mean_absolute_percentage_error: 47.1101 - val_loss: 9.1381 - val_mean_absolute_error: 9.6201 - val_root_mean_squared_error: 15.9332 - val_mean_absolute_percentage_error: 61.1605
# Epoch 9/100
# 103/103 [==============================] - 13s 122ms/step - loss: 5.7561 - mean_absolute_error: 6.2253 - root_mean_squared_error: 11.4848 - mean_absolute_percentage_error: 40.1092 - val_loss: 8.7598 - val_mean_absolute_error: 9.2380 - val_root_mean_squared_error: 15.5404 - val_mean_absolute_percentage_error: 58.4459
# Epoch 10/100
# 103/103 [==============================] - 13s 128ms/step - loss: 5.0262 - mean_absolute_error: 5.4875 - root_mean_squared_error: 10.5735 - mean_absolute_percentage_error: 34.8892 - val_loss: 8.4641 - val_mean_absolute_error: 8.9394 - val_root_mean_squared_error: 15.2200 - val_mean_absolute_percentage_error: 57.4427
# Epoch 11/100
# 103/103 [==============================] - 13s 129ms/step - loss: 4.4454 - mean_absolute_error: 4.9026 - root_mean_squared_error: 9.8146 - mean_absolute_percentage_error: 30.1806 - val_loss: 8.3529 - val_mean_absolute_error: 8.8299 - val_root_mean_squared_error: 15.3053 - val_mean_absolute_percentage_error: 52.8876
# Epoch 12/100
# 103/103 [==============================] - 12s 116ms/step - loss: 3.8906 - mean_absolute_error: 4.3375 - root_mean_squared_error: 9.1984 - mean_absolute_percentage_error: 26.7437 - val_loss: 8.2397 - val_mean_absolute_error: 8.7150 - val_root_mean_squared_error: 14.9701 - val_mean_absolute_percentage_error: 53.6374
# Epoch 13/100
# 103/103 [==============================] - 10s 99ms/step - loss: 3.4159 - mean_absolute_error: 3.8550 - root_mean_squared_error: 8.5430 - mean_absolute_percentage_error: 24.4757 - val_loss: 7.9462 - val_mean_absolute_error: 8.4102 - val_root_mean_squared_error: 14.5268 - val_mean_absolute_percentage_error: 53.0843
# Epoch 14/100
# 103/103 [==============================] - 11s 103ms/step - loss: 3.2506 - mean_absolute_error: 3.6947 - root_mean_squared_error: 8.1272 - mean_absolute_percentage_error: 23.5015 - val_loss: 7.8857 - val_mean_absolute_error: 8.3606 - val_root_mean_squared_error: 14.4306 - val_mean_absolute_percentage_error: 53.5177
# Epoch 15/100
# 103/103 [==============================] - 11s 104ms/step - loss: 2.9235 - mean_absolute_error: 3.3600 - root_mean_squared_error: 7.6357 - mean_absolute_percentage_error: 22.0654 - val_loss: 8.0893 - val_mean_absolute_error: 8.5559 - val_root_mean_squared_error: 14.4054 - val_mean_absolute_percentage_error: 57.0198
# Epoch 16/100
# 103/103 [==============================] - 11s 106ms/step - loss: 2.6119 - mean_absolute_error: 3.0404 - root_mean_squared_error: 7.1889 - mean_absolute_percentage_error: 19.5641 - val_loss: 7.6451 - val_mean_absolute_error: 8.1063 - val_root_mean_squared_error: 14.0588 - val_mean_absolute_percentage_error: 54.5529
# Epoch 17/100
# 103/103 [==============================] - 10s 102ms/step - loss: 2.3627 - mean_absolute_error: 2.7843 - root_mean_squared_error: 6.8143 - mean_absolute_percentage_error: 17.8797 - val_loss: 7.5358 - val_mean_absolute_error: 7.9943 - val_root_mean_squared_error: 14.0778 - val_mean_absolute_percentage_error: 51.6983
# Epoch 18/100
# 103/103 [==============================] - 11s 107ms/step - loss: 2.1814 - mean_absolute_error: 2.6006 - root_mean_squared_error: 6.4491 - mean_absolute_percentage_error: 16.9269 - val_loss: 7.5381 - val_mean_absolute_error: 8.0039 - val_root_mean_squared_error: 13.8680 - val_mean_absolute_percentage_error: 52.7024
# Epoch 19/100
# 103/103 [==============================] - 11s 104ms/step - loss: 2.0180 - mean_absolute_error: 2.4325 - root_mean_squared_error: 6.1320 - mean_absolute_percentage_error: 16.4328 - val_loss: 7.6076 - val_mean_absolute_error: 8.0655 - val_root_mean_squared_error: 14.1243 - val_mean_absolute_percentage_error: 53.9014
# Epoch 20/100
# 103/103 [==============================] - 11s 103ms/step - loss: 1.9164 - mean_absolute_error: 2.3265 - root_mean_squared_error: 5.9023 - mean_absolute_percentage_error: 15.5287 - val_loss: 7.4210 - val_mean_absolute_error: 7.8823 - val_root_mean_squared_error: 13.8114 - val_mean_absolute_percentage_error: 52.0888
# Epoch 21/100
# 103/103 [==============================] - 11s 106ms/step - loss: 1.6851 - mean_absolute_error: 2.0832 - root_mean_squared_error: 5.5898 - mean_absolute_percentage_error: 14.1106 - val_loss: 7.2722 - val_mean_absolute_error: 7.7264 - val_root_mean_squared_error: 13.7532 - val_mean_absolute_percentage_error: 50.8875
# Epoch 22/100
# 103/103 [==============================] - 11s 103ms/step - loss: 1.5834 - mean_absolute_error: 1.9806 - root_mean_squared_error: 5.3283 - mean_absolute_percentage_error: 13.2839 - val_loss: 7.4578 - val_mean_absolute_error: 7.9267 - val_root_mean_squared_error: 13.8745 - val_mean_absolute_percentage_error: 49.6461
# Epoch 23/100
# 103/103 [==============================] - 11s 110ms/step - loss: 1.6538 - mean_absolute_error: 2.0678 - root_mean_squared_error: 5.1617 - mean_absolute_percentage_error: 13.3735 - val_loss: 7.3946 - val_mean_absolute_error: 7.8467 - val_root_mean_squared_error: 13.8291 - val_mean_absolute_percentage_error: 53.1536
# Epoch 24/100
# 103/103 [==============================] - 11s 106ms/step - loss: 1.5863 - mean_absolute_error: 1.9999 - root_mean_squared_error: 5.0175 - mean_absolute_percentage_error: 13.2665 - val_loss: 7.2877 - val_mean_absolute_error: 7.7438 - val_root_mean_squared_error: 13.6647 - val_mean_absolute_percentage_error: 50.8805
# Epoch 25/100
# 103/103 [==============================] - 11s 106ms/step - loss: 1.3795 - mean_absolute_error: 1.7796 - root_mean_squared_error: 4.8080 - mean_absolute_percentage_error: 11.6132 - val_loss: 7.2498 - val_mean_absolute_error: 7.7100 - val_root_mean_squared_error: 13.7450 - val_mean_absolute_percentage_error: 49.8371
# Epoch 26/100
# 103/103 [==============================] - 13s 126ms/step - loss: 1.2948 - mean_absolute_error: 1.6905 - root_mean_squared_error: 4.6223 - mean_absolute_percentage_error: 11.0853 - val_loss: 7.1744 - val_mean_absolute_error: 7.6245 - val_root_mean_squared_error: 13.6131 - val_mean_absolute_percentage_error: 50.3006
# Epoch 27/100
# 103/103 [==============================] - 13s 128ms/step - loss: 1.2310 - mean_absolute_error: 1.6221 - root_mean_squared_error: 4.4713 - mean_absolute_percentage_error: 10.6253 - val_loss: 7.2677 - val_mean_absolute_error: 7.7278 - val_root_mean_squared_error: 13.6993 - val_mean_absolute_percentage_error: 52.0758
# Epoch 28/100
# 103/103 [==============================] - 13s 128ms/step - loss: 1.1257 - mean_absolute_error: 1.5109 - root_mean_squared_error: 4.3636 - mean_absolute_percentage_error: 9.8681 - val_loss: 7.1192 - val_mean_absolute_error: 7.5712 - val_root_mean_squared_error: 13.6034 - val_mean_absolute_percentage_error: 50.2233
# Epoch 29/100
# 103/103 [==============================] - 11s 105ms/step - loss: 1.0712 - mean_absolute_error: 1.4541 - root_mean_squared_error: 4.2098 - mean_absolute_percentage_error: 9.5157 - val_loss: 7.0771 - val_mean_absolute_error: 7.5275 - val_root_mean_squared_error: 13.5810 - val_mean_absolute_percentage_error: 49.2317
# Epoch 30/100
# 103/103 [==============================] - 10s 99ms/step - loss: 1.0683 - mean_absolute_error: 1.4562 - root_mean_squared_error: 4.0771 - mean_absolute_percentage_error: 9.1027 - val_loss: 7.1954 - val_mean_absolute_error: 7.6585 - val_root_mean_squared_error: 13.6130 - val_mean_absolute_percentage_error: 51.0558
# Epoch 31/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.9926 - mean_absolute_error: 1.3749 - root_mean_squared_error: 3.9669 - mean_absolute_percentage_error: 8.5724 - val_loss: 7.0899 - val_mean_absolute_error: 7.5311 - val_root_mean_squared_error: 13.6541 - val_mean_absolute_percentage_error: 49.8016
# Epoch 32/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.9279 - mean_absolute_error: 1.3052 - root_mean_squared_error: 3.8607 - mean_absolute_percentage_error: 7.9745 - val_loss: 7.2027 - val_mean_absolute_error: 7.6470 - val_root_mean_squared_error: 13.8134 - val_mean_absolute_percentage_error: 51.9025
# Epoch 33/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.8311 - mean_absolute_error: 1.1992 - root_mean_squared_error: 3.7221 - mean_absolute_percentage_error: 7.4817 - val_loss: 7.0439 - val_mean_absolute_error: 7.4900 - val_root_mean_squared_error: 13.5945 - val_mean_absolute_percentage_error: 49.5434
# Epoch 34/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.7818 - mean_absolute_error: 1.1458 - root_mean_squared_error: 3.6557 - mean_absolute_percentage_error: 7.1626 - val_loss: 7.0729 - val_mean_absolute_error: 7.5331 - val_root_mean_squared_error: 13.5076 - val_mean_absolute_percentage_error: 48.3648
# Epoch 35/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.8050 - mean_absolute_error: 1.1691 - root_mean_squared_error: 3.6025 - mean_absolute_percentage_error: 6.8937 - val_loss: 7.0479 - val_mean_absolute_error: 7.5028 - val_root_mean_squared_error: 13.5298 - val_mean_absolute_percentage_error: 48.8110
# Epoch 36/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.8025 - mean_absolute_error: 1.1734 - root_mean_squared_error: 3.5747 - mean_absolute_percentage_error: 7.1140 - val_loss: 7.1744 - val_mean_absolute_error: 7.6413 - val_root_mean_squared_error: 13.5967 - val_mean_absolute_percentage_error: 51.8683
# Epoch 37/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.7609 - mean_absolute_error: 1.1279 - root_mean_squared_error: 3.4789 - mean_absolute_percentage_error: 6.6465 - val_loss: 6.9600 - val_mean_absolute_error: 7.4114 - val_root_mean_squared_error: 13.4116 - val_mean_absolute_percentage_error: 49.4964
# Epoch 38/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.7553 - mean_absolute_error: 1.1208 - root_mean_squared_error: 3.4087 - mean_absolute_percentage_error: 6.6628 - val_loss: 7.0383 - val_mean_absolute_error: 7.4808 - val_root_mean_squared_error: 13.5537 - val_mean_absolute_percentage_error: 49.7257
# Epoch 39/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.8073 - mean_absolute_error: 1.1843 - root_mean_squared_error: 3.4062 - mean_absolute_percentage_error: 7.0889 - val_loss: 6.9578 - val_mean_absolute_error: 7.4080 - val_root_mean_squared_error: 13.3512 - val_mean_absolute_percentage_error: 50.4276
# Epoch 40/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.7385 - mean_absolute_error: 1.1124 - root_mean_squared_error: 3.2958 - mean_absolute_percentage_error: 6.5727 - val_loss: 7.0112 - val_mean_absolute_error: 7.4648 - val_root_mean_squared_error: 13.4551 - val_mean_absolute_percentage_error: 50.1121
# Epoch 41/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.6740 - mean_absolute_error: 1.0316 - root_mean_squared_error: 3.2364 - mean_absolute_percentage_error: 6.1905 - val_loss: 6.8502 - val_mean_absolute_error: 7.2889 - val_root_mean_squared_error: 13.3546 - val_mean_absolute_percentage_error: 48.0009
# Epoch 42/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.6427 - mean_absolute_error: 0.9943 - root_mean_squared_error: 3.1743 - mean_absolute_percentage_error: 5.9453 - val_loss: 7.0201 - val_mean_absolute_error: 7.4723 - val_root_mean_squared_error: 13.4792 - val_mean_absolute_percentage_error: 50.5626
# Epoch 43/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.6439 - mean_absolute_error: 1.0029 - root_mean_squared_error: 3.1065 - mean_absolute_percentage_error: 5.7025 - val_loss: 6.8610 - val_mean_absolute_error: 7.2986 - val_root_mean_squared_error: 13.4265 - val_mean_absolute_percentage_error: 48.1922
# Epoch 44/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.6254 - mean_absolute_error: 0.9824 - root_mean_squared_error: 3.0661 - mean_absolute_percentage_error: 5.6838 - val_loss: 7.0195 - val_mean_absolute_error: 7.4611 - val_root_mean_squared_error: 13.5496 - val_mean_absolute_percentage_error: 50.0810
# Epoch 45/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.6356 - mean_absolute_error: 0.9920 - root_mean_squared_error: 3.0623 - mean_absolute_percentage_error: 5.9925 - val_loss: 6.8990 - val_mean_absolute_error: 7.3408 - val_root_mean_squared_error: 13.3992 - val_mean_absolute_percentage_error: 48.9188
# Epoch 46/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.5752 - mean_absolute_error: 0.9167 - root_mean_squared_error: 2.9972 - mean_absolute_percentage_error: 5.3486 - val_loss: 6.9028 - val_mean_absolute_error: 7.3522 - val_root_mean_squared_error: 13.3608 - val_mean_absolute_percentage_error: 50.1939
# Epoch 47/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5563 - mean_absolute_error: 0.8943 - root_mean_squared_error: 2.9387 - mean_absolute_percentage_error: 5.0820 - val_loss: 6.8497 - val_mean_absolute_error: 7.2844 - val_root_mean_squared_error: 13.2976 - val_mean_absolute_percentage_error: 49.3615
# Epoch 48/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5690 - mean_absolute_error: 0.9170 - root_mean_squared_error: 2.8899 - mean_absolute_percentage_error: 5.4972 - val_loss: 6.7983 - val_mean_absolute_error: 7.2315 - val_root_mean_squared_error: 13.2255 - val_mean_absolute_percentage_error: 48.7523
# Epoch 49/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.6129 - mean_absolute_error: 0.9755 - root_mean_squared_error: 2.8754 - mean_absolute_percentage_error: 5.7065 - val_loss: 6.8643 - val_mean_absolute_error: 7.3057 - val_root_mean_squared_error: 13.1905 - val_mean_absolute_percentage_error: 48.4754
# Epoch 50/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.6000 - mean_absolute_error: 0.9572 - root_mean_squared_error: 2.8782 - mean_absolute_percentage_error: 5.6587 - val_loss: 6.8807 - val_mean_absolute_error: 7.3282 - val_root_mean_squared_error: 13.3400 - val_mean_absolute_percentage_error: 49.0190
# Epoch 51/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.5448 - mean_absolute_error: 0.8896 - root_mean_squared_error: 2.7979 - mean_absolute_percentage_error: 5.1209 - val_loss: 6.8341 - val_mean_absolute_error: 7.2737 - val_root_mean_squared_error: 13.1744 - val_mean_absolute_percentage_error: 48.4919
# Epoch 52/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5413 - mean_absolute_error: 0.8886 - root_mean_squared_error: 2.7566 - mean_absolute_percentage_error: 5.1324 - val_loss: 6.8562 - val_mean_absolute_error: 7.2990 - val_root_mean_squared_error: 13.2423 - val_mean_absolute_percentage_error: 47.6909
# Epoch 53/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.5213 - mean_absolute_error: 0.8635 - root_mean_squared_error: 2.7556 - mean_absolute_percentage_error: 4.9801 - val_loss: 6.8498 - val_mean_absolute_error: 7.2901 - val_root_mean_squared_error: 13.2666 - val_mean_absolute_percentage_error: 49.6719
# Epoch 54/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5495 - mean_absolute_error: 0.9009 - root_mean_squared_error: 2.7163 - mean_absolute_percentage_error: 5.4147 - val_loss: 6.9910 - val_mean_absolute_error: 7.4596 - val_root_mean_squared_error: 13.1309 - val_mean_absolute_percentage_error: 50.6016
# Epoch 55/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.6275 - mean_absolute_error: 0.9980 - root_mean_squared_error: 2.7377 - mean_absolute_percentage_error: 6.0388 - val_loss: 6.8523 - val_mean_absolute_error: 7.2922 - val_root_mean_squared_error: 13.2867 - val_mean_absolute_percentage_error: 49.6415
# Epoch 56/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5381 - mean_absolute_error: 0.8873 - root_mean_squared_error: 2.6675 - mean_absolute_percentage_error: 5.4497 - val_loss: 6.7314 - val_mean_absolute_error: 7.1599 - val_root_mean_squared_error: 13.1610 - val_mean_absolute_percentage_error: 47.8784
# Epoch 57/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.4786 - mean_absolute_error: 0.8033 - root_mean_squared_error: 2.6497 - mean_absolute_percentage_error: 4.6663 - val_loss: 6.7801 - val_mean_absolute_error: 7.2124 - val_root_mean_squared_error: 13.1795 - val_mean_absolute_percentage_error: 48.7611
# Epoch 58/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.4837 - mean_absolute_error: 0.8148 - root_mean_squared_error: 2.6028 - mean_absolute_percentage_error: 4.6756 - val_loss: 6.7809 - val_mean_absolute_error: 7.2137 - val_root_mean_squared_error: 13.1806 - val_mean_absolute_percentage_error: 48.9530
# Epoch 59/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.4547 - mean_absolute_error: 0.7796 - root_mean_squared_error: 2.5561 - mean_absolute_percentage_error: 4.5632 - val_loss: 6.6883 - val_mean_absolute_error: 7.1149 - val_root_mean_squared_error: 13.0750 - val_mean_absolute_percentage_error: 47.8320
# Epoch 60/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.4598 - mean_absolute_error: 0.7905 - root_mean_squared_error: 2.5479 - mean_absolute_percentage_error: 4.6611 - val_loss: 6.7170 - val_mean_absolute_error: 7.1498 - val_root_mean_squared_error: 13.1216 - val_mean_absolute_percentage_error: 47.8836
# Epoch 61/100
# 103/103 [==============================] - 10s 101ms/step - loss: 0.4473 - mean_absolute_error: 0.7748 - root_mean_squared_error: 2.5098 - mean_absolute_percentage_error: 4.5362 - val_loss: 6.9432 - val_mean_absolute_error: 7.4105 - val_root_mean_squared_error: 13.1307 - val_mean_absolute_percentage_error: 50.8090
# Epoch 62/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.4468 - mean_absolute_error: 0.7732 - root_mean_squared_error: 2.4952 - mean_absolute_percentage_error: 4.3711 - val_loss: 6.6807 - val_mean_absolute_error: 7.1145 - val_root_mean_squared_error: 13.0690 - val_mean_absolute_percentage_error: 47.8797
# Epoch 63/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.4362 - mean_absolute_error: 0.7588 - root_mean_squared_error: 2.4965 - mean_absolute_percentage_error: 4.5346 - val_loss: 6.8433 - val_mean_absolute_error: 7.3076 - val_root_mean_squared_error: 13.1764 - val_mean_absolute_percentage_error: 47.7886
# Epoch 64/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5701 - mean_absolute_error: 0.9209 - root_mean_squared_error: 2.5355 - mean_absolute_percentage_error: 5.7981 - val_loss: 6.7884 - val_mean_absolute_error: 7.2224 - val_root_mean_squared_error: 13.0237 - val_mean_absolute_percentage_error: 48.8627
# Epoch 65/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.5136 - mean_absolute_error: 0.8587 - root_mean_squared_error: 2.4736 - mean_absolute_percentage_error: 5.1192 - val_loss: 6.7825 - val_mean_absolute_error: 7.2157 - val_root_mean_squared_error: 13.0737 - val_mean_absolute_percentage_error: 49.3899
# Epoch 66/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.4476 - mean_absolute_error: 0.7781 - root_mean_squared_error: 2.3992 - mean_absolute_percentage_error: 4.6537 - val_loss: 6.7810 - val_mean_absolute_error: 7.2246 - val_root_mean_squared_error: 13.0810 - val_mean_absolute_percentage_error: 48.5419
# Epoch 67/100
# 103/103 [==============================] - 10s 102ms/step - loss: 0.3914 - mean_absolute_error: 0.7067 - root_mean_squared_error: 2.3352 - mean_absolute_percentage_error: 4.2289 - val_loss: 6.7389 - val_mean_absolute_error: 7.1742 - val_root_mean_squared_error: 13.0373 - val_mean_absolute_percentage_error: 47.8730
# Epoch 68/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.3963 - mean_absolute_error: 0.7207 - root_mean_squared_error: 2.2963 - mean_absolute_percentage_error: 4.3740 - val_loss: 6.6912 - val_mean_absolute_error: 7.1241 - val_root_mean_squared_error: 12.9642 - val_mean_absolute_percentage_error: 47.9945
# Epoch 69/100
# 103/103 [==============================] - 10s 97ms/step - loss: 0.3995 - mean_absolute_error: 0.7239 - root_mean_squared_error: 2.2844 - mean_absolute_percentage_error: 4.3514 - val_loss: 6.7290 - val_mean_absolute_error: 7.1582 - val_root_mean_squared_error: 13.1267 - val_mean_absolute_percentage_error: 47.8658
# Epoch 70/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.3640 - mean_absolute_error: 0.6729 - root_mean_squared_error: 2.2294 - mean_absolute_percentage_error: 3.8381 - val_loss: 6.6591 - val_mean_absolute_error: 7.0993 - val_root_mean_squared_error: 12.8718 - val_mean_absolute_percentage_error: 46.9442
# Epoch 71/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.3825 - mean_absolute_error: 0.7048 - root_mean_squared_error: 2.2120 - mean_absolute_percentage_error: 4.2252 - val_loss: 6.7021 - val_mean_absolute_error: 7.1359 - val_root_mean_squared_error: 13.0136 - val_mean_absolute_percentage_error: 47.9587
# Epoch 72/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.4007 - mean_absolute_error: 0.7315 - root_mean_squared_error: 2.2076 - mean_absolute_percentage_error: 4.3347 - val_loss: 6.6830 - val_mean_absolute_error: 7.1155 - val_root_mean_squared_error: 13.0262 - val_mean_absolute_percentage_error: 47.2345
# Epoch 73/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.3734 - mean_absolute_error: 0.6942 - root_mean_squared_error: 2.1727 - mean_absolute_percentage_error: 4.3448 - val_loss: 6.6622 - val_mean_absolute_error: 7.0875 - val_root_mean_squared_error: 13.0285 - val_mean_absolute_percentage_error: 47.2838
# Epoch 74/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.3563 - mean_absolute_error: 0.6699 - root_mean_squared_error: 2.1365 - mean_absolute_percentage_error: 3.9290 - val_loss: 6.6896 - val_mean_absolute_error: 7.1118 - val_root_mean_squared_error: 13.0281 - val_mean_absolute_percentage_error: 48.3206
# Epoch 75/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.3833 - mean_absolute_error: 0.7044 - root_mean_squared_error: 2.1445 - mean_absolute_percentage_error: 4.1960 - val_loss: 6.6788 - val_mean_absolute_error: 7.1057 - val_root_mean_squared_error: 13.0389 - val_mean_absolute_percentage_error: 47.6249
# Epoch 76/100
# 103/103 [==============================] - 11s 103ms/step - loss: 0.3730 - mean_absolute_error: 0.6927 - root_mean_squared_error: 2.1199 - mean_absolute_percentage_error: 4.1157 - val_loss: 6.7482 - val_mean_absolute_error: 7.1879 - val_root_mean_squared_error: 13.1784 - val_mean_absolute_percentage_error: 47.4087
# Epoch 77/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.3475 - mean_absolute_error: 0.6558 - root_mean_squared_error: 2.0874 - mean_absolute_percentage_error: 3.9738 - val_loss: 6.6484 - val_mean_absolute_error: 7.0633 - val_root_mean_squared_error: 12.9774 - val_mean_absolute_percentage_error: 48.0540
# Epoch 78/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3263 - mean_absolute_error: 0.6330 - root_mean_squared_error: 2.0540 - mean_absolute_percentage_error: 3.8902 - val_loss: 6.6203 - val_mean_absolute_error: 7.0561 - val_root_mean_squared_error: 12.9971 - val_mean_absolute_percentage_error: 46.2654
# Epoch 79/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3312 - mean_absolute_error: 0.6364 - root_mean_squared_error: 2.0585 - mean_absolute_percentage_error: 3.9100 - val_loss: 6.5968 - val_mean_absolute_error: 7.0105 - val_root_mean_squared_error: 12.9764 - val_mean_absolute_percentage_error: 47.0954
# Epoch 80/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3124 - mean_absolute_error: 0.6058 - root_mean_squared_error: 2.0161 - mean_absolute_percentage_error: 3.6140 - val_loss: 6.6624 - val_mean_absolute_error: 7.0913 - val_root_mean_squared_error: 13.0337 - val_mean_absolute_percentage_error: 47.7466
# Epoch 81/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3078 - mean_absolute_error: 0.6063 - root_mean_squared_error: 1.9946 - mean_absolute_percentage_error: 3.5892 - val_loss: 6.6152 - val_mean_absolute_error: 7.0388 - val_root_mean_squared_error: 12.9339 - val_mean_absolute_percentage_error: 46.9448
# Epoch 82/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3297 - mean_absolute_error: 0.6396 - root_mean_squared_error: 1.9928 - mean_absolute_percentage_error: 4.0134 - val_loss: 6.6692 - val_mean_absolute_error: 7.0894 - val_root_mean_squared_error: 13.0558 - val_mean_absolute_percentage_error: 48.2388
# Epoch 83/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.3221 - mean_absolute_error: 0.6262 - root_mean_squared_error: 1.9782 - mean_absolute_percentage_error: 3.8009 - val_loss: 6.5737 - val_mean_absolute_error: 6.9889 - val_root_mean_squared_error: 12.8999 - val_mean_absolute_percentage_error: 46.4527
# Epoch 84/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3245 - mean_absolute_error: 0.6304 - root_mean_squared_error: 1.9652 - mean_absolute_percentage_error: 3.8513 - val_loss: 6.5993 - val_mean_absolute_error: 7.0125 - val_root_mean_squared_error: 13.0825 - val_mean_absolute_percentage_error: 47.2066
# Epoch 85/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3413 - mean_absolute_error: 0.6547 - root_mean_squared_error: 1.9614 - mean_absolute_percentage_error: 4.0150 - val_loss: 6.6758 - val_mean_absolute_error: 7.1197 - val_root_mean_squared_error: 13.0587 - val_mean_absolute_percentage_error: 46.8916
# Epoch 86/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3658 - mean_absolute_error: 0.6915 - root_mean_squared_error: 1.9740 - mean_absolute_percentage_error: 4.2852 - val_loss: 6.7468 - val_mean_absolute_error: 7.1723 - val_root_mean_squared_error: 13.1576 - val_mean_absolute_percentage_error: 48.4435
# Epoch 87/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.3130 - mean_absolute_error: 0.6140 - root_mean_squared_error: 1.9076 - mean_absolute_percentage_error: 3.7967 - val_loss: 6.7133 - val_mean_absolute_error: 7.1362 - val_root_mean_squared_error: 13.1211 - val_mean_absolute_percentage_error: 48.0611
# Epoch 88/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.2736 - mean_absolute_error: 0.5570 - root_mean_squared_error: 1.8720 - mean_absolute_percentage_error: 3.4094 - val_loss: 6.7962 - val_mean_absolute_error: 7.2267 - val_root_mean_squared_error: 13.2071 - val_mean_absolute_percentage_error: 49.8084
# Epoch 89/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.2758 - mean_absolute_error: 0.5601 - root_mean_squared_error: 1.8586 - mean_absolute_percentage_error: 3.3741 - val_loss: 6.7070 - val_mean_absolute_error: 7.1211 - val_root_mean_squared_error: 13.1139 - val_mean_absolute_percentage_error: 47.7513
# Epoch 90/100
# 103/103 [==============================] - 9s 91ms/step - loss: 0.2825 - mean_absolute_error: 0.5761 - root_mean_squared_error: 1.8306 - mean_absolute_percentage_error: 3.4018 - val_loss: 6.7468 - val_mean_absolute_error: 7.1959 - val_root_mean_squared_error: 13.0466 - val_mean_absolute_percentage_error: 48.0622
# Epoch 91/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.3280 - mean_absolute_error: 0.6461 - root_mean_squared_error: 1.8478 - mean_absolute_percentage_error: 3.9938 - val_loss: 6.6847 - val_mean_absolute_error: 7.1063 - val_root_mean_squared_error: 13.0414 - val_mean_absolute_percentage_error: 48.6922
# Epoch 92/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.2959 - mean_absolute_error: 0.5971 - root_mean_squared_error: 1.8148 - mean_absolute_percentage_error: 3.7538 - val_loss: 6.6508 - val_mean_absolute_error: 7.0632 - val_root_mean_squared_error: 12.9804 - val_mean_absolute_percentage_error: 48.1681
# Epoch 93/100
# 103/103 [==============================] - 12s 116ms/step - loss: 0.2686 - mean_absolute_error: 0.5577 - root_mean_squared_error: 1.7788 - mean_absolute_percentage_error: 3.4677 - val_loss: 6.7316 - val_mean_absolute_error: 7.1579 - val_root_mean_squared_error: 13.1189 - val_mean_absolute_percentage_error: 48.9270
# Epoch 94/100
# 103/103 [==============================] - 13s 122ms/step - loss: 0.2804 - mean_absolute_error: 0.5773 - root_mean_squared_error: 1.7778 - mean_absolute_percentage_error: 3.5572 - val_loss: 6.6302 - val_mean_absolute_error: 7.0502 - val_root_mean_squared_error: 12.9616 - val_mean_absolute_percentage_error: 47.8219
# Epoch 95/100
# 103/103 [==============================] - 12s 119ms/step - loss: 0.2552 - mean_absolute_error: 0.5398 - root_mean_squared_error: 1.7454 - mean_absolute_percentage_error: 3.3817 - val_loss: 6.5534 - val_mean_absolute_error: 6.9778 - val_root_mean_squared_error: 12.8148 - val_mean_absolute_percentage_error: 47.2547
# Epoch 96/100
# 103/103 [==============================] - 13s 124ms/step - loss: 0.2390 - mean_absolute_error: 0.5104 - root_mean_squared_error: 1.7119 - mean_absolute_percentage_error: 3.0829 - val_loss: 6.6284 - val_mean_absolute_error: 7.0440 - val_root_mean_squared_error: 13.0155 - val_mean_absolute_percentage_error: 48.2299
# Epoch 97/100
# 103/103 [==============================] - 11s 103ms/step - loss: 0.3440 - mean_absolute_error: 0.6656 - root_mean_squared_error: 1.7802 - mean_absolute_percentage_error: 4.0993 - val_loss: 6.5663 - val_mean_absolute_error: 6.9972 - val_root_mean_squared_error: 12.9026 - val_mean_absolute_percentage_error: 46.0504
# Epoch 98/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.3165 - mean_absolute_error: 0.6336 - root_mean_squared_error: 1.7458 - mean_absolute_percentage_error: 4.2065 - val_loss: 6.6836 - val_mean_absolute_error: 7.1057 - val_root_mean_squared_error: 13.0685 - val_mean_absolute_percentage_error: 49.0473
# Epoch 99/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.2695 - mean_absolute_error: 0.5634 - root_mean_squared_error: 1.7018 - mean_absolute_percentage_error: 3.6741 - val_loss: 6.6214 - val_mean_absolute_error: 7.0404 - val_root_mean_squared_error: 12.9542 - val_mean_absolute_percentage_error: 46.8205
# Epoch 100/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.2676 - mean_absolute_error: 0.5633 - root_mean_squared_error: 1.6840 - mean_absolute_percentage_error: 3.5766 - val_loss: 6.6430 - val_mean_absolute_error: 7.0557 - val_root_mean_squared_error: 12.9940 - val_mean_absolute_percentage_error: 48.0813

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 1s 37ms/step - loss: 6.6430 - mean_absolute_error: 7.0557 - root_mean_squared_error: 12.9940 - mean_absolute_percentage_error: 48.0813
# Model Loss: [6.643014430999756, 7.055700302124023, 12.994032859802246, 48.08132553100586]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 304ms/step
# Predicted Putusan: [14.717302]

# %%
model_scenario_name = "BiLSTM_Baseline"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_Baseline\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_Baseline\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_Baseline"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 567ms/step
# Predicted Putusan: [14.717302]
