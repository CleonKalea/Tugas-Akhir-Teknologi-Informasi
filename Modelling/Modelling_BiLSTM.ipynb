# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_31640\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([pooled_lstm, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  lstm (LSTM)                    (None, 1024, 32)     36992       ['embedding[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  lstm_1 (LSTM)                  (None, 1024, 64)     24832       ['lstm[0][0]']
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  lstm_2 (LSTM)                  (None, 1024, 32)     12416       ['lstm_1[0][0]']
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 32)          0           ['lstm_2[0][0]']
#  xPooling1D)
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 64)           0           ['global_max_pooling1d[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64)          256         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          8320        ['batch_normalization[0][0]']
#
#  dropout (Dropout)              (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 3,907,297
# Trainable params: 3,907,169
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 21s 171ms/step - loss: 17.7512 - mean_absolute_error: 18.2034 - root_mean_squared_error: 29.3108 - mean_absolute_percentage_error: 68.6385 - val_loss: 11.6540 - val_mean_absolute_error: 12.1082 - val_root_mean_squared_error: 18.9104 - val_mean_absolute_percentage_error: 71.7078
# Epoch 2/100
# 103/103 [==============================] - 16s 159ms/step - loss: 9.3828 - mean_absolute_error: 9.8314 - root_mean_squared_error: 15.7393 - mean_absolute_percentage_error: 50.5423 - val_loss: 11.6062 - val_mean_absolute_error: 12.0635 - val_root_mean_squared_error: 18.8477 - val_mean_absolute_percentage_error: 57.5115
# Epoch 3/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.5031 - mean_absolute_error: 8.9487 - root_mean_squared_error: 14.7988 - mean_absolute_percentage_error: 43.2013 - val_loss: 12.3129 - val_mean_absolute_error: 12.7641 - val_root_mean_squared_error: 20.1204 - val_mean_absolute_percentage_error: 48.8827
# Epoch 4/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.0599 - mean_absolute_error: 8.5030 - root_mean_squared_error: 13.8445 - mean_absolute_percentage_error: 39.4674 - val_loss: 17.9733 - val_mean_absolute_error: 18.4233 - val_root_mean_squared_error: 28.4643 - val_mean_absolute_percentage_error: 47.4489
# Epoch 5/100
# 103/103 [==============================] - 16s 158ms/step - loss: 7.7085 - mean_absolute_error: 8.1499 - root_mean_squared_error: 13.3986 - mean_absolute_percentage_error: 36.7040 - val_loss: 7.6444 - val_mean_absolute_error: 8.0870 - val_root_mean_squared_error: 13.9788 - val_mean_absolute_percentage_error: 42.1850
# Epoch 6/100
# 103/103 [==============================] - 16s 158ms/step - loss: 6.4541 - mean_absolute_error: 6.8924 - root_mean_squared_error: 11.5309 - mean_absolute_percentage_error: 29.3316 - val_loss: 12.0863 - val_mean_absolute_error: 12.5311 - val_root_mean_squared_error: 18.3072 - val_mean_absolute_percentage_error: 53.5038
# Epoch 7/100
# 103/103 [==============================] - 16s 160ms/step - loss: 5.7929 - mean_absolute_error: 6.2293 - root_mean_squared_error: 10.3059 - mean_absolute_percentage_error: 27.6787 - val_loss: 6.9486 - val_mean_absolute_error: 7.3907 - val_root_mean_squared_error: 12.8557 - val_mean_absolute_percentage_error: 38.2215
# Epoch 8/100
# 103/103 [==============================] - 16s 159ms/step - loss: 5.5359 - mean_absolute_error: 5.9695 - root_mean_squared_error: 9.7954 - mean_absolute_percentage_error: 24.0800 - val_loss: 8.1836 - val_mean_absolute_error: 8.6335 - val_root_mean_squared_error: 13.1295 - val_mean_absolute_percentage_error: 50.1281
# Epoch 9/100
# 103/103 [==============================] - 16s 156ms/step - loss: 5.5035 - mean_absolute_error: 5.9391 - root_mean_squared_error: 9.8730 - mean_absolute_percentage_error: 24.8022 - val_loss: 6.4500 - val_mean_absolute_error: 6.8895 - val_root_mean_squared_error: 12.0315 - val_mean_absolute_percentage_error: 38.6328
# Epoch 10/100
# 103/103 [==============================] - 16s 157ms/step - loss: 5.4246 - mean_absolute_error: 5.8551 - root_mean_squared_error: 9.6772 - mean_absolute_percentage_error: 23.1424 - val_loss: 6.4493 - val_mean_absolute_error: 6.8930 - val_root_mean_squared_error: 11.9003 - val_mean_absolute_percentage_error: 36.7818
# Epoch 11/100
# 103/103 [==============================] - 16s 156ms/step - loss: 5.3914 - mean_absolute_error: 5.8248 - root_mean_squared_error: 9.7400 - mean_absolute_percentage_error: 22.8825 - val_loss: 10.5832 - val_mean_absolute_error: 11.0211 - val_root_mean_squared_error: 16.7612 - val_mean_absolute_percentage_error: 48.8011
# Epoch 12/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.9514 - mean_absolute_error: 5.3836 - root_mean_squared_error: 8.6033 - mean_absolute_percentage_error: 22.1540 - val_loss: 6.4778 - val_mean_absolute_error: 6.9184 - val_root_mean_squared_error: 11.8180 - val_mean_absolute_percentage_error: 32.6800
# Epoch 13/100
# 103/103 [==============================] - 16s 157ms/step - loss: 5.0520 - mean_absolute_error: 5.4792 - root_mean_squared_error: 9.0639 - mean_absolute_percentage_error: 21.4844 - val_loss: 6.1579 - val_mean_absolute_error: 6.5886 - val_root_mean_squared_error: 11.9080 - val_mean_absolute_percentage_error: 32.7420
# Epoch 14/100
# 103/103 [==============================] - 16s 159ms/step - loss: 4.8237 - mean_absolute_error: 5.2493 - root_mean_squared_error: 8.5764 - mean_absolute_percentage_error: 19.2885 - val_loss: 6.2409 - val_mean_absolute_error: 6.6717 - val_root_mean_squared_error: 11.8983 - val_mean_absolute_percentage_error: 33.2465
# Epoch 15/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.4853 - mean_absolute_error: 4.9098 - root_mean_squared_error: 8.1759 - mean_absolute_percentage_error: 18.8627 - val_loss: 6.0787 - val_mean_absolute_error: 6.5152 - val_root_mean_squared_error: 11.6700 - val_mean_absolute_percentage_error: 32.6685
# Epoch 16/100
# 103/103 [==============================] - 16s 159ms/step - loss: 4.4317 - mean_absolute_error: 4.8534 - root_mean_squared_error: 8.0652 - mean_absolute_percentage_error: 18.3532 - val_loss: 7.6349 - val_mean_absolute_error: 8.0666 - val_root_mean_squared_error: 13.4341 - val_mean_absolute_percentage_error: 32.7358
# Epoch 17/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.2467 - mean_absolute_error: 4.6722 - root_mean_squared_error: 7.7094 - mean_absolute_percentage_error: 18.0376 - val_loss: 5.9082 - val_mean_absolute_error: 6.3356 - val_root_mean_squared_error: 11.4908 - val_mean_absolute_percentage_error: 34.7735
# Epoch 18/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.1966 - mean_absolute_error: 4.6200 - root_mean_squared_error: 7.5728 - mean_absolute_percentage_error: 17.8358 - val_loss: 6.1179 - val_mean_absolute_error: 6.5553 - val_root_mean_squared_error: 11.5088 - val_mean_absolute_percentage_error: 34.1916
# Epoch 19/100
# 103/103 [==============================] - 16s 159ms/step - loss: 4.5399 - mean_absolute_error: 4.9636 - root_mean_squared_error: 8.2915 - mean_absolute_percentage_error: 17.6235 - val_loss: 10.3872 - val_mean_absolute_error: 10.8396 - val_root_mean_squared_error: 14.8451 - val_mean_absolute_percentage_error: 56.7356
# Epoch 20/100
# 103/103 [==============================] - 16s 157ms/step - loss: 3.9006 - mean_absolute_error: 4.3207 - root_mean_squared_error: 7.1149 - mean_absolute_percentage_error: 16.2376 - val_loss: 5.8684 - val_mean_absolute_error: 6.3017 - val_root_mean_squared_error: 11.4773 - val_mean_absolute_percentage_error: 32.9090
# Epoch 21/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.1946 - mean_absolute_error: 4.6148 - root_mean_squared_error: 7.8309 - mean_absolute_percentage_error: 16.0692 - val_loss: 5.5352 - val_mean_absolute_error: 5.9494 - val_root_mean_squared_error: 11.0331 - val_mean_absolute_percentage_error: 33.9991
# Epoch 22/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.0790 - mean_absolute_error: 4.4981 - root_mean_squared_error: 7.4152 - mean_absolute_percentage_error: 16.4915 - val_loss: 6.1501 - val_mean_absolute_error: 6.5740 - val_root_mean_squared_error: 11.5051 - val_mean_absolute_percentage_error: 30.9135
# Epoch 23/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.3534 - mean_absolute_error: 4.7739 - root_mean_squared_error: 8.0031 - mean_absolute_percentage_error: 16.7443 - val_loss: 7.3727 - val_mean_absolute_error: 7.8027 - val_root_mean_squared_error: 12.7754 - val_mean_absolute_percentage_error: 39.7033
# Epoch 24/100
# 103/103 [==============================] - 16s 156ms/step - loss: 3.6661 - mean_absolute_error: 4.0831 - root_mean_squared_error: 6.7214 - mean_absolute_percentage_error: 14.7125 - val_loss: 6.1242 - val_mean_absolute_error: 6.5480 - val_root_mean_squared_error: 11.6274 - val_mean_absolute_percentage_error: 31.2284
# Epoch 25/100
# 103/103 [==============================] - 16s 159ms/step - loss: 3.6700 - mean_absolute_error: 4.0892 - root_mean_squared_error: 6.7734 - mean_absolute_percentage_error: 15.3283 - val_loss: 5.7236 - val_mean_absolute_error: 6.1501 - val_root_mean_squared_error: 11.4367 - val_mean_absolute_percentage_error: 33.4724
# Epoch 26/100
# 103/103 [==============================] - 16s 157ms/step - loss: 3.9534 - mean_absolute_error: 4.3714 - root_mean_squared_error: 7.1310 - mean_absolute_percentage_error: 15.8584 - val_loss: 5.9284 - val_mean_absolute_error: 6.3691 - val_root_mean_squared_error: 11.1704 - val_mean_absolute_percentage_error: 32.1440
# Epoch 27/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.8324 - mean_absolute_error: 4.2493 - root_mean_squared_error: 7.0055 - mean_absolute_percentage_error: 16.0860 - val_loss: 6.0310 - val_mean_absolute_error: 6.4673 - val_root_mean_squared_error: 11.3649 - val_mean_absolute_percentage_error: 34.0175
# Epoch 28/100
# 103/103 [==============================] - 16s 156ms/step - loss: 3.8035 - mean_absolute_error: 4.2221 - root_mean_squared_error: 6.9403 - mean_absolute_percentage_error: 14.9750 - val_loss: 6.6235 - val_mean_absolute_error: 7.0551 - val_root_mean_squared_error: 11.9377 - val_mean_absolute_percentage_error: 31.3338
# Epoch 29/100
# 103/103 [==============================] - 16s 159ms/step - loss: 3.7611 - mean_absolute_error: 4.1823 - root_mean_squared_error: 6.6807 - mean_absolute_percentage_error: 15.4981 - val_loss: 6.5039 - val_mean_absolute_error: 6.9537 - val_root_mean_squared_error: 11.4542 - val_mean_absolute_percentage_error: 43.1838
# Epoch 30/100
# 103/103 [==============================] - 16s 157ms/step - loss: 3.3936 - mean_absolute_error: 3.8133 - root_mean_squared_error: 6.0698 - mean_absolute_percentage_error: 14.7047 - val_loss: 5.3431 - val_mean_absolute_error: 5.7642 - val_root_mean_squared_error: 10.8920 - val_mean_absolute_percentage_error: 31.7914
# Epoch 31/100
# 103/103 [==============================] - 17s 161ms/step - loss: 3.7580 - mean_absolute_error: 4.1725 - root_mean_squared_error: 6.7982 - mean_absolute_percentage_error: 16.0310 - val_loss: 9.6230 - val_mean_absolute_error: 10.0642 - val_root_mean_squared_error: 16.0268 - val_mean_absolute_percentage_error: 41.1507
# Epoch 32/100
# 103/103 [==============================] - 17s 160ms/step - loss: 3.6133 - mean_absolute_error: 4.0328 - root_mean_squared_error: 6.5224 - mean_absolute_percentage_error: 14.9138 - val_loss: 6.4652 - val_mean_absolute_error: 6.8854 - val_root_mean_squared_error: 11.8991 - val_mean_absolute_percentage_error: 36.6911
# Epoch 33/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.4684 - mean_absolute_error: 3.8835 - root_mean_squared_error: 6.3544 - mean_absolute_percentage_error: 14.6178 - val_loss: 6.7973 - val_mean_absolute_error: 7.2281 - val_root_mean_squared_error: 12.0311 - val_mean_absolute_percentage_error: 39.7553
# Epoch 34/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.2604 - mean_absolute_error: 3.6760 - root_mean_squared_error: 5.8309 - mean_absolute_percentage_error: 14.5345 - val_loss: 5.9407 - val_mean_absolute_error: 6.3745 - val_root_mean_squared_error: 11.4110 - val_mean_absolute_percentage_error: 34.3941
# Epoch 35/100
# 103/103 [==============================] - 16s 159ms/step - loss: 3.4791 - mean_absolute_error: 3.8936 - root_mean_squared_error: 6.6045 - mean_absolute_percentage_error: 14.1041 - val_loss: 5.7488 - val_mean_absolute_error: 6.1583 - val_root_mean_squared_error: 11.9011 - val_mean_absolute_percentage_error: 34.0917
# Epoch 36/100
# 103/103 [==============================] - 16s 159ms/step - loss: 3.2525 - mean_absolute_error: 3.6649 - root_mean_squared_error: 5.9003 - mean_absolute_percentage_error: 14.1261 - val_loss: 6.5598 - val_mean_absolute_error: 6.9825 - val_root_mean_squared_error: 12.1179 - val_mean_absolute_percentage_error: 34.4170
# Epoch 37/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.2649 - mean_absolute_error: 3.6785 - root_mean_squared_error: 5.8921 - mean_absolute_percentage_error: 13.7656 - val_loss: 5.5086 - val_mean_absolute_error: 5.9331 - val_root_mean_squared_error: 11.6698 - val_mean_absolute_percentage_error: 30.3797
# Epoch 38/100
# 103/103 [==============================] - 16s 156ms/step - loss: 3.0946 - mean_absolute_error: 3.5069 - root_mean_squared_error: 5.7299 - mean_absolute_percentage_error: 12.9289 - val_loss: 5.6353 - val_mean_absolute_error: 6.0594 - val_root_mean_squared_error: 11.0311 - val_mean_absolute_percentage_error: 31.7783
# Epoch 39/100
# 103/103 [==============================] - 16s 157ms/step - loss: 3.4115 - mean_absolute_error: 3.8269 - root_mean_squared_error: 6.2648 - mean_absolute_percentage_error: 14.7519 - val_loss: 5.4853 - val_mean_absolute_error: 5.9029 - val_root_mean_squared_error: 10.9668 - val_mean_absolute_percentage_error: 32.4390
# Epoch 40/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.3917 - mean_absolute_error: 3.8064 - root_mean_squared_error: 6.1973 - mean_absolute_percentage_error: 13.9546 - val_loss: 5.2751 - val_mean_absolute_error: 5.6852 - val_root_mean_squared_error: 10.8246 - val_mean_absolute_percentage_error: 30.2958
# Epoch 41/100
# 103/103 [==============================] - 16s 157ms/step - loss: 3.2966 - mean_absolute_error: 3.7097 - root_mean_squared_error: 6.1940 - mean_absolute_percentage_error: 13.6254 - val_loss: 6.3522 - val_mean_absolute_error: 6.7781 - val_root_mean_squared_error: 11.7864 - val_mean_absolute_percentage_error: 37.6572
# Epoch 42/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.1134 - mean_absolute_error: 3.5263 - root_mean_squared_error: 5.6719 - mean_absolute_percentage_error: 13.5802 - val_loss: 5.9592 - val_mean_absolute_error: 6.3975 - val_root_mean_squared_error: 11.2104 - val_mean_absolute_percentage_error: 35.8121
# Epoch 43/100
# 103/103 [==============================] - 16s 159ms/step - loss: 3.0697 - mean_absolute_error: 3.4824 - root_mean_squared_error: 5.5225 - mean_absolute_percentage_error: 13.7210 - val_loss: 5.7875 - val_mean_absolute_error: 6.2280 - val_root_mean_squared_error: 11.3653 - val_mean_absolute_percentage_error: 33.2921
# Epoch 44/100
# 103/103 [==============================] - 17s 160ms/step - loss: 3.1945 - mean_absolute_error: 3.6067 - root_mean_squared_error: 5.8612 - mean_absolute_percentage_error: 13.3848 - val_loss: 6.0542 - val_mean_absolute_error: 6.4837 - val_root_mean_squared_error: 11.5646 - val_mean_absolute_percentage_error: 34.4052
# Epoch 45/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.9686 - mean_absolute_error: 3.3774 - root_mean_squared_error: 5.4275 - mean_absolute_percentage_error: 12.5461 - val_loss: 8.1324 - val_mean_absolute_error: 8.5774 - val_root_mean_squared_error: 13.7145 - val_mean_absolute_percentage_error: 46.2700
# Epoch 46/100
# 103/103 [==============================] - 17s 162ms/step - loss: 3.0919 - mean_absolute_error: 3.5079 - root_mean_squared_error: 5.6624 - mean_absolute_percentage_error: 13.6018 - val_loss: 6.1038 - val_mean_absolute_error: 6.5184 - val_root_mean_squared_error: 11.7672 - val_mean_absolute_percentage_error: 35.6181
# Epoch 47/100
# 103/103 [==============================] - 17s 160ms/step - loss: 2.9402 - mean_absolute_error: 3.3511 - root_mean_squared_error: 5.5729 - mean_absolute_percentage_error: 12.7945 - val_loss: 5.3691 - val_mean_absolute_error: 5.7779 - val_root_mean_squared_error: 11.0382 - val_mean_absolute_percentage_error: 33.9013
# Epoch 48/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.0143 - mean_absolute_error: 3.4264 - root_mean_squared_error: 5.5000 - mean_absolute_percentage_error: 12.6354 - val_loss: 5.2710 - val_mean_absolute_error: 5.6933 - val_root_mean_squared_error: 10.8515 - val_mean_absolute_percentage_error: 34.8727
# Epoch 49/100
# 103/103 [==============================] - 16s 159ms/step - loss: 3.0387 - mean_absolute_error: 3.4504 - root_mean_squared_error: 5.5152 - mean_absolute_percentage_error: 12.8384 - val_loss: 5.1786 - val_mean_absolute_error: 5.5836 - val_root_mean_squared_error: 10.7492 - val_mean_absolute_percentage_error: 31.7668
# Epoch 50/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.0579 - mean_absolute_error: 3.4679 - root_mean_squared_error: 5.6640 - mean_absolute_percentage_error: 12.6784 - val_loss: 5.4547 - val_mean_absolute_error: 5.8746 - val_root_mean_squared_error: 11.1014 - val_mean_absolute_percentage_error: 31.3140
# Epoch 51/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.8843 - mean_absolute_error: 3.2924 - root_mean_squared_error: 5.2710 - mean_absolute_percentage_error: 12.3667 - val_loss: 5.3451 - val_mean_absolute_error: 5.7582 - val_root_mean_squared_error: 11.1982 - val_mean_absolute_percentage_error: 31.6864
# Epoch 52/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.8218 - mean_absolute_error: 3.2319 - root_mean_squared_error: 5.1596 - mean_absolute_percentage_error: 12.6690 - val_loss: 5.9283 - val_mean_absolute_error: 6.3746 - val_root_mean_squared_error: 11.1232 - val_mean_absolute_percentage_error: 31.9090
# Epoch 53/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.9006 - mean_absolute_error: 3.3097 - root_mean_squared_error: 5.2412 - mean_absolute_percentage_error: 13.1843 - val_loss: 5.5041 - val_mean_absolute_error: 5.9254 - val_root_mean_squared_error: 11.6514 - val_mean_absolute_percentage_error: 33.3457
# Epoch 54/100
# 103/103 [==============================] - 16s 157ms/step - loss: 2.8531 - mean_absolute_error: 3.2629 - root_mean_squared_error: 5.1563 - mean_absolute_percentage_error: 12.6533 - val_loss: 5.6371 - val_mean_absolute_error: 6.0458 - val_root_mean_squared_error: 11.2930 - val_mean_absolute_percentage_error: 34.9795
# Epoch 55/100
# 103/103 [==============================] - 16s 157ms/step - loss: 2.8832 - mean_absolute_error: 3.2947 - root_mean_squared_error: 5.2592 - mean_absolute_percentage_error: 12.6166 - val_loss: 5.3028 - val_mean_absolute_error: 5.7246 - val_root_mean_squared_error: 10.9770 - val_mean_absolute_percentage_error: 32.0593
# Epoch 56/100
# 103/103 [==============================] - 16s 157ms/step - loss: 2.8956 - mean_absolute_error: 3.3042 - root_mean_squared_error: 5.4373 - mean_absolute_percentage_error: 12.3748 - val_loss: 5.6099 - val_mean_absolute_error: 6.0437 - val_root_mean_squared_error: 11.0431 - val_mean_absolute_percentage_error: 36.9638
# Epoch 57/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.5990 - mean_absolute_error: 3.0062 - root_mean_squared_error: 4.8313 - mean_absolute_percentage_error: 11.7836 - val_loss: 5.6318 - val_mean_absolute_error: 6.0393 - val_root_mean_squared_error: 12.0392 - val_mean_absolute_percentage_error: 33.8083
# Epoch 58/100
# 103/103 [==============================] - 16s 156ms/step - loss: 2.7628 - mean_absolute_error: 3.1685 - root_mean_squared_error: 5.0853 - mean_absolute_percentage_error: 11.9973 - val_loss: 5.8662 - val_mean_absolute_error: 6.2762 - val_root_mean_squared_error: 12.3839 - val_mean_absolute_percentage_error: 31.4130
# Epoch 59/100
# 103/103 [==============================] - 16s 158ms/step - loss: 3.0189 - mean_absolute_error: 3.4279 - root_mean_squared_error: 5.6730 - mean_absolute_percentage_error: 12.3037 - val_loss: 5.2471 - val_mean_absolute_error: 5.6672 - val_root_mean_squared_error: 10.7632 - val_mean_absolute_percentage_error: 30.9428
# Epoch 60/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.6294 - mean_absolute_error: 3.0384 - root_mean_squared_error: 4.8749 - mean_absolute_percentage_error: 12.3445 - val_loss: 5.6369 - val_mean_absolute_error: 6.0616 - val_root_mean_squared_error: 11.5875 - val_mean_absolute_percentage_error: 34.9765
# Epoch 61/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.6273 - mean_absolute_error: 3.0324 - root_mean_squared_error: 4.9309 - mean_absolute_percentage_error: 11.6564 - val_loss: 5.4699 - val_mean_absolute_error: 5.8756 - val_root_mean_squared_error: 11.4874 - val_mean_absolute_percentage_error: 35.1364
# Epoch 62/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.6545 - mean_absolute_error: 3.0639 - root_mean_squared_error: 4.8012 - mean_absolute_percentage_error: 11.9960 - val_loss: 5.6614 - val_mean_absolute_error: 6.0831 - val_root_mean_squared_error: 11.4734 - val_mean_absolute_percentage_error: 35.0687
# Epoch 63/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.5201 - mean_absolute_error: 2.9251 - root_mean_squared_error: 4.7347 - mean_absolute_percentage_error: 11.1523 - val_loss: 6.3888 - val_mean_absolute_error: 6.8077 - val_root_mean_squared_error: 11.9679 - val_mean_absolute_percentage_error: 37.4855
# Epoch 64/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.6404 - mean_absolute_error: 3.0496 - root_mean_squared_error: 4.8348 - mean_absolute_percentage_error: 11.7518 - val_loss: 5.4568 - val_mean_absolute_error: 5.8626 - val_root_mean_squared_error: 11.2933 - val_mean_absolute_percentage_error: 33.1546
# Epoch 65/100
# 103/103 [==============================] - 17s 161ms/step - loss: 2.6826 - mean_absolute_error: 3.0906 - root_mean_squared_error: 5.0122 - mean_absolute_percentage_error: 11.9899 - val_loss: 5.8378 - val_mean_absolute_error: 6.2482 - val_root_mean_squared_error: 11.4711 - val_mean_absolute_percentage_error: 34.1916
# Epoch 66/100
# 103/103 [==============================] - 17s 160ms/step - loss: 2.6912 - mean_absolute_error: 3.0964 - root_mean_squared_error: 5.0283 - mean_absolute_percentage_error: 11.6620 - val_loss: 5.6979 - val_mean_absolute_error: 6.1216 - val_root_mean_squared_error: 11.2247 - val_mean_absolute_percentage_error: 32.4893
# Epoch 67/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.5612 - mean_absolute_error: 2.9623 - root_mean_squared_error: 4.9072 - mean_absolute_percentage_error: 11.0281 - val_loss: 5.9589 - val_mean_absolute_error: 6.3929 - val_root_mean_squared_error: 11.1637 - val_mean_absolute_percentage_error: 35.6383
# Epoch 68/100
# 103/103 [==============================] - 16s 156ms/step - loss: 2.5149 - mean_absolute_error: 2.9221 - root_mean_squared_error: 4.6114 - mean_absolute_percentage_error: 11.0361 - val_loss: 5.9587 - val_mean_absolute_error: 6.3706 - val_root_mean_squared_error: 12.5297 - val_mean_absolute_percentage_error: 34.8229
# Epoch 69/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.3978 - mean_absolute_error: 2.7950 - root_mean_squared_error: 4.4473 - mean_absolute_percentage_error: 10.6052 - val_loss: 5.1382 - val_mean_absolute_error: 5.5464 - val_root_mean_squared_error: 11.0237 - val_mean_absolute_percentage_error: 31.8884
# Epoch 70/100
# 103/103 [==============================] - 16s 156ms/step - loss: 2.5326 - mean_absolute_error: 2.9357 - root_mean_squared_error: 4.7059 - mean_absolute_percentage_error: 11.0701 - val_loss: 5.3706 - val_mean_absolute_error: 5.7724 - val_root_mean_squared_error: 11.0429 - val_mean_absolute_percentage_error: 32.0401
# Epoch 71/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.5507 - mean_absolute_error: 2.9560 - root_mean_squared_error: 4.8180 - mean_absolute_percentage_error: 10.9827 - val_loss: 5.5167 - val_mean_absolute_error: 5.9382 - val_root_mean_squared_error: 11.1689 - val_mean_absolute_percentage_error: 32.3704
# Epoch 72/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.5639 - mean_absolute_error: 2.9714 - root_mean_squared_error: 4.9084 - mean_absolute_percentage_error: 11.2746 - val_loss: 6.0294 - val_mean_absolute_error: 6.4366 - val_root_mean_squared_error: 12.1395 - val_mean_absolute_percentage_error: 35.0006
# Epoch 73/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.6214 - mean_absolute_error: 3.0313 - root_mean_squared_error: 4.9143 - mean_absolute_percentage_error: 12.1105 - val_loss: 6.4465 - val_mean_absolute_error: 6.8665 - val_root_mean_squared_error: 11.9525 - val_mean_absolute_percentage_error: 37.2259
# Epoch 74/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.3833 - mean_absolute_error: 2.7875 - root_mean_squared_error: 4.4258 - mean_absolute_percentage_error: 11.4741 - val_loss: 5.3339 - val_mean_absolute_error: 5.7551 - val_root_mean_squared_error: 11.5180 - val_mean_absolute_percentage_error: 31.3123
# Epoch 75/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.5953 - mean_absolute_error: 3.0060 - root_mean_squared_error: 4.6974 - mean_absolute_percentage_error: 11.9338 - val_loss: 5.1055 - val_mean_absolute_error: 5.5192 - val_root_mean_squared_error: 10.9811 - val_mean_absolute_percentage_error: 30.9775
# Epoch 76/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.3144 - mean_absolute_error: 2.7167 - root_mean_squared_error: 4.3366 - mean_absolute_percentage_error: 10.6950 - val_loss: 5.1446 - val_mean_absolute_error: 5.5400 - val_root_mean_squared_error: 10.7438 - val_mean_absolute_percentage_error: 30.9410
# Epoch 77/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.4106 - mean_absolute_error: 2.8134 - root_mean_squared_error: 4.4897 - mean_absolute_percentage_error: 11.3559 - val_loss: 5.1465 - val_mean_absolute_error: 5.5453 - val_root_mean_squared_error: 10.8457 - val_mean_absolute_percentage_error: 31.8012
# Epoch 78/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.3317 - mean_absolute_error: 2.7320 - root_mean_squared_error: 4.4171 - mean_absolute_percentage_error: 10.5417 - val_loss: 5.6407 - val_mean_absolute_error: 6.0455 - val_root_mean_squared_error: 11.3286 - val_mean_absolute_percentage_error: 32.3781
# Epoch 79/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.2385 - mean_absolute_error: 2.6411 - root_mean_squared_error: 4.1265 - mean_absolute_percentage_error: 10.2962 - val_loss: 5.6962 - val_mean_absolute_error: 6.0968 - val_root_mean_squared_error: 11.2566 - val_mean_absolute_percentage_error: 35.2793
# Epoch 80/100
# 103/103 [==============================] - 17s 162ms/step - loss: 2.4227 - mean_absolute_error: 2.8257 - root_mean_squared_error: 4.5456 - mean_absolute_percentage_error: 11.1769 - val_loss: 6.1741 - val_mean_absolute_error: 6.5992 - val_root_mean_squared_error: 11.7316 - val_mean_absolute_percentage_error: 38.3722
# Epoch 81/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.3801 - mean_absolute_error: 2.7811 - root_mean_squared_error: 4.4913 - mean_absolute_percentage_error: 10.2991 - val_loss: 5.2519 - val_mean_absolute_error: 5.6770 - val_root_mean_squared_error: 11.1707 - val_mean_absolute_percentage_error: 31.8530
# Epoch 82/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.5172 - mean_absolute_error: 2.9223 - root_mean_squared_error: 4.6771 - mean_absolute_percentage_error: 11.0328 - val_loss: 5.2042 - val_mean_absolute_error: 5.6009 - val_root_mean_squared_error: 11.0422 - val_mean_absolute_percentage_error: 30.2882
# Epoch 83/100
# 103/103 [==============================] - 16s 157ms/step - loss: 2.5534 - mean_absolute_error: 2.9546 - root_mean_squared_error: 4.9311 - mean_absolute_percentage_error: 10.9622 - val_loss: 5.3465 - val_mean_absolute_error: 5.7674 - val_root_mean_squared_error: 11.2864 - val_mean_absolute_percentage_error: 33.9717
# Epoch 84/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.5685 - mean_absolute_error: 2.9726 - root_mean_squared_error: 4.9046 - mean_absolute_percentage_error: 11.1039 - val_loss: 5.1548 - val_mean_absolute_error: 5.5651 - val_root_mean_squared_error: 10.9422 - val_mean_absolute_percentage_error: 29.9533
# Epoch 85/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.2575 - mean_absolute_error: 2.6582 - root_mean_squared_error: 4.2766 - mean_absolute_percentage_error: 10.6116 - val_loss: 5.2554 - val_mean_absolute_error: 5.6572 - val_root_mean_squared_error: 11.1194 - val_mean_absolute_percentage_error: 32.7689
# Epoch 86/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.3405 - mean_absolute_error: 2.7397 - root_mean_squared_error: 4.5957 - mean_absolute_percentage_error: 10.5138 - val_loss: 5.2641 - val_mean_absolute_error: 5.6696 - val_root_mean_squared_error: 11.0084 - val_mean_absolute_percentage_error: 30.5899
# Epoch 87/100
# 103/103 [==============================] - 17s 160ms/step - loss: 2.2879 - mean_absolute_error: 2.6924 - root_mean_squared_error: 4.3522 - mean_absolute_percentage_error: 10.7313 - val_loss: 5.4968 - val_mean_absolute_error: 5.9201 - val_root_mean_squared_error: 11.3362 - val_mean_absolute_percentage_error: 33.0947
# Epoch 88/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.3441 - mean_absolute_error: 2.7463 - root_mean_squared_error: 4.3673 - mean_absolute_percentage_error: 10.9014 - val_loss: 5.3456 - val_mean_absolute_error: 5.7599 - val_root_mean_squared_error: 11.6177 - val_mean_absolute_percentage_error: 31.6852
# Epoch 89/100
# 103/103 [==============================] - 17s 162ms/step - loss: 2.3485 - mean_absolute_error: 2.7489 - root_mean_squared_error: 4.3869 - mean_absolute_percentage_error: 10.2026 - val_loss: 5.6294 - val_mean_absolute_error: 6.0601 - val_root_mean_squared_error: 11.4273 - val_mean_absolute_percentage_error: 38.7549
# Epoch 90/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.5341 - mean_absolute_error: 2.9361 - root_mean_squared_error: 4.8322 - mean_absolute_percentage_error: 11.2358 - val_loss: 5.3008 - val_mean_absolute_error: 5.6949 - val_root_mean_squared_error: 11.3126 - val_mean_absolute_percentage_error: 33.2892
# Epoch 91/100
# 103/103 [==============================] - 19s 180ms/step - loss: 2.2901 - mean_absolute_error: 2.6873 - root_mean_squared_error: 4.2860 - mean_absolute_percentage_error: 10.0741 - val_loss: 5.4487 - val_mean_absolute_error: 5.8490 - val_root_mean_squared_error: 11.4728 - val_mean_absolute_percentage_error: 31.0973
# Epoch 92/100
# 103/103 [==============================] - 17s 161ms/step - loss: 2.2233 - mean_absolute_error: 2.6194 - root_mean_squared_error: 4.2180 - mean_absolute_percentage_error: 10.0898 - val_loss: 5.6743 - val_mean_absolute_error: 6.0862 - val_root_mean_squared_error: 11.5663 - val_mean_absolute_percentage_error: 34.0767
# Epoch 93/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.3320 - mean_absolute_error: 2.7346 - root_mean_squared_error: 4.4224 - mean_absolute_percentage_error: 10.8338 - val_loss: 5.2956 - val_mean_absolute_error: 5.7071 - val_root_mean_squared_error: 11.0385 - val_mean_absolute_percentage_error: 33.2131
# Epoch 94/100
# 103/103 [==============================] - 16s 159ms/step - loss: 2.2877 - mean_absolute_error: 2.6865 - root_mean_squared_error: 4.3875 - mean_absolute_percentage_error: 10.3183 - val_loss: 5.5386 - val_mean_absolute_error: 5.9498 - val_root_mean_squared_error: 11.4782 - val_mean_absolute_percentage_error: 33.7363
# Epoch 95/100
# 103/103 [==============================] - 16s 160ms/step - loss: 2.2272 - mean_absolute_error: 2.6269 - root_mean_squared_error: 4.2986 - mean_absolute_percentage_error: 10.1808 - val_loss: 5.5196 - val_mean_absolute_error: 5.9392 - val_root_mean_squared_error: 11.6158 - val_mean_absolute_percentage_error: 33.0902
# Epoch 96/100
# 103/103 [==============================] - 16s 157ms/step - loss: 2.2222 - mean_absolute_error: 2.6235 - root_mean_squared_error: 4.2085 - mean_absolute_percentage_error: 10.2385 - val_loss: 5.1088 - val_mean_absolute_error: 5.5150 - val_root_mean_squared_error: 10.9813 - val_mean_absolute_percentage_error: 33.0792
# Epoch 97/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.1053 - mean_absolute_error: 2.5028 - root_mean_squared_error: 4.0149 - mean_absolute_percentage_error: 9.7453 - val_loss: 5.0886 - val_mean_absolute_error: 5.4867 - val_root_mean_squared_error: 10.9755 - val_mean_absolute_percentage_error: 32.3315
# Epoch 98/100
# 103/103 [==============================] - 16s 158ms/step - loss: 2.2266 - mean_absolute_error: 2.6243 - root_mean_squared_error: 4.2634 - mean_absolute_percentage_error: 10.5773 - val_loss: 5.7072 - val_mean_absolute_error: 6.1268 - val_root_mean_squared_error: 11.4036 - val_mean_absolute_percentage_error: 33.8985
# Epoch 99/100
# 103/103 [==============================] - 16s 157ms/step - loss: 2.3176 - mean_absolute_error: 2.7194 - root_mean_squared_error: 4.4214 - mean_absolute_percentage_error: 10.6949 - val_loss: 5.2196 - val_mean_absolute_error: 5.6157 - val_root_mean_squared_error: 11.3809 - val_mean_absolute_percentage_error: 31.6353
# Epoch 100/100
# 103/103 [==============================] - 19s 181ms/step - loss: 2.1184 - mean_absolute_error: 2.5126 - root_mean_squared_error: 4.1574 - mean_absolute_percentage_error: 9.6650 - val_loss: 5.4910 - val_mean_absolute_error: 5.8867 - val_root_mean_squared_error: 11.6725 - val_mean_absolute_percentage_error: 32.1187

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 74ms/step - loss: 5.4910 - mean_absolute_error: 5.8867 - root_mean_squared_error: 11.6725 - mean_absolute_percentage_error: 32.1187
# Model Loss: [5.491042613983154, 5.88669490814209, 11.672521591186523, 32.11869812011719]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 870ms/step
# Predicted Putusan: [12.804746]

# %%
model_scenario_name = "BiLSTM_9"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_9\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_9\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_9"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 731ms/step
# Predicted Putusan: [12.804746]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
