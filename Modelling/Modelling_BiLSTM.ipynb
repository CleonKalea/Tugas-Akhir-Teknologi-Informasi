# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_9240\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output_2)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(lstm_output_3)
lstm_output_4 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(dropout_layer_1)
lstm_output_5 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output_4)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([lstm_output_5, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 128)    164352      ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 1024, 256)   263168      ['bidirectional[0][0]']
#  )
#
#  bidirectional_2 (Bidirectional  (None, 1024, 128)   164352      ['bidirectional_1[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  dropout (Dropout)              (None, 1024, 128)    0           ['bidirectional_2[0][0]']
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_3 (Bidirectional  (None, 1024, 64)    41216       ['dropout[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  bidirectional_4 (Bidirectional  (None, 64)          24832       ['bidirectional_3[0][0]']
#  )
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['bidirectional_4[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,495,201
# Trainable params: 4,495,009
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 60s 497ms/step - loss: 20.5345 - mean_absolute_error: 20.8785 - root_mean_squared_error: 31.9699 - mean_absolute_percentage_error: 83.4968 - val_loss: 24.8527 - val_mean_absolute_error: 25.2054 - val_root_mean_squared_error: 34.0638 - val_mean_absolute_percentage_error: 168.7527
# Epoch 2/100
# 103/103 [==============================] - 49s 479ms/step - loss: 11.7510 - mean_absolute_error: 12.0952 - root_mean_squared_error: 18.5675 - mean_absolute_percentage_error: 68.3453 - val_loss: 11.7514 - val_mean_absolute_error: 12.0930 - val_root_mean_squared_error: 18.9676 - val_mean_absolute_percentage_error: 74.9332
# Epoch 3/100
# 103/103 [==============================] - 50s 488ms/step - loss: 9.8790 - mean_absolute_error: 10.2157 - root_mean_squared_error: 16.0806 - mean_absolute_percentage_error: 52.9107 - val_loss: 18.3147 - val_mean_absolute_error: 18.6626 - val_root_mean_squared_error: 24.1359 - val_mean_absolute_percentage_error: 108.1708
# Epoch 4/100
# 103/103 [==============================] - 49s 479ms/step - loss: 8.8391 - mean_absolute_error: 9.1754 - root_mean_squared_error: 14.6323 - mean_absolute_percentage_error: 45.5502 - val_loss: 8.8378 - val_mean_absolute_error: 9.1751 - val_root_mean_squared_error: 15.3490 - val_mean_absolute_percentage_error: 51.4985
# Epoch 5/100
# 103/103 [==============================] - 49s 477ms/step - loss: 7.7194 - mean_absolute_error: 8.0483 - root_mean_squared_error: 12.9510 - mean_absolute_percentage_error: 36.9239 - val_loss: 12.5223 - val_mean_absolute_error: 12.8654 - val_root_mean_squared_error: 17.7787 - val_mean_absolute_percentage_error: 92.4194
# Epoch 6/100
# 103/103 [==============================] - 50s 488ms/step - loss: 7.1125 - mean_absolute_error: 7.4413 - root_mean_squared_error: 12.1514 - mean_absolute_percentage_error: 34.2839 - val_loss: 12.5468 - val_mean_absolute_error: 12.8940 - val_root_mean_squared_error: 17.0657 - val_mean_absolute_percentage_error: 82.1578
# Epoch 7/100
# 103/103 [==============================] - 50s 487ms/step - loss: 7.2575 - mean_absolute_error: 7.5844 - root_mean_squared_error: 12.3911 - mean_absolute_percentage_error: 34.1417 - val_loss: 11.0787 - val_mean_absolute_error: 11.4162 - val_root_mean_squared_error: 16.1395 - val_mean_absolute_percentage_error: 74.8913
# Epoch 8/100
# 103/103 [==============================] - 51s 496ms/step - loss: 7.0816 - mean_absolute_error: 7.4024 - root_mean_squared_error: 11.9973 - mean_absolute_percentage_error: 34.7549 - val_loss: 8.1145 - val_mean_absolute_error: 8.4431 - val_root_mean_squared_error: 13.7058 - val_mean_absolute_percentage_error: 50.5579
# Epoch 9/100
# 103/103 [==============================] - 51s 492ms/step - loss: 6.2303 - mean_absolute_error: 6.5508 - root_mean_squared_error: 10.6138 - mean_absolute_percentage_error: 29.7263 - val_loss: 7.2689 - val_mean_absolute_error: 7.5892 - val_root_mean_squared_error: 13.0143 - val_mean_absolute_percentage_error: 42.1918
# Epoch 10/100
# 103/103 [==============================] - 50s 486ms/step - loss: 5.6980 - mean_absolute_error: 6.0162 - root_mean_squared_error: 9.8928 - mean_absolute_percentage_error: 25.6554 - val_loss: 7.9301 - val_mean_absolute_error: 8.2552 - val_root_mean_squared_error: 13.5491 - val_mean_absolute_percentage_error: 43.9015
# Epoch 11/100
# 103/103 [==============================] - 50s 486ms/step - loss: 5.6441 - mean_absolute_error: 5.9617 - root_mean_squared_error: 9.7478 - mean_absolute_percentage_error: 26.1390 - val_loss: 7.7749 - val_mean_absolute_error: 8.0982 - val_root_mean_squared_error: 13.4358 - val_mean_absolute_percentage_error: 43.7030
# Epoch 12/100
# 103/103 [==============================] - 50s 487ms/step - loss: 5.4468 - mean_absolute_error: 5.7618 - root_mean_squared_error: 9.4039 - mean_absolute_percentage_error: 25.6211 - val_loss: 8.2220 - val_mean_absolute_error: 8.5540 - val_root_mean_squared_error: 13.2063 - val_mean_absolute_percentage_error: 49.3937
# Epoch 13/100
# 103/103 [==============================] - 50s 488ms/step - loss: 5.3946 - mean_absolute_error: 5.7144 - root_mean_squared_error: 9.2459 - mean_absolute_percentage_error: 25.7647 - val_loss: 9.3711 - val_mean_absolute_error: 9.7004 - val_root_mean_squared_error: 14.6319 - val_mean_absolute_percentage_error: 49.6433
# Epoch 14/100
# 103/103 [==============================] - 50s 487ms/step - loss: 5.0030 - mean_absolute_error: 5.3218 - root_mean_squared_error: 8.5618 - mean_absolute_percentage_error: 23.8508 - val_loss: 7.0232 - val_mean_absolute_error: 7.3469 - val_root_mean_squared_error: 12.7574 - val_mean_absolute_percentage_error: 36.6783
# Epoch 15/100
# 103/103 [==============================] - 50s 489ms/step - loss: 5.1671 - mean_absolute_error: 5.4856 - root_mean_squared_error: 8.8850 - mean_absolute_percentage_error: 23.6687 - val_loss: 7.7044 - val_mean_absolute_error: 8.0341 - val_root_mean_squared_error: 12.9715 - val_mean_absolute_percentage_error: 45.5963
# Epoch 16/100
# 103/103 [==============================] - 50s 488ms/step - loss: 4.7994 - mean_absolute_error: 5.1188 - root_mean_squared_error: 8.1269 - mean_absolute_percentage_error: 23.0819 - val_loss: 7.2514 - val_mean_absolute_error: 7.5770 - val_root_mean_squared_error: 12.2479 - val_mean_absolute_percentage_error: 40.6751
# Epoch 17/100
# 103/103 [==============================] - 50s 490ms/step - loss: 4.6611 - mean_absolute_error: 4.9819 - root_mean_squared_error: 8.0909 - mean_absolute_percentage_error: 21.4535 - val_loss: 12.9934 - val_mean_absolute_error: 13.3394 - val_root_mean_squared_error: 16.3310 - val_mean_absolute_percentage_error: 110.7758
# Epoch 18/100
# 103/103 [==============================] - 50s 490ms/step - loss: 4.7962 - mean_absolute_error: 5.1162 - root_mean_squared_error: 8.0209 - mean_absolute_percentage_error: 22.4071 - val_loss: 8.9452 - val_mean_absolute_error: 9.2904 - val_root_mean_squared_error: 13.4076 - val_mean_absolute_percentage_error: 64.3673
# Epoch 19/100
# 103/103 [==============================] - 50s 482ms/step - loss: 4.6349 - mean_absolute_error: 4.9585 - root_mean_squared_error: 7.9801 - mean_absolute_percentage_error: 21.4575 - val_loss: 7.6212 - val_mean_absolute_error: 7.9477 - val_root_mean_squared_error: 13.4428 - val_mean_absolute_percentage_error: 37.1791
# Epoch 20/100
# 103/103 [==============================] - 50s 487ms/step - loss: 4.4645 - mean_absolute_error: 4.7837 - root_mean_squared_error: 7.6906 - mean_absolute_percentage_error: 19.9908 - val_loss: 8.4931 - val_mean_absolute_error: 8.8359 - val_root_mean_squared_error: 13.5048 - val_mean_absolute_percentage_error: 52.3392
# Epoch 21/100
# 103/103 [==============================] - 50s 486ms/step - loss: 4.4686 - mean_absolute_error: 4.7848 - root_mean_squared_error: 7.7383 - mean_absolute_percentage_error: 20.0711 - val_loss: 8.0282 - val_mean_absolute_error: 8.3714 - val_root_mean_squared_error: 12.7211 - val_mean_absolute_percentage_error: 46.7189
# Epoch 22/100
# 103/103 [==============================] - 50s 486ms/step - loss: 4.4163 - mean_absolute_error: 4.7323 - root_mean_squared_error: 7.7212 - mean_absolute_percentage_error: 18.8548 - val_loss: 7.3087 - val_mean_absolute_error: 7.6353 - val_root_mean_squared_error: 13.2235 - val_mean_absolute_percentage_error: 39.4850
# Epoch 23/100
# 103/103 [==============================] - 50s 490ms/step - loss: 4.0940 - mean_absolute_error: 4.4103 - root_mean_squared_error: 7.0402 - mean_absolute_percentage_error: 19.0978 - val_loss: 6.6841 - val_mean_absolute_error: 7.0126 - val_root_mean_squared_error: 12.1687 - val_mean_absolute_percentage_error: 37.7476
# Epoch 24/100
# 103/103 [==============================] - 50s 486ms/step - loss: 3.9558 - mean_absolute_error: 4.2727 - root_mean_squared_error: 7.1679 - mean_absolute_percentage_error: 17.7501 - val_loss: 7.8703 - val_mean_absolute_error: 8.2096 - val_root_mean_squared_error: 12.8964 - val_mean_absolute_percentage_error: 45.2625
# Epoch 25/100
# 103/103 [==============================] - 50s 484ms/step - loss: 4.0972 - mean_absolute_error: 4.4187 - root_mean_squared_error: 7.1398 - mean_absolute_percentage_error: 18.3315 - val_loss: 6.8306 - val_mean_absolute_error: 7.1677 - val_root_mean_squared_error: 12.1676 - val_mean_absolute_percentage_error: 36.9085
# Epoch 26/100
# 103/103 [==============================] - 50s 486ms/step - loss: 4.2686 - mean_absolute_error: 4.5899 - root_mean_squared_error: 7.2506 - mean_absolute_percentage_error: 19.8368 - val_loss: 6.8138 - val_mean_absolute_error: 7.1460 - val_root_mean_squared_error: 12.4856 - val_mean_absolute_percentage_error: 40.1082
# Epoch 27/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.8033 - mean_absolute_error: 4.1228 - root_mean_squared_error: 6.5813 - mean_absolute_percentage_error: 17.0622 - val_loss: 7.1570 - val_mean_absolute_error: 7.4973 - val_root_mean_squared_error: 12.7561 - val_mean_absolute_percentage_error: 43.1604
# Epoch 28/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.8976 - mean_absolute_error: 4.2178 - root_mean_squared_error: 6.5599 - mean_absolute_percentage_error: 17.6709 - val_loss: 6.4577 - val_mean_absolute_error: 6.7818 - val_root_mean_squared_error: 12.1322 - val_mean_absolute_percentage_error: 35.0030
# Epoch 29/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.8714 - mean_absolute_error: 4.1924 - root_mean_squared_error: 6.7495 - mean_absolute_percentage_error: 16.9005 - val_loss: 7.6048 - val_mean_absolute_error: 7.9445 - val_root_mean_squared_error: 13.2151 - val_mean_absolute_percentage_error: 35.0067
# Epoch 30/100
# 103/103 [==============================] - 50s 486ms/step - loss: 3.8013 - mean_absolute_error: 4.1257 - root_mean_squared_error: 6.4259 - mean_absolute_percentage_error: 17.7677 - val_loss: 9.8094 - val_mean_absolute_error: 10.1460 - val_root_mean_squared_error: 15.8615 - val_mean_absolute_percentage_error: 44.1505
# Epoch 31/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.8967 - mean_absolute_error: 4.2190 - root_mean_squared_error: 6.7760 - mean_absolute_percentage_error: 17.7246 - val_loss: 6.6973 - val_mean_absolute_error: 7.0237 - val_root_mean_squared_error: 12.3559 - val_mean_absolute_percentage_error: 36.0767
# Epoch 32/100
# 103/103 [==============================] - 50s 489ms/step - loss: 3.6786 - mean_absolute_error: 4.0048 - root_mean_squared_error: 6.1948 - mean_absolute_percentage_error: 16.9014 - val_loss: 7.6078 - val_mean_absolute_error: 7.9502 - val_root_mean_squared_error: 13.0425 - val_mean_absolute_percentage_error: 41.2886
# Epoch 33/100
# 103/103 [==============================] - 50s 489ms/step - loss: 3.7241 - mean_absolute_error: 4.0498 - root_mean_squared_error: 6.4147 - mean_absolute_percentage_error: 17.8508 - val_loss: 6.6581 - val_mean_absolute_error: 6.9869 - val_root_mean_squared_error: 12.2524 - val_mean_absolute_percentage_error: 38.1689
# Epoch 34/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.6540 - mean_absolute_error: 3.9769 - root_mean_squared_error: 6.3087 - mean_absolute_percentage_error: 17.1910 - val_loss: 6.6939 - val_mean_absolute_error: 7.0322 - val_root_mean_squared_error: 12.2555 - val_mean_absolute_percentage_error: 41.1075
# Epoch 35/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.3653 - mean_absolute_error: 3.6877 - root_mean_squared_error: 5.6656 - mean_absolute_percentage_error: 16.2276 - val_loss: 7.4562 - val_mean_absolute_error: 7.7983 - val_root_mean_squared_error: 13.0113 - val_mean_absolute_percentage_error: 46.5186
# Epoch 36/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.7459 - mean_absolute_error: 4.0739 - root_mean_squared_error: 6.4461 - mean_absolute_percentage_error: 18.0641 - val_loss: 7.5850 - val_mean_absolute_error: 7.9310 - val_root_mean_squared_error: 12.8146 - val_mean_absolute_percentage_error: 45.2341
# Epoch 37/100
# 103/103 [==============================] - 50s 490ms/step - loss: 3.5554 - mean_absolute_error: 3.8790 - root_mean_squared_error: 6.0665 - mean_absolute_percentage_error: 17.2323 - val_loss: 7.4894 - val_mean_absolute_error: 7.8334 - val_root_mean_squared_error: 13.0546 - val_mean_absolute_percentage_error: 40.0630
# Epoch 38/100
# 103/103 [==============================] - 50s 486ms/step - loss: 3.6695 - mean_absolute_error: 3.9965 - root_mean_squared_error: 6.4173 - mean_absolute_percentage_error: 16.9631 - val_loss: 12.0915 - val_mean_absolute_error: 12.4464 - val_root_mean_squared_error: 17.3807 - val_mean_absolute_percentage_error: 59.8053
# Epoch 39/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.3394 - mean_absolute_error: 3.6638 - root_mean_squared_error: 5.8349 - mean_absolute_percentage_error: 15.7645 - val_loss: 8.8095 - val_mean_absolute_error: 9.1617 - val_root_mean_squared_error: 14.1893 - val_mean_absolute_percentage_error: 42.4703
# Epoch 40/100
# 103/103 [==============================] - 50s 486ms/step - loss: 3.2232 - mean_absolute_error: 3.5448 - root_mean_squared_error: 5.5359 - mean_absolute_percentage_error: 15.2240 - val_loss: 7.4136 - val_mean_absolute_error: 7.7558 - val_root_mean_squared_error: 12.9293 - val_mean_absolute_percentage_error: 41.2307
# Epoch 41/100
# 103/103 [==============================] - 50s 491ms/step - loss: 3.3906 - mean_absolute_error: 3.7176 - root_mean_squared_error: 5.7988 - mean_absolute_percentage_error: 16.3578 - val_loss: 6.9550 - val_mean_absolute_error: 7.2888 - val_root_mean_squared_error: 12.9094 - val_mean_absolute_percentage_error: 38.2253
# Epoch 42/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.1873 - mean_absolute_error: 3.5134 - root_mean_squared_error: 5.5229 - mean_absolute_percentage_error: 14.8411 - val_loss: 8.0057 - val_mean_absolute_error: 8.3532 - val_root_mean_squared_error: 13.3893 - val_mean_absolute_percentage_error: 42.7668
# Epoch 43/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.3611 - mean_absolute_error: 3.6870 - root_mean_squared_error: 5.7189 - mean_absolute_percentage_error: 15.8918 - val_loss: 8.9647 - val_mean_absolute_error: 9.3099 - val_root_mean_squared_error: 14.2348 - val_mean_absolute_percentage_error: 46.4095
# Epoch 44/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.2952 - mean_absolute_error: 3.6210 - root_mean_squared_error: 5.6650 - mean_absolute_percentage_error: 15.4950 - val_loss: 6.7985 - val_mean_absolute_error: 7.1360 - val_root_mean_squared_error: 12.6301 - val_mean_absolute_percentage_error: 37.6981
# Epoch 45/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.4786 - mean_absolute_error: 3.8042 - root_mean_squared_error: 5.9646 - mean_absolute_percentage_error: 17.4934 - val_loss: 7.7352 - val_mean_absolute_error: 8.0834 - val_root_mean_squared_error: 13.3963 - val_mean_absolute_percentage_error: 47.0076
# Epoch 46/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.3207 - mean_absolute_error: 3.6436 - root_mean_squared_error: 5.7164 - mean_absolute_percentage_error: 15.4583 - val_loss: 6.9978 - val_mean_absolute_error: 7.3310 - val_root_mean_squared_error: 13.1427 - val_mean_absolute_percentage_error: 40.6502
# Epoch 47/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.0704 - mean_absolute_error: 3.3886 - root_mean_squared_error: 5.4610 - mean_absolute_percentage_error: 14.6256 - val_loss: 6.5526 - val_mean_absolute_error: 6.8952 - val_root_mean_squared_error: 12.6903 - val_mean_absolute_percentage_error: 33.1866
# Epoch 48/100
# 103/103 [==============================] - 49s 475ms/step - loss: 3.1583 - mean_absolute_error: 3.4846 - root_mean_squared_error: 5.3982 - mean_absolute_percentage_error: 15.0562 - val_loss: 6.5774 - val_mean_absolute_error: 6.9082 - val_root_mean_squared_error: 12.9767 - val_mean_absolute_percentage_error: 36.6692
# Epoch 49/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.0170 - mean_absolute_error: 3.3379 - root_mean_squared_error: 5.2041 - mean_absolute_percentage_error: 14.3096 - val_loss: 8.7074 - val_mean_absolute_error: 9.0653 - val_root_mean_squared_error: 14.2840 - val_mean_absolute_percentage_error: 44.5313
# Epoch 50/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.3039 - mean_absolute_error: 3.6255 - root_mean_squared_error: 5.7503 - mean_absolute_percentage_error: 15.2386 - val_loss: 6.8539 - val_mean_absolute_error: 7.1924 - val_root_mean_squared_error: 12.9871 - val_mean_absolute_percentage_error: 36.0955
# Epoch 51/100
# 103/103 [==============================] - 50s 486ms/step - loss: 3.2495 - mean_absolute_error: 3.5742 - root_mean_squared_error: 5.6042 - mean_absolute_percentage_error: 15.4752 - val_loss: 7.5313 - val_mean_absolute_error: 7.8758 - val_root_mean_squared_error: 13.4127 - val_mean_absolute_percentage_error: 39.6402
# Epoch 52/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.0170 - mean_absolute_error: 3.3380 - root_mean_squared_error: 5.1991 - mean_absolute_percentage_error: 14.2849 - val_loss: 6.9181 - val_mean_absolute_error: 7.2601 - val_root_mean_squared_error: 13.1714 - val_mean_absolute_percentage_error: 39.7396
# Epoch 53/100
# 103/103 [==============================] - 50s 483ms/step - loss: 3.6715 - mean_absolute_error: 4.0056 - root_mean_squared_error: 6.2462 - mean_absolute_percentage_error: 19.5336 - val_loss: 7.8559 - val_mean_absolute_error: 8.1929 - val_root_mean_squared_error: 14.6328 - val_mean_absolute_percentage_error: 53.0694
# Epoch 54/100
# 103/103 [==============================] - 49s 472ms/step - loss: 3.3674 - mean_absolute_error: 3.6881 - root_mean_squared_error: 6.3177 - mean_absolute_percentage_error: 17.2433 - val_loss: 6.9892 - val_mean_absolute_error: 7.3205 - val_root_mean_squared_error: 13.5595 - val_mean_absolute_percentage_error: 39.0293
# Epoch 55/100
# 103/103 [==============================] - 50s 485ms/step - loss: 2.9466 - mean_absolute_error: 3.2599 - root_mean_squared_error: 5.1579 - mean_absolute_percentage_error: 14.7315 - val_loss: 6.8788 - val_mean_absolute_error: 7.2165 - val_root_mean_squared_error: 13.3169 - val_mean_absolute_percentage_error: 34.7148
# Epoch 56/100
# 103/103 [==============================] - 50s 486ms/step - loss: 2.8523 - mean_absolute_error: 3.1672 - root_mean_squared_error: 5.0293 - mean_absolute_percentage_error: 14.2451 - val_loss: 6.4170 - val_mean_absolute_error: 6.7485 - val_root_mean_squared_error: 12.9200 - val_mean_absolute_percentage_error: 34.0719
# Epoch 57/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.9264 - mean_absolute_error: 3.2407 - root_mean_squared_error: 5.0488 - mean_absolute_percentage_error: 13.9515 - val_loss: 6.6380 - val_mean_absolute_error: 6.9785 - val_root_mean_squared_error: 12.9367 - val_mean_absolute_percentage_error: 35.4489
# Epoch 58/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.9103 - mean_absolute_error: 3.2259 - root_mean_squared_error: 5.0768 - mean_absolute_percentage_error: 14.1719 - val_loss: 7.7124 - val_mean_absolute_error: 8.0513 - val_root_mean_squared_error: 13.3921 - val_mean_absolute_percentage_error: 41.5242
# Epoch 59/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.9153 - mean_absolute_error: 3.2314 - root_mean_squared_error: 5.0380 - mean_absolute_percentage_error: 13.5422 - val_loss: 6.8919 - val_mean_absolute_error: 7.2360 - val_root_mean_squared_error: 13.1452 - val_mean_absolute_percentage_error: 36.1485
# Epoch 60/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.8735 - mean_absolute_error: 3.1896 - root_mean_squared_error: 4.9298 - mean_absolute_percentage_error: 13.6971 - val_loss: 6.3438 - val_mean_absolute_error: 6.6795 - val_root_mean_squared_error: 12.6172 - val_mean_absolute_percentage_error: 38.7977
# Epoch 61/100
# 103/103 [==============================] - 50s 490ms/step - loss: 2.7119 - mean_absolute_error: 3.0289 - root_mean_squared_error: 4.6497 - mean_absolute_percentage_error: 13.0968 - val_loss: 6.8944 - val_mean_absolute_error: 7.2324 - val_root_mean_squared_error: 13.2435 - val_mean_absolute_percentage_error: 39.6615
# Epoch 62/100
# 103/103 [==============================] - 50s 486ms/step - loss: 2.8148 - mean_absolute_error: 3.1307 - root_mean_squared_error: 4.8839 - mean_absolute_percentage_error: 13.0128 - val_loss: 6.5182 - val_mean_absolute_error: 6.8528 - val_root_mean_squared_error: 13.0211 - val_mean_absolute_percentage_error: 35.5837
# Epoch 63/100
# 103/103 [==============================] - 50s 485ms/step - loss: 2.9575 - mean_absolute_error: 3.2770 - root_mean_squared_error: 5.4562 - mean_absolute_percentage_error: 14.2702 - val_loss: 7.2711 - val_mean_absolute_error: 7.6196 - val_root_mean_squared_error: 13.6422 - val_mean_absolute_percentage_error: 39.8478
# Epoch 64/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.9691 - mean_absolute_error: 3.2842 - root_mean_squared_error: 5.2445 - mean_absolute_percentage_error: 14.4697 - val_loss: 6.8578 - val_mean_absolute_error: 7.1854 - val_root_mean_squared_error: 13.3768 - val_mean_absolute_percentage_error: 36.8236
# Epoch 65/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.2781 - mean_absolute_error: 3.5969 - root_mean_squared_error: 6.0020 - mean_absolute_percentage_error: 15.7526 - val_loss: 6.8405 - val_mean_absolute_error: 7.1660 - val_root_mean_squared_error: 13.7266 - val_mean_absolute_percentage_error: 37.3473
# Epoch 66/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.9895 - mean_absolute_error: 3.3048 - root_mean_squared_error: 5.4870 - mean_absolute_percentage_error: 13.8761 - val_loss: 7.3498 - val_mean_absolute_error: 7.6816 - val_root_mean_squared_error: 13.8872 - val_mean_absolute_percentage_error: 40.3621
# Epoch 67/100
# 103/103 [==============================] - 50s 486ms/step - loss: 2.6731 - mean_absolute_error: 2.9832 - root_mean_squared_error: 5.0840 - mean_absolute_percentage_error: 12.6399 - val_loss: 6.6849 - val_mean_absolute_error: 7.0094 - val_root_mean_squared_error: 13.3324 - val_mean_absolute_percentage_error: 34.2467
# Epoch 68/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.7581 - mean_absolute_error: 3.0699 - root_mean_squared_error: 5.1122 - mean_absolute_percentage_error: 12.7886 - val_loss: 6.5872 - val_mean_absolute_error: 6.9039 - val_root_mean_squared_error: 13.2980 - val_mean_absolute_percentage_error: 35.3704
# Epoch 69/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.7522 - mean_absolute_error: 3.0614 - root_mean_squared_error: 4.9675 - mean_absolute_percentage_error: 12.3759 - val_loss: 7.0513 - val_mean_absolute_error: 7.3902 - val_root_mean_squared_error: 13.3000 - val_mean_absolute_percentage_error: 39.3065
# Epoch 70/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.6527 - mean_absolute_error: 2.9652 - root_mean_squared_error: 4.6237 - mean_absolute_percentage_error: 12.4731 - val_loss: 6.2849 - val_mean_absolute_error: 6.6017 - val_root_mean_squared_error: 12.7202 - val_mean_absolute_percentage_error: 35.8732
# Epoch 71/100
# 103/103 [==============================] - 50s 489ms/step - loss: 2.3910 - mean_absolute_error: 2.7040 - root_mean_squared_error: 4.0649 - mean_absolute_percentage_error: 12.1229 - val_loss: 6.4153 - val_mean_absolute_error: 6.7321 - val_root_mean_squared_error: 13.0746 - val_mean_absolute_percentage_error: 35.7497
# Epoch 72/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.4897 - mean_absolute_error: 2.7987 - root_mean_squared_error: 4.5229 - mean_absolute_percentage_error: 11.5944 - val_loss: 8.1796 - val_mean_absolute_error: 8.5197 - val_root_mean_squared_error: 14.4496 - val_mean_absolute_percentage_error: 37.9055
# Epoch 73/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.6164 - mean_absolute_error: 2.9285 - root_mean_squared_error: 4.6931 - mean_absolute_percentage_error: 11.9602 - val_loss: 7.2992 - val_mean_absolute_error: 7.6423 - val_root_mean_squared_error: 13.4653 - val_mean_absolute_percentage_error: 33.9603
# Epoch 74/100
# 103/103 [==============================] - 50s 485ms/step - loss: 2.5038 - mean_absolute_error: 2.8163 - root_mean_squared_error: 4.4553 - mean_absolute_percentage_error: 11.8986 - val_loss: 7.6197 - val_mean_absolute_error: 7.9601 - val_root_mean_squared_error: 13.7466 - val_mean_absolute_percentage_error: 39.7517
# Epoch 75/100
# 103/103 [==============================] - 50s 489ms/step - loss: 2.6475 - mean_absolute_error: 2.9619 - root_mean_squared_error: 4.6818 - mean_absolute_percentage_error: 12.2775 - val_loss: 7.0030 - val_mean_absolute_error: 7.3373 - val_root_mean_squared_error: 13.0170 - val_mean_absolute_percentage_error: 39.0753
# Epoch 76/100
# 103/103 [==============================] - 50s 491ms/step - loss: 2.5010 - mean_absolute_error: 2.8106 - root_mean_squared_error: 4.5623 - mean_absolute_percentage_error: 11.2160 - val_loss: 6.8532 - val_mean_absolute_error: 7.1859 - val_root_mean_squared_error: 13.3947 - val_mean_absolute_percentage_error: 35.7080
# Epoch 77/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.4818 - mean_absolute_error: 2.7903 - root_mean_squared_error: 4.4765 - mean_absolute_percentage_error: 11.0889 - val_loss: 6.8370 - val_mean_absolute_error: 7.1738 - val_root_mean_squared_error: 13.3789 - val_mean_absolute_percentage_error: 33.9271
# Epoch 78/100
# 103/103 [==============================] - 50s 483ms/step - loss: 2.7847 - mean_absolute_error: 3.1048 - root_mean_squared_error: 4.9677 - mean_absolute_percentage_error: 13.4804 - val_loss: 8.1564 - val_mean_absolute_error: 8.4916 - val_root_mean_squared_error: 14.6714 - val_mean_absolute_percentage_error: 39.7504
# Epoch 79/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.5751 - mean_absolute_error: 2.8918 - root_mean_squared_error: 4.5177 - mean_absolute_percentage_error: 11.6798 - val_loss: 7.4549 - val_mean_absolute_error: 7.7962 - val_root_mean_squared_error: 13.7648 - val_mean_absolute_percentage_error: 38.5778
# Epoch 80/100
# 103/103 [==============================] - 50s 486ms/step - loss: 2.7092 - mean_absolute_error: 3.0257 - root_mean_squared_error: 4.7957 - mean_absolute_percentage_error: 12.0937 - val_loss: 6.6572 - val_mean_absolute_error: 6.9871 - val_root_mean_squared_error: 13.1742 - val_mean_absolute_percentage_error: 36.0275
# Epoch 81/100
# 103/103 [==============================] - 50s 489ms/step - loss: 2.5779 - mean_absolute_error: 2.8934 - root_mean_squared_error: 4.5945 - mean_absolute_percentage_error: 11.5632 - val_loss: 6.5827 - val_mean_absolute_error: 6.9061 - val_root_mean_squared_error: 13.1514 - val_mean_absolute_percentage_error: 35.0123
# Epoch 82/100
# 103/103 [==============================] - 50s 486ms/step - loss: 2.3652 - mean_absolute_error: 2.6814 - root_mean_squared_error: 4.2294 - mean_absolute_percentage_error: 11.6179 - val_loss: 6.5759 - val_mean_absolute_error: 6.8975 - val_root_mean_squared_error: 13.4587 - val_mean_absolute_percentage_error: 34.9647
# Epoch 83/100
# 103/103 [==============================] - 50s 489ms/step - loss: 2.3901 - mean_absolute_error: 2.7014 - root_mean_squared_error: 4.2254 - mean_absolute_percentage_error: 11.1830 - val_loss: 7.8121 - val_mean_absolute_error: 8.1576 - val_root_mean_squared_error: 14.1696 - val_mean_absolute_percentage_error: 39.0436
# Epoch 84/100
# 103/103 [==============================] - 60s 582ms/step - loss: 2.4553 - mean_absolute_error: 2.7716 - root_mean_squared_error: 4.2957 - mean_absolute_percentage_error: 11.8072 - val_loss: 6.8512 - val_mean_absolute_error: 7.1889 - val_root_mean_squared_error: 13.4296 - val_mean_absolute_percentage_error: 35.7814
# Epoch 85/100
# 103/103 [==============================] - 59s 578ms/step - loss: 2.3074 - mean_absolute_error: 2.6202 - root_mean_squared_error: 4.0488 - mean_absolute_percentage_error: 10.8360 - val_loss: 7.2222 - val_mean_absolute_error: 7.5781 - val_root_mean_squared_error: 13.4138 - val_mean_absolute_percentage_error: 35.7487
# Epoch 86/100
# 103/103 [==============================] - 59s 576ms/step - loss: 2.3618 - mean_absolute_error: 2.6743 - root_mean_squared_error: 4.2469 - mean_absolute_percentage_error: 10.9492 - val_loss: 6.3472 - val_mean_absolute_error: 6.6708 - val_root_mean_squared_error: 12.6845 - val_mean_absolute_percentage_error: 35.8715
# Epoch 87/100
# 103/103 [==============================] - 60s 583ms/step - loss: 2.4310 - mean_absolute_error: 2.7443 - root_mean_squared_error: 4.4786 - mean_absolute_percentage_error: 11.1622 - val_loss: 7.2990 - val_mean_absolute_error: 7.6417 - val_root_mean_squared_error: 13.6132 - val_mean_absolute_percentage_error: 39.8557
# Epoch 88/100
# 103/103 [==============================] - 64s 620ms/step - loss: 2.4253 - mean_absolute_error: 2.7414 - root_mean_squared_error: 4.3020 - mean_absolute_percentage_error: 11.8025 - val_loss: 6.6164 - val_mean_absolute_error: 6.9558 - val_root_mean_squared_error: 13.1832 - val_mean_absolute_percentage_error: 37.0589
# Epoch 89/100
# 103/103 [==============================] - 59s 577ms/step - loss: 2.5543 - mean_absolute_error: 2.8718 - root_mean_squared_error: 4.4972 - mean_absolute_percentage_error: 12.2564 - val_loss: 8.5240 - val_mean_absolute_error: 8.8672 - val_root_mean_squared_error: 14.3386 - val_mean_absolute_percentage_error: 51.9644
# Epoch 90/100
# 103/103 [==============================] - 59s 571ms/step - loss: 2.5103 - mean_absolute_error: 2.8205 - root_mean_squared_error: 4.7050 - mean_absolute_percentage_error: 11.8601 - val_loss: 7.0880 - val_mean_absolute_error: 7.4109 - val_root_mean_squared_error: 13.9382 - val_mean_absolute_percentage_error: 38.2367
# Epoch 91/100
# 103/103 [==============================] - 60s 582ms/step - loss: 2.7159 - mean_absolute_error: 3.0310 - root_mean_squared_error: 5.5507 - mean_absolute_percentage_error: 13.1034 - val_loss: 6.8925 - val_mean_absolute_error: 7.2279 - val_root_mean_squared_error: 13.5864 - val_mean_absolute_percentage_error: 37.3802
# Epoch 92/100
# 103/103 [==============================] - 63s 608ms/step - loss: 2.3495 - mean_absolute_error: 2.6570 - root_mean_squared_error: 4.2158 - mean_absolute_percentage_error: 11.2541 - val_loss: 6.7116 - val_mean_absolute_error: 7.0338 - val_root_mean_squared_error: 13.6252 - val_mean_absolute_percentage_error: 36.4382
# Epoch 93/100
# 103/103 [==============================] - 67s 653ms/step - loss: 2.3146 - mean_absolute_error: 2.6229 - root_mean_squared_error: 4.3479 - mean_absolute_percentage_error: 10.8026 - val_loss: 6.9270 - val_mean_absolute_error: 7.2579 - val_root_mean_squared_error: 14.6209 - val_mean_absolute_percentage_error: 41.1742
# Epoch 94/100
# 103/103 [==============================] - 64s 625ms/step - loss: 2.5476 - mean_absolute_error: 2.8497 - root_mean_squared_error: 6.1076 - mean_absolute_percentage_error: 12.5853 - val_loss: 7.1933 - val_mean_absolute_error: 7.5149 - val_root_mean_squared_error: 14.6897 - val_mean_absolute_percentage_error: 37.5478
# Epoch 95/100
# 103/103 [==============================] - 65s 630ms/step - loss: 2.3115 - mean_absolute_error: 2.6093 - root_mean_squared_error: 5.1930 - mean_absolute_percentage_error: 10.9322 - val_loss: 6.6445 - val_mean_absolute_error: 6.9627 - val_root_mean_squared_error: 14.2851 - val_mean_absolute_percentage_error: 36.4406
# Epoch 96/100
# 103/103 [==============================] - 64s 623ms/step - loss: 2.2737 - mean_absolute_error: 2.5727 - root_mean_squared_error: 5.0937 - mean_absolute_percentage_error: 10.7318 - val_loss: 6.5055 - val_mean_absolute_error: 6.8147 - val_root_mean_squared_error: 13.0621 - val_mean_absolute_percentage_error: 39.0023
# Epoch 97/100
# 103/103 [==============================] - 67s 649ms/step - loss: 2.1672 - mean_absolute_error: 2.4630 - root_mean_squared_error: 3.8908 - mean_absolute_percentage_error: 10.4287 - val_loss: 6.3597 - val_mean_absolute_error: 6.6629 - val_root_mean_squared_error: 13.4420 - val_mean_absolute_percentage_error: 34.5395
# Epoch 98/100
# 103/103 [==============================] - 64s 619ms/step - loss: 2.3698 - mean_absolute_error: 2.6687 - root_mean_squared_error: 4.3489 - mean_absolute_percentage_error: 10.7107 - val_loss: 6.6633 - val_mean_absolute_error: 6.9856 - val_root_mean_squared_error: 13.9256 - val_mean_absolute_percentage_error: 34.8711
# Epoch 99/100
# 103/103 [==============================] - 62s 598ms/step - loss: 2.1852 - mean_absolute_error: 2.4792 - root_mean_squared_error: 3.9995 - mean_absolute_percentage_error: 9.6152 - val_loss: 6.4046 - val_mean_absolute_error: 6.7144 - val_root_mean_squared_error: 13.3048 - val_mean_absolute_percentage_error: 35.6877
# Epoch 100/100
# 103/103 [==============================] - 63s 611ms/step - loss: 2.1060 - mean_absolute_error: 2.4039 - root_mean_squared_error: 3.8216 - mean_absolute_percentage_error: 9.7030 - val_loss: 6.9352 - val_mean_absolute_error: 7.2645 - val_root_mean_squared_error: 13.7028 - val_mean_absolute_percentage_error: 38.4828

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 8s 255ms/step - loss: 6.9352 - mean_absolute_error: 7.2645 - root_mean_squared_error: 13.7028 - mean_absolute_percentage_error: 38.4828
# Model Loss: [6.9351606369018555, 7.2644782066345215, 13.70283031463623, 38.48283767700195]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted Putusan: [13.609978]

# %%
model_scenario_name = "BiLSTM_8"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_8\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_8\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_8"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted Putusan: [13.609978]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
