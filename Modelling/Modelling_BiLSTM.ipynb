# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_11260\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalAveragePooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['bidirectional[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['bidirectional_1[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  global_average_pooling1d (Glob  (None, 64)          0           ['bidirectional_2[0][0]']
#  alAveragePooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,018,529
# Trainable params: 4,018,337
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 35s 283ms/step - loss: 32.7406 - mean_absolute_error: 32.4021 - root_mean_squared_error: 45.3315 - mean_absolute_percentage_error: 86.5729 - val_loss: 33.6396 - val_mean_absolute_error: 33.3568 - val_root_mean_squared_error: 46.8173 - val_mean_absolute_percentage_error: 83.4758
# Epoch 2/100
# 103/103 [==============================] - 28s 268ms/step - loss: 29.3789 - mean_absolute_error: 29.1411 - root_mean_squared_error: 42.9447 - mean_absolute_percentage_error: 71.8460 - val_loss: 30.4272 - val_mean_absolute_error: 30.2406 - val_root_mean_squared_error: 44.2879 - val_mean_absolute_percentage_error: 69.4276
# Epoch 3/100
# 103/103 [==============================] - 28s 269ms/step - loss: 25.7151 - mean_absolute_error: 25.5699 - root_mean_squared_error: 39.5782 - mean_absolute_percentage_error: 66.3913 - val_loss: 24.8157 - val_mean_absolute_error: 24.7088 - val_root_mean_squared_error: 38.2707 - val_mean_absolute_percentage_error: 61.2837
# Epoch 4/100
# 103/103 [==============================] - 28s 269ms/step - loss: 21.4371 - mean_absolute_error: 21.3569 - root_mean_squared_error: 33.1068 - mean_absolute_percentage_error: 64.7783 - val_loss: 23.3559 - val_mean_absolute_error: 23.3022 - val_root_mean_squared_error: 34.2295 - val_mean_absolute_percentage_error: 60.6889
# Epoch 5/100
# 103/103 [==============================] - 28s 276ms/step - loss: 13.9806 - mean_absolute_error: 13.9365 - root_mean_squared_error: 21.2671 - mean_absolute_percentage_error: 60.8462 - val_loss: 22.1587 - val_mean_absolute_error: 22.1286 - val_root_mean_squared_error: 33.2906 - val_mean_absolute_percentage_error: 60.2473
# Epoch 6/100
# 103/103 [==============================] - 28s 270ms/step - loss: 11.1649 - mean_absolute_error: 11.1403 - root_mean_squared_error: 16.7190 - mean_absolute_percentage_error: 60.2062 - val_loss: 15.6944 - val_mean_absolute_error: 15.6795 - val_root_mean_squared_error: 24.0107 - val_mean_absolute_percentage_error: 56.3262
# Epoch 7/100
# 103/103 [==============================] - 30s 292ms/step - loss: 10.4253 - mean_absolute_error: 10.4157 - root_mean_squared_error: 16.0225 - mean_absolute_percentage_error: 58.4508 - val_loss: 13.0277 - val_mean_absolute_error: 13.0293 - val_root_mean_squared_error: 19.7570 - val_mean_absolute_percentage_error: 50.4478
# Epoch 8/100
# 103/103 [==============================] - 36s 346ms/step - loss: 10.2123 - mean_absolute_error: 10.2142 - root_mean_squared_error: 15.6385 - mean_absolute_percentage_error: 59.1341 - val_loss: 13.1244 - val_mean_absolute_error: 13.1395 - val_root_mean_squared_error: 19.8927 - val_mean_absolute_percentage_error: 48.9728
# Epoch 9/100
# 103/103 [==============================] - 40s 388ms/step - loss: 9.7655 - mean_absolute_error: 9.7791 - root_mean_squared_error: 15.0481 - mean_absolute_percentage_error: 55.1207 - val_loss: 13.4856 - val_mean_absolute_error: 13.5095 - val_root_mean_squared_error: 20.5604 - val_mean_absolute_percentage_error: 48.3007
# Epoch 10/100
# 103/103 [==============================] - 33s 325ms/step - loss: 9.5299 - mean_absolute_error: 9.5527 - root_mean_squared_error: 14.7069 - mean_absolute_percentage_error: 53.2812 - val_loss: 12.1534 - val_mean_absolute_error: 12.1881 - val_root_mean_squared_error: 18.9565 - val_mean_absolute_percentage_error: 45.7840
# Epoch 11/100
# 103/103 [==============================] - 31s 297ms/step - loss: 8.9439 - mean_absolute_error: 8.9725 - root_mean_squared_error: 14.2620 - mean_absolute_percentage_error: 49.9453 - val_loss: 10.1810 - val_mean_absolute_error: 10.2176 - val_root_mean_squared_error: 16.7252 - val_mean_absolute_percentage_error: 45.7933
# Epoch 12/100
# 103/103 [==============================] - 31s 297ms/step - loss: 8.3486 - mean_absolute_error: 8.3847 - root_mean_squared_error: 13.2264 - mean_absolute_percentage_error: 46.6222 - val_loss: 10.2991 - val_mean_absolute_error: 10.3352 - val_root_mean_squared_error: 16.7697 - val_mean_absolute_percentage_error: 44.7666
# Epoch 13/100
# 103/103 [==============================] - 29s 281ms/step - loss: 7.9177 - mean_absolute_error: 7.9576 - root_mean_squared_error: 12.4377 - mean_absolute_percentage_error: 43.9366 - val_loss: 8.9461 - val_mean_absolute_error: 8.9800 - val_root_mean_squared_error: 15.6637 - val_mean_absolute_percentage_error: 41.9577
# Epoch 14/100
# 103/103 [==============================] - 29s 283ms/step - loss: 7.7371 - mean_absolute_error: 7.7826 - root_mean_squared_error: 12.2415 - mean_absolute_percentage_error: 42.6879 - val_loss: 9.4182 - val_mean_absolute_error: 9.4698 - val_root_mean_squared_error: 16.0000 - val_mean_absolute_percentage_error: 42.6563
# Epoch 15/100
# 103/103 [==============================] - 32s 316ms/step - loss: 7.8971 - mean_absolute_error: 7.9475 - root_mean_squared_error: 12.3458 - mean_absolute_percentage_error: 43.9292 - val_loss: 9.1530 - val_mean_absolute_error: 9.2070 - val_root_mean_squared_error: 15.5198 - val_mean_absolute_percentage_error: 43.4368
# Epoch 16/100
# 103/103 [==============================] - 29s 279ms/step - loss: 7.4162 - mean_absolute_error: 7.4676 - root_mean_squared_error: 11.7855 - mean_absolute_percentage_error: 40.8932 - val_loss: 9.1882 - val_mean_absolute_error: 9.2455 - val_root_mean_squared_error: 15.3661 - val_mean_absolute_percentage_error: 43.1946
# Epoch 17/100
# 103/103 [==============================] - 29s 277ms/step - loss: 7.2201 - mean_absolute_error: 7.2761 - root_mean_squared_error: 11.2586 - mean_absolute_percentage_error: 39.3605 - val_loss: 8.8251 - val_mean_absolute_error: 8.8820 - val_root_mean_squared_error: 15.7091 - val_mean_absolute_percentage_error: 40.8896
# Epoch 18/100
# 103/103 [==============================] - 29s 279ms/step - loss: 6.7656 - mean_absolute_error: 6.8252 - root_mean_squared_error: 10.7131 - mean_absolute_percentage_error: 37.4985 - val_loss: 8.5272 - val_mean_absolute_error: 8.5934 - val_root_mean_squared_error: 14.7961 - val_mean_absolute_percentage_error: 42.6419
# Epoch 19/100
# 103/103 [==============================] - 29s 280ms/step - loss: 7.1163 - mean_absolute_error: 7.1780 - root_mean_squared_error: 11.0642 - mean_absolute_percentage_error: 37.2098 - val_loss: 9.2836 - val_mean_absolute_error: 9.3578 - val_root_mean_squared_error: 15.0778 - val_mean_absolute_percentage_error: 40.8972
# Epoch 20/100
# 103/103 [==============================] - 28s 277ms/step - loss: 6.7450 - mean_absolute_error: 6.8117 - root_mean_squared_error: 10.3979 - mean_absolute_percentage_error: 37.1631 - val_loss: 8.8978 - val_mean_absolute_error: 8.9704 - val_root_mean_squared_error: 15.0629 - val_mean_absolute_percentage_error: 41.5260
# Epoch 21/100
# 103/103 [==============================] - 29s 279ms/step - loss: 6.3978 - mean_absolute_error: 6.4643 - root_mean_squared_error: 10.1620 - mean_absolute_percentage_error: 34.5408 - val_loss: 8.3367 - val_mean_absolute_error: 8.4091 - val_root_mean_squared_error: 14.4561 - val_mean_absolute_percentage_error: 41.2325
# Epoch 22/100
# 103/103 [==============================] - 29s 279ms/step - loss: 6.2298 - mean_absolute_error: 6.2973 - root_mean_squared_error: 9.7934 - mean_absolute_percentage_error: 32.8571 - val_loss: 8.6247 - val_mean_absolute_error: 8.6969 - val_root_mean_squared_error: 14.9815 - val_mean_absolute_percentage_error: 42.1800
# Epoch 23/100
# 103/103 [==============================] - 28s 277ms/step - loss: 5.9578 - mean_absolute_error: 6.0268 - root_mean_squared_error: 9.3768 - mean_absolute_percentage_error: 32.1283 - val_loss: 8.1482 - val_mean_absolute_error: 8.2212 - val_root_mean_squared_error: 14.4356 - val_mean_absolute_percentage_error: 40.2664
# Epoch 24/100
# 103/103 [==============================] - 28s 275ms/step - loss: 6.0487 - mean_absolute_error: 6.1212 - root_mean_squared_error: 9.4042 - mean_absolute_percentage_error: 31.8321 - val_loss: 8.0106 - val_mean_absolute_error: 8.0906 - val_root_mean_squared_error: 14.6985 - val_mean_absolute_percentage_error: 41.4010
# Epoch 25/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.6923 - mean_absolute_error: 5.7652 - root_mean_squared_error: 8.9971 - mean_absolute_percentage_error: 29.3620 - val_loss: 7.9833 - val_mean_absolute_error: 8.0706 - val_root_mean_squared_error: 14.0860 - val_mean_absolute_percentage_error: 40.9249
# Epoch 26/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.6886 - mean_absolute_error: 5.7648 - root_mean_squared_error: 9.0971 - mean_absolute_percentage_error: 28.5900 - val_loss: 9.3648 - val_mean_absolute_error: 9.4582 - val_root_mean_squared_error: 14.8907 - val_mean_absolute_percentage_error: 40.6658
# Epoch 27/100
# 103/103 [==============================] - 29s 279ms/step - loss: 5.7984 - mean_absolute_error: 5.8766 - root_mean_squared_error: 9.3148 - mean_absolute_percentage_error: 28.3530 - val_loss: 7.9425 - val_mean_absolute_error: 8.0317 - val_root_mean_squared_error: 14.0601 - val_mean_absolute_percentage_error: 40.8552
# Epoch 28/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.9935 - mean_absolute_error: 6.0740 - root_mean_squared_error: 9.6423 - mean_absolute_percentage_error: 29.5246 - val_loss: 7.2484 - val_mean_absolute_error: 7.3319 - val_root_mean_squared_error: 13.5182 - val_mean_absolute_percentage_error: 39.0001
# Epoch 29/100
# 103/103 [==============================] - 28s 274ms/step - loss: 5.7666 - mean_absolute_error: 5.8501 - root_mean_squared_error: 9.4388 - mean_absolute_percentage_error: 29.1481 - val_loss: 7.3439 - val_mean_absolute_error: 7.4294 - val_root_mean_squared_error: 13.3678 - val_mean_absolute_percentage_error: 37.5814
# Epoch 30/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.3881 - mean_absolute_error: 5.4724 - root_mean_squared_error: 8.4788 - mean_absolute_percentage_error: 26.4526 - val_loss: 7.7138 - val_mean_absolute_error: 7.8108 - val_root_mean_squared_error: 13.8070 - val_mean_absolute_percentage_error: 39.8984
# Epoch 31/100
# 103/103 [==============================] - 29s 278ms/step - loss: 5.3834 - mean_absolute_error: 5.4660 - root_mean_squared_error: 8.5322 - mean_absolute_percentage_error: 25.1729 - val_loss: 7.2406 - val_mean_absolute_error: 7.3270 - val_root_mean_squared_error: 13.1962 - val_mean_absolute_percentage_error: 37.3435
# Epoch 32/100
# 103/103 [==============================] - 29s 279ms/step - loss: 5.1753 - mean_absolute_error: 5.2576 - root_mean_squared_error: 8.3325 - mean_absolute_percentage_error: 24.7004 - val_loss: 7.7116 - val_mean_absolute_error: 7.8074 - val_root_mean_squared_error: 13.6925 - val_mean_absolute_percentage_error: 39.8282
# Epoch 33/100
# 103/103 [==============================] - 30s 290ms/step - loss: 4.8096 - mean_absolute_error: 4.8893 - root_mean_squared_error: 7.6487 - mean_absolute_percentage_error: 23.5206 - val_loss: 7.7038 - val_mean_absolute_error: 7.8024 - val_root_mean_squared_error: 13.7452 - val_mean_absolute_percentage_error: 39.6609
# Epoch 34/100
# 103/103 [==============================] - 28s 274ms/step - loss: 5.0354 - mean_absolute_error: 5.1216 - root_mean_squared_error: 7.8840 - mean_absolute_percentage_error: 24.5316 - val_loss: 6.9645 - val_mean_absolute_error: 7.0499 - val_root_mean_squared_error: 13.2143 - val_mean_absolute_percentage_error: 37.6119
# Epoch 35/100
# 103/103 [==============================] - 28s 275ms/step - loss: 5.1373 - mean_absolute_error: 5.2254 - root_mean_squared_error: 8.3978 - mean_absolute_percentage_error: 23.7239 - val_loss: 7.1375 - val_mean_absolute_error: 7.2353 - val_root_mean_squared_error: 12.9584 - val_mean_absolute_percentage_error: 37.4657
# Epoch 36/100
# 103/103 [==============================] - 28s 273ms/step - loss: 5.0248 - mean_absolute_error: 5.1145 - root_mean_squared_error: 8.0929 - mean_absolute_percentage_error: 23.8429 - val_loss: 7.7428 - val_mean_absolute_error: 7.8450 - val_root_mean_squared_error: 13.6568 - val_mean_absolute_percentage_error: 38.5273
# Epoch 37/100
# 103/103 [==============================] - 28s 276ms/step - loss: 5.2194 - mean_absolute_error: 5.3121 - root_mean_squared_error: 8.3270 - mean_absolute_percentage_error: 23.5188 - val_loss: 8.4336 - val_mean_absolute_error: 8.5453 - val_root_mean_squared_error: 14.2681 - val_mean_absolute_percentage_error: 42.4877
# Epoch 38/100
# 103/103 [==============================] - 30s 292ms/step - loss: 5.3718 - mean_absolute_error: 5.4682 - root_mean_squared_error: 8.5004 - mean_absolute_percentage_error: 23.9758 - val_loss: 8.8230 - val_mean_absolute_error: 8.9381 - val_root_mean_squared_error: 13.7182 - val_mean_absolute_percentage_error: 39.1567
# Epoch 39/100
# 103/103 [==============================] - 28s 276ms/step - loss: 4.9083 - mean_absolute_error: 5.0039 - root_mean_squared_error: 7.9316 - mean_absolute_percentage_error: 22.3436 - val_loss: 8.2840 - val_mean_absolute_error: 8.3933 - val_root_mean_squared_error: 14.3700 - val_mean_absolute_percentage_error: 40.5760
# Epoch 40/100
# 103/103 [==============================] - 29s 284ms/step - loss: 5.3695 - mean_absolute_error: 5.4663 - root_mean_squared_error: 8.6874 - mean_absolute_percentage_error: 23.5265 - val_loss: 7.3061 - val_mean_absolute_error: 7.4143 - val_root_mean_squared_error: 13.1861 - val_mean_absolute_percentage_error: 34.7333
# Epoch 41/100
# 103/103 [==============================] - 30s 290ms/step - loss: 5.1245 - mean_absolute_error: 5.2199 - root_mean_squared_error: 8.2728 - mean_absolute_percentage_error: 23.1523 - val_loss: 7.1919 - val_mean_absolute_error: 7.3045 - val_root_mean_squared_error: 12.9367 - val_mean_absolute_percentage_error: 39.0860
# Epoch 42/100
# 103/103 [==============================] - 29s 280ms/step - loss: 4.8402 - mean_absolute_error: 4.9336 - root_mean_squared_error: 7.7443 - mean_absolute_percentage_error: 21.8821 - val_loss: 6.7075 - val_mean_absolute_error: 6.7984 - val_root_mean_squared_error: 13.1478 - val_mean_absolute_percentage_error: 38.8375
# Epoch 43/100
# 103/103 [==============================] - 29s 281ms/step - loss: 5.0334 - mean_absolute_error: 5.1316 - root_mean_squared_error: 8.2757 - mean_absolute_percentage_error: 23.3574 - val_loss: 7.7837 - val_mean_absolute_error: 7.8994 - val_root_mean_squared_error: 14.1970 - val_mean_absolute_percentage_error: 42.1771
# Epoch 44/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.6730 - mean_absolute_error: 4.7719 - root_mean_squared_error: 7.5712 - mean_absolute_percentage_error: 21.4798 - val_loss: 7.7732 - val_mean_absolute_error: 7.8910 - val_root_mean_squared_error: 14.1511 - val_mean_absolute_percentage_error: 41.4635
# Epoch 45/100
# 103/103 [==============================] - 29s 280ms/step - loss: 4.7465 - mean_absolute_error: 4.8450 - root_mean_squared_error: 7.8340 - mean_absolute_percentage_error: 21.5611 - val_loss: 7.5611 - val_mean_absolute_error: 7.6795 - val_root_mean_squared_error: 14.0525 - val_mean_absolute_percentage_error: 40.3759
# Epoch 46/100
# 103/103 [==============================] - 29s 282ms/step - loss: 4.9598 - mean_absolute_error: 5.0635 - root_mean_squared_error: 7.8552 - mean_absolute_percentage_error: 22.3539 - val_loss: 7.8659 - val_mean_absolute_error: 7.9890 - val_root_mean_squared_error: 13.5769 - val_mean_absolute_percentage_error: 41.8671
# Epoch 47/100
# 103/103 [==============================] - 29s 279ms/step - loss: 4.9479 - mean_absolute_error: 5.0484 - root_mean_squared_error: 8.4397 - mean_absolute_percentage_error: 21.3578 - val_loss: 7.2683 - val_mean_absolute_error: 7.3833 - val_root_mean_squared_error: 13.1812 - val_mean_absolute_percentage_error: 37.7231
# Epoch 48/100
# 103/103 [==============================] - 28s 277ms/step - loss: 4.8719 - mean_absolute_error: 4.9812 - root_mean_squared_error: 7.7572 - mean_absolute_percentage_error: 21.9737 - val_loss: 7.0272 - val_mean_absolute_error: 7.1273 - val_root_mean_squared_error: 13.1269 - val_mean_absolute_percentage_error: 37.3400
# Epoch 49/100
# 103/103 [==============================] - 29s 278ms/step - loss: 5.0454 - mean_absolute_error: 5.1524 - root_mean_squared_error: 8.2728 - mean_absolute_percentage_error: 22.1650 - val_loss: 7.5149 - val_mean_absolute_error: 7.6416 - val_root_mean_squared_error: 13.4133 - val_mean_absolute_percentage_error: 39.9256
# Epoch 50/100
# 103/103 [==============================] - 31s 302ms/step - loss: 4.6722 - mean_absolute_error: 4.7747 - root_mean_squared_error: 7.6410 - mean_absolute_percentage_error: 20.5063 - val_loss: 7.6565 - val_mean_absolute_error: 7.7856 - val_root_mean_squared_error: 13.3751 - val_mean_absolute_percentage_error: 38.7701
# Epoch 51/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.4637 - mean_absolute_error: 4.5694 - root_mean_squared_error: 7.2762 - mean_absolute_percentage_error: 19.8264 - val_loss: 7.5405 - val_mean_absolute_error: 7.6555 - val_root_mean_squared_error: 13.3965 - val_mean_absolute_percentage_error: 39.1295
# Epoch 52/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.6494 - mean_absolute_error: 4.7544 - root_mean_squared_error: 7.7021 - mean_absolute_percentage_error: 20.3880 - val_loss: 7.4800 - val_mean_absolute_error: 7.6106 - val_root_mean_squared_error: 13.3087 - val_mean_absolute_percentage_error: 39.8308
# Epoch 53/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.5580 - mean_absolute_error: 4.6657 - root_mean_squared_error: 7.5328 - mean_absolute_percentage_error: 19.6159 - val_loss: 6.8410 - val_mean_absolute_error: 6.9557 - val_root_mean_squared_error: 13.1556 - val_mean_absolute_percentage_error: 38.6462
# Epoch 54/100
# 103/103 [==============================] - 31s 303ms/step - loss: 4.5134 - mean_absolute_error: 4.6203 - root_mean_squared_error: 7.3272 - mean_absolute_percentage_error: 19.6350 - val_loss: 7.5513 - val_mean_absolute_error: 7.6691 - val_root_mean_squared_error: 13.4446 - val_mean_absolute_percentage_error: 38.5727
# Epoch 55/100
# 103/103 [==============================] - 36s 347ms/step - loss: 4.5476 - mean_absolute_error: 4.6574 - root_mean_squared_error: 7.3998 - mean_absolute_percentage_error: 19.9137 - val_loss: 6.6611 - val_mean_absolute_error: 6.7713 - val_root_mean_squared_error: 12.9688 - val_mean_absolute_percentage_error: 38.7325
# Epoch 56/100
# 103/103 [==============================] - 41s 398ms/step - loss: 4.5782 - mean_absolute_error: 4.6892 - root_mean_squared_error: 7.3895 - mean_absolute_percentage_error: 19.8663 - val_loss: 7.6138 - val_mean_absolute_error: 7.7504 - val_root_mean_squared_error: 13.2248 - val_mean_absolute_percentage_error: 40.0090
# Epoch 57/100
# 103/103 [==============================] - 34s 329ms/step - loss: 4.6111 - mean_absolute_error: 4.7238 - root_mean_squared_error: 7.3976 - mean_absolute_percentage_error: 20.4225 - val_loss: 6.5723 - val_mean_absolute_error: 6.6816 - val_root_mean_squared_error: 12.6171 - val_mean_absolute_percentage_error: 35.4623
# Epoch 58/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.2807 - mean_absolute_error: 4.3917 - root_mean_squared_error: 7.2432 - mean_absolute_percentage_error: 19.2640 - val_loss: 6.5499 - val_mean_absolute_error: 6.6578 - val_root_mean_squared_error: 12.8152 - val_mean_absolute_percentage_error: 39.2714
# Epoch 59/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4532 - mean_absolute_error: 4.5664 - root_mean_squared_error: 7.2922 - mean_absolute_percentage_error: 19.2023 - val_loss: 7.5421 - val_mean_absolute_error: 7.6795 - val_root_mean_squared_error: 13.1506 - val_mean_absolute_percentage_error: 39.2944
# Epoch 60/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.4803 - mean_absolute_error: 4.5956 - root_mean_squared_error: 7.5372 - mean_absolute_percentage_error: 19.5872 - val_loss: 6.9239 - val_mean_absolute_error: 7.0404 - val_root_mean_squared_error: 13.2994 - val_mean_absolute_percentage_error: 41.1978
# Epoch 61/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.4913 - mean_absolute_error: 4.6079 - root_mean_squared_error: 7.3918 - mean_absolute_percentage_error: 19.8393 - val_loss: 7.3292 - val_mean_absolute_error: 7.4590 - val_root_mean_squared_error: 14.0282 - val_mean_absolute_percentage_error: 35.3227
# Epoch 62/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.5475 - mean_absolute_error: 4.6661 - root_mean_squared_error: 7.6777 - mean_absolute_percentage_error: 20.4650 - val_loss: 7.0612 - val_mean_absolute_error: 7.1968 - val_root_mean_squared_error: 13.0365 - val_mean_absolute_percentage_error: 38.3487
# Epoch 63/100
# 103/103 [==============================] - 28s 276ms/step - loss: 4.0903 - mean_absolute_error: 4.2065 - root_mean_squared_error: 6.9620 - mean_absolute_percentage_error: 17.9545 - val_loss: 6.9575 - val_mean_absolute_error: 7.0952 - val_root_mean_squared_error: 12.7976 - val_mean_absolute_percentage_error: 37.7875
# Epoch 64/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.1828 - mean_absolute_error: 4.2952 - root_mean_squared_error: 6.9581 - mean_absolute_percentage_error: 18.0836 - val_loss: 6.9026 - val_mean_absolute_error: 7.0347 - val_root_mean_squared_error: 13.1177 - val_mean_absolute_percentage_error: 36.8747
# Epoch 65/100
# 103/103 [==============================] - 28s 272ms/step - loss: 3.9530 - mean_absolute_error: 4.0676 - root_mean_squared_error: 6.5718 - mean_absolute_percentage_error: 17.4034 - val_loss: 6.8101 - val_mean_absolute_error: 6.9471 - val_root_mean_squared_error: 13.2456 - val_mean_absolute_percentage_error: 39.4264
# Epoch 66/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.1259 - mean_absolute_error: 4.2466 - root_mean_squared_error: 6.8173 - mean_absolute_percentage_error: 18.4784 - val_loss: 6.9113 - val_mean_absolute_error: 7.0435 - val_root_mean_squared_error: 13.5318 - val_mean_absolute_percentage_error: 41.5100
# Epoch 67/100
# 103/103 [==============================] - 28s 275ms/step - loss: 3.8577 - mean_absolute_error: 3.9777 - root_mean_squared_error: 6.3182 - mean_absolute_percentage_error: 17.1784 - val_loss: 6.7328 - val_mean_absolute_error: 6.8721 - val_root_mean_squared_error: 12.6198 - val_mean_absolute_percentage_error: 39.2900
# Epoch 68/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.0040 - mean_absolute_error: 4.1256 - root_mean_squared_error: 6.4604 - mean_absolute_percentage_error: 17.3909 - val_loss: 7.5967 - val_mean_absolute_error: 7.7426 - val_root_mean_squared_error: 13.2497 - val_mean_absolute_percentage_error: 37.0858
# Epoch 69/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.4736 - mean_absolute_error: 4.5969 - root_mean_squared_error: 7.2950 - mean_absolute_percentage_error: 19.5918 - val_loss: 6.7442 - val_mean_absolute_error: 6.8614 - val_root_mean_squared_error: 13.5803 - val_mean_absolute_percentage_error: 41.4858
# Epoch 70/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.5581 - mean_absolute_error: 4.6833 - root_mean_squared_error: 7.6001 - mean_absolute_percentage_error: 19.7136 - val_loss: 6.5880 - val_mean_absolute_error: 6.7287 - val_root_mean_squared_error: 12.2179 - val_mean_absolute_percentage_error: 37.1586
# Epoch 71/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.3553 - mean_absolute_error: 4.4817 - root_mean_squared_error: 7.4248 - mean_absolute_percentage_error: 19.4084 - val_loss: 6.5064 - val_mean_absolute_error: 6.6258 - val_root_mean_squared_error: 12.6535 - val_mean_absolute_percentage_error: 37.6653
# Epoch 72/100
# 103/103 [==============================] - 28s 273ms/step - loss: 3.9783 - mean_absolute_error: 4.1009 - root_mean_squared_error: 6.8256 - mean_absolute_percentage_error: 18.0380 - val_loss: 7.0780 - val_mean_absolute_error: 7.2291 - val_root_mean_squared_error: 12.4398 - val_mean_absolute_percentage_error: 38.3594
# Epoch 73/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.2476 - mean_absolute_error: 4.3731 - root_mean_squared_error: 7.1777 - mean_absolute_percentage_error: 18.4447 - val_loss: 7.0654 - val_mean_absolute_error: 7.2131 - val_root_mean_squared_error: 12.9173 - val_mean_absolute_percentage_error: 38.9807
# Epoch 74/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.1229 - mean_absolute_error: 4.2459 - root_mean_squared_error: 6.8493 - mean_absolute_percentage_error: 17.6458 - val_loss: 7.1344 - val_mean_absolute_error: 7.2850 - val_root_mean_squared_error: 12.8629 - val_mean_absolute_percentage_error: 39.4675
# Epoch 75/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.1307 - mean_absolute_error: 4.2588 - root_mean_squared_error: 6.8978 - mean_absolute_percentage_error: 18.0439 - val_loss: 7.5404 - val_mean_absolute_error: 7.6953 - val_root_mean_squared_error: 12.5912 - val_mean_absolute_percentage_error: 37.3518
# Epoch 76/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.0950 - mean_absolute_error: 4.2212 - root_mean_squared_error: 6.7938 - mean_absolute_percentage_error: 17.0413 - val_loss: 6.4038 - val_mean_absolute_error: 6.5282 - val_root_mean_squared_error: 12.3252 - val_mean_absolute_percentage_error: 36.3663
# Epoch 77/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.1595 - mean_absolute_error: 4.2871 - root_mean_squared_error: 6.8881 - mean_absolute_percentage_error: 17.6585 - val_loss: 7.9399 - val_mean_absolute_error: 8.0687 - val_root_mean_squared_error: 14.4876 - val_mean_absolute_percentage_error: 42.0307
# Epoch 78/100
# 103/103 [==============================] - 28s 273ms/step - loss: 3.9880 - mean_absolute_error: 4.1172 - root_mean_squared_error: 6.4963 - mean_absolute_percentage_error: 17.3878 - val_loss: 6.6881 - val_mean_absolute_error: 6.8245 - val_root_mean_squared_error: 13.0785 - val_mean_absolute_percentage_error: 38.3930
# Epoch 79/100
# 103/103 [==============================] - 28s 271ms/step - loss: 3.9692 - mean_absolute_error: 4.0967 - root_mean_squared_error: 6.7931 - mean_absolute_percentage_error: 17.0726 - val_loss: 6.6656 - val_mean_absolute_error: 6.8201 - val_root_mean_squared_error: 12.7441 - val_mean_absolute_percentage_error: 38.8013
# Epoch 80/100
# 103/103 [==============================] - 28s 270ms/step - loss: 4.0753 - mean_absolute_error: 4.2076 - root_mean_squared_error: 6.6686 - mean_absolute_percentage_error: 17.9526 - val_loss: 6.2742 - val_mean_absolute_error: 6.4060 - val_root_mean_squared_error: 12.3236 - val_mean_absolute_percentage_error: 36.6535
# Epoch 81/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.2326 - mean_absolute_error: 4.3664 - root_mean_squared_error: 6.9177 - mean_absolute_percentage_error: 18.9672 - val_loss: 7.9601 - val_mean_absolute_error: 8.1120 - val_root_mean_squared_error: 14.1874 - val_mean_absolute_percentage_error: 41.4349
# Epoch 82/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.0584 - mean_absolute_error: 4.1881 - root_mean_squared_error: 7.0034 - mean_absolute_percentage_error: 17.7886 - val_loss: 6.6268 - val_mean_absolute_error: 6.7815 - val_root_mean_squared_error: 12.3947 - val_mean_absolute_percentage_error: 36.0581
# Epoch 83/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.1628 - mean_absolute_error: 4.2979 - root_mean_squared_error: 6.9868 - mean_absolute_percentage_error: 18.5579 - val_loss: 6.3569 - val_mean_absolute_error: 6.4969 - val_root_mean_squared_error: 12.5558 - val_mean_absolute_percentage_error: 35.9458
# Epoch 84/100
# 103/103 [==============================] - 28s 269ms/step - loss: 3.9556 - mean_absolute_error: 4.0890 - root_mean_squared_error: 6.5911 - mean_absolute_percentage_error: 17.1816 - val_loss: 6.6139 - val_mean_absolute_error: 6.7694 - val_root_mean_squared_error: 12.6265 - val_mean_absolute_percentage_error: 37.7625
# Epoch 85/100
# 103/103 [==============================] - 28s 272ms/step - loss: 3.5816 - mean_absolute_error: 3.7150 - root_mean_squared_error: 5.9633 - mean_absolute_percentage_error: 16.3205 - val_loss: 6.8034 - val_mean_absolute_error: 6.9684 - val_root_mean_squared_error: 12.4921 - val_mean_absolute_percentage_error: 38.2990
# Epoch 86/100
# 103/103 [==============================] - 28s 277ms/step - loss: 4.0024 - mean_absolute_error: 4.1389 - root_mean_squared_error: 6.8259 - mean_absolute_percentage_error: 16.8891 - val_loss: 6.9171 - val_mean_absolute_error: 7.0676 - val_root_mean_squared_error: 13.1517 - val_mean_absolute_percentage_error: 38.0241
# Epoch 87/100
# 103/103 [==============================] - 28s 275ms/step - loss: 3.6265 - mean_absolute_error: 3.7587 - root_mean_squared_error: 5.9233 - mean_absolute_percentage_error: 16.0138 - val_loss: 6.8975 - val_mean_absolute_error: 7.0475 - val_root_mean_squared_error: 12.8312 - val_mean_absolute_percentage_error: 36.1253
# Epoch 88/100
# 103/103 [==============================] - 28s 276ms/step - loss: 3.7937 - mean_absolute_error: 3.9314 - root_mean_squared_error: 6.2158 - mean_absolute_percentage_error: 16.5567 - val_loss: 6.6294 - val_mean_absolute_error: 6.7914 - val_root_mean_squared_error: 12.4212 - val_mean_absolute_percentage_error: 36.0908
# Epoch 89/100
# 103/103 [==============================] - 28s 275ms/step - loss: 3.7901 - mean_absolute_error: 3.9262 - root_mean_squared_error: 6.3325 - mean_absolute_percentage_error: 16.0001 - val_loss: 6.1533 - val_mean_absolute_error: 6.2942 - val_root_mean_squared_error: 12.3333 - val_mean_absolute_percentage_error: 37.0833
# Epoch 90/100
# 103/103 [==============================] - 28s 275ms/step - loss: 3.9908 - mean_absolute_error: 4.1290 - root_mean_squared_error: 6.7951 - mean_absolute_percentage_error: 17.3508 - val_loss: 6.1812 - val_mean_absolute_error: 6.3144 - val_root_mean_squared_error: 11.8014 - val_mean_absolute_percentage_error: 36.6666
# Epoch 91/100
# 103/103 [==============================] - 29s 279ms/step - loss: 3.6600 - mean_absolute_error: 3.7991 - root_mean_squared_error: 5.9208 - mean_absolute_percentage_error: 16.4630 - val_loss: 6.9952 - val_mean_absolute_error: 7.1662 - val_root_mean_squared_error: 12.6145 - val_mean_absolute_percentage_error: 37.2415
# Epoch 92/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.2866 - mean_absolute_error: 4.4253 - root_mean_squared_error: 7.1063 - mean_absolute_percentage_error: 17.9130 - val_loss: 8.0922 - val_mean_absolute_error: 8.2665 - val_root_mean_squared_error: 13.2195 - val_mean_absolute_percentage_error: 38.0058
# Epoch 93/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.0267 - mean_absolute_error: 4.1710 - root_mean_squared_error: 6.3984 - mean_absolute_percentage_error: 17.8924 - val_loss: 6.1101 - val_mean_absolute_error: 6.2560 - val_root_mean_squared_error: 12.2130 - val_mean_absolute_percentage_error: 35.8933
# Epoch 94/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.0700 - mean_absolute_error: 4.2140 - root_mean_squared_error: 6.7989 - mean_absolute_percentage_error: 18.1280 - val_loss: 6.3956 - val_mean_absolute_error: 6.5355 - val_root_mean_squared_error: 12.2062 - val_mean_absolute_percentage_error: 34.3600
# Epoch 95/100
# 103/103 [==============================] - 28s 272ms/step - loss: 3.9954 - mean_absolute_error: 4.1336 - root_mean_squared_error: 6.6312 - mean_absolute_percentage_error: 17.4314 - val_loss: 8.1592 - val_mean_absolute_error: 8.3264 - val_root_mean_squared_error: 14.4017 - val_mean_absolute_percentage_error: 40.9563
# Epoch 96/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.0008 - mean_absolute_error: 4.1440 - root_mean_squared_error: 6.5577 - mean_absolute_percentage_error: 17.2550 - val_loss: 6.3813 - val_mean_absolute_error: 6.5320 - val_root_mean_squared_error: 12.9015 - val_mean_absolute_percentage_error: 36.2419
# Epoch 97/100
# 103/103 [==============================] - 28s 272ms/step - loss: 3.9441 - mean_absolute_error: 4.0892 - root_mean_squared_error: 6.5627 - mean_absolute_percentage_error: 17.5516 - val_loss: 6.3107 - val_mean_absolute_error: 6.4510 - val_root_mean_squared_error: 12.5839 - val_mean_absolute_percentage_error: 38.9733
# Epoch 98/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.1077 - mean_absolute_error: 4.2519 - root_mean_squared_error: 6.8462 - mean_absolute_percentage_error: 17.8344 - val_loss: 6.2810 - val_mean_absolute_error: 6.4307 - val_root_mean_squared_error: 12.4474 - val_mean_absolute_percentage_error: 38.7865
# Epoch 99/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.0184 - mean_absolute_error: 4.1609 - root_mean_squared_error: 6.5778 - mean_absolute_percentage_error: 17.3021 - val_loss: 6.3030 - val_mean_absolute_error: 6.4546 - val_root_mean_squared_error: 12.5474 - val_mean_absolute_percentage_error: 36.7296
# Epoch 100/100
# 103/103 [==============================] - 35s 337ms/step - loss: 3.8861 - mean_absolute_error: 4.0291 - root_mean_squared_error: 6.4786 - mean_absolute_percentage_error: 17.3419 - val_loss: 6.5755 - val_mean_absolute_error: 6.7454 - val_root_mean_squared_error: 12.4679 - val_mean_absolute_percentage_error: 36.8151

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 135ms/step - loss: 6.5755 - mean_absolute_error: 6.7454 - root_mean_squared_error: 12.4679 - mean_absolute_percentage_error: 36.8151
# Model Loss: [6.575525283813477, 6.745413303375244, 12.467915534973145, 36.81507873535156]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [10.0580435]

# %%
model_scenario_name = "BiLSTM_11"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_11\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_11\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_11"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [10.0580435]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
