# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_7588\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 512
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 512

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 512)]        0           []
#
#  embedding (Embedding)          (None, 512, 256)     4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 512, 64)      73984       ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 512, 128)    66048       ['bidirectional[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 512, 64)     41216       ['bidirectional_1[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['bidirectional_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,892,001
# Trainable params: 4,891,809
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 22s 155ms/step - loss: 34.2172 - mean_absolute_error: 33.8826 - root_mean_squared_error: 46.4293 - mean_absolute_percentage_error: 95.4204 - val_loss: 35.6152 - val_mean_absolute_error: 35.3409 - val_root_mean_squared_error: 48.4998 - val_mean_absolute_percentage_error: 92.7775 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 16s 153ms/step - loss: 29.6887 - mean_absolute_error: 29.4551 - root_mean_squared_error: 42.9610 - mean_absolute_percentage_error: 73.8633 - val_loss: 29.8677 - val_mean_absolute_error: 29.6747 - val_root_mean_squared_error: 43.7721 - val_mean_absolute_percentage_error: 66.3076 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 16s 153ms/step - loss: 22.9102 - mean_absolute_error: 22.7457 - root_mean_squared_error: 36.0391 - mean_absolute_percentage_error: 58.0779 - val_loss: 22.4050 - val_mean_absolute_error: 22.2737 - val_root_mean_squared_error: 34.2752 - val_mean_absolute_percentage_error: 54.4468 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 16s 151ms/step - loss: 17.4712 - mean_absolute_error: 17.3622 - root_mean_squared_error: 27.7738 - mean_absolute_percentage_error: 57.3607 - val_loss: 16.5152 - val_mean_absolute_error: 16.4295 - val_root_mean_squared_error: 25.2754 - val_mean_absolute_percentage_error: 53.2106 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 16s 152ms/step - loss: 12.5599 - mean_absolute_error: 12.4775 - root_mean_squared_error: 20.4773 - mean_absolute_percentage_error: 50.8706 - val_loss: 14.0207 - val_mean_absolute_error: 13.9629 - val_root_mean_squared_error: 19.4539 - val_mean_absolute_percentage_error: 94.7453 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 16s 153ms/step - loss: 10.3809 - mean_absolute_error: 10.3123 - root_mean_squared_error: 16.9673 - mean_absolute_percentage_error: 48.2295 - val_loss: 10.5336 - val_mean_absolute_error: 10.4622 - val_root_mean_squared_error: 17.8577 - val_mean_absolute_percentage_error: 40.6352 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 16s 152ms/step - loss: 8.8818 - mean_absolute_error: 8.8204 - root_mean_squared_error: 14.4277 - mean_absolute_percentage_error: 40.7457 - val_loss: 9.0862 - val_mean_absolute_error: 9.0297 - val_root_mean_squared_error: 15.4719 - val_mean_absolute_percentage_error: 39.9407 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 16s 153ms/step - loss: 8.1642 - mean_absolute_error: 8.1090 - root_mean_squared_error: 13.3473 - mean_absolute_percentage_error: 38.7093 - val_loss: 8.7499 - val_mean_absolute_error: 8.7015 - val_root_mean_squared_error: 14.7873 - val_mean_absolute_percentage_error: 37.7194 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 16s 151ms/step - loss: 7.9210 - mean_absolute_error: 7.8702 - root_mean_squared_error: 12.9400 - mean_absolute_percentage_error: 36.3661 - val_loss: 8.0457 - val_mean_absolute_error: 8.0013 - val_root_mean_squared_error: 13.5083 - val_mean_absolute_percentage_error: 38.1524 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 16s 152ms/step - loss: 7.1961 - mean_absolute_error: 7.1504 - root_mean_squared_error: 12.0001 - mean_absolute_percentage_error: 32.7669 - val_loss: 8.0775 - val_mean_absolute_error: 8.0339 - val_root_mean_squared_error: 13.9952 - val_mean_absolute_percentage_error: 38.5373 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 16s 152ms/step - loss: 6.6699 - mean_absolute_error: 6.6274 - root_mean_squared_error: 10.9300 - mean_absolute_percentage_error: 30.7185 - val_loss: 7.3166 - val_mean_absolute_error: 7.2752 - val_root_mean_squared_error: 12.8959 - val_mean_absolute_percentage_error: 36.3744 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 16s 152ms/step - loss: 6.6253 - mean_absolute_error: 6.5889 - root_mean_squared_error: 10.9688 - mean_absolute_percentage_error: 30.0850 - val_loss: 7.1731 - val_mean_absolute_error: 7.1389 - val_root_mean_squared_error: 12.5080 - val_mean_absolute_percentage_error: 38.7721 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 16s 153ms/step - loss: 6.5460 - mean_absolute_error: 6.5166 - root_mean_squared_error: 10.5149 - mean_absolute_percentage_error: 30.1004 - val_loss: 7.4526 - val_mean_absolute_error: 7.4212 - val_root_mean_squared_error: 13.1656 - val_mean_absolute_percentage_error: 35.2429 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 16s 152ms/step - loss: 6.5281 - mean_absolute_error: 6.5018 - root_mean_squared_error: 10.6628 - mean_absolute_percentage_error: 28.9748 - val_loss: 7.4107 - val_mean_absolute_error: 7.3858 - val_root_mean_squared_error: 13.0319 - val_mean_absolute_percentage_error: 35.5347 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 16s 152ms/step - loss: 6.2690 - mean_absolute_error: 6.2483 - root_mean_squared_error: 10.3938 - mean_absolute_percentage_error: 28.2946 - val_loss: 8.5143 - val_mean_absolute_error: 8.4960 - val_root_mean_squared_error: 14.1100 - val_mean_absolute_percentage_error: 33.8714 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 16s 151ms/step - loss: 6.3920 - mean_absolute_error: 6.3797 - root_mean_squared_error: 10.4701 - mean_absolute_percentage_error: 28.5657 - val_loss: 7.7200 - val_mean_absolute_error: 7.6960 - val_root_mean_squared_error: 13.7433 - val_mean_absolute_percentage_error: 33.8813 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 16s 152ms/step - loss: 6.1562 - mean_absolute_error: 6.1431 - root_mean_squared_error: 9.7129 - mean_absolute_percentage_error: 27.8088 - val_loss: 7.1157 - val_mean_absolute_error: 7.1017 - val_root_mean_squared_error: 12.6155 - val_mean_absolute_percentage_error: 33.2684 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 16s 153ms/step - loss: 6.4204 - mean_absolute_error: 6.4145 - root_mean_squared_error: 10.3324 - mean_absolute_percentage_error: 31.0857 - val_loss: 6.7331 - val_mean_absolute_error: 6.7196 - val_root_mean_squared_error: 12.2087 - val_mean_absolute_percentage_error: 32.8382 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 16s 152ms/step - loss: 5.1966 - mean_absolute_error: 5.1928 - root_mean_squared_error: 8.0945 - mean_absolute_percentage_error: 25.2935 - val_loss: 6.8789 - val_mean_absolute_error: 6.8807 - val_root_mean_squared_error: 11.9715 - val_mean_absolute_percentage_error: 33.2915 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 16s 153ms/step - loss: 5.9914 - mean_absolute_error: 5.9922 - root_mean_squared_error: 9.5401 - mean_absolute_percentage_error: 27.6700 - val_loss: 6.5384 - val_mean_absolute_error: 6.5358 - val_root_mean_squared_error: 11.5854 - val_mean_absolute_percentage_error: 35.7587 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 16s 152ms/step - loss: 5.8543 - mean_absolute_error: 5.8583 - root_mean_squared_error: 9.3572 - mean_absolute_percentage_error: 26.5497 - val_loss: 6.4419 - val_mean_absolute_error: 6.4463 - val_root_mean_squared_error: 11.5638 - val_mean_absolute_percentage_error: 31.0001 - lr: 1.0000e-04
# Epoch 22/100
# 103/103 [==============================] - 16s 152ms/step - loss: 5.2198 - mean_absolute_error: 5.2247 - root_mean_squared_error: 8.3194 - mean_absolute_percentage_error: 24.6369 - val_loss: 7.7593 - val_mean_absolute_error: 7.7659 - val_root_mean_squared_error: 12.6108 - val_mean_absolute_percentage_error: 37.7081 - lr: 1.0000e-04
# Epoch 23/100
# 103/103 [==============================] - 16s 152ms/step - loss: 6.0020 - mean_absolute_error: 6.0129 - root_mean_squared_error: 9.5198 - mean_absolute_percentage_error: 26.8585 - val_loss: 6.7205 - val_mean_absolute_error: 6.7224 - val_root_mean_squared_error: 11.7041 - val_mean_absolute_percentage_error: 32.0198 - lr: 1.0000e-04
# Epoch 24/100
# 103/103 [==============================] - 16s 151ms/step - loss: 5.6589 - mean_absolute_error: 5.6729 - root_mean_squared_error: 8.9045 - mean_absolute_percentage_error: 25.2166 - val_loss: 7.1191 - val_mean_absolute_error: 7.1265 - val_root_mean_squared_error: 11.8189 - val_mean_absolute_percentage_error: 35.2676 - lr: 1.0000e-04
# Epoch 25/100
# 103/103 [==============================] - 16s 153ms/step - loss: 5.3815 - mean_absolute_error: 5.3961 - root_mean_squared_error: 8.3655 - mean_absolute_percentage_error: 25.5050 - val_loss: 6.3177 - val_mean_absolute_error: 6.3243 - val_root_mean_squared_error: 11.4103 - val_mean_absolute_percentage_error: 30.9041 - lr: 1.0000e-04
# Epoch 26/100
# 103/103 [==============================] - 16s 152ms/step - loss: 5.7154 - mean_absolute_error: 5.7381 - root_mean_squared_error: 8.9864 - mean_absolute_percentage_error: 25.0421 - val_loss: 8.4893 - val_mean_absolute_error: 8.5089 - val_root_mean_squared_error: 13.8035 - val_mean_absolute_percentage_error: 34.4266 - lr: 1.0000e-04
# Epoch 27/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.9101 - mean_absolute_error: 4.9307 - root_mean_squared_error: 7.6975 - mean_absolute_percentage_error: 22.8986 - val_loss: 5.9550 - val_mean_absolute_error: 5.9627 - val_root_mean_squared_error: 10.6794 - val_mean_absolute_percentage_error: 31.5856 - lr: 1.0000e-04
# Epoch 28/100
# 103/103 [==============================] - 15s 149ms/step - loss: 5.0188 - mean_absolute_error: 5.0412 - root_mean_squared_error: 8.0380 - mean_absolute_percentage_error: 24.1168 - val_loss: 6.8023 - val_mean_absolute_error: 6.8266 - val_root_mean_squared_error: 11.3567 - val_mean_absolute_percentage_error: 36.0789 - lr: 1.0000e-04
# Epoch 29/100
# 103/103 [==============================] - 15s 149ms/step - loss: 5.3064 - mean_absolute_error: 5.3311 - root_mean_squared_error: 8.5626 - mean_absolute_percentage_error: 23.6639 - val_loss: 6.3820 - val_mean_absolute_error: 6.4058 - val_root_mean_squared_error: 11.1182 - val_mean_absolute_percentage_error: 34.2950 - lr: 1.0000e-04
# Epoch 30/100
# 103/103 [==============================] - 15s 144ms/step - loss: 5.2147 - mean_absolute_error: 5.2476 - root_mean_squared_error: 8.0401 - mean_absolute_percentage_error: 24.0807 - val_loss: 6.0275 - val_mean_absolute_error: 6.0502 - val_root_mean_squared_error: 11.0843 - val_mean_absolute_percentage_error: 31.0342 - lr: 1.0000e-04
# Epoch 31/100
# 103/103 [==============================] - 15s 142ms/step - loss: 5.2109 - mean_absolute_error: 5.2440 - root_mean_squared_error: 8.2471 - mean_absolute_percentage_error: 23.1177 - val_loss: 8.3707 - val_mean_absolute_error: 8.4253 - val_root_mean_squared_error: 11.8695 - val_mean_absolute_percentage_error: 53.5463 - lr: 1.0000e-04
# Epoch 32/100
# 103/103 [==============================] - 15s 143ms/step - loss: 5.0908 - mean_absolute_error: 5.1274 - root_mean_squared_error: 8.0901 - mean_absolute_percentage_error: 22.6536 - val_loss: 6.2951 - val_mean_absolute_error: 6.3297 - val_root_mean_squared_error: 11.0224 - val_mean_absolute_percentage_error: 30.8433 - lr: 1.0000e-04
# Epoch 33/100
# 103/103 [==============================] - 15s 143ms/step - loss: 5.0714 - mean_absolute_error: 5.1060 - root_mean_squared_error: 8.1496 - mean_absolute_percentage_error: 22.7311 - val_loss: 6.6024 - val_mean_absolute_error: 6.6351 - val_root_mean_squared_error: 11.3869 - val_mean_absolute_percentage_error: 30.3343 - lr: 5.0000e-05
# Epoch 34/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.9459 - mean_absolute_error: 4.9825 - root_mean_squared_error: 7.9598 - mean_absolute_percentage_error: 20.9055 - val_loss: 7.0127 - val_mean_absolute_error: 7.0479 - val_root_mean_squared_error: 11.8278 - val_mean_absolute_percentage_error: 30.1839 - lr: 5.0000e-05
# Epoch 35/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.9931 - mean_absolute_error: 5.0347 - root_mean_squared_error: 7.9898 - mean_absolute_percentage_error: 22.6120 - val_loss: 5.8725 - val_mean_absolute_error: 5.9139 - val_root_mean_squared_error: 10.6270 - val_mean_absolute_percentage_error: 30.8714 - lr: 5.0000e-05
# Epoch 36/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.5721 - mean_absolute_error: 4.6112 - root_mean_squared_error: 7.2356 - mean_absolute_percentage_error: 20.3609 - val_loss: 7.2220 - val_mean_absolute_error: 7.2768 - val_root_mean_squared_error: 11.7410 - val_mean_absolute_percentage_error: 32.0798 - lr: 5.0000e-05
# Epoch 37/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.5792 - mean_absolute_error: 4.6179 - root_mean_squared_error: 7.3570 - mean_absolute_percentage_error: 21.2387 - val_loss: 6.0792 - val_mean_absolute_error: 6.1127 - val_root_mean_squared_error: 10.8700 - val_mean_absolute_percentage_error: 30.3761 - lr: 5.0000e-05
# Epoch 38/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.8772 - mean_absolute_error: 4.9180 - root_mean_squared_error: 7.9185 - mean_absolute_percentage_error: 20.8894 - val_loss: 5.7216 - val_mean_absolute_error: 5.7517 - val_root_mean_squared_error: 10.6500 - val_mean_absolute_percentage_error: 29.5951 - lr: 5.0000e-05
# Epoch 39/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.7259 - mean_absolute_error: 4.7684 - root_mean_squared_error: 7.5258 - mean_absolute_percentage_error: 21.0217 - val_loss: 5.7478 - val_mean_absolute_error: 5.7876 - val_root_mean_squared_error: 10.4759 - val_mean_absolute_percentage_error: 31.0227 - lr: 5.0000e-05
# Epoch 40/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.7012 - mean_absolute_error: 4.7452 - root_mean_squared_error: 7.4472 - mean_absolute_percentage_error: 20.2979 - val_loss: 5.7271 - val_mean_absolute_error: 5.7632 - val_root_mean_squared_error: 10.5175 - val_mean_absolute_percentage_error: 30.3564 - lr: 5.0000e-05
# Epoch 41/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.5051 - mean_absolute_error: 4.5504 - root_mean_squared_error: 7.2062 - mean_absolute_percentage_error: 20.1767 - val_loss: 6.3181 - val_mean_absolute_error: 6.3609 - val_root_mean_squared_error: 10.9016 - val_mean_absolute_percentage_error: 30.4417 - lr: 5.0000e-05
# Epoch 42/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.6733 - mean_absolute_error: 4.7180 - root_mean_squared_error: 7.4077 - mean_absolute_percentage_error: 20.2143 - val_loss: 5.8847 - val_mean_absolute_error: 5.9274 - val_root_mean_squared_error: 10.7132 - val_mean_absolute_percentage_error: 30.3408 - lr: 5.0000e-05
# Epoch 43/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.4335 - mean_absolute_error: 4.4814 - root_mean_squared_error: 6.9676 - mean_absolute_percentage_error: 20.6106 - val_loss: 5.6161 - val_mean_absolute_error: 5.6565 - val_root_mean_squared_error: 10.4729 - val_mean_absolute_percentage_error: 30.7466 - lr: 5.0000e-05
# Epoch 44/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.6811 - mean_absolute_error: 4.7313 - root_mean_squared_error: 7.5588 - mean_absolute_percentage_error: 20.0684 - val_loss: 7.3102 - val_mean_absolute_error: 7.3816 - val_root_mean_squared_error: 11.6438 - val_mean_absolute_percentage_error: 36.4749 - lr: 5.0000e-05
# Epoch 45/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.4186 - mean_absolute_error: 4.4668 - root_mean_squared_error: 6.9583 - mean_absolute_percentage_error: 19.5118 - val_loss: 5.8142 - val_mean_absolute_error: 5.8615 - val_root_mean_squared_error: 10.5425 - val_mean_absolute_percentage_error: 31.2295 - lr: 5.0000e-05
# Epoch 46/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.7245 - mean_absolute_error: 4.7777 - root_mean_squared_error: 7.4707 - mean_absolute_percentage_error: 20.2703 - val_loss: 6.6707 - val_mean_absolute_error: 6.7285 - val_root_mean_squared_error: 11.3013 - val_mean_absolute_percentage_error: 34.2669 - lr: 5.0000e-05
# Epoch 47/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.5850 - mean_absolute_error: 4.6346 - root_mean_squared_error: 7.4202 - mean_absolute_percentage_error: 19.3383 - val_loss: 5.9154 - val_mean_absolute_error: 5.9680 - val_root_mean_squared_error: 10.6001 - val_mean_absolute_percentage_error: 30.3567 - lr: 5.0000e-05
# Epoch 48/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.3224 - mean_absolute_error: 4.3774 - root_mean_squared_error: 6.8040 - mean_absolute_percentage_error: 19.3459 - val_loss: 6.1923 - val_mean_absolute_error: 6.2534 - val_root_mean_squared_error: 10.9070 - val_mean_absolute_percentage_error: 30.1347 - lr: 5.0000e-05
# Epoch 49/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.4186 - mean_absolute_error: 4.4743 - root_mean_squared_error: 6.9718 - mean_absolute_percentage_error: 19.6194 - val_loss: 5.8877 - val_mean_absolute_error: 5.9392 - val_root_mean_squared_error: 10.6057 - val_mean_absolute_percentage_error: 31.6889 - lr: 2.5000e-05
# Epoch 50/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.2946 - mean_absolute_error: 4.3484 - root_mean_squared_error: 6.7832 - mean_absolute_percentage_error: 18.2285 - val_loss: 5.5189 - val_mean_absolute_error: 5.5651 - val_root_mean_squared_error: 10.3732 - val_mean_absolute_percentage_error: 30.5430 - lr: 2.5000e-05
# Epoch 51/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.3343 - mean_absolute_error: 4.3868 - root_mean_squared_error: 7.0384 - mean_absolute_percentage_error: 19.1110 - val_loss: 5.5060 - val_mean_absolute_error: 5.5500 - val_root_mean_squared_error: 10.3708 - val_mean_absolute_percentage_error: 30.4613 - lr: 2.5000e-05
# Epoch 52/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.2362 - mean_absolute_error: 4.2921 - root_mean_squared_error: 6.7284 - mean_absolute_percentage_error: 19.3040 - val_loss: 5.8404 - val_mean_absolute_error: 5.8890 - val_root_mean_squared_error: 10.6315 - val_mean_absolute_percentage_error: 31.8632 - lr: 2.5000e-05
# Epoch 53/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.9518 - mean_absolute_error: 4.0057 - root_mean_squared_error: 6.2787 - mean_absolute_percentage_error: 18.1473 - val_loss: 5.7409 - val_mean_absolute_error: 5.7957 - val_root_mean_squared_error: 10.5868 - val_mean_absolute_percentage_error: 30.0365 - lr: 2.5000e-05
# Epoch 54/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.1834 - mean_absolute_error: 4.2428 - root_mean_squared_error: 6.5747 - mean_absolute_percentage_error: 18.4910 - val_loss: 5.6078 - val_mean_absolute_error: 5.6681 - val_root_mean_squared_error: 10.4482 - val_mean_absolute_percentage_error: 31.1567 - lr: 2.5000e-05
# Epoch 55/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.2475 - mean_absolute_error: 4.3066 - root_mean_squared_error: 6.6730 - mean_absolute_percentage_error: 18.1064 - val_loss: 6.0940 - val_mean_absolute_error: 6.1610 - val_root_mean_squared_error: 10.7384 - val_mean_absolute_percentage_error: 32.6164 - lr: 2.5000e-05
# Epoch 56/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.0617 - mean_absolute_error: 4.1159 - root_mean_squared_error: 6.4417 - mean_absolute_percentage_error: 17.7514 - val_loss: 5.7604 - val_mean_absolute_error: 5.8230 - val_root_mean_squared_error: 10.5072 - val_mean_absolute_percentage_error: 31.3340 - lr: 2.5000e-05
# Epoch 57/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.1332 - mean_absolute_error: 4.1895 - root_mean_squared_error: 6.4529 - mean_absolute_percentage_error: 18.7317 - val_loss: 5.4806 - val_mean_absolute_error: 5.5360 - val_root_mean_squared_error: 10.3286 - val_mean_absolute_percentage_error: 30.2071 - lr: 1.2500e-05
# Epoch 58/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.3871 - mean_absolute_error: 4.4471 - root_mean_squared_error: 6.8893 - mean_absolute_percentage_error: 20.1467 - val_loss: 5.6757 - val_mean_absolute_error: 5.7376 - val_root_mean_squared_error: 10.3925 - val_mean_absolute_percentage_error: 31.0900 - lr: 1.2500e-05
# Epoch 59/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.2509 - mean_absolute_error: 4.3063 - root_mean_squared_error: 6.9526 - mean_absolute_percentage_error: 17.7244 - val_loss: 5.4982 - val_mean_absolute_error: 5.5534 - val_root_mean_squared_error: 10.3688 - val_mean_absolute_percentage_error: 30.0698 - lr: 1.2500e-05
# Epoch 60/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.1648 - mean_absolute_error: 4.2242 - root_mean_squared_error: 6.5742 - mean_absolute_percentage_error: 17.4474 - val_loss: 5.4725 - val_mean_absolute_error: 5.5294 - val_root_mean_squared_error: 10.3581 - val_mean_absolute_percentage_error: 30.2130 - lr: 1.2500e-05
# Epoch 61/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.3092 - mean_absolute_error: 4.3671 - root_mean_squared_error: 6.8397 - mean_absolute_percentage_error: 18.7845 - val_loss: 5.5960 - val_mean_absolute_error: 5.6614 - val_root_mean_squared_error: 10.3930 - val_mean_absolute_percentage_error: 31.3151 - lr: 1.2500e-05
# Epoch 62/100
# 103/103 [==============================] - 15s 144ms/step - loss: 3.8625 - mean_absolute_error: 3.9218 - root_mean_squared_error: 6.0716 - mean_absolute_percentage_error: 17.4615 - val_loss: 5.5431 - val_mean_absolute_error: 5.6017 - val_root_mean_squared_error: 10.2864 - val_mean_absolute_percentage_error: 31.0610 - lr: 1.2500e-05
# Epoch 63/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.0118 - mean_absolute_error: 4.0716 - root_mean_squared_error: 6.4294 - mean_absolute_percentage_error: 17.7021 - val_loss: 5.5067 - val_mean_absolute_error: 5.5658 - val_root_mean_squared_error: 10.2943 - val_mean_absolute_percentage_error: 31.0989 - lr: 1.2500e-05
# Epoch 64/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.1161 - mean_absolute_error: 4.1708 - root_mean_squared_error: 6.5509 - mean_absolute_percentage_error: 17.5220 - val_loss: 5.5030 - val_mean_absolute_error: 5.5614 - val_root_mean_squared_error: 10.3188 - val_mean_absolute_percentage_error: 30.0691 - lr: 1.2500e-05
# Epoch 65/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.8872 - mean_absolute_error: 3.9459 - root_mean_squared_error: 6.1683 - mean_absolute_percentage_error: 17.4421 - val_loss: 5.4964 - val_mean_absolute_error: 5.5568 - val_root_mean_squared_error: 10.2640 - val_mean_absolute_percentage_error: 30.9931 - lr: 1.2500e-05
# Epoch 66/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.0324 - mean_absolute_error: 4.0929 - root_mean_squared_error: 6.3819 - mean_absolute_percentage_error: 17.5772 - val_loss: 5.3937 - val_mean_absolute_error: 5.4448 - val_root_mean_squared_error: 10.2504 - val_mean_absolute_percentage_error: 30.4682 - lr: 6.2500e-06
# Epoch 67/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.3358 - mean_absolute_error: 4.3991 - root_mean_squared_error: 7.0426 - mean_absolute_percentage_error: 17.9432 - val_loss: 5.3912 - val_mean_absolute_error: 5.4450 - val_root_mean_squared_error: 10.2248 - val_mean_absolute_percentage_error: 30.4655 - lr: 6.2500e-06
# Epoch 68/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.8614 - mean_absolute_error: 3.9212 - root_mean_squared_error: 6.0593 - mean_absolute_percentage_error: 17.0646 - val_loss: 5.3451 - val_mean_absolute_error: 5.3967 - val_root_mean_squared_error: 10.2021 - val_mean_absolute_percentage_error: 30.1967 - lr: 6.2500e-06
# Epoch 69/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.1946 - mean_absolute_error: 4.2576 - root_mean_squared_error: 6.6105 - mean_absolute_percentage_error: 18.8116 - val_loss: 5.3710 - val_mean_absolute_error: 5.4236 - val_root_mean_squared_error: 10.2167 - val_mean_absolute_percentage_error: 30.3129 - lr: 6.2500e-06
# Epoch 70/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.0309 - mean_absolute_error: 4.0915 - root_mean_squared_error: 6.4722 - mean_absolute_percentage_error: 17.0738 - val_loss: 5.4009 - val_mean_absolute_error: 5.4562 - val_root_mean_squared_error: 10.2544 - val_mean_absolute_percentage_error: 30.4894 - lr: 6.2500e-06
# Epoch 71/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.1169 - mean_absolute_error: 4.1774 - root_mean_squared_error: 6.5436 - mean_absolute_percentage_error: 17.6719 - val_loss: 5.3708 - val_mean_absolute_error: 5.4216 - val_root_mean_squared_error: 10.2337 - val_mean_absolute_percentage_error: 30.1215 - lr: 6.2500e-06
# Epoch 72/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.9137 - mean_absolute_error: 3.9709 - root_mean_squared_error: 6.2738 - mean_absolute_percentage_error: 17.2004 - val_loss: 5.3582 - val_mean_absolute_error: 5.4089 - val_root_mean_squared_error: 10.2259 - val_mean_absolute_percentage_error: 30.2331 - lr: 6.2500e-06
# Epoch 73/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8982 - mean_absolute_error: 3.9582 - root_mean_squared_error: 6.2143 - mean_absolute_percentage_error: 16.5047 - val_loss: 5.4092 - val_mean_absolute_error: 5.4679 - val_root_mean_squared_error: 10.2467 - val_mean_absolute_percentage_error: 30.6016 - lr: 6.2500e-06
# Epoch 74/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8218 - mean_absolute_error: 3.8791 - root_mean_squared_error: 6.3298 - mean_absolute_percentage_error: 17.1169 - val_loss: 5.3771 - val_mean_absolute_error: 5.4304 - val_root_mean_squared_error: 10.2275 - val_mean_absolute_percentage_error: 30.2463 - lr: 3.1250e-06
# Epoch 75/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.3843 - mean_absolute_error: 4.4471 - root_mean_squared_error: 7.1597 - mean_absolute_percentage_error: 17.7834 - val_loss: 5.3677 - val_mean_absolute_error: 5.4197 - val_root_mean_squared_error: 10.2290 - val_mean_absolute_percentage_error: 30.3030 - lr: 3.1250e-06
# Epoch 76/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.1479 - mean_absolute_error: 4.2068 - root_mean_squared_error: 6.6556 - mean_absolute_percentage_error: 17.3219 - val_loss: 5.3658 - val_mean_absolute_error: 5.4173 - val_root_mean_squared_error: 10.2295 - val_mean_absolute_percentage_error: 30.3729 - lr: 3.1250e-06
# Epoch 77/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.3958 - mean_absolute_error: 4.4580 - root_mean_squared_error: 7.0853 - mean_absolute_percentage_error: 18.1362 - val_loss: 5.3562 - val_mean_absolute_error: 5.4086 - val_root_mean_squared_error: 10.2413 - val_mean_absolute_percentage_error: 30.3564 - lr: 3.1250e-06
# Epoch 78/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.1708 - mean_absolute_error: 4.2307 - root_mean_squared_error: 6.7096 - mean_absolute_percentage_error: 17.6152 - val_loss: 5.3883 - val_mean_absolute_error: 5.4466 - val_root_mean_squared_error: 10.2450 - val_mean_absolute_percentage_error: 30.5418 - lr: 3.1250e-06
# Epoch 79/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8332 - mean_absolute_error: 3.8923 - root_mean_squared_error: 6.0747 - mean_absolute_percentage_error: 17.0341 - val_loss: 5.3671 - val_mean_absolute_error: 5.4199 - val_root_mean_squared_error: 10.2489 - val_mean_absolute_percentage_error: 30.3534 - lr: 1.5625e-06
# Epoch 80/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.7232 - mean_absolute_error: 3.7823 - root_mean_squared_error: 5.8809 - mean_absolute_percentage_error: 16.2345 - val_loss: 5.3790 - val_mean_absolute_error: 5.4337 - val_root_mean_squared_error: 10.2531 - val_mean_absolute_percentage_error: 30.4137 - lr: 1.5625e-06
# Epoch 81/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8898 - mean_absolute_error: 3.9498 - root_mean_squared_error: 6.1255 - mean_absolute_percentage_error: 17.3601 - val_loss: 5.3614 - val_mean_absolute_error: 5.4145 - val_root_mean_squared_error: 10.2449 - val_mean_absolute_percentage_error: 30.3741 - lr: 1.5625e-06
# Epoch 82/100
# 103/103 [==============================] - 15s 141ms/step - loss: 3.8635 - mean_absolute_error: 3.9219 - root_mean_squared_error: 6.1406 - mean_absolute_percentage_error: 17.2396 - val_loss: 5.3578 - val_mean_absolute_error: 5.4105 - val_root_mean_squared_error: 10.2489 - val_mean_absolute_percentage_error: 30.2351 - lr: 1.5625e-06
# Epoch 83/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.1154 - mean_absolute_error: 4.1787 - root_mean_squared_error: 6.6901 - mean_absolute_percentage_error: 17.8523 - val_loss: 5.3725 - val_mean_absolute_error: 5.4297 - val_root_mean_squared_error: 10.2472 - val_mean_absolute_percentage_error: 30.2939 - lr: 1.5625e-06
# Epoch 84/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.9657 - mean_absolute_error: 4.0231 - root_mean_squared_error: 6.3653 - mean_absolute_percentage_error: 17.4134 - val_loss: 5.3705 - val_mean_absolute_error: 5.4266 - val_root_mean_squared_error: 10.2476 - val_mean_absolute_percentage_error: 30.3992 - lr: 7.8125e-07
# Epoch 85/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.9056 - mean_absolute_error: 3.9641 - root_mean_squared_error: 6.1279 - mean_absolute_percentage_error: 17.1319 - val_loss: 5.3513 - val_mean_absolute_error: 5.4043 - val_root_mean_squared_error: 10.2411 - val_mean_absolute_percentage_error: 30.2703 - lr: 7.8125e-07
# Epoch 86/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.0026 - mean_absolute_error: 4.0643 - root_mean_squared_error: 6.3704 - mean_absolute_percentage_error: 17.1071 - val_loss: 5.3478 - val_mean_absolute_error: 5.4000 - val_root_mean_squared_error: 10.2396 - val_mean_absolute_percentage_error: 30.3293 - lr: 7.8125e-07
# Epoch 87/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.7963 - mean_absolute_error: 3.8541 - root_mean_squared_error: 6.0708 - mean_absolute_percentage_error: 16.9182 - val_loss: 5.3512 - val_mean_absolute_error: 5.4047 - val_root_mean_squared_error: 10.2379 - val_mean_absolute_percentage_error: 30.3676 - lr: 7.8125e-07
# Epoch 88/100
# 103/103 [==============================] - 15s 144ms/step - loss: 3.8457 - mean_absolute_error: 3.9093 - root_mean_squared_error: 6.2134 - mean_absolute_percentage_error: 16.3915 - val_loss: 5.3430 - val_mean_absolute_error: 5.3950 - val_root_mean_squared_error: 10.2346 - val_mean_absolute_percentage_error: 30.2164 - lr: 7.8125e-07
# Epoch 89/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.0401 - mean_absolute_error: 4.0985 - root_mean_squared_error: 6.5218 - mean_absolute_percentage_error: 16.1946 - val_loss: 5.3512 - val_mean_absolute_error: 5.4040 - val_root_mean_squared_error: 10.2409 - val_mean_absolute_percentage_error: 30.3102 - lr: 7.8125e-07
# Epoch 90/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.0916 - mean_absolute_error: 4.1544 - root_mean_squared_error: 6.5912 - mean_absolute_percentage_error: 17.6268 - val_loss: 5.3409 - val_mean_absolute_error: 5.3924 - val_root_mean_squared_error: 10.2373 - val_mean_absolute_percentage_error: 30.2950 - lr: 7.8125e-07
# Epoch 91/100
# 103/103 [==============================] - 15s 141ms/step - loss: 3.7998 - mean_absolute_error: 3.8559 - root_mean_squared_error: 6.1158 - mean_absolute_percentage_error: 16.7470 - val_loss: 5.3456 - val_mean_absolute_error: 5.3980 - val_root_mean_squared_error: 10.2402 - val_mean_absolute_percentage_error: 30.2718 - lr: 7.8125e-07
# Epoch 92/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8582 - mean_absolute_error: 3.9191 - root_mean_squared_error: 5.9679 - mean_absolute_percentage_error: 16.4913 - val_loss: 5.3486 - val_mean_absolute_error: 5.4019 - val_root_mean_squared_error: 10.2378 - val_mean_absolute_percentage_error: 30.3195 - lr: 7.8125e-07
# Epoch 93/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.1968 - mean_absolute_error: 4.2582 - root_mean_squared_error: 6.8347 - mean_absolute_percentage_error: 17.6176 - val_loss: 5.3458 - val_mean_absolute_error: 5.3987 - val_root_mean_squared_error: 10.2367 - val_mean_absolute_percentage_error: 30.3302 - lr: 7.8125e-07
# Epoch 94/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.0209 - mean_absolute_error: 4.0811 - root_mean_squared_error: 6.5462 - mean_absolute_percentage_error: 17.1206 - val_loss: 5.3427 - val_mean_absolute_error: 5.3947 - val_root_mean_squared_error: 10.2379 - val_mean_absolute_percentage_error: 30.2251 - lr: 7.8125e-07
# Epoch 95/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.7630 - mean_absolute_error: 3.8203 - root_mean_squared_error: 6.1112 - mean_absolute_percentage_error: 16.2116 - val_loss: 5.3540 - val_mean_absolute_error: 5.4078 - val_root_mean_squared_error: 10.2326 - val_mean_absolute_percentage_error: 30.3593 - lr: 7.8125e-07
# Epoch 96/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.0490 - mean_absolute_error: 4.1096 - root_mean_squared_error: 6.4923 - mean_absolute_percentage_error: 17.3118 - val_loss: 5.3548 - val_mean_absolute_error: 5.4088 - val_root_mean_squared_error: 10.2356 - val_mean_absolute_percentage_error: 30.3724 - lr: 3.9062e-07
# Epoch 97/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.2071 - mean_absolute_error: 4.2685 - root_mean_squared_error: 6.7568 - mean_absolute_percentage_error: 17.5614 - val_loss: 5.3446 - val_mean_absolute_error: 5.3961 - val_root_mean_squared_error: 10.2332 - val_mean_absolute_percentage_error: 30.2858 - lr: 3.9062e-07
# Epoch 98/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.0385 - mean_absolute_error: 4.1045 - root_mean_squared_error: 6.2689 - mean_absolute_percentage_error: 17.4360 - val_loss: 5.3502 - val_mean_absolute_error: 5.4040 - val_root_mean_squared_error: 10.2313 - val_mean_absolute_percentage_error: 30.3832 - lr: 3.9062e-07
# Epoch 99/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.2008 - mean_absolute_error: 4.2606 - root_mean_squared_error: 6.7128 - mean_absolute_percentage_error: 17.5301 - val_loss: 5.3494 - val_mean_absolute_error: 5.4026 - val_root_mean_squared_error: 10.2309 - val_mean_absolute_percentage_error: 30.3591 - lr: 3.9062e-07
# Epoch 100/100
# 103/103 [==============================] - 15s 141ms/step - loss: 3.7978 - mean_absolute_error: 3.8561 - root_mean_squared_error: 6.0805 - mean_absolute_percentage_error: 16.7063 - val_loss: 5.3407 - val_mean_absolute_error: 5.3932 - val_root_mean_squared_error: 10.2270 - val_mean_absolute_percentage_error: 30.2819 - lr: 3.9062e-07

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 61ms/step - loss: 5.3407 - mean_absolute_error: 5.3932 - root_mean_squared_error: 10.2270 - mean_absolute_percentage_error: 30.2819
# Model Loss: [5.340669631958008, 5.393243789672852, 10.226999282836914, 30.281944274902344]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [9.712888]

# %%
model_scenario_name = "BiLSTM_12_512_Compare"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_12_512_Compare\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_12_512_Compare\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_12_512_Compare"
max_len = 512

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 512
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 251ms/step
# Predicted Putusan: [9.712888]
