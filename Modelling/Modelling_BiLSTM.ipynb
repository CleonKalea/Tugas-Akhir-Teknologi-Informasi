# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_5392\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14898

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=256 
)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output = tf.keras.layers.BatchNormalization()(lstm_output)

lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_2 = tf.keras.layers.BatchNormalization()(lstm_output_2)

lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
lstm_output_3 = tf.keras.layers.BatchNormalization()(lstm_output_3)

pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical = tf.keras.layers.BatchNormalization()(numerical_input)
numerical_dense = tf.keras.layers.Dense(32, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3813888     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1024, 64)    256         ['bidirectional[0][0]']
#  alization)
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['batch_normalization[0][0]']
#  )
#
#  batch_normalization_1 (BatchNo  (None, 1024, 128)   512         ['bidirectional_1[0][0]']
#  rmalization)
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['batch_normalization_1[0][0]']
#  )
#
#  batch_normalization_3 (BatchNo  (None, 5)           20          ['numerical_input[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 1024, 64)    256         ['bidirectional_2[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 32)           192         ['batch_normalization_3[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['batch_normalization_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96)          384         ['concatenate[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,017,525
# Trainable params: 4,016,811
# Non-trainable params: 714
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 35s 282ms/step - loss: 33.6922 - mean_absolute_error: 33.3108 - root_mean_squared_error: 45.6504 - mean_absolute_percentage_error: 94.0166 - val_loss: 35.9907 - val_mean_absolute_error: 35.6254 - val_root_mean_squared_error: 48.7928 - val_mean_absolute_percentage_error: 93.7478 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 28s 271ms/step - loss: 30.1131 - mean_absolute_error: 29.7581 - root_mean_squared_error: 41.9490 - mean_absolute_percentage_error: 79.6235 - val_loss: 33.9857 - val_mean_absolute_error: 33.6458 - val_root_mean_squared_error: 47.1980 - val_mean_absolute_percentage_error: 83.1355 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 29s 277ms/step - loss: 23.2111 - mean_absolute_error: 22.8787 - root_mean_squared_error: 34.0239 - mean_absolute_percentage_error: 62.6269 - val_loss: 29.8987 - val_mean_absolute_error: 29.5806 - val_root_mean_squared_error: 42.5764 - val_mean_absolute_percentage_error: 73.7912 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 33s 322ms/step - loss: 15.3083 - mean_absolute_error: 14.9910 - root_mean_squared_error: 23.0907 - mean_absolute_percentage_error: 60.1020 - val_loss: 22.3656 - val_mean_absolute_error: 22.0606 - val_root_mean_squared_error: 31.8303 - val_mean_absolute_percentage_error: 66.6361 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 30s 295ms/step - loss: 11.3940 - mean_absolute_error: 11.0865 - root_mean_squared_error: 17.2761 - mean_absolute_percentage_error: 56.4497 - val_loss: 16.9372 - val_mean_absolute_error: 16.6450 - val_root_mean_squared_error: 23.2655 - val_mean_absolute_percentage_error: 71.1398 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 30s 295ms/step - loss: 10.3368 - mean_absolute_error: 10.0368 - root_mean_squared_error: 15.8560 - mean_absolute_percentage_error: 48.8572 - val_loss: 13.5180 - val_mean_absolute_error: 13.2289 - val_root_mean_squared_error: 20.2460 - val_mean_absolute_percentage_error: 50.1562 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 30s 295ms/step - loss: 9.4584 - mean_absolute_error: 9.1611 - root_mean_squared_error: 14.6616 - mean_absolute_percentage_error: 43.9764 - val_loss: 12.0824 - val_mean_absolute_error: 11.8000 - val_root_mean_squared_error: 17.8278 - val_mean_absolute_percentage_error: 51.9152 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 30s 295ms/step - loss: 8.9157 - mean_absolute_error: 8.6227 - root_mean_squared_error: 13.9355 - mean_absolute_percentage_error: 40.1964 - val_loss: 10.3888 - val_mean_absolute_error: 10.0986 - val_root_mean_squared_error: 16.8285 - val_mean_absolute_percentage_error: 46.6427 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 30s 294ms/step - loss: 8.6624 - mean_absolute_error: 8.3721 - root_mean_squared_error: 13.6260 - mean_absolute_percentage_error: 39.0146 - val_loss: 11.3782 - val_mean_absolute_error: 11.1020 - val_root_mean_squared_error: 16.3306 - val_mean_absolute_percentage_error: 51.4862 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 30s 295ms/step - loss: 7.8514 - mean_absolute_error: 7.5669 - root_mean_squared_error: 12.2288 - mean_absolute_percentage_error: 35.2956 - val_loss: 11.0153 - val_mean_absolute_error: 10.7457 - val_root_mean_squared_error: 15.6389 - val_mean_absolute_percentage_error: 78.4767 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 31s 297ms/step - loss: 7.8648 - mean_absolute_error: 7.5826 - root_mean_squared_error: 12.2232 - mean_absolute_percentage_error: 34.4281 - val_loss: 8.7617 - val_mean_absolute_error: 8.4809 - val_root_mean_squared_error: 14.1105 - val_mean_absolute_percentage_error: 57.1882 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 31s 298ms/step - loss: 7.3608 - mean_absolute_error: 7.0796 - root_mean_squared_error: 11.5491 - mean_absolute_percentage_error: 31.4840 - val_loss: 11.5924 - val_mean_absolute_error: 11.3295 - val_root_mean_squared_error: 17.4167 - val_mean_absolute_percentage_error: 51.3840 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 30s 294ms/step - loss: 6.9576 - mean_absolute_error: 6.6799 - root_mean_squared_error: 10.6445 - mean_absolute_percentage_error: 31.1700 - val_loss: 9.6756 - val_mean_absolute_error: 9.4115 - val_root_mean_squared_error: 14.9088 - val_mean_absolute_percentage_error: 51.4822 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 30s 294ms/step - loss: 7.2253 - mean_absolute_error: 6.9505 - root_mean_squared_error: 10.9540 - mean_absolute_percentage_error: 32.3964 - val_loss: 10.6960 - val_mean_absolute_error: 10.4343 - val_root_mean_squared_error: 16.1878 - val_mean_absolute_percentage_error: 45.7470 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 30s 296ms/step - loss: 6.4182 - mean_absolute_error: 6.1435 - root_mean_squared_error: 9.8900 - mean_absolute_percentage_error: 27.3942 - val_loss: 16.9298 - val_mean_absolute_error: 16.6768 - val_root_mean_squared_error: 24.1831 - val_mean_absolute_percentage_error: 60.9166 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 30s 295ms/step - loss: 6.4096 - mean_absolute_error: 6.1336 - root_mean_squared_error: 9.8742 - mean_absolute_percentage_error: 27.1824 - val_loss: 23.6066 - val_mean_absolute_error: 23.3574 - val_root_mean_squared_error: 32.0109 - val_mean_absolute_percentage_error: 94.0138 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 30s 294ms/step - loss: 6.2847 - mean_absolute_error: 6.0145 - root_mean_squared_error: 9.7761 - mean_absolute_percentage_error: 26.3357 - val_loss: 8.1243 - val_mean_absolute_error: 7.8514 - val_root_mean_squared_error: 13.5205 - val_mean_absolute_percentage_error: 35.2039 - lr: 5.0000e-05
# Epoch 18/100
# 103/103 [==============================] - 30s 295ms/step - loss: 5.8818 - mean_absolute_error: 5.6092 - root_mean_squared_error: 9.0546 - mean_absolute_percentage_error: 24.9492 - val_loss: 11.2450 - val_mean_absolute_error: 10.9941 - val_root_mean_squared_error: 14.9596 - val_mean_absolute_percentage_error: 85.6500 - lr: 5.0000e-05
# Epoch 19/100
# 103/103 [==============================] - 31s 297ms/step - loss: 6.0128 - mean_absolute_error: 5.7433 - root_mean_squared_error: 9.1195 - mean_absolute_percentage_error: 25.6966 - val_loss: 13.0344 - val_mean_absolute_error: 12.7882 - val_root_mean_squared_error: 18.8907 - val_mean_absolute_percentage_error: 50.6381 - lr: 5.0000e-05
# Epoch 20/100
# 103/103 [==============================] - 30s 296ms/step - loss: 5.6394 - mean_absolute_error: 5.3684 - root_mean_squared_error: 8.6254 - mean_absolute_percentage_error: 24.4061 - val_loss: 9.5093 - val_mean_absolute_error: 9.2459 - val_root_mean_squared_error: 15.1570 - val_mean_absolute_percentage_error: 34.7284 - lr: 5.0000e-05
# Epoch 21/100
# 103/103 [==============================] - 30s 296ms/step - loss: 5.6700 - mean_absolute_error: 5.4014 - root_mean_squared_error: 8.5705 - mean_absolute_percentage_error: 23.9380 - val_loss: 9.9994 - val_mean_absolute_error: 9.7472 - val_root_mean_squared_error: 13.8946 - val_mean_absolute_percentage_error: 66.1649 - lr: 5.0000e-05
# Epoch 22/100
# 103/103 [==============================] - 30s 293ms/step - loss: 5.4458 - mean_absolute_error: 5.1780 - root_mean_squared_error: 8.1948 - mean_absolute_percentage_error: 22.6004 - val_loss: 7.5510 - val_mean_absolute_error: 7.2916 - val_root_mean_squared_error: 12.3188 - val_mean_absolute_percentage_error: 40.1589 - lr: 5.0000e-05
# Epoch 23/100
# 103/103 [==============================] - 31s 297ms/step - loss: 5.1726 - mean_absolute_error: 4.9035 - root_mean_squared_error: 7.8458 - mean_absolute_percentage_error: 22.5075 - val_loss: 9.0406 - val_mean_absolute_error: 8.7651 - val_root_mean_squared_error: 14.3206 - val_mean_absolute_percentage_error: 33.2319 - lr: 5.0000e-05
# Epoch 24/100
# 103/103 [==============================] - 31s 302ms/step - loss: 5.7429 - mean_absolute_error: 5.4784 - root_mean_squared_error: 8.6746 - mean_absolute_percentage_error: 24.5721 - val_loss: 12.7298 - val_mean_absolute_error: 12.4838 - val_root_mean_squared_error: 16.4776 - val_mean_absolute_percentage_error: 77.1129 - lr: 5.0000e-05
# Epoch 25/100
# 103/103 [==============================] - 31s 299ms/step - loss: 5.1856 - mean_absolute_error: 4.9207 - root_mean_squared_error: 7.9576 - mean_absolute_percentage_error: 21.9486 - val_loss: 6.9994 - val_mean_absolute_error: 6.7270 - val_root_mean_squared_error: 11.6664 - val_mean_absolute_percentage_error: 32.8568 - lr: 5.0000e-05
# Epoch 26/100
# 103/103 [==============================] - 31s 298ms/step - loss: 5.0513 - mean_absolute_error: 4.7851 - root_mean_squared_error: 7.6793 - mean_absolute_percentage_error: 22.2106 - val_loss: 14.5087 - val_mean_absolute_error: 14.2712 - val_root_mean_squared_error: 20.2643 - val_mean_absolute_percentage_error: 58.3523 - lr: 5.0000e-05
# Epoch 27/100
# 103/103 [==============================] - 31s 299ms/step - loss: 4.9414 - mean_absolute_error: 4.6776 - root_mean_squared_error: 7.2697 - mean_absolute_percentage_error: 21.7637 - val_loss: 11.5853 - val_mean_absolute_error: 11.3414 - val_root_mean_squared_error: 17.0866 - val_mean_absolute_percentage_error: 45.3514 - lr: 5.0000e-05
# Epoch 28/100
# 103/103 [==============================] - 31s 298ms/step - loss: 5.0523 - mean_absolute_error: 4.7878 - root_mean_squared_error: 7.7895 - mean_absolute_percentage_error: 21.3091 - val_loss: 11.8147 - val_mean_absolute_error: 11.5758 - val_root_mean_squared_error: 15.7938 - val_mean_absolute_percentage_error: 64.4849 - lr: 5.0000e-05
# Epoch 29/100
# 103/103 [==============================] - 31s 297ms/step - loss: 5.2170 - mean_absolute_error: 4.9526 - root_mean_squared_error: 8.1623 - mean_absolute_percentage_error: 21.6526 - val_loss: 10.7489 - val_mean_absolute_error: 10.5145 - val_root_mean_squared_error: 15.4312 - val_mean_absolute_percentage_error: 47.6827 - lr: 5.0000e-05
# Epoch 30/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.9012 - mean_absolute_error: 4.6394 - root_mean_squared_error: 7.3353 - mean_absolute_percentage_error: 20.7692 - val_loss: 8.1498 - val_mean_absolute_error: 7.9028 - val_root_mean_squared_error: 12.8514 - val_mean_absolute_percentage_error: 32.4380 - lr: 5.0000e-05
# Epoch 31/100
# 103/103 [==============================] - 31s 299ms/step - loss: 4.8622 - mean_absolute_error: 4.6003 - root_mean_squared_error: 7.3644 - mean_absolute_percentage_error: 20.6958 - val_loss: 6.9756 - val_mean_absolute_error: 6.7170 - val_root_mean_squared_error: 11.4961 - val_mean_absolute_percentage_error: 38.2012 - lr: 2.5000e-05
# Epoch 32/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.8087 - mean_absolute_error: 4.5431 - root_mean_squared_error: 7.1423 - mean_absolute_percentage_error: 20.3620 - val_loss: 7.0370 - val_mean_absolute_error: 6.7865 - val_root_mean_squared_error: 11.4403 - val_mean_absolute_percentage_error: 34.5755 - lr: 2.5000e-05
# Epoch 33/100
# 103/103 [==============================] - 31s 299ms/step - loss: 4.7119 - mean_absolute_error: 4.4492 - root_mean_squared_error: 7.0998 - mean_absolute_percentage_error: 19.9538 - val_loss: 6.8946 - val_mean_absolute_error: 6.6520 - val_root_mean_squared_error: 11.2330 - val_mean_absolute_percentage_error: 34.7695 - lr: 2.5000e-05
# Epoch 34/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.6684 - mean_absolute_error: 4.4072 - root_mean_squared_error: 6.8574 - mean_absolute_percentage_error: 19.5048 - val_loss: 8.8817 - val_mean_absolute_error: 8.6394 - val_root_mean_squared_error: 12.7532 - val_mean_absolute_percentage_error: 50.7473 - lr: 2.5000e-05
# Epoch 35/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.5857 - mean_absolute_error: 4.3260 - root_mean_squared_error: 6.5704 - mean_absolute_percentage_error: 20.2644 - val_loss: 6.2430 - val_mean_absolute_error: 5.9810 - val_root_mean_squared_error: 10.9906 - val_mean_absolute_percentage_error: 32.7615 - lr: 2.5000e-05
# Epoch 36/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.5847 - mean_absolute_error: 4.3229 - root_mean_squared_error: 6.8921 - mean_absolute_percentage_error: 19.1590 - val_loss: 9.5697 - val_mean_absolute_error: 9.3099 - val_root_mean_squared_error: 14.8629 - val_mean_absolute_percentage_error: 34.6050 - lr: 2.5000e-05
# Epoch 37/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.4992 - mean_absolute_error: 4.2419 - root_mean_squared_error: 6.7581 - mean_absolute_percentage_error: 19.4820 - val_loss: 7.8516 - val_mean_absolute_error: 7.5803 - val_root_mean_squared_error: 12.6173 - val_mean_absolute_percentage_error: 31.9653 - lr: 2.5000e-05
# Epoch 38/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.6167 - mean_absolute_error: 4.3578 - root_mean_squared_error: 6.9734 - mean_absolute_percentage_error: 19.5780 - val_loss: 6.7739 - val_mean_absolute_error: 6.5316 - val_root_mean_squared_error: 11.1635 - val_mean_absolute_percentage_error: 33.9860 - lr: 2.5000e-05
# Epoch 39/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.7576 - mean_absolute_error: 4.4981 - root_mean_squared_error: 7.1954 - mean_absolute_percentage_error: 20.2061 - val_loss: 11.4433 - val_mean_absolute_error: 11.1939 - val_root_mean_squared_error: 17.2390 - val_mean_absolute_percentage_error: 38.8154 - lr: 2.5000e-05
# Epoch 40/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.4712 - mean_absolute_error: 4.2099 - root_mean_squared_error: 6.8594 - mean_absolute_percentage_error: 18.7342 - val_loss: 7.0144 - val_mean_absolute_error: 6.7605 - val_root_mean_squared_error: 11.6482 - val_mean_absolute_percentage_error: 31.8213 - lr: 2.5000e-05
# Epoch 41/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.5824 - mean_absolute_error: 4.3229 - root_mean_squared_error: 6.8392 - mean_absolute_percentage_error: 19.0327 - val_loss: 8.4481 - val_mean_absolute_error: 8.2025 - val_root_mean_squared_error: 12.5946 - val_mean_absolute_percentage_error: 42.2825 - lr: 1.2500e-05
# Epoch 42/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.4673 - mean_absolute_error: 4.2055 - root_mean_squared_error: 6.6656 - mean_absolute_percentage_error: 18.9839 - val_loss: 6.6371 - val_mean_absolute_error: 6.3922 - val_root_mean_squared_error: 11.1438 - val_mean_absolute_percentage_error: 33.7961 - lr: 1.2500e-05
# Epoch 43/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.4178 - mean_absolute_error: 4.1607 - root_mean_squared_error: 6.4253 - mean_absolute_percentage_error: 19.5153 - val_loss: 7.9973 - val_mean_absolute_error: 7.7297 - val_root_mean_squared_error: 12.8209 - val_mean_absolute_percentage_error: 32.3490 - lr: 1.2500e-05
# Epoch 44/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.3579 - mean_absolute_error: 4.0980 - root_mean_squared_error: 6.4921 - mean_absolute_percentage_error: 18.0253 - val_loss: 6.7449 - val_mean_absolute_error: 6.5030 - val_root_mean_squared_error: 11.4003 - val_mean_absolute_percentage_error: 31.9650 - lr: 1.2500e-05
# Epoch 45/100
# 103/103 [==============================] - 31s 296ms/step - loss: 4.3173 - mean_absolute_error: 4.0557 - root_mean_squared_error: 6.4130 - mean_absolute_percentage_error: 18.4488 - val_loss: 6.2392 - val_mean_absolute_error: 5.9629 - val_root_mean_squared_error: 11.0235 - val_mean_absolute_percentage_error: 32.9543 - lr: 1.2500e-05
# Epoch 46/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.5409 - mean_absolute_error: 4.2828 - root_mean_squared_error: 6.7228 - mean_absolute_percentage_error: 18.9737 - val_loss: 6.1311 - val_mean_absolute_error: 5.8655 - val_root_mean_squared_error: 10.9022 - val_mean_absolute_percentage_error: 31.2573 - lr: 1.2500e-05
# Epoch 47/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.3387 - mean_absolute_error: 4.0775 - root_mean_squared_error: 6.4682 - mean_absolute_percentage_error: 19.1829 - val_loss: 6.4561 - val_mean_absolute_error: 6.1915 - val_root_mean_squared_error: 11.1089 - val_mean_absolute_percentage_error: 32.1783 - lr: 1.2500e-05
# Epoch 48/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.5844 - mean_absolute_error: 4.3292 - root_mean_squared_error: 6.8060 - mean_absolute_percentage_error: 20.1389 - val_loss: 7.0859 - val_mean_absolute_error: 6.8493 - val_root_mean_squared_error: 11.3020 - val_mean_absolute_percentage_error: 35.3287 - lr: 1.2500e-05
# Epoch 49/100
# 103/103 [==============================] - 31s 298ms/step - loss: 4.5288 - mean_absolute_error: 4.2724 - root_mean_squared_error: 6.7407 - mean_absolute_percentage_error: 18.9756 - val_loss: 6.4374 - val_mean_absolute_error: 6.1973 - val_root_mean_squared_error: 11.0681 - val_mean_absolute_percentage_error: 32.9992 - lr: 1.2500e-05
# Epoch 50/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.2149 - mean_absolute_error: 3.9579 - root_mean_squared_error: 6.2335 - mean_absolute_percentage_error: 17.7465 - val_loss: 6.7947 - val_mean_absolute_error: 6.5496 - val_root_mean_squared_error: 11.1863 - val_mean_absolute_percentage_error: 34.3904 - lr: 1.2500e-05
# Epoch 51/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.2481 - mean_absolute_error: 3.9895 - root_mean_squared_error: 6.2308 - mean_absolute_percentage_error: 18.3482 - val_loss: 6.2848 - val_mean_absolute_error: 6.0371 - val_root_mean_squared_error: 10.8266 - val_mean_absolute_percentage_error: 32.5584 - lr: 1.2500e-05
# Epoch 52/100
# 103/103 [==============================] - 31s 298ms/step - loss: 4.3069 - mean_absolute_error: 4.0489 - root_mean_squared_error: 6.3270 - mean_absolute_percentage_error: 18.7333 - val_loss: 6.0968 - val_mean_absolute_error: 5.8485 - val_root_mean_squared_error: 10.8205 - val_mean_absolute_percentage_error: 32.1998 - lr: 6.2500e-06
# Epoch 53/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.1334 - mean_absolute_error: 3.8750 - root_mean_squared_error: 5.9939 - mean_absolute_percentage_error: 17.9061 - val_loss: 6.3213 - val_mean_absolute_error: 6.0528 - val_root_mean_squared_error: 11.1420 - val_mean_absolute_percentage_error: 30.3630 - lr: 6.2500e-06
# Epoch 54/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.3762 - mean_absolute_error: 4.1160 - root_mean_squared_error: 6.6495 - mean_absolute_percentage_error: 17.8080 - val_loss: 6.1996 - val_mean_absolute_error: 5.9430 - val_root_mean_squared_error: 10.9312 - val_mean_absolute_percentage_error: 31.1200 - lr: 6.2500e-06
# Epoch 55/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.2226 - mean_absolute_error: 3.9644 - root_mean_squared_error: 6.2154 - mean_absolute_percentage_error: 18.0882 - val_loss: 5.9973 - val_mean_absolute_error: 5.7365 - val_root_mean_squared_error: 10.8063 - val_mean_absolute_percentage_error: 31.7965 - lr: 6.2500e-06
# Epoch 56/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.2527 - mean_absolute_error: 3.9964 - root_mean_squared_error: 6.4577 - mean_absolute_percentage_error: 18.6843 - val_loss: 6.1394 - val_mean_absolute_error: 5.8764 - val_root_mean_squared_error: 10.8910 - val_mean_absolute_percentage_error: 31.4160 - lr: 6.2500e-06
# Epoch 57/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.2831 - mean_absolute_error: 4.0275 - root_mean_squared_error: 6.3726 - mean_absolute_percentage_error: 17.9397 - val_loss: 5.9538 - val_mean_absolute_error: 5.6938 - val_root_mean_squared_error: 10.7632 - val_mean_absolute_percentage_error: 31.9253 - lr: 6.2500e-06
# Epoch 58/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.2259 - mean_absolute_error: 3.9666 - root_mean_squared_error: 6.3531 - mean_absolute_percentage_error: 17.6263 - val_loss: 5.9784 - val_mean_absolute_error: 5.7181 - val_root_mean_squared_error: 10.8337 - val_mean_absolute_percentage_error: 31.5116 - lr: 6.2500e-06
# Epoch 59/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.0577 - mean_absolute_error: 3.7964 - root_mean_squared_error: 6.0310 - mean_absolute_percentage_error: 17.1012 - val_loss: 6.6827 - val_mean_absolute_error: 6.4354 - val_root_mean_squared_error: 11.4066 - val_mean_absolute_percentage_error: 30.9710 - lr: 6.2500e-06
# Epoch 60/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.1638 - mean_absolute_error: 3.9052 - root_mean_squared_error: 6.1812 - mean_absolute_percentage_error: 17.5195 - val_loss: 6.1640 - val_mean_absolute_error: 5.9168 - val_root_mean_squared_error: 10.9173 - val_mean_absolute_percentage_error: 31.7331 - lr: 6.2500e-06
# Epoch 61/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.2505 - mean_absolute_error: 3.9921 - root_mean_squared_error: 6.3339 - mean_absolute_percentage_error: 18.0438 - val_loss: 6.1891 - val_mean_absolute_error: 5.9326 - val_root_mean_squared_error: 10.9446 - val_mean_absolute_percentage_error: 31.1927 - lr: 6.2500e-06
# Epoch 62/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.1213 - mean_absolute_error: 3.8634 - root_mean_squared_error: 6.0055 - mean_absolute_percentage_error: 17.7869 - val_loss: 5.8298 - val_mean_absolute_error: 5.5577 - val_root_mean_squared_error: 10.6737 - val_mean_absolute_percentage_error: 31.7367 - lr: 6.2500e-06
# Epoch 63/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.2138 - mean_absolute_error: 3.9587 - root_mean_squared_error: 6.2534 - mean_absolute_percentage_error: 18.0200 - val_loss: 5.9955 - val_mean_absolute_error: 5.7395 - val_root_mean_squared_error: 10.8678 - val_mean_absolute_percentage_error: 31.3959 - lr: 6.2500e-06
# Epoch 64/100
# 103/103 [==============================] - 31s 296ms/step - loss: 4.0845 - mean_absolute_error: 3.8264 - root_mean_squared_error: 6.1065 - mean_absolute_percentage_error: 17.4389 - val_loss: 7.2244 - val_mean_absolute_error: 6.9627 - val_root_mean_squared_error: 11.7813 - val_mean_absolute_percentage_error: 31.5897 - lr: 6.2500e-06
# Epoch 65/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.1462 - mean_absolute_error: 3.8862 - root_mean_squared_error: 6.3047 - mean_absolute_percentage_error: 17.3623 - val_loss: 6.6006 - val_mean_absolute_error: 6.3571 - val_root_mean_squared_error: 11.2711 - val_mean_absolute_percentage_error: 31.3079 - lr: 6.2500e-06
# Epoch 66/100
# 103/103 [==============================] - 31s 299ms/step - loss: 4.1783 - mean_absolute_error: 3.9206 - root_mean_squared_error: 6.2122 - mean_absolute_percentage_error: 17.2938 - val_loss: 6.4135 - val_mean_absolute_error: 6.1672 - val_root_mean_squared_error: 11.1255 - val_mean_absolute_percentage_error: 31.1832 - lr: 6.2500e-06
# Epoch 67/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.2934 - mean_absolute_error: 4.0364 - root_mean_squared_error: 6.7460 - mean_absolute_percentage_error: 18.5262 - val_loss: 6.1139 - val_mean_absolute_error: 5.8565 - val_root_mean_squared_error: 10.8985 - val_mean_absolute_percentage_error: 31.1064 - lr: 6.2500e-06
# Epoch 68/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.1598 - mean_absolute_error: 3.9017 - root_mean_squared_error: 6.2095 - mean_absolute_percentage_error: 18.0682 - val_loss: 6.1525 - val_mean_absolute_error: 5.8996 - val_root_mean_squared_error: 10.9646 - val_mean_absolute_percentage_error: 31.2062 - lr: 3.1250e-06
# Epoch 69/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.1219 - mean_absolute_error: 3.8620 - root_mean_squared_error: 6.2212 - mean_absolute_percentage_error: 18.2539 - val_loss: 6.0371 - val_mean_absolute_error: 5.7892 - val_root_mean_squared_error: 10.8420 - val_mean_absolute_percentage_error: 31.8996 - lr: 3.1250e-06
# Epoch 70/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.1977 - mean_absolute_error: 3.9416 - root_mean_squared_error: 6.2260 - mean_absolute_percentage_error: 17.6381 - val_loss: 6.1932 - val_mean_absolute_error: 5.9499 - val_root_mean_squared_error: 10.9393 - val_mean_absolute_percentage_error: 31.6545 - lr: 3.1250e-06
# Epoch 71/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.2516 - mean_absolute_error: 3.9965 - root_mean_squared_error: 6.2673 - mean_absolute_percentage_error: 17.7856 - val_loss: 6.0172 - val_mean_absolute_error: 5.7641 - val_root_mean_squared_error: 10.8450 - val_mean_absolute_percentage_error: 31.5886 - lr: 3.1250e-06
# Epoch 72/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.1449 - mean_absolute_error: 3.8882 - root_mean_squared_error: 6.1256 - mean_absolute_percentage_error: 16.9503 - val_loss: 6.0763 - val_mean_absolute_error: 5.8291 - val_root_mean_squared_error: 10.9120 - val_mean_absolute_percentage_error: 31.4307 - lr: 3.1250e-06
# Epoch 73/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.1420 - mean_absolute_error: 3.8839 - root_mean_squared_error: 6.2401 - mean_absolute_percentage_error: 17.5368 - val_loss: 6.3794 - val_mean_absolute_error: 6.1340 - val_root_mean_squared_error: 11.0979 - val_mean_absolute_percentage_error: 31.3864 - lr: 1.5625e-06
# Epoch 74/100
# 103/103 [==============================] - 31s 298ms/step - loss: 4.1245 - mean_absolute_error: 3.8672 - root_mean_squared_error: 6.1285 - mean_absolute_percentage_error: 18.3083 - val_loss: 6.3589 - val_mean_absolute_error: 6.1155 - val_root_mean_squared_error: 11.0565 - val_mean_absolute_percentage_error: 31.6103 - lr: 1.5625e-06
# Epoch 75/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.0939 - mean_absolute_error: 3.8382 - root_mean_squared_error: 5.8992 - mean_absolute_percentage_error: 17.6898 - val_loss: 6.2109 - val_mean_absolute_error: 5.9664 - val_root_mean_squared_error: 10.9648 - val_mean_absolute_percentage_error: 31.5536 - lr: 1.5625e-06
# Epoch 76/100
# 103/103 [==============================] - 30s 294ms/step - loss: 3.9756 - mean_absolute_error: 3.7165 - root_mean_squared_error: 5.8933 - mean_absolute_percentage_error: 16.9635 - val_loss: 6.0251 - val_mean_absolute_error: 5.7796 - val_root_mean_squared_error: 10.8175 - val_mean_absolute_percentage_error: 32.1730 - lr: 1.5625e-06
# Epoch 77/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.0944 - mean_absolute_error: 3.8373 - root_mean_squared_error: 6.0853 - mean_absolute_percentage_error: 17.6819 - val_loss: 6.0110 - val_mean_absolute_error: 5.7606 - val_root_mean_squared_error: 10.8438 - val_mean_absolute_percentage_error: 31.5941 - lr: 1.5625e-06
# Epoch 78/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.2336 - mean_absolute_error: 3.9767 - root_mean_squared_error: 6.2415 - mean_absolute_percentage_error: 18.2136 - val_loss: 6.1081 - val_mean_absolute_error: 5.8622 - val_root_mean_squared_error: 10.9075 - val_mean_absolute_percentage_error: 31.5506 - lr: 7.8125e-07
# Epoch 79/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.1497 - mean_absolute_error: 3.8928 - root_mean_squared_error: 6.0276 - mean_absolute_percentage_error: 18.4861 - val_loss: 6.0844 - val_mean_absolute_error: 5.8386 - val_root_mean_squared_error: 10.8733 - val_mean_absolute_percentage_error: 31.5455 - lr: 7.8125e-07
# Epoch 80/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.0720 - mean_absolute_error: 3.8164 - root_mean_squared_error: 6.1349 - mean_absolute_percentage_error: 17.2156 - val_loss: 6.1225 - val_mean_absolute_error: 5.8804 - val_root_mean_squared_error: 10.8986 - val_mean_absolute_percentage_error: 31.6609 - lr: 7.8125e-07
# Epoch 81/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.1693 - mean_absolute_error: 3.9131 - root_mean_squared_error: 6.3869 - mean_absolute_percentage_error: 17.2997 - val_loss: 6.0912 - val_mean_absolute_error: 5.8457 - val_root_mean_squared_error: 10.8913 - val_mean_absolute_percentage_error: 31.5120 - lr: 7.8125e-07
# Epoch 82/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.2062 - mean_absolute_error: 3.9506 - root_mean_squared_error: 6.2077 - mean_absolute_percentage_error: 18.2900 - val_loss: 6.0235 - val_mean_absolute_error: 5.7758 - val_root_mean_squared_error: 10.8455 - val_mean_absolute_percentage_error: 31.5836 - lr: 7.8125e-07
# Epoch 83/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.0946 - mean_absolute_error: 3.8371 - root_mean_squared_error: 6.2651 - mean_absolute_percentage_error: 16.8618 - val_loss: 6.0528 - val_mean_absolute_error: 5.8068 - val_root_mean_squared_error: 10.8559 - val_mean_absolute_percentage_error: 31.6563 - lr: 3.9062e-07
# Epoch 84/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.1290 - mean_absolute_error: 3.8724 - root_mean_squared_error: 6.2325 - mean_absolute_percentage_error: 17.3504 - val_loss: 6.1007 - val_mean_absolute_error: 5.8575 - val_root_mean_squared_error: 10.8900 - val_mean_absolute_percentage_error: 31.6545 - lr: 3.9062e-07
# Epoch 85/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.1963 - mean_absolute_error: 3.9401 - root_mean_squared_error: 6.1951 - mean_absolute_percentage_error: 17.6674 - val_loss: 6.0484 - val_mean_absolute_error: 5.8022 - val_root_mean_squared_error: 10.8627 - val_mean_absolute_percentage_error: 31.7163 - lr: 3.9062e-07
# Epoch 86/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.2498 - mean_absolute_error: 3.9923 - root_mean_squared_error: 6.5219 - mean_absolute_percentage_error: 18.8612 - val_loss: 6.1667 - val_mean_absolute_error: 5.9216 - val_root_mean_squared_error: 10.9305 - val_mean_absolute_percentage_error: 31.5035 - lr: 3.9062e-07
# Epoch 87/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.2819 - mean_absolute_error: 4.0265 - root_mean_squared_error: 6.3089 - mean_absolute_percentage_error: 18.7661 - val_loss: 6.0924 - val_mean_absolute_error: 5.8489 - val_root_mean_squared_error: 10.8888 - val_mean_absolute_percentage_error: 31.5066 - lr: 3.9062e-07
# Epoch 88/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.9949 - mean_absolute_error: 3.7380 - root_mean_squared_error: 5.8768 - mean_absolute_percentage_error: 16.4165 - val_loss: 6.0090 - val_mean_absolute_error: 5.7601 - val_root_mean_squared_error: 10.8460 - val_mean_absolute_percentage_error: 31.3932 - lr: 1.9531e-07
# Epoch 89/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.9732 - mean_absolute_error: 3.7144 - root_mean_squared_error: 5.9646 - mean_absolute_percentage_error: 16.8916 - val_loss: 6.0032 - val_mean_absolute_error: 5.7532 - val_root_mean_squared_error: 10.8361 - val_mean_absolute_percentage_error: 31.4584 - lr: 1.9531e-07
# Epoch 90/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.1227 - mean_absolute_error: 3.8651 - root_mean_squared_error: 6.2474 - mean_absolute_percentage_error: 17.3316 - val_loss: 6.0870 - val_mean_absolute_error: 5.8413 - val_root_mean_squared_error: 10.8860 - val_mean_absolute_percentage_error: 31.3809 - lr: 1.9531e-07
# Epoch 91/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.1096 - mean_absolute_error: 3.8520 - root_mean_squared_error: 6.3588 - mean_absolute_percentage_error: 17.4009 - val_loss: 6.0542 - val_mean_absolute_error: 5.8062 - val_root_mean_squared_error: 10.8557 - val_mean_absolute_percentage_error: 31.4216 - lr: 1.9531e-07
# Epoch 92/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.1677 - mean_absolute_error: 3.9114 - root_mean_squared_error: 6.1656 - mean_absolute_percentage_error: 17.7209 - val_loss: 5.9774 - val_mean_absolute_error: 5.7263 - val_root_mean_squared_error: 10.8186 - val_mean_absolute_percentage_error: 31.4613 - lr: 1.9531e-07
# Epoch 93/100
# 103/103 [==============================] - 31s 298ms/step - loss: 4.1507 - mean_absolute_error: 3.8922 - root_mean_squared_error: 6.1994 - mean_absolute_percentage_error: 17.7683 - val_loss: 5.9770 - val_mean_absolute_error: 5.7263 - val_root_mean_squared_error: 10.8250 - val_mean_absolute_percentage_error: 31.4620 - lr: 9.7656e-08
# Epoch 94/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.1516 - mean_absolute_error: 3.8949 - root_mean_squared_error: 6.1757 - mean_absolute_percentage_error: 17.3434 - val_loss: 6.0377 - val_mean_absolute_error: 5.7906 - val_root_mean_squared_error: 10.8571 - val_mean_absolute_percentage_error: 31.5131 - lr: 9.7656e-08
# Epoch 95/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.0896 - mean_absolute_error: 3.8314 - root_mean_squared_error: 6.0854 - mean_absolute_percentage_error: 17.9167 - val_loss: 6.0631 - val_mean_absolute_error: 5.8182 - val_root_mean_squared_error: 10.8620 - val_mean_absolute_percentage_error: 31.5144 - lr: 9.7656e-08
# Epoch 96/100
# 103/103 [==============================] - 31s 297ms/step - loss: 3.9945 - mean_absolute_error: 3.7321 - root_mean_squared_error: 5.9727 - mean_absolute_percentage_error: 16.7977 - val_loss: 6.0691 - val_mean_absolute_error: 5.8238 - val_root_mean_squared_error: 10.8725 - val_mean_absolute_percentage_error: 31.4704 - lr: 9.7656e-08
# Epoch 97/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.0990 - mean_absolute_error: 3.8413 - root_mean_squared_error: 6.0595 - mean_absolute_percentage_error: 17.6113 - val_loss: 6.0585 - val_mean_absolute_error: 5.8122 - val_root_mean_squared_error: 10.8645 - val_mean_absolute_percentage_error: 31.4024 - lr: 9.7656e-08
# Epoch 98/100
# 103/103 [==============================] - 31s 300ms/step - loss: 4.0327 - mean_absolute_error: 3.7747 - root_mean_squared_error: 6.1149 - mean_absolute_percentage_error: 16.3799 - val_loss: 5.9979 - val_mean_absolute_error: 5.7495 - val_root_mean_squared_error: 10.8193 - val_mean_absolute_percentage_error: 31.4912 - lr: 4.8828e-08
# Epoch 99/100
# 103/103 [==============================] - 31s 298ms/step - loss: 4.3026 - mean_absolute_error: 4.0475 - root_mean_squared_error: 6.4219 - mean_absolute_percentage_error: 18.0380 - val_loss: 5.9898 - val_mean_absolute_error: 5.7395 - val_root_mean_squared_error: 10.8189 - val_mean_absolute_percentage_error: 31.5346 - lr: 4.8828e-08
# Epoch 100/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.2462 - mean_absolute_error: 3.9913 - root_mean_squared_error: 6.2407 - mean_absolute_percentage_error: 18.3598 - val_loss: 6.0039 - val_mean_absolute_error: 5.7545 - val_root_mean_squared_error: 10.8288 - val_mean_absolute_percentage_error: 31.5338 - lr: 4.8828e-08

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 126ms/step - loss: 6.0039 - mean_absolute_error: 5.7545 - root_mean_squared_error: 10.8288 - mean_absolute_percentage_error: 31.5338
# Model Loss: [6.003878593444824, 5.7544636726379395, 10.82877254486084, 31.533845901489258]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [12.787645]

# %%
model_scenario_name = "BiLSTM_13_Rerun"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13_Rerun\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13_Rerun\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_13_Rerun"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted Putusan: [12.787645]
