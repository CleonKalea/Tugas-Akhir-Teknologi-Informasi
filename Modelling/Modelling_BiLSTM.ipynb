# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_6968\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(lstm_output_2)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu')(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(16, activation='relu')(numerical_dense)

combined = tf.keras.layers.Concatenate()([lstm_output_3, numerical_dense_2])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mse', metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 32)     34944       ['embedding[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_1 (Bidirectional  (None, 1024, 64)    16640       ['bidirectional[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 128)         66048       ['bidirectional_1[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 16)           528         ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 144)          0           ['bidirectional_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            145         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,934,433
# Trainable params: 3,934,433
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 33s 266ms/step - loss: 522.1187 - mean_absolute_error: 16.8519 - root_mean_squared_error: 22.8499 - mean_absolute_percentage_error: 125.5547 - val_loss: 393.1340 - val_mean_absolute_error: 13.5902 - val_root_mean_squared_error: 19.8276 - val_mean_absolute_percentage_error: 115.8098
# Epoch 2/100
# 103/103 [==============================] - 26s 255ms/step - loss: 285.2433 - mean_absolute_error: 11.6620 - root_mean_squared_error: 16.8891 - mean_absolute_percentage_error: 96.6310 - val_loss: 301.8436 - val_mean_absolute_error: 11.2868 - val_root_mean_squared_error: 17.3736 - val_mean_absolute_percentage_error: 88.2729
# Epoch 3/100
# 103/103 [==============================] - 26s 257ms/step - loss: 207.7739 - mean_absolute_error: 9.6396 - root_mean_squared_error: 14.4144 - mean_absolute_percentage_error: 74.2837 - val_loss: 263.4808 - val_mean_absolute_error: 10.3853 - val_root_mean_squared_error: 16.2321 - val_mean_absolute_percentage_error: 77.1588
# Epoch 4/100
# 103/103 [==============================] - 27s 259ms/step - loss: 154.3738 - mean_absolute_error: 8.0118 - root_mean_squared_error: 12.4247 - mean_absolute_percentage_error: 61.4236 - val_loss: 239.1750 - val_mean_absolute_error: 9.6590 - val_root_mean_squared_error: 15.4653 - val_mean_absolute_percentage_error: 69.4787
# Epoch 5/100
# 103/103 [==============================] - 27s 260ms/step - loss: 107.9086 - mean_absolute_error: 6.2948 - root_mean_squared_error: 10.3879 - mean_absolute_percentage_error: 48.1340 - val_loss: 215.5869 - val_mean_absolute_error: 9.0504 - val_root_mean_squared_error: 14.6829 - val_mean_absolute_percentage_error: 63.9617
# Epoch 6/100
# 103/103 [==============================] - 27s 258ms/step - loss: 82.1501 - mean_absolute_error: 5.2120 - root_mean_squared_error: 9.0637 - mean_absolute_percentage_error: 36.7754 - val_loss: 205.6175 - val_mean_absolute_error: 8.3836 - val_root_mean_squared_error: 14.3394 - val_mean_absolute_percentage_error: 52.3425
# Epoch 7/100
# 103/103 [==============================] - 27s 260ms/step - loss: 64.5901 - mean_absolute_error: 4.3032 - root_mean_squared_error: 8.0368 - mean_absolute_percentage_error: 28.1042 - val_loss: 198.5239 - val_mean_absolute_error: 8.0280 - val_root_mean_squared_error: 14.0899 - val_mean_absolute_percentage_error: 47.3705
# Epoch 8/100
# 103/103 [==============================] - 27s 261ms/step - loss: 51.1244 - mean_absolute_error: 3.5939 - root_mean_squared_error: 7.1501 - mean_absolute_percentage_error: 23.9898 - val_loss: 187.0753 - val_mean_absolute_error: 7.7523 - val_root_mean_squared_error: 13.6775 - val_mean_absolute_percentage_error: 48.6429
# Epoch 9/100
# 103/103 [==============================] - 26s 249ms/step - loss: 42.3287 - mean_absolute_error: 3.2612 - root_mean_squared_error: 6.5060 - mean_absolute_percentage_error: 22.9210 - val_loss: 177.5607 - val_mean_absolute_error: 7.6738 - val_root_mean_squared_error: 13.3252 - val_mean_absolute_percentage_error: 47.0451
# Epoch 10/100
# 103/103 [==============================] - 26s 254ms/step - loss: 35.6489 - mean_absolute_error: 2.9173 - root_mean_squared_error: 5.9707 - mean_absolute_percentage_error: 20.4991 - val_loss: 178.1386 - val_mean_absolute_error: 7.4366 - val_root_mean_squared_error: 13.3469 - val_mean_absolute_percentage_error: 46.1382
# Epoch 11/100
# 103/103 [==============================] - 27s 261ms/step - loss: 30.6885 - mean_absolute_error: 2.5753 - root_mean_squared_error: 5.5397 - mean_absolute_percentage_error: 17.9339 - val_loss: 170.9388 - val_mean_absolute_error: 7.3198 - val_root_mean_squared_error: 13.0744 - val_mean_absolute_percentage_error: 46.1018
# Epoch 12/100
# 103/103 [==============================] - 27s 260ms/step - loss: 26.9998 - mean_absolute_error: 2.3888 - root_mean_squared_error: 5.1961 - mean_absolute_percentage_error: 16.4923 - val_loss: 167.7945 - val_mean_absolute_error: 7.2814 - val_root_mean_squared_error: 12.9536 - val_mean_absolute_percentage_error: 46.6487
# Epoch 13/100
# 103/103 [==============================] - 27s 259ms/step - loss: 23.9482 - mean_absolute_error: 2.2003 - root_mean_squared_error: 4.8937 - mean_absolute_percentage_error: 14.3693 - val_loss: 172.5470 - val_mean_absolute_error: 7.3770 - val_root_mean_squared_error: 13.1357 - val_mean_absolute_percentage_error: 47.6947
# Epoch 14/100
# 103/103 [==============================] - 27s 259ms/step - loss: 21.4718 - mean_absolute_error: 2.1728 - root_mean_squared_error: 4.6338 - mean_absolute_percentage_error: 15.7198 - val_loss: 166.4083 - val_mean_absolute_error: 7.1734 - val_root_mean_squared_error: 12.8999 - val_mean_absolute_percentage_error: 44.3498
# Epoch 15/100
# 103/103 [==============================] - 27s 261ms/step - loss: 20.3714 - mean_absolute_error: 2.0548 - root_mean_squared_error: 4.5135 - mean_absolute_percentage_error: 13.2952 - val_loss: 161.5718 - val_mean_absolute_error: 7.2726 - val_root_mean_squared_error: 12.7111 - val_mean_absolute_percentage_error: 46.4417
# Epoch 16/100
# 103/103 [==============================] - 27s 261ms/step - loss: 17.9299 - mean_absolute_error: 1.9015 - root_mean_squared_error: 4.2344 - mean_absolute_percentage_error: 12.2681 - val_loss: 155.9626 - val_mean_absolute_error: 6.9749 - val_root_mean_squared_error: 12.4885 - val_mean_absolute_percentage_error: 42.4786
# Epoch 17/100
# 103/103 [==============================] - 27s 261ms/step - loss: 15.2659 - mean_absolute_error: 1.7382 - root_mean_squared_error: 3.9072 - mean_absolute_percentage_error: 11.6224 - val_loss: 158.8694 - val_mean_absolute_error: 7.0235 - val_root_mean_squared_error: 12.6043 - val_mean_absolute_percentage_error: 44.5887
# Epoch 18/100
# 103/103 [==============================] - 27s 262ms/step - loss: 13.5967 - mean_absolute_error: 1.7245 - root_mean_squared_error: 3.6874 - mean_absolute_percentage_error: 11.5011 - val_loss: 156.8404 - val_mean_absolute_error: 6.9768 - val_root_mean_squared_error: 12.5236 - val_mean_absolute_percentage_error: 44.0620
# Epoch 19/100
# 103/103 [==============================] - 27s 261ms/step - loss: 12.4463 - mean_absolute_error: 1.5692 - root_mean_squared_error: 3.5279 - mean_absolute_percentage_error: 10.2038 - val_loss: 154.7160 - val_mean_absolute_error: 6.8183 - val_root_mean_squared_error: 12.4385 - val_mean_absolute_percentage_error: 42.6045
# Epoch 20/100
# 103/103 [==============================] - 27s 260ms/step - loss: 10.8465 - mean_absolute_error: 1.4517 - root_mean_squared_error: 3.2934 - mean_absolute_percentage_error: 9.2149 - val_loss: 159.6400 - val_mean_absolute_error: 7.1111 - val_root_mean_squared_error: 12.6349 - val_mean_absolute_percentage_error: 44.0278
# Epoch 21/100
# 103/103 [==============================] - 27s 261ms/step - loss: 10.8478 - mean_absolute_error: 1.5552 - root_mean_squared_error: 3.2936 - mean_absolute_percentage_error: 10.0669 - val_loss: 158.0491 - val_mean_absolute_error: 7.1569 - val_root_mean_squared_error: 12.5718 - val_mean_absolute_percentage_error: 45.9197
# Epoch 22/100
# 103/103 [==============================] - 27s 260ms/step - loss: 9.6244 - mean_absolute_error: 1.4565 - root_mean_squared_error: 3.1023 - mean_absolute_percentage_error: 9.7673 - val_loss: 152.9924 - val_mean_absolute_error: 6.8565 - val_root_mean_squared_error: 12.3690 - val_mean_absolute_percentage_error: 43.2548
# Epoch 23/100
# 103/103 [==============================] - 27s 260ms/step - loss: 9.0224 - mean_absolute_error: 1.3576 - root_mean_squared_error: 3.0037 - mean_absolute_percentage_error: 8.3529 - val_loss: 154.9023 - val_mean_absolute_error: 6.8650 - val_root_mean_squared_error: 12.4460 - val_mean_absolute_percentage_error: 42.4362
# Epoch 24/100
# 103/103 [==============================] - 27s 261ms/step - loss: 8.5629 - mean_absolute_error: 1.3500 - root_mean_squared_error: 2.9263 - mean_absolute_percentage_error: 8.6702 - val_loss: 152.4828 - val_mean_absolute_error: 6.7920 - val_root_mean_squared_error: 12.3484 - val_mean_absolute_percentage_error: 42.1622
# Epoch 25/100
# 103/103 [==============================] - 27s 260ms/step - loss: 7.6073 - mean_absolute_error: 1.2612 - root_mean_squared_error: 2.7581 - mean_absolute_percentage_error: 8.4350 - val_loss: 150.4478 - val_mean_absolute_error: 6.6953 - val_root_mean_squared_error: 12.2657 - val_mean_absolute_percentage_error: 41.9851
# Epoch 26/100
# 103/103 [==============================] - 27s 260ms/step - loss: 6.8544 - mean_absolute_error: 1.1879 - root_mean_squared_error: 2.6181 - mean_absolute_percentage_error: 8.0491 - val_loss: 150.5215 - val_mean_absolute_error: 6.9820 - val_root_mean_squared_error: 12.2687 - val_mean_absolute_percentage_error: 43.9893
# Epoch 27/100
# 103/103 [==============================] - 27s 261ms/step - loss: 7.0253 - mean_absolute_error: 1.2904 - root_mean_squared_error: 2.6505 - mean_absolute_percentage_error: 8.2624 - val_loss: 159.3854 - val_mean_absolute_error: 7.0118 - val_root_mean_squared_error: 12.6248 - val_mean_absolute_percentage_error: 44.1976
# Epoch 28/100
# 103/103 [==============================] - 27s 261ms/step - loss: 7.0930 - mean_absolute_error: 1.3219 - root_mean_squared_error: 2.6633 - mean_absolute_percentage_error: 8.1751 - val_loss: 151.4914 - val_mean_absolute_error: 6.9017 - val_root_mean_squared_error: 12.3082 - val_mean_absolute_percentage_error: 43.8049
# Epoch 29/100
# 103/103 [==============================] - 27s 261ms/step - loss: 6.7286 - mean_absolute_error: 1.3302 - root_mean_squared_error: 2.5940 - mean_absolute_percentage_error: 8.7430 - val_loss: 147.9755 - val_mean_absolute_error: 6.8051 - val_root_mean_squared_error: 12.1645 - val_mean_absolute_percentage_error: 42.1028
# Epoch 30/100
# 103/103 [==============================] - 27s 262ms/step - loss: 6.8022 - mean_absolute_error: 1.2266 - root_mean_squared_error: 2.6081 - mean_absolute_percentage_error: 8.2409 - val_loss: 144.6415 - val_mean_absolute_error: 6.6176 - val_root_mean_squared_error: 12.0267 - val_mean_absolute_percentage_error: 41.8588
# Epoch 31/100
# 103/103 [==============================] - 27s 259ms/step - loss: 6.3715 - mean_absolute_error: 1.1560 - root_mean_squared_error: 2.5242 - mean_absolute_percentage_error: 7.5775 - val_loss: 149.1350 - val_mean_absolute_error: 6.6492 - val_root_mean_squared_error: 12.2121 - val_mean_absolute_percentage_error: 42.0588
# Epoch 32/100
# 103/103 [==============================] - 27s 259ms/step - loss: 5.5364 - mean_absolute_error: 1.0641 - root_mean_squared_error: 2.3530 - mean_absolute_percentage_error: 6.7793 - val_loss: 146.0011 - val_mean_absolute_error: 6.6315 - val_root_mean_squared_error: 12.0831 - val_mean_absolute_percentage_error: 41.5814
# Epoch 33/100
# 103/103 [==============================] - 27s 260ms/step - loss: 5.2984 - mean_absolute_error: 1.0812 - root_mean_squared_error: 2.3018 - mean_absolute_percentage_error: 6.8797 - val_loss: 146.9743 - val_mean_absolute_error: 6.6235 - val_root_mean_squared_error: 12.1233 - val_mean_absolute_percentage_error: 42.6043
# Epoch 34/100
# 103/103 [==============================] - 27s 262ms/step - loss: 5.0518 - mean_absolute_error: 1.0481 - root_mean_squared_error: 2.2476 - mean_absolute_percentage_error: 6.7489 - val_loss: 144.2803 - val_mean_absolute_error: 6.6366 - val_root_mean_squared_error: 12.0117 - val_mean_absolute_percentage_error: 43.2288
# Epoch 35/100
# 103/103 [==============================] - 27s 260ms/step - loss: 4.7759 - mean_absolute_error: 1.0465 - root_mean_squared_error: 2.1854 - mean_absolute_percentage_error: 6.7480 - val_loss: 147.1391 - val_mean_absolute_error: 6.6886 - val_root_mean_squared_error: 12.1301 - val_mean_absolute_percentage_error: 42.6599
# Epoch 36/100
# 103/103 [==============================] - 27s 261ms/step - loss: 5.3995 - mean_absolute_error: 1.1846 - root_mean_squared_error: 2.3237 - mean_absolute_percentage_error: 7.5095 - val_loss: 149.2098 - val_mean_absolute_error: 6.7490 - val_root_mean_squared_error: 12.2151 - val_mean_absolute_percentage_error: 43.9347
# Epoch 37/100
# 103/103 [==============================] - 27s 260ms/step - loss: 6.2244 - mean_absolute_error: 1.3812 - root_mean_squared_error: 2.4949 - mean_absolute_percentage_error: 8.8697 - val_loss: 146.7899 - val_mean_absolute_error: 6.7486 - val_root_mean_squared_error: 12.1157 - val_mean_absolute_percentage_error: 42.0811
# Epoch 38/100
# 103/103 [==============================] - 27s 260ms/step - loss: 5.7134 - mean_absolute_error: 1.2964 - root_mean_squared_error: 2.3903 - mean_absolute_percentage_error: 8.5268 - val_loss: 148.7095 - val_mean_absolute_error: 6.8581 - val_root_mean_squared_error: 12.1947 - val_mean_absolute_percentage_error: 44.0957
# Epoch 39/100
# 103/103 [==============================] - 27s 258ms/step - loss: 5.2657 - mean_absolute_error: 1.1968 - root_mean_squared_error: 2.2947 - mean_absolute_percentage_error: 7.7234 - val_loss: 146.9092 - val_mean_absolute_error: 6.6133 - val_root_mean_squared_error: 12.1206 - val_mean_absolute_percentage_error: 41.0485
# Epoch 40/100
# 103/103 [==============================] - 27s 260ms/step - loss: 4.3334 - mean_absolute_error: 1.0494 - root_mean_squared_error: 2.0817 - mean_absolute_percentage_error: 6.9601 - val_loss: 140.8119 - val_mean_absolute_error: 6.4612 - val_root_mean_squared_error: 11.8664 - val_mean_absolute_percentage_error: 38.8543
# Epoch 41/100
# 103/103 [==============================] - 27s 260ms/step - loss: 4.5042 - mean_absolute_error: 1.0507 - root_mean_squared_error: 2.1223 - mean_absolute_percentage_error: 6.9655 - val_loss: 153.5182 - val_mean_absolute_error: 6.8502 - val_root_mean_squared_error: 12.3902 - val_mean_absolute_percentage_error: 44.4925
# Epoch 42/100
# 103/103 [==============================] - 27s 261ms/step - loss: 5.9348 - mean_absolute_error: 1.3270 - root_mean_squared_error: 2.4361 - mean_absolute_percentage_error: 8.5020 - val_loss: 193.8411 - val_mean_absolute_error: 9.7203 - val_root_mean_squared_error: 13.9227 - val_mean_absolute_percentage_error: 60.0124
# Epoch 43/100
# 103/103 [==============================] - 27s 261ms/step - loss: 22.2056 - mean_absolute_error: 3.0546 - root_mean_squared_error: 4.7123 - mean_absolute_percentage_error: 20.3758 - val_loss: 157.9931 - val_mean_absolute_error: 7.3955 - val_root_mean_squared_error: 12.5695 - val_mean_absolute_percentage_error: 47.0654
# Epoch 44/100
# 103/103 [==============================] - 27s 261ms/step - loss: 9.5057 - mean_absolute_error: 2.0104 - root_mean_squared_error: 3.0831 - mean_absolute_percentage_error: 13.1683 - val_loss: 153.6396 - val_mean_absolute_error: 6.9207 - val_root_mean_squared_error: 12.3951 - val_mean_absolute_percentage_error: 40.9321
# Epoch 45/100
# 103/103 [==============================] - 27s 258ms/step - loss: 5.0849 - mean_absolute_error: 1.3516 - root_mean_squared_error: 2.2550 - mean_absolute_percentage_error: 9.1145 - val_loss: 147.5659 - val_mean_absolute_error: 6.7107 - val_root_mean_squared_error: 12.1477 - val_mean_absolute_percentage_error: 39.4960
# Epoch 46/100
# 103/103 [==============================] - 27s 259ms/step - loss: 3.9395 - mean_absolute_error: 1.1073 - root_mean_squared_error: 1.9848 - mean_absolute_percentage_error: 7.3814 - val_loss: 149.4467 - val_mean_absolute_error: 6.6663 - val_root_mean_squared_error: 12.2248 - val_mean_absolute_percentage_error: 40.3302
# Epoch 47/100
# 103/103 [==============================] - 27s 261ms/step - loss: 2.9483 - mean_absolute_error: 0.8859 - root_mean_squared_error: 1.7171 - mean_absolute_percentage_error: 5.9393 - val_loss: 151.5231 - val_mean_absolute_error: 6.7987 - val_root_mean_squared_error: 12.3095 - val_mean_absolute_percentage_error: 41.3208
# Epoch 48/100
# 103/103 [==============================] - 27s 260ms/step - loss: 2.4876 - mean_absolute_error: 0.7837 - root_mean_squared_error: 1.5772 - mean_absolute_percentage_error: 5.2183 - val_loss: 147.3892 - val_mean_absolute_error: 6.5373 - val_root_mean_squared_error: 12.1404 - val_mean_absolute_percentage_error: 39.5711
# Epoch 49/100
# 103/103 [==============================] - 27s 259ms/step - loss: 2.3116 - mean_absolute_error: 0.7379 - root_mean_squared_error: 1.5204 - mean_absolute_percentage_error: 4.9663 - val_loss: 149.1048 - val_mean_absolute_error: 6.5525 - val_root_mean_squared_error: 12.2108 - val_mean_absolute_percentage_error: 39.5137
# Epoch 50/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.9277 - mean_absolute_error: 0.6679 - root_mean_squared_error: 1.3884 - mean_absolute_percentage_error: 4.4578 - val_loss: 148.2371 - val_mean_absolute_error: 6.5434 - val_root_mean_squared_error: 12.1753 - val_mean_absolute_percentage_error: 39.8193
# Epoch 51/100
# 103/103 [==============================] - 27s 258ms/step - loss: 1.8557 - mean_absolute_error: 0.6573 - root_mean_squared_error: 1.3623 - mean_absolute_percentage_error: 4.3554 - val_loss: 147.9390 - val_mean_absolute_error: 6.5204 - val_root_mean_squared_error: 12.1630 - val_mean_absolute_percentage_error: 39.7740
# Epoch 52/100
# 103/103 [==============================] - 27s 259ms/step - loss: 1.6788 - mean_absolute_error: 0.5755 - root_mean_squared_error: 1.2957 - mean_absolute_percentage_error: 3.6991 - val_loss: 144.7569 - val_mean_absolute_error: 6.4398 - val_root_mean_squared_error: 12.0315 - val_mean_absolute_percentage_error: 39.8700
# Epoch 53/100
# 103/103 [==============================] - 27s 262ms/step - loss: 1.5069 - mean_absolute_error: 0.6004 - root_mean_squared_error: 1.2276 - mean_absolute_percentage_error: 3.9552 - val_loss: 146.6445 - val_mean_absolute_error: 6.4855 - val_root_mean_squared_error: 12.1097 - val_mean_absolute_percentage_error: 39.6999
# Epoch 54/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.3704 - mean_absolute_error: 0.5712 - root_mean_squared_error: 1.1707 - mean_absolute_percentage_error: 3.7348 - val_loss: 145.9666 - val_mean_absolute_error: 6.5163 - val_root_mean_squared_error: 12.0817 - val_mean_absolute_percentage_error: 41.0235
# Epoch 55/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.3305 - mean_absolute_error: 0.5825 - root_mean_squared_error: 1.1535 - mean_absolute_percentage_error: 3.8879 - val_loss: 145.2204 - val_mean_absolute_error: 6.4645 - val_root_mean_squared_error: 12.0507 - val_mean_absolute_percentage_error: 40.2117
# Epoch 56/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.3409 - mean_absolute_error: 0.6183 - root_mean_squared_error: 1.1580 - mean_absolute_percentage_error: 4.0007 - val_loss: 147.4254 - val_mean_absolute_error: 6.5710 - val_root_mean_squared_error: 12.1419 - val_mean_absolute_percentage_error: 41.4855
# Epoch 57/100
# 103/103 [==============================] - 27s 262ms/step - loss: 1.4237 - mean_absolute_error: 0.6641 - root_mean_squared_error: 1.1932 - mean_absolute_percentage_error: 4.3419 - val_loss: 144.0131 - val_mean_absolute_error: 6.4800 - val_root_mean_squared_error: 12.0005 - val_mean_absolute_percentage_error: 41.2410
# Epoch 58/100
# 103/103 [==============================] - 27s 262ms/step - loss: 1.3357 - mean_absolute_error: 0.6509 - root_mean_squared_error: 1.1557 - mean_absolute_percentage_error: 4.3540 - val_loss: 146.3263 - val_mean_absolute_error: 6.5490 - val_root_mean_squared_error: 12.0965 - val_mean_absolute_percentage_error: 40.1331
# Epoch 59/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.5061 - mean_absolute_error: 0.7581 - root_mean_squared_error: 1.2272 - mean_absolute_percentage_error: 5.0876 - val_loss: 145.0393 - val_mean_absolute_error: 6.4980 - val_root_mean_squared_error: 12.0432 - val_mean_absolute_percentage_error: 40.3151
# Epoch 60/100
# 103/103 [==============================] - 27s 262ms/step - loss: 1.3333 - mean_absolute_error: 0.6898 - root_mean_squared_error: 1.1547 - mean_absolute_percentage_error: 4.5402 - val_loss: 143.5999 - val_mean_absolute_error: 6.4008 - val_root_mean_squared_error: 11.9833 - val_mean_absolute_percentage_error: 40.0614
# Epoch 61/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.2457 - mean_absolute_error: 0.6726 - root_mean_squared_error: 1.1161 - mean_absolute_percentage_error: 4.5289 - val_loss: 145.6347 - val_mean_absolute_error: 6.5284 - val_root_mean_squared_error: 12.0679 - val_mean_absolute_percentage_error: 40.2191
# Epoch 62/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.2121 - mean_absolute_error: 0.6799 - root_mean_squared_error: 1.1009 - mean_absolute_percentage_error: 4.4900 - val_loss: 143.2626 - val_mean_absolute_error: 6.3756 - val_root_mean_squared_error: 11.9692 - val_mean_absolute_percentage_error: 39.9557
# Epoch 63/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.1349 - mean_absolute_error: 0.6514 - root_mean_squared_error: 1.0653 - mean_absolute_percentage_error: 4.3328 - val_loss: 142.9280 - val_mean_absolute_error: 6.4531 - val_root_mean_squared_error: 11.9553 - val_mean_absolute_percentage_error: 41.3333
# Epoch 64/100
# 103/103 [==============================] - 27s 262ms/step - loss: 1.1178 - mean_absolute_error: 0.6346 - root_mean_squared_error: 1.0573 - mean_absolute_percentage_error: 4.2456 - val_loss: 143.8588 - val_mean_absolute_error: 6.4481 - val_root_mean_squared_error: 11.9941 - val_mean_absolute_percentage_error: 40.9667
# Epoch 65/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.0812 - mean_absolute_error: 0.6347 - root_mean_squared_error: 1.0398 - mean_absolute_percentage_error: 4.1271 - val_loss: 142.6237 - val_mean_absolute_error: 6.3599 - val_root_mean_squared_error: 11.9425 - val_mean_absolute_percentage_error: 40.8065
# Epoch 66/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.9757 - mean_absolute_error: 0.5976 - root_mean_squared_error: 0.9878 - mean_absolute_percentage_error: 3.9806 - val_loss: 140.9971 - val_mean_absolute_error: 6.3007 - val_root_mean_squared_error: 11.8742 - val_mean_absolute_percentage_error: 39.2612
# Epoch 67/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.9978 - mean_absolute_error: 0.5979 - root_mean_squared_error: 0.9989 - mean_absolute_percentage_error: 3.7717 - val_loss: 140.7615 - val_mean_absolute_error: 6.2667 - val_root_mean_squared_error: 11.8643 - val_mean_absolute_percentage_error: 38.4528
# Epoch 68/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.9286 - mean_absolute_error: 0.5731 - root_mean_squared_error: 0.9636 - mean_absolute_percentage_error: 3.7510 - val_loss: 142.4631 - val_mean_absolute_error: 6.3487 - val_root_mean_squared_error: 11.9358 - val_mean_absolute_percentage_error: 39.9176
# Epoch 69/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.0597 - mean_absolute_error: 0.6501 - root_mean_squared_error: 1.0294 - mean_absolute_percentage_error: 4.5446 - val_loss: 141.8361 - val_mean_absolute_error: 6.3344 - val_root_mean_squared_error: 11.9095 - val_mean_absolute_percentage_error: 39.9534
# Epoch 70/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.9565 - mean_absolute_error: 0.6187 - root_mean_squared_error: 0.9780 - mean_absolute_percentage_error: 4.1482 - val_loss: 139.0052 - val_mean_absolute_error: 6.2989 - val_root_mean_squared_error: 11.7900 - val_mean_absolute_percentage_error: 40.2391
# Epoch 71/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.4142 - mean_absolute_error: 0.7178 - root_mean_squared_error: 1.1892 - mean_absolute_percentage_error: 4.6197 - val_loss: 141.1611 - val_mean_absolute_error: 6.3905 - val_root_mean_squared_error: 11.8811 - val_mean_absolute_percentage_error: 40.2466
# Epoch 72/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.2897 - mean_absolute_error: 0.7349 - root_mean_squared_error: 1.1357 - mean_absolute_percentage_error: 4.8485 - val_loss: 144.0662 - val_mean_absolute_error: 6.3583 - val_root_mean_squared_error: 12.0028 - val_mean_absolute_percentage_error: 39.0702
# Epoch 73/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.6800 - mean_absolute_error: 0.7984 - root_mean_squared_error: 1.2962 - mean_absolute_percentage_error: 5.4312 - val_loss: 141.6988 - val_mean_absolute_error: 6.4580 - val_root_mean_squared_error: 11.9037 - val_mean_absolute_percentage_error: 39.8602
# Epoch 74/100
# 103/103 [==============================] - 27s 259ms/step - loss: 2.5552 - mean_absolute_error: 1.0775 - root_mean_squared_error: 1.5985 - mean_absolute_percentage_error: 7.0526 - val_loss: 140.7115 - val_mean_absolute_error: 6.4155 - val_root_mean_squared_error: 11.8622 - val_mean_absolute_percentage_error: 39.1848
# Epoch 75/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.9586 - mean_absolute_error: 0.9374 - root_mean_squared_error: 1.3995 - mean_absolute_percentage_error: 5.9485 - val_loss: 138.8288 - val_mean_absolute_error: 6.3427 - val_root_mean_squared_error: 11.7826 - val_mean_absolute_percentage_error: 40.2700
# Epoch 76/100
# 103/103 [==============================] - 27s 259ms/step - loss: 1.6588 - mean_absolute_error: 0.8900 - root_mean_squared_error: 1.2879 - mean_absolute_percentage_error: 5.6758 - val_loss: 137.6241 - val_mean_absolute_error: 6.2761 - val_root_mean_squared_error: 11.7313 - val_mean_absolute_percentage_error: 39.0449
# Epoch 77/100
# 103/103 [==============================] - 27s 260ms/step - loss: 1.1066 - mean_absolute_error: 0.6916 - root_mean_squared_error: 1.0519 - mean_absolute_percentage_error: 4.4155 - val_loss: 136.6802 - val_mean_absolute_error: 6.2263 - val_root_mean_squared_error: 11.6910 - val_mean_absolute_percentage_error: 38.8519
# Epoch 78/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.8240 - mean_absolute_error: 0.5995 - root_mean_squared_error: 0.9077 - mean_absolute_percentage_error: 4.0905 - val_loss: 139.5734 - val_mean_absolute_error: 6.2793 - val_root_mean_squared_error: 11.8141 - val_mean_absolute_percentage_error: 39.3497
# Epoch 79/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.7239 - mean_absolute_error: 0.5589 - root_mean_squared_error: 0.8508 - mean_absolute_percentage_error: 3.8676 - val_loss: 137.6686 - val_mean_absolute_error: 6.2116 - val_root_mean_squared_error: 11.7332 - val_mean_absolute_percentage_error: 38.5033
# Epoch 80/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.6271 - mean_absolute_error: 0.5043 - root_mean_squared_error: 0.7919 - mean_absolute_percentage_error: 3.3991 - val_loss: 137.2012 - val_mean_absolute_error: 6.1724 - val_root_mean_squared_error: 11.7133 - val_mean_absolute_percentage_error: 37.8562
# Epoch 81/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.6801 - mean_absolute_error: 0.5246 - root_mean_squared_error: 0.8247 - mean_absolute_percentage_error: 3.3213 - val_loss: 139.8682 - val_mean_absolute_error: 6.2036 - val_root_mean_squared_error: 11.8266 - val_mean_absolute_percentage_error: 38.0544
# Epoch 82/100
# 103/103 [==============================] - 27s 262ms/step - loss: 0.6282 - mean_absolute_error: 0.4976 - root_mean_squared_error: 0.7926 - mean_absolute_percentage_error: 3.2535 - val_loss: 139.6242 - val_mean_absolute_error: 6.2624 - val_root_mean_squared_error: 11.8163 - val_mean_absolute_percentage_error: 39.5871
# Epoch 83/100
# 103/103 [==============================] - 27s 259ms/step - loss: 0.7837 - mean_absolute_error: 0.5446 - root_mean_squared_error: 0.8852 - mean_absolute_percentage_error: 3.4267 - val_loss: 140.0915 - val_mean_absolute_error: 6.1987 - val_root_mean_squared_error: 11.8360 - val_mean_absolute_percentage_error: 37.7468
# Epoch 84/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.7756 - mean_absolute_error: 0.5802 - root_mean_squared_error: 0.8807 - mean_absolute_percentage_error: 3.9003 - val_loss: 141.8867 - val_mean_absolute_error: 6.3219 - val_root_mean_squared_error: 11.9116 - val_mean_absolute_percentage_error: 40.0141
# Epoch 85/100
# 103/103 [==============================] - 27s 262ms/step - loss: 0.6874 - mean_absolute_error: 0.5605 - root_mean_squared_error: 0.8291 - mean_absolute_percentage_error: 3.7254 - val_loss: 143.6258 - val_mean_absolute_error: 6.3784 - val_root_mean_squared_error: 11.9844 - val_mean_absolute_percentage_error: 39.8303
# Epoch 86/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.1898 - mean_absolute_error: 0.6584 - root_mean_squared_error: 1.0908 - mean_absolute_percentage_error: 4.1753 - val_loss: 139.4747 - val_mean_absolute_error: 6.2266 - val_root_mean_squared_error: 11.8099 - val_mean_absolute_percentage_error: 38.1240
# Epoch 87/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.9561 - mean_absolute_error: 0.6445 - root_mean_squared_error: 0.9778 - mean_absolute_percentage_error: 4.0606 - val_loss: 140.3256 - val_mean_absolute_error: 6.2694 - val_root_mean_squared_error: 11.8459 - val_mean_absolute_percentage_error: 39.0895
# Epoch 88/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.7760 - mean_absolute_error: 0.5852 - root_mean_squared_error: 0.8809 - mean_absolute_percentage_error: 3.7261 - val_loss: 139.8100 - val_mean_absolute_error: 6.2171 - val_root_mean_squared_error: 11.8241 - val_mean_absolute_percentage_error: 38.6067
# Epoch 89/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.8551 - mean_absolute_error: 0.6099 - root_mean_squared_error: 0.9247 - mean_absolute_percentage_error: 3.9985 - val_loss: 137.6105 - val_mean_absolute_error: 6.2541 - val_root_mean_squared_error: 11.7307 - val_mean_absolute_percentage_error: 38.9090
# Epoch 90/100
# 103/103 [==============================] - 27s 259ms/step - loss: 0.7900 - mean_absolute_error: 0.5993 - root_mean_squared_error: 0.8888 - mean_absolute_percentage_error: 3.8159 - val_loss: 138.5918 - val_mean_absolute_error: 6.1507 - val_root_mean_squared_error: 11.7725 - val_mean_absolute_percentage_error: 37.5503
# Epoch 91/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.6753 - mean_absolute_error: 0.5577 - root_mean_squared_error: 0.8218 - mean_absolute_percentage_error: 3.5194 - val_loss: 139.2447 - val_mean_absolute_error: 6.2559 - val_root_mean_squared_error: 11.8002 - val_mean_absolute_percentage_error: 39.4511
# Epoch 92/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.6577 - mean_absolute_error: 0.5371 - root_mean_squared_error: 0.8110 - mean_absolute_percentage_error: 3.3235 - val_loss: 141.6653 - val_mean_absolute_error: 6.1938 - val_root_mean_squared_error: 11.9023 - val_mean_absolute_percentage_error: 37.9015
# Epoch 93/100
# 103/103 [==============================] - 27s 259ms/step - loss: 0.5622 - mean_absolute_error: 0.4863 - root_mean_squared_error: 0.7498 - mean_absolute_percentage_error: 3.1119 - val_loss: 141.8127 - val_mean_absolute_error: 6.2473 - val_root_mean_squared_error: 11.9085 - val_mean_absolute_percentage_error: 38.7019
# Epoch 94/100
# 103/103 [==============================] - 27s 261ms/step - loss: 1.4861 - mean_absolute_error: 0.7304 - root_mean_squared_error: 1.2190 - mean_absolute_percentage_error: 4.9009 - val_loss: 135.3409 - val_mean_absolute_error: 6.2383 - val_root_mean_squared_error: 11.6336 - val_mean_absolute_percentage_error: 38.5879
# Epoch 95/100
# 103/103 [==============================] - 27s 261ms/step - loss: 2.1957 - mean_absolute_error: 1.0098 - root_mean_squared_error: 1.4818 - mean_absolute_percentage_error: 6.9212 - val_loss: 146.2324 - val_mean_absolute_error: 6.6405 - val_root_mean_squared_error: 12.0927 - val_mean_absolute_percentage_error: 39.3017
# Epoch 96/100
# 103/103 [==============================] - 27s 261ms/step - loss: 2.4123 - mean_absolute_error: 1.0862 - root_mean_squared_error: 1.5531 - mean_absolute_percentage_error: 7.7179 - val_loss: 147.7921 - val_mean_absolute_error: 6.5551 - val_root_mean_squared_error: 12.1570 - val_mean_absolute_percentage_error: 40.9679
# Epoch 97/100
# 103/103 [==============================] - 27s 262ms/step - loss: 1.1962 - mean_absolute_error: 0.7883 - root_mean_squared_error: 1.0937 - mean_absolute_percentage_error: 5.3933 - val_loss: 139.0488 - val_mean_absolute_error: 6.1555 - val_root_mean_squared_error: 11.7919 - val_mean_absolute_percentage_error: 37.4441
# Epoch 98/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.7010 - mean_absolute_error: 0.6023 - root_mean_squared_error: 0.8373 - mean_absolute_percentage_error: 3.8690 - val_loss: 140.5316 - val_mean_absolute_error: 6.1731 - val_root_mean_squared_error: 11.8546 - val_mean_absolute_percentage_error: 38.4747
# Epoch 99/100
# 103/103 [==============================] - 27s 261ms/step - loss: 0.4440 - mean_absolute_error: 0.4497 - root_mean_squared_error: 0.6664 - mean_absolute_percentage_error: 3.0982 - val_loss: 138.2776 - val_mean_absolute_error: 6.0703 - val_root_mean_squared_error: 11.7592 - val_mean_absolute_percentage_error: 37.3567
# Epoch 100/100
# 103/103 [==============================] - 27s 263ms/step - loss: 0.3568 - mean_absolute_error: 0.3684 - root_mean_squared_error: 0.5973 - mean_absolute_percentage_error: 2.3879 - val_loss: 139.0743 - val_mean_absolute_error: 6.0822 - val_root_mean_squared_error: 11.7930 - val_mean_absolute_percentage_error: 37.5520

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 117ms/step - loss: 139.0743 - mean_absolute_error: 6.0822 - root_mean_squared_error: 11.7930 - mean_absolute_percentage_error: 37.5520
# Model Loss: [139.0742645263672, 6.08224630355835, 11.792975425720215, 37.55196762084961]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [26.058058]

# %%
model_scenario_name = "BiLSTM_6"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_6\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_6\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_6"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [26.058058]
