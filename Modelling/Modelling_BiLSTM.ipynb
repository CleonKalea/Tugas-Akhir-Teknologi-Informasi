# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_36716\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output_2)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(lstm_output_3)
lstm_output_4 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(dropout_layer_1)
lstm_output_5 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, kernel_regularizer=tf.keras.regularizers.l2(0.0001)))(lstm_output_4)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.0001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([lstm_output_5, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 128)    164352      ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 1024, 256)   263168      ['bidirectional[0][0]']
#  )
#
#  bidirectional_2 (Bidirectional  (None, 1024, 128)   164352      ['bidirectional_1[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  dropout (Dropout)              (None, 1024, 128)    0           ['bidirectional_2[0][0]']
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_3 (Bidirectional  (None, 1024, 64)    41216       ['dropout[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  bidirectional_4 (Bidirectional  (None, 64)          24832       ['bidirectional_3[0][0]']
#  )
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['bidirectional_4[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 5,368,673
# Trainable params: 5,368,481
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 58s 484ms/step - loss: 20.7620 - mean_absolute_error: 21.1042 - root_mean_squared_error: 32.2868 - mean_absolute_percentage_error: 84.6257 - val_loss: 14.8218 - val_mean_absolute_error: 15.1749 - val_root_mean_squared_error: 22.1822 - val_mean_absolute_percentage_error: 97.0222
# Epoch 2/100
# 103/103 [==============================] - 52s 502ms/step - loss: 12.4254 - mean_absolute_error: 12.7757 - root_mean_squared_error: 18.9734 - mean_absolute_percentage_error: 73.8561 - val_loss: 12.5975 - val_mean_absolute_error: 12.9486 - val_root_mean_squared_error: 19.4657 - val_mean_absolute_percentage_error: 77.5875
# Epoch 3/100
# 103/103 [==============================] - 53s 510ms/step - loss: 10.9123 - mean_absolute_error: 11.2597 - root_mean_squared_error: 17.2951 - mean_absolute_percentage_error: 63.9175 - val_loss: 15.2506 - val_mean_absolute_error: 15.6046 - val_root_mean_squared_error: 21.5636 - val_mean_absolute_percentage_error: 92.3103
# Epoch 4/100
# 103/103 [==============================] - 53s 514ms/step - loss: 9.7962 - mean_absolute_error: 10.1413 - root_mean_squared_error: 15.7929 - mean_absolute_percentage_error: 51.1225 - val_loss: 9.7877 - val_mean_absolute_error: 10.1285 - val_root_mean_squared_error: 15.5264 - val_mean_absolute_percentage_error: 49.1582
# Epoch 5/100
# 103/103 [==============================] - 52s 506ms/step - loss: 8.2214 - mean_absolute_error: 8.5623 - root_mean_squared_error: 13.3483 - mean_absolute_percentage_error: 42.7390 - val_loss: 9.5628 - val_mean_absolute_error: 9.9070 - val_root_mean_squared_error: 15.6618 - val_mean_absolute_percentage_error: 48.2948
# Epoch 6/100
# 103/103 [==============================] - 53s 517ms/step - loss: 7.9252 - mean_absolute_error: 8.2633 - root_mean_squared_error: 12.8363 - mean_absolute_percentage_error: 38.5289 - val_loss: 8.7305 - val_mean_absolute_error: 9.0649 - val_root_mean_squared_error: 14.4038 - val_mean_absolute_percentage_error: 42.8059
# Epoch 7/100
# 103/103 [==============================] - 50s 484ms/step - loss: 7.0217 - mean_absolute_error: 7.3525 - root_mean_squared_error: 11.9723 - mean_absolute_percentage_error: 33.5686 - val_loss: 8.2172 - val_mean_absolute_error: 8.5537 - val_root_mean_squared_error: 13.9090 - val_mean_absolute_percentage_error: 43.1658
# Epoch 8/100
# 103/103 [==============================] - 50s 490ms/step - loss: 6.5226 - mean_absolute_error: 6.8506 - root_mean_squared_error: 10.9127 - mean_absolute_percentage_error: 30.9544 - val_loss: 8.5552 - val_mean_absolute_error: 8.8869 - val_root_mean_squared_error: 14.8884 - val_mean_absolute_percentage_error: 38.6584
# Epoch 9/100
# 103/103 [==============================] - 54s 523ms/step - loss: 5.9762 - mean_absolute_error: 6.3048 - root_mean_squared_error: 10.0651 - mean_absolute_percentage_error: 29.1228 - val_loss: 8.6529 - val_mean_absolute_error: 8.9885 - val_root_mean_squared_error: 14.6586 - val_mean_absolute_percentage_error: 35.8402
# Epoch 10/100
# 103/103 [==============================] - 51s 493ms/step - loss: 5.3740 - mean_absolute_error: 5.6985 - root_mean_squared_error: 9.1849 - mean_absolute_percentage_error: 26.8125 - val_loss: 7.8470 - val_mean_absolute_error: 8.1805 - val_root_mean_squared_error: 13.1588 - val_mean_absolute_percentage_error: 48.4097
# Epoch 11/100
# 103/103 [==============================] - 55s 540ms/step - loss: 5.2773 - mean_absolute_error: 5.6065 - root_mean_squared_error: 8.9766 - mean_absolute_percentage_error: 26.1015 - val_loss: 6.8351 - val_mean_absolute_error: 7.1671 - val_root_mean_squared_error: 12.3559 - val_mean_absolute_percentage_error: 38.2307
# Epoch 12/100
# 103/103 [==============================] - 54s 524ms/step - loss: 5.5099 - mean_absolute_error: 5.8412 - root_mean_squared_error: 9.2722 - mean_absolute_percentage_error: 26.8122 - val_loss: 8.5580 - val_mean_absolute_error: 8.9045 - val_root_mean_squared_error: 13.5142 - val_mean_absolute_percentage_error: 49.7005
# Epoch 13/100
# 103/103 [==============================] - 53s 518ms/step - loss: 5.0952 - mean_absolute_error: 5.4242 - root_mean_squared_error: 8.7712 - mean_absolute_percentage_error: 23.7739 - val_loss: 8.1971 - val_mean_absolute_error: 8.5472 - val_root_mean_squared_error: 13.2043 - val_mean_absolute_percentage_error: 51.8321
# Epoch 14/100
# 103/103 [==============================] - 52s 505ms/step - loss: 4.9325 - mean_absolute_error: 5.2602 - root_mean_squared_error: 8.5730 - mean_absolute_percentage_error: 23.1931 - val_loss: 7.8581 - val_mean_absolute_error: 8.2080 - val_root_mean_squared_error: 12.8273 - val_mean_absolute_percentage_error: 50.3736
# Epoch 15/100
# 103/103 [==============================] - 55s 537ms/step - loss: 4.7334 - mean_absolute_error: 5.0620 - root_mean_squared_error: 8.1658 - mean_absolute_percentage_error: 22.3563 - val_loss: 7.7291 - val_mean_absolute_error: 8.0718 - val_root_mean_squared_error: 13.4914 - val_mean_absolute_percentage_error: 36.9984
# Epoch 16/100
# 103/103 [==============================] - 55s 531ms/step - loss: 4.7128 - mean_absolute_error: 5.0452 - root_mean_squared_error: 7.9304 - mean_absolute_percentage_error: 22.4424 - val_loss: 15.7189 - val_mean_absolute_error: 16.0746 - val_root_mean_squared_error: 22.6140 - val_mean_absolute_percentage_error: 47.9630
# Epoch 17/100
# 103/103 [==============================] - 52s 507ms/step - loss: 4.6647 - mean_absolute_error: 4.9963 - root_mean_squared_error: 7.9880 - mean_absolute_percentage_error: 21.8954 - val_loss: 6.7972 - val_mean_absolute_error: 7.1339 - val_root_mean_squared_error: 12.3226 - val_mean_absolute_percentage_error: 34.1025
# Epoch 18/100
# 103/103 [==============================] - 55s 533ms/step - loss: 4.5015 - mean_absolute_error: 4.8344 - root_mean_squared_error: 7.7209 - mean_absolute_percentage_error: 21.1720 - val_loss: 8.0366 - val_mean_absolute_error: 8.3915 - val_root_mean_squared_error: 12.9716 - val_mean_absolute_percentage_error: 49.1169
# Epoch 19/100
# 103/103 [==============================] - 54s 525ms/step - loss: 4.1542 - mean_absolute_error: 4.4838 - root_mean_squared_error: 7.1140 - mean_absolute_percentage_error: 20.0198 - val_loss: 8.6829 - val_mean_absolute_error: 9.0397 - val_root_mean_squared_error: 14.3499 - val_mean_absolute_percentage_error: 35.0670
# Epoch 20/100
# 103/103 [==============================] - 54s 520ms/step - loss: 4.3325 - mean_absolute_error: 4.6681 - root_mean_squared_error: 7.4109 - mean_absolute_percentage_error: 19.9013 - val_loss: 6.9766 - val_mean_absolute_error: 7.3158 - val_root_mean_squared_error: 12.2504 - val_mean_absolute_percentage_error: 38.1979
# Epoch 21/100
# 103/103 [==============================] - 54s 528ms/step - loss: 3.9579 - mean_absolute_error: 4.2918 - root_mean_squared_error: 6.9313 - mean_absolute_percentage_error: 19.4679 - val_loss: 6.6570 - val_mean_absolute_error: 6.9970 - val_root_mean_squared_error: 12.1616 - val_mean_absolute_percentage_error: 39.4132
# Epoch 22/100
# 103/103 [==============================] - 53s 512ms/step - loss: 4.0730 - mean_absolute_error: 4.4083 - root_mean_squared_error: 6.8773 - mean_absolute_percentage_error: 19.5402 - val_loss: 8.7695 - val_mean_absolute_error: 9.1130 - val_root_mean_squared_error: 14.4868 - val_mean_absolute_percentage_error: 35.3833
# Epoch 23/100
# 103/103 [==============================] - 51s 495ms/step - loss: 4.2519 - mean_absolute_error: 4.5898 - root_mean_squared_error: 7.4082 - mean_absolute_percentage_error: 19.8043 - val_loss: 9.2171 - val_mean_absolute_error: 9.5751 - val_root_mean_squared_error: 14.1040 - val_mean_absolute_percentage_error: 44.4070
# Epoch 24/100
# 103/103 [==============================] - 51s 492ms/step - loss: 3.8132 - mean_absolute_error: 4.1453 - root_mean_squared_error: 6.6249 - mean_absolute_percentage_error: 18.3044 - val_loss: 7.2011 - val_mean_absolute_error: 7.5559 - val_root_mean_squared_error: 13.0461 - val_mean_absolute_percentage_error: 32.4642
# Epoch 25/100
# 103/103 [==============================] - 50s 486ms/step - loss: 4.1190 - mean_absolute_error: 4.4563 - root_mean_squared_error: 7.4528 - mean_absolute_percentage_error: 18.1839 - val_loss: 7.3374 - val_mean_absolute_error: 7.6904 - val_root_mean_squared_error: 12.4365 - val_mean_absolute_percentage_error: 42.8404
# Epoch 26/100
# 103/103 [==============================] - 50s 487ms/step - loss: 3.7917 - mean_absolute_error: 4.1268 - root_mean_squared_error: 6.4675 - mean_absolute_percentage_error: 18.0728 - val_loss: 6.6465 - val_mean_absolute_error: 7.0009 - val_root_mean_squared_error: 11.9800 - val_mean_absolute_percentage_error: 36.5281
# Epoch 27/100
# 103/103 [==============================] - 50s 490ms/step - loss: 3.5878 - mean_absolute_error: 3.9205 - root_mean_squared_error: 6.2196 - mean_absolute_percentage_error: 16.9405 - val_loss: 6.3303 - val_mean_absolute_error: 6.6743 - val_root_mean_squared_error: 11.9301 - val_mean_absolute_percentage_error: 35.8427
# Epoch 28/100
# 103/103 [==============================] - 51s 492ms/step - loss: 3.7340 - mean_absolute_error: 4.0723 - root_mean_squared_error: 6.4185 - mean_absolute_percentage_error: 17.3548 - val_loss: 6.4471 - val_mean_absolute_error: 6.8023 - val_root_mean_squared_error: 11.9417 - val_mean_absolute_percentage_error: 32.9475
# Epoch 29/100
# 103/103 [==============================] - 50s 488ms/step - loss: 3.6389 - mean_absolute_error: 3.9770 - root_mean_squared_error: 6.2747 - mean_absolute_percentage_error: 17.4079 - val_loss: 6.6329 - val_mean_absolute_error: 6.9759 - val_root_mean_squared_error: 12.4113 - val_mean_absolute_percentage_error: 32.5977
# Epoch 30/100
# 103/103 [==============================] - 50s 491ms/step - loss: 3.4291 - mean_absolute_error: 3.7711 - root_mean_squared_error: 5.6677 - mean_absolute_percentage_error: 17.1661 - val_loss: 8.2794 - val_mean_absolute_error: 8.6408 - val_root_mean_squared_error: 13.0405 - val_mean_absolute_percentage_error: 43.5927
# Epoch 31/100
# 103/103 [==============================] - 51s 493ms/step - loss: 3.4645 - mean_absolute_error: 3.8042 - root_mean_squared_error: 5.8624 - mean_absolute_percentage_error: 16.8994 - val_loss: 8.5894 - val_mean_absolute_error: 8.9525 - val_root_mean_squared_error: 13.4029 - val_mean_absolute_percentage_error: 43.0115
# Epoch 32/100
# 103/103 [==============================] - 50s 490ms/step - loss: 3.3637 - mean_absolute_error: 3.6986 - root_mean_squared_error: 5.8394 - mean_absolute_percentage_error: 16.5889 - val_loss: 6.8308 - val_mean_absolute_error: 7.1909 - val_root_mean_squared_error: 12.1549 - val_mean_absolute_percentage_error: 39.4937
# Epoch 33/100
# 103/103 [==============================] - 50s 490ms/step - loss: 3.6475 - mean_absolute_error: 3.9889 - root_mean_squared_error: 6.1970 - mean_absolute_percentage_error: 18.2260 - val_loss: 6.9196 - val_mean_absolute_error: 7.2634 - val_root_mean_squared_error: 12.7152 - val_mean_absolute_percentage_error: 33.7198
# Epoch 34/100
# 103/103 [==============================] - 51s 491ms/step - loss: 3.2817 - mean_absolute_error: 3.6189 - root_mean_squared_error: 5.5423 - mean_absolute_percentage_error: 16.3886 - val_loss: 6.6991 - val_mean_absolute_error: 7.0537 - val_root_mean_squared_error: 12.2058 - val_mean_absolute_percentage_error: 33.3507
# Epoch 35/100
# 103/103 [==============================] - 51s 496ms/step - loss: 3.3785 - mean_absolute_error: 3.7186 - root_mean_squared_error: 5.7578 - mean_absolute_percentage_error: 17.4896 - val_loss: 6.2560 - val_mean_absolute_error: 6.5980 - val_root_mean_squared_error: 11.7262 - val_mean_absolute_percentage_error: 34.3970
# Epoch 36/100
# 103/103 [==============================] - 53s 514ms/step - loss: 3.0366 - mean_absolute_error: 3.3716 - root_mean_squared_error: 5.2101 - mean_absolute_percentage_error: 15.1333 - val_loss: 8.3208 - val_mean_absolute_error: 8.6756 - val_root_mean_squared_error: 13.2802 - val_mean_absolute_percentage_error: 45.2492
# Epoch 37/100
# 103/103 [==============================] - 52s 506ms/step - loss: 3.3165 - mean_absolute_error: 3.6538 - root_mean_squared_error: 5.6447 - mean_absolute_percentage_error: 15.8979 - val_loss: 7.9859 - val_mean_absolute_error: 8.3410 - val_root_mean_squared_error: 13.2001 - val_mean_absolute_percentage_error: 43.2571
# Epoch 38/100
# 103/103 [==============================] - 51s 493ms/step - loss: 3.2582 - mean_absolute_error: 3.5950 - root_mean_squared_error: 5.5604 - mean_absolute_percentage_error: 15.8483 - val_loss: 9.9617 - val_mean_absolute_error: 10.3337 - val_root_mean_squared_error: 14.5128 - val_mean_absolute_percentage_error: 54.1245
# Epoch 39/100
# 103/103 [==============================] - 52s 501ms/step - loss: 3.2283 - mean_absolute_error: 3.5599 - root_mean_squared_error: 5.5548 - mean_absolute_percentage_error: 15.5088 - val_loss: 6.4846 - val_mean_absolute_error: 6.8408 - val_root_mean_squared_error: 12.2065 - val_mean_absolute_percentage_error: 32.6703
# Epoch 40/100
# 103/103 [==============================] - 51s 495ms/step - loss: 3.1312 - mean_absolute_error: 3.4691 - root_mean_squared_error: 5.3762 - mean_absolute_percentage_error: 14.6934 - val_loss: 7.7977 - val_mean_absolute_error: 8.1592 - val_root_mean_squared_error: 12.7584 - val_mean_absolute_percentage_error: 40.5660
# Epoch 41/100
# 103/103 [==============================] - 53s 519ms/step - loss: 2.9083 - mean_absolute_error: 3.2440 - root_mean_squared_error: 5.0353 - mean_absolute_percentage_error: 13.8772 - val_loss: 6.8279 - val_mean_absolute_error: 7.1937 - val_root_mean_squared_error: 11.8503 - val_mean_absolute_percentage_error: 39.3692
# Epoch 42/100
# 103/103 [==============================] - 53s 514ms/step - loss: 3.2230 - mean_absolute_error: 3.5607 - root_mean_squared_error: 5.5447 - mean_absolute_percentage_error: 15.3681 - val_loss: 5.8965 - val_mean_absolute_error: 6.2412 - val_root_mean_squared_error: 11.4160 - val_mean_absolute_percentage_error: 33.4989
# Epoch 43/100
# 103/103 [==============================] - 51s 497ms/step - loss: 2.9633 - mean_absolute_error: 3.3021 - root_mean_squared_error: 5.3418 - mean_absolute_percentage_error: 13.9073 - val_loss: 6.6305 - val_mean_absolute_error: 6.9912 - val_root_mean_squared_error: 12.0932 - val_mean_absolute_percentage_error: 33.6162
# Epoch 44/100
# 103/103 [==============================] - 52s 508ms/step - loss: 3.2350 - mean_absolute_error: 3.5774 - root_mean_squared_error: 5.5487 - mean_absolute_percentage_error: 15.1990 - val_loss: 6.7093 - val_mean_absolute_error: 7.0704 - val_root_mean_squared_error: 12.0400 - val_mean_absolute_percentage_error: 37.4423
# Epoch 45/100
# 103/103 [==============================] - 52s 502ms/step - loss: 2.8575 - mean_absolute_error: 3.1952 - root_mean_squared_error: 4.9081 - mean_absolute_percentage_error: 13.8416 - val_loss: 6.3322 - val_mean_absolute_error: 6.6831 - val_root_mean_squared_error: 11.9808 - val_mean_absolute_percentage_error: 33.5867
# Epoch 46/100
# 103/103 [==============================] - 55s 532ms/step - loss: 2.7996 - mean_absolute_error: 3.1394 - root_mean_squared_error: 4.9836 - mean_absolute_percentage_error: 13.9993 - val_loss: 6.1566 - val_mean_absolute_error: 6.5041 - val_root_mean_squared_error: 11.5251 - val_mean_absolute_percentage_error: 35.3059
# Epoch 47/100
# 103/103 [==============================] - 53s 514ms/step - loss: 3.2587 - mean_absolute_error: 3.6021 - root_mean_squared_error: 5.5998 - mean_absolute_percentage_error: 14.8896 - val_loss: 6.4111 - val_mean_absolute_error: 6.7652 - val_root_mean_squared_error: 11.8892 - val_mean_absolute_percentage_error: 34.9246
# Epoch 48/100
# 103/103 [==============================] - 51s 497ms/step - loss: 2.7939 - mean_absolute_error: 3.1285 - root_mean_squared_error: 4.8372 - mean_absolute_percentage_error: 13.1638 - val_loss: 6.9662 - val_mean_absolute_error: 7.3267 - val_root_mean_squared_error: 12.2136 - val_mean_absolute_percentage_error: 38.4900
# Epoch 49/100
# 103/103 [==============================] - 53s 512ms/step - loss: 2.8503 - mean_absolute_error: 3.1876 - root_mean_squared_error: 5.0503 - mean_absolute_percentage_error: 13.2209 - val_loss: 6.8727 - val_mean_absolute_error: 7.2340 - val_root_mean_squared_error: 12.0834 - val_mean_absolute_percentage_error: 37.4727
# Epoch 50/100
# 103/103 [==============================] - 51s 496ms/step - loss: 2.6354 - mean_absolute_error: 2.9709 - root_mean_squared_error: 4.5881 - mean_absolute_percentage_error: 12.8386 - val_loss: 6.6580 - val_mean_absolute_error: 7.0136 - val_root_mean_squared_error: 12.2949 - val_mean_absolute_percentage_error: 34.5641
# Epoch 51/100
# 103/103 [==============================] - 51s 494ms/step - loss: 3.0958 - mean_absolute_error: 3.4424 - root_mean_squared_error: 5.2666 - mean_absolute_percentage_error: 15.9160 - val_loss: 6.4903 - val_mean_absolute_error: 6.8511 - val_root_mean_squared_error: 11.8921 - val_mean_absolute_percentage_error: 36.3842
# Epoch 52/100
# 103/103 [==============================] - 51s 494ms/step - loss: 2.7873 - mean_absolute_error: 3.1267 - root_mean_squared_error: 4.9544 - mean_absolute_percentage_error: 13.1839 - val_loss: 6.1219 - val_mean_absolute_error: 6.4771 - val_root_mean_squared_error: 11.6979 - val_mean_absolute_percentage_error: 31.8048
# Epoch 53/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.8210 - mean_absolute_error: 3.1568 - root_mean_squared_error: 5.0545 - mean_absolute_percentage_error: 12.6586 - val_loss: 6.5848 - val_mean_absolute_error: 6.9412 - val_root_mean_squared_error: 12.2216 - val_mean_absolute_percentage_error: 33.8494
# Epoch 54/100
# 103/103 [==============================] - 51s 492ms/step - loss: 2.8157 - mean_absolute_error: 3.1497 - root_mean_squared_error: 5.0207 - mean_absolute_percentage_error: 12.3807 - val_loss: 6.2168 - val_mean_absolute_error: 6.5596 - val_root_mean_squared_error: 11.9046 - val_mean_absolute_percentage_error: 33.1589
# Epoch 55/100
# 103/103 [==============================] - 51s 493ms/step - loss: 2.7597 - mean_absolute_error: 3.0908 - root_mean_squared_error: 5.0691 - mean_absolute_percentage_error: 12.0322 - val_loss: 6.8827 - val_mean_absolute_error: 7.2368 - val_root_mean_squared_error: 12.1377 - val_mean_absolute_percentage_error: 35.7966
# Epoch 56/100
# 103/103 [==============================] - 51s 493ms/step - loss: 2.5905 - mean_absolute_error: 2.9252 - root_mean_squared_error: 4.5766 - mean_absolute_percentage_error: 11.9962 - val_loss: 6.0479 - val_mean_absolute_error: 6.3996 - val_root_mean_squared_error: 11.6297 - val_mean_absolute_percentage_error: 33.7684
# Epoch 57/100
# 103/103 [==============================] - 53s 519ms/step - loss: 2.6716 - mean_absolute_error: 3.0072 - root_mean_squared_error: 4.9077 - mean_absolute_percentage_error: 11.8682 - val_loss: 6.1403 - val_mean_absolute_error: 6.4987 - val_root_mean_squared_error: 11.7017 - val_mean_absolute_percentage_error: 32.0698
# Epoch 58/100
# 103/103 [==============================] - 52s 506ms/step - loss: 2.5815 - mean_absolute_error: 2.9193 - root_mean_squared_error: 4.6456 - mean_absolute_percentage_error: 11.6945 - val_loss: 6.1383 - val_mean_absolute_error: 6.4969 - val_root_mean_squared_error: 11.9469 - val_mean_absolute_percentage_error: 31.4728
# Epoch 59/100
# 103/103 [==============================] - 51s 493ms/step - loss: 2.5286 - mean_absolute_error: 2.8636 - root_mean_squared_error: 4.5535 - mean_absolute_percentage_error: 11.1697 - val_loss: 8.2335 - val_mean_absolute_error: 8.6032 - val_root_mean_squared_error: 13.4216 - val_mean_absolute_percentage_error: 39.1679
# Epoch 60/100
# 103/103 [==============================] - 51s 495ms/step - loss: 2.7531 - mean_absolute_error: 3.0927 - root_mean_squared_error: 4.8946 - mean_absolute_percentage_error: 11.8610 - val_loss: 6.2928 - val_mean_absolute_error: 6.6515 - val_root_mean_squared_error: 12.0043 - val_mean_absolute_percentage_error: 31.8511
# Epoch 61/100
# 103/103 [==============================] - 51s 495ms/step - loss: 2.5443 - mean_absolute_error: 2.8811 - root_mean_squared_error: 4.6144 - mean_absolute_percentage_error: 11.4667 - val_loss: 5.9208 - val_mean_absolute_error: 6.2694 - val_root_mean_squared_error: 11.8090 - val_mean_absolute_percentage_error: 32.1288
# Epoch 62/100
# 103/103 [==============================] - 50s 489ms/step - loss: 2.4128 - mean_absolute_error: 2.7502 - root_mean_squared_error: 4.4230 - mean_absolute_percentage_error: 11.0372 - val_loss: 6.1417 - val_mean_absolute_error: 6.5024 - val_root_mean_squared_error: 11.8886 - val_mean_absolute_percentage_error: 33.4412
# Epoch 63/100
# 103/103 [==============================] - 58s 569ms/step - loss: 2.6667 - mean_absolute_error: 3.0114 - root_mean_squared_error: 4.7807 - mean_absolute_percentage_error: 11.8436 - val_loss: 5.9603 - val_mean_absolute_error: 6.3235 - val_root_mean_squared_error: 11.6830 - val_mean_absolute_percentage_error: 33.8151
# Epoch 64/100
# 103/103 [==============================] - 52s 505ms/step - loss: 2.5758 - mean_absolute_error: 2.9154 - root_mean_squared_error: 4.6661 - mean_absolute_percentage_error: 11.5059 - val_loss: 7.2134 - val_mean_absolute_error: 7.5770 - val_root_mean_squared_error: 12.4851 - val_mean_absolute_percentage_error: 38.4323
# Epoch 65/100
# 103/103 [==============================] - 51s 498ms/step - loss: 2.5508 - mean_absolute_error: 2.8902 - root_mean_squared_error: 4.6145 - mean_absolute_percentage_error: 10.9911 - val_loss: 6.4973 - val_mean_absolute_error: 6.8640 - val_root_mean_squared_error: 12.1796 - val_mean_absolute_percentage_error: 30.5715
# Epoch 66/100
# 103/103 [==============================] - 52s 509ms/step - loss: 2.6453 - mean_absolute_error: 2.9875 - root_mean_squared_error: 4.7735 - mean_absolute_percentage_error: 11.5748 - val_loss: 6.6762 - val_mean_absolute_error: 7.0499 - val_root_mean_squared_error: 12.3091 - val_mean_absolute_percentage_error: 32.8061
# Epoch 67/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.5221 - mean_absolute_error: 2.8575 - root_mean_squared_error: 4.9204 - mean_absolute_percentage_error: 10.6109 - val_loss: 6.2496 - val_mean_absolute_error: 6.5977 - val_root_mean_squared_error: 11.7407 - val_mean_absolute_percentage_error: 31.3721
# Epoch 68/100
# 103/103 [==============================] - 51s 493ms/step - loss: 2.4242 - mean_absolute_error: 2.7616 - root_mean_squared_error: 4.4637 - mean_absolute_percentage_error: 11.0376 - val_loss: 6.1158 - val_mean_absolute_error: 6.4705 - val_root_mean_squared_error: 12.0544 - val_mean_absolute_percentage_error: 34.2553
# Epoch 69/100
# 103/103 [==============================] - 51s 493ms/step - loss: 2.5158 - mean_absolute_error: 2.8608 - root_mean_squared_error: 4.6290 - mean_absolute_percentage_error: 11.2612 - val_loss: 11.8031 - val_mean_absolute_error: 12.1815 - val_root_mean_squared_error: 16.6982 - val_mean_absolute_percentage_error: 113.6426
# Epoch 70/100
# 103/103 [==============================] - 50s 490ms/step - loss: 2.3298 - mean_absolute_error: 2.6703 - root_mean_squared_error: 4.1350 - mean_absolute_percentage_error: 11.7215 - val_loss: 7.4209 - val_mean_absolute_error: 7.7915 - val_root_mean_squared_error: 13.0890 - val_mean_absolute_percentage_error: 38.5239
# Epoch 71/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.7696 - mean_absolute_error: 3.1111 - root_mean_squared_error: 5.0056 - mean_absolute_percentage_error: 12.0038 - val_loss: 5.9976 - val_mean_absolute_error: 6.3566 - val_root_mean_squared_error: 11.8469 - val_mean_absolute_percentage_error: 32.9337
# Epoch 72/100
# 103/103 [==============================] - 52s 506ms/step - loss: 2.5186 - mean_absolute_error: 2.8610 - root_mean_squared_error: 4.3881 - mean_absolute_percentage_error: 12.1614 - val_loss: 6.6230 - val_mean_absolute_error: 6.9908 - val_root_mean_squared_error: 12.3058 - val_mean_absolute_percentage_error: 34.1609
# Epoch 73/100
# 103/103 [==============================] - 53s 511ms/step - loss: 2.4580 - mean_absolute_error: 2.7973 - root_mean_squared_error: 4.3968 - mean_absolute_percentage_error: 11.2670 - val_loss: 6.1488 - val_mean_absolute_error: 6.5135 - val_root_mean_squared_error: 11.6692 - val_mean_absolute_percentage_error: 34.4489
# Epoch 74/100
# 103/103 [==============================] - 51s 494ms/step - loss: 2.3632 - mean_absolute_error: 2.7002 - root_mean_squared_error: 4.1812 - mean_absolute_percentage_error: 11.1955 - val_loss: 6.1216 - val_mean_absolute_error: 6.4937 - val_root_mean_squared_error: 11.6379 - val_mean_absolute_percentage_error: 32.0169
# Epoch 75/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.2892 - mean_absolute_error: 2.6223 - root_mean_squared_error: 4.1871 - mean_absolute_percentage_error: 10.6612 - val_loss: 6.0797 - val_mean_absolute_error: 6.4373 - val_root_mean_squared_error: 11.7085 - val_mean_absolute_percentage_error: 31.0311
# Epoch 76/100
# 103/103 [==============================] - 51s 500ms/step - loss: 2.4696 - mean_absolute_error: 2.8059 - root_mean_squared_error: 4.5186 - mean_absolute_percentage_error: 11.2465 - val_loss: 6.3776 - val_mean_absolute_error: 6.7455 - val_root_mean_squared_error: 12.0528 - val_mean_absolute_percentage_error: 35.0292
# Epoch 77/100
# 103/103 [==============================] - 56s 541ms/step - loss: 2.4029 - mean_absolute_error: 2.7418 - root_mean_squared_error: 4.4048 - mean_absolute_percentage_error: 10.7138 - val_loss: 6.2219 - val_mean_absolute_error: 6.5822 - val_root_mean_squared_error: 11.9800 - val_mean_absolute_percentage_error: 34.4772
# Epoch 78/100
# 103/103 [==============================] - 52s 505ms/step - loss: 2.2333 - mean_absolute_error: 2.5651 - root_mean_squared_error: 4.0780 - mean_absolute_percentage_error: 10.0637 - val_loss: 6.3441 - val_mean_absolute_error: 6.7005 - val_root_mean_squared_error: 12.2392 - val_mean_absolute_percentage_error: 33.4571
# Epoch 79/100
# 103/103 [==============================] - 54s 521ms/step - loss: 2.2413 - mean_absolute_error: 2.5736 - root_mean_squared_error: 4.2031 - mean_absolute_percentage_error: 9.6953 - val_loss: 6.0833 - val_mean_absolute_error: 6.4486 - val_root_mean_squared_error: 11.8086 - val_mean_absolute_percentage_error: 32.4101
# Epoch 80/100
# 103/103 [==============================] - 53s 514ms/step - loss: 2.3372 - mean_absolute_error: 2.6702 - root_mean_squared_error: 4.4743 - mean_absolute_percentage_error: 10.3068 - val_loss: 6.1053 - val_mean_absolute_error: 6.4608 - val_root_mean_squared_error: 12.0787 - val_mean_absolute_percentage_error: 34.4426
# Epoch 81/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.2812 - mean_absolute_error: 2.6115 - root_mean_squared_error: 4.2584 - mean_absolute_percentage_error: 10.7571 - val_loss: 6.2476 - val_mean_absolute_error: 6.6051 - val_root_mean_squared_error: 12.2509 - val_mean_absolute_percentage_error: 35.2632
# Epoch 82/100
# 103/103 [==============================] - 50s 485ms/step - loss: 2.2567 - mean_absolute_error: 2.5805 - root_mean_squared_error: 4.1125 - mean_absolute_percentage_error: 10.9623 - val_loss: 6.4534 - val_mean_absolute_error: 6.8099 - val_root_mean_squared_error: 12.4001 - val_mean_absolute_percentage_error: 32.8374
# Epoch 83/100
# 103/103 [==============================] - 50s 482ms/step - loss: 2.4527 - mean_absolute_error: 2.7817 - root_mean_squared_error: 4.4969 - mean_absolute_percentage_error: 11.3851 - val_loss: 6.6062 - val_mean_absolute_error: 6.9576 - val_root_mean_squared_error: 13.1860 - val_mean_absolute_percentage_error: 35.6164
# Epoch 84/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.4224 - mean_absolute_error: 2.7544 - root_mean_squared_error: 4.3895 - mean_absolute_percentage_error: 11.0900 - val_loss: 6.1843 - val_mean_absolute_error: 6.5416 - val_root_mean_squared_error: 11.7998 - val_mean_absolute_percentage_error: 33.7029
# Epoch 85/100
# 103/103 [==============================] - 50s 488ms/step - loss: 2.3140 - mean_absolute_error: 2.6406 - root_mean_squared_error: 4.2761 - mean_absolute_percentage_error: 11.1396 - val_loss: 6.7497 - val_mean_absolute_error: 7.1065 - val_root_mean_squared_error: 12.1634 - val_mean_absolute_percentage_error: 35.3504
# Epoch 86/100
# 103/103 [==============================] - 51s 492ms/step - loss: 2.1679 - mean_absolute_error: 2.4881 - root_mean_squared_error: 4.0166 - mean_absolute_percentage_error: 9.5772 - val_loss: 6.1697 - val_mean_absolute_error: 6.5301 - val_root_mean_squared_error: 12.0571 - val_mean_absolute_percentage_error: 34.1657
# Epoch 87/100
# 103/103 [==============================] - 49s 476ms/step - loss: 2.2953 - mean_absolute_error: 2.6199 - root_mean_squared_error: 4.2424 - mean_absolute_percentage_error: 10.3695 - val_loss: 6.4160 - val_mean_absolute_error: 6.7568 - val_root_mean_squared_error: 12.2891 - val_mean_absolute_percentage_error: 35.4707
# Epoch 88/100
# 103/103 [==============================] - 49s 480ms/step - loss: 2.0540 - mean_absolute_error: 2.3696 - root_mean_squared_error: 3.8372 - mean_absolute_percentage_error: 8.8346 - val_loss: 6.0721 - val_mean_absolute_error: 6.4254 - val_root_mean_squared_error: 11.9306 - val_mean_absolute_percentage_error: 32.5515
# Epoch 89/100
# 103/103 [==============================] - 50s 484ms/step - loss: 2.1267 - mean_absolute_error: 2.4479 - root_mean_squared_error: 4.0148 - mean_absolute_percentage_error: 9.4135 - val_loss: 5.9026 - val_mean_absolute_error: 6.2552 - val_root_mean_squared_error: 11.6952 - val_mean_absolute_percentage_error: 31.8695
# Epoch 90/100
# 103/103 [==============================] - 50s 485ms/step - loss: 2.1702 - mean_absolute_error: 2.4895 - root_mean_squared_error: 3.9823 - mean_absolute_percentage_error: 9.0600 - val_loss: 6.8429 - val_mean_absolute_error: 7.2055 - val_root_mean_squared_error: 12.3487 - val_mean_absolute_percentage_error: 35.3618
# Epoch 91/100
# 103/103 [==============================] - 50s 486ms/step - loss: 2.2406 - mean_absolute_error: 2.5654 - root_mean_squared_error: 4.2623 - mean_absolute_percentage_error: 9.5080 - val_loss: 6.1917 - val_mean_absolute_error: 6.5438 - val_root_mean_squared_error: 12.1226 - val_mean_absolute_percentage_error: 32.6296
# Epoch 92/100
# 103/103 [==============================] - 49s 473ms/step - loss: 2.1810 - mean_absolute_error: 2.5027 - root_mean_squared_error: 4.0481 - mean_absolute_percentage_error: 9.2179 - val_loss: 6.0502 - val_mean_absolute_error: 6.3965 - val_root_mean_squared_error: 12.0847 - val_mean_absolute_percentage_error: 30.5762
# Epoch 93/100
# 103/103 [==============================] - 51s 499ms/step - loss: 2.2388 - mean_absolute_error: 2.5672 - root_mean_squared_error: 4.1606 - mean_absolute_percentage_error: 9.6947 - val_loss: 6.1849 - val_mean_absolute_error: 6.5525 - val_root_mean_squared_error: 12.0513 - val_mean_absolute_percentage_error: 30.6816
# Epoch 94/100
# 103/103 [==============================] - 50s 490ms/step - loss: 2.1695 - mean_absolute_error: 2.4914 - root_mean_squared_error: 4.0636 - mean_absolute_percentage_error: 9.3876 - val_loss: 6.6000 - val_mean_absolute_error: 6.9648 - val_root_mean_squared_error: 12.0657 - val_mean_absolute_percentage_error: 34.0311
# Epoch 95/100
# 103/103 [==============================] - 50s 489ms/step - loss: 2.1489 - mean_absolute_error: 2.4760 - root_mean_squared_error: 4.0486 - mean_absolute_percentage_error: 9.2933 - val_loss: 6.0746 - val_mean_absolute_error: 6.4231 - val_root_mean_squared_error: 11.8943 - val_mean_absolute_percentage_error: 33.7108
# Epoch 96/100
# 103/103 [==============================] - 50s 484ms/step - loss: 2.1045 - mean_absolute_error: 2.4281 - root_mean_squared_error: 4.0004 - mean_absolute_percentage_error: 9.2889 - val_loss: 6.0591 - val_mean_absolute_error: 6.4109 - val_root_mean_squared_error: 11.8645 - val_mean_absolute_percentage_error: 33.3836
# Epoch 97/100
# 103/103 [==============================] - 49s 478ms/step - loss: 2.1363 - mean_absolute_error: 2.4646 - root_mean_squared_error: 3.9899 - mean_absolute_percentage_error: 9.4554 - val_loss: 6.6824 - val_mean_absolute_error: 7.0380 - val_root_mean_squared_error: 12.2844 - val_mean_absolute_percentage_error: 37.3665
# Epoch 98/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.2499 - mean_absolute_error: 2.5812 - root_mean_squared_error: 6.7145 - mean_absolute_percentage_error: 10.4891 - val_loss: 15.5515 - val_mean_absolute_error: 15.9382 - val_root_mean_squared_error: 23.7302 - val_mean_absolute_percentage_error: 51.5695
# Epoch 99/100
# 103/103 [==============================] - 50s 486ms/step - loss: 1.9764 - mean_absolute_error: 2.2967 - root_mean_squared_error: 4.6586 - mean_absolute_percentage_error: 8.6707 - val_loss: 13.5197 - val_mean_absolute_error: 13.9000 - val_root_mean_squared_error: 21.1579 - val_mean_absolute_percentage_error: 41.6232
# Epoch 100/100
# 103/103 [==============================] - 50s 487ms/step - loss: 2.1426 - mean_absolute_error: 2.4673 - root_mean_squared_error: 4.0087 - mean_absolute_percentage_error: 9.5242 - val_loss: 10.6795 - val_mean_absolute_error: 11.0669 - val_root_mean_squared_error: 16.8403 - val_mean_absolute_percentage_error: 35.6463

# %% [markdown]
# 2,1426 2,4673 4,0087 9,5242 10,6795 11,0669 16,8403 35,6463

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 7s 197ms/step - loss: 10.6795 - mean_absolute_error: 11.0669 - root_mean_squared_error: 16.8403 - mean_absolute_percentage_error: 35.6463
# Model Loss: [10.679473876953125, 11.066879272460938, 16.840288162231445, 35.64629364013672]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 394ms/step
# Predicted Putusan: [10.174796]

# %%
model_scenario_name = "BiLSTM_8"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_8\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_8\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_8"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 350ms/step
# Predicted Putusan: [10.174796]
