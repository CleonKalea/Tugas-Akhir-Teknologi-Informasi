# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_6968\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(lstm_output_2)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu')(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(16, activation='relu')(numerical_dense)

combined = tf.keras.layers.Concatenate()([lstm_output_3, numerical_dense_2])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='mae', metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding_2 (Embedding)        (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional_6 (Bidirectional  (None, 1024, 32)    34944       ['embedding_2[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_7 (Bidirectional  (None, 1024, 64)    16640       ['bidirectional_6[0][0]']
#  )
#
#  dense_6 (Dense)                (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_8 (Bidirectional  (None, 128)         66048       ['bidirectional_7[0][0]']
#  )
#
#  dense_7 (Dense)                (None, 16)           528         ['dense_6[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 144)          0           ['bidirectional_8[0][0]',
#                                                                   'dense_7[0][0]']
#
#  dense_8 (Dense)                (None, 1)            145         ['concatenate_2[0][0]']
#
# ==================================================================================================
# Total params: 3,934,433
# Trainable params: 3,934,433
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 45s 393ms/step - loss: 16.4640 - mean_absolute_error: 16.4640 - root_mean_squared_error: 23.4493 - mean_absolute_percentage_error: 100.7581 - val_loss: 14.0145 - val_mean_absolute_error: 14.0145 - val_root_mean_squared_error: 20.3998 - val_mean_absolute_percentage_error: 114.6672
# Epoch 2/100
# 103/103 [==============================] - 33s 319ms/step - loss: 11.8470 - mean_absolute_error: 11.8470 - root_mean_squared_error: 17.3782 - mean_absolute_percentage_error: 92.9870 - val_loss: 11.5134 - val_mean_absolute_error: 11.5134 - val_root_mean_squared_error: 17.6953 - val_mean_absolute_percentage_error: 85.8266
# Epoch 3/100
# 103/103 [==============================] - 33s 321ms/step - loss: 9.4689 - mean_absolute_error: 9.4689 - root_mean_squared_error: 14.8258 - mean_absolute_percentage_error: 68.4689 - val_loss: 10.2855 - val_mean_absolute_error: 10.2855 - val_root_mean_squared_error: 16.7381 - val_mean_absolute_percentage_error: 70.0030
# Epoch 4/100
# 103/103 [==============================] - 33s 319ms/step - loss: 7.7437 - mean_absolute_error: 7.7437 - root_mean_squared_error: 13.1404 - mean_absolute_percentage_error: 51.0995 - val_loss: 9.7264 - val_mean_absolute_error: 9.7264 - val_root_mean_squared_error: 16.2888 - val_mean_absolute_percentage_error: 59.3149
# Epoch 5/100
# 103/103 [==============================] - 33s 323ms/step - loss: 6.4648 - mean_absolute_error: 6.4648 - root_mean_squared_error: 11.7677 - mean_absolute_percentage_error: 39.5544 - val_loss: 8.8392 - val_mean_absolute_error: 8.8392 - val_root_mean_squared_error: 15.3939 - val_mean_absolute_percentage_error: 52.2898
# Epoch 6/100
# 103/103 [==============================] - 33s 321ms/step - loss: 5.5121 - mean_absolute_error: 5.5121 - root_mean_squared_error: 10.6310 - mean_absolute_percentage_error: 30.5478 - val_loss: 8.5821 - val_mean_absolute_error: 8.5821 - val_root_mean_squared_error: 15.2004 - val_mean_absolute_percentage_error: 47.6922
# Epoch 7/100
# 103/103 [==============================] - 33s 319ms/step - loss: 5.0164 - mean_absolute_error: 5.0164 - root_mean_squared_error: 10.0453 - mean_absolute_percentage_error: 27.4969 - val_loss: 8.8128 - val_mean_absolute_error: 8.8128 - val_root_mean_squared_error: 15.5234 - val_mean_absolute_percentage_error: 46.8819
# Epoch 8/100
# 103/103 [==============================] - 33s 319ms/step - loss: 4.5445 - mean_absolute_error: 4.5445 - root_mean_squared_error: 9.3932 - mean_absolute_percentage_error: 24.4828 - val_loss: 8.2215 - val_mean_absolute_error: 8.2215 - val_root_mean_squared_error: 14.9469 - val_mean_absolute_percentage_error: 45.1996
# Epoch 9/100
# 103/103 [==============================] - 33s 317ms/step - loss: 4.0927 - mean_absolute_error: 4.0927 - root_mean_squared_error: 8.7222 - mean_absolute_percentage_error: 22.4344 - val_loss: 8.4382 - val_mean_absolute_error: 8.4382 - val_root_mean_squared_error: 14.7844 - val_mean_absolute_percentage_error: 48.7008
# Epoch 10/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.9924 - mean_absolute_error: 3.9924 - root_mean_squared_error: 8.3686 - mean_absolute_percentage_error: 22.4055 - val_loss: 7.8183 - val_mean_absolute_error: 7.8183 - val_root_mean_squared_error: 14.3430 - val_mean_absolute_percentage_error: 44.6667
# Epoch 11/100
# 103/103 [==============================] - 33s 320ms/step - loss: 3.5711 - mean_absolute_error: 3.5711 - root_mean_squared_error: 7.9186 - mean_absolute_percentage_error: 20.6103 - val_loss: 8.3811 - val_mean_absolute_error: 8.3811 - val_root_mean_squared_error: 14.5237 - val_mean_absolute_percentage_error: 46.4651
# Epoch 12/100
# 103/103 [==============================] - 33s 321ms/step - loss: 3.3357 - mean_absolute_error: 3.3357 - root_mean_squared_error: 7.4956 - mean_absolute_percentage_error: 19.9789 - val_loss: 7.3514 - val_mean_absolute_error: 7.3514 - val_root_mean_squared_error: 13.8567 - val_mean_absolute_percentage_error: 42.0166
# Epoch 13/100
# 103/103 [==============================] - 33s 318ms/step - loss: 3.0923 - mean_absolute_error: 3.0923 - root_mean_squared_error: 7.0919 - mean_absolute_percentage_error: 18.5303 - val_loss: 7.5378 - val_mean_absolute_error: 7.5378 - val_root_mean_squared_error: 13.8760 - val_mean_absolute_percentage_error: 41.2415
# Epoch 14/100
# 103/103 [==============================] - 33s 319ms/step - loss: 2.8293 - mean_absolute_error: 2.8293 - root_mean_squared_error: 6.6956 - mean_absolute_percentage_error: 17.1930 - val_loss: 7.2268 - val_mean_absolute_error: 7.2268 - val_root_mean_squared_error: 13.5814 - val_mean_absolute_percentage_error: 41.2262
# Epoch 15/100
# 103/103 [==============================] - 33s 324ms/step - loss: 2.5453 - mean_absolute_error: 2.5453 - root_mean_squared_error: 6.3141 - mean_absolute_percentage_error: 15.5855 - val_loss: 7.3392 - val_mean_absolute_error: 7.3392 - val_root_mean_squared_error: 13.6647 - val_mean_absolute_percentage_error: 41.2289
# Epoch 16/100
# 103/103 [==============================] - 33s 319ms/step - loss: 2.4443 - mean_absolute_error: 2.4443 - root_mean_squared_error: 6.0922 - mean_absolute_percentage_error: 15.0565 - val_loss: 6.9641 - val_mean_absolute_error: 6.9641 - val_root_mean_squared_error: 13.4156 - val_mean_absolute_percentage_error: 40.2423
# Epoch 17/100
# 103/103 [==============================] - 33s 316ms/step - loss: 2.2577 - mean_absolute_error: 2.2577 - root_mean_squared_error: 5.7342 - mean_absolute_percentage_error: 13.8189 - val_loss: 7.0049 - val_mean_absolute_error: 7.0049 - val_root_mean_squared_error: 13.3016 - val_mean_absolute_percentage_error: 40.5601
# Epoch 18/100
# 103/103 [==============================] - 36s 347ms/step - loss: 2.1092 - mean_absolute_error: 2.1092 - root_mean_squared_error: 5.4894 - mean_absolute_percentage_error: 12.6438 - val_loss: 6.9575 - val_mean_absolute_error: 6.9575 - val_root_mean_squared_error: 13.2549 - val_mean_absolute_percentage_error: 40.3886
# Epoch 19/100
# 103/103 [==============================] - 33s 321ms/step - loss: 2.0675 - mean_absolute_error: 2.0675 - root_mean_squared_error: 5.3055 - mean_absolute_percentage_error: 12.7454 - val_loss: 6.9651 - val_mean_absolute_error: 6.9651 - val_root_mean_squared_error: 13.0643 - val_mean_absolute_percentage_error: 40.8295
# Epoch 20/100
# 103/103 [==============================] - 33s 318ms/step - loss: 2.0174 - mean_absolute_error: 2.0174 - root_mean_squared_error: 5.1457 - mean_absolute_percentage_error: 12.2548 - val_loss: 7.1263 - val_mean_absolute_error: 7.1263 - val_root_mean_squared_error: 13.2218 - val_mean_absolute_percentage_error: 43.3273
# Epoch 21/100
# 103/103 [==============================] - 33s 321ms/step - loss: 1.9652 - mean_absolute_error: 1.9652 - root_mean_squared_error: 5.0814 - mean_absolute_percentage_error: 12.0228 - val_loss: 6.9073 - val_mean_absolute_error: 6.9073 - val_root_mean_squared_error: 13.2104 - val_mean_absolute_percentage_error: 40.9686
# Epoch 22/100
# 103/103 [==============================] - 33s 323ms/step - loss: 1.8373 - mean_absolute_error: 1.8373 - root_mean_squared_error: 4.8747 - mean_absolute_percentage_error: 11.4633 - val_loss: 6.8175 - val_mean_absolute_error: 6.8175 - val_root_mean_squared_error: 13.1025 - val_mean_absolute_percentage_error: 40.8595
# Epoch 23/100
# 103/103 [==============================] - 33s 318ms/step - loss: 1.7781 - mean_absolute_error: 1.7781 - root_mean_squared_error: 4.7426 - mean_absolute_percentage_error: 10.9325 - val_loss: 6.7721 - val_mean_absolute_error: 6.7721 - val_root_mean_squared_error: 13.0761 - val_mean_absolute_percentage_error: 38.6212
# Epoch 24/100
# 103/103 [==============================] - 33s 319ms/step - loss: 1.6605 - mean_absolute_error: 1.6605 - root_mean_squared_error: 4.6151 - mean_absolute_percentage_error: 9.8563 - val_loss: 6.5856 - val_mean_absolute_error: 6.5856 - val_root_mean_squared_error: 12.9093 - val_mean_absolute_percentage_error: 38.4613
# Epoch 25/100
# 103/103 [==============================] - 33s 318ms/step - loss: 1.6276 - mean_absolute_error: 1.6276 - root_mean_squared_error: 4.4544 - mean_absolute_percentage_error: 9.8892 - val_loss: 6.6582 - val_mean_absolute_error: 6.6582 - val_root_mean_squared_error: 12.9481 - val_mean_absolute_percentage_error: 39.0798
# Epoch 26/100
# 103/103 [==============================] - 32s 315ms/step - loss: 1.5718 - mean_absolute_error: 1.5718 - root_mean_squared_error: 4.3838 - mean_absolute_percentage_error: 9.2842 - val_loss: 6.5803 - val_mean_absolute_error: 6.5803 - val_root_mean_squared_error: 12.9035 - val_mean_absolute_percentage_error: 37.2909
# Epoch 27/100
# 103/103 [==============================] - 32s 310ms/step - loss: 1.6131 - mean_absolute_error: 1.6131 - root_mean_squared_error: 4.2795 - mean_absolute_percentage_error: 10.4939 - val_loss: 7.1649 - val_mean_absolute_error: 7.1649 - val_root_mean_squared_error: 13.1114 - val_mean_absolute_percentage_error: 45.5180
# Epoch 28/100
# 103/103 [==============================] - 32s 314ms/step - loss: 1.6292 - mean_absolute_error: 1.6292 - root_mean_squared_error: 4.4801 - mean_absolute_percentage_error: 9.5736 - val_loss: 6.6127 - val_mean_absolute_error: 6.6127 - val_root_mean_squared_error: 12.9327 - val_mean_absolute_percentage_error: 39.1069
# Epoch 29/100
# 103/103 [==============================] - 33s 326ms/step - loss: 1.5264 - mean_absolute_error: 1.5264 - root_mean_squared_error: 4.0921 - mean_absolute_percentage_error: 9.1950 - val_loss: 6.5697 - val_mean_absolute_error: 6.5697 - val_root_mean_squared_error: 12.8930 - val_mean_absolute_percentage_error: 37.1474
# Epoch 30/100
# 103/103 [==============================] - 33s 321ms/step - loss: 1.3838 - mean_absolute_error: 1.3838 - root_mean_squared_error: 3.8823 - mean_absolute_percentage_error: 8.5871 - val_loss: 6.5188 - val_mean_absolute_error: 6.5188 - val_root_mean_squared_error: 12.9828 - val_mean_absolute_percentage_error: 37.3555
# Epoch 31/100
# 103/103 [==============================] - 33s 322ms/step - loss: 1.3494 - mean_absolute_error: 1.3494 - root_mean_squared_error: 4.0146 - mean_absolute_percentage_error: 7.7951 - val_loss: 6.4962 - val_mean_absolute_error: 6.4962 - val_root_mean_squared_error: 12.8091 - val_mean_absolute_percentage_error: 37.0969
# Epoch 32/100
# 103/103 [==============================] - 33s 319ms/step - loss: 1.3295 - mean_absolute_error: 1.3295 - root_mean_squared_error: 3.7695 - mean_absolute_percentage_error: 7.5010 - val_loss: 6.6076 - val_mean_absolute_error: 6.6076 - val_root_mean_squared_error: 13.0258 - val_mean_absolute_percentage_error: 39.6780
# Epoch 33/100
# 103/103 [==============================] - 33s 317ms/step - loss: 1.2594 - mean_absolute_error: 1.2594 - root_mean_squared_error: 3.6344 - mean_absolute_percentage_error: 7.3650 - val_loss: 6.4672 - val_mean_absolute_error: 6.4672 - val_root_mean_squared_error: 12.8283 - val_mean_absolute_percentage_error: 38.3264
# Epoch 34/100
# 103/103 [==============================] - 33s 319ms/step - loss: 1.8615 - mean_absolute_error: 1.8615 - root_mean_squared_error: 5.2703 - mean_absolute_percentage_error: 12.3304 - val_loss: 6.9216 - val_mean_absolute_error: 6.9216 - val_root_mean_squared_error: 13.7631 - val_mean_absolute_percentage_error: 44.5537
# Epoch 35/100
# 103/103 [==============================] - 33s 317ms/step - loss: 1.4168 - mean_absolute_error: 1.4168 - root_mean_squared_error: 4.0948 - mean_absolute_percentage_error: 8.3457 - val_loss: 6.7573 - val_mean_absolute_error: 6.7573 - val_root_mean_squared_error: 13.5738 - val_mean_absolute_percentage_error: 41.9147
# Epoch 36/100
# 103/103 [==============================] - 33s 318ms/step - loss: 1.2237 - mean_absolute_error: 1.2237 - root_mean_squared_error: 3.7377 - mean_absolute_percentage_error: 6.8884 - val_loss: 6.7512 - val_mean_absolute_error: 6.7512 - val_root_mean_squared_error: 13.5314 - val_mean_absolute_percentage_error: 42.0201
# Epoch 37/100
# 103/103 [==============================] - 33s 318ms/step - loss: 1.1666 - mean_absolute_error: 1.1666 - root_mean_squared_error: 3.5641 - mean_absolute_percentage_error: 6.6445 - val_loss: 6.6589 - val_mean_absolute_error: 6.6589 - val_root_mean_squared_error: 13.4361 - val_mean_absolute_percentage_error: 42.9712
# Epoch 38/100
# 103/103 [==============================] - 33s 317ms/step - loss: 1.1077 - mean_absolute_error: 1.1077 - root_mean_squared_error: 3.4948 - mean_absolute_percentage_error: 6.2079 - val_loss: 6.7373 - val_mean_absolute_error: 6.7373 - val_root_mean_squared_error: 13.3208 - val_mean_absolute_percentage_error: 41.4103
# Epoch 39/100
# 103/103 [==============================] - 33s 317ms/step - loss: 1.1364 - mean_absolute_error: 1.1364 - root_mean_squared_error: 3.3952 - mean_absolute_percentage_error: 6.6449 - val_loss: 6.5130 - val_mean_absolute_error: 6.5130 - val_root_mean_squared_error: 12.7658 - val_mean_absolute_percentage_error: 37.5446
# Epoch 40/100
# 103/103 [==============================] - 33s 317ms/step - loss: 1.0643 - mean_absolute_error: 1.0643 - root_mean_squared_error: 3.3343 - mean_absolute_percentage_error: 5.9888 - val_loss: 6.5494 - val_mean_absolute_error: 6.5494 - val_root_mean_squared_error: 12.9886 - val_mean_absolute_percentage_error: 38.9786
# Epoch 41/100
# 103/103 [==============================] - 33s 317ms/step - loss: 0.9679 - mean_absolute_error: 0.9679 - root_mean_squared_error: 3.2234 - mean_absolute_percentage_error: 5.4971 - val_loss: 6.5672 - val_mean_absolute_error: 6.5672 - val_root_mean_squared_error: 12.8982 - val_mean_absolute_percentage_error: 37.6336
# Epoch 42/100
# 103/103 [==============================] - 35s 344ms/step - loss: 0.9895 - mean_absolute_error: 0.9895 - root_mean_squared_error: 3.2222 - mean_absolute_percentage_error: 5.8937 - val_loss: 6.5217 - val_mean_absolute_error: 6.5217 - val_root_mean_squared_error: 12.9231 - val_mean_absolute_percentage_error: 37.9057
# Epoch 43/100
# 103/103 [==============================] - 37s 357ms/step - loss: 0.9926 - mean_absolute_error: 0.9926 - root_mean_squared_error: 3.1925 - mean_absolute_percentage_error: 5.7782 - val_loss: 6.4871 - val_mean_absolute_error: 6.4871 - val_root_mean_squared_error: 12.8099 - val_mean_absolute_percentage_error: 38.8410
# Epoch 44/100
# 103/103 [==============================] - 33s 324ms/step - loss: 0.9215 - mean_absolute_error: 0.9215 - root_mean_squared_error: 3.1396 - mean_absolute_percentage_error: 5.2819 - val_loss: 6.4065 - val_mean_absolute_error: 6.4065 - val_root_mean_squared_error: 12.8073 - val_mean_absolute_percentage_error: 37.6004
# Epoch 45/100
# 103/103 [==============================] - 36s 351ms/step - loss: 0.9045 - mean_absolute_error: 0.9045 - root_mean_squared_error: 3.1034 - mean_absolute_percentage_error: 5.2455 - val_loss: 6.4922 - val_mean_absolute_error: 6.4922 - val_root_mean_squared_error: 12.7780 - val_mean_absolute_percentage_error: 37.4894
# Epoch 46/100
# 103/103 [==============================] - 36s 353ms/step - loss: 0.9016 - mean_absolute_error: 0.9016 - root_mean_squared_error: 3.0851 - mean_absolute_percentage_error: 5.1389 - val_loss: 6.4312 - val_mean_absolute_error: 6.4312 - val_root_mean_squared_error: 12.7893 - val_mean_absolute_percentage_error: 37.2444
# Epoch 47/100
# 103/103 [==============================] - 37s 361ms/step - loss: 0.8904 - mean_absolute_error: 0.8904 - root_mean_squared_error: 3.0274 - mean_absolute_percentage_error: 5.0867 - val_loss: 6.4535 - val_mean_absolute_error: 6.4535 - val_root_mean_squared_error: 12.7889 - val_mean_absolute_percentage_error: 37.8133
# Epoch 48/100
# 103/103 [==============================] - 36s 346ms/step - loss: 0.8756 - mean_absolute_error: 0.8756 - root_mean_squared_error: 3.0354 - mean_absolute_percentage_error: 5.1129 - val_loss: 6.3046 - val_mean_absolute_error: 6.3046 - val_root_mean_squared_error: 12.6708 - val_mean_absolute_percentage_error: 37.3003
# Epoch 49/100
# 103/103 [==============================] - 34s 329ms/step - loss: 0.8766 - mean_absolute_error: 0.8766 - root_mean_squared_error: 2.9979 - mean_absolute_percentage_error: 5.1353 - val_loss: 6.4017 - val_mean_absolute_error: 6.4017 - val_root_mean_squared_error: 12.7795 - val_mean_absolute_percentage_error: 37.4756
# Epoch 50/100
# 103/103 [==============================] - 33s 324ms/step - loss: 0.8359 - mean_absolute_error: 0.8359 - root_mean_squared_error: 2.9315 - mean_absolute_percentage_error: 4.9754 - val_loss: 6.4666 - val_mean_absolute_error: 6.4666 - val_root_mean_squared_error: 12.7657 - val_mean_absolute_percentage_error: 37.3996
# Epoch 51/100
# 103/103 [==============================] - 33s 317ms/step - loss: 0.8517 - mean_absolute_error: 0.8517 - root_mean_squared_error: 2.8384 - mean_absolute_percentage_error: 4.8218 - val_loss: 6.3426 - val_mean_absolute_error: 6.3426 - val_root_mean_squared_error: 12.6427 - val_mean_absolute_percentage_error: 37.8966
# Epoch 52/100
# 103/103 [==============================] - 32s 310ms/step - loss: 0.8708 - mean_absolute_error: 0.8708 - root_mean_squared_error: 2.8160 - mean_absolute_percentage_error: 5.2313 - val_loss: 6.3548 - val_mean_absolute_error: 6.3548 - val_root_mean_squared_error: 12.6053 - val_mean_absolute_percentage_error: 39.9745
# Epoch 53/100
# 103/103 [==============================] - 32s 311ms/step - loss: 1.0419 - mean_absolute_error: 1.0419 - root_mean_squared_error: 2.9919 - mean_absolute_percentage_error: 6.1531 - val_loss: 6.3867 - val_mean_absolute_error: 6.3867 - val_root_mean_squared_error: 12.5683 - val_mean_absolute_percentage_error: 37.8857
# Epoch 54/100
# 103/103 [==============================] - 32s 314ms/step - loss: 0.9166 - mean_absolute_error: 0.9166 - root_mean_squared_error: 2.8200 - mean_absolute_percentage_error: 5.3826 - val_loss: 6.5028 - val_mean_absolute_error: 6.5028 - val_root_mean_squared_error: 12.8929 - val_mean_absolute_percentage_error: 37.5179
# Epoch 55/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.8986 - mean_absolute_error: 0.8986 - root_mean_squared_error: 2.8882 - mean_absolute_percentage_error: 5.2239 - val_loss: 6.4294 - val_mean_absolute_error: 6.4294 - val_root_mean_squared_error: 12.6959 - val_mean_absolute_percentage_error: 36.9163
# Epoch 56/100
# 103/103 [==============================] - 32s 309ms/step - loss: 0.8808 - mean_absolute_error: 0.8808 - root_mean_squared_error: 2.7927 - mean_absolute_percentage_error: 4.9948 - val_loss: 6.3278 - val_mean_absolute_error: 6.3278 - val_root_mean_squared_error: 12.5793 - val_mean_absolute_percentage_error: 37.2389
# Epoch 57/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.7674 - mean_absolute_error: 0.7674 - root_mean_squared_error: 2.6682 - mean_absolute_percentage_error: 4.6437 - val_loss: 6.2977 - val_mean_absolute_error: 6.2977 - val_root_mean_squared_error: 12.6802 - val_mean_absolute_percentage_error: 36.9077
# Epoch 58/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.7783 - mean_absolute_error: 0.7783 - root_mean_squared_error: 2.6943 - mean_absolute_percentage_error: 4.7277 - val_loss: 6.2805 - val_mean_absolute_error: 6.2805 - val_root_mean_squared_error: 12.6458 - val_mean_absolute_percentage_error: 36.7628
# Epoch 59/100
# 103/103 [==============================] - 32s 310ms/step - loss: 0.7874 - mean_absolute_error: 0.7874 - root_mean_squared_error: 2.6361 - mean_absolute_percentage_error: 4.5254 - val_loss: 6.3239 - val_mean_absolute_error: 6.3239 - val_root_mean_squared_error: 12.4120 - val_mean_absolute_percentage_error: 35.8968
# Epoch 60/100
# 103/103 [==============================] - 33s 317ms/step - loss: 0.7725 - mean_absolute_error: 0.7725 - root_mean_squared_error: 2.6186 - mean_absolute_percentage_error: 4.5229 - val_loss: 6.2380 - val_mean_absolute_error: 6.2380 - val_root_mean_squared_error: 12.4811 - val_mean_absolute_percentage_error: 36.2764
# Epoch 61/100
# 103/103 [==============================] - 32s 313ms/step - loss: 0.7192 - mean_absolute_error: 0.7192 - root_mean_squared_error: 2.6911 - mean_absolute_percentage_error: 4.1338 - val_loss: 6.2201 - val_mean_absolute_error: 6.2201 - val_root_mean_squared_error: 12.5297 - val_mean_absolute_percentage_error: 37.2631
# Epoch 62/100
# 103/103 [==============================] - 32s 313ms/step - loss: 0.7354 - mean_absolute_error: 0.7354 - root_mean_squared_error: 2.5935 - mean_absolute_percentage_error: 4.3481 - val_loss: 6.2363 - val_mean_absolute_error: 6.2363 - val_root_mean_squared_error: 12.6101 - val_mean_absolute_percentage_error: 36.6660
# Epoch 63/100
# 103/103 [==============================] - 32s 313ms/step - loss: 0.7050 - mean_absolute_error: 0.7050 - root_mean_squared_error: 2.5366 - mean_absolute_percentage_error: 4.0498 - val_loss: 6.2202 - val_mean_absolute_error: 6.2202 - val_root_mean_squared_error: 12.5671 - val_mean_absolute_percentage_error: 36.2722
# Epoch 64/100
# 103/103 [==============================] - 32s 314ms/step - loss: 0.7041 - mean_absolute_error: 0.7041 - root_mean_squared_error: 2.5400 - mean_absolute_percentage_error: 3.9630 - val_loss: 6.1797 - val_mean_absolute_error: 6.1797 - val_root_mean_squared_error: 12.4726 - val_mean_absolute_percentage_error: 36.5381
# Epoch 65/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.7087 - mean_absolute_error: 0.7087 - root_mean_squared_error: 2.5073 - mean_absolute_percentage_error: 4.1989 - val_loss: 6.2738 - val_mean_absolute_error: 6.2738 - val_root_mean_squared_error: 12.4855 - val_mean_absolute_percentage_error: 36.5921
# Epoch 66/100
# 103/103 [==============================] - 32s 313ms/step - loss: 0.7131 - mean_absolute_error: 0.7131 - root_mean_squared_error: 2.5043 - mean_absolute_percentage_error: 4.0443 - val_loss: 6.1633 - val_mean_absolute_error: 6.1633 - val_root_mean_squared_error: 12.4948 - val_mean_absolute_percentage_error: 36.5725
# Epoch 67/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.6967 - mean_absolute_error: 0.6967 - root_mean_squared_error: 2.4491 - mean_absolute_percentage_error: 4.0005 - val_loss: 6.2733 - val_mean_absolute_error: 6.2733 - val_root_mean_squared_error: 12.5590 - val_mean_absolute_percentage_error: 37.3174
# Epoch 68/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.7101 - mean_absolute_error: 0.7101 - root_mean_squared_error: 2.4187 - mean_absolute_percentage_error: 4.1475 - val_loss: 6.1375 - val_mean_absolute_error: 6.1375 - val_root_mean_squared_error: 12.4589 - val_mean_absolute_percentage_error: 35.3809
# Epoch 69/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.6555 - mean_absolute_error: 0.6555 - root_mean_squared_error: 2.3797 - mean_absolute_percentage_error: 3.7608 - val_loss: 6.1273 - val_mean_absolute_error: 6.1273 - val_root_mean_squared_error: 12.4679 - val_mean_absolute_percentage_error: 35.4816
# Epoch 70/100
# 103/103 [==============================] - 33s 321ms/step - loss: 0.6410 - mean_absolute_error: 0.6410 - root_mean_squared_error: 2.4184 - mean_absolute_percentage_error: 3.5236 - val_loss: 6.1746 - val_mean_absolute_error: 6.1746 - val_root_mean_squared_error: 12.3661 - val_mean_absolute_percentage_error: 36.3897
# Epoch 71/100
# 103/103 [==============================] - 32s 314ms/step - loss: 0.6589 - mean_absolute_error: 0.6589 - root_mean_squared_error: 2.4832 - mean_absolute_percentage_error: 3.5188 - val_loss: 6.1667 - val_mean_absolute_error: 6.1667 - val_root_mean_squared_error: 12.3822 - val_mean_absolute_percentage_error: 35.7921
# Epoch 72/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.6588 - mean_absolute_error: 0.6588 - root_mean_squared_error: 2.3430 - mean_absolute_percentage_error: 3.5772 - val_loss: 6.3396 - val_mean_absolute_error: 6.3396 - val_root_mean_squared_error: 12.5232 - val_mean_absolute_percentage_error: 37.6831
# Epoch 73/100
# 103/103 [==============================] - 32s 313ms/step - loss: 0.7033 - mean_absolute_error: 0.7033 - root_mean_squared_error: 2.3047 - mean_absolute_percentage_error: 4.0354 - val_loss: 6.1469 - val_mean_absolute_error: 6.1469 - val_root_mean_squared_error: 12.4145 - val_mean_absolute_percentage_error: 35.6946
# Epoch 74/100
# 103/103 [==============================] - 32s 309ms/step - loss: 0.6257 - mean_absolute_error: 0.6257 - root_mean_squared_error: 2.2200 - mean_absolute_percentage_error: 3.4616 - val_loss: 6.1514 - val_mean_absolute_error: 6.1514 - val_root_mean_squared_error: 12.5076 - val_mean_absolute_percentage_error: 36.9397
# Epoch 75/100
# 103/103 [==============================] - 32s 310ms/step - loss: 0.6667 - mean_absolute_error: 0.6667 - root_mean_squared_error: 2.2077 - mean_absolute_percentage_error: 3.7941 - val_loss: 6.1251 - val_mean_absolute_error: 6.1251 - val_root_mean_squared_error: 12.4247 - val_mean_absolute_percentage_error: 36.1120
# Epoch 76/100
# 103/103 [==============================] - 32s 308ms/step - loss: 0.5928 - mean_absolute_error: 0.5928 - root_mean_squared_error: 2.1758 - mean_absolute_percentage_error: 3.3513 - val_loss: 6.1357 - val_mean_absolute_error: 6.1357 - val_root_mean_squared_error: 12.2573 - val_mean_absolute_percentage_error: 35.2937
# Epoch 77/100
# 103/103 [==============================] - 32s 309ms/step - loss: 0.6348 - mean_absolute_error: 0.6348 - root_mean_squared_error: 2.1754 - mean_absolute_percentage_error: 3.6557 - val_loss: 6.0793 - val_mean_absolute_error: 6.0793 - val_root_mean_squared_error: 12.3527 - val_mean_absolute_percentage_error: 35.9005
# Epoch 78/100
# 103/103 [==============================] - 32s 314ms/step - loss: 0.6277 - mean_absolute_error: 0.6277 - root_mean_squared_error: 2.1587 - mean_absolute_percentage_error: 3.5797 - val_loss: 6.0221 - val_mean_absolute_error: 6.0221 - val_root_mean_squared_error: 12.2602 - val_mean_absolute_percentage_error: 34.6806
# Epoch 79/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.5733 - mean_absolute_error: 0.5733 - root_mean_squared_error: 2.1106 - mean_absolute_percentage_error: 3.2125 - val_loss: 6.0284 - val_mean_absolute_error: 6.0284 - val_root_mean_squared_error: 12.3294 - val_mean_absolute_percentage_error: 35.3159
# Epoch 80/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.5596 - mean_absolute_error: 0.5596 - root_mean_squared_error: 2.0954 - mean_absolute_percentage_error: 3.2765 - val_loss: 6.1465 - val_mean_absolute_error: 6.1465 - val_root_mean_squared_error: 12.2634 - val_mean_absolute_percentage_error: 35.0833
# Epoch 81/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.5844 - mean_absolute_error: 0.5844 - root_mean_squared_error: 2.1009 - mean_absolute_percentage_error: 3.3604 - val_loss: 6.0481 - val_mean_absolute_error: 6.0481 - val_root_mean_squared_error: 12.2877 - val_mean_absolute_percentage_error: 36.6061
# Epoch 82/100
# 103/103 [==============================] - 32s 309ms/step - loss: 0.5778 - mean_absolute_error: 0.5778 - root_mean_squared_error: 2.0834 - mean_absolute_percentage_error: 3.2633 - val_loss: 6.2008 - val_mean_absolute_error: 6.2008 - val_root_mean_squared_error: 12.5577 - val_mean_absolute_percentage_error: 35.7910
# Epoch 83/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.5801 - mean_absolute_error: 0.5801 - root_mean_squared_error: 2.0596 - mean_absolute_percentage_error: 3.3438 - val_loss: 6.0694 - val_mean_absolute_error: 6.0694 - val_root_mean_squared_error: 12.3330 - val_mean_absolute_percentage_error: 36.4747
# Epoch 84/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.5783 - mean_absolute_error: 0.5783 - root_mean_squared_error: 2.0627 - mean_absolute_percentage_error: 3.3021 - val_loss: 6.1775 - val_mean_absolute_error: 6.1775 - val_root_mean_squared_error: 12.4913 - val_mean_absolute_percentage_error: 36.6883
# Epoch 85/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.6172 - mean_absolute_error: 0.6172 - root_mean_squared_error: 2.0659 - mean_absolute_percentage_error: 3.4278 - val_loss: 6.1111 - val_mean_absolute_error: 6.1111 - val_root_mean_squared_error: 12.4429 - val_mean_absolute_percentage_error: 36.2174
# Epoch 86/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.6568 - mean_absolute_error: 0.6568 - root_mean_squared_error: 2.2739 - mean_absolute_percentage_error: 3.8011 - val_loss: 6.1273 - val_mean_absolute_error: 6.1273 - val_root_mean_squared_error: 12.6567 - val_mean_absolute_percentage_error: 34.8049
# Epoch 87/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.6342 - mean_absolute_error: 0.6342 - root_mean_squared_error: 2.0765 - mean_absolute_percentage_error: 3.6300 - val_loss: 6.1203 - val_mean_absolute_error: 6.1203 - val_root_mean_squared_error: 12.4023 - val_mean_absolute_percentage_error: 36.1026
# Epoch 88/100
# 103/103 [==============================] - 32s 316ms/step - loss: 0.5898 - mean_absolute_error: 0.5898 - root_mean_squared_error: 2.0041 - mean_absolute_percentage_error: 3.3243 - val_loss: 6.1396 - val_mean_absolute_error: 6.1396 - val_root_mean_squared_error: 12.5152 - val_mean_absolute_percentage_error: 35.8927
# Epoch 89/100
# 103/103 [==============================] - 34s 331ms/step - loss: 0.5062 - mean_absolute_error: 0.5062 - root_mean_squared_error: 1.9627 - mean_absolute_percentage_error: 2.8329 - val_loss: 6.1217 - val_mean_absolute_error: 6.1217 - val_root_mean_squared_error: 12.5146 - val_mean_absolute_percentage_error: 36.8319
# Epoch 90/100
# 103/103 [==============================] - 33s 319ms/step - loss: 0.5410 - mean_absolute_error: 0.5410 - root_mean_squared_error: 2.1448 - mean_absolute_percentage_error: 3.0281 - val_loss: 6.2768 - val_mean_absolute_error: 6.2768 - val_root_mean_squared_error: 12.6182 - val_mean_absolute_percentage_error: 36.6969
# Epoch 91/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.6261 - mean_absolute_error: 0.6261 - root_mean_squared_error: 2.1409 - mean_absolute_percentage_error: 3.7909 - val_loss: 6.2394 - val_mean_absolute_error: 6.2394 - val_root_mean_squared_error: 12.7138 - val_mean_absolute_percentage_error: 36.6922
# Epoch 92/100
# 103/103 [==============================] - 33s 319ms/step - loss: 0.5519 - mean_absolute_error: 0.5519 - root_mean_squared_error: 2.0587 - mean_absolute_percentage_error: 3.1452 - val_loss: 6.1975 - val_mean_absolute_error: 6.1975 - val_root_mean_squared_error: 12.6709 - val_mean_absolute_percentage_error: 35.5440
# Epoch 93/100
# 103/103 [==============================] - 33s 320ms/step - loss: 0.5590 - mean_absolute_error: 0.5590 - root_mean_squared_error: 2.0854 - mean_absolute_percentage_error: 3.2922 - val_loss: 6.2307 - val_mean_absolute_error: 6.2307 - val_root_mean_squared_error: 12.6107 - val_mean_absolute_percentage_error: 36.6618
# Epoch 94/100
# 103/103 [==============================] - 32s 314ms/step - loss: 0.6415 - mean_absolute_error: 0.6415 - root_mean_squared_error: 2.2606 - mean_absolute_percentage_error: 3.6609 - val_loss: 6.2578 - val_mean_absolute_error: 6.2578 - val_root_mean_squared_error: 12.9090 - val_mean_absolute_percentage_error: 35.2955
# Epoch 95/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.9749 - mean_absolute_error: 0.9749 - root_mean_squared_error: 5.6303 - mean_absolute_percentage_error: 6.9765 - val_loss: 6.2688 - val_mean_absolute_error: 6.2688 - val_root_mean_squared_error: 12.6783 - val_mean_absolute_percentage_error: 34.3413
# Epoch 96/100
# 103/103 [==============================] - 36s 348ms/step - loss: 0.6581 - mean_absolute_error: 0.6581 - root_mean_squared_error: 2.0870 - mean_absolute_percentage_error: 3.5699 - val_loss: 6.2148 - val_mean_absolute_error: 6.2148 - val_root_mean_squared_error: 12.9205 - val_mean_absolute_percentage_error: 36.0220
# Epoch 97/100
# 103/103 [==============================] - 33s 321ms/step - loss: 0.5842 - mean_absolute_error: 0.5842 - root_mean_squared_error: 2.4019 - mean_absolute_percentage_error: 3.2737 - val_loss: 6.2335 - val_mean_absolute_error: 6.2335 - val_root_mean_squared_error: 12.9871 - val_mean_absolute_percentage_error: 37.3592
# Epoch 98/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.5793 - mean_absolute_error: 0.5793 - root_mean_squared_error: 2.4018 - mean_absolute_percentage_error: 3.2428 - val_loss: 6.2076 - val_mean_absolute_error: 6.2076 - val_root_mean_squared_error: 12.9125 - val_mean_absolute_percentage_error: 36.4016
# Epoch 99/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.5213 - mean_absolute_error: 0.5213 - root_mean_squared_error: 2.2939 - mean_absolute_percentage_error: 2.9848 - val_loss: 6.0736 - val_mean_absolute_error: 6.0736 - val_root_mean_squared_error: 12.7845 - val_mean_absolute_percentage_error: 34.7674
# Epoch 100/100
# 103/103 [==============================] - 32s 315ms/step - loss: 0.4975 - mean_absolute_error: 0.4975 - root_mean_squared_error: 1.9100 - mean_absolute_percentage_error: 2.7630 - val_loss: 6.1609 - val_mean_absolute_error: 6.1609 - val_root_mean_squared_error: 12.9168 - val_mean_absolute_percentage_error: 35.1022

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 5s 139ms/step - loss: 6.1609 - mean_absolute_error: 6.1609 - root_mean_squared_error: 12.9168 - mean_absolute_percentage_error: 35.1022
# Model Loss: [6.1609344482421875, 6.1609344482421875, 12.916801452636719, 35.10216522216797]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [11.638673]

# %%
model_scenario_name = "BiLSTM_5"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_28_layer_call_fn, lstm_cell_28_layer_call_and_return_conditional_losses, lstm_cell_29_layer_call_fn, lstm_cell_29_layer_call_and_return_conditional_losses, lstm_cell_31_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_5\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_5\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_5"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted Putusan: [11.638673]
