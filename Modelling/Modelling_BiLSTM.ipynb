# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_7924\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output_2 =tf.keras.layers.Bidirectional( tf.keras.layers.LSTM(16, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
lstm_output_4 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_3)
lstm_output_5 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_4)
lstm_output_6 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(8, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_5)
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_6)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 128)    164352      ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 1024, 32)    18560       ['bidirectional[0][0]']
#  )
#
#  bidirectional_2 (Bidirectional  (None, 1024, 32)    6272        ['bidirectional_1[0][0]']
#  )
#
#  bidirectional_3 (Bidirectional  (None, 1024, 32)    6272        ['bidirectional_2[0][0]']
#  )
#
#  bidirectional_4 (Bidirectional  (None, 1024, 16)    2624        ['bidirectional_3[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_5 (Bidirectional  (None, 1024, 16)    1600        ['bidirectional_4[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 16)          0           ['bidirectional_5[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 16)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 48)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 48)          192         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          6272        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,904,097
# Trainable params: 4,904,001
# Non-trainable params: 96
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), 
                    callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 65s 522ms/step - loss: 33.4216 - mean_absolute_error: 32.9384 - root_mean_squared_error: 45.4752 - mean_absolute_percentage_error: 90.6597 - val_loss: 33.7163 - val_mean_absolute_error: 33.3048 - val_root_mean_squared_error: 46.3581 - val_mean_absolute_percentage_error: 83.9826 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 52s 510ms/step - loss: 30.0784 - mean_absolute_error: 29.7208 - root_mean_squared_error: 42.4749 - mean_absolute_percentage_error: 76.7361 - val_loss: 29.6093 - val_mean_absolute_error: 29.3102 - val_root_mean_squared_error: 42.5472 - val_mean_absolute_percentage_error: 70.1163 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 52s 507ms/step - loss: 24.9769 - mean_absolute_error: 24.7195 - root_mean_squared_error: 36.9865 - mean_absolute_percentage_error: 63.5724 - val_loss: 23.2258 - val_mean_absolute_error: 23.0092 - val_root_mean_squared_error: 34.8755 - val_mean_absolute_percentage_error: 58.4538 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 52s 507ms/step - loss: 18.3546 - mean_absolute_error: 18.1677 - root_mean_squared_error: 27.8430 - mean_absolute_percentage_error: 58.2169 - val_loss: 16.5063 - val_mean_absolute_error: 16.3501 - val_root_mean_squared_error: 25.0603 - val_mean_absolute_percentage_error: 54.0863 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 51s 493ms/step - loss: 12.0592 - mean_absolute_error: 11.9235 - root_mean_squared_error: 18.6037 - mean_absolute_percentage_error: 55.2921 - val_loss: 10.3210 - val_mean_absolute_error: 10.1986 - val_root_mean_squared_error: 16.5388 - val_mean_absolute_percentage_error: 53.2604 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 52s 507ms/step - loss: 10.6422 - mean_absolute_error: 10.5375 - root_mean_squared_error: 16.0673 - mean_absolute_percentage_error: 57.6886 - val_loss: 9.5030 - val_mean_absolute_error: 9.4018 - val_root_mean_squared_error: 15.3040 - val_mean_absolute_percentage_error: 49.0248 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 54s 526ms/step - loss: 9.0161 - mean_absolute_error: 8.9290 - root_mean_squared_error: 14.0254 - mean_absolute_percentage_error: 50.7074 - val_loss: 9.8257 - val_mean_absolute_error: 9.7507 - val_root_mean_squared_error: 15.9759 - val_mean_absolute_percentage_error: 47.9698 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 55s 532ms/step - loss: 8.5530 - mean_absolute_error: 8.4815 - root_mean_squared_error: 13.0948 - mean_absolute_percentage_error: 48.7449 - val_loss: 8.0834 - val_mean_absolute_error: 8.0136 - val_root_mean_squared_error: 13.7109 - val_mean_absolute_percentage_error: 45.6577 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 53s 512ms/step - loss: 7.7272 - mean_absolute_error: 7.6683 - root_mean_squared_error: 12.0310 - mean_absolute_percentage_error: 45.6851 - val_loss: 8.6342 - val_mean_absolute_error: 8.5823 - val_root_mean_squared_error: 13.5269 - val_mean_absolute_percentage_error: 48.9665 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 52s 508ms/step - loss: 7.5051 - mean_absolute_error: 7.4565 - root_mean_squared_error: 11.6311 - mean_absolute_percentage_error: 43.6240 - val_loss: 8.3052 - val_mean_absolute_error: 8.2636 - val_root_mean_squared_error: 13.2195 - val_mean_absolute_percentage_error: 45.8089 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 52s 509ms/step - loss: 7.1247 - mean_absolute_error: 7.0856 - root_mean_squared_error: 11.1023 - mean_absolute_percentage_error: 40.6349 - val_loss: 7.5985 - val_mean_absolute_error: 7.5583 - val_root_mean_squared_error: 12.8046 - val_mean_absolute_percentage_error: 42.3503 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 53s 514ms/step - loss: 7.0875 - mean_absolute_error: 7.0570 - root_mean_squared_error: 11.0053 - mean_absolute_percentage_error: 40.8240 - val_loss: 7.5736 - val_mean_absolute_error: 7.5445 - val_root_mean_squared_error: 12.8816 - val_mean_absolute_percentage_error: 42.7758 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 52s 510ms/step - loss: 6.5304 - mean_absolute_error: 6.5066 - root_mean_squared_error: 9.9892 - mean_absolute_percentage_error: 37.4526 - val_loss: 7.8293 - val_mean_absolute_error: 7.8068 - val_root_mean_squared_error: 13.1038 - val_mean_absolute_percentage_error: 41.2482 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 51s 500ms/step - loss: 6.6547 - mean_absolute_error: 6.6392 - root_mean_squared_error: 10.2390 - mean_absolute_percentage_error: 37.2556 - val_loss: 7.3787 - val_mean_absolute_error: 7.3651 - val_root_mean_squared_error: 12.2695 - val_mean_absolute_percentage_error: 41.7897 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 52s 503ms/step - loss: 6.5509 - mean_absolute_error: 6.5421 - root_mean_squared_error: 9.9070 - mean_absolute_percentage_error: 36.8797 - val_loss: 7.7939 - val_mean_absolute_error: 7.7891 - val_root_mean_squared_error: 12.5123 - val_mean_absolute_percentage_error: 43.2899 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 52s 508ms/step - loss: 6.4927 - mean_absolute_error: 6.4903 - root_mean_squared_error: 9.8871 - mean_absolute_percentage_error: 36.3917 - val_loss: 7.0043 - val_mean_absolute_error: 6.9959 - val_root_mean_squared_error: 11.9674 - val_mean_absolute_percentage_error: 39.4588 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 52s 509ms/step - loss: 5.9784 - mean_absolute_error: 5.9798 - root_mean_squared_error: 9.1831 - mean_absolute_percentage_error: 33.4138 - val_loss: 7.0674 - val_mean_absolute_error: 7.0720 - val_root_mean_squared_error: 12.0530 - val_mean_absolute_percentage_error: 39.4436 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 51s 498ms/step - loss: 6.2558 - mean_absolute_error: 6.2621 - root_mean_squared_error: 9.6289 - mean_absolute_percentage_error: 34.6632 - val_loss: 7.0306 - val_mean_absolute_error: 7.0356 - val_root_mean_squared_error: 12.0326 - val_mean_absolute_percentage_error: 41.9561 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 53s 519ms/step - loss: 6.2970 - mean_absolute_error: 6.3058 - root_mean_squared_error: 9.4836 - mean_absolute_percentage_error: 34.5370 - val_loss: 6.9466 - val_mean_absolute_error: 6.9589 - val_root_mean_squared_error: 11.8427 - val_mean_absolute_percentage_error: 39.0133 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 53s 511ms/step - loss: 6.2334 - mean_absolute_error: 6.2481 - root_mean_squared_error: 9.2945 - mean_absolute_percentage_error: 35.5926 - val_loss: 6.9327 - val_mean_absolute_error: 6.9449 - val_root_mean_squared_error: 11.7201 - val_mean_absolute_percentage_error: 39.6673 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 52s 509ms/step - loss: 6.2288 - mean_absolute_error: 6.2469 - root_mean_squared_error: 9.6297 - mean_absolute_percentage_error: 36.0848 - val_loss: 7.1246 - val_mean_absolute_error: 7.1468 - val_root_mean_squared_error: 11.9745 - val_mean_absolute_percentage_error: 38.9525 - lr: 1.0000e-04
# Epoch 22/100
# 103/103 [==============================] - 52s 510ms/step - loss: 6.1682 - mean_absolute_error: 6.1902 - root_mean_squared_error: 9.3394 - mean_absolute_percentage_error: 34.6115 - val_loss: 6.7819 - val_mean_absolute_error: 6.8028 - val_root_mean_squared_error: 11.6361 - val_mean_absolute_percentage_error: 37.7510 - lr: 1.0000e-04
# Epoch 23/100
# 103/103 [==============================] - 51s 494ms/step - loss: 5.8154 - mean_absolute_error: 5.8403 - root_mean_squared_error: 8.8762 - mean_absolute_percentage_error: 32.3471 - val_loss: 8.3486 - val_mean_absolute_error: 8.3770 - val_root_mean_squared_error: 13.0942 - val_mean_absolute_percentage_error: 44.7079 - lr: 1.0000e-04
# Epoch 24/100
# 103/103 [==============================] - 53s 520ms/step - loss: 5.7423 - mean_absolute_error: 5.7728 - root_mean_squared_error: 8.7467 - mean_absolute_percentage_error: 32.3919 - val_loss: 6.6600 - val_mean_absolute_error: 6.6852 - val_root_mean_squared_error: 11.3602 - val_mean_absolute_percentage_error: 39.0928 - lr: 1.0000e-04
# Epoch 25/100
# 103/103 [==============================] - 52s 503ms/step - loss: 5.8502 - mean_absolute_error: 5.8789 - root_mean_squared_error: 8.9677 - mean_absolute_percentage_error: 33.4242 - val_loss: 6.6260 - val_mean_absolute_error: 6.6460 - val_root_mean_squared_error: 11.3489 - val_mean_absolute_percentage_error: 37.5473 - lr: 1.0000e-04
# Epoch 26/100
# 103/103 [==============================] - 52s 509ms/step - loss: 5.6982 - mean_absolute_error: 5.7300 - root_mean_squared_error: 8.6868 - mean_absolute_percentage_error: 31.6086 - val_loss: 6.7317 - val_mean_absolute_error: 6.7622 - val_root_mean_squared_error: 11.4573 - val_mean_absolute_percentage_error: 36.8028 - lr: 1.0000e-04
# Epoch 27/100
# 103/103 [==============================] - 51s 500ms/step - loss: 5.8982 - mean_absolute_error: 5.9341 - root_mean_squared_error: 9.0558 - mean_absolute_percentage_error: 32.0551 - val_loss: 6.6253 - val_mean_absolute_error: 6.6548 - val_root_mean_squared_error: 11.4826 - val_mean_absolute_percentage_error: 36.1894 - lr: 1.0000e-04
# Epoch 28/100
# 103/103 [==============================] - 50s 491ms/step - loss: 5.6474 - mean_absolute_error: 5.6847 - root_mean_squared_error: 8.6722 - mean_absolute_percentage_error: 30.4336 - val_loss: 6.4260 - val_mean_absolute_error: 6.4596 - val_root_mean_squared_error: 11.2638 - val_mean_absolute_percentage_error: 36.1244 - lr: 1.0000e-04
# Epoch 29/100
# 103/103 [==============================] - 51s 497ms/step - loss: 5.6891 - mean_absolute_error: 5.7270 - root_mean_squared_error: 8.7493 - mean_absolute_percentage_error: 31.0061 - val_loss: 7.3977 - val_mean_absolute_error: 7.4348 - val_root_mean_squared_error: 12.2788 - val_mean_absolute_percentage_error: 34.8400 - lr: 1.0000e-04
# Epoch 30/100
# 103/103 [==============================] - 52s 503ms/step - loss: 5.7897 - mean_absolute_error: 5.8335 - root_mean_squared_error: 8.8496 - mean_absolute_percentage_error: 31.6371 - val_loss: 6.3589 - val_mean_absolute_error: 6.3943 - val_root_mean_squared_error: 11.3496 - val_mean_absolute_percentage_error: 35.3110 - lr: 1.0000e-04
# Epoch 31/100
# 103/103 [==============================] - 52s 502ms/step - loss: 5.3789 - mean_absolute_error: 5.4230 - root_mean_squared_error: 8.0025 - mean_absolute_percentage_error: 30.9954 - val_loss: 6.3651 - val_mean_absolute_error: 6.4008 - val_root_mean_squared_error: 11.1882 - val_mean_absolute_percentage_error: 36.8496 - lr: 1.0000e-04
# Epoch 32/100
# 103/103 [==============================] - 52s 502ms/step - loss: 5.3547 - mean_absolute_error: 5.4001 - root_mean_squared_error: 8.2166 - mean_absolute_percentage_error: 28.8906 - val_loss: 6.3267 - val_mean_absolute_error: 6.3635 - val_root_mean_squared_error: 11.3558 - val_mean_absolute_percentage_error: 34.8058 - lr: 1.0000e-04
# Epoch 33/100
# 103/103 [==============================] - 51s 495ms/step - loss: 5.2000 - mean_absolute_error: 5.2450 - root_mean_squared_error: 8.1102 - mean_absolute_percentage_error: 28.1624 - val_loss: 6.1512 - val_mean_absolute_error: 6.1919 - val_root_mean_squared_error: 10.8894 - val_mean_absolute_percentage_error: 37.1482 - lr: 1.0000e-04
# Epoch 34/100
# 103/103 [==============================] - 52s 502ms/step - loss: 5.4394 - mean_absolute_error: 5.4882 - root_mean_squared_error: 8.6199 - mean_absolute_percentage_error: 27.9137 - val_loss: 6.1683 - val_mean_absolute_error: 6.2188 - val_root_mean_squared_error: 10.9737 - val_mean_absolute_percentage_error: 36.2649 - lr: 1.0000e-04
# Epoch 35/100
# 103/103 [==============================] - 52s 502ms/step - loss: 5.3570 - mean_absolute_error: 5.4064 - root_mean_squared_error: 8.3315 - mean_absolute_percentage_error: 28.0063 - val_loss: 6.8220 - val_mean_absolute_error: 6.8716 - val_root_mean_squared_error: 11.8457 - val_mean_absolute_percentage_error: 33.2364 - lr: 1.0000e-04
# Epoch 36/100
# 103/103 [==============================] - 52s 502ms/step - loss: 5.2791 - mean_absolute_error: 5.3291 - root_mean_squared_error: 8.1985 - mean_absolute_percentage_error: 27.9683 - val_loss: 7.0719 - val_mean_absolute_error: 7.1187 - val_root_mean_squared_error: 11.3874 - val_mean_absolute_percentage_error: 38.0647 - lr: 1.0000e-04
# Epoch 37/100
# 103/103 [==============================] - 51s 493ms/step - loss: 5.0605 - mean_absolute_error: 5.1120 - root_mean_squared_error: 7.9034 - mean_absolute_percentage_error: 26.7157 - val_loss: 6.2362 - val_mean_absolute_error: 6.2839 - val_root_mean_squared_error: 10.9432 - val_mean_absolute_percentage_error: 34.6246 - lr: 1.0000e-04
# Epoch 38/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.9569 - mean_absolute_error: 5.0083 - root_mean_squared_error: 8.0476 - mean_absolute_percentage_error: 26.5324 - val_loss: 6.0633 - val_mean_absolute_error: 6.1074 - val_root_mean_squared_error: 10.9448 - val_mean_absolute_percentage_error: 34.3082 - lr: 1.0000e-04
# Epoch 39/100
# 103/103 [==============================] - 51s 499ms/step - loss: 5.4864 - mean_absolute_error: 5.5427 - root_mean_squared_error: 8.4159 - mean_absolute_percentage_error: 28.1082 - val_loss: 6.3833 - val_mean_absolute_error: 6.4353 - val_root_mean_squared_error: 11.0727 - val_mean_absolute_percentage_error: 36.2562 - lr: 1.0000e-04
# Epoch 40/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.9093 - mean_absolute_error: 4.9655 - root_mean_squared_error: 7.6349 - mean_absolute_percentage_error: 23.8381 - val_loss: 6.4305 - val_mean_absolute_error: 6.4805 - val_root_mean_squared_error: 10.9372 - val_mean_absolute_percentage_error: 35.6069 - lr: 1.0000e-04
# Epoch 41/100
# 103/103 [==============================] - 52s 501ms/step - loss: 4.9986 - mean_absolute_error: 5.0558 - root_mean_squared_error: 7.8655 - mean_absolute_percentage_error: 25.9488 - val_loss: 6.1875 - val_mean_absolute_error: 6.2374 - val_root_mean_squared_error: 10.9446 - val_mean_absolute_percentage_error: 33.9951 - lr: 1.0000e-04
# Epoch 42/100
# 103/103 [==============================] - 50s 491ms/step - loss: 4.7881 - mean_absolute_error: 4.8467 - root_mean_squared_error: 7.4388 - mean_absolute_percentage_error: 24.6188 - val_loss: 6.0649 - val_mean_absolute_error: 6.1247 - val_root_mean_squared_error: 10.9133 - val_mean_absolute_percentage_error: 32.3130 - lr: 1.0000e-04
# Epoch 43/100
# 103/103 [==============================] - 50s 488ms/step - loss: 4.6711 - mean_absolute_error: 4.7283 - root_mean_squared_error: 7.1693 - mean_absolute_percentage_error: 23.8312 - val_loss: 6.2027 - val_mean_absolute_error: 6.2567 - val_root_mean_squared_error: 11.0313 - val_mean_absolute_percentage_error: 34.0088 - lr: 1.0000e-04
# Epoch 44/100
# 103/103 [==============================] - 50s 488ms/step - loss: 4.8700 - mean_absolute_error: 4.9293 - root_mean_squared_error: 7.6864 - mean_absolute_percentage_error: 23.7439 - val_loss: 5.8772 - val_mean_absolute_error: 5.9219 - val_root_mean_squared_error: 10.6813 - val_mean_absolute_percentage_error: 32.7075 - lr: 5.0000e-05
# Epoch 45/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.9856 - mean_absolute_error: 5.0476 - root_mean_squared_error: 7.7465 - mean_absolute_percentage_error: 24.2240 - val_loss: 6.6726 - val_mean_absolute_error: 6.7277 - val_root_mean_squared_error: 11.5115 - val_mean_absolute_percentage_error: 35.8365 - lr: 5.0000e-05
# Epoch 46/100
# 103/103 [==============================] - 51s 500ms/step - loss: 4.9475 - mean_absolute_error: 5.0095 - root_mean_squared_error: 7.9574 - mean_absolute_percentage_error: 24.1706 - val_loss: 6.1151 - val_mean_absolute_error: 6.1784 - val_root_mean_squared_error: 11.0150 - val_mean_absolute_percentage_error: 31.4089 - lr: 5.0000e-05
# Epoch 47/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.7106 - mean_absolute_error: 4.7710 - root_mean_squared_error: 7.2820 - mean_absolute_percentage_error: 22.9699 - val_loss: 5.9789 - val_mean_absolute_error: 6.0388 - val_root_mean_squared_error: 10.7069 - val_mean_absolute_percentage_error: 32.8123 - lr: 5.0000e-05
# Epoch 48/100
# 103/103 [==============================] - 50s 488ms/step - loss: 4.7754 - mean_absolute_error: 4.8365 - root_mean_squared_error: 7.4123 - mean_absolute_percentage_error: 23.8071 - val_loss: 5.9992 - val_mean_absolute_error: 6.0572 - val_root_mean_squared_error: 10.7266 - val_mean_absolute_percentage_error: 32.5969 - lr: 5.0000e-05
# Epoch 49/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.4294 - mean_absolute_error: 4.4894 - root_mean_squared_error: 7.0090 - mean_absolute_percentage_error: 21.0738 - val_loss: 5.7809 - val_mean_absolute_error: 5.8329 - val_root_mean_squared_error: 10.6527 - val_mean_absolute_percentage_error: 32.0652 - lr: 5.0000e-05
# Epoch 50/100
# 103/103 [==============================] - 52s 504ms/step - loss: 4.5063 - mean_absolute_error: 4.5661 - root_mean_squared_error: 7.0687 - mean_absolute_percentage_error: 21.0930 - val_loss: 5.9196 - val_mean_absolute_error: 5.9879 - val_root_mean_squared_error: 10.6357 - val_mean_absolute_percentage_error: 32.5830 - lr: 5.0000e-05
# Epoch 51/100
# 103/103 [==============================] - 51s 497ms/step - loss: 4.8433 - mean_absolute_error: 4.9033 - root_mean_squared_error: 7.7189 - mean_absolute_percentage_error: 23.6456 - val_loss: 5.6681 - val_mean_absolute_error: 5.7136 - val_root_mean_squared_error: 10.5621 - val_mean_absolute_percentage_error: 31.0816 - lr: 5.0000e-05
# Epoch 52/100
# 103/103 [==============================] - 51s 495ms/step - loss: 4.9267 - mean_absolute_error: 4.9908 - root_mean_squared_error: 7.7959 - mean_absolute_percentage_error: 22.2827 - val_loss: 5.9837 - val_mean_absolute_error: 6.0488 - val_root_mean_squared_error: 10.6330 - val_mean_absolute_percentage_error: 32.2540 - lr: 5.0000e-05
# Epoch 53/100
# 103/103 [==============================] - 52s 506ms/step - loss: 4.4344 - mean_absolute_error: 4.4950 - root_mean_squared_error: 7.0562 - mean_absolute_percentage_error: 21.8956 - val_loss: 5.7270 - val_mean_absolute_error: 5.7857 - val_root_mean_squared_error: 10.6866 - val_mean_absolute_percentage_error: 31.3277 - lr: 5.0000e-05
# Epoch 54/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.7427 - mean_absolute_error: 4.8054 - root_mean_squared_error: 7.3322 - mean_absolute_percentage_error: 22.1374 - val_loss: 5.9012 - val_mean_absolute_error: 5.9555 - val_root_mean_squared_error: 10.7467 - val_mean_absolute_percentage_error: 31.7371 - lr: 5.0000e-05
# Epoch 55/100
# 103/103 [==============================] - 51s 501ms/step - loss: 4.7159 - mean_absolute_error: 4.7769 - root_mean_squared_error: 7.2907 - mean_absolute_percentage_error: 21.4497 - val_loss: 5.6021 - val_mean_absolute_error: 5.6536 - val_root_mean_squared_error: 10.5180 - val_mean_absolute_percentage_error: 30.8216 - lr: 5.0000e-05
# Epoch 56/100
# 103/103 [==============================] - 52s 501ms/step - loss: 4.4795 - mean_absolute_error: 4.5436 - root_mean_squared_error: 7.0489 - mean_absolute_percentage_error: 21.2326 - val_loss: 5.9249 - val_mean_absolute_error: 5.9953 - val_root_mean_squared_error: 10.7542 - val_mean_absolute_percentage_error: 31.6508 - lr: 5.0000e-05
# Epoch 57/100
# 103/103 [==============================] - 52s 501ms/step - loss: 4.4168 - mean_absolute_error: 4.4819 - root_mean_squared_error: 7.0299 - mean_absolute_percentage_error: 20.3901 - val_loss: 5.6431 - val_mean_absolute_error: 5.6926 - val_root_mean_squared_error: 10.5862 - val_mean_absolute_percentage_error: 31.4601 - lr: 5.0000e-05
# Epoch 58/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.2026 - mean_absolute_error: 4.2622 - root_mean_squared_error: 6.6207 - mean_absolute_percentage_error: 19.7567 - val_loss: 5.5822 - val_mean_absolute_error: 5.6391 - val_root_mean_squared_error: 10.4519 - val_mean_absolute_percentage_error: 31.7772 - lr: 5.0000e-05
# Epoch 59/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.4508 - mean_absolute_error: 4.5176 - root_mean_squared_error: 7.2086 - mean_absolute_percentage_error: 20.2711 - val_loss: 5.6395 - val_mean_absolute_error: 5.7052 - val_root_mean_squared_error: 10.5259 - val_mean_absolute_percentage_error: 30.9271 - lr: 5.0000e-05
# Epoch 60/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.5947 - mean_absolute_error: 4.6615 - root_mean_squared_error: 7.2405 - mean_absolute_percentage_error: 21.2945 - val_loss: 5.5511 - val_mean_absolute_error: 5.6004 - val_root_mean_squared_error: 10.5548 - val_mean_absolute_percentage_error: 30.6736 - lr: 5.0000e-05
# Epoch 61/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.2965 - mean_absolute_error: 4.3601 - root_mean_squared_error: 6.7399 - mean_absolute_percentage_error: 20.6063 - val_loss: 5.6784 - val_mean_absolute_error: 5.7466 - val_root_mean_squared_error: 10.5437 - val_mean_absolute_percentage_error: 31.0035 - lr: 5.0000e-05
# Epoch 62/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.2502 - mean_absolute_error: 4.3131 - root_mean_squared_error: 6.7321 - mean_absolute_percentage_error: 19.6202 - val_loss: 5.5268 - val_mean_absolute_error: 5.5823 - val_root_mean_squared_error: 10.4661 - val_mean_absolute_percentage_error: 31.2631 - lr: 5.0000e-05
# Epoch 63/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.2159 - mean_absolute_error: 4.2853 - root_mean_squared_error: 6.5299 - mean_absolute_percentage_error: 20.4538 - val_loss: 5.6359 - val_mean_absolute_error: 5.6944 - val_root_mean_squared_error: 10.5230 - val_mean_absolute_percentage_error: 30.6903 - lr: 5.0000e-05
# Epoch 64/100
# 103/103 [==============================] - 51s 501ms/step - loss: 4.2996 - mean_absolute_error: 4.3665 - root_mean_squared_error: 6.9533 - mean_absolute_percentage_error: 20.4269 - val_loss: 5.5312 - val_mean_absolute_error: 5.5783 - val_root_mean_squared_error: 10.5232 - val_mean_absolute_percentage_error: 30.5680 - lr: 5.0000e-05
# Epoch 65/100
# 103/103 [==============================] - 51s 496ms/step - loss: 4.3069 - mean_absolute_error: 4.3742 - root_mean_squared_error: 6.7989 - mean_absolute_percentage_error: 20.6640 - val_loss: 5.6930 - val_mean_absolute_error: 5.7489 - val_root_mean_squared_error: 10.6763 - val_mean_absolute_percentage_error: 30.3211 - lr: 5.0000e-05
# Epoch 66/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.3964 - mean_absolute_error: 4.4659 - root_mean_squared_error: 6.8793 - mean_absolute_percentage_error: 21.1752 - val_loss: 5.7027 - val_mean_absolute_error: 5.7582 - val_root_mean_squared_error: 10.5797 - val_mean_absolute_percentage_error: 31.3078 - lr: 5.0000e-05
# Epoch 67/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.2971 - mean_absolute_error: 4.3644 - root_mean_squared_error: 6.8685 - mean_absolute_percentage_error: 19.7751 - val_loss: 5.8687 - val_mean_absolute_error: 5.9313 - val_root_mean_squared_error: 10.8043 - val_mean_absolute_percentage_error: 31.5838 - lr: 5.0000e-05
# Epoch 68/100
# 103/103 [==============================] - 52s 504ms/step - loss: 4.1322 - mean_absolute_error: 4.2018 - root_mean_squared_error: 6.4955 - mean_absolute_percentage_error: 19.4713 - val_loss: 5.5447 - val_mean_absolute_error: 5.6049 - val_root_mean_squared_error: 10.5409 - val_mean_absolute_percentage_error: 30.2191 - lr: 2.5000e-05
# Epoch 69/100
# 103/103 [==============================] - 51s 497ms/step - loss: 4.2334 - mean_absolute_error: 4.2995 - root_mean_squared_error: 6.8260 - mean_absolute_percentage_error: 19.2292 - val_loss: 5.5653 - val_mean_absolute_error: 5.6264 - val_root_mean_squared_error: 10.5321 - val_mean_absolute_percentage_error: 30.2405 - lr: 2.5000e-05
# Epoch 70/100
# 103/103 [==============================] - 51s 497ms/step - loss: 4.2267 - mean_absolute_error: 4.2935 - root_mean_squared_error: 6.8281 - mean_absolute_percentage_error: 19.1745 - val_loss: 5.5257 - val_mean_absolute_error: 5.5823 - val_root_mean_squared_error: 10.4978 - val_mean_absolute_percentage_error: 30.3287 - lr: 2.5000e-05
# Epoch 71/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.0510 - mean_absolute_error: 4.1189 - root_mean_squared_error: 6.3800 - mean_absolute_percentage_error: 19.3863 - val_loss: 5.4614 - val_mean_absolute_error: 5.5204 - val_root_mean_squared_error: 10.4601 - val_mean_absolute_percentage_error: 29.8745 - lr: 2.5000e-05
# Epoch 72/100
# 103/103 [==============================] - 52s 504ms/step - loss: 4.2373 - mean_absolute_error: 4.3053 - root_mean_squared_error: 6.6295 - mean_absolute_percentage_error: 19.3471 - val_loss: 5.5489 - val_mean_absolute_error: 5.6206 - val_root_mean_squared_error: 10.4542 - val_mean_absolute_percentage_error: 30.9632 - lr: 2.5000e-05
# Epoch 73/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.4152 - mean_absolute_error: 4.4798 - root_mean_squared_error: 7.1887 - mean_absolute_percentage_error: 19.0897 - val_loss: 5.5592 - val_mean_absolute_error: 5.6268 - val_root_mean_squared_error: 10.5024 - val_mean_absolute_percentage_error: 30.4314 - lr: 2.5000e-05
# Epoch 74/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.0454 - mean_absolute_error: 4.1121 - root_mean_squared_error: 6.5168 - mean_absolute_percentage_error: 19.2067 - val_loss: 5.5547 - val_mean_absolute_error: 5.6258 - val_root_mean_squared_error: 10.5695 - val_mean_absolute_percentage_error: 30.0210 - lr: 2.5000e-05
# Epoch 75/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.2109 - mean_absolute_error: 4.2823 - root_mean_squared_error: 6.6395 - mean_absolute_percentage_error: 18.8919 - val_loss: 5.4562 - val_mean_absolute_error: 5.5169 - val_root_mean_squared_error: 10.4365 - val_mean_absolute_percentage_error: 30.2694 - lr: 2.5000e-05
# Epoch 76/100
# 103/103 [==============================] - 51s 496ms/step - loss: 4.1808 - mean_absolute_error: 4.2500 - root_mean_squared_error: 6.7363 - mean_absolute_percentage_error: 18.9491 - val_loss: 5.5275 - val_mean_absolute_error: 5.5943 - val_root_mean_squared_error: 10.4866 - val_mean_absolute_percentage_error: 30.1139 - lr: 2.5000e-05
# Epoch 77/100
# 103/103 [==============================] - 51s 501ms/step - loss: 4.1158 - mean_absolute_error: 4.1809 - root_mean_squared_error: 6.5366 - mean_absolute_percentage_error: 19.0511 - val_loss: 5.4912 - val_mean_absolute_error: 5.5526 - val_root_mean_squared_error: 10.5034 - val_mean_absolute_percentage_error: 30.3098 - lr: 2.5000e-05
# Epoch 78/100
# 103/103 [==============================] - 51s 496ms/step - loss: 4.2709 - mean_absolute_error: 4.3438 - root_mean_squared_error: 6.8374 - mean_absolute_percentage_error: 19.8967 - val_loss: 5.5214 - val_mean_absolute_error: 5.5809 - val_root_mean_squared_error: 10.4874 - val_mean_absolute_percentage_error: 30.5881 - lr: 2.5000e-05
# Epoch 79/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.0859 - mean_absolute_error: 4.1573 - root_mean_squared_error: 6.5037 - mean_absolute_percentage_error: 18.6643 - val_loss: 5.4510 - val_mean_absolute_error: 5.5167 - val_root_mean_squared_error: 10.4485 - val_mean_absolute_percentage_error: 30.1996 - lr: 2.5000e-05
# Epoch 80/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.1238 - mean_absolute_error: 4.1940 - root_mean_squared_error: 6.5784 - mean_absolute_percentage_error: 18.6068 - val_loss: 5.4903 - val_mean_absolute_error: 5.5463 - val_root_mean_squared_error: 10.4082 - val_mean_absolute_percentage_error: 30.4629 - lr: 2.5000e-05
# Epoch 81/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.0432 - mean_absolute_error: 4.1125 - root_mean_squared_error: 6.5385 - mean_absolute_percentage_error: 18.6831 - val_loss: 5.5171 - val_mean_absolute_error: 5.5766 - val_root_mean_squared_error: 10.5911 - val_mean_absolute_percentage_error: 29.6253 - lr: 2.5000e-05
# Epoch 82/100
# 103/103 [==============================] - 52s 501ms/step - loss: 4.1760 - mean_absolute_error: 4.2466 - root_mean_squared_error: 6.6273 - mean_absolute_percentage_error: 18.6870 - val_loss: 5.4409 - val_mean_absolute_error: 5.5036 - val_root_mean_squared_error: 10.4333 - val_mean_absolute_percentage_error: 30.3999 - lr: 2.5000e-05
# Epoch 83/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.1077 - mean_absolute_error: 4.1802 - root_mean_squared_error: 6.3952 - mean_absolute_percentage_error: 18.4043 - val_loss: 5.5187 - val_mean_absolute_error: 5.5803 - val_root_mean_squared_error: 10.4566 - val_mean_absolute_percentage_error: 30.2555 - lr: 2.5000e-05
# Epoch 84/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.2916 - mean_absolute_error: 4.3656 - root_mean_squared_error: 6.9060 - mean_absolute_percentage_error: 19.1098 - val_loss: 5.4745 - val_mean_absolute_error: 5.5287 - val_root_mean_squared_error: 10.4483 - val_mean_absolute_percentage_error: 29.9967 - lr: 2.5000e-05
# Epoch 85/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.1786 - mean_absolute_error: 4.2528 - root_mean_squared_error: 6.5682 - mean_absolute_percentage_error: 19.3836 - val_loss: 5.4701 - val_mean_absolute_error: 5.5290 - val_root_mean_squared_error: 10.4825 - val_mean_absolute_percentage_error: 30.2683 - lr: 2.5000e-05
# Epoch 86/100
# 103/103 [==============================] - 52s 501ms/step - loss: 3.8531 - mean_absolute_error: 3.9253 - root_mean_squared_error: 6.0942 - mean_absolute_percentage_error: 18.3129 - val_loss: 5.6140 - val_mean_absolute_error: 5.6946 - val_root_mean_squared_error: 10.5130 - val_mean_absolute_percentage_error: 30.2752 - lr: 2.5000e-05
# Epoch 87/100
# 103/103 [==============================] - 52s 503ms/step - loss: 4.2995 - mean_absolute_error: 4.3723 - root_mean_squared_error: 6.7453 - mean_absolute_percentage_error: 19.7337 - val_loss: 5.4390 - val_mean_absolute_error: 5.5005 - val_root_mean_squared_error: 10.4109 - val_mean_absolute_percentage_error: 30.2670 - lr: 2.5000e-05
# Epoch 88/100
# 103/103 [==============================] - 51s 499ms/step - loss: 3.9361 - mean_absolute_error: 4.0032 - root_mean_squared_error: 6.3968 - mean_absolute_percentage_error: 17.5053 - val_loss: 5.5561 - val_mean_absolute_error: 5.6170 - val_root_mean_squared_error: 10.6895 - val_mean_absolute_percentage_error: 29.0772 - lr: 2.5000e-05
# Epoch 89/100
# 103/103 [==============================] - 51s 500ms/step - loss: 4.1176 - mean_absolute_error: 4.1895 - root_mean_squared_error: 6.5812 - mean_absolute_percentage_error: 18.5643 - val_loss: 5.5184 - val_mean_absolute_error: 5.5835 - val_root_mean_squared_error: 10.4277 - val_mean_absolute_percentage_error: 30.1286 - lr: 2.5000e-05
# Epoch 90/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.0585 - mean_absolute_error: 4.1296 - root_mean_squared_error: 6.5226 - mean_absolute_percentage_error: 18.4203 - val_loss: 5.3901 - val_mean_absolute_error: 5.4417 - val_root_mean_squared_error: 10.3528 - val_mean_absolute_percentage_error: 29.8890 - lr: 2.5000e-05
# Epoch 91/100
# 103/103 [==============================] - 52s 502ms/step - loss: 4.0578 - mean_absolute_error: 4.1287 - root_mean_squared_error: 6.5360 - mean_absolute_percentage_error: 19.6266 - val_loss: 5.4171 - val_mean_absolute_error: 5.4732 - val_root_mean_squared_error: 10.3756 - val_mean_absolute_percentage_error: 29.9146 - lr: 2.5000e-05
# Epoch 92/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.1133 - mean_absolute_error: 4.1877 - root_mean_squared_error: 6.5710 - mean_absolute_percentage_error: 18.0619 - val_loss: 5.3628 - val_mean_absolute_error: 5.4139 - val_root_mean_squared_error: 10.3821 - val_mean_absolute_percentage_error: 29.4913 - lr: 2.5000e-05
# Epoch 93/100
# 103/103 [==============================] - 51s 500ms/step - loss: 3.9796 - mean_absolute_error: 4.0496 - root_mean_squared_error: 6.3224 - mean_absolute_percentage_error: 17.4701 - val_loss: 5.4919 - val_mean_absolute_error: 5.5659 - val_root_mean_squared_error: 10.4667 - val_mean_absolute_percentage_error: 29.7211 - lr: 2.5000e-05
# Epoch 94/100
# 103/103 [==============================] - 51s 499ms/step - loss: 4.0405 - mean_absolute_error: 4.1157 - root_mean_squared_error: 6.3468 - mean_absolute_percentage_error: 18.7861 - val_loss: 5.3802 - val_mean_absolute_error: 5.4364 - val_root_mean_squared_error: 10.4758 - val_mean_absolute_percentage_error: 29.1716 - lr: 2.5000e-05
# Epoch 95/100
# 103/103 [==============================] - 51s 501ms/step - loss: 4.0148 - mean_absolute_error: 4.0863 - root_mean_squared_error: 6.4096 - mean_absolute_percentage_error: 18.2478 - val_loss: 5.4267 - val_mean_absolute_error: 5.4871 - val_root_mean_squared_error: 10.4021 - val_mean_absolute_percentage_error: 29.7230 - lr: 2.5000e-05
# Epoch 96/100
# 103/103 [==============================] - 52s 502ms/step - loss: 3.9845 - mean_absolute_error: 4.0565 - root_mean_squared_error: 6.3249 - mean_absolute_percentage_error: 18.1394 - val_loss: 5.3897 - val_mean_absolute_error: 5.4467 - val_root_mean_squared_error: 10.3205 - val_mean_absolute_percentage_error: 30.4226 - lr: 2.5000e-05
# Epoch 97/100
# 103/103 [==============================] - 51s 498ms/step - loss: 4.2005 - mean_absolute_error: 4.2736 - root_mean_squared_error: 6.7824 - mean_absolute_percentage_error: 18.4456 - val_loss: 5.4604 - val_mean_absolute_error: 5.5203 - val_root_mean_squared_error: 10.5156 - val_mean_absolute_percentage_error: 29.4313 - lr: 2.5000e-05
# Epoch 98/100
# 103/103 [==============================] - 51s 498ms/step - loss: 3.9996 - mean_absolute_error: 4.0725 - root_mean_squared_error: 6.2610 - mean_absolute_percentage_error: 17.4997 - val_loss: 5.4198 - val_mean_absolute_error: 5.4774 - val_root_mean_squared_error: 10.4675 - val_mean_absolute_percentage_error: 29.3491 - lr: 1.2500e-05
# Epoch 99/100
# 103/103 [==============================] - 51s 497ms/step - loss: 4.1445 - mean_absolute_error: 4.2200 - root_mean_squared_error: 6.6771 - mean_absolute_percentage_error: 18.4140 - val_loss: 5.4623 - val_mean_absolute_error: 5.5258 - val_root_mean_squared_error: 10.4164 - val_mean_absolute_percentage_error: 30.0277 - lr: 1.2500e-05
# Epoch 100/100
# 103/103 [==============================] - 51s 499ms/step - loss: 3.7377 - mean_absolute_error: 3.8102 - root_mean_squared_error: 5.9065 - mean_absolute_percentage_error: 16.8625 - val_loss: 5.3796 - val_mean_absolute_error: 5.4332 - val_root_mean_squared_error: 10.5111 - val_mean_absolute_percentage_error: 29.1679 - lr: 1.2500e-05

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 8s 226ms/step - loss: 5.3796 - mean_absolute_error: 5.4332 - root_mean_squared_error: 10.5111 - mean_absolute_percentage_error: 29.1679
# Model Loss: [5.379638195037842, 5.433199882507324, 10.511089324951172, 29.167940139770508]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 427ms/step
# Predicted Putusan: [7.3153915]

# %%
model_scenario_name = "BiLSTM_15"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 24). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_15\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_15\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_15"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted Putusan: [7.3153915]
