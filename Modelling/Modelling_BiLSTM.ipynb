# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_12816\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.LSTM(64, return_sequences=True)(embedding_layer)
lstm_output_2 = tf.keras.layers.LSTM(128, return_sequences=True)(lstm_output)
lstm_output_3 = tf.keras.layers.LSTM(64, return_sequences=True)(lstm_output_2)
lstm_output_4 = tf.keras.layers.LSTM(32, return_sequences=True)(lstm_output_3)
lstm_output_5 = tf.keras.layers.LSTM(32)(lstm_output_4)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu')(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu')(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu')(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([lstm_output_5, numerical_dense_3])

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(combined)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(concated_dense_1)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  lstm (LSTM)                    (None, 1024, 64)     82176       ['embedding[0][0]']
#
#  lstm_1 (LSTM)                  (None, 1024, 128)    98816       ['lstm[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  lstm_2 (LSTM)                  (None, 1024, 64)     49408       ['lstm_1[0][0]']
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  lstm_3 (LSTM)                  (None, 1024, 32)     12416       ['lstm_2[0][0]']
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  lstm_4 (LSTM)                  (None, 32)           8320        ['lstm_3[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 64)           0           ['lstm_4[0][0]',
#                                                                   'dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 128)          8320        ['concatenate[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,083,937
# Trainable params: 4,083,937
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 31s 250ms/step - loss: 16.0331 - mean_absolute_error: 16.5254 - root_mean_squared_error: 24.8901 - mean_absolute_percentage_error: 111.1305 - val_loss: 11.9877 - val_mean_absolute_error: 12.4764 - val_root_mean_squared_error: 18.8622 - val_mean_absolute_percentage_error: 100.5001
# Epoch 2/100
# 103/103 [==============================] - 25s 241ms/step - loss: 11.4528 - mean_absolute_error: 11.9411 - root_mean_squared_error: 17.6710 - mean_absolute_percentage_error: 89.2217 - val_loss: 11.5045 - val_mean_absolute_error: 11.9899 - val_root_mean_squared_error: 18.6068 - val_mean_absolute_percentage_error: 83.7822
# Epoch 3/100
# 103/103 [==============================] - 25s 239ms/step - loss: 11.1027 - mean_absolute_error: 11.5889 - root_mean_squared_error: 17.3435 - mean_absolute_percentage_error: 85.0522 - val_loss: 11.1774 - val_mean_absolute_error: 11.6636 - val_root_mean_squared_error: 18.1444 - val_mean_absolute_percentage_error: 85.3521
# Epoch 4/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.9899 - mean_absolute_error: 11.4770 - root_mean_squared_error: 17.2845 - mean_absolute_percentage_error: 81.5297 - val_loss: 10.8924 - val_mean_absolute_error: 11.3790 - val_root_mean_squared_error: 18.1061 - val_mean_absolute_percentage_error: 76.6002
# Epoch 5/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.9634 - mean_absolute_error: 11.4513 - root_mean_squared_error: 17.2688 - mean_absolute_percentage_error: 79.5755 - val_loss: 10.9647 - val_mean_absolute_error: 11.4483 - val_root_mean_squared_error: 18.0104 - val_mean_absolute_percentage_error: 77.7042
# Epoch 6/100
# 103/103 [==============================] - 25s 239ms/step - loss: 10.7340 - mean_absolute_error: 11.2219 - root_mean_squared_error: 17.1204 - mean_absolute_percentage_error: 75.1287 - val_loss: 10.7484 - val_mean_absolute_error: 11.2387 - val_root_mean_squared_error: 17.9190 - val_mean_absolute_percentage_error: 73.4912
# Epoch 7/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.8345 - mean_absolute_error: 11.3231 - root_mean_squared_error: 17.1820 - mean_absolute_percentage_error: 76.6565 - val_loss: 10.8887 - val_mean_absolute_error: 11.3748 - val_root_mean_squared_error: 17.9711 - val_mean_absolute_percentage_error: 80.1594
# Epoch 8/100
# 103/103 [==============================] - 25s 239ms/step - loss: 10.5541 - mean_absolute_error: 11.0408 - root_mean_squared_error: 17.0179 - mean_absolute_percentage_error: 74.1955 - val_loss: 10.6186 - val_mean_absolute_error: 11.1004 - val_root_mean_squared_error: 18.0448 - val_mean_absolute_percentage_error: 71.7309
# Epoch 9/100
# 103/103 [==============================] - 24s 238ms/step - loss: 10.4251 - mean_absolute_error: 10.9116 - root_mean_squared_error: 16.9226 - mean_absolute_percentage_error: 72.6738 - val_loss: 10.6995 - val_mean_absolute_error: 11.1857 - val_root_mean_squared_error: 18.3918 - val_mean_absolute_percentage_error: 62.6754
# Epoch 10/100
# 103/103 [==============================] - 25s 239ms/step - loss: 10.5014 - mean_absolute_error: 10.9892 - root_mean_squared_error: 17.1585 - mean_absolute_percentage_error: 70.1831 - val_loss: 11.1485 - val_mean_absolute_error: 11.6350 - val_root_mean_squared_error: 18.9825 - val_mean_absolute_percentage_error: 63.7340
# Epoch 11/100
# 103/103 [==============================] - 24s 238ms/step - loss: 10.4376 - mean_absolute_error: 10.9227 - root_mean_squared_error: 17.2541 - mean_absolute_percentage_error: 68.8281 - val_loss: 10.6022 - val_mean_absolute_error: 11.0847 - val_root_mean_squared_error: 18.2410 - val_mean_absolute_percentage_error: 62.8971
# Epoch 12/100
# 103/103 [==============================] - 25s 239ms/step - loss: 10.3871 - mean_absolute_error: 10.8738 - root_mean_squared_error: 17.1050 - mean_absolute_percentage_error: 67.6328 - val_loss: 10.5703 - val_mean_absolute_error: 11.0494 - val_root_mean_squared_error: 17.8524 - val_mean_absolute_percentage_error: 74.3431
# Epoch 13/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.3851 - mean_absolute_error: 10.8720 - root_mean_squared_error: 17.0947 - mean_absolute_percentage_error: 67.9460 - val_loss: 10.6408 - val_mean_absolute_error: 11.1311 - val_root_mean_squared_error: 18.0144 - val_mean_absolute_percentage_error: 65.6649
# Epoch 14/100
# 103/103 [==============================] - 24s 238ms/step - loss: 10.4259 - mean_absolute_error: 10.9103 - root_mean_squared_error: 17.2286 - mean_absolute_percentage_error: 66.8498 - val_loss: 10.4676 - val_mean_absolute_error: 10.9550 - val_root_mean_squared_error: 18.1296 - val_mean_absolute_percentage_error: 61.1171
# Epoch 15/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.3038 - mean_absolute_error: 10.7913 - root_mean_squared_error: 17.1466 - mean_absolute_percentage_error: 65.0961 - val_loss: 10.4234 - val_mean_absolute_error: 10.9062 - val_root_mean_squared_error: 18.0137 - val_mean_absolute_percentage_error: 64.6470
# Epoch 16/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.4604 - mean_absolute_error: 10.9470 - root_mean_squared_error: 17.3170 - mean_absolute_percentage_error: 65.6557 - val_loss: 10.6213 - val_mean_absolute_error: 11.1053 - val_root_mean_squared_error: 18.3709 - val_mean_absolute_percentage_error: 64.2044
# Epoch 17/100
# 103/103 [==============================] - 25s 239ms/step - loss: 10.1413 - mean_absolute_error: 10.6252 - root_mean_squared_error: 16.9523 - mean_absolute_percentage_error: 64.5717 - val_loss: 11.0263 - val_mean_absolute_error: 11.5135 - val_root_mean_squared_error: 18.2274 - val_mean_absolute_percentage_error: 70.0114
# Epoch 18/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.3096 - mean_absolute_error: 10.7933 - root_mean_squared_error: 17.1224 - mean_absolute_percentage_error: 64.1254 - val_loss: 10.3906 - val_mean_absolute_error: 10.8774 - val_root_mean_squared_error: 18.0415 - val_mean_absolute_percentage_error: 60.3020
# Epoch 19/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.1185 - mean_absolute_error: 10.6049 - root_mean_squared_error: 17.0200 - mean_absolute_percentage_error: 63.0210 - val_loss: 10.3583 - val_mean_absolute_error: 10.8429 - val_root_mean_squared_error: 17.9354 - val_mean_absolute_percentage_error: 67.0985
# Epoch 20/100
# 103/103 [==============================] - 24s 238ms/step - loss: 10.0777 - mean_absolute_error: 10.5609 - root_mean_squared_error: 16.9937 - mean_absolute_percentage_error: 61.6896 - val_loss: 10.4315 - val_mean_absolute_error: 10.9182 - val_root_mean_squared_error: 18.0613 - val_mean_absolute_percentage_error: 61.0409
# Epoch 21/100
# 103/103 [==============================] - 24s 238ms/step - loss: 9.9933 - mean_absolute_error: 10.4773 - root_mean_squared_error: 16.8995 - mean_absolute_percentage_error: 60.5276 - val_loss: 10.3402 - val_mean_absolute_error: 10.8235 - val_root_mean_squared_error: 18.0242 - val_mean_absolute_percentage_error: 59.5266
# Epoch 22/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.0887 - mean_absolute_error: 10.5712 - root_mean_squared_error: 16.9923 - mean_absolute_percentage_error: 60.2183 - val_loss: 10.3665 - val_mean_absolute_error: 10.8500 - val_root_mean_squared_error: 18.0495 - val_mean_absolute_percentage_error: 57.9359
# Epoch 23/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.1087 - mean_absolute_error: 10.5935 - root_mean_squared_error: 16.9768 - mean_absolute_percentage_error: 60.8856 - val_loss: 10.4272 - val_mean_absolute_error: 10.9123 - val_root_mean_squared_error: 18.1675 - val_mean_absolute_percentage_error: 59.6456
# Epoch 24/100
# 103/103 [==============================] - 24s 237ms/step - loss: 9.9558 - mean_absolute_error: 10.4387 - root_mean_squared_error: 16.8826 - mean_absolute_percentage_error: 59.5820 - val_loss: 10.7921 - val_mean_absolute_error: 11.2817 - val_root_mean_squared_error: 18.0940 - val_mean_absolute_percentage_error: 67.3863
# Epoch 25/100
# 103/103 [==============================] - 25s 239ms/step - loss: 9.9535 - mean_absolute_error: 10.4366 - root_mean_squared_error: 16.7922 - mean_absolute_percentage_error: 59.9641 - val_loss: 10.8180 - val_mean_absolute_error: 11.3029 - val_root_mean_squared_error: 18.0391 - val_mean_absolute_percentage_error: 63.0142
# Epoch 26/100
# 103/103 [==============================] - 25s 242ms/step - loss: 10.0829 - mean_absolute_error: 10.5648 - root_mean_squared_error: 17.0232 - mean_absolute_percentage_error: 60.2280 - val_loss: 10.6278 - val_mean_absolute_error: 11.1127 - val_root_mean_squared_error: 17.8985 - val_mean_absolute_percentage_error: 61.2949
# Epoch 27/100
# 103/103 [==============================] - 25s 240ms/step - loss: 10.1575 - mean_absolute_error: 10.6418 - root_mean_squared_error: 16.9955 - mean_absolute_percentage_error: 59.9586 - val_loss: 10.2442 - val_mean_absolute_error: 10.7276 - val_root_mean_squared_error: 17.8961 - val_mean_absolute_percentage_error: 55.7022
# Epoch 28/100
# 103/103 [==============================] - 24s 230ms/step - loss: 9.9336 - mean_absolute_error: 10.4162 - root_mean_squared_error: 16.7734 - mean_absolute_percentage_error: 58.8611 - val_loss: 10.5458 - val_mean_absolute_error: 11.0295 - val_root_mean_squared_error: 17.8887 - val_mean_absolute_percentage_error: 62.3502
# Epoch 29/100
# 103/103 [==============================] - 24s 231ms/step - loss: 10.0147 - mean_absolute_error: 10.4998 - root_mean_squared_error: 16.9119 - mean_absolute_percentage_error: 58.8601 - val_loss: 10.2564 - val_mean_absolute_error: 10.7441 - val_root_mean_squared_error: 17.8285 - val_mean_absolute_percentage_error: 60.3245
# Epoch 30/100
# 103/103 [==============================] - 25s 239ms/step - loss: 10.0059 - mean_absolute_error: 10.4903 - root_mean_squared_error: 16.8904 - mean_absolute_percentage_error: 58.6532 - val_loss: 10.3841 - val_mean_absolute_error: 10.8688 - val_root_mean_squared_error: 17.7834 - val_mean_absolute_percentage_error: 63.1686
# Epoch 31/100
# 103/103 [==============================] - 25s 239ms/step - loss: 9.9701 - mean_absolute_error: 10.4543 - root_mean_squared_error: 16.8768 - mean_absolute_percentage_error: 58.9138 - val_loss: 10.3039 - val_mean_absolute_error: 10.7881 - val_root_mean_squared_error: 17.8567 - val_mean_absolute_percentage_error: 60.5272
# Epoch 32/100
# 103/103 [==============================] - 24s 238ms/step - loss: 10.0648 - mean_absolute_error: 10.5504 - root_mean_squared_error: 17.0075 - mean_absolute_percentage_error: 59.2338 - val_loss: 10.2345 - val_mean_absolute_error: 10.7200 - val_root_mean_squared_error: 17.9993 - val_mean_absolute_percentage_error: 54.5895
# Epoch 33/100
# 103/103 [==============================] - 25s 239ms/step - loss: 9.8273 - mean_absolute_error: 10.3092 - root_mean_squared_error: 16.7649 - mean_absolute_percentage_error: 56.6616 - val_loss: 10.1725 - val_mean_absolute_error: 10.6557 - val_root_mean_squared_error: 17.8209 - val_mean_absolute_percentage_error: 57.6615
# Epoch 34/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.8041 - mean_absolute_error: 10.2909 - root_mean_squared_error: 16.7316 - mean_absolute_percentage_error: 55.8582 - val_loss: 10.3335 - val_mean_absolute_error: 10.8166 - val_root_mean_squared_error: 18.3262 - val_mean_absolute_percentage_error: 53.7485
# Epoch 35/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.8655 - mean_absolute_error: 10.3491 - root_mean_squared_error: 16.7288 - mean_absolute_percentage_error: 58.2501 - val_loss: 10.3748 - val_mean_absolute_error: 10.8567 - val_root_mean_squared_error: 18.2413 - val_mean_absolute_percentage_error: 54.9773
# Epoch 36/100
# 103/103 [==============================] - 26s 250ms/step - loss: 9.9421 - mean_absolute_error: 10.4243 - root_mean_squared_error: 16.8262 - mean_absolute_percentage_error: 56.8791 - val_loss: 10.4763 - val_mean_absolute_error: 10.9642 - val_root_mean_squared_error: 17.9014 - val_mean_absolute_percentage_error: 63.7429
# Epoch 37/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.8471 - mean_absolute_error: 10.3325 - root_mean_squared_error: 16.7386 - mean_absolute_percentage_error: 57.5268 - val_loss: 10.2279 - val_mean_absolute_error: 10.7110 - val_root_mean_squared_error: 17.7825 - val_mean_absolute_percentage_error: 59.4748
# Epoch 38/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.8969 - mean_absolute_error: 10.3819 - root_mean_squared_error: 16.7507 - mean_absolute_percentage_error: 57.3881 - val_loss: 11.0802 - val_mean_absolute_error: 11.5661 - val_root_mean_squared_error: 19.2142 - val_mean_absolute_percentage_error: 50.0458
# Epoch 39/100
# 103/103 [==============================] - 25s 242ms/step - loss: 10.0578 - mean_absolute_error: 10.5431 - root_mean_squared_error: 16.9694 - mean_absolute_percentage_error: 56.9869 - val_loss: 10.2626 - val_mean_absolute_error: 10.7450 - val_root_mean_squared_error: 18.0514 - val_mean_absolute_percentage_error: 57.2875
# Epoch 40/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.7950 - mean_absolute_error: 10.2771 - root_mean_squared_error: 16.7428 - mean_absolute_percentage_error: 57.8047 - val_loss: 10.0790 - val_mean_absolute_error: 10.5642 - val_root_mean_squared_error: 17.9046 - val_mean_absolute_percentage_error: 54.7089
# Epoch 41/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.7584 - mean_absolute_error: 10.2428 - root_mean_squared_error: 16.6041 - mean_absolute_percentage_error: 56.7735 - val_loss: 10.8502 - val_mean_absolute_error: 11.3347 - val_root_mean_squared_error: 18.8759 - val_mean_absolute_percentage_error: 51.9924
# Epoch 42/100
# 103/103 [==============================] - 25s 240ms/step - loss: 9.9388 - mean_absolute_error: 10.4239 - root_mean_squared_error: 16.7484 - mean_absolute_percentage_error: 57.0239 - val_loss: 10.2081 - val_mean_absolute_error: 10.6917 - val_root_mean_squared_error: 17.8141 - val_mean_absolute_percentage_error: 57.1572
# Epoch 43/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.9056 - mean_absolute_error: 10.3898 - root_mean_squared_error: 16.6852 - mean_absolute_percentage_error: 56.5952 - val_loss: 10.5285 - val_mean_absolute_error: 11.0117 - val_root_mean_squared_error: 18.3398 - val_mean_absolute_percentage_error: 51.0525
# Epoch 44/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.7877 - mean_absolute_error: 10.2697 - root_mean_squared_error: 16.7191 - mean_absolute_percentage_error: 56.5275 - val_loss: 10.2800 - val_mean_absolute_error: 10.7627 - val_root_mean_squared_error: 18.1480 - val_mean_absolute_percentage_error: 54.6308
# Epoch 45/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.7733 - mean_absolute_error: 10.2566 - root_mean_squared_error: 16.7004 - mean_absolute_percentage_error: 56.0296 - val_loss: 10.3926 - val_mean_absolute_error: 10.8814 - val_root_mean_squared_error: 17.6235 - val_mean_absolute_percentage_error: 62.0146
# Epoch 46/100
# 103/103 [==============================] - 25s 246ms/step - loss: 9.9580 - mean_absolute_error: 10.4404 - root_mean_squared_error: 16.7619 - mean_absolute_percentage_error: 57.0214 - val_loss: 10.6250 - val_mean_absolute_error: 11.1116 - val_root_mean_squared_error: 17.8297 - val_mean_absolute_percentage_error: 62.3625
# Epoch 47/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.9450 - mean_absolute_error: 10.4296 - root_mean_squared_error: 16.7775 - mean_absolute_percentage_error: 57.0780 - val_loss: 10.4078 - val_mean_absolute_error: 10.8915 - val_root_mean_squared_error: 17.8085 - val_mean_absolute_percentage_error: 59.9218
# Epoch 48/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.7705 - mean_absolute_error: 10.2528 - root_mean_squared_error: 16.6354 - mean_absolute_percentage_error: 55.5952 - val_loss: 10.3610 - val_mean_absolute_error: 10.8405 - val_root_mean_squared_error: 17.6579 - val_mean_absolute_percentage_error: 58.6050
# Epoch 49/100
# 103/103 [==============================] - 25s 240ms/step - loss: 9.7063 - mean_absolute_error: 10.1908 - root_mean_squared_error: 16.5915 - mean_absolute_percentage_error: 55.7477 - val_loss: 10.0926 - val_mean_absolute_error: 10.5745 - val_root_mean_squared_error: 17.7221 - val_mean_absolute_percentage_error: 53.8035
# Epoch 50/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.7499 - mean_absolute_error: 10.2339 - root_mean_squared_error: 16.6991 - mean_absolute_percentage_error: 55.0898 - val_loss: 10.1488 - val_mean_absolute_error: 10.6324 - val_root_mean_squared_error: 17.8767 - val_mean_absolute_percentage_error: 55.6737
# Epoch 51/100
# 103/103 [==============================] - 26s 248ms/step - loss: 9.7204 - mean_absolute_error: 10.2010 - root_mean_squared_error: 16.6035 - mean_absolute_percentage_error: 54.9537 - val_loss: 10.4513 - val_mean_absolute_error: 10.9372 - val_root_mean_squared_error: 17.7041 - val_mean_absolute_percentage_error: 63.4019
# Epoch 52/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.7983 - mean_absolute_error: 10.2804 - root_mean_squared_error: 16.6837 - mean_absolute_percentage_error: 56.7488 - val_loss: 10.4558 - val_mean_absolute_error: 10.9432 - val_root_mean_squared_error: 17.6348 - val_mean_absolute_percentage_error: 64.9974
# Epoch 53/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.6264 - mean_absolute_error: 10.1086 - root_mean_squared_error: 16.5692 - mean_absolute_percentage_error: 54.4586 - val_loss: 10.2139 - val_mean_absolute_error: 10.6965 - val_root_mean_squared_error: 17.8002 - val_mean_absolute_percentage_error: 61.2365
# Epoch 54/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.7258 - mean_absolute_error: 10.2071 - root_mean_squared_error: 16.6438 - mean_absolute_percentage_error: 55.6907 - val_loss: 10.0359 - val_mean_absolute_error: 10.5185 - val_root_mean_squared_error: 17.7397 - val_mean_absolute_percentage_error: 55.0778
# Epoch 55/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.6876 - mean_absolute_error: 10.1682 - root_mean_squared_error: 16.5717 - mean_absolute_percentage_error: 55.0741 - val_loss: 10.3136 - val_mean_absolute_error: 10.7981 - val_root_mean_squared_error: 17.9110 - val_mean_absolute_percentage_error: 53.6068
# Epoch 56/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.7241 - mean_absolute_error: 10.2080 - root_mean_squared_error: 16.4657 - mean_absolute_percentage_error: 56.0797 - val_loss: 10.9511 - val_mean_absolute_error: 11.4330 - val_root_mean_squared_error: 18.0618 - val_mean_absolute_percentage_error: 62.1682
# Epoch 57/100
# 103/103 [==============================] - 24s 237ms/step - loss: 9.7689 - mean_absolute_error: 10.2513 - root_mean_squared_error: 16.6686 - mean_absolute_percentage_error: 55.1529 - val_loss: 10.1265 - val_mean_absolute_error: 10.6074 - val_root_mean_squared_error: 17.8019 - val_mean_absolute_percentage_error: 55.8459
# Epoch 58/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.6189 - mean_absolute_error: 10.0995 - root_mean_squared_error: 16.4395 - mean_absolute_percentage_error: 55.1969 - val_loss: 9.9564 - val_mean_absolute_error: 10.4380 - val_root_mean_squared_error: 17.5682 - val_mean_absolute_percentage_error: 53.7436
# Epoch 59/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.6689 - mean_absolute_error: 10.1493 - root_mean_squared_error: 16.5066 - mean_absolute_percentage_error: 55.3242 - val_loss: 10.0276 - val_mean_absolute_error: 10.5109 - val_root_mean_squared_error: 17.5732 - val_mean_absolute_percentage_error: 54.5952
# Epoch 60/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.6320 - mean_absolute_error: 10.1162 - root_mean_squared_error: 16.4776 - mean_absolute_percentage_error: 56.0439 - val_loss: 10.0687 - val_mean_absolute_error: 10.5498 - val_root_mean_squared_error: 17.8952 - val_mean_absolute_percentage_error: 55.4171
# Epoch 61/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.6067 - mean_absolute_error: 10.0887 - root_mean_squared_error: 16.3859 - mean_absolute_percentage_error: 54.6141 - val_loss: 10.3792 - val_mean_absolute_error: 10.8650 - val_root_mean_squared_error: 17.6103 - val_mean_absolute_percentage_error: 60.1036
# Epoch 62/100
# 103/103 [==============================] - 25s 240ms/step - loss: 9.6714 - mean_absolute_error: 10.1548 - root_mean_squared_error: 16.3607 - mean_absolute_percentage_error: 55.6419 - val_loss: 10.0985 - val_mean_absolute_error: 10.5819 - val_root_mean_squared_error: 17.6911 - val_mean_absolute_percentage_error: 55.0175
# Epoch 63/100
# 103/103 [==============================] - 25s 244ms/step - loss: 9.5731 - mean_absolute_error: 10.0550 - root_mean_squared_error: 16.3310 - mean_absolute_percentage_error: 55.1700 - val_loss: 9.9796 - val_mean_absolute_error: 10.4613 - val_root_mean_squared_error: 17.5975 - val_mean_absolute_percentage_error: 53.4700
# Epoch 64/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.5836 - mean_absolute_error: 10.0651 - root_mean_squared_error: 16.4164 - mean_absolute_percentage_error: 54.8043 - val_loss: 10.1712 - val_mean_absolute_error: 10.6541 - val_root_mean_squared_error: 17.5511 - val_mean_absolute_percentage_error: 55.2585
# Epoch 65/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.6547 - mean_absolute_error: 10.1374 - root_mean_squared_error: 16.3911 - mean_absolute_percentage_error: 55.6199 - val_loss: 10.1124 - val_mean_absolute_error: 10.5948 - val_root_mean_squared_error: 17.4835 - val_mean_absolute_percentage_error: 59.4833
# Epoch 66/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.5242 - mean_absolute_error: 10.0076 - root_mean_squared_error: 16.2990 - mean_absolute_percentage_error: 54.7230 - val_loss: 10.2279 - val_mean_absolute_error: 10.7125 - val_root_mean_squared_error: 17.4184 - val_mean_absolute_percentage_error: 62.6859
# Epoch 67/100
# 103/103 [==============================] - 25s 240ms/step - loss: 9.5373 - mean_absolute_error: 10.0186 - root_mean_squared_error: 16.3978 - mean_absolute_percentage_error: 55.4707 - val_loss: 10.2352 - val_mean_absolute_error: 10.7209 - val_root_mean_squared_error: 17.5224 - val_mean_absolute_percentage_error: 58.4073
# Epoch 68/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.5033 - mean_absolute_error: 9.9835 - root_mean_squared_error: 16.2940 - mean_absolute_percentage_error: 54.2725 - val_loss: 10.2909 - val_mean_absolute_error: 10.7789 - val_root_mean_squared_error: 17.4275 - val_mean_absolute_percentage_error: 60.0258
# Epoch 69/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.6362 - mean_absolute_error: 10.1181 - root_mean_squared_error: 16.4059 - mean_absolute_percentage_error: 55.3158 - val_loss: 10.1799 - val_mean_absolute_error: 10.6599 - val_root_mean_squared_error: 17.9272 - val_mean_absolute_percentage_error: 50.9876
# Epoch 70/100
# 103/103 [==============================] - 25s 244ms/step - loss: 9.4638 - mean_absolute_error: 9.9452 - root_mean_squared_error: 16.2106 - mean_absolute_percentage_error: 54.3338 - val_loss: 9.9854 - val_mean_absolute_error: 10.4650 - val_root_mean_squared_error: 17.6896 - val_mean_absolute_percentage_error: 51.6740
# Epoch 71/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.5537 - mean_absolute_error: 10.0337 - root_mean_squared_error: 16.3421 - mean_absolute_percentage_error: 54.7509 - val_loss: 10.0853 - val_mean_absolute_error: 10.5667 - val_root_mean_squared_error: 17.4474 - val_mean_absolute_percentage_error: 56.9192
# Epoch 72/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.5428 - mean_absolute_error: 10.0233 - root_mean_squared_error: 16.3137 - mean_absolute_percentage_error: 54.7476 - val_loss: 9.8779 - val_mean_absolute_error: 10.3596 - val_root_mean_squared_error: 17.3896 - val_mean_absolute_percentage_error: 53.3290
# Epoch 73/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.5200 - mean_absolute_error: 10.0009 - root_mean_squared_error: 16.2547 - mean_absolute_percentage_error: 54.2138 - val_loss: 10.9185 - val_mean_absolute_error: 11.4019 - val_root_mean_squared_error: 18.0963 - val_mean_absolute_percentage_error: 62.9542
# Epoch 74/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.4981 - mean_absolute_error: 9.9788 - root_mean_squared_error: 16.1890 - mean_absolute_percentage_error: 54.7406 - val_loss: 10.4328 - val_mean_absolute_error: 10.9147 - val_root_mean_squared_error: 17.5486 - val_mean_absolute_percentage_error: 57.3259
# Epoch 75/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.4961 - mean_absolute_error: 9.9796 - root_mean_squared_error: 16.1494 - mean_absolute_percentage_error: 54.1106 - val_loss: 10.7829 - val_mean_absolute_error: 11.2679 - val_root_mean_squared_error: 18.7101 - val_mean_absolute_percentage_error: 55.9072
# Epoch 76/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.5007 - mean_absolute_error: 9.9821 - root_mean_squared_error: 16.3576 - mean_absolute_percentage_error: 54.4667 - val_loss: 9.9990 - val_mean_absolute_error: 10.4840 - val_root_mean_squared_error: 17.3267 - val_mean_absolute_percentage_error: 54.1483
# Epoch 77/100
# 103/103 [==============================] - 24s 235ms/step - loss: 9.4638 - mean_absolute_error: 9.9457 - root_mean_squared_error: 16.2507 - mean_absolute_percentage_error: 54.1165 - val_loss: 9.9017 - val_mean_absolute_error: 10.3861 - val_root_mean_squared_error: 17.4122 - val_mean_absolute_percentage_error: 54.7641
# Epoch 78/100
# 103/103 [==============================] - 24s 238ms/step - loss: 9.3850 - mean_absolute_error: 9.8647 - root_mean_squared_error: 16.1451 - mean_absolute_percentage_error: 53.8538 - val_loss: 9.9784 - val_mean_absolute_error: 10.4626 - val_root_mean_squared_error: 17.3230 - val_mean_absolute_percentage_error: 55.7335
# Epoch 79/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.4606 - mean_absolute_error: 9.9418 - root_mean_squared_error: 16.1069 - mean_absolute_percentage_error: 54.3872 - val_loss: 9.9879 - val_mean_absolute_error: 10.4689 - val_root_mean_squared_error: 17.3620 - val_mean_absolute_percentage_error: 55.8514
# Epoch 80/100
# 103/103 [==============================] - 25s 244ms/step - loss: 9.4095 - mean_absolute_error: 9.8904 - root_mean_squared_error: 16.1572 - mean_absolute_percentage_error: 53.6450 - val_loss: 9.9461 - val_mean_absolute_error: 10.4257 - val_root_mean_squared_error: 17.6142 - val_mean_absolute_percentage_error: 52.3588
# Epoch 81/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.4303 - mean_absolute_error: 9.9093 - root_mean_squared_error: 16.1824 - mean_absolute_percentage_error: 54.2874 - val_loss: 9.9245 - val_mean_absolute_error: 10.4067 - val_root_mean_squared_error: 17.4062 - val_mean_absolute_percentage_error: 52.9331
# Epoch 82/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.4077 - mean_absolute_error: 9.8857 - root_mean_squared_error: 16.1279 - mean_absolute_percentage_error: 53.8555 - val_loss: 9.9814 - val_mean_absolute_error: 10.4630 - val_root_mean_squared_error: 17.4047 - val_mean_absolute_percentage_error: 52.2963
# Epoch 83/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.2839 - mean_absolute_error: 9.7638 - root_mean_squared_error: 15.9564 - mean_absolute_percentage_error: 52.8582 - val_loss: 9.8796 - val_mean_absolute_error: 10.3615 - val_root_mean_squared_error: 17.3836 - val_mean_absolute_percentage_error: 53.9063
# Epoch 84/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.3874 - mean_absolute_error: 9.8660 - root_mean_squared_error: 16.1231 - mean_absolute_percentage_error: 53.6088 - val_loss: 9.9478 - val_mean_absolute_error: 10.4283 - val_root_mean_squared_error: 17.2099 - val_mean_absolute_percentage_error: 55.3988
# Epoch 85/100
# 103/103 [==============================] - 25s 244ms/step - loss: 9.3691 - mean_absolute_error: 9.8492 - root_mean_squared_error: 16.0686 - mean_absolute_percentage_error: 53.5119 - val_loss: 9.9579 - val_mean_absolute_error: 10.4449 - val_root_mean_squared_error: 17.3669 - val_mean_absolute_percentage_error: 55.0558
# Epoch 86/100
# 103/103 [==============================] - 25s 239ms/step - loss: 9.3911 - mean_absolute_error: 9.8697 - root_mean_squared_error: 16.1198 - mean_absolute_percentage_error: 53.8447 - val_loss: 9.9488 - val_mean_absolute_error: 10.4296 - val_root_mean_squared_error: 17.4064 - val_mean_absolute_percentage_error: 54.6713
# Epoch 87/100
# 103/103 [==============================] - 25s 246ms/step - loss: 9.3614 - mean_absolute_error: 9.8425 - root_mean_squared_error: 16.0101 - mean_absolute_percentage_error: 54.4252 - val_loss: 10.0255 - val_mean_absolute_error: 10.5047 - val_root_mean_squared_error: 17.6150 - val_mean_absolute_percentage_error: 53.0794
# Epoch 88/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.3989 - mean_absolute_error: 9.8786 - root_mean_squared_error: 16.1841 - mean_absolute_percentage_error: 53.2385 - val_loss: 10.0596 - val_mean_absolute_error: 10.5405 - val_root_mean_squared_error: 17.1479 - val_mean_absolute_percentage_error: 57.7616
# Epoch 89/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.3956 - mean_absolute_error: 9.8759 - root_mean_squared_error: 16.0888 - mean_absolute_percentage_error: 53.1882 - val_loss: 10.1182 - val_mean_absolute_error: 10.6041 - val_root_mean_squared_error: 17.3816 - val_mean_absolute_percentage_error: 57.8094
# Epoch 90/100
# 103/103 [==============================] - 25s 244ms/step - loss: 9.3790 - mean_absolute_error: 9.8581 - root_mean_squared_error: 16.0129 - mean_absolute_percentage_error: 53.7952 - val_loss: 10.1667 - val_mean_absolute_error: 10.6485 - val_root_mean_squared_error: 17.3846 - val_mean_absolute_percentage_error: 58.9596
# Epoch 91/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.3601 - mean_absolute_error: 9.8395 - root_mean_squared_error: 16.1418 - mean_absolute_percentage_error: 53.7435 - val_loss: 10.0595 - val_mean_absolute_error: 10.5381 - val_root_mean_squared_error: 17.3990 - val_mean_absolute_percentage_error: 55.3583
# Epoch 92/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.3404 - mean_absolute_error: 9.8208 - root_mean_squared_error: 16.0533 - mean_absolute_percentage_error: 53.4945 - val_loss: 9.9459 - val_mean_absolute_error: 10.4246 - val_root_mean_squared_error: 17.4574 - val_mean_absolute_percentage_error: 54.0721
# Epoch 93/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.3493 - mean_absolute_error: 9.8293 - root_mean_squared_error: 15.9713 - mean_absolute_percentage_error: 54.7449 - val_loss: 9.9564 - val_mean_absolute_error: 10.4380 - val_root_mean_squared_error: 17.4043 - val_mean_absolute_percentage_error: 56.5820
# Epoch 94/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.3312 - mean_absolute_error: 9.8112 - root_mean_squared_error: 15.9717 - mean_absolute_percentage_error: 54.2865 - val_loss: 10.1410 - val_mean_absolute_error: 10.6244 - val_root_mean_squared_error: 17.6014 - val_mean_absolute_percentage_error: 58.4033
# Epoch 95/100
# 103/103 [==============================] - 25s 244ms/step - loss: 9.4368 - mean_absolute_error: 9.9179 - root_mean_squared_error: 16.1057 - mean_absolute_percentage_error: 54.0950 - val_loss: 9.9761 - val_mean_absolute_error: 10.4617 - val_root_mean_squared_error: 17.2056 - val_mean_absolute_percentage_error: 56.2671
# Epoch 96/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.2321 - mean_absolute_error: 9.7115 - root_mean_squared_error: 15.9647 - mean_absolute_percentage_error: 52.3793 - val_loss: 10.0080 - val_mean_absolute_error: 10.4847 - val_root_mean_squared_error: 17.5062 - val_mean_absolute_percentage_error: 52.2144
# Epoch 97/100
# 103/103 [==============================] - 25s 243ms/step - loss: 9.3429 - mean_absolute_error: 9.8234 - root_mean_squared_error: 15.9831 - mean_absolute_percentage_error: 54.0738 - val_loss: 9.9645 - val_mean_absolute_error: 10.4429 - val_root_mean_squared_error: 17.4408 - val_mean_absolute_percentage_error: 52.8943
# Epoch 98/100
# 103/103 [==============================] - 25s 241ms/step - loss: 9.2375 - mean_absolute_error: 9.7172 - root_mean_squared_error: 15.8580 - mean_absolute_percentage_error: 52.5230 - val_loss: 10.6231 - val_mean_absolute_error: 11.1070 - val_root_mean_squared_error: 18.2911 - val_mean_absolute_percentage_error: 51.8402
# Epoch 99/100
# 103/103 [==============================] - 25s 242ms/step - loss: 9.2739 - mean_absolute_error: 9.7519 - root_mean_squared_error: 15.9801 - mean_absolute_percentage_error: 52.9603 - val_loss: 9.8567 - val_mean_absolute_error: 10.3342 - val_root_mean_squared_error: 17.2095 - val_mean_absolute_percentage_error: 56.2015
# Epoch 100/100
# 103/103 [==============================] - 25s 245ms/step - loss: 9.1712 - mean_absolute_error: 9.6520 - root_mean_squared_error: 15.9210 - mean_absolute_percentage_error: 52.8138 - val_loss: 10.0593 - val_mean_absolute_error: 10.5460 - val_root_mean_squared_error: 17.2280 - val_mean_absolute_percentage_error: 60.1312

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 3s 100ms/step - loss: 10.0593 - mean_absolute_error: 10.5460 - root_mean_squared_error: 17.2280 - mean_absolute_percentage_error: 60.1312
# Model Loss: [10.05928897857666, 10.545950889587402, 17.22800636291504, 60.131229400634766]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 883ms/step
# Predicted Putusan: [12.069752]

# %%
model_scenario_name = "BiLSTM_7"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 10). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_7\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_7\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_7"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [12.069752]
