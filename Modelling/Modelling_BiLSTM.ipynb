# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_33008\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001))(embedding_layer)
lstm_output_2 = tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001))(lstm_output)
lstm_output_3 = tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalAveragePooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  lstm (LSTM)                    (None, 1024, 32)     36992       ['embedding[0][0]']
#
#  lstm_1 (LSTM)                  (None, 1024, 64)     24832       ['lstm[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  lstm_2 (LSTM)                  (None, 1024, 32)     12416       ['lstm_1[0][0]']
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  global_average_pooling1d (Glob  (None, 32)          0           ['lstm_2[0][0]']
#  alAveragePooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 64)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64)          256         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          8320        ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 3,907,297
# Trainable params: 3,907,169
# Non-trainable params: 128
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 18s 141ms/step - loss: 34.0907 - mean_absolute_error: 34.2109 - root_mean_squared_error: 46.6449 - mean_absolute_percentage_error: 98.3194 - val_loss: 34.1041 - val_mean_absolute_error: 34.2512 - val_root_mean_squared_error: 47.3653 - val_mean_absolute_percentage_error: 89.2573
# Epoch 2/100
# 103/103 [==============================] - 15s 143ms/step - loss: 31.4258 - mean_absolute_error: 31.5887 - root_mean_squared_error: 44.7957 - mean_absolute_percentage_error: 82.4023 - val_loss: 30.3374 - val_mean_absolute_error: 30.5133 - val_root_mean_squared_error: 44.8198 - val_mean_absolute_percentage_error: 70.4591
# Epoch 3/100
# 103/103 [==============================] - 18s 178ms/step - loss: 26.4836 - mean_absolute_error: 26.6697 - root_mean_squared_error: 41.1272 - mean_absolute_percentage_error: 65.8306 - val_loss: 26.1835 - val_mean_absolute_error: 26.3785 - val_root_mean_squared_error: 41.1208 - val_mean_absolute_percentage_error: 66.8800
# Epoch 4/100
# 103/103 [==============================] - 17s 164ms/step - loss: 21.9797 - mean_absolute_error: 22.1811 - root_mean_squared_error: 34.3874 - mean_absolute_percentage_error: 70.7917 - val_loss: 20.5371 - val_mean_absolute_error: 20.7463 - val_root_mean_squared_error: 31.3936 - val_mean_absolute_percentage_error: 77.2859
# Epoch 5/100
# 103/103 [==============================] - 17s 163ms/step - loss: 16.9194 - mean_absolute_error: 17.1340 - root_mean_squared_error: 25.6363 - mean_absolute_percentage_error: 82.2835 - val_loss: 14.7453 - val_mean_absolute_error: 14.9667 - val_root_mean_squared_error: 21.9269 - val_mean_absolute_percentage_error: 86.9701
# Epoch 6/100
# 103/103 [==============================] - 17s 163ms/step - loss: 13.5095 - mean_absolute_error: 13.7335 - root_mean_squared_error: 20.7022 - mean_absolute_percentage_error: 79.3658 - val_loss: 13.6787 - val_mean_absolute_error: 13.9096 - val_root_mean_squared_error: 21.3393 - val_mean_absolute_percentage_error: 78.9454
# Epoch 7/100
# 103/103 [==============================] - 17s 166ms/step - loss: 13.9195 - mean_absolute_error: 14.1545 - root_mean_squared_error: 21.6221 - mean_absolute_percentage_error: 78.0201 - val_loss: 14.4000 - val_mean_absolute_error: 14.6383 - val_root_mean_squared_error: 23.2987 - val_mean_absolute_percentage_error: 73.0241
# Epoch 8/100
# 103/103 [==============================] - 17s 163ms/step - loss: 14.2889 - mean_absolute_error: 14.5291 - root_mean_squared_error: 22.4212 - mean_absolute_percentage_error: 63.2661 - val_loss: 14.8867 - val_mean_absolute_error: 15.1341 - val_root_mean_squared_error: 23.8598 - val_mean_absolute_percentage_error: 72.6688
# Epoch 9/100
# 103/103 [==============================] - 17s 162ms/step - loss: 12.1797 - mean_absolute_error: 12.4273 - root_mean_squared_error: 19.1187 - mean_absolute_percentage_error: 70.7255 - val_loss: 11.7335 - val_mean_absolute_error: 11.9775 - val_root_mean_squared_error: 19.6434 - val_mean_absolute_percentage_error: 68.5775
# Epoch 10/100
# 103/103 [==============================] - 17s 164ms/step - loss: 11.9646 - mean_absolute_error: 12.2146 - root_mean_squared_error: 18.8452 - mean_absolute_percentage_error: 69.5163 - val_loss: 11.7368 - val_mean_absolute_error: 11.9825 - val_root_mean_squared_error: 20.1200 - val_mean_absolute_percentage_error: 65.3231
# Epoch 11/100
# 103/103 [==============================] - 17s 163ms/step - loss: 11.8880 - mean_absolute_error: 12.1426 - root_mean_squared_error: 18.4992 - mean_absolute_percentage_error: 74.0021 - val_loss: 11.6310 - val_mean_absolute_error: 11.8787 - val_root_mean_squared_error: 19.7488 - val_mean_absolute_percentage_error: 64.1426
# Epoch 12/100
# 103/103 [==============================] - 17s 161ms/step - loss: 11.8245 - mean_absolute_error: 12.0848 - root_mean_squared_error: 18.3329 - mean_absolute_percentage_error: 77.5167 - val_loss: 11.6563 - val_mean_absolute_error: 11.9103 - val_root_mean_squared_error: 19.1104 - val_mean_absolute_percentage_error: 70.6475
# Epoch 13/100
# 103/103 [==============================] - 17s 163ms/step - loss: 11.5066 - mean_absolute_error: 11.7684 - root_mean_squared_error: 17.9187 - mean_absolute_percentage_error: 74.7523 - val_loss: 11.2563 - val_mean_absolute_error: 11.5124 - val_root_mean_squared_error: 19.0443 - val_mean_absolute_percentage_error: 69.9845
# Epoch 14/100
# 103/103 [==============================] - 17s 164ms/step - loss: 11.6727 - mean_absolute_error: 11.9386 - root_mean_squared_error: 18.0231 - mean_absolute_percentage_error: 82.0446 - val_loss: 11.5045 - val_mean_absolute_error: 11.7660 - val_root_mean_squared_error: 18.3956 - val_mean_absolute_percentage_error: 85.8425
# Epoch 15/100
# 103/103 [==============================] - 17s 164ms/step - loss: 11.6430 - mean_absolute_error: 11.9115 - root_mean_squared_error: 17.8414 - mean_absolute_percentage_error: 88.0401 - val_loss: 11.9154 - val_mean_absolute_error: 12.1800 - val_root_mean_squared_error: 19.1921 - val_mean_absolute_percentage_error: 89.6389
# Epoch 16/100
# 103/103 [==============================] - 17s 163ms/step - loss: 11.3123 - mean_absolute_error: 11.5835 - root_mean_squared_error: 17.1811 - mean_absolute_percentage_error: 81.0656 - val_loss: 11.3589 - val_mean_absolute_error: 11.6319 - val_root_mean_squared_error: 18.7306 - val_mean_absolute_percentage_error: 80.0872
# Epoch 17/100
# 103/103 [==============================] - 17s 164ms/step - loss: 11.3631 - mean_absolute_error: 11.6342 - root_mean_squared_error: 17.5224 - mean_absolute_percentage_error: 80.2183 - val_loss: 10.7806 - val_mean_absolute_error: 11.0555 - val_root_mean_squared_error: 17.7387 - val_mean_absolute_percentage_error: 80.3915
# Epoch 18/100
# 103/103 [==============================] - 17s 164ms/step - loss: 10.9302 - mean_absolute_error: 11.2052 - root_mean_squared_error: 17.1416 - mean_absolute_percentage_error: 76.2082 - val_loss: 11.4531 - val_mean_absolute_error: 11.7295 - val_root_mean_squared_error: 19.0748 - val_mean_absolute_percentage_error: 67.0497
# Epoch 19/100
# 103/103 [==============================] - 17s 162ms/step - loss: 10.8091 - mean_absolute_error: 11.0877 - root_mean_squared_error: 16.9427 - mean_absolute_percentage_error: 71.3623 - val_loss: 10.6247 - val_mean_absolute_error: 10.8990 - val_root_mean_squared_error: 17.5396 - val_mean_absolute_percentage_error: 76.1237
# Epoch 20/100
# 103/103 [==============================] - 17s 162ms/step - loss: 10.6150 - mean_absolute_error: 10.8924 - root_mean_squared_error: 16.9762 - mean_absolute_percentage_error: 68.1802 - val_loss: 10.3789 - val_mean_absolute_error: 10.6565 - val_root_mean_squared_error: 17.5058 - val_mean_absolute_percentage_error: 67.0391
# Epoch 21/100
# 103/103 [==============================] - 17s 164ms/step - loss: 10.8255 - mean_absolute_error: 11.1050 - root_mean_squared_error: 17.3113 - mean_absolute_percentage_error: 60.2204 - val_loss: 10.3222 - val_mean_absolute_error: 10.5985 - val_root_mean_squared_error: 17.9581 - val_mean_absolute_percentage_error: 57.5764
# Epoch 22/100
# 103/103 [==============================] - 17s 167ms/step - loss: 10.5145 - mean_absolute_error: 10.7967 - root_mean_squared_error: 17.1147 - mean_absolute_percentage_error: 58.1754 - val_loss: 10.5798 - val_mean_absolute_error: 10.8597 - val_root_mean_squared_error: 17.3289 - val_mean_absolute_percentage_error: 64.5661
# Epoch 23/100
# 103/103 [==============================] - 18s 179ms/step - loss: 10.5817 - mean_absolute_error: 10.8641 - root_mean_squared_error: 17.1045 - mean_absolute_percentage_error: 58.1369 - val_loss: 10.0791 - val_mean_absolute_error: 10.3563 - val_root_mean_squared_error: 16.9953 - val_mean_absolute_percentage_error: 62.9830
# Epoch 24/100
# 103/103 [==============================] - 18s 173ms/step - loss: 10.3677 - mean_absolute_error: 10.6508 - root_mean_squared_error: 16.8965 - mean_absolute_percentage_error: 59.0353 - val_loss: 9.9097 - val_mean_absolute_error: 10.1898 - val_root_mean_squared_error: 17.0619 - val_mean_absolute_percentage_error: 57.8682
# Epoch 25/100
# 103/103 [==============================] - 17s 167ms/step - loss: 10.4338 - mean_absolute_error: 10.7202 - root_mean_squared_error: 17.1658 - mean_absolute_percentage_error: 58.4284 - val_loss: 10.0452 - val_mean_absolute_error: 10.3271 - val_root_mean_squared_error: 17.0776 - val_mean_absolute_percentage_error: 57.5049
# Epoch 26/100
# 103/103 [==============================] - 16s 157ms/step - loss: 10.3733 - mean_absolute_error: 10.6613 - root_mean_squared_error: 17.1860 - mean_absolute_percentage_error: 59.9301 - val_loss: 9.8369 - val_mean_absolute_error: 10.1224 - val_root_mean_squared_error: 17.2117 - val_mean_absolute_percentage_error: 56.4348
# Epoch 27/100
# 103/103 [==============================] - 16s 157ms/step - loss: 10.0850 - mean_absolute_error: 10.3726 - root_mean_squared_error: 16.4658 - mean_absolute_percentage_error: 60.8787 - val_loss: 10.0836 - val_mean_absolute_error: 10.3729 - val_root_mean_squared_error: 17.6374 - val_mean_absolute_percentage_error: 55.0569
# Epoch 28/100
# 103/103 [==============================] - 16s 156ms/step - loss: 9.8649 - mean_absolute_error: 10.1571 - root_mean_squared_error: 16.1354 - mean_absolute_percentage_error: 58.9382 - val_loss: 9.9192 - val_mean_absolute_error: 10.2124 - val_root_mean_squared_error: 17.1309 - val_mean_absolute_percentage_error: 55.8267
# Epoch 29/100
# 103/103 [==============================] - 16s 157ms/step - loss: 10.0129 - mean_absolute_error: 10.3038 - root_mean_squared_error: 16.6184 - mean_absolute_percentage_error: 59.3492 - val_loss: 9.8246 - val_mean_absolute_error: 10.1142 - val_root_mean_squared_error: 16.9143 - val_mean_absolute_percentage_error: 57.6987
# Epoch 30/100
# 103/103 [==============================] - 16s 156ms/step - loss: 10.5522 - mean_absolute_error: 10.8459 - root_mean_squared_error: 17.2890 - mean_absolute_percentage_error: 59.7671 - val_loss: 10.4798 - val_mean_absolute_error: 10.7725 - val_root_mean_squared_error: 17.0940 - val_mean_absolute_percentage_error: 63.1431
# Epoch 31/100
# 103/103 [==============================] - 16s 159ms/step - loss: 10.3210 - mean_absolute_error: 10.6167 - root_mean_squared_error: 16.9031 - mean_absolute_percentage_error: 60.1635 - val_loss: 9.9614 - val_mean_absolute_error: 10.2525 - val_root_mean_squared_error: 17.5514 - val_mean_absolute_percentage_error: 55.9952
# Epoch 32/100
# 103/103 [==============================] - 16s 158ms/step - loss: 10.0469 - mean_absolute_error: 10.3455 - root_mean_squared_error: 16.2777 - mean_absolute_percentage_error: 60.8426 - val_loss: 10.2261 - val_mean_absolute_error: 10.5180 - val_root_mean_squared_error: 18.0187 - val_mean_absolute_percentage_error: 55.9090
# Epoch 33/100
# 103/103 [==============================] - 16s 158ms/step - loss: 10.0634 - mean_absolute_error: 10.3602 - root_mean_squared_error: 16.3514 - mean_absolute_percentage_error: 62.5861 - val_loss: 10.0166 - val_mean_absolute_error: 10.3210 - val_root_mean_squared_error: 16.7686 - val_mean_absolute_percentage_error: 64.2389
# Epoch 34/100
# 103/103 [==============================] - 16s 158ms/step - loss: 10.0519 - mean_absolute_error: 10.3510 - root_mean_squared_error: 16.5225 - mean_absolute_percentage_error: 59.6162 - val_loss: 10.2522 - val_mean_absolute_error: 10.5531 - val_root_mean_squared_error: 16.7449 - val_mean_absolute_percentage_error: 63.1991
# Epoch 35/100
# 103/103 [==============================] - 16s 159ms/step - loss: 9.8994 - mean_absolute_error: 10.2002 - root_mean_squared_error: 16.1415 - mean_absolute_percentage_error: 62.3860 - val_loss: 9.6095 - val_mean_absolute_error: 9.9109 - val_root_mean_squared_error: 16.5506 - val_mean_absolute_percentage_error: 59.0149
# Epoch 36/100
# 103/103 [==============================] - 16s 157ms/step - loss: 10.1381 - mean_absolute_error: 10.4394 - root_mean_squared_error: 16.2298 - mean_absolute_percentage_error: 64.1868 - val_loss: 11.0821 - val_mean_absolute_error: 11.3799 - val_root_mean_squared_error: 17.1048 - val_mean_absolute_percentage_error: 73.0983
# Epoch 37/100
# 103/103 [==============================] - 16s 158ms/step - loss: 9.8307 - mean_absolute_error: 10.1315 - root_mean_squared_error: 15.8931 - mean_absolute_percentage_error: 60.9215 - val_loss: 9.5605 - val_mean_absolute_error: 9.8610 - val_root_mean_squared_error: 16.8100 - val_mean_absolute_percentage_error: 54.9585
# Epoch 38/100
# 103/103 [==============================] - 16s 158ms/step - loss: 9.4159 - mean_absolute_error: 9.7186 - root_mean_squared_error: 15.2445 - mean_absolute_percentage_error: 57.4071 - val_loss: 10.4890 - val_mean_absolute_error: 10.7933 - val_root_mean_squared_error: 16.5568 - val_mean_absolute_percentage_error: 63.4115
# Epoch 39/100
# 103/103 [==============================] - 16s 160ms/step - loss: 9.1054 - mean_absolute_error: 9.4073 - root_mean_squared_error: 14.9077 - mean_absolute_percentage_error: 56.4440 - val_loss: 9.9885 - val_mean_absolute_error: 10.2907 - val_root_mean_squared_error: 16.7356 - val_mean_absolute_percentage_error: 51.8859
# Epoch 40/100
# 103/103 [==============================] - 16s 158ms/step - loss: 9.8261 - mean_absolute_error: 10.1299 - root_mean_squared_error: 15.7008 - mean_absolute_percentage_error: 63.6996 - val_loss: 10.6923 - val_mean_absolute_error: 10.9936 - val_root_mean_squared_error: 18.0538 - val_mean_absolute_percentage_error: 55.3572
# Epoch 41/100
# 103/103 [==============================] - 16s 159ms/step - loss: 9.6436 - mean_absolute_error: 9.9483 - root_mean_squared_error: 15.5909 - mean_absolute_percentage_error: 60.2381 - val_loss: 9.8930 - val_mean_absolute_error: 10.1983 - val_root_mean_squared_error: 17.4874 - val_mean_absolute_percentage_error: 53.9580
# Epoch 42/100
# 103/103 [==============================] - 16s 159ms/step - loss: 9.8071 - mean_absolute_error: 10.1109 - root_mean_squared_error: 15.6787 - mean_absolute_percentage_error: 62.9741 - val_loss: 10.5338 - val_mean_absolute_error: 10.8327 - val_root_mean_squared_error: 16.9280 - val_mean_absolute_percentage_error: 62.7336
# Epoch 43/100
# 103/103 [==============================] - 16s 156ms/step - loss: 9.4057 - mean_absolute_error: 9.7098 - root_mean_squared_error: 14.9847 - mean_absolute_percentage_error: 60.7906 - val_loss: 12.5546 - val_mean_absolute_error: 12.8596 - val_root_mean_squared_error: 18.9050 - val_mean_absolute_percentage_error: 78.2310
# Epoch 44/100
# 103/103 [==============================] - 16s 158ms/step - loss: 9.2927 - mean_absolute_error: 9.5965 - root_mean_squared_error: 14.8057 - mean_absolute_percentage_error: 64.4683 - val_loss: 9.6774 - val_mean_absolute_error: 9.9822 - val_root_mean_squared_error: 16.2837 - val_mean_absolute_percentage_error: 61.2225
# Epoch 45/100
# 103/103 [==============================] - 16s 157ms/step - loss: 9.2828 - mean_absolute_error: 9.5880 - root_mean_squared_error: 14.4131 - mean_absolute_percentage_error: 64.0822 - val_loss: 9.7101 - val_mean_absolute_error: 10.0154 - val_root_mean_squared_error: 16.2598 - val_mean_absolute_percentage_error: 63.7715
# Epoch 46/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.9313 - mean_absolute_error: 9.2366 - root_mean_squared_error: 13.8581 - mean_absolute_percentage_error: 64.3471 - val_loss: 10.2089 - val_mean_absolute_error: 10.5147 - val_root_mean_squared_error: 16.6512 - val_mean_absolute_percentage_error: 60.3344
# Epoch 47/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.6122 - mean_absolute_error: 8.9183 - root_mean_squared_error: 13.6088 - mean_absolute_percentage_error: 54.3483 - val_loss: 9.6887 - val_mean_absolute_error: 9.9916 - val_root_mean_squared_error: 16.2651 - val_mean_absolute_percentage_error: 51.1907
# Epoch 48/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.4546 - mean_absolute_error: 8.7607 - root_mean_squared_error: 13.2190 - mean_absolute_percentage_error: 50.8184 - val_loss: 9.2417 - val_mean_absolute_error: 9.5447 - val_root_mean_squared_error: 15.7186 - val_mean_absolute_percentage_error: 49.4169
# Epoch 49/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.4361 - mean_absolute_error: 8.7422 - root_mean_squared_error: 13.3467 - mean_absolute_percentage_error: 53.4416 - val_loss: 8.8302 - val_mean_absolute_error: 9.1324 - val_root_mean_squared_error: 15.0678 - val_mean_absolute_percentage_error: 49.5155
# Epoch 50/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.3830 - mean_absolute_error: 8.6895 - root_mean_squared_error: 12.9497 - mean_absolute_percentage_error: 56.4609 - val_loss: 10.1167 - val_mean_absolute_error: 10.4266 - val_root_mean_squared_error: 16.0775 - val_mean_absolute_percentage_error: 47.7485
# Epoch 51/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.2829 - mean_absolute_error: 8.5894 - root_mean_squared_error: 12.7818 - mean_absolute_percentage_error: 56.7442 - val_loss: 9.6673 - val_mean_absolute_error: 9.9784 - val_root_mean_squared_error: 15.7841 - val_mean_absolute_percentage_error: 62.3003
# Epoch 52/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.3847 - mean_absolute_error: 8.6911 - root_mean_squared_error: 13.0637 - mean_absolute_percentage_error: 59.7315 - val_loss: 8.9323 - val_mean_absolute_error: 9.2408 - val_root_mean_squared_error: 15.1869 - val_mean_absolute_percentage_error: 53.6460
# Epoch 53/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.2816 - mean_absolute_error: 8.5910 - root_mean_squared_error: 12.8957 - mean_absolute_percentage_error: 57.5365 - val_loss: 9.2108 - val_mean_absolute_error: 9.5236 - val_root_mean_squared_error: 15.4299 - val_mean_absolute_percentage_error: 54.1760
# Epoch 54/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.2201 - mean_absolute_error: 8.5289 - root_mean_squared_error: 12.8803 - mean_absolute_percentage_error: 58.1517 - val_loss: 8.9006 - val_mean_absolute_error: 9.2074 - val_root_mean_squared_error: 15.1478 - val_mean_absolute_percentage_error: 54.7531
# Epoch 55/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.5337 - mean_absolute_error: 8.8443 - root_mean_squared_error: 13.3526 - mean_absolute_percentage_error: 57.0776 - val_loss: 9.7970 - val_mean_absolute_error: 10.1033 - val_root_mean_squared_error: 16.2824 - val_mean_absolute_percentage_error: 58.4741
# Epoch 56/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.0564 - mean_absolute_error: 8.3646 - root_mean_squared_error: 12.9059 - mean_absolute_percentage_error: 54.8765 - val_loss: 9.1420 - val_mean_absolute_error: 9.4431 - val_root_mean_squared_error: 15.5578 - val_mean_absolute_percentage_error: 55.4834
# Epoch 57/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.4371 - mean_absolute_error: 8.7466 - root_mean_squared_error: 13.0326 - mean_absolute_percentage_error: 59.0611 - val_loss: 9.2407 - val_mean_absolute_error: 9.5508 - val_root_mean_squared_error: 15.6205 - val_mean_absolute_percentage_error: 56.6845
# Epoch 58/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.3239 - mean_absolute_error: 8.6340 - root_mean_squared_error: 12.7212 - mean_absolute_percentage_error: 61.4930 - val_loss: 9.2908 - val_mean_absolute_error: 9.5989 - val_root_mean_squared_error: 15.4943 - val_mean_absolute_percentage_error: 60.9661
# Epoch 59/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.4867 - mean_absolute_error: 8.7948 - root_mean_squared_error: 12.9628 - mean_absolute_percentage_error: 60.5296 - val_loss: 9.1237 - val_mean_absolute_error: 9.4355 - val_root_mean_squared_error: 15.2850 - val_mean_absolute_percentage_error: 58.2316
# Epoch 60/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.2547 - mean_absolute_error: 8.5658 - root_mean_squared_error: 12.6894 - mean_absolute_percentage_error: 60.4558 - val_loss: 9.1168 - val_mean_absolute_error: 9.4276 - val_root_mean_squared_error: 15.3454 - val_mean_absolute_percentage_error: 57.6977
# Epoch 61/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.7430 - mean_absolute_error: 9.0558 - root_mean_squared_error: 13.5709 - mean_absolute_percentage_error: 58.0687 - val_loss: 9.6930 - val_mean_absolute_error: 10.0001 - val_root_mean_squared_error: 16.0257 - val_mean_absolute_percentage_error: 54.6586
# Epoch 62/100
# 103/103 [==============================] - 17s 162ms/step - loss: 8.5971 - mean_absolute_error: 8.9083 - root_mean_squared_error: 13.6074 - mean_absolute_percentage_error: 57.2428 - val_loss: 9.5174 - val_mean_absolute_error: 9.8307 - val_root_mean_squared_error: 16.0791 - val_mean_absolute_percentage_error: 57.0032
# Epoch 63/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.2189 - mean_absolute_error: 8.5301 - root_mean_squared_error: 12.9578 - mean_absolute_percentage_error: 57.5943 - val_loss: 9.3475 - val_mean_absolute_error: 9.6572 - val_root_mean_squared_error: 15.8867 - val_mean_absolute_percentage_error: 56.2853
# Epoch 64/100
# 103/103 [==============================] - 16s 160ms/step - loss: 8.1701 - mean_absolute_error: 8.4825 - root_mean_squared_error: 12.8272 - mean_absolute_percentage_error: 58.8041 - val_loss: 9.5330 - val_mean_absolute_error: 9.8419 - val_root_mean_squared_error: 16.0205 - val_mean_absolute_percentage_error: 61.2865
# Epoch 65/100
# 103/103 [==============================] - 16s 160ms/step - loss: 8.1254 - mean_absolute_error: 8.4350 - root_mean_squared_error: 12.7743 - mean_absolute_percentage_error: 60.7788 - val_loss: 10.0387 - val_mean_absolute_error: 10.3503 - val_root_mean_squared_error: 16.3664 - val_mean_absolute_percentage_error: 64.2467
# Epoch 66/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.8640 - mean_absolute_error: 9.1778 - root_mean_squared_error: 13.7220 - mean_absolute_percentage_error: 63.0018 - val_loss: 9.3455 - val_mean_absolute_error: 9.6576 - val_root_mean_squared_error: 15.7393 - val_mean_absolute_percentage_error: 58.1820
# Epoch 67/100
# 103/103 [==============================] - 16s 160ms/step - loss: 8.2083 - mean_absolute_error: 8.5212 - root_mean_squared_error: 12.6798 - mean_absolute_percentage_error: 61.3525 - val_loss: 9.5409 - val_mean_absolute_error: 9.8528 - val_root_mean_squared_error: 15.5463 - val_mean_absolute_percentage_error: 64.2678
# Epoch 68/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.2898 - mean_absolute_error: 8.6012 - root_mean_squared_error: 12.9695 - mean_absolute_percentage_error: 61.6219 - val_loss: 9.4759 - val_mean_absolute_error: 9.7847 - val_root_mean_squared_error: 15.5913 - val_mean_absolute_percentage_error: 59.5635
# Epoch 69/100
# 103/103 [==============================] - 17s 163ms/step - loss: 7.9033 - mean_absolute_error: 8.2153 - root_mean_squared_error: 12.3657 - mean_absolute_percentage_error: 57.5759 - val_loss: 9.7241 - val_mean_absolute_error: 10.0391 - val_root_mean_squared_error: 15.6555 - val_mean_absolute_percentage_error: 60.7051
# Epoch 70/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.3718 - mean_absolute_error: 8.6845 - root_mean_squared_error: 12.7706 - mean_absolute_percentage_error: 61.9202 - val_loss: 9.9419 - val_mean_absolute_error: 10.2589 - val_root_mean_squared_error: 15.9194 - val_mean_absolute_percentage_error: 67.1920
# Epoch 71/100
# 103/103 [==============================] - 16s 160ms/step - loss: 8.6255 - mean_absolute_error: 8.9428 - root_mean_squared_error: 13.1303 - mean_absolute_percentage_error: 62.3737 - val_loss: 9.5135 - val_mean_absolute_error: 9.8287 - val_root_mean_squared_error: 15.6778 - val_mean_absolute_percentage_error: 61.2357
# Epoch 72/100
# 103/103 [==============================] - 17s 160ms/step - loss: 8.4786 - mean_absolute_error: 8.7930 - root_mean_squared_error: 13.1150 - mean_absolute_percentage_error: 63.0444 - val_loss: 9.6250 - val_mean_absolute_error: 9.9402 - val_root_mean_squared_error: 15.8064 - val_mean_absolute_percentage_error: 58.7946
# Epoch 73/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.6321 - mean_absolute_error: 8.9486 - root_mean_squared_error: 13.0886 - mean_absolute_percentage_error: 62.6211 - val_loss: 9.6852 - val_mean_absolute_error: 10.0027 - val_root_mean_squared_error: 15.4553 - val_mean_absolute_percentage_error: 67.8026
# Epoch 74/100
# 103/103 [==============================] - 16s 159ms/step - loss: 9.1435 - mean_absolute_error: 9.4621 - root_mean_squared_error: 14.0709 - mean_absolute_percentage_error: 66.4554 - val_loss: 9.8694 - val_mean_absolute_error: 10.1882 - val_root_mean_squared_error: 16.1716 - val_mean_absolute_percentage_error: 60.4746
# Epoch 75/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.9129 - mean_absolute_error: 9.2305 - root_mean_squared_error: 13.4207 - mean_absolute_percentage_error: 62.8145 - val_loss: 9.4625 - val_mean_absolute_error: 9.7852 - val_root_mean_squared_error: 15.4746 - val_mean_absolute_percentage_error: 56.7286
# Epoch 76/100
# 103/103 [==============================] - 16s 156ms/step - loss: 8.8358 - mean_absolute_error: 9.1536 - root_mean_squared_error: 13.3888 - mean_absolute_percentage_error: 61.9796 - val_loss: 9.4902 - val_mean_absolute_error: 9.8127 - val_root_mean_squared_error: 15.5013 - val_mean_absolute_percentage_error: 56.0094
# Epoch 77/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.9730 - mean_absolute_error: 9.2919 - root_mean_squared_error: 13.8816 - mean_absolute_percentage_error: 61.4397 - val_loss: 9.6141 - val_mean_absolute_error: 9.9331 - val_root_mean_squared_error: 15.6992 - val_mean_absolute_percentage_error: 54.0980
# Epoch 78/100
# 103/103 [==============================] - 16s 160ms/step - loss: 9.0209 - mean_absolute_error: 9.3387 - root_mean_squared_error: 13.8599 - mean_absolute_percentage_error: 61.5247 - val_loss: 9.2423 - val_mean_absolute_error: 9.5622 - val_root_mean_squared_error: 15.3295 - val_mean_absolute_percentage_error: 57.5148
# Epoch 79/100
# 103/103 [==============================] - 16s 160ms/step - loss: 8.6870 - mean_absolute_error: 9.0037 - root_mean_squared_error: 13.2764 - mean_absolute_percentage_error: 60.0958 - val_loss: 10.0275 - val_mean_absolute_error: 10.3492 - val_root_mean_squared_error: 15.9370 - val_mean_absolute_percentage_error: 54.7844
# Epoch 80/100
# 103/103 [==============================] - 17s 160ms/step - loss: 8.9334 - mean_absolute_error: 9.2509 - root_mean_squared_error: 13.6806 - mean_absolute_percentage_error: 60.6743 - val_loss: 9.2880 - val_mean_absolute_error: 9.6074 - val_root_mean_squared_error: 15.2555 - val_mean_absolute_percentage_error: 57.8664
# Epoch 81/100
# 103/103 [==============================] - 16s 157ms/step - loss: 8.6309 - mean_absolute_error: 8.9504 - root_mean_squared_error: 13.3364 - mean_absolute_percentage_error: 60.7970 - val_loss: 9.2364 - val_mean_absolute_error: 9.5532 - val_root_mean_squared_error: 15.2791 - val_mean_absolute_percentage_error: 56.8399
# Epoch 82/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.9236 - mean_absolute_error: 9.2436 - root_mean_squared_error: 13.6670 - mean_absolute_percentage_error: 62.2137 - val_loss: 9.5397 - val_mean_absolute_error: 9.8627 - val_root_mean_squared_error: 15.4631 - val_mean_absolute_percentage_error: 55.5574
# Epoch 83/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.9631 - mean_absolute_error: 9.2824 - root_mean_squared_error: 13.6956 - mean_absolute_percentage_error: 61.6337 - val_loss: 9.5313 - val_mean_absolute_error: 9.8501 - val_root_mean_squared_error: 15.6062 - val_mean_absolute_percentage_error: 58.2885
# Epoch 84/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.8512 - mean_absolute_error: 9.1714 - root_mean_squared_error: 13.5146 - mean_absolute_percentage_error: 59.5370 - val_loss: 9.8011 - val_mean_absolute_error: 10.1242 - val_root_mean_squared_error: 15.8214 - val_mean_absolute_percentage_error: 53.5687
# Epoch 85/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.9619 - mean_absolute_error: 9.2819 - root_mean_squared_error: 13.5141 - mean_absolute_percentage_error: 61.4558 - val_loss: 9.2504 - val_mean_absolute_error: 9.5698 - val_root_mean_squared_error: 15.1575 - val_mean_absolute_percentage_error: 57.0068
# Epoch 86/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.8128 - mean_absolute_error: 9.1318 - root_mean_squared_error: 13.4866 - mean_absolute_percentage_error: 62.0595 - val_loss: 9.1587 - val_mean_absolute_error: 9.4749 - val_root_mean_squared_error: 14.9914 - val_mean_absolute_percentage_error: 53.8624
# Epoch 87/100
# 103/103 [==============================] - 16s 159ms/step - loss: 8.6977 - mean_absolute_error: 9.0163 - root_mean_squared_error: 13.4789 - mean_absolute_percentage_error: 59.8438 - val_loss: 9.4325 - val_mean_absolute_error: 9.7539 - val_root_mean_squared_error: 15.1543 - val_mean_absolute_percentage_error: 56.8560
# Epoch 88/100
# 103/103 [==============================] - 16s 160ms/step - loss: 8.6273 - mean_absolute_error: 8.9470 - root_mean_squared_error: 13.2712 - mean_absolute_percentage_error: 59.2393 - val_loss: 8.9814 - val_mean_absolute_error: 9.3005 - val_root_mean_squared_error: 14.8568 - val_mean_absolute_percentage_error: 53.3559
# Epoch 89/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.3957 - mean_absolute_error: 8.7171 - root_mean_squared_error: 12.9613 - mean_absolute_percentage_error: 57.2516 - val_loss: 10.2948 - val_mean_absolute_error: 10.6157 - val_root_mean_squared_error: 16.0268 - val_mean_absolute_percentage_error: 69.6931
# Epoch 90/100
# 103/103 [==============================] - 17s 160ms/step - loss: 8.5178 - mean_absolute_error: 8.8376 - root_mean_squared_error: 13.0511 - mean_absolute_percentage_error: 58.7899 - val_loss: 15.5423 - val_mean_absolute_error: 15.8704 - val_root_mean_squared_error: 20.0182 - val_mean_absolute_percentage_error: 113.2489
# Epoch 91/100
# 103/103 [==============================] - 16s 156ms/step - loss: 8.8366 - mean_absolute_error: 9.1585 - root_mean_squared_error: 13.3970 - mean_absolute_percentage_error: 63.3677 - val_loss: 10.0999 - val_mean_absolute_error: 10.4208 - val_root_mean_squared_error: 15.8069 - val_mean_absolute_percentage_error: 64.2687
# Epoch 92/100
# 103/103 [==============================] - 16s 158ms/step - loss: 8.5555 - mean_absolute_error: 8.8745 - root_mean_squared_error: 13.1894 - mean_absolute_percentage_error: 59.7209 - val_loss: 9.2421 - val_mean_absolute_error: 9.5639 - val_root_mean_squared_error: 15.1397 - val_mean_absolute_percentage_error: 60.5828
# Epoch 93/100
# 103/103 [==============================] - 17s 162ms/step - loss: 8.5111 - mean_absolute_error: 8.8300 - root_mean_squared_error: 13.1017 - mean_absolute_percentage_error: 58.6794 - val_loss: 9.2794 - val_mean_absolute_error: 9.6021 - val_root_mean_squared_error: 15.2114 - val_mean_absolute_percentage_error: 58.5772
# Epoch 94/100
# 103/103 [==============================] - 16s 159ms/step - loss: 7.9860 - mean_absolute_error: 8.3042 - root_mean_squared_error: 12.6258 - mean_absolute_percentage_error: 54.9523 - val_loss: 9.2093 - val_mean_absolute_error: 9.5300 - val_root_mean_squared_error: 15.1302 - val_mean_absolute_percentage_error: 56.3012
# Epoch 95/100
# 103/103 [==============================] - 16s 160ms/step - loss: 7.7292 - mean_absolute_error: 8.0447 - root_mean_squared_error: 12.2331 - mean_absolute_percentage_error: 52.3953 - val_loss: 9.5017 - val_mean_absolute_error: 9.8236 - val_root_mean_squared_error: 15.3982 - val_mean_absolute_percentage_error: 55.8954
# Epoch 96/100
# 103/103 [==============================] - 17s 161ms/step - loss: 7.5474 - mean_absolute_error: 7.8651 - root_mean_squared_error: 11.8759 - mean_absolute_percentage_error: 52.9586 - val_loss: 9.2619 - val_mean_absolute_error: 9.5831 - val_root_mean_squared_error: 15.2621 - val_mean_absolute_percentage_error: 56.2982
# Epoch 97/100
# 103/103 [==============================] - 17s 162ms/step - loss: 8.0248 - mean_absolute_error: 8.3433 - root_mean_squared_error: 12.6027 - mean_absolute_percentage_error: 55.1216 - val_loss: 9.3811 - val_mean_absolute_error: 9.7004 - val_root_mean_squared_error: 15.2471 - val_mean_absolute_percentage_error: 58.9161
# Epoch 98/100
# 103/103 [==============================] - 16s 160ms/step - loss: 7.9295 - mean_absolute_error: 8.2493 - root_mean_squared_error: 12.4885 - mean_absolute_percentage_error: 56.2545 - val_loss: 9.6828 - val_mean_absolute_error: 10.0029 - val_root_mean_squared_error: 15.5047 - val_mean_absolute_percentage_error: 56.7547
# Epoch 99/100
# 103/103 [==============================] - 16s 160ms/step - loss: 7.9747 - mean_absolute_error: 8.2925 - root_mean_squared_error: 12.7253 - mean_absolute_percentage_error: 55.6982 - val_loss: 9.6311 - val_mean_absolute_error: 9.9548 - val_root_mean_squared_error: 15.5077 - val_mean_absolute_percentage_error: 59.8751
# Epoch 100/100
# 103/103 [==============================] - 16s 159ms/step - loss: 7.8324 - mean_absolute_error: 8.1516 - root_mean_squared_error: 12.6540 - mean_absolute_percentage_error: 51.3751 - val_loss: 8.9795 - val_mean_absolute_error: 9.2998 - val_root_mean_squared_error: 14.9759 - val_mean_absolute_percentage_error: 54.4653

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 62ms/step - loss: 8.9795 - mean_absolute_error: 9.2998 - root_mean_squared_error: 14.9759 - mean_absolute_percentage_error: 54.4653
# Model Loss: [8.979458808898926, 9.299792289733887, 14.975850105285645, 54.46533966064453]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 165ms/step
# Predicted Putusan: [11.140948]

# %%
model_scenario_name = "LSTM 11"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/LSTM 11\assets
# INFO:tensorflow:Assets written to: ../Model/LSTM 11\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "LSTM 11"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 164ms/step
# Predicted Putusan: [11.140948]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
