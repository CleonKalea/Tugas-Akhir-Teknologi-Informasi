# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_8372\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 512
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 512

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=256 
)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output = tf.keras.layers.BatchNormalization()(lstm_output)

lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_2 = tf.keras.layers.BatchNormalization()(lstm_output_2)

lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
lstm_output_3 = tf.keras.layers.BatchNormalization()(lstm_output_3)

pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical = tf.keras.layers.BatchNormalization()(numerical_input)
numerical_dense = tf.keras.layers.Dense(32, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 512)]        0           []
#
#  embedding (Embedding)          (None, 512, 256)     4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 512, 64)      73984       ['embedding[0][0]']
#
#  batch_normalization (BatchNorm  (None, 512, 64)     256         ['bidirectional[0][0]']
#  alization)
#
#  bidirectional_1 (Bidirectional  (None, 512, 128)    66048       ['batch_normalization[0][0]']
#  )
#
#  batch_normalization_1 (BatchNo  (None, 512, 128)    512         ['bidirectional_1[0][0]']
#  rmalization)
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 512, 64)     41216       ['batch_normalization_1[0][0]']
#  )
#
#  batch_normalization_3 (BatchNo  (None, 5)           20          ['numerical_input[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 512, 64)     256         ['bidirectional_2[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 32)           192         ['batch_normalization_3[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['batch_normalization_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96)          384         ['concatenate[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,893,045
# Trainable params: 4,892,331
# Non-trainable params: 714
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 27s 202ms/step - loss: 33.8947 - mean_absolute_error: 33.5101 - root_mean_squared_error: 46.0498 - mean_absolute_percentage_error: 94.3914 - val_loss: 35.1928 - val_mean_absolute_error: 34.8232 - val_root_mean_squared_error: 48.2302 - val_mean_absolute_percentage_error: 88.5270 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 19s 187ms/step - loss: 30.2116 - mean_absolute_error: 29.8545 - root_mean_squared_error: 42.8243 - mean_absolute_percentage_error: 76.1779 - val_loss: 32.9299 - val_mean_absolute_error: 32.5846 - val_root_mean_squared_error: 46.5184 - val_mean_absolute_percentage_error: 77.2027 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 19s 183ms/step - loss: 23.2761 - mean_absolute_error: 22.9404 - root_mean_squared_error: 35.0756 - mean_absolute_percentage_error: 60.0023 - val_loss: 29.1553 - val_mean_absolute_error: 28.8343 - val_root_mean_squared_error: 42.7109 - val_mean_absolute_percentage_error: 65.2301 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 19s 187ms/step - loss: 15.3304 - mean_absolute_error: 15.0181 - root_mean_squared_error: 23.2654 - mean_absolute_percentage_error: 57.4562 - val_loss: 19.8164 - val_mean_absolute_error: 19.5117 - val_root_mean_squared_error: 29.7698 - val_mean_absolute_percentage_error: 52.2201 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 18s 176ms/step - loss: 10.7688 - mean_absolute_error: 10.4654 - root_mean_squared_error: 16.5466 - mean_absolute_percentage_error: 49.2310 - val_loss: 14.9859 - val_mean_absolute_error: 14.6876 - val_root_mean_squared_error: 23.0048 - val_mean_absolute_percentage_error: 44.5451 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 18s 177ms/step - loss: 9.6867 - mean_absolute_error: 9.3894 - root_mean_squared_error: 14.9270 - mean_absolute_percentage_error: 45.7304 - val_loss: 11.1922 - val_mean_absolute_error: 10.9031 - val_root_mean_squared_error: 18.0278 - val_mean_absolute_percentage_error: 41.8862 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 18s 176ms/step - loss: 8.8129 - mean_absolute_error: 8.5200 - root_mean_squared_error: 13.7701 - mean_absolute_percentage_error: 40.0529 - val_loss: 9.2503 - val_mean_absolute_error: 8.9605 - val_root_mean_squared_error: 15.4352 - val_mean_absolute_percentage_error: 36.8533 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 18s 175ms/step - loss: 7.9960 - mean_absolute_error: 7.7099 - root_mean_squared_error: 12.6479 - mean_absolute_percentage_error: 36.5908 - val_loss: 9.1053 - val_mean_absolute_error: 8.8209 - val_root_mean_squared_error: 15.2177 - val_mean_absolute_percentage_error: 35.6283 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 18s 174ms/step - loss: 7.9392 - mean_absolute_error: 7.6559 - root_mean_squared_error: 12.3724 - mean_absolute_percentage_error: 37.0613 - val_loss: 10.4595 - val_mean_absolute_error: 10.1837 - val_root_mean_squared_error: 16.3356 - val_mean_absolute_percentage_error: 40.5260 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 18s 178ms/step - loss: 7.3613 - mean_absolute_error: 7.0802 - root_mean_squared_error: 11.5655 - mean_absolute_percentage_error: 33.9750 - val_loss: 7.6087 - val_mean_absolute_error: 7.3257 - val_root_mean_squared_error: 13.0781 - val_mean_absolute_percentage_error: 33.2202 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 18s 173ms/step - loss: 6.9870 - mean_absolute_error: 6.7113 - root_mean_squared_error: 11.0075 - mean_absolute_percentage_error: 30.8721 - val_loss: 7.5687 - val_mean_absolute_error: 7.2899 - val_root_mean_squared_error: 13.2716 - val_mean_absolute_percentage_error: 34.2235 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 18s 176ms/step - loss: 7.1557 - mean_absolute_error: 6.8824 - root_mean_squared_error: 11.0997 - mean_absolute_percentage_error: 31.4538 - val_loss: 7.4628 - val_mean_absolute_error: 7.1962 - val_root_mean_squared_error: 12.7209 - val_mean_absolute_percentage_error: 35.0697 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 18s 173ms/step - loss: 6.6809 - mean_absolute_error: 6.4110 - root_mean_squared_error: 10.2365 - mean_absolute_percentage_error: 30.5324 - val_loss: 8.0619 - val_mean_absolute_error: 7.8004 - val_root_mean_squared_error: 12.6795 - val_mean_absolute_percentage_error: 38.1848 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 18s 178ms/step - loss: 6.0502 - mean_absolute_error: 5.7803 - root_mean_squared_error: 9.1947 - mean_absolute_percentage_error: 27.5916 - val_loss: 7.5577 - val_mean_absolute_error: 7.2935 - val_root_mean_squared_error: 12.5790 - val_mean_absolute_percentage_error: 33.2526 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 18s 177ms/step - loss: 6.1978 - mean_absolute_error: 5.9314 - root_mean_squared_error: 9.4950 - mean_absolute_percentage_error: 27.3648 - val_loss: 8.7383 - val_mean_absolute_error: 8.4696 - val_root_mean_squared_error: 13.8683 - val_mean_absolute_percentage_error: 34.2397 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 19s 182ms/step - loss: 5.9895 - mean_absolute_error: 5.7256 - root_mean_squared_error: 9.2382 - mean_absolute_percentage_error: 27.2333 - val_loss: 7.1214 - val_mean_absolute_error: 6.8617 - val_root_mean_squared_error: 12.0587 - val_mean_absolute_percentage_error: 34.2030 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 19s 181ms/step - loss: 5.7333 - mean_absolute_error: 5.4713 - root_mean_squared_error: 8.6663 - mean_absolute_percentage_error: 25.2895 - val_loss: 6.9372 - val_mean_absolute_error: 6.6665 - val_root_mean_squared_error: 12.1021 - val_mean_absolute_percentage_error: 33.0953 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 18s 175ms/step - loss: 5.7724 - mean_absolute_error: 5.5137 - root_mean_squared_error: 8.9475 - mean_absolute_percentage_error: 25.1646 - val_loss: 7.2084 - val_mean_absolute_error: 6.9575 - val_root_mean_squared_error: 11.6069 - val_mean_absolute_percentage_error: 34.6125 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 19s 180ms/step - loss: 5.5854 - mean_absolute_error: 5.3261 - root_mean_squared_error: 8.6873 - mean_absolute_percentage_error: 24.2462 - val_loss: 6.5120 - val_mean_absolute_error: 6.2540 - val_root_mean_squared_error: 11.2342 - val_mean_absolute_percentage_error: 34.3090 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 18s 176ms/step - loss: 5.5564 - mean_absolute_error: 5.3018 - root_mean_squared_error: 8.4837 - mean_absolute_percentage_error: 24.7633 - val_loss: 6.5678 - val_mean_absolute_error: 6.3146 - val_root_mean_squared_error: 11.0181 - val_mean_absolute_percentage_error: 33.8689 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 17s 167ms/step - loss: 5.5490 - mean_absolute_error: 5.2983 - root_mean_squared_error: 8.4493 - mean_absolute_percentage_error: 23.7879 - val_loss: 7.3997 - val_mean_absolute_error: 7.1530 - val_root_mean_squared_error: 11.9715 - val_mean_absolute_percentage_error: 35.5869 - lr: 1.0000e-04
# Epoch 22/100
# 103/103 [==============================] - 16s 151ms/step - loss: 5.3549 - mean_absolute_error: 5.1047 - root_mean_squared_error: 8.2496 - mean_absolute_percentage_error: 23.3204 - val_loss: 6.7572 - val_mean_absolute_error: 6.5062 - val_root_mean_squared_error: 11.3394 - val_mean_absolute_percentage_error: 33.0274 - lr: 1.0000e-04
# Epoch 23/100
# 103/103 [==============================] - 16s 158ms/step - loss: 5.2096 - mean_absolute_error: 4.9650 - root_mean_squared_error: 7.9785 - mean_absolute_percentage_error: 23.3382 - val_loss: 6.9755 - val_mean_absolute_error: 6.7428 - val_root_mean_squared_error: 11.3564 - val_mean_absolute_percentage_error: 34.6367 - lr: 1.0000e-04
# Epoch 24/100
# 103/103 [==============================] - 16s 157ms/step - loss: 5.0448 - mean_absolute_error: 4.7996 - root_mean_squared_error: 7.8087 - mean_absolute_percentage_error: 21.9367 - val_loss: 6.8972 - val_mean_absolute_error: 6.6660 - val_root_mean_squared_error: 11.3476 - val_mean_absolute_percentage_error: 35.2105 - lr: 1.0000e-04
# Epoch 25/100
# 103/103 [==============================] - 16s 155ms/step - loss: 4.9275 - mean_absolute_error: 4.6822 - root_mean_squared_error: 7.5253 - mean_absolute_percentage_error: 21.3117 - val_loss: 7.1121 - val_mean_absolute_error: 6.8839 - val_root_mean_squared_error: 11.6778 - val_mean_absolute_percentage_error: 33.7654 - lr: 5.0000e-05
# Epoch 26/100
# 103/103 [==============================] - 16s 154ms/step - loss: 4.8527 - mean_absolute_error: 4.6112 - root_mean_squared_error: 7.3725 - mean_absolute_percentage_error: 21.7305 - val_loss: 6.8715 - val_mean_absolute_error: 6.6401 - val_root_mean_squared_error: 11.2997 - val_mean_absolute_percentage_error: 35.5099 - lr: 5.0000e-05
# Epoch 27/100
# 103/103 [==============================] - 16s 151ms/step - loss: 4.8607 - mean_absolute_error: 4.6165 - root_mean_squared_error: 7.2965 - mean_absolute_percentage_error: 21.2169 - val_loss: 6.5217 - val_mean_absolute_error: 6.2764 - val_root_mean_squared_error: 11.0610 - val_mean_absolute_percentage_error: 32.7897 - lr: 5.0000e-05
# Epoch 28/100
# 103/103 [==============================] - 16s 160ms/step - loss: 4.6491 - mean_absolute_error: 4.4048 - root_mean_squared_error: 7.0494 - mean_absolute_percentage_error: 20.0305 - val_loss: 6.7059 - val_mean_absolute_error: 6.4654 - val_root_mean_squared_error: 11.1731 - val_mean_absolute_percentage_error: 32.4003 - lr: 5.0000e-05
# Epoch 29/100
# 103/103 [==============================] - 19s 183ms/step - loss: 4.7052 - mean_absolute_error: 4.4636 - root_mean_squared_error: 7.0749 - mean_absolute_percentage_error: 21.2359 - val_loss: 6.5301 - val_mean_absolute_error: 6.3047 - val_root_mean_squared_error: 11.0479 - val_mean_absolute_percentage_error: 34.2910 - lr: 5.0000e-05
# Epoch 30/100
# 103/103 [==============================] - 17s 167ms/step - loss: 4.7337 - mean_absolute_error: 4.4944 - root_mean_squared_error: 7.1302 - mean_absolute_percentage_error: 21.7621 - val_loss: 6.4361 - val_mean_absolute_error: 6.2114 - val_root_mean_squared_error: 10.9267 - val_mean_absolute_percentage_error: 33.6022 - lr: 2.5000e-05
# Epoch 31/100
# 103/103 [==============================] - 17s 169ms/step - loss: 4.5679 - mean_absolute_error: 4.3278 - root_mean_squared_error: 6.8044 - mean_absolute_percentage_error: 19.8034 - val_loss: 6.5633 - val_mean_absolute_error: 6.3384 - val_root_mean_squared_error: 10.9743 - val_mean_absolute_percentage_error: 33.5235 - lr: 2.5000e-05
# Epoch 32/100
# 103/103 [==============================] - 18s 172ms/step - loss: 4.5253 - mean_absolute_error: 4.2871 - root_mean_squared_error: 6.8272 - mean_absolute_percentage_error: 20.7146 - val_loss: 6.2286 - val_mean_absolute_error: 6.0017 - val_root_mean_squared_error: 10.8317 - val_mean_absolute_percentage_error: 32.5574 - lr: 2.5000e-05
# Epoch 33/100
# 103/103 [==============================] - 18s 176ms/step - loss: 4.4277 - mean_absolute_error: 4.1874 - root_mean_squared_error: 6.4094 - mean_absolute_percentage_error: 20.6138 - val_loss: 6.3455 - val_mean_absolute_error: 6.1101 - val_root_mean_squared_error: 10.9326 - val_mean_absolute_percentage_error: 32.7278 - lr: 2.5000e-05
# Epoch 34/100
# 103/103 [==============================] - 19s 186ms/step - loss: 4.4728 - mean_absolute_error: 4.2331 - root_mean_squared_error: 6.6546 - mean_absolute_percentage_error: 20.2136 - val_loss: 6.2396 - val_mean_absolute_error: 6.0050 - val_root_mean_squared_error: 10.8199 - val_mean_absolute_percentage_error: 32.7326 - lr: 2.5000e-05
# Epoch 35/100
# 103/103 [==============================] - 19s 187ms/step - loss: 4.6042 - mean_absolute_error: 4.3673 - root_mean_squared_error: 6.9814 - mean_absolute_percentage_error: 20.6186 - val_loss: 6.1488 - val_mean_absolute_error: 5.9161 - val_root_mean_squared_error: 10.7602 - val_mean_absolute_percentage_error: 32.7574 - lr: 2.5000e-05
# Epoch 36/100
# 103/103 [==============================] - 19s 186ms/step - loss: 4.1971 - mean_absolute_error: 3.9600 - root_mean_squared_error: 6.1932 - mean_absolute_percentage_error: 18.6154 - val_loss: 6.1990 - val_mean_absolute_error: 5.9748 - val_root_mean_squared_error: 10.7798 - val_mean_absolute_percentage_error: 33.1601 - lr: 2.5000e-05
# Epoch 37/100
# 103/103 [==============================] - 19s 188ms/step - loss: 4.4142 - mean_absolute_error: 4.1763 - root_mean_squared_error: 6.7077 - mean_absolute_percentage_error: 19.3576 - val_loss: 6.2014 - val_mean_absolute_error: 5.9734 - val_root_mean_squared_error: 10.8204 - val_mean_absolute_percentage_error: 33.5173 - lr: 2.5000e-05
# Epoch 38/100
# 103/103 [==============================] - 20s 190ms/step - loss: 4.3592 - mean_absolute_error: 4.1226 - root_mean_squared_error: 6.4800 - mean_absolute_percentage_error: 20.4569 - val_loss: 6.6760 - val_mean_absolute_error: 6.4542 - val_root_mean_squared_error: 11.1426 - val_mean_absolute_percentage_error: 32.9374 - lr: 2.5000e-05
# Epoch 39/100
# 103/103 [==============================] - 19s 189ms/step - loss: 4.4277 - mean_absolute_error: 4.1907 - root_mean_squared_error: 6.7452 - mean_absolute_percentage_error: 19.9947 - val_loss: 6.2133 - val_mean_absolute_error: 5.9878 - val_root_mean_squared_error: 10.8309 - val_mean_absolute_percentage_error: 33.4103 - lr: 2.5000e-05
# Epoch 40/100
# 103/103 [==============================] - 19s 185ms/step - loss: 4.6301 - mean_absolute_error: 4.3972 - root_mean_squared_error: 7.0107 - mean_absolute_percentage_error: 20.4808 - val_loss: 6.2952 - val_mean_absolute_error: 6.0682 - val_root_mean_squared_error: 10.8940 - val_mean_absolute_percentage_error: 32.5102 - lr: 2.5000e-05
# Epoch 41/100
# 103/103 [==============================] - 17s 169ms/step - loss: 4.3624 - mean_absolute_error: 4.1275 - root_mean_squared_error: 6.5836 - mean_absolute_percentage_error: 19.7493 - val_loss: 6.2485 - val_mean_absolute_error: 6.0229 - val_root_mean_squared_error: 10.8620 - val_mean_absolute_percentage_error: 32.8365 - lr: 1.2500e-05
# Epoch 42/100
# 103/103 [==============================] - 16s 151ms/step - loss: 4.3590 - mean_absolute_error: 4.1233 - root_mean_squared_error: 6.4265 - mean_absolute_percentage_error: 19.4505 - val_loss: 6.2279 - val_mean_absolute_error: 6.0038 - val_root_mean_squared_error: 10.8110 - val_mean_absolute_percentage_error: 33.2312 - lr: 1.2500e-05
# Epoch 43/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.3128 - mean_absolute_error: 4.0772 - root_mean_squared_error: 6.2957 - mean_absolute_percentage_error: 20.1710 - val_loss: 6.1434 - val_mean_absolute_error: 5.9189 - val_root_mean_squared_error: 10.7845 - val_mean_absolute_percentage_error: 33.7107 - lr: 1.2500e-05
# Epoch 44/100
# 103/103 [==============================] - 17s 165ms/step - loss: 4.1815 - mean_absolute_error: 3.9451 - root_mean_squared_error: 6.0648 - mean_absolute_percentage_error: 19.0751 - val_loss: 6.2191 - val_mean_absolute_error: 5.9963 - val_root_mean_squared_error: 10.7673 - val_mean_absolute_percentage_error: 32.9699 - lr: 1.2500e-05
# Epoch 45/100
# 103/103 [==============================] - 16s 159ms/step - loss: 4.2871 - mean_absolute_error: 4.0554 - root_mean_squared_error: 6.4573 - mean_absolute_percentage_error: 19.5327 - val_loss: 6.1648 - val_mean_absolute_error: 5.9390 - val_root_mean_squared_error: 10.7811 - val_mean_absolute_percentage_error: 33.1668 - lr: 1.2500e-05
# Epoch 46/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.1413 - mean_absolute_error: 3.9047 - root_mean_squared_error: 6.2936 - mean_absolute_percentage_error: 18.4504 - val_loss: 6.1144 - val_mean_absolute_error: 5.8910 - val_root_mean_squared_error: 10.7465 - val_mean_absolute_percentage_error: 32.8188 - lr: 1.2500e-05
# Epoch 47/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.4163 - mean_absolute_error: 4.1811 - root_mean_squared_error: 6.5959 - mean_absolute_percentage_error: 19.8845 - val_loss: 6.0441 - val_mean_absolute_error: 5.8191 - val_root_mean_squared_error: 10.6197 - val_mean_absolute_percentage_error: 33.2481 - lr: 1.2500e-05
# Epoch 48/100
# 103/103 [==============================] - 16s 158ms/step - loss: 4.1589 - mean_absolute_error: 3.9240 - root_mean_squared_error: 6.2354 - mean_absolute_percentage_error: 18.2866 - val_loss: 6.0373 - val_mean_absolute_error: 5.8116 - val_root_mean_squared_error: 10.6177 - val_mean_absolute_percentage_error: 32.8671 - lr: 1.2500e-05
# Epoch 49/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.2513 - mean_absolute_error: 4.0190 - root_mean_squared_error: 6.3314 - mean_absolute_percentage_error: 19.1043 - val_loss: 6.0151 - val_mean_absolute_error: 5.7929 - val_root_mean_squared_error: 10.5895 - val_mean_absolute_percentage_error: 33.1929 - lr: 1.2500e-05
# Epoch 50/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.2450 - mean_absolute_error: 4.0114 - root_mean_squared_error: 6.3563 - mean_absolute_percentage_error: 19.0757 - val_loss: 6.1091 - val_mean_absolute_error: 5.8891 - val_root_mean_squared_error: 10.6884 - val_mean_absolute_percentage_error: 33.0833 - lr: 1.2500e-05
# Epoch 51/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.3586 - mean_absolute_error: 4.1239 - root_mean_squared_error: 6.6171 - mean_absolute_percentage_error: 18.8949 - val_loss: 6.0636 - val_mean_absolute_error: 5.8442 - val_root_mean_squared_error: 10.6489 - val_mean_absolute_percentage_error: 32.7897 - lr: 1.2500e-05
# Epoch 52/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.2061 - mean_absolute_error: 3.9712 - root_mean_squared_error: 6.3448 - mean_absolute_percentage_error: 18.9619 - val_loss: 5.9922 - val_mean_absolute_error: 5.7707 - val_root_mean_squared_error: 10.6210 - val_mean_absolute_percentage_error: 32.5232 - lr: 1.2500e-05
# Epoch 53/100
# 103/103 [==============================] - 16s 156ms/step - loss: 4.1716 - mean_absolute_error: 3.9380 - root_mean_squared_error: 6.2625 - mean_absolute_percentage_error: 18.4950 - val_loss: 6.0034 - val_mean_absolute_error: 5.7831 - val_root_mean_squared_error: 10.6086 - val_mean_absolute_percentage_error: 32.8600 - lr: 1.2500e-05
# Epoch 54/100
# 103/103 [==============================] - 16s 156ms/step - loss: 4.1857 - mean_absolute_error: 3.9508 - root_mean_squared_error: 6.4016 - mean_absolute_percentage_error: 18.9580 - val_loss: 6.1360 - val_mean_absolute_error: 5.9163 - val_root_mean_squared_error: 10.6847 - val_mean_absolute_percentage_error: 32.7522 - lr: 1.2500e-05
# Epoch 55/100
# 103/103 [==============================] - 16s 159ms/step - loss: 4.1654 - mean_absolute_error: 3.9313 - root_mean_squared_error: 6.1856 - mean_absolute_percentage_error: 18.0084 - val_loss: 5.9952 - val_mean_absolute_error: 5.7747 - val_root_mean_squared_error: 10.6357 - val_mean_absolute_percentage_error: 32.6320 - lr: 1.2500e-05
# Epoch 56/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0558 - mean_absolute_error: 3.8199 - root_mean_squared_error: 6.0556 - mean_absolute_percentage_error: 18.1232 - val_loss: 6.0848 - val_mean_absolute_error: 5.8652 - val_root_mean_squared_error: 10.6714 - val_mean_absolute_percentage_error: 32.5499 - lr: 1.2500e-05
# Epoch 57/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.1549 - mean_absolute_error: 3.9229 - root_mean_squared_error: 6.1676 - mean_absolute_percentage_error: 18.9191 - val_loss: 5.9980 - val_mean_absolute_error: 5.7778 - val_root_mean_squared_error: 10.6398 - val_mean_absolute_percentage_error: 32.4758 - lr: 1.2500e-05
# Epoch 58/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0613 - mean_absolute_error: 3.8262 - root_mean_squared_error: 6.0191 - mean_absolute_percentage_error: 17.7130 - val_loss: 6.0048 - val_mean_absolute_error: 5.7849 - val_root_mean_squared_error: 10.6342 - val_mean_absolute_percentage_error: 32.6656 - lr: 6.2500e-06
# Epoch 59/100
# 103/103 [==============================] - 16s 156ms/step - loss: 4.0674 - mean_absolute_error: 3.8314 - root_mean_squared_error: 6.1659 - mean_absolute_percentage_error: 17.2892 - val_loss: 6.0042 - val_mean_absolute_error: 5.7856 - val_root_mean_squared_error: 10.6622 - val_mean_absolute_percentage_error: 32.5343 - lr: 6.2500e-06
# Epoch 60/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.2063 - mean_absolute_error: 3.9729 - root_mean_squared_error: 6.5133 - mean_absolute_percentage_error: 18.5332 - val_loss: 5.9741 - val_mean_absolute_error: 5.7551 - val_root_mean_squared_error: 10.6528 - val_mean_absolute_percentage_error: 32.5583 - lr: 6.2500e-06
# Epoch 61/100
# 103/103 [==============================] - 16s 157ms/step - loss: 3.9546 - mean_absolute_error: 3.7207 - root_mean_squared_error: 5.8360 - mean_absolute_percentage_error: 17.3461 - val_loss: 5.9637 - val_mean_absolute_error: 5.7439 - val_root_mean_squared_error: 10.6404 - val_mean_absolute_percentage_error: 32.5069 - lr: 6.2500e-06
# Epoch 62/100
# 103/103 [==============================] - 16s 156ms/step - loss: 4.1824 - mean_absolute_error: 3.9495 - root_mean_squared_error: 6.0803 - mean_absolute_percentage_error: 19.2982 - val_loss: 5.9737 - val_mean_absolute_error: 5.7534 - val_root_mean_squared_error: 10.6603 - val_mean_absolute_percentage_error: 32.8343 - lr: 6.2500e-06
# Epoch 63/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.2473 - mean_absolute_error: 4.0152 - root_mean_squared_error: 6.3582 - mean_absolute_percentage_error: 19.4233 - val_loss: 5.9733 - val_mean_absolute_error: 5.7526 - val_root_mean_squared_error: 10.6498 - val_mean_absolute_percentage_error: 32.6655 - lr: 6.2500e-06
# Epoch 64/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.1352 - mean_absolute_error: 3.9044 - root_mean_squared_error: 6.0496 - mean_absolute_percentage_error: 19.1719 - val_loss: 6.0175 - val_mean_absolute_error: 5.8029 - val_root_mean_squared_error: 10.6447 - val_mean_absolute_percentage_error: 32.7675 - lr: 6.2500e-06
# Epoch 65/100
# 103/103 [==============================] - 16s 154ms/step - loss: 3.9872 - mean_absolute_error: 3.7578 - root_mean_squared_error: 5.9375 - mean_absolute_percentage_error: 17.8252 - val_loss: 5.9639 - val_mean_absolute_error: 5.7432 - val_root_mean_squared_error: 10.6613 - val_mean_absolute_percentage_error: 32.7541 - lr: 6.2500e-06
# Epoch 66/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0944 - mean_absolute_error: 3.8656 - root_mean_squared_error: 5.9826 - mean_absolute_percentage_error: 18.5901 - val_loss: 5.9189 - val_mean_absolute_error: 5.7002 - val_root_mean_squared_error: 10.6312 - val_mean_absolute_percentage_error: 32.8421 - lr: 6.2500e-06
# Epoch 67/100
# 103/103 [==============================] - 16s 154ms/step - loss: 4.3184 - mean_absolute_error: 4.0884 - root_mean_squared_error: 6.4223 - mean_absolute_percentage_error: 18.9510 - val_loss: 5.9729 - val_mean_absolute_error: 5.7535 - val_root_mean_squared_error: 10.6184 - val_mean_absolute_percentage_error: 32.7798 - lr: 6.2500e-06
# Epoch 68/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0486 - mean_absolute_error: 3.8129 - root_mean_squared_error: 5.9774 - mean_absolute_percentage_error: 17.9831 - val_loss: 6.0325 - val_mean_absolute_error: 5.8170 - val_root_mean_squared_error: 10.6486 - val_mean_absolute_percentage_error: 32.6479 - lr: 6.2500e-06
# Epoch 69/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0224 - mean_absolute_error: 3.7902 - root_mean_squared_error: 5.9790 - mean_absolute_percentage_error: 17.9586 - val_loss: 5.9676 - val_mean_absolute_error: 5.7496 - val_root_mean_squared_error: 10.6130 - val_mean_absolute_percentage_error: 32.6916 - lr: 6.2500e-06
# Epoch 70/100
# 103/103 [==============================] - 16s 152ms/step - loss: 3.9634 - mean_absolute_error: 3.7308 - root_mean_squared_error: 5.8847 - mean_absolute_percentage_error: 17.5689 - val_loss: 5.9433 - val_mean_absolute_error: 5.7264 - val_root_mean_squared_error: 10.5792 - val_mean_absolute_percentage_error: 32.7431 - lr: 6.2500e-06
# Epoch 71/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.2183 - mean_absolute_error: 3.9852 - root_mean_squared_error: 6.2274 - mean_absolute_percentage_error: 18.5264 - val_loss: 5.9831 - val_mean_absolute_error: 5.7648 - val_root_mean_squared_error: 10.5884 - val_mean_absolute_percentage_error: 32.7158 - lr: 6.2500e-06
# Epoch 72/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.1786 - mean_absolute_error: 3.9493 - root_mean_squared_error: 6.1417 - mean_absolute_percentage_error: 18.4237 - val_loss: 6.0027 - val_mean_absolute_error: 5.7878 - val_root_mean_squared_error: 10.6148 - val_mean_absolute_percentage_error: 32.6227 - lr: 3.1250e-06
# Epoch 73/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0329 - mean_absolute_error: 3.8015 - root_mean_squared_error: 6.0633 - mean_absolute_percentage_error: 18.2303 - val_loss: 5.9800 - val_mean_absolute_error: 5.7618 - val_root_mean_squared_error: 10.6147 - val_mean_absolute_percentage_error: 32.6722 - lr: 3.1250e-06
# Epoch 74/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0718 - mean_absolute_error: 3.8361 - root_mean_squared_error: 5.9765 - mean_absolute_percentage_error: 17.7843 - val_loss: 5.9608 - val_mean_absolute_error: 5.7445 - val_root_mean_squared_error: 10.5910 - val_mean_absolute_percentage_error: 32.7200 - lr: 3.1250e-06
# Epoch 75/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0210 - mean_absolute_error: 3.7895 - root_mean_squared_error: 5.9388 - mean_absolute_percentage_error: 18.1434 - val_loss: 5.9578 - val_mean_absolute_error: 5.7405 - val_root_mean_squared_error: 10.6133 - val_mean_absolute_percentage_error: 32.6434 - lr: 3.1250e-06
# Epoch 76/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.2226 - mean_absolute_error: 3.9925 - root_mean_squared_error: 6.2456 - mean_absolute_percentage_error: 18.9030 - val_loss: 6.0006 - val_mean_absolute_error: 5.7865 - val_root_mean_squared_error: 10.6127 - val_mean_absolute_percentage_error: 32.7199 - lr: 3.1250e-06
# Epoch 77/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0310 - mean_absolute_error: 3.7993 - root_mean_squared_error: 6.0227 - mean_absolute_percentage_error: 17.4521 - val_loss: 6.0055 - val_mean_absolute_error: 5.7913 - val_root_mean_squared_error: 10.6295 - val_mean_absolute_percentage_error: 32.7974 - lr: 1.5625e-06
# Epoch 78/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0028 - mean_absolute_error: 3.7722 - root_mean_squared_error: 5.9574 - mean_absolute_percentage_error: 17.9279 - val_loss: 5.9854 - val_mean_absolute_error: 5.7705 - val_root_mean_squared_error: 10.6192 - val_mean_absolute_percentage_error: 32.6825 - lr: 1.5625e-06
# Epoch 79/100
# 103/103 [==============================] - 16s 151ms/step - loss: 4.1068 - mean_absolute_error: 3.8773 - root_mean_squared_error: 6.1515 - mean_absolute_percentage_error: 18.2028 - val_loss: 5.9549 - val_mean_absolute_error: 5.7385 - val_root_mean_squared_error: 10.6297 - val_mean_absolute_percentage_error: 32.6306 - lr: 1.5625e-06
# Epoch 80/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.2261 - mean_absolute_error: 3.9928 - root_mean_squared_error: 6.4319 - mean_absolute_percentage_error: 17.9940 - val_loss: 5.9813 - val_mean_absolute_error: 5.7658 - val_root_mean_squared_error: 10.6382 - val_mean_absolute_percentage_error: 32.5365 - lr: 1.5625e-06
# Epoch 81/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0419 - mean_absolute_error: 3.8109 - root_mean_squared_error: 5.9063 - mean_absolute_percentage_error: 17.7625 - val_loss: 5.9823 - val_mean_absolute_error: 5.7651 - val_root_mean_squared_error: 10.6524 - val_mean_absolute_percentage_error: 32.7388 - lr: 1.5625e-06
# Epoch 82/100
# 103/103 [==============================] - 16s 153ms/step - loss: 3.9551 - mean_absolute_error: 3.7242 - root_mean_squared_error: 6.0690 - mean_absolute_percentage_error: 17.3846 - val_loss: 5.9866 - val_mean_absolute_error: 5.7706 - val_root_mean_squared_error: 10.6398 - val_mean_absolute_percentage_error: 32.9362 - lr: 7.8125e-07
# Epoch 83/100
# 103/103 [==============================] - 16s 153ms/step - loss: 3.9726 - mean_absolute_error: 3.7399 - root_mean_squared_error: 5.7502 - mean_absolute_percentage_error: 17.7207 - val_loss: 5.9547 - val_mean_absolute_error: 5.7378 - val_root_mean_squared_error: 10.6238 - val_mean_absolute_percentage_error: 32.8184 - lr: 7.8125e-07
# Epoch 84/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.1814 - mean_absolute_error: 3.9484 - root_mean_squared_error: 6.1965 - mean_absolute_percentage_error: 18.0340 - val_loss: 5.9624 - val_mean_absolute_error: 5.7448 - val_root_mean_squared_error: 10.6346 - val_mean_absolute_percentage_error: 32.7642 - lr: 7.8125e-07
# Epoch 85/100
# 103/103 [==============================] - 16s 153ms/step - loss: 3.9452 - mean_absolute_error: 3.7156 - root_mean_squared_error: 5.7376 - mean_absolute_percentage_error: 18.3263 - val_loss: 5.9703 - val_mean_absolute_error: 5.7537 - val_root_mean_squared_error: 10.6306 - val_mean_absolute_percentage_error: 32.8612 - lr: 7.8125e-07
# Epoch 86/100
# 103/103 [==============================] - 16s 153ms/step - loss: 3.9515 - mean_absolute_error: 3.7174 - root_mean_squared_error: 5.7594 - mean_absolute_percentage_error: 17.1970 - val_loss: 5.9393 - val_mean_absolute_error: 5.7223 - val_root_mean_squared_error: 10.6062 - val_mean_absolute_percentage_error: 32.8200 - lr: 7.8125e-07
# Epoch 87/100
# 103/103 [==============================] - 16s 152ms/step - loss: 3.8940 - mean_absolute_error: 3.6609 - root_mean_squared_error: 5.6343 - mean_absolute_percentage_error: 17.5267 - val_loss: 5.9493 - val_mean_absolute_error: 5.7318 - val_root_mean_squared_error: 10.6169 - val_mean_absolute_percentage_error: 32.8304 - lr: 3.9062e-07
# Epoch 88/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0862 - mean_absolute_error: 3.8524 - root_mean_squared_error: 6.1586 - mean_absolute_percentage_error: 17.6321 - val_loss: 5.9503 - val_mean_absolute_error: 5.7328 - val_root_mean_squared_error: 10.6184 - val_mean_absolute_percentage_error: 32.7600 - lr: 3.9062e-07
# Epoch 89/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.2367 - mean_absolute_error: 4.0009 - root_mean_squared_error: 6.5669 - mean_absolute_percentage_error: 18.8471 - val_loss: 5.9525 - val_mean_absolute_error: 5.7352 - val_root_mean_squared_error: 10.6155 - val_mean_absolute_percentage_error: 32.8396 - lr: 3.9062e-07
# Epoch 90/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0669 - mean_absolute_error: 3.8345 - root_mean_squared_error: 6.0129 - mean_absolute_percentage_error: 18.1255 - val_loss: 5.9757 - val_mean_absolute_error: 5.7587 - val_root_mean_squared_error: 10.6331 - val_mean_absolute_percentage_error: 32.8597 - lr: 3.9062e-07
# Epoch 91/100
# 103/103 [==============================] - 16s 153ms/step - loss: 3.9147 - mean_absolute_error: 3.6849 - root_mean_squared_error: 5.6670 - mean_absolute_percentage_error: 17.9457 - val_loss: 5.9562 - val_mean_absolute_error: 5.7393 - val_root_mean_squared_error: 10.6258 - val_mean_absolute_percentage_error: 32.7628 - lr: 3.9062e-07
# Epoch 92/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.0601 - mean_absolute_error: 3.8275 - root_mean_squared_error: 6.1638 - mean_absolute_percentage_error: 17.1160 - val_loss: 5.9531 - val_mean_absolute_error: 5.7357 - val_root_mean_squared_error: 10.6256 - val_mean_absolute_percentage_error: 32.7898 - lr: 1.9531e-07
# Epoch 93/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0959 - mean_absolute_error: 3.8642 - root_mean_squared_error: 6.1725 - mean_absolute_percentage_error: 18.0105 - val_loss: 5.9635 - val_mean_absolute_error: 5.7475 - val_root_mean_squared_error: 10.6238 - val_mean_absolute_percentage_error: 32.8252 - lr: 1.9531e-07
# Epoch 94/100
# 103/103 [==============================] - 16s 152ms/step - loss: 3.9945 - mean_absolute_error: 3.7607 - root_mean_squared_error: 5.9905 - mean_absolute_percentage_error: 17.7564 - val_loss: 5.9902 - val_mean_absolute_error: 5.7746 - val_root_mean_squared_error: 10.6414 - val_mean_absolute_percentage_error: 32.8042 - lr: 1.9531e-07
# Epoch 95/100
# 103/103 [==============================] - 16s 152ms/step - loss: 4.0788 - mean_absolute_error: 3.8438 - root_mean_squared_error: 6.0596 - mean_absolute_percentage_error: 18.6060 - val_loss: 5.9865 - val_mean_absolute_error: 5.7708 - val_root_mean_squared_error: 10.6469 - val_mean_absolute_percentage_error: 32.7150 - lr: 1.9531e-07
# Epoch 96/100
# 103/103 [==============================] - 16s 152ms/step - loss: 3.8991 - mean_absolute_error: 3.6630 - root_mean_squared_error: 5.9893 - mean_absolute_percentage_error: 16.8461 - val_loss: 5.9560 - val_mean_absolute_error: 5.7388 - val_root_mean_squared_error: 10.6401 - val_mean_absolute_percentage_error: 32.6857 - lr: 1.9531e-07
# Epoch 97/100
# 103/103 [==============================] - 16s 152ms/step - loss: 3.9851 - mean_absolute_error: 3.7552 - root_mean_squared_error: 5.8689 - mean_absolute_percentage_error: 18.1707 - val_loss: 5.9817 - val_mean_absolute_error: 5.7657 - val_root_mean_squared_error: 10.6392 - val_mean_absolute_percentage_error: 32.7716 - lr: 9.7656e-08
# Epoch 98/100
# 103/103 [==============================] - 16s 154ms/step - loss: 4.1968 - mean_absolute_error: 3.9649 - root_mean_squared_error: 6.5375 - mean_absolute_percentage_error: 18.1528 - val_loss: 5.9806 - val_mean_absolute_error: 5.7640 - val_root_mean_squared_error: 10.6307 - val_mean_absolute_percentage_error: 32.9564 - lr: 9.7656e-08
# Epoch 99/100
# 103/103 [==============================] - 18s 178ms/step - loss: 3.9611 - mean_absolute_error: 3.7314 - root_mean_squared_error: 5.7597 - mean_absolute_percentage_error: 18.3104 - val_loss: 5.9901 - val_mean_absolute_error: 5.7745 - val_root_mean_squared_error: 10.6445 - val_mean_absolute_percentage_error: 32.7366 - lr: 9.7656e-08
# Epoch 100/100
# 103/103 [==============================] - 19s 182ms/step - loss: 3.9149 - mean_absolute_error: 3.6819 - root_mean_squared_error: 5.7327 - mean_absolute_percentage_error: 16.8928 - val_loss: 5.9463 - val_mean_absolute_error: 5.7299 - val_root_mean_squared_error: 10.6237 - val_mean_absolute_percentage_error: 32.6974 - lr: 9.7656e-08

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 69ms/step - loss: 5.9463 - mean_absolute_error: 5.7299 - root_mean_squared_error: 10.6237 - mean_absolute_percentage_error: 32.6974
# Model Loss: [5.946302890777588, 5.7299017906188965, 10.623674392700195, 32.69741439819336]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 242ms/step
# Predicted Putusan: [8.734955]

# %%
model_scenario_name = "BiLSTM_13_512_Compare"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13_512_Compare\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13_512_Compare\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_13_512_Compare"
max_len = 512

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 512
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [8.734955]
