# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_32888\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['bidirectional[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['bidirectional_1[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['bidirectional_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,892,001
# Trainable params: 4,891,809
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 39s 321ms/step - loss: 33.3063 - mean_absolute_error: 32.9707 - root_mean_squared_error: 45.3566 - mean_absolute_percentage_error: 92.4055 - val_loss: 33.7049 - val_mean_absolute_error: 33.4239 - val_root_mean_squared_error: 46.5259 - val_mean_absolute_percentage_error: 84.2553 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 34s 334ms/step - loss: 27.4835 - mean_absolute_error: 27.2395 - root_mean_squared_error: 38.9013 - mean_absolute_percentage_error: 72.4392 - val_loss: 26.1944 - val_mean_absolute_error: 25.9847 - val_root_mean_squared_error: 37.6357 - val_mean_absolute_percentage_error: 63.5694 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 34s 335ms/step - loss: 18.2852 - mean_absolute_error: 18.0948 - root_mean_squared_error: 27.2450 - mean_absolute_percentage_error: 59.2850 - val_loss: 16.6563 - val_mean_absolute_error: 16.4870 - val_root_mean_squared_error: 24.5639 - val_mean_absolute_percentage_error: 51.9133 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 36s 345ms/step - loss: 11.3688 - mean_absolute_error: 11.2138 - root_mean_squared_error: 17.2600 - mean_absolute_percentage_error: 52.4973 - val_loss: 11.6255 - val_mean_absolute_error: 11.4891 - val_root_mean_squared_error: 17.8948 - val_mean_absolute_percentage_error: 47.8819 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 33s 323ms/step - loss: 9.8335 - mean_absolute_error: 9.7021 - root_mean_squared_error: 15.3535 - mean_absolute_percentage_error: 46.7068 - val_loss: 12.7835 - val_mean_absolute_error: 12.6656 - val_root_mean_squared_error: 20.1379 - val_mean_absolute_percentage_error: 50.5855 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 33s 325ms/step - loss: 8.7905 - mean_absolute_error: 8.6780 - root_mean_squared_error: 14.0747 - mean_absolute_percentage_error: 40.5748 - val_loss: 10.0453 - val_mean_absolute_error: 9.9499 - val_root_mean_squared_error: 15.4693 - val_mean_absolute_percentage_error: 50.7122 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 34s 327ms/step - loss: 8.1068 - mean_absolute_error: 8.0084 - root_mean_squared_error: 13.1196 - mean_absolute_percentage_error: 38.7663 - val_loss: 8.5051 - val_mean_absolute_error: 8.4112 - val_root_mean_squared_error: 14.5261 - val_mean_absolute_percentage_error: 40.7867 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 34s 327ms/step - loss: 7.4941 - mean_absolute_error: 7.4115 - root_mean_squared_error: 11.8593 - mean_absolute_percentage_error: 35.5290 - val_loss: 8.6296 - val_mean_absolute_error: 8.5541 - val_root_mean_squared_error: 14.5255 - val_mean_absolute_percentage_error: 45.0042 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 34s 328ms/step - loss: 7.0007 - mean_absolute_error: 6.9304 - root_mean_squared_error: 11.0332 - mean_absolute_percentage_error: 33.8469 - val_loss: 7.8158 - val_mean_absolute_error: 7.7498 - val_root_mean_squared_error: 13.4398 - val_mean_absolute_percentage_error: 39.2766 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 33s 324ms/step - loss: 6.9519 - mean_absolute_error: 6.8949 - root_mean_squared_error: 11.0376 - mean_absolute_percentage_error: 33.8169 - val_loss: 8.7786 - val_mean_absolute_error: 8.7238 - val_root_mean_squared_error: 14.5577 - val_mean_absolute_percentage_error: 38.8277 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 33s 322ms/step - loss: 6.5387 - mean_absolute_error: 6.4907 - root_mean_squared_error: 10.4440 - mean_absolute_percentage_error: 30.6178 - val_loss: 7.5705 - val_mean_absolute_error: 7.5343 - val_root_mean_squared_error: 12.3777 - val_mean_absolute_percentage_error: 40.9313 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 33s 319ms/step - loss: 6.4936 - mean_absolute_error: 6.4574 - root_mean_squared_error: 10.2261 - mean_absolute_percentage_error: 30.8247 - val_loss: 7.4157 - val_mean_absolute_error: 7.3918 - val_root_mean_squared_error: 12.3200 - val_mean_absolute_percentage_error: 39.7664 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 33s 322ms/step - loss: 6.4854 - mean_absolute_error: 6.4607 - root_mean_squared_error: 10.0720 - mean_absolute_percentage_error: 32.1296 - val_loss: 6.9962 - val_mean_absolute_error: 6.9662 - val_root_mean_squared_error: 11.7540 - val_mean_absolute_percentage_error: 38.2210 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 34s 326ms/step - loss: 6.3487 - mean_absolute_error: 6.3319 - root_mean_squared_error: 9.9511 - mean_absolute_percentage_error: 30.3951 - val_loss: 7.5304 - val_mean_absolute_error: 7.5234 - val_root_mean_squared_error: 12.3033 - val_mean_absolute_percentage_error: 40.8979 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 33s 320ms/step - loss: 6.5082 - mean_absolute_error: 6.4982 - root_mean_squared_error: 10.1288 - mean_absolute_percentage_error: 30.4619 - val_loss: 6.7753 - val_mean_absolute_error: 6.7638 - val_root_mean_squared_error: 11.9199 - val_mean_absolute_percentage_error: 35.2397 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 33s 321ms/step - loss: 5.8956 - mean_absolute_error: 5.8910 - root_mean_squared_error: 9.1575 - mean_absolute_percentage_error: 27.6301 - val_loss: 7.2569 - val_mean_absolute_error: 7.2570 - val_root_mean_squared_error: 11.8965 - val_mean_absolute_percentage_error: 37.6422 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 33s 322ms/step - loss: 5.9008 - mean_absolute_error: 5.8990 - root_mean_squared_error: 9.3173 - mean_absolute_percentage_error: 26.0956 - val_loss: 7.4921 - val_mean_absolute_error: 7.4978 - val_root_mean_squared_error: 12.0772 - val_mean_absolute_percentage_error: 37.6031 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 33s 321ms/step - loss: 5.8257 - mean_absolute_error: 5.8352 - root_mean_squared_error: 9.0369 - mean_absolute_percentage_error: 27.4789 - val_loss: 7.7995 - val_mean_absolute_error: 7.8170 - val_root_mean_squared_error: 12.8675 - val_mean_absolute_percentage_error: 41.1630 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 33s 324ms/step - loss: 5.6235 - mean_absolute_error: 5.6371 - root_mean_squared_error: 8.8342 - mean_absolute_percentage_error: 25.7484 - val_loss: 7.1414 - val_mean_absolute_error: 7.1642 - val_root_mean_squared_error: 11.9574 - val_mean_absolute_percentage_error: 36.6292 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 33s 321ms/step - loss: 5.7557 - mean_absolute_error: 5.7774 - root_mean_squared_error: 9.0520 - mean_absolute_percentage_error: 25.1915 - val_loss: 6.5839 - val_mean_absolute_error: 6.6050 - val_root_mean_squared_error: 11.4981 - val_mean_absolute_percentage_error: 35.4904 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 33s 324ms/step - loss: 5.5201 - mean_absolute_error: 5.5433 - root_mean_squared_error: 8.7023 - mean_absolute_percentage_error: 24.9866 - val_loss: 8.1879 - val_mean_absolute_error: 8.2215 - val_root_mean_squared_error: 12.6969 - val_mean_absolute_percentage_error: 40.2606 - lr: 1.0000e-04
# Epoch 22/100
# 103/103 [==============================] - 33s 320ms/step - loss: 5.6809 - mean_absolute_error: 5.7098 - root_mean_squared_error: 8.9224 - mean_absolute_percentage_error: 25.8498 - val_loss: 6.8288 - val_mean_absolute_error: 6.8666 - val_root_mean_squared_error: 11.7430 - val_mean_absolute_percentage_error: 35.7404 - lr: 1.0000e-04
# Epoch 23/100
# 103/103 [==============================] - 32s 313ms/step - loss: 5.0575 - mean_absolute_error: 5.0913 - root_mean_squared_error: 8.0234 - mean_absolute_percentage_error: 22.6942 - val_loss: 6.3283 - val_mean_absolute_error: 6.3645 - val_root_mean_squared_error: 11.1968 - val_mean_absolute_percentage_error: 35.2593 - lr: 1.0000e-04
# Epoch 24/100
# 103/103 [==============================] - 32s 313ms/step - loss: 5.3886 - mean_absolute_error: 5.4270 - root_mean_squared_error: 8.6677 - mean_absolute_percentage_error: 23.2899 - val_loss: 7.4218 - val_mean_absolute_error: 7.4699 - val_root_mean_squared_error: 12.0656 - val_mean_absolute_percentage_error: 38.9169 - lr: 1.0000e-04
# Epoch 25/100
# 103/103 [==============================] - 33s 318ms/step - loss: 5.3463 - mean_absolute_error: 5.3920 - root_mean_squared_error: 8.2251 - mean_absolute_percentage_error: 24.3870 - val_loss: 7.1053 - val_mean_absolute_error: 7.1496 - val_root_mean_squared_error: 12.1569 - val_mean_absolute_percentage_error: 33.7148 - lr: 1.0000e-04
# Epoch 26/100
# 103/103 [==============================] - 32s 315ms/step - loss: 5.5795 - mean_absolute_error: 5.6261 - root_mean_squared_error: 8.8769 - mean_absolute_percentage_error: 23.4816 - val_loss: 6.4560 - val_mean_absolute_error: 6.5155 - val_root_mean_squared_error: 11.1636 - val_mean_absolute_percentage_error: 35.8250 - lr: 1.0000e-04
# Epoch 27/100
# 103/103 [==============================] - 32s 313ms/step - loss: 4.9395 - mean_absolute_error: 4.9892 - root_mean_squared_error: 7.7853 - mean_absolute_percentage_error: 22.0352 - val_loss: 6.2510 - val_mean_absolute_error: 6.3041 - val_root_mean_squared_error: 11.0451 - val_mean_absolute_percentage_error: 34.1052 - lr: 1.0000e-04
# Epoch 28/100
# 103/103 [==============================] - 32s 311ms/step - loss: 4.9151 - mean_absolute_error: 4.9696 - root_mean_squared_error: 7.9823 - mean_absolute_percentage_error: 21.4715 - val_loss: 6.4993 - val_mean_absolute_error: 6.5651 - val_root_mean_squared_error: 11.3706 - val_mean_absolute_percentage_error: 34.2913 - lr: 1.0000e-04
# Epoch 29/100
# 103/103 [==============================] - 32s 311ms/step - loss: 4.8483 - mean_absolute_error: 4.9052 - root_mean_squared_error: 7.7716 - mean_absolute_percentage_error: 21.0106 - val_loss: 6.0429 - val_mean_absolute_error: 6.0958 - val_root_mean_squared_error: 10.9966 - val_mean_absolute_percentage_error: 33.0909 - lr: 1.0000e-04
# Epoch 30/100
# 103/103 [==============================] - 32s 311ms/step - loss: 4.8765 - mean_absolute_error: 4.9387 - root_mean_squared_error: 7.6683 - mean_absolute_percentage_error: 21.6134 - val_loss: 6.3960 - val_mean_absolute_error: 6.4634 - val_root_mean_squared_error: 11.2642 - val_mean_absolute_percentage_error: 33.0486 - lr: 1.0000e-04
# Epoch 31/100
# 103/103 [==============================] - 32s 313ms/step - loss: 4.9394 - mean_absolute_error: 5.0055 - root_mean_squared_error: 7.9677 - mean_absolute_percentage_error: 20.7975 - val_loss: 6.0109 - val_mean_absolute_error: 6.0676 - val_root_mean_squared_error: 10.9534 - val_mean_absolute_percentage_error: 33.2645 - lr: 1.0000e-04
# Epoch 32/100
# 103/103 [==============================] - 33s 319ms/step - loss: 4.5712 - mean_absolute_error: 4.6391 - root_mean_squared_error: 7.0363 - mean_absolute_percentage_error: 19.9116 - val_loss: 6.0985 - val_mean_absolute_error: 6.1705 - val_root_mean_squared_error: 10.8686 - val_mean_absolute_percentage_error: 33.9093 - lr: 1.0000e-04
# Epoch 33/100
# 103/103 [==============================] - 32s 310ms/step - loss: 5.0363 - mean_absolute_error: 5.1101 - root_mean_squared_error: 8.0016 - mean_absolute_percentage_error: 21.4546 - val_loss: 6.5606 - val_mean_absolute_error: 6.6419 - val_root_mean_squared_error: 11.0740 - val_mean_absolute_percentage_error: 36.6865 - lr: 1.0000e-04
# Epoch 34/100
# 103/103 [==============================] - 33s 321ms/step - loss: 4.5761 - mean_absolute_error: 4.6495 - root_mean_squared_error: 7.2342 - mean_absolute_percentage_error: 19.8016 - val_loss: 6.2316 - val_mean_absolute_error: 6.3094 - val_root_mean_squared_error: 10.8692 - val_mean_absolute_percentage_error: 34.0782 - lr: 1.0000e-04
# Epoch 35/100
# 103/103 [==============================] - 32s 313ms/step - loss: 4.8762 - mean_absolute_error: 4.9534 - root_mean_squared_error: 7.7431 - mean_absolute_percentage_error: 20.6848 - val_loss: 6.2153 - val_mean_absolute_error: 6.2931 - val_root_mean_squared_error: 11.0641 - val_mean_absolute_percentage_error: 33.9237 - lr: 1.0000e-04
# Epoch 36/100
# 103/103 [==============================] - 32s 307ms/step - loss: 4.5706 - mean_absolute_error: 4.6523 - root_mean_squared_error: 7.2205 - mean_absolute_percentage_error: 20.0426 - val_loss: 6.0759 - val_mean_absolute_error: 6.1542 - val_root_mean_squared_error: 10.8078 - val_mean_absolute_percentage_error: 34.3544 - lr: 1.0000e-04
# Epoch 37/100
# 103/103 [==============================] - 32s 308ms/step - loss: 4.3545 - mean_absolute_error: 4.4326 - root_mean_squared_error: 6.9671 - mean_absolute_percentage_error: 19.0521 - val_loss: 5.9105 - val_mean_absolute_error: 5.9903 - val_root_mean_squared_error: 10.6414 - val_mean_absolute_percentage_error: 32.7336 - lr: 5.0000e-05
# Epoch 38/100
# 103/103 [==============================] - 32s 310ms/step - loss: 4.5616 - mean_absolute_error: 4.6464 - root_mean_squared_error: 7.3184 - mean_absolute_percentage_error: 20.0734 - val_loss: 6.1656 - val_mean_absolute_error: 6.2457 - val_root_mean_squared_error: 11.0132 - val_mean_absolute_percentage_error: 32.7900 - lr: 5.0000e-05
# Epoch 39/100
# 103/103 [==============================] - 32s 307ms/step - loss: 4.3150 - mean_absolute_error: 4.3976 - root_mean_squared_error: 6.8910 - mean_absolute_percentage_error: 18.8499 - val_loss: 5.6506 - val_mean_absolute_error: 5.7235 - val_root_mean_squared_error: 10.5442 - val_mean_absolute_percentage_error: 32.1142 - lr: 5.0000e-05
# Epoch 40/100
# 103/103 [==============================] - 32s 308ms/step - loss: 4.3196 - mean_absolute_error: 4.4017 - root_mean_squared_error: 6.9156 - mean_absolute_percentage_error: 18.6225 - val_loss: 5.9755 - val_mean_absolute_error: 6.0664 - val_root_mean_squared_error: 10.6245 - val_mean_absolute_percentage_error: 32.9267 - lr: 5.0000e-05
# Epoch 41/100
# 103/103 [==============================] - 32s 308ms/step - loss: 4.4265 - mean_absolute_error: 4.5130 - root_mean_squared_error: 6.9300 - mean_absolute_percentage_error: 18.8997 - val_loss: 5.7765 - val_mean_absolute_error: 5.8694 - val_root_mean_squared_error: 10.4866 - val_mean_absolute_percentage_error: 32.9854 - lr: 5.0000e-05
# Epoch 42/100
# 103/103 [==============================] - 32s 312ms/step - loss: 4.2408 - mean_absolute_error: 4.3257 - root_mean_squared_error: 6.7648 - mean_absolute_percentage_error: 18.6436 - val_loss: 5.6911 - val_mean_absolute_error: 5.7712 - val_root_mean_squared_error: 10.6074 - val_mean_absolute_percentage_error: 32.4696 - lr: 5.0000e-05
# Epoch 43/100
# 103/103 [==============================] - 32s 311ms/step - loss: 4.5048 - mean_absolute_error: 4.5935 - root_mean_squared_error: 7.3193 - mean_absolute_percentage_error: 18.6398 - val_loss: 5.6118 - val_mean_absolute_error: 5.6912 - val_root_mean_squared_error: 10.5522 - val_mean_absolute_percentage_error: 32.5169 - lr: 5.0000e-05
# Epoch 44/100
# 103/103 [==============================] - 32s 309ms/step - loss: 4.2631 - mean_absolute_error: 4.3517 - root_mean_squared_error: 6.8874 - mean_absolute_percentage_error: 18.0263 - val_loss: 5.6162 - val_mean_absolute_error: 5.7013 - val_root_mean_squared_error: 10.5705 - val_mean_absolute_percentage_error: 32.1848 - lr: 5.0000e-05
# Epoch 45/100
# 103/103 [==============================] - 32s 309ms/step - loss: 4.0464 - mean_absolute_error: 4.1360 - root_mean_squared_error: 6.2984 - mean_absolute_percentage_error: 17.4676 - val_loss: 6.0391 - val_mean_absolute_error: 6.1412 - val_root_mean_squared_error: 10.7256 - val_mean_absolute_percentage_error: 34.2381 - lr: 5.0000e-05
# Epoch 46/100
# 103/103 [==============================] - 32s 309ms/step - loss: 4.1098 - mean_absolute_error: 4.2025 - root_mean_squared_error: 6.5380 - mean_absolute_percentage_error: 17.7259 - val_loss: 5.7378 - val_mean_absolute_error: 5.8310 - val_root_mean_squared_error: 10.6426 - val_mean_absolute_percentage_error: 33.9342 - lr: 5.0000e-05
# Epoch 47/100
# 103/103 [==============================] - 32s 308ms/step - loss: 4.1828 - mean_absolute_error: 4.2729 - root_mean_squared_error: 6.6600 - mean_absolute_percentage_error: 18.2306 - val_loss: 5.8220 - val_mean_absolute_error: 5.9152 - val_root_mean_squared_error: 10.7796 - val_mean_absolute_percentage_error: 31.2039 - lr: 5.0000e-05
# Epoch 48/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.3132 - mean_absolute_error: 4.4045 - root_mean_squared_error: 6.9915 - mean_absolute_percentage_error: 17.9688 - val_loss: 5.5737 - val_mean_absolute_error: 5.6602 - val_root_mean_squared_error: 10.5832 - val_mean_absolute_percentage_error: 31.2571 - lr: 5.0000e-05
# Epoch 49/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.2379 - mean_absolute_error: 4.3328 - root_mean_squared_error: 6.7168 - mean_absolute_percentage_error: 18.1921 - val_loss: 5.9780 - val_mean_absolute_error: 6.0830 - val_root_mean_squared_error: 10.7124 - val_mean_absolute_percentage_error: 33.9030 - lr: 5.0000e-05
# Epoch 50/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.0871 - mean_absolute_error: 4.1815 - root_mean_squared_error: 6.5920 - mean_absolute_percentage_error: 17.3554 - val_loss: 5.6925 - val_mean_absolute_error: 5.7842 - val_root_mean_squared_error: 10.6401 - val_mean_absolute_percentage_error: 32.2359 - lr: 5.0000e-05
# Epoch 51/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.5480 - mean_absolute_error: 4.6455 - root_mean_squared_error: 7.2381 - mean_absolute_percentage_error: 18.8662 - val_loss: 5.6282 - val_mean_absolute_error: 5.7184 - val_root_mean_squared_error: 10.5806 - val_mean_absolute_percentage_error: 32.3361 - lr: 5.0000e-05
# Epoch 52/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.9882 - mean_absolute_error: 4.0830 - root_mean_squared_error: 6.4454 - mean_absolute_percentage_error: 17.0487 - val_loss: 5.6521 - val_mean_absolute_error: 5.7528 - val_root_mean_squared_error: 10.5965 - val_mean_absolute_percentage_error: 32.2021 - lr: 5.0000e-05
# Epoch 53/100
# 103/103 [==============================] - 29s 284ms/step - loss: 4.2147 - mean_absolute_error: 4.3155 - root_mean_squared_error: 6.8280 - mean_absolute_percentage_error: 17.8571 - val_loss: 5.5007 - val_mean_absolute_error: 5.5909 - val_root_mean_squared_error: 10.5113 - val_mean_absolute_percentage_error: 31.5678 - lr: 5.0000e-05
# Epoch 54/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.0030 - mean_absolute_error: 4.1020 - root_mean_squared_error: 6.4737 - mean_absolute_percentage_error: 16.8742 - val_loss: 5.4911 - val_mean_absolute_error: 5.5795 - val_root_mean_squared_error: 10.5131 - val_mean_absolute_percentage_error: 31.5574 - lr: 5.0000e-05
# Epoch 55/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.9807 - mean_absolute_error: 4.0826 - root_mean_squared_error: 6.4270 - mean_absolute_percentage_error: 17.1891 - val_loss: 5.5865 - val_mean_absolute_error: 5.6790 - val_root_mean_squared_error: 10.4929 - val_mean_absolute_percentage_error: 32.0682 - lr: 5.0000e-05
# Epoch 56/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.2764 - mean_absolute_error: 4.3790 - root_mean_squared_error: 6.8025 - mean_absolute_percentage_error: 17.8566 - val_loss: 5.5248 - val_mean_absolute_error: 5.6232 - val_root_mean_squared_error: 10.5139 - val_mean_absolute_percentage_error: 31.4138 - lr: 5.0000e-05
# Epoch 57/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.9753 - mean_absolute_error: 4.0771 - root_mean_squared_error: 6.4231 - mean_absolute_percentage_error: 16.9502 - val_loss: 5.4519 - val_mean_absolute_error: 5.5489 - val_root_mean_squared_error: 10.4121 - val_mean_absolute_percentage_error: 31.7606 - lr: 5.0000e-05
# Epoch 58/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.1675 - mean_absolute_error: 4.2733 - root_mean_squared_error: 6.6989 - mean_absolute_percentage_error: 18.0747 - val_loss: 5.6861 - val_mean_absolute_error: 5.7880 - val_root_mean_squared_error: 10.5451 - val_mean_absolute_percentage_error: 32.8485 - lr: 5.0000e-05
# Epoch 59/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.0906 - mean_absolute_error: 4.1963 - root_mean_squared_error: 6.5445 - mean_absolute_percentage_error: 17.7200 - val_loss: 5.7334 - val_mean_absolute_error: 5.8332 - val_root_mean_squared_error: 10.6716 - val_mean_absolute_percentage_error: 32.3341 - lr: 5.0000e-05
# Epoch 60/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.1571 - mean_absolute_error: 4.2615 - root_mean_squared_error: 6.7120 - mean_absolute_percentage_error: 17.1335 - val_loss: 5.9644 - val_mean_absolute_error: 6.0882 - val_root_mean_squared_error: 10.6836 - val_mean_absolute_percentage_error: 33.5246 - lr: 5.0000e-05
# Epoch 61/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.9867 - mean_absolute_error: 4.0960 - root_mean_squared_error: 6.5409 - mean_absolute_percentage_error: 17.2475 - val_loss: 5.4529 - val_mean_absolute_error: 5.5498 - val_root_mean_squared_error: 10.4951 - val_mean_absolute_percentage_error: 32.3423 - lr: 5.0000e-05
# Epoch 62/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.0042 - mean_absolute_error: 4.1156 - root_mean_squared_error: 6.3897 - mean_absolute_percentage_error: 17.3786 - val_loss: 5.6387 - val_mean_absolute_error: 5.7556 - val_root_mean_squared_error: 10.4515 - val_mean_absolute_percentage_error: 33.0190 - lr: 5.0000e-05
# Epoch 63/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.9979 - mean_absolute_error: 4.1041 - root_mean_squared_error: 6.4686 - mean_absolute_percentage_error: 17.1440 - val_loss: 5.3621 - val_mean_absolute_error: 5.4634 - val_root_mean_squared_error: 10.3688 - val_mean_absolute_percentage_error: 31.4647 - lr: 2.5000e-05
# Epoch 64/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.9972 - mean_absolute_error: 4.1106 - root_mean_squared_error: 6.2761 - mean_absolute_percentage_error: 17.4919 - val_loss: 5.6984 - val_mean_absolute_error: 5.8178 - val_root_mean_squared_error: 10.5477 - val_mean_absolute_percentage_error: 32.8270 - lr: 2.5000e-05
# Epoch 65/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.1312 - mean_absolute_error: 4.2445 - root_mean_squared_error: 6.7719 - mean_absolute_percentage_error: 17.1736 - val_loss: 5.4929 - val_mean_absolute_error: 5.6036 - val_root_mean_squared_error: 10.4649 - val_mean_absolute_percentage_error: 32.0606 - lr: 2.5000e-05
# Epoch 66/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.9256 - mean_absolute_error: 4.0348 - root_mean_squared_error: 6.5084 - mean_absolute_percentage_error: 16.7319 - val_loss: 5.3617 - val_mean_absolute_error: 5.4636 - val_root_mean_squared_error: 10.4131 - val_mean_absolute_percentage_error: 31.4097 - lr: 2.5000e-05
# Epoch 67/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.9713 - mean_absolute_error: 4.0845 - root_mean_squared_error: 6.3735 - mean_absolute_percentage_error: 17.0376 - val_loss: 5.4027 - val_mean_absolute_error: 5.5096 - val_root_mean_squared_error: 10.3882 - val_mean_absolute_percentage_error: 31.8005 - lr: 2.5000e-05
# Epoch 68/100
# 103/103 [==============================] - 30s 288ms/step - loss: 3.6327 - mean_absolute_error: 3.7405 - root_mean_squared_error: 5.8402 - mean_absolute_percentage_error: 15.7931 - val_loss: 5.4170 - val_mean_absolute_error: 5.5223 - val_root_mean_squared_error: 10.4242 - val_mean_absolute_percentage_error: 31.7848 - lr: 2.5000e-05
# Epoch 69/100
# 103/103 [==============================] - 29s 285ms/step - loss: 3.7295 - mean_absolute_error: 3.8389 - root_mean_squared_error: 6.1445 - mean_absolute_percentage_error: 15.9202 - val_loss: 5.3223 - val_mean_absolute_error: 5.4168 - val_root_mean_squared_error: 10.4059 - val_mean_absolute_percentage_error: 31.1331 - lr: 2.5000e-05
# Epoch 70/100
# 103/103 [==============================] - 29s 286ms/step - loss: 3.8078 - mean_absolute_error: 3.9211 - root_mean_squared_error: 6.0563 - mean_absolute_percentage_error: 16.0664 - val_loss: 5.7436 - val_mean_absolute_error: 5.8690 - val_root_mean_squared_error: 10.5512 - val_mean_absolute_percentage_error: 32.9761 - lr: 2.5000e-05
# Epoch 71/100
# 103/103 [==============================] - 30s 289ms/step - loss: 3.6518 - mean_absolute_error: 3.7645 - root_mean_squared_error: 5.8651 - mean_absolute_percentage_error: 15.8643 - val_loss: 5.3379 - val_mean_absolute_error: 5.4405 - val_root_mean_squared_error: 10.4414 - val_mean_absolute_percentage_error: 31.7041 - lr: 2.5000e-05
# Epoch 72/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.9474 - mean_absolute_error: 4.0599 - root_mean_squared_error: 6.4516 - mean_absolute_percentage_error: 16.7064 - val_loss: 5.2694 - val_mean_absolute_error: 5.3619 - val_root_mean_squared_error: 10.4180 - val_mean_absolute_percentage_error: 31.5863 - lr: 2.5000e-05
# Epoch 73/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.7748 - mean_absolute_error: 3.8880 - root_mean_squared_error: 6.0465 - mean_absolute_percentage_error: 16.3623 - val_loss: 5.3583 - val_mean_absolute_error: 5.4688 - val_root_mean_squared_error: 10.4368 - val_mean_absolute_percentage_error: 31.6175 - lr: 2.5000e-05
# Epoch 74/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.7507 - mean_absolute_error: 3.8659 - root_mean_squared_error: 5.9774 - mean_absolute_percentage_error: 16.1149 - val_loss: 5.2922 - val_mean_absolute_error: 5.3946 - val_root_mean_squared_error: 10.4020 - val_mean_absolute_percentage_error: 31.9070 - lr: 2.5000e-05
# Epoch 75/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.8751 - mean_absolute_error: 3.9889 - root_mean_squared_error: 6.3353 - mean_absolute_percentage_error: 15.7284 - val_loss: 5.5693 - val_mean_absolute_error: 5.6973 - val_root_mean_squared_error: 10.4967 - val_mean_absolute_percentage_error: 32.2968 - lr: 2.5000e-05
# Epoch 76/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.8268 - mean_absolute_error: 3.9444 - root_mean_squared_error: 6.1466 - mean_absolute_percentage_error: 16.3899 - val_loss: 5.3610 - val_mean_absolute_error: 5.4774 - val_root_mean_squared_error: 10.4011 - val_mean_absolute_percentage_error: 31.5737 - lr: 2.5000e-05
# Epoch 77/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.5140 - mean_absolute_error: 3.6280 - root_mean_squared_error: 5.6252 - mean_absolute_percentage_error: 15.0271 - val_loss: 5.5700 - val_mean_absolute_error: 5.6848 - val_root_mean_squared_error: 10.5164 - val_mean_absolute_percentage_error: 32.4652 - lr: 2.5000e-05
# Epoch 78/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.6877 - mean_absolute_error: 3.7987 - root_mean_squared_error: 6.0016 - mean_absolute_percentage_error: 15.3535 - val_loss: 5.2770 - val_mean_absolute_error: 5.3866 - val_root_mean_squared_error: 10.3885 - val_mean_absolute_percentage_error: 31.1332 - lr: 1.2500e-05
# Epoch 79/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.6599 - mean_absolute_error: 3.7702 - root_mean_squared_error: 5.9749 - mean_absolute_percentage_error: 14.9809 - val_loss: 5.2179 - val_mean_absolute_error: 5.3141 - val_root_mean_squared_error: 10.3977 - val_mean_absolute_percentage_error: 30.7648 - lr: 1.2500e-05
# Epoch 80/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.0709 - mean_absolute_error: 4.1860 - root_mean_squared_error: 6.9090 - mean_absolute_percentage_error: 16.1663 - val_loss: 5.2903 - val_mean_absolute_error: 5.4003 - val_root_mean_squared_error: 10.3985 - val_mean_absolute_percentage_error: 30.9363 - lr: 1.2500e-05
# Epoch 81/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.8203 - mean_absolute_error: 3.9364 - root_mean_squared_error: 6.1247 - mean_absolute_percentage_error: 15.8475 - val_loss: 5.3955 - val_mean_absolute_error: 5.5145 - val_root_mean_squared_error: 10.4182 - val_mean_absolute_percentage_error: 31.4870 - lr: 1.2500e-05
# Epoch 82/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.7295 - mean_absolute_error: 3.8408 - root_mean_squared_error: 6.0156 - mean_absolute_percentage_error: 15.2376 - val_loss: 5.1890 - val_mean_absolute_error: 5.2865 - val_root_mean_squared_error: 10.3928 - val_mean_absolute_percentage_error: 30.7340 - lr: 1.2500e-05
# Epoch 83/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.3327 - mean_absolute_error: 4.4512 - root_mean_squared_error: 6.9959 - mean_absolute_percentage_error: 17.3126 - val_loss: 5.3178 - val_mean_absolute_error: 5.4236 - val_root_mean_squared_error: 10.4388 - val_mean_absolute_percentage_error: 31.4473 - lr: 1.2500e-05
# Epoch 84/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.8362 - mean_absolute_error: 3.9481 - root_mean_squared_error: 6.4754 - mean_absolute_percentage_error: 15.8543 - val_loss: 5.2280 - val_mean_absolute_error: 5.3293 - val_root_mean_squared_error: 10.3959 - val_mean_absolute_percentage_error: 31.0758 - lr: 1.2500e-05
# Epoch 85/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.5970 - mean_absolute_error: 3.7093 - root_mean_squared_error: 5.7428 - mean_absolute_percentage_error: 15.1126 - val_loss: 5.3269 - val_mean_absolute_error: 5.4416 - val_root_mean_squared_error: 10.3763 - val_mean_absolute_percentage_error: 31.5690 - lr: 1.2500e-05
# Epoch 86/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.6260 - mean_absolute_error: 3.7388 - root_mean_squared_error: 5.9355 - mean_absolute_percentage_error: 15.6804 - val_loss: 5.1869 - val_mean_absolute_error: 5.2861 - val_root_mean_squared_error: 10.3516 - val_mean_absolute_percentage_error: 31.2270 - lr: 1.2500e-05
# Epoch 87/100
# 103/103 [==============================] - 30s 295ms/step - loss: 3.5334 - mean_absolute_error: 3.6487 - root_mean_squared_error: 5.8711 - mean_absolute_percentage_error: 14.7534 - val_loss: 5.2782 - val_mean_absolute_error: 5.3893 - val_root_mean_squared_error: 10.3934 - val_mean_absolute_percentage_error: 31.1630 - lr: 1.2500e-05
# Epoch 88/100
# 103/103 [==============================] - 30s 294ms/step - loss: 3.4971 - mean_absolute_error: 3.6120 - root_mean_squared_error: 5.7228 - mean_absolute_percentage_error: 14.7904 - val_loss: 5.2580 - val_mean_absolute_error: 5.3694 - val_root_mean_squared_error: 10.3789 - val_mean_absolute_percentage_error: 31.3046 - lr: 1.2500e-05
# Epoch 89/100
# 103/103 [==============================] - 30s 295ms/step - loss: 3.6939 - mean_absolute_error: 3.8121 - root_mean_squared_error: 5.9408 - mean_absolute_percentage_error: 15.2502 - val_loss: 5.3047 - val_mean_absolute_error: 5.4035 - val_root_mean_squared_error: 10.4531 - val_mean_absolute_percentage_error: 30.9568 - lr: 1.2500e-05
# Epoch 90/100
# 103/103 [==============================] - 30s 293ms/step - loss: 3.6097 - mean_absolute_error: 3.7234 - root_mean_squared_error: 5.9030 - mean_absolute_percentage_error: 15.3978 - val_loss: 5.3294 - val_mean_absolute_error: 5.4485 - val_root_mean_squared_error: 10.4219 - val_mean_absolute_percentage_error: 31.7879 - lr: 1.2500e-05
# Epoch 91/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.6232 - mean_absolute_error: 3.7409 - root_mean_squared_error: 5.8015 - mean_absolute_percentage_error: 15.5339 - val_loss: 5.3099 - val_mean_absolute_error: 5.4262 - val_root_mean_squared_error: 10.4244 - val_mean_absolute_percentage_error: 31.6380 - lr: 1.2500e-05
# Epoch 92/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.6643 - mean_absolute_error: 3.7822 - root_mean_squared_error: 5.9323 - mean_absolute_percentage_error: 16.4614 - val_loss: 5.2818 - val_mean_absolute_error: 5.3960 - val_root_mean_squared_error: 10.3841 - val_mean_absolute_percentage_error: 31.4171 - lr: 6.2500e-06
# Epoch 93/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.6657 - mean_absolute_error: 3.7830 - root_mean_squared_error: 5.9342 - mean_absolute_percentage_error: 15.9744 - val_loss: 5.2147 - val_mean_absolute_error: 5.3200 - val_root_mean_squared_error: 10.3761 - val_mean_absolute_percentage_error: 31.1706 - lr: 6.2500e-06
# Epoch 94/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.5071 - mean_absolute_error: 3.6195 - root_mean_squared_error: 5.7732 - mean_absolute_percentage_error: 15.0471 - val_loss: 5.2477 - val_mean_absolute_error: 5.3579 - val_root_mean_squared_error: 10.3939 - val_mean_absolute_percentage_error: 31.3514 - lr: 6.2500e-06
# Epoch 95/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.6290 - mean_absolute_error: 3.7456 - root_mean_squared_error: 6.0598 - mean_absolute_percentage_error: 15.1367 - val_loss: 5.1901 - val_mean_absolute_error: 5.2949 - val_root_mean_squared_error: 10.3664 - val_mean_absolute_percentage_error: 30.9314 - lr: 6.2500e-06
# Epoch 96/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.6385 - mean_absolute_error: 3.7533 - root_mean_squared_error: 5.9987 - mean_absolute_percentage_error: 14.9140 - val_loss: 5.2150 - val_mean_absolute_error: 5.3219 - val_root_mean_squared_error: 10.3487 - val_mean_absolute_percentage_error: 31.3276 - lr: 6.2500e-06
# Epoch 97/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.6323 - mean_absolute_error: 3.7482 - root_mean_squared_error: 5.9004 - mean_absolute_percentage_error: 15.3022 - val_loss: 5.2176 - val_mean_absolute_error: 5.3257 - val_root_mean_squared_error: 10.3427 - val_mean_absolute_percentage_error: 31.3053 - lr: 3.1250e-06
# Epoch 98/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.4520 - mean_absolute_error: 3.5677 - root_mean_squared_error: 5.5478 - mean_absolute_percentage_error: 15.0915 - val_loss: 5.1972 - val_mean_absolute_error: 5.3035 - val_root_mean_squared_error: 10.3453 - val_mean_absolute_percentage_error: 31.2791 - lr: 3.1250e-06
# Epoch 99/100
# 103/103 [==============================] - 30s 291ms/step - loss: 3.7076 - mean_absolute_error: 3.8274 - root_mean_squared_error: 5.9874 - mean_absolute_percentage_error: 15.2976 - val_loss: 5.2050 - val_mean_absolute_error: 5.3120 - val_root_mean_squared_error: 10.3529 - val_mean_absolute_percentage_error: 31.2763 - lr: 3.1250e-06
# Epoch 100/100
# 103/103 [==============================] - 30s 289ms/step - loss: 3.8974 - mean_absolute_error: 4.0161 - root_mean_squared_error: 6.4322 - mean_absolute_percentage_error: 16.6174 - val_loss: 5.2176 - val_mean_absolute_error: 5.3267 - val_root_mean_squared_error: 10.3598 - val_mean_absolute_percentage_error: 31.3073 - lr: 3.1250e-06

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 5s 138ms/step - loss: 5.2176 - mean_absolute_error: 5.3267 - root_mean_squared_error: 10.3598 - mean_absolute_percentage_error: 31.3073
# Model Loss: [5.217636585235596, 5.326746463775635, 10.359848022460938, 31.307262420654297]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 290ms/step
# Predicted Putusan: [11.355816]

# %%
model_scenario_name = "BiLSTM_12"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_12\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_12\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_12"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [11.355816]
