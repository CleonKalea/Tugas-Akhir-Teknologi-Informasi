# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_15144\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=256 
)(text_input)

# Bi-LSTM Layer 
lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output = tf.keras.layers.BatchNormalization()(lstm_output)

lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_2 = tf.keras.layers.BatchNormalization()(lstm_output_2)

lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
lstm_output_3 = tf.keras.layers.BatchNormalization()(lstm_output_3)

# Pooling Layer 
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
# Dropout 
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

# Numerical Dense 
numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical = tf.keras.layers.BatchNormalization()(numerical_input)
numerical_dense = tf.keras.layers.Dense(32, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)
# Concated Dense 
concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
# Dropout 
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)
# Output
output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding_1 (Embedding)        (None, 1024, 256)    4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 1024, 64)    256         ['bidirectional[0][0]']
#  rmalization)
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['batch_normalization_1[0][0]']
#  )
#
#  batch_normalization_2 (BatchNo  (None, 1024, 128)   512         ['bidirectional_1[0][0]']
#  rmalization)
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['batch_normalization_2[0][0]']
#  )
#
#  batch_normalization_4 (BatchNo  (None, 5)           20          ['numerical_input[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 1024, 64)    256         ['bidirectional_2[0][0]']
#  rmalization)
#
#  dense_6 (Dense)                (None, 32)           192         ['batch_normalization_4[0][0]']
#
#  global_max_pooling1d_1 (Global  (None, 64)          0           ['batch_normalization_3[0][0]']
#  MaxPooling1D)
#
#  dense_7 (Dense)                (None, 64)           2112        ['dense_6[0][0]']
#
#  dropout_2 (Dropout)            (None, 64)           0           ['global_max_pooling1d_1[0][0]']
#
#  dense_8 (Dense)                (None, 32)           2080        ['dense_7[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 96)           0           ['dropout_2[0][0]',
#                                                                   'dense_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 96)          384         ['concatenate_1[0][0]']
#  rmalization)
#
#  dense_9 (Dense)                (None, 128)          12416       ['batch_normalization_5[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_9[0][0]']
#
#  dense_10 (Dense)               (None, 32)           4128        ['dropout_3[0][0]']
#
#  dense_11 (Dense)               (None, 1)            33          ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 4,893,045
# Trainable params: 4,892,331
# Non-trainable params: 714
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 32s 256ms/step - loss: 33.3939 - mean_absolute_error: 33.0081 - root_mean_squared_error: 45.5792 - mean_absolute_percentage_error: 91.4635 - val_loss: 33.2324 - val_mean_absolute_error: 32.8533 - val_root_mean_squared_error: 46.8232 - val_mean_absolute_percentage_error: 78.1077 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 25s 241ms/step - loss: 29.1444 - mean_absolute_error: 28.7771 - root_mean_squared_error: 41.7318 - mean_absolute_percentage_error: 72.0808 - val_loss: 28.6182 - val_mean_absolute_error: 28.2646 - val_root_mean_squared_error: 42.9691 - val_mean_absolute_percentage_error: 68.0755 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 25s 245ms/step - loss: 22.0481 - mean_absolute_error: 21.6989 - root_mean_squared_error: 33.3679 - mean_absolute_percentage_error: 59.6372 - val_loss: 24.7326 - val_mean_absolute_error: 24.3877 - val_root_mean_squared_error: 37.8030 - val_mean_absolute_percentage_error: 70.3515 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 28s 272ms/step - loss: 14.5327 - mean_absolute_error: 14.2005 - root_mean_squared_error: 22.0012 - mean_absolute_percentage_error: 58.6484 - val_loss: 19.4013 - val_mean_absolute_error: 19.0797 - val_root_mean_squared_error: 28.4226 - val_mean_absolute_percentage_error: 63.0016 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 32s 310ms/step - loss: 11.6820 - mean_absolute_error: 11.3600 - root_mean_squared_error: 17.4667 - mean_absolute_percentage_error: 54.9055 - val_loss: 15.0858 - val_mean_absolute_error: 14.7722 - val_root_mean_squared_error: 22.5133 - val_mean_absolute_percentage_error: 57.2708 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 32s 307ms/step - loss: 10.4023 - mean_absolute_error: 10.0842 - root_mean_squared_error: 15.8013 - mean_absolute_percentage_error: 51.0712 - val_loss: 11.5899 - val_mean_absolute_error: 11.2779 - val_root_mean_squared_error: 17.9762 - val_mean_absolute_percentage_error: 46.3817 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 32s 308ms/step - loss: 9.5254 - mean_absolute_error: 9.2119 - root_mean_squared_error: 14.5583 - mean_absolute_percentage_error: 43.8944 - val_loss: 9.4842 - val_mean_absolute_error: 9.1776 - val_root_mean_squared_error: 14.9183 - val_mean_absolute_percentage_error: 51.5933 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 32s 310ms/step - loss: 9.0419 - mean_absolute_error: 8.7330 - root_mean_squared_error: 13.8392 - mean_absolute_percentage_error: 42.5129 - val_loss: 9.4240 - val_mean_absolute_error: 9.1247 - val_root_mean_squared_error: 14.2959 - val_mean_absolute_percentage_error: 58.0992 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 32s 309ms/step - loss: 8.5057 - mean_absolute_error: 8.2004 - root_mean_squared_error: 13.2908 - mean_absolute_percentage_error: 38.3904 - val_loss: 16.4498 - val_mean_absolute_error: 16.1617 - val_root_mean_squared_error: 23.7860 - val_mean_absolute_percentage_error: 62.9958 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 31s 305ms/step - loss: 8.0934 - mean_absolute_error: 7.7890 - root_mean_squared_error: 12.5550 - mean_absolute_percentage_error: 37.1206 - val_loss: 9.3343 - val_mean_absolute_error: 9.0387 - val_root_mean_squared_error: 14.0072 - val_mean_absolute_percentage_error: 57.0440 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 32s 307ms/step - loss: 7.4748 - mean_absolute_error: 7.1729 - root_mean_squared_error: 11.5209 - mean_absolute_percentage_error: 33.8312 - val_loss: 8.3498 - val_mean_absolute_error: 8.0473 - val_root_mean_squared_error: 14.0408 - val_mean_absolute_percentage_error: 35.7033 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 32s 312ms/step - loss: 6.9207 - mean_absolute_error: 6.6205 - root_mean_squared_error: 10.5747 - mean_absolute_percentage_error: 32.7627 - val_loss: 9.1498 - val_mean_absolute_error: 8.8609 - val_root_mean_squared_error: 14.1041 - val_mean_absolute_percentage_error: 36.2664 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 32s 309ms/step - loss: 7.0532 - mean_absolute_error: 6.7574 - root_mean_squared_error: 10.8454 - mean_absolute_percentage_error: 32.1676 - val_loss: 11.3872 - val_mean_absolute_error: 11.1107 - val_root_mean_squared_error: 16.3987 - val_mean_absolute_percentage_error: 56.2912 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 31s 306ms/step - loss: 6.5668 - mean_absolute_error: 6.2694 - root_mean_squared_error: 10.1198 - mean_absolute_percentage_error: 29.5162 - val_loss: 10.7355 - val_mean_absolute_error: 10.4480 - val_root_mean_squared_error: 16.4719 - val_mean_absolute_percentage_error: 39.2664 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 31s 305ms/step - loss: 6.4220 - mean_absolute_error: 6.1291 - root_mean_squared_error: 9.8570 - mean_absolute_percentage_error: 29.3825 - val_loss: 12.2963 - val_mean_absolute_error: 12.0236 - val_root_mean_squared_error: 17.6621 - val_mean_absolute_percentage_error: 56.3354 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 32s 309ms/step - loss: 6.0272 - mean_absolute_error: 5.7348 - root_mean_squared_error: 9.2269 - mean_absolute_percentage_error: 26.9461 - val_loss: 11.1376 - val_mean_absolute_error: 10.8664 - val_root_mean_squared_error: 14.9453 - val_mean_absolute_percentage_error: 80.2554 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 31s 305ms/step - loss: 5.9920 - mean_absolute_error: 5.7011 - root_mean_squared_error: 9.1018 - mean_absolute_percentage_error: 27.1788 - val_loss: 6.5981 - val_mean_absolute_error: 6.2981 - val_root_mean_squared_error: 11.7025 - val_mean_absolute_percentage_error: 33.5313 - lr: 5.0000e-05
# Epoch 18/100
# 103/103 [==============================] - 32s 310ms/step - loss: 5.8668 - mean_absolute_error: 5.5781 - root_mean_squared_error: 8.9859 - mean_absolute_percentage_error: 25.9779 - val_loss: 7.5787 - val_mean_absolute_error: 7.2906 - val_root_mean_squared_error: 12.8298 - val_mean_absolute_percentage_error: 33.2107 - lr: 5.0000e-05
# Epoch 19/100
# 103/103 [==============================] - 32s 309ms/step - loss: 5.4408 - mean_absolute_error: 5.1522 - root_mean_squared_error: 8.2333 - mean_absolute_percentage_error: 24.3109 - val_loss: 9.3232 - val_mean_absolute_error: 9.0532 - val_root_mean_squared_error: 13.9368 - val_mean_absolute_percentage_error: 42.6440 - lr: 5.0000e-05
# Epoch 20/100
# 103/103 [==============================] - 32s 307ms/step - loss: 5.4878 - mean_absolute_error: 5.1972 - root_mean_squared_error: 8.2688 - mean_absolute_percentage_error: 24.5830 - val_loss: 7.8368 - val_mean_absolute_error: 7.5654 - val_root_mean_squared_error: 12.4638 - val_mean_absolute_percentage_error: 48.6761 - lr: 5.0000e-05
# Epoch 21/100
# 103/103 [==============================] - 32s 308ms/step - loss: 5.3888 - mean_absolute_error: 5.0997 - root_mean_squared_error: 8.3318 - mean_absolute_percentage_error: 24.4316 - val_loss: 7.3424 - val_mean_absolute_error: 7.0457 - val_root_mean_squared_error: 12.2858 - val_mean_absolute_percentage_error: 32.0823 - lr: 5.0000e-05
# Epoch 22/100
# 103/103 [==============================] - 32s 311ms/step - loss: 5.3417 - mean_absolute_error: 5.0562 - root_mean_squared_error: 8.2223 - mean_absolute_percentage_error: 24.2082 - val_loss: 6.4347 - val_mean_absolute_error: 6.1313 - val_root_mean_squared_error: 11.4088 - val_mean_absolute_percentage_error: 32.8674 - lr: 5.0000e-05
# Epoch 23/100
# 103/103 [==============================] - 31s 303ms/step - loss: 5.3505 - mean_absolute_error: 5.0663 - root_mean_squared_error: 8.1448 - mean_absolute_percentage_error: 23.5166 - val_loss: 6.4319 - val_mean_absolute_error: 6.1445 - val_root_mean_squared_error: 11.2819 - val_mean_absolute_percentage_error: 32.2878 - lr: 5.0000e-05
# Epoch 24/100
# 103/103 [==============================] - 31s 305ms/step - loss: 5.1068 - mean_absolute_error: 4.8214 - root_mean_squared_error: 7.9095 - mean_absolute_percentage_error: 22.4752 - val_loss: 8.2277 - val_mean_absolute_error: 7.9439 - val_root_mean_squared_error: 13.0974 - val_mean_absolute_percentage_error: 34.2587 - lr: 5.0000e-05
# Epoch 25/100
# 103/103 [==============================] - 31s 306ms/step - loss: 5.0882 - mean_absolute_error: 4.8039 - root_mean_squared_error: 7.8056 - mean_absolute_percentage_error: 22.5686 - val_loss: 6.3746 - val_mean_absolute_error: 6.0821 - val_root_mean_squared_error: 11.3484 - val_mean_absolute_percentage_error: 32.7432 - lr: 5.0000e-05
# Epoch 26/100
# 103/103 [==============================] - 32s 308ms/step - loss: 5.0255 - mean_absolute_error: 4.7427 - root_mean_squared_error: 7.4629 - mean_absolute_percentage_error: 22.9351 - val_loss: 9.1329 - val_mean_absolute_error: 8.8649 - val_root_mean_squared_error: 13.3574 - val_mean_absolute_percentage_error: 47.2745 - lr: 5.0000e-05
# Epoch 27/100
# 103/103 [==============================] - 32s 311ms/step - loss: 4.9290 - mean_absolute_error: 4.6486 - root_mean_squared_error: 7.3920 - mean_absolute_percentage_error: 21.7233 - val_loss: 6.4511 - val_mean_absolute_error: 6.1721 - val_root_mean_squared_error: 11.1112 - val_mean_absolute_percentage_error: 36.5149 - lr: 5.0000e-05
# Epoch 28/100
# 103/103 [==============================] - 32s 308ms/step - loss: 4.9958 - mean_absolute_error: 4.7172 - root_mean_squared_error: 7.4045 - mean_absolute_percentage_error: 22.3526 - val_loss: 6.6985 - val_mean_absolute_error: 6.4223 - val_root_mean_squared_error: 11.5316 - val_mean_absolute_percentage_error: 31.6581 - lr: 5.0000e-05
# Epoch 29/100
# 103/103 [==============================] - 32s 310ms/step - loss: 5.0096 - mean_absolute_error: 4.7311 - root_mean_squared_error: 7.7392 - mean_absolute_percentage_error: 22.9646 - val_loss: 8.8417 - val_mean_absolute_error: 8.5681 - val_root_mean_squared_error: 13.8752 - val_mean_absolute_percentage_error: 34.4256 - lr: 5.0000e-05
# Epoch 30/100
# 103/103 [==============================] - 31s 297ms/step - loss: 4.8382 - mean_absolute_error: 4.5583 - root_mean_squared_error: 7.1732 - mean_absolute_percentage_error: 22.1210 - val_loss: 6.9920 - val_mean_absolute_error: 6.7068 - val_root_mean_squared_error: 11.9120 - val_mean_absolute_percentage_error: 32.8669 - lr: 5.0000e-05
# Epoch 31/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.8039 - mean_absolute_error: 4.5289 - root_mean_squared_error: 7.0309 - mean_absolute_percentage_error: 21.8449 - val_loss: 6.8015 - val_mean_absolute_error: 6.5229 - val_root_mean_squared_error: 11.3855 - val_mean_absolute_percentage_error: 34.7262 - lr: 2.5000e-05
# Epoch 32/100
# 103/103 [==============================] - 29s 284ms/step - loss: 4.9079 - mean_absolute_error: 4.6341 - root_mean_squared_error: 7.4448 - mean_absolute_percentage_error: 22.5021 - val_loss: 6.8160 - val_mean_absolute_error: 6.5515 - val_root_mean_squared_error: 11.2867 - val_mean_absolute_percentage_error: 34.9813 - lr: 2.5000e-05
# Epoch 33/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.7752 - mean_absolute_error: 4.4977 - root_mean_squared_error: 7.0733 - mean_absolute_percentage_error: 21.1641 - val_loss: 8.1232 - val_mean_absolute_error: 7.8468 - val_root_mean_squared_error: 12.8927 - val_mean_absolute_percentage_error: 32.6938 - lr: 2.5000e-05
# Epoch 34/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.4563 - mean_absolute_error: 4.1781 - root_mean_squared_error: 6.7267 - mean_absolute_percentage_error: 20.0845 - val_loss: 7.2799 - val_mean_absolute_error: 7.0066 - val_root_mean_squared_error: 11.5968 - val_mean_absolute_percentage_error: 37.4698 - lr: 2.5000e-05
# Epoch 35/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.6878 - mean_absolute_error: 4.4104 - root_mean_squared_error: 7.1038 - mean_absolute_percentage_error: 20.9518 - val_loss: 6.2266 - val_mean_absolute_error: 5.9503 - val_root_mean_squared_error: 10.9559 - val_mean_absolute_percentage_error: 32.1958 - lr: 2.5000e-05
# Epoch 36/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.6091 - mean_absolute_error: 4.3305 - root_mean_squared_error: 7.0112 - mean_absolute_percentage_error: 20.8980 - val_loss: 6.7839 - val_mean_absolute_error: 6.5225 - val_root_mean_squared_error: 11.3415 - val_mean_absolute_percentage_error: 32.7190 - lr: 2.5000e-05
# Epoch 37/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.4315 - mean_absolute_error: 4.1539 - root_mean_squared_error: 6.7919 - mean_absolute_percentage_error: 19.8969 - val_loss: 6.6218 - val_mean_absolute_error: 6.3505 - val_root_mean_squared_error: 11.1781 - val_mean_absolute_percentage_error: 34.4893 - lr: 2.5000e-05
# Epoch 38/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.5101 - mean_absolute_error: 4.2370 - root_mean_squared_error: 6.7384 - mean_absolute_percentage_error: 20.1100 - val_loss: 6.6380 - val_mean_absolute_error: 6.3629 - val_root_mean_squared_error: 11.2999 - val_mean_absolute_percentage_error: 34.8002 - lr: 2.5000e-05
# Epoch 39/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.5613 - mean_absolute_error: 4.2862 - root_mean_squared_error: 6.6911 - mean_absolute_percentage_error: 20.1838 - val_loss: 6.1062 - val_mean_absolute_error: 5.8295 - val_root_mean_squared_error: 10.9543 - val_mean_absolute_percentage_error: 32.0686 - lr: 2.5000e-05
# Epoch 40/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.4904 - mean_absolute_error: 4.2162 - root_mean_squared_error: 6.6085 - mean_absolute_percentage_error: 20.7126 - val_loss: 6.2891 - val_mean_absolute_error: 6.0260 - val_root_mean_squared_error: 11.0226 - val_mean_absolute_percentage_error: 33.0972 - lr: 2.5000e-05
# Epoch 41/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.4118 - mean_absolute_error: 4.1393 - root_mean_squared_error: 6.6811 - mean_absolute_percentage_error: 20.5360 - val_loss: 7.7448 - val_mean_absolute_error: 7.4768 - val_root_mean_squared_error: 12.0997 - val_mean_absolute_percentage_error: 38.2815 - lr: 2.5000e-05
# Epoch 42/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.6332 - mean_absolute_error: 4.3619 - root_mean_squared_error: 6.9449 - mean_absolute_percentage_error: 20.7510 - val_loss: 6.0081 - val_mean_absolute_error: 5.7319 - val_root_mean_squared_error: 10.8018 - val_mean_absolute_percentage_error: 31.9029 - lr: 2.5000e-05
# Epoch 43/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.2433 - mean_absolute_error: 3.9742 - root_mean_squared_error: 6.1963 - mean_absolute_percentage_error: 19.9499 - val_loss: 6.3874 - val_mean_absolute_error: 6.1196 - val_root_mean_squared_error: 11.0702 - val_mean_absolute_percentage_error: 31.1842 - lr: 2.5000e-05
# Epoch 44/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.4307 - mean_absolute_error: 4.1610 - root_mean_squared_error: 6.6925 - mean_absolute_percentage_error: 19.9463 - val_loss: 6.9360 - val_mean_absolute_error: 6.6668 - val_root_mean_squared_error: 11.3775 - val_mean_absolute_percentage_error: 35.1007 - lr: 2.5000e-05
# Epoch 45/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.4325 - mean_absolute_error: 4.1625 - root_mean_squared_error: 6.3936 - mean_absolute_percentage_error: 20.6746 - val_loss: 7.4754 - val_mean_absolute_error: 7.2163 - val_root_mean_squared_error: 11.7245 - val_mean_absolute_percentage_error: 36.3631 - lr: 2.5000e-05
# Epoch 46/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.6495 - mean_absolute_error: 4.3789 - root_mean_squared_error: 6.8471 - mean_absolute_percentage_error: 21.3559 - val_loss: 6.6727 - val_mean_absolute_error: 6.4184 - val_root_mean_squared_error: 11.0900 - val_mean_absolute_percentage_error: 32.7292 - lr: 2.5000e-05
# Epoch 47/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.5306 - mean_absolute_error: 4.2626 - root_mean_squared_error: 6.6388 - mean_absolute_percentage_error: 20.9323 - val_loss: 6.6864 - val_mean_absolute_error: 6.4068 - val_root_mean_squared_error: 11.2593 - val_mean_absolute_percentage_error: 31.8239 - lr: 2.5000e-05
# Epoch 48/100
# 103/103 [==============================] - 29s 286ms/step - loss: 4.2274 - mean_absolute_error: 3.9586 - root_mean_squared_error: 6.2989 - mean_absolute_percentage_error: 18.8794 - val_loss: 6.6028 - val_mean_absolute_error: 6.3448 - val_root_mean_squared_error: 11.0988 - val_mean_absolute_percentage_error: 33.0084 - lr: 1.2500e-05
# Epoch 49/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.4223 - mean_absolute_error: 4.1536 - root_mean_squared_error: 6.6638 - mean_absolute_percentage_error: 19.5101 - val_loss: 6.1146 - val_mean_absolute_error: 5.8523 - val_root_mean_squared_error: 10.7519 - val_mean_absolute_percentage_error: 32.5020 - lr: 1.2500e-05
# Epoch 50/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.3251 - mean_absolute_error: 4.0551 - root_mean_squared_error: 6.4561 - mean_absolute_percentage_error: 19.5170 - val_loss: 6.0736 - val_mean_absolute_error: 5.8108 - val_root_mean_squared_error: 10.7535 - val_mean_absolute_percentage_error: 33.2897 - lr: 1.2500e-05
# Epoch 51/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.3521 - mean_absolute_error: 4.0855 - root_mean_squared_error: 6.5653 - mean_absolute_percentage_error: 18.7540 - val_loss: 5.9228 - val_mean_absolute_error: 5.6466 - val_root_mean_squared_error: 10.7613 - val_mean_absolute_percentage_error: 32.4983 - lr: 1.2500e-05
# Epoch 52/100
# 103/103 [==============================] - 30s 294ms/step - loss: 4.3264 - mean_absolute_error: 4.0567 - root_mean_squared_error: 6.5192 - mean_absolute_percentage_error: 19.5448 - val_loss: 6.1175 - val_mean_absolute_error: 5.8587 - val_root_mean_squared_error: 10.8528 - val_mean_absolute_percentage_error: 33.5396 - lr: 1.2500e-05
# Epoch 53/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.0489 - mean_absolute_error: 3.7787 - root_mean_squared_error: 5.9216 - mean_absolute_percentage_error: 18.2860 - val_loss: 6.3075 - val_mean_absolute_error: 6.0489 - val_root_mean_squared_error: 10.9026 - val_mean_absolute_percentage_error: 34.2808 - lr: 1.2500e-05
# Epoch 54/100
# 103/103 [==============================] - 30s 290ms/step - loss: 3.9967 - mean_absolute_error: 3.7279 - root_mean_squared_error: 5.7583 - mean_absolute_percentage_error: 19.1803 - val_loss: 6.2085 - val_mean_absolute_error: 5.9488 - val_root_mean_squared_error: 10.8462 - val_mean_absolute_percentage_error: 32.7560 - lr: 1.2500e-05
# Epoch 55/100
# 103/103 [==============================] - 30s 287ms/step - loss: 4.1475 - mean_absolute_error: 3.8768 - root_mean_squared_error: 6.1930 - mean_absolute_percentage_error: 18.5650 - val_loss: 7.4676 - val_mean_absolute_error: 7.1998 - val_root_mean_squared_error: 11.9397 - val_mean_absolute_percentage_error: 37.5852 - lr: 1.2500e-05
# Epoch 56/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.2215 - mean_absolute_error: 3.9551 - root_mean_squared_error: 6.2156 - mean_absolute_percentage_error: 19.5658 - val_loss: 6.0089 - val_mean_absolute_error: 5.7456 - val_root_mean_squared_error: 10.7752 - val_mean_absolute_percentage_error: 32.6821 - lr: 1.2500e-05
# Epoch 57/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.2170 - mean_absolute_error: 3.9475 - root_mean_squared_error: 6.0911 - mean_absolute_percentage_error: 19.2584 - val_loss: 6.8475 - val_mean_absolute_error: 6.5908 - val_root_mean_squared_error: 11.3290 - val_mean_absolute_percentage_error: 32.2019 - lr: 6.2500e-06
# Epoch 58/100
# 103/103 [==============================] - 30s 290ms/step - loss: 4.2250 - mean_absolute_error: 3.9573 - root_mean_squared_error: 6.2486 - mean_absolute_percentage_error: 19.1097 - val_loss: 5.9970 - val_mean_absolute_error: 5.7392 - val_root_mean_squared_error: 10.7317 - val_mean_absolute_percentage_error: 32.7615 - lr: 6.2500e-06
# Epoch 59/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.0236 - mean_absolute_error: 3.7557 - root_mean_squared_error: 5.7804 - mean_absolute_percentage_error: 18.2583 - val_loss: 6.6984 - val_mean_absolute_error: 6.4483 - val_root_mean_squared_error: 11.1729 - val_mean_absolute_percentage_error: 32.0984 - lr: 6.2500e-06
# Epoch 60/100
# 103/103 [==============================] - 30s 296ms/step - loss: 4.3039 - mean_absolute_error: 4.0371 - root_mean_squared_error: 6.6410 - mean_absolute_percentage_error: 18.9609 - val_loss: 5.9843 - val_mean_absolute_error: 5.7161 - val_root_mean_squared_error: 10.7762 - val_mean_absolute_percentage_error: 32.8300 - lr: 6.2500e-06
# Epoch 61/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.1491 - mean_absolute_error: 3.8810 - root_mean_squared_error: 6.1735 - mean_absolute_percentage_error: 18.1297 - val_loss: 6.4144 - val_mean_absolute_error: 6.1651 - val_root_mean_squared_error: 10.9143 - val_mean_absolute_percentage_error: 34.3867 - lr: 6.2500e-06
# Epoch 62/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.2659 - mean_absolute_error: 4.0021 - root_mean_squared_error: 6.1503 - mean_absolute_percentage_error: 19.8760 - val_loss: 6.4561 - val_mean_absolute_error: 6.2029 - val_root_mean_squared_error: 11.0029 - val_mean_absolute_percentage_error: 32.6887 - lr: 3.1250e-06
# Epoch 63/100
# 103/103 [==============================] - 30s 292ms/step - loss: 4.1981 - mean_absolute_error: 3.9314 - root_mean_squared_error: 6.0673 - mean_absolute_percentage_error: 19.4261 - val_loss: 6.4140 - val_mean_absolute_error: 6.1599 - val_root_mean_squared_error: 10.9485 - val_mean_absolute_percentage_error: 32.7750 - lr: 3.1250e-06
# Epoch 64/100
# 103/103 [==============================] - 30s 291ms/step - loss: 4.2383 - mean_absolute_error: 3.9687 - root_mean_squared_error: 6.2675 - mean_absolute_percentage_error: 18.2632 - val_loss: 6.0565 - val_mean_absolute_error: 5.8017 - val_root_mean_squared_error: 10.7313 - val_mean_absolute_percentage_error: 32.9022 - lr: 3.1250e-06
# Epoch 65/100
# 103/103 [==============================] - 30s 292ms/step - loss: 3.9986 - mean_absolute_error: 3.7295 - root_mean_squared_error: 5.9410 - mean_absolute_percentage_error: 18.0851 - val_loss: 6.1452 - val_mean_absolute_error: 5.8893 - val_root_mean_squared_error: 10.7735 - val_mean_absolute_percentage_error: 32.6894 - lr: 3.1250e-06
# Epoch 66/100
# 103/103 [==============================] - 30s 287ms/step - loss: 4.2000 - mean_absolute_error: 3.9303 - root_mean_squared_error: 6.2949 - mean_absolute_percentage_error: 19.1024 - val_loss: 6.5075 - val_mean_absolute_error: 6.2529 - val_root_mean_squared_error: 10.9978 - val_mean_absolute_percentage_error: 34.8994 - lr: 3.1250e-06
# Epoch 67/100
# 103/103 [==============================] - 27s 260ms/step - loss: 4.0886 - mean_absolute_error: 3.8191 - root_mean_squared_error: 5.8974 - mean_absolute_percentage_error: 18.4681 - val_loss: 6.0702 - val_mean_absolute_error: 5.8126 - val_root_mean_squared_error: 10.7479 - val_mean_absolute_percentage_error: 33.5400 - lr: 1.5625e-06
# Epoch 68/100
# 103/103 [==============================] - 27s 267ms/step - loss: 4.1911 - mean_absolute_error: 3.9223 - root_mean_squared_error: 6.2072 - mean_absolute_percentage_error: 19.1136 - val_loss: 6.0668 - val_mean_absolute_error: 5.8120 - val_root_mean_squared_error: 10.7514 - val_mean_absolute_percentage_error: 33.1334 - lr: 1.5625e-06
# Epoch 69/100
# 103/103 [==============================] - 28s 268ms/step - loss: 4.0715 - mean_absolute_error: 3.8043 - root_mean_squared_error: 6.1551 - mean_absolute_percentage_error: 17.5723 - val_loss: 6.0624 - val_mean_absolute_error: 5.8072 - val_root_mean_squared_error: 10.7587 - val_mean_absolute_percentage_error: 33.1812 - lr: 1.5625e-06
# Epoch 70/100
# 103/103 [==============================] - 27s 267ms/step - loss: 4.0321 - mean_absolute_error: 3.7647 - root_mean_squared_error: 5.9273 - mean_absolute_percentage_error: 18.2783 - val_loss: 6.0429 - val_mean_absolute_error: 5.7866 - val_root_mean_squared_error: 10.7307 - val_mean_absolute_percentage_error: 32.7212 - lr: 1.5625e-06
# Epoch 71/100
# 103/103 [==============================] - 27s 259ms/step - loss: 4.2035 - mean_absolute_error: 3.9380 - root_mean_squared_error: 6.1734 - mean_absolute_percentage_error: 18.6542 - val_loss: 6.0364 - val_mean_absolute_error: 5.7807 - val_root_mean_squared_error: 10.7196 - val_mean_absolute_percentage_error: 33.1550 - lr: 1.5625e-06
# Epoch 72/100
# 103/103 [==============================] - 27s 259ms/step - loss: 4.1169 - mean_absolute_error: 3.8479 - root_mean_squared_error: 6.4163 - mean_absolute_percentage_error: 18.2758 - val_loss: 6.0808 - val_mean_absolute_error: 5.8260 - val_root_mean_squared_error: 10.7422 - val_mean_absolute_percentage_error: 33.2214 - lr: 7.8125e-07
# Epoch 73/100
# 103/103 [==============================] - 27s 261ms/step - loss: 4.1473 - mean_absolute_error: 3.8804 - root_mean_squared_error: 6.2139 - mean_absolute_percentage_error: 18.2584 - val_loss: 6.0299 - val_mean_absolute_error: 5.7752 - val_root_mean_squared_error: 10.7340 - val_mean_absolute_percentage_error: 33.2602 - lr: 7.8125e-07
# Epoch 74/100
# 103/103 [==============================] - 27s 262ms/step - loss: 4.0732 - mean_absolute_error: 3.8043 - root_mean_squared_error: 6.0956 - mean_absolute_percentage_error: 18.7913 - val_loss: 6.0403 - val_mean_absolute_error: 5.7856 - val_root_mean_squared_error: 10.7452 - val_mean_absolute_percentage_error: 32.9471 - lr: 7.8125e-07
# Epoch 75/100
# 103/103 [==============================] - 27s 262ms/step - loss: 4.1492 - mean_absolute_error: 3.8834 - root_mean_squared_error: 6.1989 - mean_absolute_percentage_error: 18.8629 - val_loss: 6.0356 - val_mean_absolute_error: 5.7801 - val_root_mean_squared_error: 10.7457 - val_mean_absolute_percentage_error: 32.9314 - lr: 7.8125e-07
# Epoch 76/100
# 103/103 [==============================] - 28s 268ms/step - loss: 4.0465 - mean_absolute_error: 3.7773 - root_mean_squared_error: 6.0036 - mean_absolute_percentage_error: 18.4581 - val_loss: 6.0312 - val_mean_absolute_error: 5.7771 - val_root_mean_squared_error: 10.7264 - val_mean_absolute_percentage_error: 33.0500 - lr: 7.8125e-07
# Epoch 77/100
# 103/103 [==============================] - 27s 266ms/step - loss: 4.2939 - mean_absolute_error: 4.0269 - root_mean_squared_error: 6.3283 - mean_absolute_percentage_error: 19.4523 - val_loss: 6.0029 - val_mean_absolute_error: 5.7471 - val_root_mean_squared_error: 10.7193 - val_mean_absolute_percentage_error: 32.8301 - lr: 3.9062e-07
# Epoch 78/100
# 103/103 [==============================] - 27s 266ms/step - loss: 4.0617 - mean_absolute_error: 3.7965 - root_mean_squared_error: 6.0000 - mean_absolute_percentage_error: 17.9595 - val_loss: 6.0268 - val_mean_absolute_error: 5.7723 - val_root_mean_squared_error: 10.7434 - val_mean_absolute_percentage_error: 33.1643 - lr: 3.9062e-07
# Epoch 79/100
# 103/103 [==============================] - 27s 265ms/step - loss: 4.1804 - mean_absolute_error: 3.9112 - root_mean_squared_error: 6.2391 - mean_absolute_percentage_error: 18.7596 - val_loss: 6.0442 - val_mean_absolute_error: 5.7903 - val_root_mean_squared_error: 10.7419 - val_mean_absolute_percentage_error: 33.2629 - lr: 3.9062e-07
# Epoch 80/100
# 103/103 [==============================] - 26s 257ms/step - loss: 4.0154 - mean_absolute_error: 3.7470 - root_mean_squared_error: 5.9460 - mean_absolute_percentage_error: 17.9541 - val_loss: 6.0064 - val_mean_absolute_error: 5.7510 - val_root_mean_squared_error: 10.7243 - val_mean_absolute_percentage_error: 32.9939 - lr: 3.9062e-07
# Epoch 81/100
# 103/103 [==============================] - 26s 255ms/step - loss: 4.0957 - mean_absolute_error: 3.8302 - root_mean_squared_error: 6.1264 - mean_absolute_percentage_error: 18.0753 - val_loss: 6.0291 - val_mean_absolute_error: 5.7746 - val_root_mean_squared_error: 10.7529 - val_mean_absolute_percentage_error: 32.9351 - lr: 3.9062e-07
# Epoch 82/100
# 103/103 [==============================] - 27s 258ms/step - loss: 4.2108 - mean_absolute_error: 3.9457 - root_mean_squared_error: 6.2169 - mean_absolute_percentage_error: 18.8259 - val_loss: 5.9952 - val_mean_absolute_error: 5.7393 - val_root_mean_squared_error: 10.7302 - val_mean_absolute_percentage_error: 32.7911 - lr: 1.9531e-07
# Epoch 83/100
# 103/103 [==============================] - 29s 280ms/step - loss: 4.0697 - mean_absolute_error: 3.8024 - root_mean_squared_error: 6.2885 - mean_absolute_percentage_error: 17.6202 - val_loss: 6.0009 - val_mean_absolute_error: 5.7453 - val_root_mean_squared_error: 10.7353 - val_mean_absolute_percentage_error: 32.8056 - lr: 1.9531e-07
# Epoch 84/100
# 103/103 [==============================] - 30s 290ms/step - loss: 4.3100 - mean_absolute_error: 4.0437 - root_mean_squared_error: 6.2793 - mean_absolute_percentage_error: 19.1810 - val_loss: 6.0248 - val_mean_absolute_error: 5.7702 - val_root_mean_squared_error: 10.7267 - val_mean_absolute_percentage_error: 32.9432 - lr: 1.9531e-07
# Epoch 85/100
# 103/103 [==============================] - 30s 293ms/step - loss: 4.2431 - mean_absolute_error: 3.9760 - root_mean_squared_error: 6.0917 - mean_absolute_percentage_error: 19.1506 - val_loss: 6.0422 - val_mean_absolute_error: 5.7880 - val_root_mean_squared_error: 10.7195 - val_mean_absolute_percentage_error: 32.9959 - lr: 1.9531e-07
# Epoch 86/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.0519 - mean_absolute_error: 3.7831 - root_mean_squared_error: 6.2423 - mean_absolute_percentage_error: 17.6486 - val_loss: 6.0297 - val_mean_absolute_error: 5.7756 - val_root_mean_squared_error: 10.7200 - val_mean_absolute_percentage_error: 33.1058 - lr: 1.9531e-07
# Epoch 87/100
# 103/103 [==============================] - 30s 295ms/step - loss: 4.0494 - mean_absolute_error: 3.7823 - root_mean_squared_error: 6.0924 - mean_absolute_percentage_error: 18.2088 - val_loss: 6.0214 - val_mean_absolute_error: 5.7657 - val_root_mean_squared_error: 10.7229 - val_mean_absolute_percentage_error: 33.1298 - lr: 9.7656e-08
# Epoch 88/100
# 103/103 [==============================] - 30s 289ms/step - loss: 4.0062 - mean_absolute_error: 3.7386 - root_mean_squared_error: 5.9738 - mean_absolute_percentage_error: 17.7363 - val_loss: 6.0022 - val_mean_absolute_error: 5.7470 - val_root_mean_squared_error: 10.7245 - val_mean_absolute_percentage_error: 32.9971 - lr: 9.7656e-08
# Epoch 89/100
# 103/103 [==============================] - 30s 287ms/step - loss: 4.2616 - mean_absolute_error: 3.9969 - root_mean_squared_error: 6.2497 - mean_absolute_percentage_error: 19.2313 - val_loss: 5.9846 - val_mean_absolute_error: 5.7282 - val_root_mean_squared_error: 10.7188 - val_mean_absolute_percentage_error: 32.7911 - lr: 9.7656e-08
# Epoch 90/100
# 103/103 [==============================] - 30s 287ms/step - loss: 3.9786 - mean_absolute_error: 3.7111 - root_mean_squared_error: 5.9911 - mean_absolute_percentage_error: 18.1160 - val_loss: 6.0203 - val_mean_absolute_error: 5.7651 - val_root_mean_squared_error: 10.7436 - val_mean_absolute_percentage_error: 33.0022 - lr: 9.7656e-08
# Epoch 91/100
# 103/103 [==============================] - 29s 287ms/step - loss: 4.0308 - mean_absolute_error: 3.7613 - root_mean_squared_error: 5.9806 - mean_absolute_percentage_error: 18.5566 - val_loss: 6.0129 - val_mean_absolute_error: 5.7573 - val_root_mean_squared_error: 10.7241 - val_mean_absolute_percentage_error: 33.0796 - lr: 9.7656e-08
# Epoch 92/100
# 103/103 [==============================] - 29s 283ms/step - loss: 4.2378 - mean_absolute_error: 3.9727 - root_mean_squared_error: 6.4420 - mean_absolute_percentage_error: 19.0972 - val_loss: 6.0013 - val_mean_absolute_error: 5.7461 - val_root_mean_squared_error: 10.7120 - val_mean_absolute_percentage_error: 32.8402 - lr: 4.8828e-08
# Epoch 93/100
# 103/103 [==============================] - 30s 288ms/step - loss: 4.1257 - mean_absolute_error: 3.8566 - root_mean_squared_error: 6.1349 - mean_absolute_percentage_error: 18.2452 - val_loss: 6.0345 - val_mean_absolute_error: 5.7803 - val_root_mean_squared_error: 10.7335 - val_mean_absolute_percentage_error: 33.1091 - lr: 4.8828e-08
# Epoch 94/100
# 103/103 [==============================] - 30s 287ms/step - loss: 4.0438 - mean_absolute_error: 3.7732 - root_mean_squared_error: 5.9033 - mean_absolute_percentage_error: 18.6041 - val_loss: 6.0233 - val_mean_absolute_error: 5.7688 - val_root_mean_squared_error: 10.7449 - val_mean_absolute_percentage_error: 32.9553 - lr: 4.8828e-08
# Epoch 95/100
# 103/103 [==============================] - 31s 301ms/step - loss: 3.9907 - mean_absolute_error: 3.7241 - root_mean_squared_error: 5.7480 - mean_absolute_percentage_error: 17.8102 - val_loss: 6.0011 - val_mean_absolute_error: 5.7457 - val_root_mean_squared_error: 10.7421 - val_mean_absolute_percentage_error: 32.8665 - lr: 4.8828e-08
# Epoch 96/100
# 103/103 [==============================] - 32s 311ms/step - loss: 4.1754 - mean_absolute_error: 3.9095 - root_mean_squared_error: 6.2746 - mean_absolute_percentage_error: 18.8944 - val_loss: 5.9868 - val_mean_absolute_error: 5.7308 - val_root_mean_squared_error: 10.7318 - val_mean_absolute_percentage_error: 32.7798 - lr: 4.8828e-08
# Epoch 97/100
# 103/103 [==============================] - 27s 265ms/step - loss: 4.0813 - mean_absolute_error: 3.8132 - root_mean_squared_error: 5.8618 - mean_absolute_percentage_error: 18.6627 - val_loss: 6.0249 - val_mean_absolute_error: 5.7706 - val_root_mean_squared_error: 10.7428 - val_mean_absolute_percentage_error: 32.9711 - lr: 2.4414e-08
# Epoch 98/100
# 103/103 [==============================] - 27s 266ms/step - loss: 3.8966 - mean_absolute_error: 3.6256 - root_mean_squared_error: 5.7924 - mean_absolute_percentage_error: 17.6390 - val_loss: 6.0096 - val_mean_absolute_error: 5.7553 - val_root_mean_squared_error: 10.7345 - val_mean_absolute_percentage_error: 32.9623 - lr: 2.4414e-08
# Epoch 99/100
# 103/103 [==============================] - 27s 267ms/step - loss: 4.1561 - mean_absolute_error: 3.8885 - root_mean_squared_error: 6.3121 - mean_absolute_percentage_error: 18.4700 - val_loss: 6.0304 - val_mean_absolute_error: 5.7755 - val_root_mean_squared_error: 10.7508 - val_mean_absolute_percentage_error: 33.1106 - lr: 2.4414e-08
# Epoch 100/100
# 103/103 [==============================] - 27s 266ms/step - loss: 4.1253 - mean_absolute_error: 3.8599 - root_mean_squared_error: 5.9606 - mean_absolute_percentage_error: 19.3511 - val_loss: 6.0333 - val_mean_absolute_error: 5.7784 - val_root_mean_squared_error: 10.7596 - val_mean_absolute_percentage_error: 33.1643 - lr: 2.4414e-08

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 121ms/step - loss: 6.0333 - mean_absolute_error: 5.7784 - root_mean_squared_error: 10.7596 - mean_absolute_percentage_error: 33.1643
# Model Loss: [6.033318519592285, 5.778396129608154, 10.759591102600098, 33.164329528808594]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 515ms/step
# Predicted Putusan: [9.81989]

# %%
model_scenario_name = "BiLSTM_13"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses, lstm_cell_8_layer_call_fn, lstm_cell_8_layer_call_and_return_conditional_losses, lstm_cell_10_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_13"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 362ms/step
# Predicted Putusan: [9.81989]
