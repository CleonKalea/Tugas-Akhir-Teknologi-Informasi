# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_29800\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=256 
)(text_input)

lstm_output = tf.keras.layers.LSTM(32, return_sequences=True, 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.001))(embedding_layer)
lstm_output = tf.keras.layers.BatchNormalization()(lstm_output)

lstm_output_2 = tf.keras.layers.LSTM(64, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001))(lstm_output)
lstm_output_2 = tf.keras.layers.BatchNormalization()(lstm_output_2)
lstm_output_3 = tf.keras.layers.LSTM(32, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001))(lstm_output_2)
lstm_output_3 = tf.keras.layers.BatchNormalization()(lstm_output_3)

pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical = tf.keras.layers.BatchNormalization()(numerical_input)
numerical_dense = tf.keras.layers.Dense(32, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)
combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.6,
    patience=7,
    min_lr=1e-7
)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
# model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])


model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  lstm (LSTM)                    (None, 1024, 32)     36992       ['embedding[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1024, 32)    128         ['lstm[0][0]']
#  alization)
#
#  lstm_1 (LSTM)                  (None, 1024, 64)     24832       ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 1024, 64)    256         ['lstm_1[0][0]']
#  rmalization)
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  lstm_2 (LSTM)                  (None, 1024, 32)     12416       ['batch_normalization_1[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 5)           20          ['numerical_input[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 1024, 32)    128         ['lstm_2[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 32)           192         ['batch_normalization_3[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 32)          0           ['batch_normalization_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 32)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 64)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64)          256         ['concatenate[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 128)          8320        ['batch_normalization_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 3,907,829
# Trainable params: 3,907,435
# Non-trainable params: 394
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), 
                    callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 20s 150ms/step - loss: 33.6223 - mean_absolute_error: 33.7249 - root_mean_squared_error: 46.2015 - mean_absolute_percentage_error: 95.1969 - val_loss: 34.7205 - val_mean_absolute_error: 34.8320 - val_root_mean_squared_error: 48.1639 - val_mean_absolute_percentage_error: 89.5436 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 15s 150ms/step - loss: 31.2240 - mean_absolute_error: 31.3421 - root_mean_squared_error: 43.9809 - mean_absolute_percentage_error: 82.7097 - val_loss: 31.9124 - val_mean_absolute_error: 32.0375 - val_root_mean_squared_error: 46.0020 - val_mean_absolute_percentage_error: 76.0320 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 17s 168ms/step - loss: 26.7278 - mean_absolute_error: 26.8547 - root_mean_squared_error: 39.7141 - mean_absolute_percentage_error: 66.1571 - val_loss: 28.2857 - val_mean_absolute_error: 28.4228 - val_root_mean_squared_error: 42.4220 - val_mean_absolute_percentage_error: 66.7454 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 15s 148ms/step - loss: 20.4029 - mean_absolute_error: 20.5393 - root_mean_squared_error: 31.7763 - mean_absolute_percentage_error: 56.5050 - val_loss: 22.3476 - val_mean_absolute_error: 22.4880 - val_root_mean_squared_error: 34.0202 - val_mean_absolute_percentage_error: 59.1939 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 14s 139ms/step - loss: 13.0466 - mean_absolute_error: 13.1886 - root_mean_squared_error: 20.8346 - mean_absolute_percentage_error: 52.4062 - val_loss: 14.2984 - val_mean_absolute_error: 14.4427 - val_root_mean_squared_error: 22.3557 - val_mean_absolute_percentage_error: 52.0265 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 15s 150ms/step - loss: 10.4093 - mean_absolute_error: 10.5518 - root_mean_squared_error: 16.7612 - mean_absolute_percentage_error: 50.5647 - val_loss: 12.1569 - val_mean_absolute_error: 12.3054 - val_root_mean_squared_error: 19.8970 - val_mean_absolute_percentage_error: 46.9114 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 17s 165ms/step - loss: 9.0764 - mean_absolute_error: 9.2162 - root_mean_squared_error: 15.0147 - mean_absolute_percentage_error: 44.7688 - val_loss: 9.5912 - val_mean_absolute_error: 9.7347 - val_root_mean_squared_error: 16.2039 - val_mean_absolute_percentage_error: 46.0218 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 14s 140ms/step - loss: 8.5469 - mean_absolute_error: 8.6886 - root_mean_squared_error: 14.0530 - mean_absolute_percentage_error: 41.8549 - val_loss: 10.4632 - val_mean_absolute_error: 10.6107 - val_root_mean_squared_error: 16.0557 - val_mean_absolute_percentage_error: 67.7678 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 15s 142ms/step - loss: 8.1130 - mean_absolute_error: 8.2559 - root_mean_squared_error: 13.6253 - mean_absolute_percentage_error: 40.2768 - val_loss: 8.3404 - val_mean_absolute_error: 8.4842 - val_root_mean_squared_error: 14.9229 - val_mean_absolute_percentage_error: 37.7611 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 16s 152ms/step - loss: 7.7588 - mean_absolute_error: 7.8976 - root_mean_squared_error: 12.7607 - mean_absolute_percentage_error: 37.5756 - val_loss: 8.9187 - val_mean_absolute_error: 9.0546 - val_root_mean_squared_error: 15.8088 - val_mean_absolute_percentage_error: 38.5146 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 18s 176ms/step - loss: 6.8921 - mean_absolute_error: 7.0320 - root_mean_squared_error: 11.7470 - mean_absolute_percentage_error: 32.4632 - val_loss: 7.9107 - val_mean_absolute_error: 8.0576 - val_root_mean_squared_error: 13.6445 - val_mean_absolute_percentage_error: 42.5270 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 18s 174ms/step - loss: 6.8210 - mean_absolute_error: 6.9640 - root_mean_squared_error: 11.4539 - mean_absolute_percentage_error: 33.0028 - val_loss: 8.2039 - val_mean_absolute_error: 8.3490 - val_root_mean_squared_error: 14.4890 - val_mean_absolute_percentage_error: 42.4187 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 17s 167ms/step - loss: 6.6140 - mean_absolute_error: 6.7550 - root_mean_squared_error: 11.2504 - mean_absolute_percentage_error: 31.1468 - val_loss: 11.7412 - val_mean_absolute_error: 11.8925 - val_root_mean_squared_error: 18.8262 - val_mean_absolute_percentage_error: 43.9966 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 16s 157ms/step - loss: 6.3247 - mean_absolute_error: 6.4675 - root_mean_squared_error: 10.4313 - mean_absolute_percentage_error: 30.5716 - val_loss: 7.1254 - val_mean_absolute_error: 7.2635 - val_root_mean_squared_error: 12.5675 - val_mean_absolute_percentage_error: 39.7487 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 18s 170ms/step - loss: 5.9699 - mean_absolute_error: 6.1144 - root_mean_squared_error: 9.8915 - mean_absolute_percentage_error: 28.3440 - val_loss: 7.6091 - val_mean_absolute_error: 7.7606 - val_root_mean_squared_error: 12.4283 - val_mean_absolute_percentage_error: 40.3391 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 17s 163ms/step - loss: 6.2077 - mean_absolute_error: 6.3512 - root_mean_squared_error: 10.3075 - mean_absolute_percentage_error: 30.5624 - val_loss: 7.9702 - val_mean_absolute_error: 8.1146 - val_root_mean_squared_error: 13.4518 - val_mean_absolute_percentage_error: 35.0102 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 17s 169ms/step - loss: 5.5364 - mean_absolute_error: 5.6775 - root_mean_squared_error: 9.2005 - mean_absolute_percentage_error: 26.2675 - val_loss: 6.6772 - val_mean_absolute_error: 6.8128 - val_root_mean_squared_error: 12.1922 - val_mean_absolute_percentage_error: 36.6823 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 16s 157ms/step - loss: 5.9106 - mean_absolute_error: 6.0504 - root_mean_squared_error: 9.8983 - mean_absolute_percentage_error: 27.1834 - val_loss: 12.9057 - val_mean_absolute_error: 13.0637 - val_root_mean_squared_error: 19.4996 - val_mean_absolute_percentage_error: 50.3682 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 16s 152ms/step - loss: 5.5880 - mean_absolute_error: 5.7315 - root_mean_squared_error: 9.3132 - mean_absolute_percentage_error: 27.0982 - val_loss: 7.9738 - val_mean_absolute_error: 8.1217 - val_root_mean_squared_error: 13.4894 - val_mean_absolute_percentage_error: 36.4778 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 14s 139ms/step - loss: 5.3432 - mean_absolute_error: 5.4848 - root_mean_squared_error: 8.8284 - mean_absolute_percentage_error: 26.9382 - val_loss: 7.2474 - val_mean_absolute_error: 7.3912 - val_root_mean_squared_error: 12.5747 - val_mean_absolute_percentage_error: 39.7122 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 14s 140ms/step - loss: 5.0308 - mean_absolute_error: 5.1720 - root_mean_squared_error: 8.5779 - mean_absolute_percentage_error: 24.6418 - val_loss: 9.5677 - val_mean_absolute_error: 9.7084 - val_root_mean_squared_error: 15.6400 - val_mean_absolute_percentage_error: 35.4022 - lr: 1.0000e-04
# Epoch 22/100
# 103/103 [==============================] - 15s 141ms/step - loss: 5.0438 - mean_absolute_error: 5.1884 - root_mean_squared_error: 8.3418 - mean_absolute_percentage_error: 23.8781 - val_loss: 7.1672 - val_mean_absolute_error: 7.3176 - val_root_mean_squared_error: 12.3765 - val_mean_absolute_percentage_error: 45.8928 - lr: 1.0000e-04
# Epoch 23/100
# 103/103 [==============================] - 14s 139ms/step - loss: 5.1479 - mean_absolute_error: 5.2941 - root_mean_squared_error: 8.5682 - mean_absolute_percentage_error: 24.8045 - val_loss: 6.9253 - val_mean_absolute_error: 7.0766 - val_root_mean_squared_error: 12.1742 - val_mean_absolute_percentage_error: 45.3491 - lr: 1.0000e-04
# Epoch 24/100
# 103/103 [==============================] - 14s 137ms/step - loss: 4.7315 - mean_absolute_error: 4.8743 - root_mean_squared_error: 7.8967 - mean_absolute_percentage_error: 23.0318 - val_loss: 6.8117 - val_mean_absolute_error: 6.9525 - val_root_mean_squared_error: 12.2236 - val_mean_absolute_percentage_error: 36.2971 - lr: 1.0000e-04
# Epoch 25/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.7947 - mean_absolute_error: 4.9406 - root_mean_squared_error: 7.9284 - mean_absolute_percentage_error: 22.9898 - val_loss: 6.1188 - val_mean_absolute_error: 6.2651 - val_root_mean_squared_error: 11.4230 - val_mean_absolute_percentage_error: 34.3603 - lr: 6.0000e-05
# Epoch 26/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.6915 - mean_absolute_error: 4.8360 - root_mean_squared_error: 7.5667 - mean_absolute_percentage_error: 22.4280 - val_loss: 6.1038 - val_mean_absolute_error: 6.2473 - val_root_mean_squared_error: 11.2558 - val_mean_absolute_percentage_error: 34.9097 - lr: 6.0000e-05
# Epoch 27/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.5031 - mean_absolute_error: 4.6452 - root_mean_squared_error: 7.5322 - mean_absolute_percentage_error: 22.5439 - val_loss: 7.2596 - val_mean_absolute_error: 7.4120 - val_root_mean_squared_error: 12.5722 - val_mean_absolute_percentage_error: 35.6303 - lr: 6.0000e-05
# Epoch 28/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.8017 - mean_absolute_error: 4.9504 - root_mean_squared_error: 7.9470 - mean_absolute_percentage_error: 22.9177 - val_loss: 6.9038 - val_mean_absolute_error: 7.0445 - val_root_mean_squared_error: 11.9861 - val_mean_absolute_percentage_error: 34.0598 - lr: 6.0000e-05
# Epoch 29/100
# 103/103 [==============================] - 14s 139ms/step - loss: 4.4559 - mean_absolute_error: 4.5991 - root_mean_squared_error: 7.3171 - mean_absolute_percentage_error: 21.9529 - val_loss: 9.4549 - val_mean_absolute_error: 9.6125 - val_root_mean_squared_error: 14.7879 - val_mean_absolute_percentage_error: 40.3500 - lr: 6.0000e-05
# Epoch 30/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.2424 - mean_absolute_error: 4.3861 - root_mean_squared_error: 7.0393 - mean_absolute_percentage_error: 22.1724 - val_loss: 7.9052 - val_mean_absolute_error: 8.0526 - val_root_mean_squared_error: 12.8782 - val_mean_absolute_percentage_error: 37.3334 - lr: 6.0000e-05
# Epoch 31/100
# 103/103 [==============================] - 14s 139ms/step - loss: 4.3545 - mean_absolute_error: 4.4963 - root_mean_squared_error: 7.1687 - mean_absolute_percentage_error: 20.7245 - val_loss: 6.0601 - val_mean_absolute_error: 6.2069 - val_root_mean_squared_error: 11.1438 - val_mean_absolute_percentage_error: 33.7104 - lr: 6.0000e-05
# Epoch 32/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.2836 - mean_absolute_error: 4.4288 - root_mean_squared_error: 7.1311 - mean_absolute_percentage_error: 21.0679 - val_loss: 6.2731 - val_mean_absolute_error: 6.4244 - val_root_mean_squared_error: 11.2600 - val_mean_absolute_percentage_error: 34.2129 - lr: 6.0000e-05
# Epoch 33/100
# 103/103 [==============================] - 14s 137ms/step - loss: 4.4496 - mean_absolute_error: 4.5960 - root_mean_squared_error: 7.3938 - mean_absolute_percentage_error: 22.9108 - val_loss: 6.2799 - val_mean_absolute_error: 6.4250 - val_root_mean_squared_error: 11.5657 - val_mean_absolute_percentage_error: 38.2557 - lr: 6.0000e-05
# Epoch 34/100
# 103/103 [==============================] - 14s 138ms/step - loss: 4.2226 - mean_absolute_error: 4.3636 - root_mean_squared_error: 7.1509 - mean_absolute_percentage_error: 20.9269 - val_loss: 7.0814 - val_mean_absolute_error: 7.2272 - val_root_mean_squared_error: 12.2231 - val_mean_absolute_percentage_error: 32.7722 - lr: 6.0000e-05
# Epoch 35/100
# 103/103 [==============================] - 14s 137ms/step - loss: 4.3558 - mean_absolute_error: 4.4999 - root_mean_squared_error: 7.3170 - mean_absolute_percentage_error: 21.8616 - val_loss: 9.2337 - val_mean_absolute_error: 9.3863 - val_root_mean_squared_error: 14.7700 - val_mean_absolute_percentage_error: 36.4359 - lr: 6.0000e-05
# Epoch 36/100
# 103/103 [==============================] - 14s 138ms/step - loss: 4.2421 - mean_absolute_error: 4.3885 - root_mean_squared_error: 6.8281 - mean_absolute_percentage_error: 20.9588 - val_loss: 9.1829 - val_mean_absolute_error: 9.3438 - val_root_mean_squared_error: 14.0182 - val_mean_absolute_percentage_error: 43.9573 - lr: 6.0000e-05
# Epoch 37/100
# 103/103 [==============================] - 14s 137ms/step - loss: 4.2052 - mean_absolute_error: 4.3526 - root_mean_squared_error: 6.8011 - mean_absolute_percentage_error: 20.6665 - val_loss: 6.1104 - val_mean_absolute_error: 6.2522 - val_root_mean_squared_error: 11.3288 - val_mean_absolute_percentage_error: 34.1433 - lr: 6.0000e-05
# Epoch 38/100
# 103/103 [==============================] - 14s 137ms/step - loss: 4.3964 - mean_absolute_error: 4.5424 - root_mean_squared_error: 7.2873 - mean_absolute_percentage_error: 21.7940 - val_loss: 6.5097 - val_mean_absolute_error: 6.6493 - val_root_mean_squared_error: 11.6498 - val_mean_absolute_percentage_error: 34.5566 - lr: 6.0000e-05
# Epoch 39/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.0615 - mean_absolute_error: 4.2069 - root_mean_squared_error: 6.6403 - mean_absolute_percentage_error: 20.2293 - val_loss: 7.0869 - val_mean_absolute_error: 7.2452 - val_root_mean_squared_error: 11.9598 - val_mean_absolute_percentage_error: 39.9571 - lr: 3.6000e-05
# Epoch 40/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.0142 - mean_absolute_error: 4.1591 - root_mean_squared_error: 6.6893 - mean_absolute_percentage_error: 19.9481 - val_loss: 5.8020 - val_mean_absolute_error: 5.9415 - val_root_mean_squared_error: 11.0475 - val_mean_absolute_percentage_error: 34.0373 - lr: 3.6000e-05
# Epoch 41/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.0100 - mean_absolute_error: 4.1538 - root_mean_squared_error: 6.6253 - mean_absolute_percentage_error: 19.5192 - val_loss: 5.8010 - val_mean_absolute_error: 5.9402 - val_root_mean_squared_error: 11.1046 - val_mean_absolute_percentage_error: 32.9547 - lr: 3.6000e-05
# Epoch 42/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.0476 - mean_absolute_error: 4.1905 - root_mean_squared_error: 6.6178 - mean_absolute_percentage_error: 20.2868 - val_loss: 8.2180 - val_mean_absolute_error: 8.3713 - val_root_mean_squared_error: 13.1163 - val_mean_absolute_percentage_error: 37.7368 - lr: 3.6000e-05
# Epoch 43/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.9427 - mean_absolute_error: 4.0859 - root_mean_squared_error: 6.6842 - mean_absolute_percentage_error: 20.0404 - val_loss: 7.8677 - val_mean_absolute_error: 8.0185 - val_root_mean_squared_error: 12.8478 - val_mean_absolute_percentage_error: 36.0218 - lr: 3.6000e-05
# Epoch 44/100
# 103/103 [==============================] - 15s 144ms/step - loss: 3.8962 - mean_absolute_error: 4.0447 - root_mean_squared_error: 6.1891 - mean_absolute_percentage_error: 20.6142 - val_loss: 6.3797 - val_mean_absolute_error: 6.5268 - val_root_mean_squared_error: 11.4744 - val_mean_absolute_percentage_error: 32.8089 - lr: 3.6000e-05
# Epoch 45/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.0601 - mean_absolute_error: 4.2074 - root_mean_squared_error: 6.8989 - mean_absolute_percentage_error: 20.6855 - val_loss: 5.7583 - val_mean_absolute_error: 5.8897 - val_root_mean_squared_error: 11.0149 - val_mean_absolute_percentage_error: 32.6839 - lr: 3.6000e-05
# Epoch 46/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.1334 - mean_absolute_error: 4.2815 - root_mean_squared_error: 7.0744 - mean_absolute_percentage_error: 19.3307 - val_loss: 5.9310 - val_mean_absolute_error: 6.0737 - val_root_mean_squared_error: 11.1945 - val_mean_absolute_percentage_error: 33.6180 - lr: 3.6000e-05
# Epoch 47/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.0218 - mean_absolute_error: 4.1653 - root_mean_squared_error: 6.6091 - mean_absolute_percentage_error: 20.8317 - val_loss: 8.2389 - val_mean_absolute_error: 8.3930 - val_root_mean_squared_error: 13.1417 - val_mean_absolute_percentage_error: 38.3313 - lr: 3.6000e-05
# Epoch 48/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.9848 - mean_absolute_error: 4.1319 - root_mean_squared_error: 6.4884 - mean_absolute_percentage_error: 19.8659 - val_loss: 6.2995 - val_mean_absolute_error: 6.4559 - val_root_mean_squared_error: 11.3252 - val_mean_absolute_percentage_error: 34.1655 - lr: 3.6000e-05
# Epoch 49/100
# 103/103 [==============================] - 14s 141ms/step - loss: 3.7759 - mean_absolute_error: 3.9194 - root_mean_squared_error: 6.0965 - mean_absolute_percentage_error: 18.3237 - val_loss: 6.1721 - val_mean_absolute_error: 6.3223 - val_root_mean_squared_error: 11.3459 - val_mean_absolute_percentage_error: 36.4948 - lr: 3.6000e-05
# Epoch 50/100
# 103/103 [==============================] - 14s 139ms/step - loss: 4.0114 - mean_absolute_error: 4.1601 - root_mean_squared_error: 6.5586 - mean_absolute_percentage_error: 20.9357 - val_loss: 6.2209 - val_mean_absolute_error: 6.3727 - val_root_mean_squared_error: 11.1849 - val_mean_absolute_percentage_error: 37.8586 - lr: 3.6000e-05
# Epoch 51/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.9509 - mean_absolute_error: 4.0972 - root_mean_squared_error: 6.5736 - mean_absolute_percentage_error: 19.7382 - val_loss: 5.7564 - val_mean_absolute_error: 5.9040 - val_root_mean_squared_error: 10.9229 - val_mean_absolute_percentage_error: 32.7122 - lr: 3.6000e-05
# Epoch 52/100
# 103/103 [==============================] - 15s 141ms/step - loss: 3.7997 - mean_absolute_error: 3.9463 - root_mean_squared_error: 6.4371 - mean_absolute_percentage_error: 18.9566 - val_loss: 6.3877 - val_mean_absolute_error: 6.5532 - val_root_mean_squared_error: 11.2406 - val_mean_absolute_percentage_error: 36.0337 - lr: 3.6000e-05
# Epoch 53/100
# 103/103 [==============================] - 15s 144ms/step - loss: 3.8022 - mean_absolute_error: 3.9496 - root_mean_squared_error: 6.1001 - mean_absolute_percentage_error: 19.0826 - val_loss: 5.6069 - val_mean_absolute_error: 5.7456 - val_root_mean_squared_error: 10.8910 - val_mean_absolute_percentage_error: 33.6303 - lr: 3.6000e-05
# Epoch 54/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8316 - mean_absolute_error: 3.9750 - root_mean_squared_error: 6.5356 - mean_absolute_percentage_error: 18.3839 - val_loss: 8.1611 - val_mean_absolute_error: 8.3089 - val_root_mean_squared_error: 13.2534 - val_mean_absolute_percentage_error: 35.5298 - lr: 3.6000e-05
# Epoch 55/100
# 103/103 [==============================] - 14s 140ms/step - loss: 3.7965 - mean_absolute_error: 3.9447 - root_mean_squared_error: 6.3207 - mean_absolute_percentage_error: 18.0079 - val_loss: 7.7313 - val_mean_absolute_error: 7.8790 - val_root_mean_squared_error: 12.6664 - val_mean_absolute_percentage_error: 35.6672 - lr: 3.6000e-05
# Epoch 56/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.7385 - mean_absolute_error: 3.8817 - root_mean_squared_error: 6.1242 - mean_absolute_percentage_error: 18.3973 - val_loss: 5.5451 - val_mean_absolute_error: 5.6749 - val_root_mean_squared_error: 10.8325 - val_mean_absolute_percentage_error: 33.1654 - lr: 3.6000e-05
# Epoch 57/100
# 103/103 [==============================] - 15s 147ms/step - loss: 3.8529 - mean_absolute_error: 4.0020 - root_mean_squared_error: 6.2729 - mean_absolute_percentage_error: 19.2431 - val_loss: 7.4239 - val_mean_absolute_error: 7.5726 - val_root_mean_squared_error: 12.2715 - val_mean_absolute_percentage_error: 35.9544 - lr: 3.6000e-05
# Epoch 58/100
# 103/103 [==============================] - 14s 141ms/step - loss: 3.7593 - mean_absolute_error: 3.9071 - root_mean_squared_error: 6.1228 - mean_absolute_percentage_error: 18.9917 - val_loss: 5.8344 - val_mean_absolute_error: 5.9851 - val_root_mean_squared_error: 11.0083 - val_mean_absolute_percentage_error: 33.3213 - lr: 3.6000e-05
# Epoch 59/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.6979 - mean_absolute_error: 3.8423 - root_mean_squared_error: 6.1929 - mean_absolute_percentage_error: 17.6336 - val_loss: 5.7403 - val_mean_absolute_error: 5.8883 - val_root_mean_squared_error: 10.9569 - val_mean_absolute_percentage_error: 34.5726 - lr: 3.6000e-05
# Epoch 60/100
# 103/103 [==============================] - 15s 141ms/step - loss: 3.6489 - mean_absolute_error: 3.7964 - root_mean_squared_error: 5.9474 - mean_absolute_percentage_error: 18.7662 - val_loss: 5.8263 - val_mean_absolute_error: 5.9703 - val_root_mean_squared_error: 11.0109 - val_mean_absolute_percentage_error: 34.0333 - lr: 3.6000e-05
# Epoch 61/100
# 103/103 [==============================] - 14s 138ms/step - loss: 3.6885 - mean_absolute_error: 3.8332 - root_mean_squared_error: 6.1363 - mean_absolute_percentage_error: 19.1528 - val_loss: 6.0812 - val_mean_absolute_error: 6.2196 - val_root_mean_squared_error: 11.2634 - val_mean_absolute_percentage_error: 32.5865 - lr: 3.6000e-05
# Epoch 62/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.6871 - mean_absolute_error: 3.8361 - root_mean_squared_error: 6.0060 - mean_absolute_percentage_error: 19.4613 - val_loss: 6.8029 - val_mean_absolute_error: 6.9599 - val_root_mean_squared_error: 11.8623 - val_mean_absolute_percentage_error: 36.8867 - lr: 3.6000e-05
# Epoch 63/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.8666 - mean_absolute_error: 4.0136 - root_mean_squared_error: 6.5422 - mean_absolute_percentage_error: 19.7737 - val_loss: 7.6706 - val_mean_absolute_error: 7.8184 - val_root_mean_squared_error: 12.5990 - val_mean_absolute_percentage_error: 35.7930 - lr: 3.6000e-05
# Epoch 64/100
# 103/103 [==============================] - 14s 140ms/step - loss: 3.6971 - mean_absolute_error: 3.8440 - root_mean_squared_error: 6.0730 - mean_absolute_percentage_error: 19.1003 - val_loss: 5.9034 - val_mean_absolute_error: 6.0666 - val_root_mean_squared_error: 10.8895 - val_mean_absolute_percentage_error: 34.1255 - lr: 2.1600e-05
# Epoch 65/100
# 103/103 [==============================] - 15s 144ms/step - loss: 3.8488 - mean_absolute_error: 3.9977 - root_mean_squared_error: 6.2586 - mean_absolute_percentage_error: 19.3686 - val_loss: 5.9604 - val_mean_absolute_error: 6.1123 - val_root_mean_squared_error: 11.1677 - val_mean_absolute_percentage_error: 35.7027 - lr: 2.1600e-05
# Epoch 66/100
# 103/103 [==============================] - 14s 141ms/step - loss: 3.6436 - mean_absolute_error: 3.7949 - root_mean_squared_error: 5.9249 - mean_absolute_percentage_error: 19.2757 - val_loss: 6.4116 - val_mean_absolute_error: 6.5646 - val_root_mean_squared_error: 11.4470 - val_mean_absolute_percentage_error: 33.6974 - lr: 2.1600e-05
# Epoch 67/100
# 103/103 [==============================] - 14s 140ms/step - loss: 3.6610 - mean_absolute_error: 3.8092 - root_mean_squared_error: 5.9167 - mean_absolute_percentage_error: 19.0507 - val_loss: 5.9324 - val_mean_absolute_error: 6.0930 - val_root_mean_squared_error: 11.0824 - val_mean_absolute_percentage_error: 35.5813 - lr: 2.1600e-05
# Epoch 68/100
# 103/103 [==============================] - 14s 140ms/step - loss: 3.5398 - mean_absolute_error: 3.6870 - root_mean_squared_error: 5.7670 - mean_absolute_percentage_error: 17.9699 - val_loss: 5.5888 - val_mean_absolute_error: 5.7275 - val_root_mean_squared_error: 10.8400 - val_mean_absolute_percentage_error: 33.1892 - lr: 2.1600e-05
# Epoch 69/100
# 103/103 [==============================] - 14s 137ms/step - loss: 3.5548 - mean_absolute_error: 3.7034 - root_mean_squared_error: 5.7373 - mean_absolute_percentage_error: 18.6378 - val_loss: 7.1913 - val_mean_absolute_error: 7.3515 - val_root_mean_squared_error: 12.0379 - val_mean_absolute_percentage_error: 33.8211 - lr: 2.1600e-05
# Epoch 70/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.5619 - mean_absolute_error: 3.7100 - root_mean_squared_error: 5.7339 - mean_absolute_percentage_error: 18.0804 - val_loss: 6.3109 - val_mean_absolute_error: 6.4557 - val_root_mean_squared_error: 11.4197 - val_mean_absolute_percentage_error: 32.4637 - lr: 2.1600e-05
# Epoch 71/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.5102 - mean_absolute_error: 3.6559 - root_mean_squared_error: 5.7530 - mean_absolute_percentage_error: 17.6226 - val_loss: 5.5887 - val_mean_absolute_error: 5.7427 - val_root_mean_squared_error: 10.8514 - val_mean_absolute_percentage_error: 33.0913 - lr: 1.2960e-05

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 59ms/step - loss: 5.5451 - mean_absolute_error: 5.6749 - root_mean_squared_error: 10.8325 - mean_absolute_percentage_error: 33.1654
# Model Loss: [5.545112133026123, 5.67493200302124, 10.832520484924316, 33.165374755859375]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 678ms/step
# Predicted Putusan: [11.277099]

# %%
model_scenario_name = "BiLSTM_14"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_14\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_14\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_14"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 639ms/step
# Predicted Putusan: [11.277099]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
