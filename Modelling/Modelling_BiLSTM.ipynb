# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_32360\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=256 
)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output = tf.keras.layers.BatchNormalization()(lstm_output)

lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_2 = tf.keras.layers.BatchNormalization()(lstm_output_2)

lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
lstm_output_3 = tf.keras.layers.BatchNormalization()(lstm_output_3)

pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical = tf.keras.layers.BatchNormalization()(numerical_input)
numerical_dense = tf.keras.layers.Dense(32, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding[0][0]']
#  batch_normalization (BatchNorm  (None, 1024, 64)    256         ['bidirectional[0][0]']
#  alization)
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['batch_normalization[0][0]']
#  )
#
#  batch_normalization_1 (BatchNo  (None, 1024, 128)   512         ['bidirectional_1[0][0]']
#  rmalization)
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['batch_normalization_1[0][0]']
#  )
#
#  batch_normalization_3 (BatchNo  (None, 5)           20          ['numerical_input[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 1024, 64)    256         ['bidirectional_2[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 32)           192         ['batch_normalization_3[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['batch_normalization_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96)          384         ['concatenate[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,893,045
# Trainable params: 4,892,331
# Non-trainable params: 714
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 36s 291ms/step - loss: 34.2792 - mean_absolute_error: 33.9040 - root_mean_squared_error: 46.3718 - mean_absolute_percentage_error: 96.0900 - val_loss: 35.5346 - val_mean_absolute_error: 35.1795 - val_root_mean_squared_error: 48.4609 - val_mean_absolute_percentage_error: 90.6847 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 29s 279ms/step - loss: 31.3679 - mean_absolute_error: 31.0302 - root_mean_squared_error: 43.7030 - mean_absolute_percentage_error: 81.7890 - val_loss: 32.1725 - val_mean_absolute_error: 31.8499 - val_root_mean_squared_error: 45.8228 - val_mean_absolute_percentage_error: 75.0600 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 28s 272ms/step - loss: 25.3058 - mean_absolute_error: 24.9930 - root_mean_squared_error: 37.0972 - mean_absolute_percentage_error: 64.0115 - val_loss: 28.0774 - val_mean_absolute_error: 27.7811 - val_root_mean_squared_error: 41.5777 - val_mean_absolute_percentage_error: 66.5609 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 28s 272ms/step - loss: 17.3816 - mean_absolute_error: 17.0909 - root_mean_squared_error: 26.5247 - mean_absolute_percentage_error: 58.9374 - val_loss: 21.0644 - val_mean_absolute_error: 20.7827 - val_root_mean_squared_error: 31.3280 - val_mean_absolute_percentage_error: 61.4423 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 28s 272ms/step - loss: 11.3222 - mean_absolute_error: 11.0438 - root_mean_squared_error: 17.3383 - mean_absolute_percentage_error: 52.5935 - val_loss: 15.4357 - val_mean_absolute_error: 15.1628 - val_root_mean_squared_error: 23.1242 - val_mean_absolute_percentage_error: 60.7587 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 28s 273ms/step - loss: 10.4577 - mean_absolute_error: 10.1839 - root_mean_squared_error: 15.8497 - mean_absolute_percentage_error: 48.9444 - val_loss: 12.1117 - val_mean_absolute_error: 11.8454 - val_root_mean_squared_error: 18.5585 - val_mean_absolute_percentage_error: 43.9272 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 28s 273ms/step - loss: 9.1103 - mean_absolute_error: 8.8394 - root_mean_squared_error: 14.1533 - mean_absolute_percentage_error: 43.5169 - val_loss: 9.6609 - val_mean_absolute_error: 9.3961 - val_root_mean_squared_error: 15.5734 - val_mean_absolute_percentage_error: 52.0155 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 28s 272ms/step - loss: 8.4619 - mean_absolute_error: 8.1919 - root_mean_squared_error: 13.2679 - mean_absolute_percentage_error: 39.8023 - val_loss: 8.9238 - val_mean_absolute_error: 8.6659 - val_root_mean_squared_error: 13.9697 - val_mean_absolute_percentage_error: 42.0732 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 28s 272ms/step - loss: 8.2234 - mean_absolute_error: 7.9583 - root_mean_squared_error: 12.7213 - mean_absolute_percentage_error: 38.2143 - val_loss: 8.7130 - val_mean_absolute_error: 8.4545 - val_root_mean_squared_error: 14.2211 - val_mean_absolute_percentage_error: 39.0383 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 28s 272ms/step - loss: 7.6517 - mean_absolute_error: 7.3878 - root_mean_squared_error: 11.9863 - mean_absolute_percentage_error: 35.7296 - val_loss: 8.4019 - val_mean_absolute_error: 8.1483 - val_root_mean_squared_error: 13.3339 - val_mean_absolute_percentage_error: 43.4712 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 28s 272ms/step - loss: 7.5970 - mean_absolute_error: 7.3344 - root_mean_squared_error: 12.1053 - mean_absolute_percentage_error: 34.0457 - val_loss: 7.6361 - val_mean_absolute_error: 7.3698 - val_root_mean_squared_error: 12.8366 - val_mean_absolute_percentage_error: 38.2398 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 28s 271ms/step - loss: 7.0895 - mean_absolute_error: 6.8310 - root_mean_squared_error: 10.7738 - mean_absolute_percentage_error: 32.4288 - val_loss: 9.0565 - val_mean_absolute_error: 8.8015 - val_root_mean_squared_error: 14.5494 - val_mean_absolute_percentage_error: 38.8131 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 28s 271ms/step - loss: 6.9842 - mean_absolute_error: 6.7292 - root_mean_squared_error: 11.1569 - mean_absolute_percentage_error: 31.9082 - val_loss: 9.1870 - val_mean_absolute_error: 8.9417 - val_root_mean_squared_error: 13.4080 - val_mean_absolute_percentage_error: 55.9846 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 28s 274ms/step - loss: 6.4239 - mean_absolute_error: 6.1711 - root_mean_squared_error: 10.1840 - mean_absolute_percentage_error: 28.4391 - val_loss: 8.1440 - val_mean_absolute_error: 7.8976 - val_root_mean_squared_error: 13.2073 - val_mean_absolute_percentage_error: 38.0181 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 28s 275ms/step - loss: 6.3064 - mean_absolute_error: 6.0534 - root_mean_squared_error: 9.9023 - mean_absolute_percentage_error: 28.1790 - val_loss: 7.1823 - val_mean_absolute_error: 6.9261 - val_root_mean_squared_error: 12.5361 - val_mean_absolute_percentage_error: 35.0429 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 28s 275ms/step - loss: 6.0998 - mean_absolute_error: 5.8485 - root_mean_squared_error: 9.7246 - mean_absolute_percentage_error: 27.8825 - val_loss: 7.4334 - val_mean_absolute_error: 7.1875 - val_root_mean_squared_error: 12.1038 - val_mean_absolute_percentage_error: 41.3833 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 28s 272ms/step - loss: 6.2522 - mean_absolute_error: 6.0068 - root_mean_squared_error: 9.4563 - mean_absolute_percentage_error: 29.2579 - val_loss: 11.3083 - val_mean_absolute_error: 11.0786 - val_root_mean_squared_error: 16.6298 - val_mean_absolute_percentage_error: 47.1890 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 28s 271ms/step - loss: 5.8950 - mean_absolute_error: 5.6510 - root_mean_squared_error: 9.1179 - mean_absolute_percentage_error: 26.3533 - val_loss: 7.2281 - val_mean_absolute_error: 6.9788 - val_root_mean_squared_error: 12.5977 - val_mean_absolute_percentage_error: 33.2145 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 28s 271ms/step - loss: 5.8286 - mean_absolute_error: 5.5833 - root_mean_squared_error: 8.8924 - mean_absolute_percentage_error: 26.6970 - val_loss: 8.3616 - val_mean_absolute_error: 8.1248 - val_root_mean_squared_error: 13.0224 - val_mean_absolute_percentage_error: 40.5463 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 28s 273ms/step - loss: 5.7009 - mean_absolute_error: 5.4558 - root_mean_squared_error: 8.7641 - mean_absolute_percentage_error: 25.9559 - val_loss: 7.6417 - val_mean_absolute_error: 7.4118 - val_root_mean_squared_error: 12.3463 - val_mean_absolute_percentage_error: 34.2942 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 28s 274ms/step - loss: 5.3877 - mean_absolute_error: 5.1460 - root_mean_squared_error: 8.4412 - mean_absolute_percentage_error: 23.7855 - val_loss: 9.4758 - val_mean_absolute_error: 9.2494 - val_root_mean_squared_error: 14.3761 - val_mean_absolute_percentage_error: 43.0842 - lr: 5.0000e-05
# Epoch 22/100
# 103/103 [==============================] - 28s 272ms/step - loss: 5.5637 - mean_absolute_error: 5.3247 - root_mean_squared_error: 8.6604 - mean_absolute_percentage_error: 25.0839 - val_loss: 14.2382 - val_mean_absolute_error: 14.0226 - val_root_mean_squared_error: 19.8153 - val_mean_absolute_percentage_error: 58.4322 - lr: 5.0000e-05
# Epoch 23/100
# 103/103 [==============================] - 28s 273ms/step - loss: 5.2687 - mean_absolute_error: 5.0245 - root_mean_squared_error: 8.1930 - mean_absolute_percentage_error: 23.1913 - val_loss: 8.2104 - val_mean_absolute_error: 7.9800 - val_root_mean_squared_error: 12.8141 - val_mean_absolute_percentage_error: 40.4247 - lr: 5.0000e-05
# Epoch 24/100
# 103/103 [==============================] - 28s 273ms/step - loss: 5.2608 - mean_absolute_error: 5.0195 - root_mean_squared_error: 7.9786 - mean_absolute_percentage_error: 23.5791 - val_loss: 8.4073 - val_mean_absolute_error: 8.1740 - val_root_mean_squared_error: 13.2366 - val_mean_absolute_percentage_error: 37.9935 - lr: 5.0000e-05
# Epoch 25/100
# 103/103 [==============================] - 28s 272ms/step - loss: 5.2099 - mean_absolute_error: 4.9727 - root_mean_squared_error: 7.8763 - mean_absolute_percentage_error: 23.7342 - val_loss: 7.5146 - val_mean_absolute_error: 7.2714 - val_root_mean_squared_error: 12.1749 - val_mean_absolute_percentage_error: 31.2499 - lr: 5.0000e-05
# Epoch 26/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.9954 - mean_absolute_error: 4.7576 - root_mean_squared_error: 7.6415 - mean_absolute_percentage_error: 22.0627 - val_loss: 6.4489 - val_mean_absolute_error: 6.2177 - val_root_mean_squared_error: 10.9465 - val_mean_absolute_percentage_error: 32.6217 - lr: 2.5000e-05
# Epoch 27/100
# 103/103 [==============================] - 28s 274ms/step - loss: 5.1163 - mean_absolute_error: 4.8817 - root_mean_squared_error: 7.7856 - mean_absolute_percentage_error: 23.4459 - val_loss: 7.2111 - val_mean_absolute_error: 6.9778 - val_root_mean_squared_error: 11.6041 - val_mean_absolute_percentage_error: 34.7497 - lr: 2.5000e-05
# Epoch 28/100
# 103/103 [==============================] - 28s 273ms/step - loss: 5.0616 - mean_absolute_error: 4.8243 - root_mean_squared_error: 7.5978 - mean_absolute_percentage_error: 22.8405 - val_loss: 6.0984 - val_mean_absolute_error: 5.8576 - val_root_mean_squared_error: 10.6052 - val_mean_absolute_percentage_error: 31.9950 - lr: 2.5000e-05
# Epoch 29/100
# 103/103 [==============================] - 28s 273ms/step - loss: 5.0417 - mean_absolute_error: 4.8088 - root_mean_squared_error: 7.5013 - mean_absolute_percentage_error: 24.0016 - val_loss: 7.1286 - val_mean_absolute_error: 6.8873 - val_root_mean_squared_error: 11.6318 - val_mean_absolute_percentage_error: 31.5759 - lr: 2.5000e-05
# Epoch 30/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.8611 - mean_absolute_error: 4.6238 - root_mean_squared_error: 7.3237 - mean_absolute_percentage_error: 21.7241 - val_loss: 6.2607 - val_mean_absolute_error: 6.0280 - val_root_mean_squared_error: 10.8039 - val_mean_absolute_percentage_error: 31.8543 - lr: 2.5000e-05
# Epoch 31/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.9663 - mean_absolute_error: 4.7299 - root_mean_squared_error: 7.7280 - mean_absolute_percentage_error: 21.0183 - val_loss: 6.2155 - val_mean_absolute_error: 5.9856 - val_root_mean_squared_error: 10.7754 - val_mean_absolute_percentage_error: 31.9956 - lr: 2.5000e-05
# Epoch 32/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.9927 - mean_absolute_error: 4.7557 - root_mean_squared_error: 7.8134 - mean_absolute_percentage_error: 21.4526 - val_loss: 6.7832 - val_mean_absolute_error: 6.5398 - val_root_mean_squared_error: 11.3952 - val_mean_absolute_percentage_error: 31.6515 - lr: 2.5000e-05
# Epoch 33/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.7514 - mean_absolute_error: 4.5186 - root_mean_squared_error: 7.1849 - mean_absolute_percentage_error: 21.4772 - val_loss: 6.0333 - val_mean_absolute_error: 5.7873 - val_root_mean_squared_error: 10.5711 - val_mean_absolute_percentage_error: 30.7726 - lr: 2.5000e-05
# Epoch 34/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.7072 - mean_absolute_error: 4.4725 - root_mean_squared_error: 7.2156 - mean_absolute_percentage_error: 20.8180 - val_loss: 6.4142 - val_mean_absolute_error: 6.1690 - val_root_mean_squared_error: 10.8728 - val_mean_absolute_percentage_error: 31.1590 - lr: 2.5000e-05
# Epoch 35/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.7027 - mean_absolute_error: 4.4685 - root_mean_squared_error: 7.0197 - mean_absolute_percentage_error: 20.3600 - val_loss: 6.9067 - val_mean_absolute_error: 6.6632 - val_root_mean_squared_error: 11.3924 - val_mean_absolute_percentage_error: 31.1470 - lr: 2.5000e-05
# Epoch 36/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.5743 - mean_absolute_error: 4.3420 - root_mean_squared_error: 6.7501 - mean_absolute_percentage_error: 20.6468 - val_loss: 6.0835 - val_mean_absolute_error: 5.8508 - val_root_mean_squared_error: 10.5553 - val_mean_absolute_percentage_error: 32.1341 - lr: 2.5000e-05
# Epoch 37/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.6795 - mean_absolute_error: 4.4427 - root_mean_squared_error: 7.0292 - mean_absolute_percentage_error: 20.6836 - val_loss: 6.1643 - val_mean_absolute_error: 5.9278 - val_root_mean_squared_error: 10.6699 - val_mean_absolute_percentage_error: 31.8713 - lr: 2.5000e-05
# Epoch 38/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.5648 - mean_absolute_error: 4.3276 - root_mean_squared_error: 6.8217 - mean_absolute_percentage_error: 20.3587 - val_loss: 6.0863 - val_mean_absolute_error: 5.8627 - val_root_mean_squared_error: 10.4780 - val_mean_absolute_percentage_error: 32.1592 - lr: 2.5000e-05
# Epoch 39/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.6343 - mean_absolute_error: 4.4038 - root_mean_squared_error: 6.8973 - mean_absolute_percentage_error: 21.6197 - val_loss: 6.0187 - val_mean_absolute_error: 5.7915 - val_root_mean_squared_error: 10.4547 - val_mean_absolute_percentage_error: 31.6789 - lr: 1.2500e-05
# Epoch 40/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.4991 - mean_absolute_error: 4.2659 - root_mean_squared_error: 6.8836 - mean_absolute_percentage_error: 20.1820 - val_loss: 5.8211 - val_mean_absolute_error: 5.5796 - val_root_mean_squared_error: 10.3236 - val_mean_absolute_percentage_error: 30.7754 - lr: 1.2500e-05
# Epoch 41/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.5641 - mean_absolute_error: 4.3311 - root_mean_squared_error: 7.0434 - mean_absolute_percentage_error: 21.1227 - val_loss: 6.3022 - val_mean_absolute_error: 6.0754 - val_root_mean_squared_error: 10.6304 - val_mean_absolute_percentage_error: 32.8262 - lr: 1.2500e-05
# Epoch 42/100
# 103/103 [==============================] - 28s 276ms/step - loss: 4.4913 - mean_absolute_error: 4.2555 - root_mean_squared_error: 6.8613 - mean_absolute_percentage_error: 19.6114 - val_loss: 6.5333 - val_mean_absolute_error: 6.3086 - val_root_mean_squared_error: 10.8788 - val_mean_absolute_percentage_error: 33.7114 - lr: 1.2500e-05
# Epoch 43/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.4959 - mean_absolute_error: 4.2608 - root_mean_squared_error: 6.8968 - mean_absolute_percentage_error: 20.3832 - val_loss: 6.0120 - val_mean_absolute_error: 5.7795 - val_root_mean_squared_error: 10.4022 - val_mean_absolute_percentage_error: 31.0732 - lr: 1.2500e-05
# Epoch 44/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.4700 - mean_absolute_error: 4.2353 - root_mean_squared_error: 6.6581 - mean_absolute_percentage_error: 20.0625 - val_loss: 6.0601 - val_mean_absolute_error: 5.8279 - val_root_mean_squared_error: 10.5960 - val_mean_absolute_percentage_error: 31.2092 - lr: 1.2500e-05
# Epoch 45/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.5002 - mean_absolute_error: 4.2668 - root_mean_squared_error: 6.8381 - mean_absolute_percentage_error: 19.6047 - val_loss: 7.0580 - val_mean_absolute_error: 6.8421 - val_root_mean_squared_error: 11.1954 - val_mean_absolute_percentage_error: 35.4525 - lr: 1.2500e-05
# Epoch 46/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.3108 - mean_absolute_error: 4.0743 - root_mean_squared_error: 6.4884 - mean_absolute_percentage_error: 19.3886 - val_loss: 5.8348 - val_mean_absolute_error: 5.6038 - val_root_mean_squared_error: 10.3737 - val_mean_absolute_percentage_error: 31.9190 - lr: 6.2500e-06
# Epoch 47/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.3284 - mean_absolute_error: 4.0947 - root_mean_squared_error: 6.5539 - mean_absolute_percentage_error: 19.7744 - val_loss: 5.9052 - val_mean_absolute_error: 5.6760 - val_root_mean_squared_error: 10.4035 - val_mean_absolute_percentage_error: 31.2515 - lr: 6.2500e-06
# Epoch 48/100
# 103/103 [==============================] - 28s 270ms/step - loss: 4.4290 - mean_absolute_error: 4.1944 - root_mean_squared_error: 6.6909 - mean_absolute_percentage_error: 20.2568 - val_loss: 5.9534 - val_mean_absolute_error: 5.7188 - val_root_mean_squared_error: 10.4694 - val_mean_absolute_percentage_error: 30.9318 - lr: 6.2500e-06
# Epoch 49/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.1659 - mean_absolute_error: 3.9318 - root_mean_squared_error: 6.2284 - mean_absolute_percentage_error: 19.4163 - val_loss: 5.8892 - val_mean_absolute_error: 5.6650 - val_root_mean_squared_error: 10.3422 - val_mean_absolute_percentage_error: 31.8413 - lr: 6.2500e-06
# Epoch 50/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4027 - mean_absolute_error: 4.1662 - root_mean_squared_error: 6.6806 - mean_absolute_percentage_error: 19.4406 - val_loss: 5.8266 - val_mean_absolute_error: 5.5883 - val_root_mean_squared_error: 10.3152 - val_mean_absolute_percentage_error: 30.5834 - lr: 6.2500e-06
# Epoch 51/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.3890 - mean_absolute_error: 4.1588 - root_mean_squared_error: 6.5781 - mean_absolute_percentage_error: 19.8948 - val_loss: 5.7799 - val_mean_absolute_error: 5.5489 - val_root_mean_squared_error: 10.2707 - val_mean_absolute_percentage_error: 31.0925 - lr: 3.1250e-06
# Epoch 52/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.5047 - mean_absolute_error: 4.2730 - root_mean_squared_error: 6.6302 - mean_absolute_percentage_error: 19.8679 - val_loss: 5.8017 - val_mean_absolute_error: 5.5738 - val_root_mean_squared_error: 10.2664 - val_mean_absolute_percentage_error: 31.1291 - lr: 3.1250e-06
# Epoch 53/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.3604 - mean_absolute_error: 4.1279 - root_mean_squared_error: 6.6040 - mean_absolute_percentage_error: 19.6590 - val_loss: 5.8346 - val_mean_absolute_error: 5.6109 - val_root_mean_squared_error: 10.3537 - val_mean_absolute_percentage_error: 31.4208 - lr: 3.1250e-06
# Epoch 54/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4590 - mean_absolute_error: 4.2237 - root_mean_squared_error: 6.6589 - mean_absolute_percentage_error: 19.6024 - val_loss: 5.7924 - val_mean_absolute_error: 5.5671 - val_root_mean_squared_error: 10.2941 - val_mean_absolute_percentage_error: 31.4485 - lr: 3.1250e-06
# Epoch 55/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.3868 - mean_absolute_error: 4.1530 - root_mean_squared_error: 6.5770 - mean_absolute_percentage_error: 19.8304 - val_loss: 5.8074 - val_mean_absolute_error: 5.5822 - val_root_mean_squared_error: 10.3044 - val_mean_absolute_percentage_error: 31.2366 - lr: 3.1250e-06
# Epoch 56/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.2847 - mean_absolute_error: 4.0528 - root_mean_squared_error: 6.4228 - mean_absolute_percentage_error: 19.1196 - val_loss: 5.8507 - val_mean_absolute_error: 5.6193 - val_root_mean_squared_error: 10.3529 - val_mean_absolute_percentage_error: 30.8223 - lr: 3.1250e-06
# Epoch 57/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.2426 - mean_absolute_error: 4.0090 - root_mean_squared_error: 6.4154 - mean_absolute_percentage_error: 18.0174 - val_loss: 5.7540 - val_mean_absolute_error: 5.5217 - val_root_mean_squared_error: 10.2815 - val_mean_absolute_percentage_error: 30.9819 - lr: 1.5625e-06
# Epoch 58/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3213 - mean_absolute_error: 4.0878 - root_mean_squared_error: 6.4373 - mean_absolute_percentage_error: 19.5478 - val_loss: 5.8013 - val_mean_absolute_error: 5.5734 - val_root_mean_squared_error: 10.3261 - val_mean_absolute_percentage_error: 31.2062 - lr: 1.5625e-06
# Epoch 59/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.3495 - mean_absolute_error: 4.1146 - root_mean_squared_error: 6.6752 - mean_absolute_percentage_error: 19.2768 - val_loss: 5.7948 - val_mean_absolute_error: 5.5712 - val_root_mean_squared_error: 10.2706 - val_mean_absolute_percentage_error: 31.5779 - lr: 1.5625e-06
# Epoch 60/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.5279 - mean_absolute_error: 4.2931 - root_mean_squared_error: 6.6988 - mean_absolute_percentage_error: 20.0800 - val_loss: 5.8854 - val_mean_absolute_error: 5.6648 - val_root_mean_squared_error: 10.3252 - val_mean_absolute_percentage_error: 31.6070 - lr: 1.5625e-06
# Epoch 61/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.2015 - mean_absolute_error: 3.9673 - root_mean_squared_error: 6.2385 - mean_absolute_percentage_error: 19.1495 - val_loss: 5.8463 - val_mean_absolute_error: 5.6241 - val_root_mean_squared_error: 10.3281 - val_mean_absolute_percentage_error: 31.4320 - lr: 1.5625e-06
# Epoch 62/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.2016 - mean_absolute_error: 3.9687 - root_mean_squared_error: 6.1962 - mean_absolute_percentage_error: 19.0622 - val_loss: 5.7850 - val_mean_absolute_error: 5.5601 - val_root_mean_squared_error: 10.2796 - val_mean_absolute_percentage_error: 31.3065 - lr: 1.5625e-06
# Epoch 63/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.4859 - mean_absolute_error: 4.2526 - root_mean_squared_error: 6.8571 - mean_absolute_percentage_error: 19.2990 - val_loss: 5.8118 - val_mean_absolute_error: 5.5894 - val_root_mean_squared_error: 10.2745 - val_mean_absolute_percentage_error: 31.5494 - lr: 7.8125e-07
# Epoch 64/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.3676 - mean_absolute_error: 4.1375 - root_mean_squared_error: 6.5242 - mean_absolute_percentage_error: 20.0678 - val_loss: 5.8272 - val_mean_absolute_error: 5.6054 - val_root_mean_squared_error: 10.2939 - val_mean_absolute_percentage_error: 31.5926 - lr: 7.8125e-07
# Epoch 65/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.2591 - mean_absolute_error: 4.0275 - root_mean_squared_error: 6.4150 - mean_absolute_percentage_error: 19.5148 - val_loss: 5.7923 - val_mean_absolute_error: 5.5688 - val_root_mean_squared_error: 10.2605 - val_mean_absolute_percentage_error: 31.5999 - lr: 7.8125e-07
# Epoch 66/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.2691 - mean_absolute_error: 4.0391 - root_mean_squared_error: 6.4645 - mean_absolute_percentage_error: 19.2001 - val_loss: 5.8083 - val_mean_absolute_error: 5.5863 - val_root_mean_squared_error: 10.2663 - val_mean_absolute_percentage_error: 31.6196 - lr: 7.8125e-07
# Epoch 67/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.3317 - mean_absolute_error: 4.1008 - root_mean_squared_error: 6.4852 - mean_absolute_percentage_error: 19.0970 - val_loss: 5.7949 - val_mean_absolute_error: 5.5714 - val_root_mean_squared_error: 10.2806 - val_mean_absolute_percentage_error: 31.3443 - lr: 7.8125e-07
# Epoch 68/100
# 103/103 [==============================] - 29s 279ms/step - loss: 4.2806 - mean_absolute_error: 4.0476 - root_mean_squared_error: 6.3852 - mean_absolute_percentage_error: 18.9327 - val_loss: 5.8052 - val_mean_absolute_error: 5.5822 - val_root_mean_squared_error: 10.2846 - val_mean_absolute_percentage_error: 31.4677 - lr: 3.9062e-07
# Epoch 69/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.3862 - mean_absolute_error: 4.1524 - root_mean_squared_error: 6.6321 - mean_absolute_percentage_error: 19.0333 - val_loss: 5.8010 - val_mean_absolute_error: 5.5789 - val_root_mean_squared_error: 10.2718 - val_mean_absolute_percentage_error: 31.4940 - lr: 3.9062e-07
# Epoch 70/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3709 - mean_absolute_error: 4.1349 - root_mean_squared_error: 6.7601 - mean_absolute_percentage_error: 18.8594 - val_loss: 5.7748 - val_mean_absolute_error: 5.5507 - val_root_mean_squared_error: 10.2491 - val_mean_absolute_percentage_error: 31.3493 - lr: 3.9062e-07
# Epoch 71/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.2435 - mean_absolute_error: 4.0115 - root_mean_squared_error: 6.4381 - mean_absolute_percentage_error: 19.2434 - val_loss: 5.7816 - val_mean_absolute_error: 5.5588 - val_root_mean_squared_error: 10.2512 - val_mean_absolute_percentage_error: 31.3840 - lr: 3.9062e-07
# Epoch 72/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.4147 - mean_absolute_error: 4.1818 - root_mean_squared_error: 6.5996 - mean_absolute_percentage_error: 19.4518 - val_loss: 5.7791 - val_mean_absolute_error: 5.5558 - val_root_mean_squared_error: 10.2551 - val_mean_absolute_percentage_error: 31.2769 - lr: 3.9062e-07
# Epoch 73/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.2924 - mean_absolute_error: 4.0600 - root_mean_squared_error: 6.6181 - mean_absolute_percentage_error: 19.7634 - val_loss: 5.7778 - val_mean_absolute_error: 5.5540 - val_root_mean_squared_error: 10.2628 - val_mean_absolute_percentage_error: 31.2705 - lr: 1.9531e-07
# Epoch 74/100
# 103/103 [==============================] - 27s 266ms/step - loss: 4.2894 - mean_absolute_error: 4.0564 - root_mean_squared_error: 6.5153 - mean_absolute_percentage_error: 19.2072 - val_loss: 5.7886 - val_mean_absolute_error: 5.5657 - val_root_mean_squared_error: 10.2701 - val_mean_absolute_percentage_error: 31.3685 - lr: 1.9531e-07
# Epoch 75/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.2834 - mean_absolute_error: 4.0494 - root_mean_squared_error: 6.4767 - mean_absolute_percentage_error: 19.5422 - val_loss: 5.8014 - val_mean_absolute_error: 5.5803 - val_root_mean_squared_error: 10.2615 - val_mean_absolute_percentage_error: 31.6450 - lr: 1.9531e-07
# Epoch 76/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.4300 - mean_absolute_error: 4.1974 - root_mean_squared_error: 6.7859 - mean_absolute_percentage_error: 19.8051 - val_loss: 5.7914 - val_mean_absolute_error: 5.5696 - val_root_mean_squared_error: 10.2518 - val_mean_absolute_percentage_error: 31.4975 - lr: 1.9531e-07
# Epoch 77/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.2713 - mean_absolute_error: 4.0402 - root_mean_squared_error: 6.4835 - mean_absolute_percentage_error: 19.7715 - val_loss: 5.8157 - val_mean_absolute_error: 5.5945 - val_root_mean_squared_error: 10.2792 - val_mean_absolute_percentage_error: 31.6559 - lr: 1.9531e-07
# Epoch 78/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.2342 - mean_absolute_error: 4.0017 - root_mean_squared_error: 6.4546 - mean_absolute_percentage_error: 18.6745 - val_loss: 5.7840 - val_mean_absolute_error: 5.5626 - val_root_mean_squared_error: 10.2561 - val_mean_absolute_percentage_error: 31.5163 - lr: 9.7656e-08
# Epoch 79/100
# 103/103 [==============================] - 28s 276ms/step - loss: 4.4145 - mean_absolute_error: 4.1826 - root_mean_squared_error: 6.5690 - mean_absolute_percentage_error: 20.2602 - val_loss: 5.7871 - val_mean_absolute_error: 5.5646 - val_root_mean_squared_error: 10.2595 - val_mean_absolute_percentage_error: 31.4191 - lr: 9.7656e-08
# Epoch 80/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4162 - mean_absolute_error: 4.1849 - root_mean_squared_error: 6.6541 - mean_absolute_percentage_error: 20.1754 - val_loss: 5.7800 - val_mean_absolute_error: 5.5584 - val_root_mean_squared_error: 10.2454 - val_mean_absolute_percentage_error: 31.4246 - lr: 9.7656e-08
# Epoch 81/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3530 - mean_absolute_error: 4.1230 - root_mean_squared_error: 6.6308 - mean_absolute_percentage_error: 19.0893 - val_loss: 5.7994 - val_mean_absolute_error: 5.5772 - val_root_mean_squared_error: 10.2793 - val_mean_absolute_percentage_error: 31.4596 - lr: 9.7656e-08
# Epoch 82/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4535 - mean_absolute_error: 4.2209 - root_mean_squared_error: 6.6134 - mean_absolute_percentage_error: 20.5449 - val_loss: 5.8083 - val_mean_absolute_error: 5.5865 - val_root_mean_squared_error: 10.2770 - val_mean_absolute_percentage_error: 31.4612 - lr: 9.7656e-08
# Epoch 83/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4067 - mean_absolute_error: 4.1767 - root_mean_squared_error: 6.5141 - mean_absolute_percentage_error: 19.7193 - val_loss: 5.7880 - val_mean_absolute_error: 5.5648 - val_root_mean_squared_error: 10.2736 - val_mean_absolute_percentage_error: 31.3611 - lr: 4.8828e-08
# Epoch 84/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.3580 - mean_absolute_error: 4.1258 - root_mean_squared_error: 6.6174 - mean_absolute_percentage_error: 18.8720 - val_loss: 5.7955 - val_mean_absolute_error: 5.5725 - val_root_mean_squared_error: 10.2525 - val_mean_absolute_percentage_error: 31.6747 - lr: 4.8828e-08
# Epoch 85/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.1798 - mean_absolute_error: 3.9440 - root_mean_squared_error: 6.3285 - mean_absolute_percentage_error: 18.7608 - val_loss: 5.7962 - val_mean_absolute_error: 5.5743 - val_root_mean_squared_error: 10.2723 - val_mean_absolute_percentage_error: 31.5480 - lr: 4.8828e-08
# Epoch 86/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3381 - mean_absolute_error: 4.1037 - root_mean_squared_error: 6.7445 - mean_absolute_percentage_error: 18.7651 - val_loss: 5.7687 - val_mean_absolute_error: 5.5454 - val_root_mean_squared_error: 10.2572 - val_mean_absolute_percentage_error: 31.4805 - lr: 4.8828e-08
# Epoch 87/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3957 - mean_absolute_error: 4.1665 - root_mean_squared_error: 6.5685 - mean_absolute_percentage_error: 19.2812 - val_loss: 5.7972 - val_mean_absolute_error: 5.5751 - val_root_mean_squared_error: 10.2848 - val_mean_absolute_percentage_error: 31.5955 - lr: 4.8828e-08
# Epoch 88/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.2626 - mean_absolute_error: 4.0259 - root_mean_squared_error: 6.6125 - mean_absolute_percentage_error: 18.6458 - val_loss: 5.7854 - val_mean_absolute_error: 5.5630 - val_root_mean_squared_error: 10.2663 - val_mean_absolute_percentage_error: 31.5020 - lr: 2.4414e-08
# Epoch 89/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3566 - mean_absolute_error: 4.1245 - root_mean_squared_error: 6.2792 - mean_absolute_percentage_error: 19.7842 - val_loss: 5.7710 - val_mean_absolute_error: 5.5475 - val_root_mean_squared_error: 10.2674 - val_mean_absolute_percentage_error: 31.3725 - lr: 2.4414e-08
# Epoch 90/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.3756 - mean_absolute_error: 4.1443 - root_mean_squared_error: 6.4433 - mean_absolute_percentage_error: 19.3907 - val_loss: 5.7824 - val_mean_absolute_error: 5.5598 - val_root_mean_squared_error: 10.2621 - val_mean_absolute_percentage_error: 31.5736 - lr: 2.4414e-08
# Epoch 91/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.2365 - mean_absolute_error: 4.0020 - root_mean_squared_error: 6.4038 - mean_absolute_percentage_error: 19.3172 - val_loss: 5.7967 - val_mean_absolute_error: 5.5753 - val_root_mean_squared_error: 10.2521 - val_mean_absolute_percentage_error: 31.5762 - lr: 2.4414e-08
# Epoch 92/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4509 - mean_absolute_error: 4.2206 - root_mean_squared_error: 6.7424 - mean_absolute_percentage_error: 19.5593 - val_loss: 5.7929 - val_mean_absolute_error: 5.5707 - val_root_mean_squared_error: 10.2698 - val_mean_absolute_percentage_error: 31.4918 - lr: 2.4414e-08
# Epoch 93/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.3312 - mean_absolute_error: 4.1000 - root_mean_squared_error: 6.4398 - mean_absolute_percentage_error: 19.5158 - val_loss: 5.7678 - val_mean_absolute_error: 5.5424 - val_root_mean_squared_error: 10.2690 - val_mean_absolute_percentage_error: 31.2571 - lr: 1.2207e-08
# Epoch 94/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.4000 - mean_absolute_error: 4.1686 - root_mean_squared_error: 6.6524 - mean_absolute_percentage_error: 19.1343 - val_loss: 5.7936 - val_mean_absolute_error: 5.5718 - val_root_mean_squared_error: 10.2728 - val_mean_absolute_percentage_error: 31.5765 - lr: 1.2207e-08
# Epoch 95/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.3072 - mean_absolute_error: 4.0734 - root_mean_squared_error: 6.6235 - mean_absolute_percentage_error: 18.5333 - val_loss: 5.7698 - val_mean_absolute_error: 5.5468 - val_root_mean_squared_error: 10.2601 - val_mean_absolute_percentage_error: 31.3983 - lr: 1.2207e-08
# Epoch 96/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.2590 - mean_absolute_error: 4.0234 - root_mean_squared_error: 6.5020 - mean_absolute_percentage_error: 18.6308 - val_loss: 5.7832 - val_mean_absolute_error: 5.5602 - val_root_mean_squared_error: 10.2717 - val_mean_absolute_percentage_error: 31.4115 - lr: 1.2207e-08
# Epoch 97/100
# 103/103 [==============================] - 28s 275ms/step - loss: 4.5185 - mean_absolute_error: 4.2852 - root_mean_squared_error: 6.7029 - mean_absolute_percentage_error: 19.9512 - val_loss: 5.7819 - val_mean_absolute_error: 5.5598 - val_root_mean_squared_error: 10.2587 - val_mean_absolute_percentage_error: 31.5649 - lr: 1.2207e-08
# Epoch 98/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.1831 - mean_absolute_error: 3.9487 - root_mean_squared_error: 6.2094 - mean_absolute_percentage_error: 18.3656 - val_loss: 5.7736 - val_mean_absolute_error: 5.5504 - val_root_mean_squared_error: 10.2610 - val_mean_absolute_percentage_error: 31.4724 - lr: 6.1035e-09
# Epoch 99/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.4765 - mean_absolute_error: 4.2438 - root_mean_squared_error: 6.7660 - mean_absolute_percentage_error: 19.7162 - val_loss: 5.7798 - val_mean_absolute_error: 5.5557 - val_root_mean_squared_error: 10.2754 - val_mean_absolute_percentage_error: 31.3317 - lr: 6.1035e-09
# Epoch 100/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.5841 - mean_absolute_error: 4.3538 - root_mean_squared_error: 6.8789 - mean_absolute_percentage_error: 19.9037 - val_loss: 5.7855 - val_mean_absolute_error: 5.5628 - val_root_mean_squared_error: 10.2813 - val_mean_absolute_percentage_error: 31.4995 - lr: 6.1035e-09

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 117ms/step - loss: 5.7855 - mean_absolute_error: 5.5628 - root_mean_squared_error: 10.2813 - mean_absolute_percentage_error: 31.4995
# Model Loss: [5.785536289215088, 5.562837600708008, 10.281298637390137, 31.49953269958496]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 312ms/step
# Predicted Putusan: [19.737585]

# %%
model_scenario_name = "BiLSTM_13"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_13\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_13"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [19.737585]
