# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_9652\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=128)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(lstm_output_2)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu')(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(16, activation='relu')(numerical_dense)

combined = tf.keras.layers.Concatenate()([lstm_output_3, numerical_dense_2])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 128)    1907968     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 32)     18560       ['embedding[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_1 (Bidirectional  (None, 1024, 64)    16640       ['bidirectional[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 128)         66048       ['bidirectional_1[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 16)           528         ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 144)          0           ['bidirectional_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            145         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2,010,081
# Trainable params: 2,010,081
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 34s 280ms/step - loss: 18.9842 - mean_absolute_error: 19.4788 - root_mean_squared_error: 27.5612 - mean_absolute_percentage_error: 109.6609 - val_loss: 15.4493 - val_mean_absolute_error: 15.9337 - val_root_mean_squared_error: 22.1860 - val_mean_absolute_percentage_error: 124.7550
# Epoch 2/100
# 103/103 [==============================] - 36s 350ms/step - loss: 12.7294 - mean_absolute_error: 13.2182 - root_mean_squared_error: 18.7162 - mean_absolute_percentage_error: 110.2139 - val_loss: 11.7284 - val_mean_absolute_error: 12.2145 - val_root_mean_squared_error: 18.7770 - val_mean_absolute_percentage_error: 91.0670
# Epoch 3/100
# 103/103 [==============================] - 32s 313ms/step - loss: 10.3947 - mean_absolute_error: 10.8819 - root_mean_squared_error: 16.3567 - mean_absolute_percentage_error: 82.9163 - val_loss: 10.9625 - val_mean_absolute_error: 11.4490 - val_root_mean_squared_error: 17.8310 - val_mean_absolute_percentage_error: 81.0726
# Epoch 4/100
# 103/103 [==============================] - 34s 332ms/step - loss: 9.0424 - mean_absolute_error: 9.5254 - root_mean_squared_error: 14.8164 - mean_absolute_percentage_error: 73.4333 - val_loss: 10.6196 - val_mean_absolute_error: 11.1057 - val_root_mean_squared_error: 17.0806 - val_mean_absolute_percentage_error: 84.2555
# Epoch 5/100
# 103/103 [==============================] - 33s 322ms/step - loss: 7.9107 - mean_absolute_error: 8.3915 - root_mean_squared_error: 13.4896 - mean_absolute_percentage_error: 64.4746 - val_loss: 9.6581 - val_mean_absolute_error: 10.1438 - val_root_mean_squared_error: 16.3854 - val_mean_absolute_percentage_error: 69.0379
# Epoch 6/100
# 103/103 [==============================] - 31s 300ms/step - loss: 6.7985 - mean_absolute_error: 7.2729 - root_mean_squared_error: 12.4099 - mean_absolute_percentage_error: 53.7337 - val_loss: 8.8133 - val_mean_absolute_error: 9.2901 - val_root_mean_squared_error: 15.6389 - val_mean_absolute_percentage_error: 59.3482
# Epoch 7/100
# 103/103 [==============================] - 33s 324ms/step - loss: 5.5865 - mean_absolute_error: 6.0587 - root_mean_squared_error: 11.0137 - mean_absolute_percentage_error: 40.6612 - val_loss: 8.7534 - val_mean_absolute_error: 9.2373 - val_root_mean_squared_error: 15.2123 - val_mean_absolute_percentage_error: 58.2275
# Epoch 8/100
# 103/103 [==============================] - 38s 371ms/step - loss: 4.9970 - mean_absolute_error: 5.4655 - root_mean_squared_error: 10.2884 - mean_absolute_percentage_error: 33.9562 - val_loss: 7.8501 - val_mean_absolute_error: 8.3278 - val_root_mean_squared_error: 14.6964 - val_mean_absolute_percentage_error: 51.4617
# Epoch 9/100
# 103/103 [==============================] - 36s 349ms/step - loss: 4.2402 - mean_absolute_error: 4.6960 - root_mean_squared_error: 9.4293 - mean_absolute_percentage_error: 27.5578 - val_loss: 7.8778 - val_mean_absolute_error: 8.3558 - val_root_mean_squared_error: 14.7440 - val_mean_absolute_percentage_error: 50.0296
# Epoch 10/100
# 103/103 [==============================] - 39s 382ms/step - loss: 4.0855 - mean_absolute_error: 4.5393 - root_mean_squared_error: 9.1371 - mean_absolute_percentage_error: 27.4254 - val_loss: 7.6521 - val_mean_absolute_error: 8.1211 - val_root_mean_squared_error: 14.5017 - val_mean_absolute_percentage_error: 49.4721
# Epoch 11/100
# 103/103 [==============================] - 36s 354ms/step - loss: 3.5954 - mean_absolute_error: 4.0468 - root_mean_squared_error: 8.5217 - mean_absolute_percentage_error: 24.7954 - val_loss: 7.1813 - val_mean_absolute_error: 7.6377 - val_root_mean_squared_error: 14.1114 - val_mean_absolute_percentage_error: 45.8459
# Epoch 12/100
# 103/103 [==============================] - 31s 303ms/step - loss: 3.3166 - mean_absolute_error: 3.7562 - root_mean_squared_error: 8.2205 - mean_absolute_percentage_error: 22.8532 - val_loss: 7.1636 - val_mean_absolute_error: 7.6228 - val_root_mean_squared_error: 14.1197 - val_mean_absolute_percentage_error: 45.7422
# Epoch 13/100
# 103/103 [==============================] - 29s 281ms/step - loss: 3.0059 - mean_absolute_error: 3.4425 - root_mean_squared_error: 7.8414 - mean_absolute_percentage_error: 21.5369 - val_loss: 7.0688 - val_mean_absolute_error: 7.5228 - val_root_mean_squared_error: 14.0236 - val_mean_absolute_percentage_error: 45.0093
# Epoch 14/100
# 103/103 [==============================] - 29s 281ms/step - loss: 2.7951 - mean_absolute_error: 3.2321 - root_mean_squared_error: 7.4686 - mean_absolute_percentage_error: 20.3636 - val_loss: 7.2160 - val_mean_absolute_error: 7.6729 - val_root_mean_squared_error: 13.9600 - val_mean_absolute_percentage_error: 47.9399
# Epoch 15/100
# 103/103 [==============================] - 29s 282ms/step - loss: 2.7149 - mean_absolute_error: 3.1473 - root_mean_squared_error: 7.2154 - mean_absolute_percentage_error: 19.9692 - val_loss: 7.0608 - val_mean_absolute_error: 7.5235 - val_root_mean_squared_error: 13.7758 - val_mean_absolute_percentage_error: 46.3839
# Epoch 16/100
# 103/103 [==============================] - 29s 283ms/step - loss: 2.6989 - mean_absolute_error: 3.1434 - root_mean_squared_error: 6.9710 - mean_absolute_percentage_error: 20.7897 - val_loss: 6.9692 - val_mean_absolute_error: 7.4287 - val_root_mean_squared_error: 13.6440 - val_mean_absolute_percentage_error: 44.1319
# Epoch 17/100
# 103/103 [==============================] - 30s 291ms/step - loss: 2.4799 - mean_absolute_error: 2.9083 - root_mean_squared_error: 6.8466 - mean_absolute_percentage_error: 19.6429 - val_loss: 7.3858 - val_mean_absolute_error: 7.8618 - val_root_mean_squared_error: 13.7017 - val_mean_absolute_percentage_error: 50.4532
# Epoch 18/100
# 103/103 [==============================] - 30s 287ms/step - loss: 2.4118 - mean_absolute_error: 2.8437 - root_mean_squared_error: 6.6301 - mean_absolute_percentage_error: 19.2438 - val_loss: 6.7932 - val_mean_absolute_error: 7.2508 - val_root_mean_squared_error: 13.4735 - val_mean_absolute_percentage_error: 44.6705
# Epoch 19/100
# 103/103 [==============================] - 29s 284ms/step - loss: 2.2776 - mean_absolute_error: 2.7032 - root_mean_squared_error: 6.4295 - mean_absolute_percentage_error: 18.4546 - val_loss: 6.8184 - val_mean_absolute_error: 7.2702 - val_root_mean_squared_error: 13.5166 - val_mean_absolute_percentage_error: 46.9242
# Epoch 20/100
# 103/103 [==============================] - 31s 302ms/step - loss: 2.1085 - mean_absolute_error: 2.5285 - root_mean_squared_error: 6.2363 - mean_absolute_percentage_error: 17.5804 - val_loss: 6.6924 - val_mean_absolute_error: 7.1400 - val_root_mean_squared_error: 13.4092 - val_mean_absolute_percentage_error: 43.5532
# Epoch 21/100
# 103/103 [==============================] - 37s 359ms/step - loss: 2.0281 - mean_absolute_error: 2.4417 - root_mean_squared_error: 6.0159 - mean_absolute_percentage_error: 16.4068 - val_loss: 6.7067 - val_mean_absolute_error: 7.1580 - val_root_mean_squared_error: 13.3432 - val_mean_absolute_percentage_error: 43.6727
# Epoch 22/100
# 103/103 [==============================] - 41s 403ms/step - loss: 1.9191 - mean_absolute_error: 2.3272 - root_mean_squared_error: 5.8899 - mean_absolute_percentage_error: 16.5016 - val_loss: 6.6752 - val_mean_absolute_error: 7.1322 - val_root_mean_squared_error: 13.3509 - val_mean_absolute_percentage_error: 44.4125
# Epoch 23/100
# 103/103 [==============================] - 40s 391ms/step - loss: 1.7812 - mean_absolute_error: 2.1869 - root_mean_squared_error: 5.6617 - mean_absolute_percentage_error: 15.5234 - val_loss: 6.5816 - val_mean_absolute_error: 7.0230 - val_root_mean_squared_error: 13.1816 - val_mean_absolute_percentage_error: 45.1343
# Epoch 24/100
# 103/103 [==============================] - 40s 388ms/step - loss: 1.7786 - mean_absolute_error: 2.1825 - root_mean_squared_error: 5.6271 - mean_absolute_percentage_error: 15.1384 - val_loss: 6.6098 - val_mean_absolute_error: 7.0628 - val_root_mean_squared_error: 13.1325 - val_mean_absolute_percentage_error: 42.5085
# Epoch 25/100
# 103/103 [==============================] - 40s 387ms/step - loss: 1.7516 - mean_absolute_error: 2.1631 - root_mean_squared_error: 5.5564 - mean_absolute_percentage_error: 15.1248 - val_loss: 6.4057 - val_mean_absolute_error: 6.8423 - val_root_mean_squared_error: 13.0762 - val_mean_absolute_percentage_error: 42.8410
# Epoch 26/100
# 103/103 [==============================] - 35s 336ms/step - loss: 1.7115 - mean_absolute_error: 2.1205 - root_mean_squared_error: 5.4723 - mean_absolute_percentage_error: 14.9583 - val_loss: 6.7957 - val_mean_absolute_error: 7.2724 - val_root_mean_squared_error: 13.1203 - val_mean_absolute_percentage_error: 47.5622
# Epoch 27/100
# 103/103 [==============================] - 37s 356ms/step - loss: 1.7025 - mean_absolute_error: 2.1140 - root_mean_squared_error: 5.2403 - mean_absolute_percentage_error: 14.5646 - val_loss: 6.6726 - val_mean_absolute_error: 7.1165 - val_root_mean_squared_error: 13.1818 - val_mean_absolute_percentage_error: 44.8524
# Epoch 28/100
# 103/103 [==============================] - 38s 372ms/step - loss: 1.6555 - mean_absolute_error: 2.0601 - root_mean_squared_error: 5.1825 - mean_absolute_percentage_error: 14.2245 - val_loss: 6.3784 - val_mean_absolute_error: 6.8178 - val_root_mean_squared_error: 12.9752 - val_mean_absolute_percentage_error: 42.0173
# Epoch 29/100
# 103/103 [==============================] - 38s 367ms/step - loss: 1.5752 - mean_absolute_error: 1.9821 - root_mean_squared_error: 5.0904 - mean_absolute_percentage_error: 13.4130 - val_loss: 6.3912 - val_mean_absolute_error: 6.8350 - val_root_mean_squared_error: 12.9688 - val_mean_absolute_percentage_error: 43.1751
# Epoch 30/100
# 103/103 [==============================] - 35s 345ms/step - loss: 1.5446 - mean_absolute_error: 1.9446 - root_mean_squared_error: 5.0736 - mean_absolute_percentage_error: 13.5837 - val_loss: 6.5043 - val_mean_absolute_error: 6.9439 - val_root_mean_squared_error: 13.0749 - val_mean_absolute_percentage_error: 44.0827
# Epoch 31/100
# 103/103 [==============================] - 33s 318ms/step - loss: 1.4794 - mean_absolute_error: 1.8762 - root_mean_squared_error: 4.9506 - mean_absolute_percentage_error: 12.7716 - val_loss: 6.4506 - val_mean_absolute_error: 6.8934 - val_root_mean_squared_error: 13.0924 - val_mean_absolute_percentage_error: 44.3413
# Epoch 32/100
# 103/103 [==============================] - 34s 327ms/step - loss: 1.3955 - mean_absolute_error: 1.7843 - root_mean_squared_error: 4.8418 - mean_absolute_percentage_error: 11.7239 - val_loss: 6.2885 - val_mean_absolute_error: 6.7343 - val_root_mean_squared_error: 12.9640 - val_mean_absolute_percentage_error: 40.3984
# Epoch 33/100
# 103/103 [==============================] - 31s 301ms/step - loss: 1.3954 - mean_absolute_error: 1.7893 - root_mean_squared_error: 4.8119 - mean_absolute_percentage_error: 11.8747 - val_loss: 6.2563 - val_mean_absolute_error: 6.6915 - val_root_mean_squared_error: 12.8850 - val_mean_absolute_percentage_error: 41.0231
# Epoch 34/100
# 103/103 [==============================] - 31s 302ms/step - loss: 1.2947 - mean_absolute_error: 1.6911 - root_mean_squared_error: 4.5709 - mean_absolute_percentage_error: 11.1252 - val_loss: 6.3155 - val_mean_absolute_error: 6.7532 - val_root_mean_squared_error: 12.9836 - val_mean_absolute_percentage_error: 42.5622
# Epoch 35/100
# 103/103 [==============================] - 31s 302ms/step - loss: 1.2915 - mean_absolute_error: 1.6814 - root_mean_squared_error: 4.5302 - mean_absolute_percentage_error: 10.8813 - val_loss: 6.2468 - val_mean_absolute_error: 6.6819 - val_root_mean_squared_error: 13.0098 - val_mean_absolute_percentage_error: 42.2626
# Epoch 36/100
# 103/103 [==============================] - 30s 290ms/step - loss: 1.2295 - mean_absolute_error: 1.6295 - root_mean_squared_error: 4.3439 - mean_absolute_percentage_error: 10.7364 - val_loss: 6.3028 - val_mean_absolute_error: 6.7489 - val_root_mean_squared_error: 13.0172 - val_mean_absolute_percentage_error: 42.5802
# Epoch 37/100
# 103/103 [==============================] - 29s 277ms/step - loss: 1.1078 - mean_absolute_error: 1.4880 - root_mean_squared_error: 4.2211 - mean_absolute_percentage_error: 9.5563 - val_loss: 6.2306 - val_mean_absolute_error: 6.6676 - val_root_mean_squared_error: 12.9157 - val_mean_absolute_percentage_error: 41.3561
# Epoch 38/100
# 103/103 [==============================] - 28s 276ms/step - loss: 1.0336 - mean_absolute_error: 1.4062 - root_mean_squared_error: 4.0973 - mean_absolute_percentage_error: 8.8270 - val_loss: 6.1915 - val_mean_absolute_error: 6.6221 - val_root_mean_squared_error: 12.9502 - val_mean_absolute_percentage_error: 42.0237
# Epoch 39/100
# 103/103 [==============================] - 29s 279ms/step - loss: 1.0712 - mean_absolute_error: 1.4543 - root_mean_squared_error: 4.0535 - mean_absolute_percentage_error: 9.1745 - val_loss: 6.2195 - val_mean_absolute_error: 6.6593 - val_root_mean_squared_error: 12.9146 - val_mean_absolute_percentage_error: 40.4354
# Epoch 40/100
# 103/103 [==============================] - 28s 276ms/step - loss: 1.0021 - mean_absolute_error: 1.3812 - root_mean_squared_error: 3.9925 - mean_absolute_percentage_error: 8.7759 - val_loss: 6.3005 - val_mean_absolute_error: 6.7491 - val_root_mean_squared_error: 12.9932 - val_mean_absolute_percentage_error: 43.1427
# Epoch 41/100
# 103/103 [==============================] - 28s 272ms/step - loss: 0.9814 - mean_absolute_error: 1.3582 - root_mean_squared_error: 3.8394 - mean_absolute_percentage_error: 8.5322 - val_loss: 6.2723 - val_mean_absolute_error: 6.7099 - val_root_mean_squared_error: 12.9813 - val_mean_absolute_percentage_error: 42.6552
# Epoch 42/100
# 103/103 [==============================] - 29s 279ms/step - loss: 0.9526 - mean_absolute_error: 1.3293 - root_mean_squared_error: 3.8437 - mean_absolute_percentage_error: 7.9464 - val_loss: 6.2803 - val_mean_absolute_error: 6.7292 - val_root_mean_squared_error: 13.0508 - val_mean_absolute_percentage_error: 41.9766
# Epoch 43/100
# 103/103 [==============================] - 29s 282ms/step - loss: 0.8952 - mean_absolute_error: 1.2675 - root_mean_squared_error: 3.6936 - mean_absolute_percentage_error: 7.8710 - val_loss: 6.0819 - val_mean_absolute_error: 6.5090 - val_root_mean_squared_error: 12.8112 - val_mean_absolute_percentage_error: 41.0327
# Epoch 44/100
# 103/103 [==============================] - 30s 292ms/step - loss: 0.8039 - mean_absolute_error: 1.1640 - root_mean_squared_error: 3.5843 - mean_absolute_percentage_error: 7.0106 - val_loss: 6.0777 - val_mean_absolute_error: 6.5079 - val_root_mean_squared_error: 12.8023 - val_mean_absolute_percentage_error: 40.0382
# Epoch 45/100
# 103/103 [==============================] - 28s 271ms/step - loss: 0.7663 - mean_absolute_error: 1.1248 - root_mean_squared_error: 3.5258 - mean_absolute_percentage_error: 6.7646 - val_loss: 6.2798 - val_mean_absolute_error: 6.7223 - val_root_mean_squared_error: 12.9362 - val_mean_absolute_percentage_error: 42.6974
# Epoch 46/100
# 103/103 [==============================] - 28s 275ms/step - loss: 0.7492 - mean_absolute_error: 1.1043 - root_mean_squared_error: 3.4791 - mean_absolute_percentage_error: 6.5141 - val_loss: 6.1086 - val_mean_absolute_error: 6.5355 - val_root_mean_squared_error: 12.7652 - val_mean_absolute_percentage_error: 40.2248
# Epoch 47/100
# 103/103 [==============================] - 30s 289ms/step - loss: 0.7232 - mean_absolute_error: 1.0746 - root_mean_squared_error: 3.4127 - mean_absolute_percentage_error: 6.3957 - val_loss: 6.1094 - val_mean_absolute_error: 6.5533 - val_root_mean_squared_error: 12.7244 - val_mean_absolute_percentage_error: 41.3798
# Epoch 48/100
# 103/103 [==============================] - 29s 278ms/step - loss: 0.7483 - mean_absolute_error: 1.1036 - root_mean_squared_error: 3.3593 - mean_absolute_percentage_error: 6.6108 - val_loss: 6.0302 - val_mean_absolute_error: 6.4543 - val_root_mean_squared_error: 12.6949 - val_mean_absolute_percentage_error: 40.4084
# Epoch 49/100
# 103/103 [==============================] - 28s 275ms/step - loss: 0.6964 - mean_absolute_error: 1.0512 - root_mean_squared_error: 3.2945 - mean_absolute_percentage_error: 6.2839 - val_loss: 6.0021 - val_mean_absolute_error: 6.4288 - val_root_mean_squared_error: 12.5726 - val_mean_absolute_percentage_error: 39.3214
# Epoch 50/100
# 103/103 [==============================] - 29s 280ms/step - loss: 0.7141 - mean_absolute_error: 1.0696 - root_mean_squared_error: 3.2408 - mean_absolute_percentage_error: 6.5850 - val_loss: 6.1051 - val_mean_absolute_error: 6.5346 - val_root_mean_squared_error: 12.7025 - val_mean_absolute_percentage_error: 40.9599
# Epoch 51/100
# 103/103 [==============================] - 29s 283ms/step - loss: 0.6655 - mean_absolute_error: 1.0126 - root_mean_squared_error: 3.1781 - mean_absolute_percentage_error: 6.2507 - val_loss: 6.0618 - val_mean_absolute_error: 6.4872 - val_root_mean_squared_error: 12.6130 - val_mean_absolute_percentage_error: 40.7830
# Epoch 52/100
# 103/103 [==============================] - 29s 284ms/step - loss: 0.7324 - mean_absolute_error: 1.0871 - root_mean_squared_error: 3.3516 - mean_absolute_percentage_error: 6.5790 - val_loss: 6.3135 - val_mean_absolute_error: 6.7818 - val_root_mean_squared_error: 12.7825 - val_mean_absolute_percentage_error: 41.9708
# Epoch 53/100
# 103/103 [==============================] - 29s 285ms/step - loss: 0.7262 - mean_absolute_error: 1.0873 - root_mean_squared_error: 3.1777 - mean_absolute_percentage_error: 6.7700 - val_loss: 5.9189 - val_mean_absolute_error: 6.3460 - val_root_mean_squared_error: 12.4660 - val_mean_absolute_percentage_error: 39.1835
# Epoch 54/100
# 103/103 [==============================] - 30s 288ms/step - loss: 0.6528 - mean_absolute_error: 1.0024 - root_mean_squared_error: 3.0785 - mean_absolute_percentage_error: 6.0813 - val_loss: 5.8951 - val_mean_absolute_error: 6.3168 - val_root_mean_squared_error: 12.4252 - val_mean_absolute_percentage_error: 39.5932
# Epoch 55/100
# 103/103 [==============================] - 28s 272ms/step - loss: 0.6330 - mean_absolute_error: 0.9798 - root_mean_squared_error: 3.0342 - mean_absolute_percentage_error: 6.0892 - val_loss: 5.8881 - val_mean_absolute_error: 6.3094 - val_root_mean_squared_error: 12.4774 - val_mean_absolute_percentage_error: 40.1946
# Epoch 56/100
# 103/103 [==============================] - 27s 264ms/step - loss: 0.6347 - mean_absolute_error: 0.9873 - root_mean_squared_error: 2.9772 - mean_absolute_percentage_error: 6.0193 - val_loss: 5.9406 - val_mean_absolute_error: 6.3724 - val_root_mean_squared_error: 12.4851 - val_mean_absolute_percentage_error: 39.5590
# Epoch 57/100
# 103/103 [==============================] - 27s 264ms/step - loss: 0.5970 - mean_absolute_error: 0.9390 - root_mean_squared_error: 2.9543 - mean_absolute_percentage_error: 5.6949 - val_loss: 5.9931 - val_mean_absolute_error: 6.4161 - val_root_mean_squared_error: 12.5596 - val_mean_absolute_percentage_error: 40.4053
# Epoch 58/100
# 103/103 [==============================] - 28s 272ms/step - loss: 0.6231 - mean_absolute_error: 0.9690 - root_mean_squared_error: 2.9483 - mean_absolute_percentage_error: 5.8461 - val_loss: 5.9345 - val_mean_absolute_error: 6.3508 - val_root_mean_squared_error: 12.5264 - val_mean_absolute_percentage_error: 40.2519
# Epoch 59/100
# 103/103 [==============================] - 27s 267ms/step - loss: 0.7489 - mean_absolute_error: 1.1038 - root_mean_squared_error: 3.4570 - mean_absolute_percentage_error: 6.6983 - val_loss: 7.4549 - val_mean_absolute_error: 7.9180 - val_root_mean_squared_error: 13.4794 - val_mean_absolute_percentage_error: 50.3816
# Epoch 60/100
# 103/103 [==============================] - 28s 271ms/step - loss: 1.0271 - mean_absolute_error: 1.4217 - root_mean_squared_error: 3.2860 - mean_absolute_percentage_error: 10.0410 - val_loss: 6.0845 - val_mean_absolute_error: 6.5344 - val_root_mean_squared_error: 12.6153 - val_mean_absolute_percentage_error: 39.9623
# Epoch 61/100
# 103/103 [==============================] - 28s 271ms/step - loss: 0.6984 - mean_absolute_error: 1.0527 - root_mean_squared_error: 2.9600 - mean_absolute_percentage_error: 6.6214 - val_loss: 5.9022 - val_mean_absolute_error: 6.3250 - val_root_mean_squared_error: 12.4878 - val_mean_absolute_percentage_error: 39.2106
# Epoch 62/100
# 103/103 [==============================] - 28s 272ms/step - loss: 0.6122 - mean_absolute_error: 0.9719 - root_mean_squared_error: 2.8567 - mean_absolute_percentage_error: 5.8922 - val_loss: 5.8648 - val_mean_absolute_error: 6.2932 - val_root_mean_squared_error: 12.3874 - val_mean_absolute_percentage_error: 38.9642
# Epoch 63/100
# 103/103 [==============================] - 28s 271ms/step - loss: 0.5847 - mean_absolute_error: 0.9372 - root_mean_squared_error: 2.7760 - mean_absolute_percentage_error: 5.3638 - val_loss: 5.8411 - val_mean_absolute_error: 6.2584 - val_root_mean_squared_error: 12.3745 - val_mean_absolute_percentage_error: 39.1381
# Epoch 64/100
# 103/103 [==============================] - 28s 274ms/step - loss: 0.4875 - mean_absolute_error: 0.8057 - root_mean_squared_error: 2.7024 - mean_absolute_percentage_error: 4.5241 - val_loss: 5.8510 - val_mean_absolute_error: 6.2844 - val_root_mean_squared_error: 12.3270 - val_mean_absolute_percentage_error: 36.9896
# Epoch 65/100
# 103/103 [==============================] - 27s 265ms/step - loss: 0.4794 - mean_absolute_error: 0.7930 - root_mean_squared_error: 2.6492 - mean_absolute_percentage_error: 4.6574 - val_loss: 5.7810 - val_mean_absolute_error: 6.1850 - val_root_mean_squared_error: 12.2996 - val_mean_absolute_percentage_error: 37.1677
# Epoch 66/100
# 103/103 [==============================] - 28s 269ms/step - loss: 0.4236 - mean_absolute_error: 0.7218 - root_mean_squared_error: 2.6254 - mean_absolute_percentage_error: 4.1202 - val_loss: 5.8612 - val_mean_absolute_error: 6.2777 - val_root_mean_squared_error: 12.3767 - val_mean_absolute_percentage_error: 38.5400
# Epoch 67/100
# 103/103 [==============================] - 28s 273ms/step - loss: 0.4223 - mean_absolute_error: 0.7284 - root_mean_squared_error: 2.5803 - mean_absolute_percentage_error: 4.4371 - val_loss: 5.9038 - val_mean_absolute_error: 6.3295 - val_root_mean_squared_error: 12.3192 - val_mean_absolute_percentage_error: 38.5085
# Epoch 68/100
# 103/103 [==============================] - 29s 282ms/step - loss: 0.4507 - mean_absolute_error: 0.7595 - root_mean_squared_error: 2.5695 - mean_absolute_percentage_error: 4.2438 - val_loss: 5.9124 - val_mean_absolute_error: 6.3230 - val_root_mean_squared_error: 12.4293 - val_mean_absolute_percentage_error: 40.2366
# Epoch 69/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.4173 - mean_absolute_error: 0.7280 - root_mean_squared_error: 2.5122 - mean_absolute_percentage_error: 4.0870 - val_loss: 5.9838 - val_mean_absolute_error: 6.4267 - val_root_mean_squared_error: 12.3688 - val_mean_absolute_percentage_error: 40.5590
# Epoch 70/100
# 103/103 [==============================] - 27s 258ms/step - loss: 0.4478 - mean_absolute_error: 0.7543 - root_mean_squared_error: 2.7677 - mean_absolute_percentage_error: 4.3095 - val_loss: 5.7890 - val_mean_absolute_error: 6.1924 - val_root_mean_squared_error: 12.2900 - val_mean_absolute_percentage_error: 37.6788
# Epoch 71/100
# 103/103 [==============================] - 27s 259ms/step - loss: 0.4248 - mean_absolute_error: 0.7359 - root_mean_squared_error: 2.4902 - mean_absolute_percentage_error: 4.1435 - val_loss: 5.8409 - val_mean_absolute_error: 6.2551 - val_root_mean_squared_error: 12.3543 - val_mean_absolute_percentage_error: 39.0888
# Epoch 72/100
# 103/103 [==============================] - 26s 257ms/step - loss: 0.3780 - mean_absolute_error: 0.6712 - root_mean_squared_error: 2.4643 - mean_absolute_percentage_error: 3.8540 - val_loss: 5.7642 - val_mean_absolute_error: 6.1648 - val_root_mean_squared_error: 12.2211 - val_mean_absolute_percentage_error: 38.0784
# Epoch 73/100
# 103/103 [==============================] - 27s 259ms/step - loss: 0.3766 - mean_absolute_error: 0.6778 - root_mean_squared_error: 2.4122 - mean_absolute_percentage_error: 3.6902 - val_loss: 5.8320 - val_mean_absolute_error: 6.2480 - val_root_mean_squared_error: 12.3037 - val_mean_absolute_percentage_error: 38.8167
# Epoch 74/100
# 103/103 [==============================] - 26s 256ms/step - loss: 0.3909 - mean_absolute_error: 0.6915 - root_mean_squared_error: 2.4503 - mean_absolute_percentage_error: 3.8511 - val_loss: 5.7631 - val_mean_absolute_error: 6.1755 - val_root_mean_squared_error: 12.2976 - val_mean_absolute_percentage_error: 38.8131
# Epoch 75/100
# 103/103 [==============================] - 26s 254ms/step - loss: 0.3892 - mean_absolute_error: 0.6901 - root_mean_squared_error: 2.3741 - mean_absolute_percentage_error: 3.7608 - val_loss: 5.8662 - val_mean_absolute_error: 6.2757 - val_root_mean_squared_error: 12.3567 - val_mean_absolute_percentage_error: 39.3845
# Epoch 76/100
# 103/103 [==============================] - 26s 257ms/step - loss: 0.3979 - mean_absolute_error: 0.6957 - root_mean_squared_error: 2.3877 - mean_absolute_percentage_error: 3.7196 - val_loss: 5.8948 - val_mean_absolute_error: 6.3050 - val_root_mean_squared_error: 12.4715 - val_mean_absolute_percentage_error: 40.2399
# Epoch 77/100
# 103/103 [==============================] - 27s 263ms/step - loss: 0.4161 - mean_absolute_error: 0.7339 - root_mean_squared_error: 2.3577 - mean_absolute_percentage_error: 4.0428 - val_loss: 5.8182 - val_mean_absolute_error: 6.2238 - val_root_mean_squared_error: 12.3394 - val_mean_absolute_percentage_error: 39.5850
# Epoch 78/100
# 103/103 [==============================] - 26s 257ms/step - loss: 0.4070 - mean_absolute_error: 0.7245 - root_mean_squared_error: 2.3369 - mean_absolute_percentage_error: 4.1533 - val_loss: 5.8638 - val_mean_absolute_error: 6.2770 - val_root_mean_squared_error: 12.3853 - val_mean_absolute_percentage_error: 38.6249
# Epoch 79/100
# 103/103 [==============================] - 27s 262ms/step - loss: 0.3799 - mean_absolute_error: 0.6849 - root_mean_squared_error: 2.2888 - mean_absolute_percentage_error: 3.9463 - val_loss: 5.8174 - val_mean_absolute_error: 6.2346 - val_root_mean_squared_error: 12.3033 - val_mean_absolute_percentage_error: 38.4291
# Epoch 80/100
# 103/103 [==============================] - 27s 259ms/step - loss: 0.3985 - mean_absolute_error: 0.7123 - root_mean_squared_error: 2.2656 - mean_absolute_percentage_error: 4.3468 - val_loss: 5.7890 - val_mean_absolute_error: 6.2129 - val_root_mean_squared_error: 12.2453 - val_mean_absolute_percentage_error: 39.1560
# Epoch 81/100
# 103/103 [==============================] - 26s 257ms/step - loss: 0.4574 - mean_absolute_error: 0.7977 - root_mean_squared_error: 2.2793 - mean_absolute_percentage_error: 4.7222 - val_loss: 5.7770 - val_mean_absolute_error: 6.1942 - val_root_mean_squared_error: 12.2428 - val_mean_absolute_percentage_error: 38.2351
# Epoch 82/100
# 103/103 [==============================] - 26s 249ms/step - loss: 0.4195 - mean_absolute_error: 0.7431 - root_mean_squared_error: 2.2507 - mean_absolute_percentage_error: 4.4162 - val_loss: 5.8570 - val_mean_absolute_error: 6.2758 - val_root_mean_squared_error: 12.3362 - val_mean_absolute_percentage_error: 39.2340
# Epoch 83/100
# 103/103 [==============================] - 28s 276ms/step - loss: 0.3543 - mean_absolute_error: 0.6580 - root_mean_squared_error: 2.1597 - mean_absolute_percentage_error: 3.8607 - val_loss: 5.8818 - val_mean_absolute_error: 6.2962 - val_root_mean_squared_error: 12.3623 - val_mean_absolute_percentage_error: 41.0092
# Epoch 84/100
# 103/103 [==============================] - 29s 280ms/step - loss: 0.4071 - mean_absolute_error: 0.7319 - root_mean_squared_error: 2.1783 - mean_absolute_percentage_error: 4.6079 - val_loss: 5.8503 - val_mean_absolute_error: 6.2701 - val_root_mean_squared_error: 12.3056 - val_mean_absolute_percentage_error: 38.7927
# Epoch 85/100
# 103/103 [==============================] - 30s 292ms/step - loss: 0.4109 - mean_absolute_error: 0.7374 - root_mean_squared_error: 2.1562 - mean_absolute_percentage_error: 4.3675 - val_loss: 5.8461 - val_mean_absolute_error: 6.2528 - val_root_mean_squared_error: 12.3564 - val_mean_absolute_percentage_error: 38.7934
# Epoch 86/100
# 103/103 [==============================] - 27s 266ms/step - loss: 0.3466 - mean_absolute_error: 0.6443 - root_mean_squared_error: 2.1310 - mean_absolute_percentage_error: 3.7424 - val_loss: 5.7613 - val_mean_absolute_error: 6.1650 - val_root_mean_squared_error: 12.2105 - val_mean_absolute_percentage_error: 38.6450
# Epoch 87/100
# 103/103 [==============================] - 30s 288ms/step - loss: 0.3804 - mean_absolute_error: 0.6972 - root_mean_squared_error: 2.1501 - mean_absolute_percentage_error: 4.0191 - val_loss: 5.8462 - val_mean_absolute_error: 6.2583 - val_root_mean_squared_error: 12.3388 - val_mean_absolute_percentage_error: 39.6815
# Epoch 88/100
# 103/103 [==============================] - 26s 250ms/step - loss: 0.3839 - mean_absolute_error: 0.6942 - root_mean_squared_error: 2.1389 - mean_absolute_percentage_error: 3.9164 - val_loss: 5.8613 - val_mean_absolute_error: 6.2639 - val_root_mean_squared_error: 12.4129 - val_mean_absolute_percentage_error: 38.9407
# Epoch 89/100
# 103/103 [==============================] - 29s 281ms/step - loss: 0.6306 - mean_absolute_error: 0.9578 - root_mean_squared_error: 4.1551 - mean_absolute_percentage_error: 7.3043 - val_loss: 5.9091 - val_mean_absolute_error: 6.3292 - val_root_mean_squared_error: 12.3623 - val_mean_absolute_percentage_error: 37.8407
# Epoch 90/100
# 103/103 [==============================] - 26s 253ms/step - loss: 0.5023 - mean_absolute_error: 0.8478 - root_mean_squared_error: 2.2011 - mean_absolute_percentage_error: 5.1273 - val_loss: 5.8027 - val_mean_absolute_error: 6.2153 - val_root_mean_squared_error: 12.3490 - val_mean_absolute_percentage_error: 38.7952
# Epoch 91/100
# 103/103 [==============================] - 28s 271ms/step - loss: 0.3811 - mean_absolute_error: 0.6998 - root_mean_squared_error: 2.0552 - mean_absolute_percentage_error: 4.1649 - val_loss: 5.8923 - val_mean_absolute_error: 6.3316 - val_root_mean_squared_error: 12.4090 - val_mean_absolute_percentage_error: 39.9748
# Epoch 92/100
# 103/103 [==============================] - 28s 272ms/step - loss: 0.3334 - mean_absolute_error: 0.6387 - root_mean_squared_error: 1.9932 - mean_absolute_percentage_error: 3.7706 - val_loss: 5.8501 - val_mean_absolute_error: 6.2564 - val_root_mean_squared_error: 12.3440 - val_mean_absolute_percentage_error: 40.5685
# Epoch 93/100
# 103/103 [==============================] - 27s 258ms/step - loss: 0.3054 - mean_absolute_error: 0.5903 - root_mean_squared_error: 1.9677 - mean_absolute_percentage_error: 3.4590 - val_loss: 5.8441 - val_mean_absolute_error: 6.2593 - val_root_mean_squared_error: 12.3328 - val_mean_absolute_percentage_error: 40.4894
# Epoch 94/100
# 103/103 [==============================] - 27s 263ms/step - loss: 0.2755 - mean_absolute_error: 0.5505 - root_mean_squared_error: 1.9337 - mean_absolute_percentage_error: 3.1715 - val_loss: 5.8245 - val_mean_absolute_error: 6.2216 - val_root_mean_squared_error: 12.3829 - val_mean_absolute_percentage_error: 39.7281
# Epoch 95/100
# 103/103 [==============================] - 27s 267ms/step - loss: 0.2912 - mean_absolute_error: 0.5722 - root_mean_squared_error: 1.9158 - mean_absolute_percentage_error: 3.2852 - val_loss: 5.8017 - val_mean_absolute_error: 6.1992 - val_root_mean_squared_error: 12.3590 - val_mean_absolute_percentage_error: 39.0597
# Epoch 96/100
# 103/103 [==============================] - 31s 303ms/step - loss: 0.2705 - mean_absolute_error: 0.5483 - root_mean_squared_error: 1.9099 - mean_absolute_percentage_error: 3.0688 - val_loss: 5.7584 - val_mean_absolute_error: 6.1509 - val_root_mean_squared_error: 12.3033 - val_mean_absolute_percentage_error: 38.7005
# Epoch 97/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.2964 - mean_absolute_error: 0.5658 - root_mean_squared_error: 2.4375 - mean_absolute_percentage_error: 3.1737 - val_loss: 5.7718 - val_mean_absolute_error: 6.2006 - val_root_mean_squared_error: 12.3051 - val_mean_absolute_percentage_error: 39.0870
# Epoch 98/100
# 103/103 [==============================] - 27s 264ms/step - loss: 0.3285 - mean_absolute_error: 0.6252 - root_mean_squared_error: 2.0120 - mean_absolute_percentage_error: 3.7723 - val_loss: 5.8435 - val_mean_absolute_error: 6.2500 - val_root_mean_squared_error: 12.3504 - val_mean_absolute_percentage_error: 39.6204
# Epoch 99/100
# 103/103 [==============================] - 27s 260ms/step - loss: 0.2874 - mean_absolute_error: 0.5641 - root_mean_squared_error: 1.8960 - mean_absolute_percentage_error: 3.2598 - val_loss: 5.9144 - val_mean_absolute_error: 6.3408 - val_root_mean_squared_error: 12.4815 - val_mean_absolute_percentage_error: 40.1930
# Epoch 100/100
# 103/103 [==============================] - 27s 263ms/step - loss: 0.2844 - mean_absolute_error: 0.5735 - root_mean_squared_error: 1.8407 - mean_absolute_percentage_error: 3.2116 - val_loss: 5.7744 - val_mean_absolute_error: 6.1816 - val_root_mean_squared_error: 12.3147 - val_mean_absolute_percentage_error: 38.5522

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 3s 103ms/step - loss: 5.7744 - mean_absolute_error: 6.1816 - root_mean_squared_error: 12.3147 - mean_absolute_percentage_error: 38.5522
# Model Loss: [5.774426460266113, 6.1815690994262695, 12.314667701721191, 38.55220413208008]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [25.48897]

# %%
model_scenario_name = "BiLSTM_1"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_1\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_1\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_1"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 267ms/step
# Predicted Putusan: [25.48897]
