# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_33380\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=256 
)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                  kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output = tf.keras.layers.BatchNormalization()(lstm_output)

lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_2 = tf.keras.layers.BatchNormalization()(lstm_output_2)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, 
                                    kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
lstm_output_3 = tf.keras.layers.BatchNormalization()(lstm_output_3)

pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical = tf.keras.layers.BatchNormalization()(numerical_input)
numerical_dense = tf.keras.layers.Dense(32, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', 
                                        kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
# Callbacks
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=15,
    restore_best_weights=True
)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.6,  # Pengurangan learning rate yang lebih agresif
    patience=7,
    min_lr=1e-7
)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 64)     73984       ['embedding[0][0]']
#
#  batch_normalization (BatchNorm  (None, 1024, 64)    256         ['bidirectional[0][0]']
#  alization)
#
#  bidirectional_1 (Bidirectional  (None, 1024, 128)   66048       ['batch_normalization[0][0]']
#  )
#
#  batch_normalization_1 (BatchNo  (None, 1024, 128)   512         ['bidirectional_1[0][0]']
#  rmalization)
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 1024, 64)    41216       ['batch_normalization_1[0][0]']
#  )
#
#  batch_normalization_3 (BatchNo  (None, 5)           20          ['numerical_input[0][0]']
#  rmalization)
#
#  batch_normalization_2 (BatchNo  (None, 1024, 64)    256         ['bidirectional_2[0][0]']
#  rmalization)
#
#  dense (Dense)                  (None, 32)           192         ['batch_normalization_3[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['batch_normalization_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96)          384         ['concatenate[0][0]']
#  rmalization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization_4[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,019,573
# Trainable params: 4,018,859
# Non-trainable params: 714
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), 
                    callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 36s 288ms/step - loss: 33.9836 - mean_absolute_error: 33.6023 - root_mean_squared_error: 46.1098 - mean_absolute_percentage_error: 94.6291 - val_loss: 35.5594 - val_mean_absolute_error: 35.1884 - val_root_mean_squared_error: 48.3742 - val_mean_absolute_percentage_error: 92.3664 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 28s 272ms/step - loss: 30.3235 - mean_absolute_error: 29.9572 - root_mean_squared_error: 42.8950 - mean_absolute_percentage_error: 76.6671 - val_loss: 32.7041 - val_mean_absolute_error: 32.3491 - val_root_mean_squared_error: 46.0369 - val_mean_absolute_percentage_error: 77.8355 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 28s 273ms/step - loss: 23.7705 - mean_absolute_error: 23.4187 - root_mean_squared_error: 35.5941 - mean_absolute_percentage_error: 61.5006 - val_loss: 27.2617 - val_mean_absolute_error: 26.9220 - val_root_mean_squared_error: 39.9968 - val_mean_absolute_percentage_error: 65.0094 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 28s 273ms/step - loss: 15.5022 - mean_absolute_error: 15.1663 - root_mean_squared_error: 23.5930 - mean_absolute_percentage_error: 57.5823 - val_loss: 19.0146 - val_mean_absolute_error: 18.6909 - val_root_mean_squared_error: 27.4854 - val_mean_absolute_percentage_error: 60.5325 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 28s 270ms/step - loss: 11.1888 - mean_absolute_error: 10.8618 - root_mean_squared_error: 17.2188 - mean_absolute_percentage_error: 51.7906 - val_loss: 14.6399 - val_mean_absolute_error: 14.3242 - val_root_mean_squared_error: 21.4839 - val_mean_absolute_percentage_error: 55.0653 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 27s 261ms/step - loss: 10.8403 - mean_absolute_error: 10.5206 - root_mean_squared_error: 16.6998 - mean_absolute_percentage_error: 51.5990 - val_loss: 12.6278 - val_mean_absolute_error: 12.3178 - val_root_mean_squared_error: 18.3770 - val_mean_absolute_percentage_error: 56.4616 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 31s 305ms/step - loss: 9.5233 - mean_absolute_error: 9.2037 - root_mean_squared_error: 15.2185 - mean_absolute_percentage_error: 43.0993 - val_loss: 11.5169 - val_mean_absolute_error: 11.2115 - val_root_mean_squared_error: 16.5617 - val_mean_absolute_percentage_error: 68.5987 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 32s 315ms/step - loss: 9.0944 - mean_absolute_error: 8.7832 - root_mean_squared_error: 14.2622 - mean_absolute_percentage_error: 41.8370 - val_loss: 10.0603 - val_mean_absolute_error: 9.7432 - val_root_mean_squared_error: 16.4112 - val_mean_absolute_percentage_error: 39.7644 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 32s 313ms/step - loss: 8.5264 - mean_absolute_error: 8.2169 - root_mean_squared_error: 13.3734 - mean_absolute_percentage_error: 37.9122 - val_loss: 11.6398 - val_mean_absolute_error: 11.3340 - val_root_mean_squared_error: 18.4971 - val_mean_absolute_percentage_error: 44.9178 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 32s 313ms/step - loss: 7.8366 - mean_absolute_error: 7.5286 - root_mean_squared_error: 12.2664 - mean_absolute_percentage_error: 35.6481 - val_loss: 10.6237 - val_mean_absolute_error: 10.3276 - val_root_mean_squared_error: 15.1654 - val_mean_absolute_percentage_error: 68.0976 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 32s 315ms/step - loss: 7.6175 - mean_absolute_error: 7.3135 - root_mean_squared_error: 11.7263 - mean_absolute_percentage_error: 35.2208 - val_loss: 8.6678 - val_mean_absolute_error: 8.3672 - val_root_mean_squared_error: 14.4440 - val_mean_absolute_percentage_error: 44.6703 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 32s 313ms/step - loss: 7.1382 - mean_absolute_error: 6.8343 - root_mean_squared_error: 11.2489 - mean_absolute_percentage_error: 33.0124 - val_loss: 11.7280 - val_mean_absolute_error: 11.4250 - val_root_mean_squared_error: 18.4625 - val_mean_absolute_percentage_error: 39.4814 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 32s 312ms/step - loss: 7.0850 - mean_absolute_error: 6.7829 - root_mean_squared_error: 11.0282 - mean_absolute_percentage_error: 31.8175 - val_loss: 8.0487 - val_mean_absolute_error: 7.7486 - val_root_mean_squared_error: 13.1076 - val_mean_absolute_percentage_error: 46.7985 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 32s 315ms/step - loss: 6.8414 - mean_absolute_error: 6.5426 - root_mean_squared_error: 10.3278 - mean_absolute_percentage_error: 30.7893 - val_loss: 7.8016 - val_mean_absolute_error: 7.5084 - val_root_mean_squared_error: 12.4242 - val_mean_absolute_percentage_error: 45.8734 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 32s 315ms/step - loss: 6.7254 - mean_absolute_error: 6.4297 - root_mean_squared_error: 10.3553 - mean_absolute_percentage_error: 30.6757 - val_loss: 8.8190 - val_mean_absolute_error: 8.5362 - val_root_mean_squared_error: 13.1436 - val_mean_absolute_percentage_error: 47.2245 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 32s 316ms/step - loss: 6.3865 - mean_absolute_error: 6.0917 - root_mean_squared_error: 9.6927 - mean_absolute_percentage_error: 29.1437 - val_loss: 8.4409 - val_mean_absolute_error: 8.1424 - val_root_mean_squared_error: 13.8032 - val_mean_absolute_percentage_error: 36.8778 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 33s 317ms/step - loss: 6.2365 - mean_absolute_error: 5.9467 - root_mean_squared_error: 9.3108 - mean_absolute_percentage_error: 28.9617 - val_loss: 7.7060 - val_mean_absolute_error: 7.4170 - val_root_mean_squared_error: 12.7003 - val_mean_absolute_percentage_error: 34.6171 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 32s 316ms/step - loss: 6.1689 - mean_absolute_error: 5.8778 - root_mean_squared_error: 9.5586 - mean_absolute_percentage_error: 27.9436 - val_loss: 9.6850 - val_mean_absolute_error: 9.3978 - val_root_mean_squared_error: 15.5104 - val_mean_absolute_percentage_error: 34.2691 - lr: 1.0000e-04
# Epoch 19/100
# 103/103 [==============================] - 32s 314ms/step - loss: 6.1493 - mean_absolute_error: 5.8577 - root_mean_squared_error: 9.2642 - mean_absolute_percentage_error: 27.9279 - val_loss: 6.9207 - val_mean_absolute_error: 6.6221 - val_root_mean_squared_error: 12.0899 - val_mean_absolute_percentage_error: 34.4235 - lr: 1.0000e-04
# Epoch 20/100
# 103/103 [==============================] - 33s 316ms/step - loss: 5.9963 - mean_absolute_error: 5.7088 - root_mean_squared_error: 9.2901 - mean_absolute_percentage_error: 27.5632 - val_loss: 12.2565 - val_mean_absolute_error: 11.9892 - val_root_mean_squared_error: 18.0649 - val_mean_absolute_percentage_error: 49.6060 - lr: 1.0000e-04
# Epoch 21/100
# 103/103 [==============================] - 32s 315ms/step - loss: 5.8219 - mean_absolute_error: 5.5367 - root_mean_squared_error: 8.9408 - mean_absolute_percentage_error: 25.7276 - val_loss: 9.3335 - val_mean_absolute_error: 9.0635 - val_root_mean_squared_error: 13.6406 - val_mean_absolute_percentage_error: 50.7071 - lr: 1.0000e-04
# Epoch 22/100
# 103/103 [==============================] - 32s 315ms/step - loss: 5.9359 - mean_absolute_error: 5.6521 - root_mean_squared_error: 8.9348 - mean_absolute_percentage_error: 27.3480 - val_loss: 8.1425 - val_mean_absolute_error: 7.8748 - val_root_mean_squared_error: 12.5037 - val_mean_absolute_percentage_error: 46.1907 - lr: 1.0000e-04
# Epoch 23/100
# 103/103 [==============================] - 32s 314ms/step - loss: 5.5233 - mean_absolute_error: 5.2413 - root_mean_squared_error: 8.4352 - mean_absolute_percentage_error: 23.5976 - val_loss: 8.1598 - val_mean_absolute_error: 7.8955 - val_root_mean_squared_error: 11.9176 - val_mean_absolute_percentage_error: 55.4250 - lr: 1.0000e-04
# Epoch 24/100
# 103/103 [==============================] - 32s 314ms/step - loss: 5.4706 - mean_absolute_error: 5.1907 - root_mean_squared_error: 8.3240 - mean_absolute_percentage_error: 25.0742 - val_loss: 7.0896 - val_mean_absolute_error: 6.8113 - val_root_mean_squared_error: 11.5768 - val_mean_absolute_percentage_error: 36.0703 - lr: 1.0000e-04
# Epoch 25/100
# 103/103 [==============================] - 32s 315ms/step - loss: 5.4064 - mean_absolute_error: 5.1289 - root_mean_squared_error: 8.2945 - mean_absolute_percentage_error: 23.2620 - val_loss: 6.8589 - val_mean_absolute_error: 6.5863 - val_root_mean_squared_error: 11.9430 - val_mean_absolute_percentage_error: 37.1241 - lr: 1.0000e-04
# Epoch 26/100
# 103/103 [==============================] - 32s 315ms/step - loss: 5.1364 - mean_absolute_error: 4.8545 - root_mean_squared_error: 7.8281 - mean_absolute_percentage_error: 22.4227 - val_loss: 7.7509 - val_mean_absolute_error: 7.4886 - val_root_mean_squared_error: 12.2588 - val_mean_absolute_percentage_error: 39.8337 - lr: 1.0000e-04
# Epoch 27/100
# 103/103 [==============================] - 32s 314ms/step - loss: 5.3206 - mean_absolute_error: 5.0467 - root_mean_squared_error: 7.8649 - mean_absolute_percentage_error: 24.2954 - val_loss: 10.3620 - val_mean_absolute_error: 10.0895 - val_root_mean_squared_error: 15.9856 - val_mean_absolute_percentage_error: 36.0348 - lr: 1.0000e-04
# Epoch 28/100
# 103/103 [==============================] - 32s 313ms/step - loss: 5.0267 - mean_absolute_error: 4.7532 - root_mean_squared_error: 7.5608 - mean_absolute_percentage_error: 22.4338 - val_loss: 8.5252 - val_mean_absolute_error: 8.2718 - val_root_mean_squared_error: 13.1009 - val_mean_absolute_percentage_error: 34.8904 - lr: 1.0000e-04
# Epoch 29/100
# 103/103 [==============================] - 32s 312ms/step - loss: 4.9405 - mean_absolute_error: 4.6696 - root_mean_squared_error: 7.4059 - mean_absolute_percentage_error: 21.7883 - val_loss: 6.5607 - val_mean_absolute_error: 6.2854 - val_root_mean_squared_error: 11.3539 - val_mean_absolute_percentage_error: 34.6576 - lr: 1.0000e-04
# Epoch 30/100
# 103/103 [==============================] - 32s 314ms/step - loss: 4.9743 - mean_absolute_error: 4.7076 - root_mean_squared_error: 7.4847 - mean_absolute_percentage_error: 21.9571 - val_loss: 9.4537 - val_mean_absolute_error: 9.1911 - val_root_mean_squared_error: 14.5699 - val_mean_absolute_percentage_error: 34.0262 - lr: 1.0000e-04
# Epoch 31/100
# 103/103 [==============================] - 33s 316ms/step - loss: 4.9701 - mean_absolute_error: 4.7034 - root_mean_squared_error: 7.4471 - mean_absolute_percentage_error: 21.6940 - val_loss: 7.0838 - val_mean_absolute_error: 6.8125 - val_root_mean_squared_error: 12.0483 - val_mean_absolute_percentage_error: 32.9521 - lr: 1.0000e-04
# Epoch 32/100
# 103/103 [==============================] - 33s 316ms/step - loss: 4.7208 - mean_absolute_error: 4.4551 - root_mean_squared_error: 6.9750 - mean_absolute_percentage_error: 20.4242 - val_loss: 10.3330 - val_mean_absolute_error: 10.0892 - val_root_mean_squared_error: 14.6493 - val_mean_absolute_percentage_error: 53.4042 - lr: 1.0000e-04
# Epoch 33/100
# 103/103 [==============================] - 33s 316ms/step - loss: 4.9061 - mean_absolute_error: 4.6426 - root_mean_squared_error: 7.5079 - mean_absolute_percentage_error: 21.1751 - val_loss: 7.0115 - val_mean_absolute_error: 6.7464 - val_root_mean_squared_error: 11.8293 - val_mean_absolute_percentage_error: 36.2803 - lr: 1.0000e-04
# Epoch 34/100
# 103/103 [==============================] - 32s 314ms/step - loss: 4.7422 - mean_absolute_error: 4.4815 - root_mean_squared_error: 7.0974 - mean_absolute_percentage_error: 21.0875 - val_loss: 7.2767 - val_mean_absolute_error: 7.0244 - val_root_mean_squared_error: 12.1571 - val_mean_absolute_percentage_error: 33.9468 - lr: 1.0000e-04
# Epoch 35/100
# 103/103 [==============================] - 32s 310ms/step - loss: 4.6399 - mean_absolute_error: 4.3758 - root_mean_squared_error: 6.8853 - mean_absolute_percentage_error: 19.9602 - val_loss: 10.9903 - val_mean_absolute_error: 10.7493 - val_root_mean_squared_error: 15.6827 - val_mean_absolute_percentage_error: 54.5867 - lr: 1.0000e-04
# Epoch 36/100
# 103/103 [==============================] - 28s 270ms/step - loss: 4.9228 - mean_absolute_error: 4.6662 - root_mean_squared_error: 7.3564 - mean_absolute_percentage_error: 21.7031 - val_loss: 19.0750 - val_mean_absolute_error: 18.8492 - val_root_mean_squared_error: 25.7319 - val_mean_absolute_percentage_error: 83.3147 - lr: 1.0000e-04
# Epoch 37/100
# 103/103 [==============================] - 28s 270ms/step - loss: 4.6889 - mean_absolute_error: 4.4325 - root_mean_squared_error: 6.8984 - mean_absolute_percentage_error: 20.6155 - val_loss: 7.5601 - val_mean_absolute_error: 7.3059 - val_root_mean_squared_error: 12.3317 - val_mean_absolute_percentage_error: 33.2759 - lr: 6.0000e-05
# Epoch 38/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.3179 - mean_absolute_error: 4.0613 - root_mean_squared_error: 6.2350 - mean_absolute_percentage_error: 18.7320 - val_loss: 9.2789 - val_mean_absolute_error: 9.0358 - val_root_mean_squared_error: 13.6588 - val_mean_absolute_percentage_error: 44.5862 - lr: 6.0000e-05
# Epoch 39/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.2908 - mean_absolute_error: 4.0334 - root_mean_squared_error: 6.4816 - mean_absolute_percentage_error: 18.7034 - val_loss: 9.2013 - val_mean_absolute_error: 8.9653 - val_root_mean_squared_error: 13.4285 - val_mean_absolute_percentage_error: 43.0007 - lr: 6.0000e-05
# Epoch 40/100
# 103/103 [==============================] - 28s 269ms/step - loss: 4.2835 - mean_absolute_error: 4.0268 - root_mean_squared_error: 6.3682 - mean_absolute_percentage_error: 19.4371 - val_loss: 10.6407 - val_mean_absolute_error: 10.4079 - val_root_mean_squared_error: 14.8984 - val_mean_absolute_percentage_error: 57.2147 - lr: 6.0000e-05
# Epoch 41/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.3771 - mean_absolute_error: 4.1254 - root_mean_squared_error: 6.4875 - mean_absolute_percentage_error: 18.4373 - val_loss: 6.4845 - val_mean_absolute_error: 6.2403 - val_root_mean_squared_error: 10.9668 - val_mean_absolute_percentage_error: 33.6672 - lr: 6.0000e-05
# Epoch 42/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.2449 - mean_absolute_error: 3.9883 - root_mean_squared_error: 6.4252 - mean_absolute_percentage_error: 18.2379 - val_loss: 7.5935 - val_mean_absolute_error: 7.3484 - val_root_mean_squared_error: 12.0018 - val_mean_absolute_percentage_error: 39.1256 - lr: 6.0000e-05
# Epoch 43/100
# 103/103 [==============================] - 28s 272ms/step - loss: 4.5459 - mean_absolute_error: 4.2967 - root_mean_squared_error: 6.7183 - mean_absolute_percentage_error: 21.2928 - val_loss: 7.7324 - val_mean_absolute_error: 7.5009 - val_root_mean_squared_error: 11.9135 - val_mean_absolute_percentage_error: 36.0160 - lr: 6.0000e-05
# Epoch 44/100
# 103/103 [==============================] - 28s 273ms/step - loss: 4.3991 - mean_absolute_error: 4.1495 - root_mean_squared_error: 6.6948 - mean_absolute_percentage_error: 20.0693 - val_loss: 8.1796 - val_mean_absolute_error: 7.9398 - val_root_mean_squared_error: 12.8683 - val_mean_absolute_percentage_error: 32.6473 - lr: 6.0000e-05
# Epoch 45/100
# 103/103 [==============================] - 28s 274ms/step - loss: 4.2816 - mean_absolute_error: 4.0311 - root_mean_squared_error: 6.2236 - mean_absolute_percentage_error: 19.1205 - val_loss: 6.7986 - val_mean_absolute_error: 6.5547 - val_root_mean_squared_error: 11.3576 - val_mean_absolute_percentage_error: 33.3264 - lr: 6.0000e-05
# Epoch 46/100
# 103/103 [==============================] - 27s 267ms/step - loss: 4.2902 - mean_absolute_error: 4.0405 - root_mean_squared_error: 6.3006 - mean_absolute_percentage_error: 18.7407 - val_loss: 6.2121 - val_mean_absolute_error: 5.9485 - val_root_mean_squared_error: 10.9561 - val_mean_absolute_percentage_error: 33.4797 - lr: 6.0000e-05
# Epoch 47/100
# 103/103 [==============================] - 28s 276ms/step - loss: 4.3839 - mean_absolute_error: 4.1386 - root_mean_squared_error: 6.4580 - mean_absolute_percentage_error: 18.8286 - val_loss: 7.2923 - val_mean_absolute_error: 7.0562 - val_root_mean_squared_error: 11.8888 - val_mean_absolute_percentage_error: 36.3734 - lr: 6.0000e-05
# Epoch 48/100
# 103/103 [==============================] - 28s 268ms/step - loss: 4.2993 - mean_absolute_error: 4.0529 - root_mean_squared_error: 6.3447 - mean_absolute_percentage_error: 18.4759 - val_loss: 7.7160 - val_mean_absolute_error: 7.4956 - val_root_mean_squared_error: 11.8087 - val_mean_absolute_percentage_error: 48.2828 - lr: 6.0000e-05
# Epoch 49/100
# 103/103 [==============================] - 28s 268ms/step - loss: 4.1568 - mean_absolute_error: 3.9069 - root_mean_squared_error: 6.2923 - mean_absolute_percentage_error: 17.1859 - val_loss: 7.9648 - val_mean_absolute_error: 7.7222 - val_root_mean_squared_error: 12.4164 - val_mean_absolute_percentage_error: 38.5394 - lr: 6.0000e-05
# Epoch 50/100
# 103/103 [==============================] - 28s 270ms/step - loss: 4.2126 - mean_absolute_error: 3.9692 - root_mean_squared_error: 6.1573 - mean_absolute_percentage_error: 17.8570 - val_loss: 8.2331 - val_mean_absolute_error: 7.9876 - val_root_mean_squared_error: 12.6770 - val_mean_absolute_percentage_error: 39.9378 - lr: 6.0000e-05
# Epoch 51/100
# 103/103 [==============================] - 28s 271ms/step - loss: 4.1206 - mean_absolute_error: 3.8758 - root_mean_squared_error: 6.0909 - mean_absolute_percentage_error: 17.7437 - val_loss: 8.9612 - val_mean_absolute_error: 8.7318 - val_root_mean_squared_error: 13.3783 - val_mean_absolute_percentage_error: 47.5316 - lr: 6.0000e-05
# Epoch 52/100
# 103/103 [==============================] - 28s 269ms/step - loss: 4.0248 - mean_absolute_error: 3.7804 - root_mean_squared_error: 5.9064 - mean_absolute_percentage_error: 17.1027 - val_loss: 6.5659 - val_mean_absolute_error: 6.3354 - val_root_mean_squared_error: 11.2105 - val_mean_absolute_percentage_error: 31.8361 - lr: 6.0000e-05
# Epoch 53/100
# 103/103 [==============================] - 28s 270ms/step - loss: 4.0040 - mean_absolute_error: 3.7607 - root_mean_squared_error: 6.1153 - mean_absolute_percentage_error: 16.9835 - val_loss: 10.0883 - val_mean_absolute_error: 9.8617 - val_root_mean_squared_error: 15.3350 - val_mean_absolute_percentage_error: 36.6107 - lr: 6.0000e-05
# Epoch 54/100
# 103/103 [==============================] - 28s 271ms/step - loss: 3.9257 - mean_absolute_error: 3.6839 - root_mean_squared_error: 5.7019 - mean_absolute_percentage_error: 16.9147 - val_loss: 6.5221 - val_mean_absolute_error: 6.2939 - val_root_mean_squared_error: 11.1292 - val_mean_absolute_percentage_error: 34.0936 - lr: 3.6000e-05
# Epoch 55/100
# 103/103 [==============================] - 28s 270ms/step - loss: 3.7447 - mean_absolute_error: 3.5014 - root_mean_squared_error: 5.6650 - mean_absolute_percentage_error: 16.6825 - val_loss: 7.0916 - val_mean_absolute_error: 6.8717 - val_root_mean_squared_error: 11.4569 - val_mean_absolute_percentage_error: 35.8975 - lr: 3.6000e-05
# Epoch 56/100
# 103/103 [==============================] - 28s 273ms/step - loss: 3.9826 - mean_absolute_error: 3.7399 - root_mean_squared_error: 5.8486 - mean_absolute_percentage_error: 17.0947 - val_loss: 6.8084 - val_mean_absolute_error: 6.5851 - val_root_mean_squared_error: 11.1939 - val_mean_absolute_percentage_error: 32.4426 - lr: 3.6000e-05
# Epoch 57/100
# 103/103 [==============================] - 28s 270ms/step - loss: 3.7465 - mean_absolute_error: 3.5031 - root_mean_squared_error: 5.6426 - mean_absolute_percentage_error: 16.2022 - val_loss: 6.5103 - val_mean_absolute_error: 6.2860 - val_root_mean_squared_error: 11.0166 - val_mean_absolute_percentage_error: 33.9429 - lr: 3.6000e-05
# Epoch 58/100
# 103/103 [==============================] - 28s 269ms/step - loss: 3.9296 - mean_absolute_error: 3.6891 - root_mean_squared_error: 5.8992 - mean_absolute_percentage_error: 16.2212 - val_loss: 9.0668 - val_mean_absolute_error: 8.8417 - val_root_mean_squared_error: 13.5513 - val_mean_absolute_percentage_error: 44.0866 - lr: 3.6000e-05
# Epoch 59/100
# 103/103 [==============================] - 28s 268ms/step - loss: 3.7542 - mean_absolute_error: 3.5130 - root_mean_squared_error: 5.5156 - mean_absolute_percentage_error: 16.1127 - val_loss: 7.6866 - val_mean_absolute_error: 7.4650 - val_root_mean_squared_error: 12.1144 - val_mean_absolute_percentage_error: 38.6902 - lr: 3.6000e-05
# Epoch 60/100
# 103/103 [==============================] - 28s 271ms/step - loss: 3.7856 - mean_absolute_error: 3.5453 - root_mean_squared_error: 5.6951 - mean_absolute_percentage_error: 16.2287 - val_loss: 9.0701 - val_mean_absolute_error: 8.8549 - val_root_mean_squared_error: 13.3480 - val_mean_absolute_percentage_error: 41.9851 - lr: 3.6000e-05
# Epoch 61/100
# 103/103 [==============================] - 28s 269ms/step - loss: 3.8405 - mean_absolute_error: 3.6000 - root_mean_squared_error: 5.6372 - mean_absolute_percentage_error: 16.8945 - val_loss: 7.2185 - val_mean_absolute_error: 7.0047 - val_root_mean_squared_error: 11.4828 - val_mean_absolute_percentage_error: 33.3094 - lr: 2.1600e-05

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 4s 116ms/step - loss: 6.2121 - mean_absolute_error: 5.9485 - root_mean_squared_error: 10.9561 - mean_absolute_percentage_error: 33.4797
# Model Loss: [6.212141036987305, 5.948460578918457, 10.956141471862793, 33.47968292236328]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 290ms/step
# Predicted Putusan: [8.545948]

# %%
model_scenario_name = "BiLSTM_14"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_14\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_14\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_14"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 213ms/step
# Predicted Putusan: [8.545948]

# %% [markdown]
# ### Count Inverse-Log MAPE

# %%
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, root_mean_squared_error

y_pred_log = loaded_model.predict([X_test_texts, test_numerical])

# Inverse Log
y_true_real = np.expm1(y_test_log)
y_pred_real = np.expm1(y_pred_log)

mape_real = mean_absolute_percentage_error(y_true_real, y_pred_real) * 100

print(f"MAPE: {mape_real}%")
# Out:
# 33/33 [==============================] - 4s 89ms/step
# MAPE: 31.814866615842462%

# %%
mae_real = mean_absolute_error(y_true_real, y_pred_real)
print(f"MAE: {mae_real}")
# Out:
# MAE: 6.783241236966205

# %%
rmse_real = root_mean_squared_error(y_true_real, y_pred_real)
print(f"RMSE: {rmse_real} ")
# Out:
# RMSE: 12.085025884452556

# %%
y_true_real = np.expm1(y_test_log).ravel()
y_pred_real = np.expm1(y_pred_log).ravel()

def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * (error[is_small_error]) ** 2
    linear_loss = delta * (np.abs(error[~is_small_error]) - 0.5 * delta)
    return np.mean(np.concatenate([squared_loss, linear_loss]))

loss = huber_loss(y_true_real, y_pred_real)
print(f"Huber loss (real scale): {loss}")
# Out:
# Huber loss (real scale): 6.326372674872768
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_25908\478846792.py:1: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y_true_real = np.expm1(y_test_log).ravel()
