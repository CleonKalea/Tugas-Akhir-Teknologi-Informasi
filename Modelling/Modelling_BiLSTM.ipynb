# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_8340\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(lstm_output_2)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu')(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(16, activation='relu')(numerical_dense)

combined = tf.keras.layers.Concatenate()([lstm_output_3, numerical_dense_2])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 256)    3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 1024, 32)     34944       ['embedding[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_1 (Bidirectional  (None, 1024, 64)    16640       ['bidirectional[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 128)         66048       ['bidirectional_1[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 16)           528         ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 144)          0           ['bidirectional_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            145         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,934,433
# Trainable params: 3,934,433
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 34s 274ms/step - loss: 14.1510 - mean_absolute_error: 14.6411 - root_mean_squared_error: 21.9012 - mean_absolute_percentage_error: 97.4624 - val_loss: 11.5440 - val_mean_absolute_error: 12.0327 - val_root_mean_squared_error: 18.3705 - val_mean_absolute_percentage_error: 92.3169
# Epoch 2/100
# 103/103 [==============================] - 27s 259ms/step - loss: 10.0450 - mean_absolute_error: 10.5296 - root_mean_squared_error: 15.9929 - mean_absolute_percentage_error: 79.9864 - val_loss: 10.2427 - val_mean_absolute_error: 10.7254 - val_root_mean_squared_error: 17.2547 - val_mean_absolute_percentage_error: 73.5760
# Epoch 3/100
# 103/103 [==============================] - 27s 263ms/step - loss: 8.0202 - mean_absolute_error: 8.4993 - root_mean_squared_error: 13.9421 - mean_absolute_percentage_error: 61.2146 - val_loss: 8.9515 - val_mean_absolute_error: 9.4327 - val_root_mean_squared_error: 15.8638 - val_mean_absolute_percentage_error: 62.0591
# Epoch 4/100
# 103/103 [==============================] - 27s 259ms/step - loss: 6.1547 - mean_absolute_error: 6.6258 - root_mean_squared_error: 11.9527 - mean_absolute_percentage_error: 44.7663 - val_loss: 8.0430 - val_mean_absolute_error: 8.5169 - val_root_mean_squared_error: 15.1081 - val_mean_absolute_percentage_error: 52.2671
# Epoch 5/100
# 103/103 [==============================] - 27s 260ms/step - loss: 4.9980 - mean_absolute_error: 5.4623 - root_mean_squared_error: 10.5628 - mean_absolute_percentage_error: 33.2786 - val_loss: 7.9828 - val_mean_absolute_error: 8.4550 - val_root_mean_squared_error: 15.1111 - val_mean_absolute_percentage_error: 43.5854
# Epoch 6/100
# 103/103 [==============================] - 27s 264ms/step - loss: 4.2933 - mean_absolute_error: 4.7517 - root_mean_squared_error: 9.6693 - mean_absolute_percentage_error: 27.3498 - val_loss: 7.3093 - val_mean_absolute_error: 7.7773 - val_root_mean_squared_error: 14.1717 - val_mean_absolute_percentage_error: 44.9243
# Epoch 7/100
# 103/103 [==============================] - 28s 271ms/step - loss: 3.6926 - mean_absolute_error: 4.1433 - root_mean_squared_error: 8.8447 - mean_absolute_percentage_error: 23.7616 - val_loss: 7.6954 - val_mean_absolute_error: 8.1720 - val_root_mean_squared_error: 14.2918 - val_mean_absolute_percentage_error: 47.6081
# Epoch 8/100
# 103/103 [==============================] - 28s 273ms/step - loss: 3.3380 - mean_absolute_error: 3.7833 - root_mean_squared_error: 8.2137 - mean_absolute_percentage_error: 22.1091 - val_loss: 6.7861 - val_mean_absolute_error: 7.2462 - val_root_mean_squared_error: 13.7632 - val_mean_absolute_percentage_error: 42.2592
# Epoch 9/100
# 103/103 [==============================] - 28s 268ms/step - loss: 2.8807 - mean_absolute_error: 3.3174 - root_mean_squared_error: 7.6304 - mean_absolute_percentage_error: 19.9130 - val_loss: 6.7545 - val_mean_absolute_error: 7.2162 - val_root_mean_squared_error: 13.5561 - val_mean_absolute_percentage_error: 43.7655
# Epoch 10/100
# 103/103 [==============================] - 28s 270ms/step - loss: 2.6970 - mean_absolute_error: 3.1290 - root_mean_squared_error: 7.2803 - mean_absolute_percentage_error: 18.8559 - val_loss: 6.6454 - val_mean_absolute_error: 7.1067 - val_root_mean_squared_error: 13.4284 - val_mean_absolute_percentage_error: 43.0277
# Epoch 11/100
# 103/103 [==============================] - 28s 271ms/step - loss: 2.3744 - mean_absolute_error: 2.8012 - root_mean_squared_error: 6.7994 - mean_absolute_percentage_error: 16.5821 - val_loss: 6.4741 - val_mean_absolute_error: 6.9325 - val_root_mean_squared_error: 13.2637 - val_mean_absolute_percentage_error: 40.6308
# Epoch 12/100
# 103/103 [==============================] - 28s 268ms/step - loss: 2.1837 - mean_absolute_error: 2.6031 - root_mean_squared_error: 6.5368 - mean_absolute_percentage_error: 15.2283 - val_loss: 6.4396 - val_mean_absolute_error: 6.8986 - val_root_mean_squared_error: 13.1390 - val_mean_absolute_percentage_error: 40.0321
# Epoch 13/100
# 103/103 [==============================] - 28s 268ms/step - loss: 1.9528 - mean_absolute_error: 2.3652 - root_mean_squared_error: 6.0854 - mean_absolute_percentage_error: 14.1371 - val_loss: 6.4024 - val_mean_absolute_error: 6.8590 - val_root_mean_squared_error: 12.9902 - val_mean_absolute_percentage_error: 42.4065
# Epoch 14/100
# 103/103 [==============================] - 27s 267ms/step - loss: 1.7583 - mean_absolute_error: 2.1640 - root_mean_squared_error: 5.6982 - mean_absolute_percentage_error: 12.9826 - val_loss: 6.2104 - val_mean_absolute_error: 6.6563 - val_root_mean_squared_error: 12.7052 - val_mean_absolute_percentage_error: 40.5900
# Epoch 15/100
# 103/103 [==============================] - 27s 264ms/step - loss: 1.6962 - mean_absolute_error: 2.1108 - root_mean_squared_error: 5.4531 - mean_absolute_percentage_error: 13.0999 - val_loss: 6.2900 - val_mean_absolute_error: 6.7513 - val_root_mean_squared_error: 12.8414 - val_mean_absolute_percentage_error: 40.4891
# Epoch 16/100
# 103/103 [==============================] - 27s 266ms/step - loss: 1.6065 - mean_absolute_error: 2.0245 - root_mean_squared_error: 5.1973 - mean_absolute_percentage_error: 12.5727 - val_loss: 6.1749 - val_mean_absolute_error: 6.6290 - val_root_mean_squared_error: 12.8132 - val_mean_absolute_percentage_error: 38.6641
# Epoch 17/100
# 103/103 [==============================] - 28s 269ms/step - loss: 1.4273 - mean_absolute_error: 1.8266 - root_mean_squared_error: 5.0171 - mean_absolute_percentage_error: 11.1313 - val_loss: 6.0507 - val_mean_absolute_error: 6.4938 - val_root_mean_squared_error: 12.7548 - val_mean_absolute_percentage_error: 37.2968
# Epoch 18/100
# 103/103 [==============================] - 28s 268ms/step - loss: 1.2795 - mean_absolute_error: 1.6663 - root_mean_squared_error: 4.8026 - mean_absolute_percentage_error: 9.9716 - val_loss: 5.9403 - val_mean_absolute_error: 6.3859 - val_root_mean_squared_error: 12.3978 - val_mean_absolute_percentage_error: 36.5370
# Epoch 19/100
# 103/103 [==============================] - 28s 272ms/step - loss: 1.2118 - mean_absolute_error: 1.6048 - root_mean_squared_error: 4.6082 - mean_absolute_percentage_error: 9.2611 - val_loss: 6.0050 - val_mean_absolute_error: 6.4509 - val_root_mean_squared_error: 12.5126 - val_mean_absolute_percentage_error: 38.1715
# Epoch 20/100
# 103/103 [==============================] - 27s 267ms/step - loss: 1.1536 - mean_absolute_error: 1.5409 - root_mean_squared_error: 4.4728 - mean_absolute_percentage_error: 9.0119 - val_loss: 5.9250 - val_mean_absolute_error: 6.3635 - val_root_mean_squared_error: 12.5680 - val_mean_absolute_percentage_error: 37.2193
# Epoch 21/100
# 103/103 [==============================] - 27s 264ms/step - loss: 1.0194 - mean_absolute_error: 1.3923 - root_mean_squared_error: 4.3464 - mean_absolute_percentage_error: 7.6470 - val_loss: 5.8171 - val_mean_absolute_error: 6.2562 - val_root_mean_squared_error: 12.4979 - val_mean_absolute_percentage_error: 35.6745
# Epoch 22/100
# 103/103 [==============================] - 27s 267ms/step - loss: 0.9810 - mean_absolute_error: 1.3470 - root_mean_squared_error: 4.3001 - mean_absolute_percentage_error: 7.3975 - val_loss: 5.7727 - val_mean_absolute_error: 6.2075 - val_root_mean_squared_error: 12.3446 - val_mean_absolute_percentage_error: 37.6427
# Epoch 23/100
# 103/103 [==============================] - 28s 268ms/step - loss: 0.9772 - mean_absolute_error: 1.3484 - root_mean_squared_error: 4.2204 - mean_absolute_percentage_error: 7.2632 - val_loss: 5.8302 - val_mean_absolute_error: 6.2699 - val_root_mean_squared_error: 12.3478 - val_mean_absolute_percentage_error: 35.4111
# Epoch 24/100
# 103/103 [==============================] - 36s 345ms/step - loss: 0.9866 - mean_absolute_error: 1.3604 - root_mean_squared_error: 4.2654 - mean_absolute_percentage_error: 7.2182 - val_loss: 5.7796 - val_mean_absolute_error: 6.2175 - val_root_mean_squared_error: 12.5026 - val_mean_absolute_percentage_error: 36.0914
# Epoch 25/100
# 103/103 [==============================] - 34s 328ms/step - loss: 0.9962 - mean_absolute_error: 1.3723 - root_mean_squared_error: 4.1722 - mean_absolute_percentage_error: 7.9236 - val_loss: 5.7863 - val_mean_absolute_error: 6.2271 - val_root_mean_squared_error: 12.3649 - val_mean_absolute_percentage_error: 36.4433
# Epoch 26/100
# 103/103 [==============================] - 37s 363ms/step - loss: 0.9091 - mean_absolute_error: 1.2801 - root_mean_squared_error: 4.2025 - mean_absolute_percentage_error: 7.5592 - val_loss: 5.7026 - val_mean_absolute_error: 6.1353 - val_root_mean_squared_error: 12.2981 - val_mean_absolute_percentage_error: 35.1830
# Epoch 27/100
# 103/103 [==============================] - 36s 346ms/step - loss: 0.8528 - mean_absolute_error: 1.2171 - root_mean_squared_error: 3.9509 - mean_absolute_percentage_error: 7.1871 - val_loss: 5.8602 - val_mean_absolute_error: 6.2987 - val_root_mean_squared_error: 12.4265 - val_mean_absolute_percentage_error: 37.6239
# Epoch 28/100
# 103/103 [==============================] - 34s 332ms/step - loss: 0.8410 - mean_absolute_error: 1.2024 - root_mean_squared_error: 3.8672 - mean_absolute_percentage_error: 7.0191 - val_loss: 5.7594 - val_mean_absolute_error: 6.2037 - val_root_mean_squared_error: 12.1708 - val_mean_absolute_percentage_error: 34.8515
# Epoch 29/100
# 103/103 [==============================] - 35s 338ms/step - loss: 0.8255 - mean_absolute_error: 1.1855 - root_mean_squared_error: 3.8294 - mean_absolute_percentage_error: 6.6667 - val_loss: 5.8554 - val_mean_absolute_error: 6.2829 - val_root_mean_squared_error: 12.5525 - val_mean_absolute_percentage_error: 37.6441
# Epoch 30/100
# 103/103 [==============================] - 34s 334ms/step - loss: 0.7598 - mean_absolute_error: 1.1061 - root_mean_squared_error: 3.7305 - mean_absolute_percentage_error: 6.3168 - val_loss: 5.7225 - val_mean_absolute_error: 6.1503 - val_root_mean_squared_error: 12.2775 - val_mean_absolute_percentage_error: 36.6906
# Epoch 31/100
# 103/103 [==============================] - 34s 330ms/step - loss: 0.7039 - mean_absolute_error: 1.0462 - root_mean_squared_error: 3.6132 - mean_absolute_percentage_error: 5.8949 - val_loss: 5.6360 - val_mean_absolute_error: 6.0569 - val_root_mean_squared_error: 12.0128 - val_mean_absolute_percentage_error: 35.3838
# Epoch 32/100
# 103/103 [==============================] - 34s 326ms/step - loss: 0.6615 - mean_absolute_error: 1.0023 - root_mean_squared_error: 3.4390 - mean_absolute_percentage_error: 5.4868 - val_loss: 5.7000 - val_mean_absolute_error: 6.1310 - val_root_mean_squared_error: 12.2900 - val_mean_absolute_percentage_error: 36.4400
# Epoch 33/100
# 103/103 [==============================] - 34s 329ms/step - loss: 0.6635 - mean_absolute_error: 1.0070 - root_mean_squared_error: 3.3863 - mean_absolute_percentage_error: 5.7467 - val_loss: 5.7131 - val_mean_absolute_error: 6.1452 - val_root_mean_squared_error: 12.2463 - val_mean_absolute_percentage_error: 37.2070
# Epoch 34/100
# 103/103 [==============================] - 34s 329ms/step - loss: 0.6777 - mean_absolute_error: 1.0349 - root_mean_squared_error: 3.3554 - mean_absolute_percentage_error: 6.0744 - val_loss: 5.7317 - val_mean_absolute_error: 6.1747 - val_root_mean_squared_error: 12.0956 - val_mean_absolute_percentage_error: 36.1203
# Epoch 35/100
# 103/103 [==============================] - 34s 330ms/step - loss: 0.6181 - mean_absolute_error: 0.9640 - root_mean_squared_error: 3.2023 - mean_absolute_percentage_error: 5.3550 - val_loss: 5.7058 - val_mean_absolute_error: 6.1384 - val_root_mean_squared_error: 12.2183 - val_mean_absolute_percentage_error: 36.0414
# Epoch 36/100
# 103/103 [==============================] - 32s 315ms/step - loss: 0.5919 - mean_absolute_error: 0.9264 - root_mean_squared_error: 3.1814 - mean_absolute_percentage_error: 5.2944 - val_loss: 5.6140 - val_mean_absolute_error: 6.0421 - val_root_mean_squared_error: 11.8982 - val_mean_absolute_percentage_error: 35.5187
# Epoch 37/100
# 103/103 [==============================] - 29s 279ms/step - loss: 0.6038 - mean_absolute_error: 0.9466 - root_mean_squared_error: 3.1690 - mean_absolute_percentage_error: 5.5610 - val_loss: 5.7144 - val_mean_absolute_error: 6.1501 - val_root_mean_squared_error: 12.1249 - val_mean_absolute_percentage_error: 35.2231
# Epoch 38/100
# 103/103 [==============================] - 29s 280ms/step - loss: 0.5906 - mean_absolute_error: 0.9302 - root_mean_squared_error: 3.1025 - mean_absolute_percentage_error: 5.4883 - val_loss: 5.6573 - val_mean_absolute_error: 6.0893 - val_root_mean_squared_error: 12.1514 - val_mean_absolute_percentage_error: 36.8740
# Epoch 39/100
# 103/103 [==============================] - 31s 304ms/step - loss: 0.5810 - mean_absolute_error: 0.9230 - root_mean_squared_error: 3.0589 - mean_absolute_percentage_error: 5.2454 - val_loss: 5.6824 - val_mean_absolute_error: 6.1163 - val_root_mean_squared_error: 12.3183 - val_mean_absolute_percentage_error: 35.3073
# Epoch 40/100
# 103/103 [==============================] - 31s 300ms/step - loss: 0.6207 - mean_absolute_error: 0.9567 - root_mean_squared_error: 3.5282 - mean_absolute_percentage_error: 5.0548 - val_loss: 5.5965 - val_mean_absolute_error: 6.0243 - val_root_mean_squared_error: 12.1236 - val_mean_absolute_percentage_error: 35.7106
# Epoch 41/100
# 103/103 [==============================] - 31s 302ms/step - loss: 0.5695 - mean_absolute_error: 0.9085 - root_mean_squared_error: 2.9844 - mean_absolute_percentage_error: 5.3101 - val_loss: 5.5635 - val_mean_absolute_error: 5.9784 - val_root_mean_squared_error: 12.0470 - val_mean_absolute_percentage_error: 34.6969
# Epoch 42/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.4729 - mean_absolute_error: 0.7828 - root_mean_squared_error: 2.8685 - mean_absolute_percentage_error: 4.4695 - val_loss: 5.5594 - val_mean_absolute_error: 5.9669 - val_root_mean_squared_error: 12.0301 - val_mean_absolute_percentage_error: 34.2555
# Epoch 43/100
# 103/103 [==============================] - 31s 298ms/step - loss: 0.4339 - mean_absolute_error: 0.7383 - root_mean_squared_error: 2.8086 - mean_absolute_percentage_error: 3.9408 - val_loss: 5.5435 - val_mean_absolute_error: 5.9571 - val_root_mean_squared_error: 12.0457 - val_mean_absolute_percentage_error: 35.1255
# Epoch 44/100
# 103/103 [==============================] - 31s 298ms/step - loss: 0.4116 - mean_absolute_error: 0.7089 - root_mean_squared_error: 2.7985 - mean_absolute_percentage_error: 3.8689 - val_loss: 5.6108 - val_mean_absolute_error: 6.0179 - val_root_mean_squared_error: 12.1746 - val_mean_absolute_percentage_error: 34.8851
# Epoch 45/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.3944 - mean_absolute_error: 0.6838 - root_mean_squared_error: 2.7484 - mean_absolute_percentage_error: 3.7497 - val_loss: 5.4724 - val_mean_absolute_error: 5.8795 - val_root_mean_squared_error: 11.8628 - val_mean_absolute_percentage_error: 34.6418
# Epoch 46/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.3852 - mean_absolute_error: 0.6685 - root_mean_squared_error: 2.7198 - mean_absolute_percentage_error: 3.4800 - val_loss: 5.5485 - val_mean_absolute_error: 5.9615 - val_root_mean_squared_error: 12.0086 - val_mean_absolute_percentage_error: 35.6565
# Epoch 47/100
# 103/103 [==============================] - 31s 299ms/step - loss: 0.3954 - mean_absolute_error: 0.6933 - root_mean_squared_error: 2.7181 - mean_absolute_percentage_error: 3.9270 - val_loss: 5.5269 - val_mean_absolute_error: 5.9482 - val_root_mean_squared_error: 12.0864 - val_mean_absolute_percentage_error: 35.4668
# Epoch 48/100
# 103/103 [==============================] - 31s 297ms/step - loss: 0.4135 - mean_absolute_error: 0.7159 - root_mean_squared_error: 2.7108 - mean_absolute_percentage_error: 3.9963 - val_loss: 5.5308 - val_mean_absolute_error: 5.9415 - val_root_mean_squared_error: 12.0978 - val_mean_absolute_percentage_error: 35.8589
# Epoch 49/100
# 103/103 [==============================] - 31s 305ms/step - loss: 0.4089 - mean_absolute_error: 0.7128 - root_mean_squared_error: 2.6723 - mean_absolute_percentage_error: 4.0324 - val_loss: 5.6701 - val_mean_absolute_error: 6.0954 - val_root_mean_squared_error: 12.3566 - val_mean_absolute_percentage_error: 34.0225
# Epoch 50/100
# 103/103 [==============================] - 30s 292ms/step - loss: 0.4258 - mean_absolute_error: 0.7398 - root_mean_squared_error: 2.6166 - mean_absolute_percentage_error: 4.0262 - val_loss: 5.4921 - val_mean_absolute_error: 5.9070 - val_root_mean_squared_error: 12.0686 - val_mean_absolute_percentage_error: 35.3665
# Epoch 51/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.3819 - mean_absolute_error: 0.6785 - root_mean_squared_error: 2.5736 - mean_absolute_percentage_error: 3.5612 - val_loss: 5.5439 - val_mean_absolute_error: 5.9540 - val_root_mean_squared_error: 12.1499 - val_mean_absolute_percentage_error: 34.9423
# Epoch 52/100
# 103/103 [==============================] - 30s 288ms/step - loss: 1.6122 - mean_absolute_error: 1.9668 - root_mean_squared_error: 7.9495 - mean_absolute_percentage_error: 15.5499 - val_loss: 6.9980 - val_mean_absolute_error: 7.4518 - val_root_mean_squared_error: 14.5421 - val_mean_absolute_percentage_error: 50.8328
# Epoch 53/100
# 103/103 [==============================] - 30s 289ms/step - loss: 1.7108 - mean_absolute_error: 2.1205 - root_mean_squared_error: 5.8622 - mean_absolute_percentage_error: 16.1555 - val_loss: 6.7198 - val_mean_absolute_error: 7.1770 - val_root_mean_squared_error: 13.3383 - val_mean_absolute_percentage_error: 42.2800
# Epoch 54/100
# 103/103 [==============================] - 30s 289ms/step - loss: 1.2141 - mean_absolute_error: 1.6065 - root_mean_squared_error: 4.1294 - mean_absolute_percentage_error: 11.1802 - val_loss: 6.0110 - val_mean_absolute_error: 6.4420 - val_root_mean_squared_error: 12.6466 - val_mean_absolute_percentage_error: 38.8978
# Epoch 55/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.8600 - mean_absolute_error: 1.2146 - root_mean_squared_error: 3.7795 - mean_absolute_percentage_error: 8.4757 - val_loss: 5.8228 - val_mean_absolute_error: 6.2502 - val_root_mean_squared_error: 12.3169 - val_mean_absolute_percentage_error: 37.3641
# Epoch 56/100
# 103/103 [==============================] - 30s 290ms/step - loss: 1.2758 - mean_absolute_error: 1.6462 - root_mean_squared_error: 4.6831 - mean_absolute_percentage_error: 11.3339 - val_loss: 6.9157 - val_mean_absolute_error: 7.3712 - val_root_mean_squared_error: 13.6154 - val_mean_absolute_percentage_error: 44.9655
# Epoch 57/100
# 103/103 [==============================] - 30s 289ms/step - loss: 1.3655 - mean_absolute_error: 1.7591 - root_mean_squared_error: 4.5355 - mean_absolute_percentage_error: 11.0862 - val_loss: 6.1746 - val_mean_absolute_error: 6.6104 - val_root_mean_squared_error: 12.9492 - val_mean_absolute_percentage_error: 40.0700
# Epoch 58/100
# 103/103 [==============================] - 30s 290ms/step - loss: 0.7820 - mean_absolute_error: 1.1328 - root_mean_squared_error: 3.5257 - mean_absolute_percentage_error: 7.6092 - val_loss: 6.1922 - val_mean_absolute_error: 6.6153 - val_root_mean_squared_error: 13.2592 - val_mean_absolute_percentage_error: 39.2857
# Epoch 59/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.5948 - mean_absolute_error: 0.8940 - root_mean_squared_error: 3.6797 - mean_absolute_percentage_error: 5.7500 - val_loss: 6.1608 - val_mean_absolute_error: 6.5827 - val_root_mean_squared_error: 13.3223 - val_mean_absolute_percentage_error: 39.9095
# Epoch 60/100
# 103/103 [==============================] - 30s 290ms/step - loss: 0.5031 - mean_absolute_error: 0.7835 - root_mean_squared_error: 3.4873 - mean_absolute_percentage_error: 4.9737 - val_loss: 6.0539 - val_mean_absolute_error: 6.4658 - val_root_mean_squared_error: 12.9414 - val_mean_absolute_percentage_error: 37.4505
# Epoch 61/100
# 103/103 [==============================] - 30s 289ms/step - loss: 0.4413 - mean_absolute_error: 0.7132 - root_mean_squared_error: 3.3287 - mean_absolute_percentage_error: 4.5366 - val_loss: 5.9870 - val_mean_absolute_error: 6.3951 - val_root_mean_squared_error: 12.8170 - val_mean_absolute_percentage_error: 37.7742
# Epoch 62/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.3898 - mean_absolute_error: 0.6428 - root_mean_squared_error: 3.1902 - mean_absolute_percentage_error: 4.1346 - val_loss: 5.9374 - val_mean_absolute_error: 6.3674 - val_root_mean_squared_error: 12.7336 - val_mean_absolute_percentage_error: 38.1165
# Epoch 63/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.3996 - mean_absolute_error: 0.6794 - root_mean_squared_error: 2.9560 - mean_absolute_percentage_error: 4.2724 - val_loss: 5.9447 - val_mean_absolute_error: 6.3596 - val_root_mean_squared_error: 12.8495 - val_mean_absolute_percentage_error: 38.3020
# Epoch 64/100
# 103/103 [==============================] - 30s 293ms/step - loss: 0.3724 - mean_absolute_error: 0.6538 - root_mean_squared_error: 2.8512 - mean_absolute_percentage_error: 4.3106 - val_loss: 5.9165 - val_mean_absolute_error: 6.3293 - val_root_mean_squared_error: 12.7939 - val_mean_absolute_percentage_error: 37.8489
# Epoch 65/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.3538 - mean_absolute_error: 0.6198 - root_mean_squared_error: 2.8918 - mean_absolute_percentage_error: 4.2030 - val_loss: 5.9735 - val_mean_absolute_error: 6.3885 - val_root_mean_squared_error: 12.8967 - val_mean_absolute_percentage_error: 37.5455
# Epoch 66/100
# 103/103 [==============================] - 30s 291ms/step - loss: 0.3290 - mean_absolute_error: 0.5788 - root_mean_squared_error: 2.8210 - mean_absolute_percentage_error: 3.8686 - val_loss: 5.9215 - val_mean_absolute_error: 6.3287 - val_root_mean_squared_error: 12.8401 - val_mean_absolute_percentage_error: 38.1849
# Epoch 67/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.3076 - mean_absolute_error: 0.5444 - root_mean_squared_error: 2.7817 - mean_absolute_percentage_error: 3.5895 - val_loss: 5.9296 - val_mean_absolute_error: 6.3473 - val_root_mean_squared_error: 12.8091 - val_mean_absolute_percentage_error: 37.7966
# Epoch 68/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.3032 - mean_absolute_error: 0.5462 - root_mean_squared_error: 2.7521 - mean_absolute_percentage_error: 3.6303 - val_loss: 5.9176 - val_mean_absolute_error: 6.3316 - val_root_mean_squared_error: 12.7640 - val_mean_absolute_percentage_error: 38.2901
# Epoch 69/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.3169 - mean_absolute_error: 0.5713 - root_mean_squared_error: 2.7249 - mean_absolute_percentage_error: 3.7060 - val_loss: 5.8926 - val_mean_absolute_error: 6.2980 - val_root_mean_squared_error: 12.7287 - val_mean_absolute_percentage_error: 38.2960
# Epoch 70/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.3074 - mean_absolute_error: 0.5626 - root_mean_squared_error: 2.6537 - mean_absolute_percentage_error: 3.8866 - val_loss: 5.9084 - val_mean_absolute_error: 6.3149 - val_root_mean_squared_error: 12.8046 - val_mean_absolute_percentage_error: 38.3045
# Epoch 71/100
# 103/103 [==============================] - 31s 298ms/step - loss: 0.2899 - mean_absolute_error: 0.5413 - root_mean_squared_error: 2.5535 - mean_absolute_percentage_error: 3.7617 - val_loss: 5.8893 - val_mean_absolute_error: 6.2935 - val_root_mean_squared_error: 12.7234 - val_mean_absolute_percentage_error: 38.2726
# Epoch 72/100
# 103/103 [==============================] - 31s 299ms/step - loss: 0.3036 - mean_absolute_error: 0.5712 - root_mean_squared_error: 2.5234 - mean_absolute_percentage_error: 3.8269 - val_loss: 5.8816 - val_mean_absolute_error: 6.2884 - val_root_mean_squared_error: 12.7012 - val_mean_absolute_percentage_error: 38.6555
# Epoch 73/100
# 103/103 [==============================] - 31s 299ms/step - loss: 0.2934 - mean_absolute_error: 0.5524 - root_mean_squared_error: 2.4918 - mean_absolute_percentage_error: 3.5697 - val_loss: 5.8434 - val_mean_absolute_error: 6.2464 - val_root_mean_squared_error: 12.6665 - val_mean_absolute_percentage_error: 38.0573
# Epoch 74/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.2800 - mean_absolute_error: 0.5449 - root_mean_squared_error: 2.4160 - mean_absolute_percentage_error: 3.6907 - val_loss: 5.9710 - val_mean_absolute_error: 6.4045 - val_root_mean_squared_error: 12.7792 - val_mean_absolute_percentage_error: 38.9700
# Epoch 75/100
# 103/103 [==============================] - 30s 295ms/step - loss: 0.2788 - mean_absolute_error: 0.5380 - root_mean_squared_error: 2.3707 - mean_absolute_percentage_error: 3.6146 - val_loss: 5.8691 - val_mean_absolute_error: 6.2767 - val_root_mean_squared_error: 12.6535 - val_mean_absolute_percentage_error: 38.1488
# Epoch 76/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.2800 - mean_absolute_error: 0.5449 - root_mean_squared_error: 2.3383 - mean_absolute_percentage_error: 3.5515 - val_loss: 5.8589 - val_mean_absolute_error: 6.2593 - val_root_mean_squared_error: 12.6442 - val_mean_absolute_percentage_error: 38.4942
# Epoch 77/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.2794 - mean_absolute_error: 0.5447 - root_mean_squared_error: 2.3127 - mean_absolute_percentage_error: 3.6427 - val_loss: 5.8586 - val_mean_absolute_error: 6.2668 - val_root_mean_squared_error: 12.6842 - val_mean_absolute_percentage_error: 38.3815
# Epoch 78/100
# 103/103 [==============================] - 32s 311ms/step - loss: 0.2767 - mean_absolute_error: 0.5384 - root_mean_squared_error: 2.2916 - mean_absolute_percentage_error: 3.6069 - val_loss: 5.8630 - val_mean_absolute_error: 6.2794 - val_root_mean_squared_error: 12.6554 - val_mean_absolute_percentage_error: 39.0334
# Epoch 79/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.2846 - mean_absolute_error: 0.5578 - root_mean_squared_error: 2.2458 - mean_absolute_percentage_error: 3.9714 - val_loss: 5.9159 - val_mean_absolute_error: 6.3267 - val_root_mean_squared_error: 12.8153 - val_mean_absolute_percentage_error: 38.2522
# Epoch 80/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.2685 - mean_absolute_error: 0.5372 - root_mean_squared_error: 2.2125 - mean_absolute_percentage_error: 3.6746 - val_loss: 5.8255 - val_mean_absolute_error: 6.2248 - val_root_mean_squared_error: 12.6926 - val_mean_absolute_percentage_error: 38.4274
# Epoch 81/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.2517 - mean_absolute_error: 0.5114 - root_mean_squared_error: 2.1843 - mean_absolute_percentage_error: 3.4654 - val_loss: 5.8307 - val_mean_absolute_error: 6.2385 - val_root_mean_squared_error: 12.6772 - val_mean_absolute_percentage_error: 38.4371
# Epoch 82/100
# 103/103 [==============================] - 33s 317ms/step - loss: 0.2693 - mean_absolute_error: 0.5416 - root_mean_squared_error: 2.1745 - mean_absolute_percentage_error: 3.6608 - val_loss: 5.8595 - val_mean_absolute_error: 6.2799 - val_root_mean_squared_error: 12.6581 - val_mean_absolute_percentage_error: 39.1084
# Epoch 83/100
# 103/103 [==============================] - 32s 312ms/step - loss: 0.2733 - mean_absolute_error: 0.5479 - root_mean_squared_error: 2.1397 - mean_absolute_percentage_error: 3.8174 - val_loss: 5.9080 - val_mean_absolute_error: 6.3404 - val_root_mean_squared_error: 12.7709 - val_mean_absolute_percentage_error: 38.9361
# Epoch 84/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.2865 - mean_absolute_error: 0.5689 - root_mean_squared_error: 2.1462 - mean_absolute_percentage_error: 3.8667 - val_loss: 5.8146 - val_mean_absolute_error: 6.2214 - val_root_mean_squared_error: 12.7249 - val_mean_absolute_percentage_error: 38.4366
# Epoch 85/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.2401 - mean_absolute_error: 0.4985 - root_mean_squared_error: 2.0659 - mean_absolute_percentage_error: 3.4443 - val_loss: 5.8027 - val_mean_absolute_error: 6.2105 - val_root_mean_squared_error: 12.7358 - val_mean_absolute_percentage_error: 38.4074
# Epoch 86/100
# 103/103 [==============================] - 30s 294ms/step - loss: 0.2434 - mean_absolute_error: 0.4923 - root_mean_squared_error: 2.1419 - mean_absolute_percentage_error: 3.2520 - val_loss: 5.7916 - val_mean_absolute_error: 6.1955 - val_root_mean_squared_error: 12.6924 - val_mean_absolute_percentage_error: 38.3671
# Epoch 87/100
# 103/103 [==============================] - 30s 296ms/step - loss: 0.2243 - mean_absolute_error: 0.4694 - root_mean_squared_error: 2.0406 - mean_absolute_percentage_error: 3.1930 - val_loss: 5.8100 - val_mean_absolute_error: 6.2016 - val_root_mean_squared_error: 12.6346 - val_mean_absolute_percentage_error: 38.0569
# Epoch 88/100
# 103/103 [==============================] - 30s 295ms/step - loss: 0.2478 - mean_absolute_error: 0.5086 - root_mean_squared_error: 2.0854 - mean_absolute_percentage_error: 3.4158 - val_loss: 5.8791 - val_mean_absolute_error: 6.2959 - val_root_mean_squared_error: 12.8161 - val_mean_absolute_percentage_error: 37.9214
# Epoch 89/100
# 103/103 [==============================] - 30s 290ms/step - loss: 0.2498 - mean_absolute_error: 0.5117 - root_mean_squared_error: 2.0996 - mean_absolute_percentage_error: 3.3525 - val_loss: 5.7680 - val_mean_absolute_error: 6.1712 - val_root_mean_squared_error: 12.5712 - val_mean_absolute_percentage_error: 37.7788
# Epoch 90/100
# 103/103 [==============================] - 30s 290ms/step - loss: 0.2478 - mean_absolute_error: 0.5097 - root_mean_squared_error: 2.0035 - mean_absolute_percentage_error: 3.4456 - val_loss: 5.8062 - val_mean_absolute_error: 6.2038 - val_root_mean_squared_error: 12.6237 - val_mean_absolute_percentage_error: 38.4060
# Epoch 91/100
# 103/103 [==============================] - 30s 289ms/step - loss: 0.2367 - mean_absolute_error: 0.4912 - root_mean_squared_error: 1.9602 - mean_absolute_percentage_error: 3.3233 - val_loss: 5.7541 - val_mean_absolute_error: 6.1518 - val_root_mean_squared_error: 12.5103 - val_mean_absolute_percentage_error: 38.0906
# Epoch 92/100
# 103/103 [==============================] - 30s 289ms/step - loss: 0.2286 - mean_absolute_error: 0.4821 - root_mean_squared_error: 1.9130 - mean_absolute_percentage_error: 3.4062 - val_loss: 5.7601 - val_mean_absolute_error: 6.1570 - val_root_mean_squared_error: 12.5909 - val_mean_absolute_percentage_error: 38.3127
# Epoch 93/100
# 103/103 [==============================] - 30s 287ms/step - loss: 0.2061 - mean_absolute_error: 0.4472 - root_mean_squared_error: 1.8826 - mean_absolute_percentage_error: 2.9990 - val_loss: 5.7655 - val_mean_absolute_error: 6.1550 - val_root_mean_squared_error: 12.5855 - val_mean_absolute_percentage_error: 38.1890
# Epoch 94/100
# 103/103 [==============================] - 30s 288ms/step - loss: 0.1834 - mean_absolute_error: 0.4067 - root_mean_squared_error: 1.8349 - mean_absolute_percentage_error: 2.8479 - val_loss: 5.7485 - val_mean_absolute_error: 6.1618 - val_root_mean_squared_error: 12.5852 - val_mean_absolute_percentage_error: 38.0372
# Epoch 95/100
# 103/103 [==============================] - 30s 293ms/step - loss: 0.1959 - mean_absolute_error: 0.4313 - root_mean_squared_error: 1.8322 - mean_absolute_percentage_error: 2.9486 - val_loss: 5.7750 - val_mean_absolute_error: 6.1672 - val_root_mean_squared_error: 12.6538 - val_mean_absolute_percentage_error: 38.2119
# Epoch 96/100
# 103/103 [==============================] - 30s 289ms/step - loss: 0.2104 - mean_absolute_error: 0.4623 - root_mean_squared_error: 1.8292 - mean_absolute_percentage_error: 3.1527 - val_loss: 5.8007 - val_mean_absolute_error: 6.2016 - val_root_mean_squared_error: 12.6421 - val_mean_absolute_percentage_error: 39.0101
# Epoch 97/100
# 103/103 [==============================] - 30s 287ms/step - loss: 0.4213 - mean_absolute_error: 0.7134 - root_mean_squared_error: 2.4717 - mean_absolute_percentage_error: 5.4492 - val_loss: 5.8808 - val_mean_absolute_error: 6.2900 - val_root_mean_squared_error: 12.8383 - val_mean_absolute_percentage_error: 38.7925
# Epoch 98/100
# 103/103 [==============================] - 30s 287ms/step - loss: 0.3335 - mean_absolute_error: 0.6347 - root_mean_squared_error: 1.9560 - mean_absolute_percentage_error: 4.6461 - val_loss: 5.8752 - val_mean_absolute_error: 6.3029 - val_root_mean_squared_error: 12.7762 - val_mean_absolute_percentage_error: 37.6735
# Epoch 99/100
# 103/103 [==============================] - 30s 288ms/step - loss: 0.3454 - mean_absolute_error: 0.6371 - root_mean_squared_error: 2.2920 - mean_absolute_percentage_error: 4.2831 - val_loss: 5.8927 - val_mean_absolute_error: 6.3084 - val_root_mean_squared_error: 13.0387 - val_mean_absolute_percentage_error: 38.4911
# Epoch 100/100
# 103/103 [==============================] - 30s 287ms/step - loss: 0.2657 - mean_absolute_error: 0.5370 - root_mean_squared_error: 1.8440 - mean_absolute_percentage_error: 3.6961 - val_loss: 5.7979 - val_mean_absolute_error: 6.1992 - val_root_mean_squared_error: 12.5371 - val_mean_absolute_percentage_error: 38.7781

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 5s 137ms/step - loss: 5.7979 - mean_absolute_error: 6.1992 - root_mean_squared_error: 12.5371 - mean_absolute_percentage_error: 38.7781
# Model Loss: [5.797915458679199, 6.1991801261901855, 12.537064552307129, 38.77809143066406]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [8.105262]

# %%
model_scenario_name = "BiLSTM_4"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_4\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_4\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_4"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 0s 338ms/step
# Predicted Putusan: [8.105262]
