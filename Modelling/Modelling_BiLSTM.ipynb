# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_4928\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 512
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 512

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.001)))(lstm_output_2)
pooled_lstm = tf.keras.layers.GlobalMaxPooling1D()(lstm_output_3)
dropout_layer_1 = tf.keras.layers.Dropout(0.2)(pooled_lstm)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense)
numerical_dense_3 = tf.keras.layers.Dense(32, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_dense_2)

combined = tf.keras.layers.Concatenate()([dropout_layer_1, numerical_dense_3])
batch_norm = tf.keras.layers.BatchNormalization()(combined)

concated_dense_1 = tf.keras.layers.Dense(128, activation='relu')(batch_norm)
dropout_layer_2 = tf.keras.layers.Dropout(0.2)(concated_dense_1)
concated_dense_2 = tf.keras.layers.Dense(32, activation='relu')(dropout_layer_2)

output = tf.keras.layers.Dense(1, activation='linear')(concated_dense_2)

# %%
reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 512)]        0           []
#
#  embedding (Embedding)          (None, 512, 256)     4689408     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 512, 64)      73984       ['embedding[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 512, 128)    66048       ['bidirectional[0][0]']
#  )
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_2 (Bidirectional  (None, 512, 64)     41216       ['bidirectional_1[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 64)          0           ['bidirectional_2[0][0]']
#  xPooling1D)
#
#  dense_1 (Dense)                (None, 64)           2112        ['dense[0][0]']
#
#  dropout (Dropout)              (None, 64)           0           ['global_max_pooling1d[0][0]']
#
#  dense_2 (Dense)                (None, 32)           2080        ['dense_1[0][0]']
#
#  concatenate (Concatenate)      (None, 96)           0           ['dropout[0][0]',
#                                                                   'dense_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 96)          384         ['concatenate[0][0]']
#  alization)
#
#  dense_3 (Dense)                (None, 128)          12416       ['batch_normalization[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 32)           4128        ['dropout_1[0][0]']
#
#  dense_5 (Dense)                (None, 1)            33          ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 4,892,001
# Trainable params: 4,891,809
# Non-trainable params: 192
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test), callbacks=[reduce_lr_on_plateau])
# Out:
# Epoch 1/100
# 103/103 [==============================] - 23s 162ms/step - loss: 34.1099 - mean_absolute_error: 33.7761 - root_mean_squared_error: 46.0827 - mean_absolute_percentage_error: 96.4979 - val_loss: 34.3185 - val_mean_absolute_error: 34.0451 - val_root_mean_squared_error: 46.8990 - val_mean_absolute_percentage_error: 88.1801 - lr: 1.0000e-04
# Epoch 2/100
# 103/103 [==============================] - 15s 149ms/step - loss: 28.6853 - mean_absolute_error: 28.4545 - root_mean_squared_error: 39.9665 - mean_absolute_percentage_error: 78.2372 - val_loss: 27.9676 - val_mean_absolute_error: 27.7721 - val_root_mean_squared_error: 39.0280 - val_mean_absolute_percentage_error: 71.2919 - lr: 1.0000e-04
# Epoch 3/100
# 103/103 [==============================] - 15s 151ms/step - loss: 18.3929 - mean_absolute_error: 18.2199 - root_mean_squared_error: 27.0871 - mean_absolute_percentage_error: 58.1056 - val_loss: 16.2540 - val_mean_absolute_error: 16.1047 - val_root_mean_squared_error: 24.1743 - val_mean_absolute_percentage_error: 49.9704 - lr: 1.0000e-04
# Epoch 4/100
# 103/103 [==============================] - 16s 157ms/step - loss: 11.6739 - mean_absolute_error: 11.5386 - root_mean_squared_error: 17.7560 - mean_absolute_percentage_error: 53.1909 - val_loss: 12.6353 - val_mean_absolute_error: 12.5142 - val_root_mean_squared_error: 19.4057 - val_mean_absolute_percentage_error: 45.4959 - lr: 1.0000e-04
# Epoch 5/100
# 103/103 [==============================] - 15s 145ms/step - loss: 10.0775 - mean_absolute_error: 9.9636 - root_mean_squared_error: 15.4546 - mean_absolute_percentage_error: 46.7428 - val_loss: 12.3867 - val_mean_absolute_error: 12.2832 - val_root_mean_squared_error: 19.5477 - val_mean_absolute_percentage_error: 42.3620 - lr: 1.0000e-04
# Epoch 6/100
# 103/103 [==============================] - 15s 145ms/step - loss: 8.4838 - mean_absolute_error: 8.3859 - root_mean_squared_error: 13.3095 - mean_absolute_percentage_error: 40.5158 - val_loss: 9.3420 - val_mean_absolute_error: 9.2548 - val_root_mean_squared_error: 15.3956 - val_mean_absolute_percentage_error: 39.3421 - lr: 1.0000e-04
# Epoch 7/100
# 103/103 [==============================] - 15s 147ms/step - loss: 7.9044 - mean_absolute_error: 7.8238 - root_mean_squared_error: 12.5213 - mean_absolute_percentage_error: 37.8315 - val_loss: 11.6332 - val_mean_absolute_error: 11.5729 - val_root_mean_squared_error: 16.5589 - val_mean_absolute_percentage_error: 68.1148 - lr: 1.0000e-04
# Epoch 8/100
# 103/103 [==============================] - 15s 144ms/step - loss: 7.8219 - mean_absolute_error: 7.7544 - root_mean_squared_error: 12.4208 - mean_absolute_percentage_error: 35.1408 - val_loss: 7.7419 - val_mean_absolute_error: 7.6839 - val_root_mean_squared_error: 12.9040 - val_mean_absolute_percentage_error: 44.1483 - lr: 1.0000e-04
# Epoch 9/100
# 103/103 [==============================] - 15s 143ms/step - loss: 7.8103 - mean_absolute_error: 7.7583 - root_mean_squared_error: 12.1467 - mean_absolute_percentage_error: 36.4897 - val_loss: 8.0925 - val_mean_absolute_error: 8.0477 - val_root_mean_squared_error: 12.9222 - val_mean_absolute_percentage_error: 49.7611 - lr: 1.0000e-04
# Epoch 10/100
# 103/103 [==============================] - 17s 165ms/step - loss: 7.1203 - mean_absolute_error: 7.0791 - root_mean_squared_error: 11.1496 - mean_absolute_percentage_error: 33.4090 - val_loss: 7.6564 - val_mean_absolute_error: 7.6144 - val_root_mean_squared_error: 12.6493 - val_mean_absolute_percentage_error: 38.0800 - lr: 1.0000e-04
# Epoch 11/100
# 103/103 [==============================] - 18s 172ms/step - loss: 7.0266 - mean_absolute_error: 6.9941 - root_mean_squared_error: 10.8929 - mean_absolute_percentage_error: 33.5362 - val_loss: 8.1916 - val_mean_absolute_error: 8.1648 - val_root_mean_squared_error: 13.4776 - val_mean_absolute_percentage_error: 36.6927 - lr: 1.0000e-04
# Epoch 12/100
# 103/103 [==============================] - 18s 174ms/step - loss: 7.0624 - mean_absolute_error: 7.0405 - root_mean_squared_error: 10.9272 - mean_absolute_percentage_error: 34.5233 - val_loss: 7.2494 - val_mean_absolute_error: 7.2298 - val_root_mean_squared_error: 12.0612 - val_mean_absolute_percentage_error: 40.2920 - lr: 1.0000e-04
# Epoch 13/100
# 103/103 [==============================] - 16s 156ms/step - loss: 6.4886 - mean_absolute_error: 6.4751 - root_mean_squared_error: 10.0935 - mean_absolute_percentage_error: 31.1430 - val_loss: 7.4688 - val_mean_absolute_error: 7.4532 - val_root_mean_squared_error: 12.3284 - val_mean_absolute_percentage_error: 39.3995 - lr: 1.0000e-04
# Epoch 14/100
# 103/103 [==============================] - 16s 154ms/step - loss: 6.3787 - mean_absolute_error: 6.3724 - root_mean_squared_error: 9.6503 - mean_absolute_percentage_error: 31.2377 - val_loss: 7.8025 - val_mean_absolute_error: 7.8068 - val_root_mean_squared_error: 12.3939 - val_mean_absolute_percentage_error: 40.9372 - lr: 1.0000e-04
# Epoch 15/100
# 103/103 [==============================] - 15s 142ms/step - loss: 6.2900 - mean_absolute_error: 6.2926 - root_mean_squared_error: 9.5727 - mean_absolute_percentage_error: 30.9612 - val_loss: 9.6478 - val_mean_absolute_error: 9.6656 - val_root_mean_squared_error: 14.1741 - val_mean_absolute_percentage_error: 41.0390 - lr: 1.0000e-04
# Epoch 16/100
# 103/103 [==============================] - 14s 141ms/step - loss: 6.2127 - mean_absolute_error: 6.2225 - root_mean_squared_error: 9.5556 - mean_absolute_percentage_error: 29.9866 - val_loss: 8.4409 - val_mean_absolute_error: 8.4562 - val_root_mean_squared_error: 13.5897 - val_mean_absolute_percentage_error: 36.4253 - lr: 1.0000e-04
# Epoch 17/100
# 103/103 [==============================] - 15s 143ms/step - loss: 6.1073 - mean_absolute_error: 6.1227 - root_mean_squared_error: 9.4144 - mean_absolute_percentage_error: 30.6879 - val_loss: 7.2617 - val_mean_absolute_error: 7.2856 - val_root_mean_squared_error: 11.9177 - val_mean_absolute_percentage_error: 38.3811 - lr: 1.0000e-04
# Epoch 18/100
# 103/103 [==============================] - 16s 155ms/step - loss: 5.6544 - mean_absolute_error: 5.6730 - root_mean_squared_error: 8.5958 - mean_absolute_percentage_error: 27.6193 - val_loss: 6.8337 - val_mean_absolute_error: 6.8616 - val_root_mean_squared_error: 11.5959 - val_mean_absolute_percentage_error: 36.7056 - lr: 5.0000e-05
# Epoch 19/100
# 103/103 [==============================] - 15s 148ms/step - loss: 5.9154 - mean_absolute_error: 5.9384 - root_mean_squared_error: 8.9706 - mean_absolute_percentage_error: 30.1026 - val_loss: 7.7744 - val_mean_absolute_error: 7.8058 - val_root_mean_squared_error: 12.2985 - val_mean_absolute_percentage_error: 41.3314 - lr: 5.0000e-05
# Epoch 20/100
# 103/103 [==============================] - 14s 141ms/step - loss: 5.3444 - mean_absolute_error: 5.3674 - root_mean_squared_error: 8.2079 - mean_absolute_percentage_error: 26.8704 - val_loss: 6.4343 - val_mean_absolute_error: 6.4545 - val_root_mean_squared_error: 11.3380 - val_mean_absolute_percentage_error: 36.3780 - lr: 5.0000e-05
# Epoch 21/100
# 103/103 [==============================] - 15s 144ms/step - loss: 5.2377 - mean_absolute_error: 5.2614 - root_mean_squared_error: 8.2924 - mean_absolute_percentage_error: 25.3466 - val_loss: 6.9925 - val_mean_absolute_error: 7.0239 - val_root_mean_squared_error: 11.6861 - val_mean_absolute_percentage_error: 37.0620 - lr: 5.0000e-05
# Epoch 22/100
# 103/103 [==============================] - 16s 156ms/step - loss: 5.5710 - mean_absolute_error: 5.6002 - root_mean_squared_error: 8.6003 - mean_absolute_percentage_error: 27.9268 - val_loss: 6.5718 - val_mean_absolute_error: 6.5995 - val_root_mean_squared_error: 11.6411 - val_mean_absolute_percentage_error: 34.0995 - lr: 5.0000e-05
# Epoch 23/100
# 103/103 [==============================] - 15s 145ms/step - loss: 5.6511 - mean_absolute_error: 5.6863 - root_mean_squared_error: 8.5685 - mean_absolute_percentage_error: 28.7225 - val_loss: 6.7760 - val_mean_absolute_error: 6.8174 - val_root_mean_squared_error: 11.7462 - val_mean_absolute_percentage_error: 34.5162 - lr: 5.0000e-05
# Epoch 24/100
# 103/103 [==============================] - 14s 140ms/step - loss: 5.2348 - mean_absolute_error: 5.2690 - root_mean_squared_error: 8.0828 - mean_absolute_percentage_error: 25.1662 - val_loss: 6.3862 - val_mean_absolute_error: 6.4251 - val_root_mean_squared_error: 11.4012 - val_mean_absolute_percentage_error: 33.9506 - lr: 5.0000e-05
# Epoch 25/100
# 103/103 [==============================] - 14s 139ms/step - loss: 5.7163 - mean_absolute_error: 5.7562 - root_mean_squared_error: 9.0314 - mean_absolute_percentage_error: 26.8270 - val_loss: 6.5358 - val_mean_absolute_error: 6.5712 - val_root_mean_squared_error: 11.4379 - val_mean_absolute_percentage_error: 35.8646 - lr: 5.0000e-05
# Epoch 26/100
# 103/103 [==============================] - 15s 144ms/step - loss: 5.1544 - mean_absolute_error: 5.1932 - root_mean_squared_error: 7.7865 - mean_absolute_percentage_error: 26.1435 - val_loss: 6.2348 - val_mean_absolute_error: 6.2795 - val_root_mean_squared_error: 11.2589 - val_mean_absolute_percentage_error: 34.8871 - lr: 5.0000e-05
# Epoch 27/100
# 103/103 [==============================] - 16s 153ms/step - loss: 4.9645 - mean_absolute_error: 5.0058 - root_mean_squared_error: 7.5107 - mean_absolute_percentage_error: 25.5795 - val_loss: 7.0278 - val_mean_absolute_error: 7.0763 - val_root_mean_squared_error: 11.8577 - val_mean_absolute_percentage_error: 34.8126 - lr: 5.0000e-05
# Epoch 28/100
# 103/103 [==============================] - 17s 170ms/step - loss: 5.1971 - mean_absolute_error: 5.2429 - root_mean_squared_error: 8.1210 - mean_absolute_percentage_error: 25.6156 - val_loss: 6.1066 - val_mean_absolute_error: 6.1447 - val_root_mean_squared_error: 11.1155 - val_mean_absolute_percentage_error: 34.4261 - lr: 5.0000e-05
# Epoch 29/100
# 103/103 [==============================] - 16s 160ms/step - loss: 5.0263 - mean_absolute_error: 5.0734 - root_mean_squared_error: 7.8058 - mean_absolute_percentage_error: 24.0424 - val_loss: 5.9543 - val_mean_absolute_error: 5.9974 - val_root_mean_squared_error: 11.0629 - val_mean_absolute_percentage_error: 33.9430 - lr: 5.0000e-05
# Epoch 30/100
# 103/103 [==============================] - 16s 157ms/step - loss: 4.8621 - mean_absolute_error: 4.9098 - root_mean_squared_error: 7.4014 - mean_absolute_percentage_error: 23.6654 - val_loss: 6.4146 - val_mean_absolute_error: 6.4685 - val_root_mean_squared_error: 11.4232 - val_mean_absolute_percentage_error: 33.7184 - lr: 5.0000e-05
# Epoch 31/100
# 103/103 [==============================] - 15s 143ms/step - loss: 5.2618 - mean_absolute_error: 5.3162 - root_mean_squared_error: 8.2047 - mean_absolute_percentage_error: 24.7723 - val_loss: 6.1200 - val_mean_absolute_error: 6.1660 - val_root_mean_squared_error: 11.1425 - val_mean_absolute_percentage_error: 35.0048 - lr: 5.0000e-05
# Epoch 32/100
# 103/103 [==============================] - 15s 142ms/step - loss: 5.0588 - mean_absolute_error: 5.1113 - root_mean_squared_error: 7.7710 - mean_absolute_percentage_error: 23.9895 - val_loss: 7.0543 - val_mean_absolute_error: 7.1073 - val_root_mean_squared_error: 11.6827 - val_mean_absolute_percentage_error: 37.3734 - lr: 5.0000e-05
# Epoch 33/100
# 103/103 [==============================] - 15s 143ms/step - loss: 5.1934 - mean_absolute_error: 5.2475 - root_mean_squared_error: 8.0512 - mean_absolute_percentage_error: 25.0392 - val_loss: 7.0388 - val_mean_absolute_error: 7.0990 - val_root_mean_squared_error: 11.7740 - val_mean_absolute_percentage_error: 36.1908 - lr: 5.0000e-05
# Epoch 34/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.8176 - mean_absolute_error: 4.8717 - root_mean_squared_error: 7.4786 - mean_absolute_percentage_error: 22.5657 - val_loss: 6.4525 - val_mean_absolute_error: 6.5105 - val_root_mean_squared_error: 11.3880 - val_mean_absolute_percentage_error: 32.6525 - lr: 5.0000e-05
# Epoch 35/100
# 103/103 [==============================] - 15s 143ms/step - loss: 5.0197 - mean_absolute_error: 5.0788 - root_mean_squared_error: 7.7971 - mean_absolute_percentage_error: 22.7672 - val_loss: 6.0389 - val_mean_absolute_error: 6.0973 - val_root_mean_squared_error: 11.0132 - val_mean_absolute_percentage_error: 33.7226 - lr: 2.5000e-05
# Epoch 36/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.9514 - mean_absolute_error: 5.0112 - root_mean_squared_error: 7.4700 - mean_absolute_percentage_error: 22.8295 - val_loss: 5.8781 - val_mean_absolute_error: 5.9336 - val_root_mean_squared_error: 11.0123 - val_mean_absolute_percentage_error: 32.6061 - lr: 2.5000e-05
# Epoch 37/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.8812 - mean_absolute_error: 4.9399 - root_mean_squared_error: 7.7028 - mean_absolute_percentage_error: 21.6317 - val_loss: 6.0157 - val_mean_absolute_error: 6.0709 - val_root_mean_squared_error: 11.0388 - val_mean_absolute_percentage_error: 34.0070 - lr: 2.5000e-05
# Epoch 38/100
# 103/103 [==============================] - 16s 160ms/step - loss: 5.1599 - mean_absolute_error: 5.2213 - root_mean_squared_error: 8.0026 - mean_absolute_percentage_error: 23.6641 - val_loss: 5.9945 - val_mean_absolute_error: 6.0518 - val_root_mean_squared_error: 11.1356 - val_mean_absolute_percentage_error: 32.6053 - lr: 2.5000e-05
# Epoch 39/100
# 103/103 [==============================] - 17s 163ms/step - loss: 5.0179 - mean_absolute_error: 5.0829 - root_mean_squared_error: 7.7105 - mean_absolute_percentage_error: 22.2804 - val_loss: 5.8420 - val_mean_absolute_error: 5.8953 - val_root_mean_squared_error: 10.9675 - val_mean_absolute_percentage_error: 33.5892 - lr: 2.5000e-05
# Epoch 40/100
# 103/103 [==============================] - 17s 163ms/step - loss: 4.9480 - mean_absolute_error: 5.0134 - root_mean_squared_error: 7.7295 - mean_absolute_percentage_error: 23.0520 - val_loss: 6.3078 - val_mean_absolute_error: 6.3679 - val_root_mean_squared_error: 11.2831 - val_mean_absolute_percentage_error: 32.6391 - lr: 2.5000e-05
# Epoch 41/100
# 103/103 [==============================] - 16s 160ms/step - loss: 4.3502 - mean_absolute_error: 4.4116 - root_mean_squared_error: 6.8513 - mean_absolute_percentage_error: 20.4472 - val_loss: 6.1148 - val_mean_absolute_error: 6.1812 - val_root_mean_squared_error: 11.0722 - val_mean_absolute_percentage_error: 34.1216 - lr: 2.5000e-05
# Epoch 42/100
# 103/103 [==============================] - 15s 145ms/step - loss: 4.8967 - mean_absolute_error: 4.9617 - root_mean_squared_error: 7.5365 - mean_absolute_percentage_error: 21.6779 - val_loss: 5.8120 - val_mean_absolute_error: 5.8641 - val_root_mean_squared_error: 10.9757 - val_mean_absolute_percentage_error: 32.8516 - lr: 2.5000e-05
# Epoch 43/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.5187 - mean_absolute_error: 4.5822 - root_mean_squared_error: 7.0119 - mean_absolute_percentage_error: 21.1066 - val_loss: 5.8940 - val_mean_absolute_error: 5.9545 - val_root_mean_squared_error: 11.1099 - val_mean_absolute_percentage_error: 32.0410 - lr: 2.5000e-05
# Epoch 44/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.6742 - mean_absolute_error: 4.7402 - root_mean_squared_error: 7.2152 - mean_absolute_percentage_error: 20.7778 - val_loss: 5.6961 - val_mean_absolute_error: 5.7531 - val_root_mean_squared_error: 10.9511 - val_mean_absolute_percentage_error: 32.5679 - lr: 2.5000e-05
# Epoch 45/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.6695 - mean_absolute_error: 4.7377 - root_mean_squared_error: 7.1730 - mean_absolute_percentage_error: 21.4156 - val_loss: 5.8495 - val_mean_absolute_error: 5.9123 - val_root_mean_squared_error: 10.9413 - val_mean_absolute_percentage_error: 32.9498 - lr: 2.5000e-05
# Epoch 46/100
# 103/103 [==============================] - 16s 156ms/step - loss: 4.8182 - mean_absolute_error: 4.8867 - root_mean_squared_error: 7.6222 - mean_absolute_percentage_error: 21.6542 - val_loss: 5.8081 - val_mean_absolute_error: 5.8779 - val_root_mean_squared_error: 10.8950 - val_mean_absolute_percentage_error: 32.7084 - lr: 2.5000e-05
# Epoch 47/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.8063 - mean_absolute_error: 4.8759 - root_mean_squared_error: 7.4781 - mean_absolute_percentage_error: 21.9242 - val_loss: 5.6143 - val_mean_absolute_error: 5.6657 - val_root_mean_squared_error: 10.8409 - val_mean_absolute_percentage_error: 32.0211 - lr: 2.5000e-05
# Epoch 48/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.4675 - mean_absolute_error: 4.5381 - root_mean_squared_error: 6.9617 - mean_absolute_percentage_error: 19.6729 - val_loss: 5.6733 - val_mean_absolute_error: 5.7270 - val_root_mean_squared_error: 10.8169 - val_mean_absolute_percentage_error: 32.5955 - lr: 2.5000e-05
# Epoch 49/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.5658 - mean_absolute_error: 4.6352 - root_mean_squared_error: 7.2607 - mean_absolute_percentage_error: 19.6733 - val_loss: 6.0564 - val_mean_absolute_error: 6.1147 - val_root_mean_squared_error: 11.0362 - val_mean_absolute_percentage_error: 33.6310 - lr: 2.5000e-05
# Epoch 50/100
# 103/103 [==============================] - 15s 146ms/step - loss: 4.5473 - mean_absolute_error: 4.6168 - root_mean_squared_error: 7.3215 - mean_absolute_percentage_error: 20.0218 - val_loss: 5.7290 - val_mean_absolute_error: 5.7914 - val_root_mean_squared_error: 10.8892 - val_mean_absolute_percentage_error: 31.8736 - lr: 2.5000e-05
# Epoch 51/100
# 103/103 [==============================] - 15s 150ms/step - loss: 4.7878 - mean_absolute_error: 4.8580 - root_mean_squared_error: 7.6762 - mean_absolute_percentage_error: 21.4103 - val_loss: 5.6620 - val_mean_absolute_error: 5.7245 - val_root_mean_squared_error: 10.8035 - val_mean_absolute_percentage_error: 32.4049 - lr: 2.5000e-05
# Epoch 52/100
# 103/103 [==============================] - 15s 147ms/step - loss: 4.9574 - mean_absolute_error: 5.0308 - root_mean_squared_error: 7.7424 - mean_absolute_percentage_error: 22.5145 - val_loss: 6.1542 - val_mean_absolute_error: 6.2290 - val_root_mean_squared_error: 11.0345 - val_mean_absolute_percentage_error: 33.3680 - lr: 2.5000e-05
# Epoch 53/100
# 103/103 [==============================] - 15s 147ms/step - loss: 4.6468 - mean_absolute_error: 4.7205 - root_mean_squared_error: 7.3070 - mean_absolute_percentage_error: 20.5549 - val_loss: 5.6775 - val_mean_absolute_error: 5.7430 - val_root_mean_squared_error: 10.8892 - val_mean_absolute_percentage_error: 32.1537 - lr: 1.2500e-05
# Epoch 54/100
# 103/103 [==============================] - 15s 145ms/step - loss: 4.3307 - mean_absolute_error: 4.4015 - root_mean_squared_error: 6.7319 - mean_absolute_percentage_error: 19.6000 - val_loss: 5.5785 - val_mean_absolute_error: 5.6381 - val_root_mean_squared_error: 10.8418 - val_mean_absolute_percentage_error: 31.6925 - lr: 1.2500e-05
# Epoch 55/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.4690 - mean_absolute_error: 4.5404 - root_mean_squared_error: 7.1160 - mean_absolute_percentage_error: 19.5618 - val_loss: 5.5784 - val_mean_absolute_error: 5.6369 - val_root_mean_squared_error: 10.7815 - val_mean_absolute_percentage_error: 32.1164 - lr: 1.2500e-05
# Epoch 56/100
# 103/103 [==============================] - 14s 139ms/step - loss: 4.2116 - mean_absolute_error: 4.2845 - root_mean_squared_error: 6.5447 - mean_absolute_percentage_error: 18.2299 - val_loss: 5.9394 - val_mean_absolute_error: 6.0095 - val_root_mean_squared_error: 10.9398 - val_mean_absolute_percentage_error: 33.4613 - lr: 1.2500e-05
# Epoch 57/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.2727 - mean_absolute_error: 4.3444 - root_mean_squared_error: 6.7993 - mean_absolute_percentage_error: 19.6147 - val_loss: 5.6414 - val_mean_absolute_error: 5.7053 - val_root_mean_squared_error: 10.8203 - val_mean_absolute_percentage_error: 32.7677 - lr: 1.2500e-05
# Epoch 58/100
# 103/103 [==============================] - 15s 149ms/step - loss: 4.8486 - mean_absolute_error: 4.9236 - root_mean_squared_error: 7.6150 - mean_absolute_percentage_error: 20.4874 - val_loss: 5.5678 - val_mean_absolute_error: 5.6290 - val_root_mean_squared_error: 10.8226 - val_mean_absolute_percentage_error: 32.0701 - lr: 1.2500e-05
# Epoch 59/100
# 103/103 [==============================] - 15s 147ms/step - loss: 4.7578 - mean_absolute_error: 4.8304 - root_mean_squared_error: 7.6370 - mean_absolute_percentage_error: 20.0486 - val_loss: 5.5864 - val_mean_absolute_error: 5.6442 - val_root_mean_squared_error: 10.8301 - val_mean_absolute_percentage_error: 32.4702 - lr: 1.2500e-05
# Epoch 60/100
# 103/103 [==============================] - 15s 145ms/step - loss: 4.4111 - mean_absolute_error: 4.4836 - root_mean_squared_error: 7.2994 - mean_absolute_percentage_error: 18.6291 - val_loss: 5.6435 - val_mean_absolute_error: 5.7080 - val_root_mean_squared_error: 10.8962 - val_mean_absolute_percentage_error: 31.8808 - lr: 1.2500e-05
# Epoch 61/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.4859 - mean_absolute_error: 4.5626 - root_mean_squared_error: 6.9614 - mean_absolute_percentage_error: 19.8243 - val_loss: 5.5623 - val_mean_absolute_error: 5.6226 - val_root_mean_squared_error: 10.8417 - val_mean_absolute_percentage_error: 32.2750 - lr: 1.2500e-05
# Epoch 62/100
# 103/103 [==============================] - 15s 145ms/step - loss: 4.2376 - mean_absolute_error: 4.3108 - root_mean_squared_error: 6.5979 - mean_absolute_percentage_error: 19.7833 - val_loss: 5.6181 - val_mean_absolute_error: 5.6806 - val_root_mean_squared_error: 10.8412 - val_mean_absolute_percentage_error: 32.6037 - lr: 1.2500e-05
# Epoch 63/100
# 103/103 [==============================] - 15s 146ms/step - loss: 4.2009 - mean_absolute_error: 4.2763 - root_mean_squared_error: 6.4378 - mean_absolute_percentage_error: 18.3508 - val_loss: 5.6043 - val_mean_absolute_error: 5.6697 - val_root_mean_squared_error: 10.8509 - val_mean_absolute_percentage_error: 32.5578 - lr: 1.2500e-05
# Epoch 64/100
# 103/103 [==============================] - 15s 146ms/step - loss: 4.2966 - mean_absolute_error: 4.3685 - root_mean_squared_error: 6.7106 - mean_absolute_percentage_error: 18.4277 - val_loss: 5.6466 - val_mean_absolute_error: 5.7146 - val_root_mean_squared_error: 10.8827 - val_mean_absolute_percentage_error: 32.5767 - lr: 1.2500e-05
# Epoch 65/100
# 103/103 [==============================] - 15s 146ms/step - loss: 4.3554 - mean_absolute_error: 4.4290 - root_mean_squared_error: 6.9628 - mean_absolute_percentage_error: 19.2327 - val_loss: 5.6836 - val_mean_absolute_error: 5.7549 - val_root_mean_squared_error: 10.9037 - val_mean_absolute_percentage_error: 32.4096 - lr: 1.2500e-05
# Epoch 66/100
# 103/103 [==============================] - 15s 141ms/step - loss: 4.2235 - mean_absolute_error: 4.2941 - root_mean_squared_error: 6.7255 - mean_absolute_percentage_error: 19.3509 - val_loss: 5.5447 - val_mean_absolute_error: 5.6031 - val_root_mean_squared_error: 10.8467 - val_mean_absolute_percentage_error: 32.1378 - lr: 1.2500e-05
# Epoch 67/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.0963 - mean_absolute_error: 4.1689 - root_mean_squared_error: 6.5620 - mean_absolute_percentage_error: 17.9314 - val_loss: 5.5681 - val_mean_absolute_error: 5.6358 - val_root_mean_squared_error: 10.8337 - val_mean_absolute_percentage_error: 32.3310 - lr: 1.2500e-05
# Epoch 68/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.3120 - mean_absolute_error: 4.3856 - root_mean_squared_error: 6.8808 - mean_absolute_percentage_error: 18.4623 - val_loss: 5.6695 - val_mean_absolute_error: 5.7434 - val_root_mean_squared_error: 10.8719 - val_mean_absolute_percentage_error: 32.5040 - lr: 1.2500e-05
# Epoch 69/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.5409 - mean_absolute_error: 4.6194 - root_mean_squared_error: 7.2032 - mean_absolute_percentage_error: 19.4028 - val_loss: 5.6313 - val_mean_absolute_error: 5.7048 - val_root_mean_squared_error: 10.8814 - val_mean_absolute_percentage_error: 32.4839 - lr: 1.2500e-05
# Epoch 70/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.1285 - mean_absolute_error: 4.2053 - root_mean_squared_error: 6.4536 - mean_absolute_percentage_error: 17.8754 - val_loss: 5.5641 - val_mean_absolute_error: 5.6373 - val_root_mean_squared_error: 10.8212 - val_mean_absolute_percentage_error: 32.1794 - lr: 1.2500e-05
# Epoch 71/100
# 103/103 [==============================] - 15s 149ms/step - loss: 4.1143 - mean_absolute_error: 4.1913 - root_mean_squared_error: 6.3431 - mean_absolute_percentage_error: 18.2723 - val_loss: 5.7381 - val_mean_absolute_error: 5.8132 - val_root_mean_squared_error: 10.8675 - val_mean_absolute_percentage_error: 32.8351 - lr: 1.2500e-05
# Epoch 72/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.6184 - mean_absolute_error: 4.6966 - root_mean_squared_error: 7.2139 - mean_absolute_percentage_error: 20.5970 - val_loss: 5.5927 - val_mean_absolute_error: 5.6651 - val_root_mean_squared_error: 10.8295 - val_mean_absolute_percentage_error: 32.3023 - lr: 6.2500e-06
# Epoch 73/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.4674 - mean_absolute_error: 4.5452 - root_mean_squared_error: 7.2926 - mean_absolute_percentage_error: 19.2398 - val_loss: 5.4921 - val_mean_absolute_error: 5.5527 - val_root_mean_squared_error: 10.8288 - val_mean_absolute_percentage_error: 31.9530 - lr: 6.2500e-06
# Epoch 74/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.3128 - mean_absolute_error: 4.3880 - root_mean_squared_error: 6.9024 - mean_absolute_percentage_error: 17.7284 - val_loss: 5.5366 - val_mean_absolute_error: 5.6038 - val_root_mean_squared_error: 10.8433 - val_mean_absolute_percentage_error: 32.1007 - lr: 6.2500e-06
# Epoch 75/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.4835 - mean_absolute_error: 4.5588 - root_mean_squared_error: 7.1204 - mean_absolute_percentage_error: 19.7547 - val_loss: 5.5313 - val_mean_absolute_error: 5.6010 - val_root_mean_squared_error: 10.8263 - val_mean_absolute_percentage_error: 31.9514 - lr: 6.2500e-06
# Epoch 76/100
# 103/103 [==============================] - 15s 148ms/step - loss: 3.9915 - mean_absolute_error: 4.0699 - root_mean_squared_error: 6.2191 - mean_absolute_percentage_error: 17.2071 - val_loss: 5.4933 - val_mean_absolute_error: 5.5527 - val_root_mean_squared_error: 10.8335 - val_mean_absolute_percentage_error: 31.9598 - lr: 6.2500e-06
# Epoch 77/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.0782 - mean_absolute_error: 4.1580 - root_mean_squared_error: 6.3593 - mean_absolute_percentage_error: 18.3506 - val_loss: 5.6295 - val_mean_absolute_error: 5.6984 - val_root_mean_squared_error: 10.8728 - val_mean_absolute_percentage_error: 32.3647 - lr: 6.2500e-06
# Epoch 78/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.6468 - mean_absolute_error: 4.7254 - root_mean_squared_error: 7.3731 - mean_absolute_percentage_error: 19.4250 - val_loss: 5.5290 - val_mean_absolute_error: 5.5937 - val_root_mean_squared_error: 10.8429 - val_mean_absolute_percentage_error: 32.0801 - lr: 6.2500e-06
# Epoch 79/100
# 103/103 [==============================] - 15s 145ms/step - loss: 4.4511 - mean_absolute_error: 4.5288 - root_mean_squared_error: 6.9403 - mean_absolute_percentage_error: 19.5698 - val_loss: 5.5018 - val_mean_absolute_error: 5.5604 - val_root_mean_squared_error: 10.8344 - val_mean_absolute_percentage_error: 31.9585 - lr: 3.1250e-06
# Epoch 80/100
# 103/103 [==============================] - 15s 144ms/step - loss: 4.1176 - mean_absolute_error: 4.1920 - root_mean_squared_error: 6.4986 - mean_absolute_percentage_error: 18.6453 - val_loss: 5.5129 - val_mean_absolute_error: 5.5781 - val_root_mean_squared_error: 10.8402 - val_mean_absolute_percentage_error: 31.8487 - lr: 3.1250e-06
# Epoch 81/100
# 103/103 [==============================] - 15s 147ms/step - loss: 4.2484 - mean_absolute_error: 4.3282 - root_mean_squared_error: 6.6215 - mean_absolute_percentage_error: 18.6742 - val_loss: 5.5091 - val_mean_absolute_error: 5.5748 - val_root_mean_squared_error: 10.8372 - val_mean_absolute_percentage_error: 31.8439 - lr: 3.1250e-06
# Epoch 82/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.9355 - mean_absolute_error: 5.0159 - root_mean_squared_error: 7.6844 - mean_absolute_percentage_error: 21.0366 - val_loss: 5.5629 - val_mean_absolute_error: 5.6332 - val_root_mean_squared_error: 10.8421 - val_mean_absolute_percentage_error: 32.1051 - lr: 3.1250e-06
# Epoch 83/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.1242 - mean_absolute_error: 4.2029 - root_mean_squared_error: 6.4833 - mean_absolute_percentage_error: 18.5452 - val_loss: 5.6903 - val_mean_absolute_error: 5.7700 - val_root_mean_squared_error: 10.8791 - val_mean_absolute_percentage_error: 32.6294 - lr: 3.1250e-06
# Epoch 84/100
# 103/103 [==============================] - 15s 143ms/step - loss: 4.2602 - mean_absolute_error: 4.3374 - root_mean_squared_error: 6.7622 - mean_absolute_percentage_error: 18.7361 - val_loss: 5.6072 - val_mean_absolute_error: 5.6824 - val_root_mean_squared_error: 10.8550 - val_mean_absolute_percentage_error: 32.4007 - lr: 1.5625e-06
# Epoch 85/100
# 103/103 [==============================] - 15s 146ms/step - loss: 4.0908 - mean_absolute_error: 4.1664 - root_mean_squared_error: 6.4629 - mean_absolute_percentage_error: 18.2671 - val_loss: 5.5692 - val_mean_absolute_error: 5.6423 - val_root_mean_squared_error: 10.8481 - val_mean_absolute_percentage_error: 32.2807 - lr: 1.5625e-06
# Epoch 86/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.3686 - mean_absolute_error: 4.4471 - root_mean_squared_error: 6.8299 - mean_absolute_percentage_error: 19.0905 - val_loss: 5.5185 - val_mean_absolute_error: 5.5834 - val_root_mean_squared_error: 10.8427 - val_mean_absolute_percentage_error: 31.9865 - lr: 1.5625e-06
# Epoch 87/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.3275 - mean_absolute_error: 4.4056 - root_mean_squared_error: 6.8318 - mean_absolute_percentage_error: 18.6353 - val_loss: 5.5136 - val_mean_absolute_error: 5.5795 - val_root_mean_squared_error: 10.8427 - val_mean_absolute_percentage_error: 31.9370 - lr: 1.5625e-06
# Epoch 88/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.2275 - mean_absolute_error: 4.3046 - root_mean_squared_error: 6.8889 - mean_absolute_percentage_error: 18.5063 - val_loss: 5.5467 - val_mean_absolute_error: 5.6182 - val_root_mean_squared_error: 10.8491 - val_mean_absolute_percentage_error: 32.1180 - lr: 1.5625e-06
# Epoch 89/100
# 103/103 [==============================] - 15s 145ms/step - loss: 4.2951 - mean_absolute_error: 4.3745 - root_mean_squared_error: 6.7777 - mean_absolute_percentage_error: 18.9888 - val_loss: 5.5127 - val_mean_absolute_error: 5.5798 - val_root_mean_squared_error: 10.8428 - val_mean_absolute_percentage_error: 31.9538 - lr: 7.8125e-07
# Epoch 90/100
# 103/103 [==============================] - 14s 140ms/step - loss: 4.1212 - mean_absolute_error: 4.2010 - root_mean_squared_error: 6.4314 - mean_absolute_percentage_error: 18.9354 - val_loss: 5.5536 - val_mean_absolute_error: 5.6263 - val_root_mean_squared_error: 10.8467 - val_mean_absolute_percentage_error: 32.1681 - lr: 7.8125e-07
# Epoch 91/100
# 103/103 [==============================] - 14s 141ms/step - loss: 4.4559 - mean_absolute_error: 4.5332 - root_mean_squared_error: 7.0106 - mean_absolute_percentage_error: 19.1447 - val_loss: 5.5346 - val_mean_absolute_error: 5.6051 - val_root_mean_squared_error: 10.8488 - val_mean_absolute_percentage_error: 32.0463 - lr: 7.8125e-07
# Epoch 92/100
# 103/103 [==============================] - 17s 162ms/step - loss: 4.3025 - mean_absolute_error: 4.3823 - root_mean_squared_error: 6.8064 - mean_absolute_percentage_error: 19.2591 - val_loss: 5.5387 - val_mean_absolute_error: 5.6081 - val_root_mean_squared_error: 10.8519 - val_mean_absolute_percentage_error: 32.0907 - lr: 7.8125e-07
# Epoch 93/100
# 103/103 [==============================] - 18s 172ms/step - loss: 4.6137 - mean_absolute_error: 4.6973 - root_mean_squared_error: 7.0831 - mean_absolute_percentage_error: 20.9957 - val_loss: 5.6096 - val_mean_absolute_error: 5.6847 - val_root_mean_squared_error: 10.8647 - val_mean_absolute_percentage_error: 32.3418 - lr: 7.8125e-07
# Epoch 94/100
# 103/103 [==============================] - 22s 213ms/step - loss: 4.5373 - mean_absolute_error: 4.6195 - root_mean_squared_error: 7.1196 - mean_absolute_percentage_error: 19.5120 - val_loss: 5.7002 - val_mean_absolute_error: 5.7811 - val_root_mean_squared_error: 10.8867 - val_mean_absolute_percentage_error: 32.6528 - lr: 3.9062e-07
# Epoch 95/100
# 103/103 [==============================] - 20s 198ms/step - loss: 4.2721 - mean_absolute_error: 4.3506 - root_mean_squared_error: 6.6513 - mean_absolute_percentage_error: 18.6300 - val_loss: 5.6116 - val_mean_absolute_error: 5.6879 - val_root_mean_squared_error: 10.8623 - val_mean_absolute_percentage_error: 32.3702 - lr: 3.9062e-07
# Epoch 96/100
# 103/103 [==============================] - 18s 174ms/step - loss: 4.3072 - mean_absolute_error: 4.3884 - root_mean_squared_error: 6.7526 - mean_absolute_percentage_error: 19.1372 - val_loss: 5.5394 - val_mean_absolute_error: 5.6109 - val_root_mean_squared_error: 10.8434 - val_mean_absolute_percentage_error: 32.1014 - lr: 3.9062e-07
# Epoch 97/100
# 103/103 [==============================] - 22s 212ms/step - loss: 4.6966 - mean_absolute_error: 4.7794 - root_mean_squared_error: 7.4083 - mean_absolute_percentage_error: 20.5633 - val_loss: 5.5110 - val_mean_absolute_error: 5.5781 - val_root_mean_squared_error: 10.8405 - val_mean_absolute_percentage_error: 31.9794 - lr: 3.9062e-07
# Epoch 98/100
# 103/103 [==============================] - 17s 166ms/step - loss: 4.3330 - mean_absolute_error: 4.4112 - root_mean_squared_error: 6.7275 - mean_absolute_percentage_error: 17.8801 - val_loss: 5.5528 - val_mean_absolute_error: 5.6263 - val_root_mean_squared_error: 10.8390 - val_mean_absolute_percentage_error: 32.1817 - lr: 3.9062e-07
# Epoch 99/100
# 103/103 [==============================] - 21s 205ms/step - loss: 4.5385 - mean_absolute_error: 4.6199 - root_mean_squared_error: 7.2527 - mean_absolute_percentage_error: 19.5016 - val_loss: 5.5376 - val_mean_absolute_error: 5.6091 - val_root_mean_squared_error: 10.8328 - val_mean_absolute_percentage_error: 32.1042 - lr: 1.9531e-07
# Epoch 100/100
# 103/103 [==============================] - 19s 182ms/step - loss: 4.1557 - mean_absolute_error: 4.2362 - root_mean_squared_error: 6.6649 - mean_absolute_percentage_error: 17.7908 - val_loss: 5.5508 - val_mean_absolute_error: 5.6227 - val_root_mean_squared_error: 10.8385 - val_mean_absolute_percentage_error: 32.1440 - lr: 1.9531e-07

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 64ms/step - loss: 5.5508 - mean_absolute_error: 5.6227 - root_mean_squared_error: 10.8385 - mean_absolute_percentage_error: 32.1440
# Model Loss: [5.550766468048096, 5.622664928436279, 10.838458061218262, 32.144020080566406]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [14.124401]

# %%
model_scenario_name = "BiLSTM_12_512_Compare"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_12_512_Compare\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_12_512_Compare\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_12_512_Compare"
max_len = 512

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 512
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 2s 2s/step
# Predicted Putusan: [14.124401]
