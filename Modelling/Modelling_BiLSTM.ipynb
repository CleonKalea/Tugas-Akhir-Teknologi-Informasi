# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    276            128
# 4319                            0                    264            117
# 4320                            0                    287            117
# 4321                            0                    264            117
# 4322                            0                    287            117
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 37): [1051], (0, 21, 55): [1612], (0, 21, 57): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 39, 10): [294, 360, 387], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [134], (0, 46, 14): [260], (0, 47, 10): [211, 242, 243], (0, 47, 12): [145, 236, 237, 238, 239], (0, 47, 14): [149, 151], (0, 48, 10): [352], (0, 48, 16): [324, 325, 326, 384, 385], (0, 50, 12): [179, 195], (0, 52, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 52, 18): [651, 652], (0, 52, 19): [425, 426, 429, 547, 580, 635, 643], (0, 52, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 52, 21): [628, 647, 771], (0, 54, 10): [199, 250, 251, 252, 253], (0, 54, 12): [200], (0, 54, 14): [232], (0, 54, 16): [265], (0, 55, 15): [182], (0, 56, 10): [330], (0, 56, 16): [296, 389], (0, 56, 17): [366], (0, 57, 10): [198, 282, 283], (0, 57, 12): [201], (0, 57, 17): [364], (0, 58, 10): [380], (0, 58, 14): [327, 328], (0, 58, 16): [338], (0, 59, 14): [221, 222, 223, 224, 517, 614], (0, 59, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 59, 20): [433], (0, 59, 21): [645, 746], (0, 59, 23): [810, 834], (0, 59, 48): [1257, 1259], (0, 62, 10): [318, 333, 334, 368], (0, 62, 13): [292], (0, 62, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 62, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 62, 19): [440, 479, 593, 598], (0, 62, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 62, 21): [557], (0, 62, 22): [721], (0, 63, 10): [379], (0, 63, 19): [534, 535, 627, 814], (0, 63, 20): [630], (0, 64, 14): [408, 524, 540], (0, 64, 18): [753, 796], (0, 64, 19): [494, 508, 560, 561, 562, 588], (0, 64, 20): [455, 581], (0, 64, 21): [631, 641], (0, 65, 14): [610], (0, 65, 16): [409], (0, 65, 19): [500, 799, 800], (0, 65, 20): [476], (0, 65, 21): [638], (0, 66, 14): [484, 485], (0, 66, 20): [566, 567, 568, 738, 780], (0, 66 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_12600\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3273
# klasifikasi_perkara_encoded
# 0    1378
# 2    1251
# 3     289
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1050
# klasifikasi_perkara_encoded
# 0    490
# 2    438
# 4     51
# 3     48
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
nltk.download('stopwords')

stop_words = set(stopwords.words('indonesian'))

def remove_stopwords(text):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(remove_stopwords)
test_df['stopword_removal'] = test_df['normalized_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Kalea\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Stemming

# %%
stemmer = PorterStemmer()

def stem_text(text):
    return ' '.join([stemmer.stem(word) for word in text.split()])

train_df['stemmed_text'] = train_df['stopword_removal'].apply(stem_text)
test_df['stemmed_text'] = test_df['stopword_removal'].apply(stem_text)

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stemmed_text'])
train_sequences = tokenizer.texts_to_sequences(train_df['stemmed_text'])
test_sequences = tokenizer.texts_to_sequences(test_df['stemmed_text'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 14906

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 512
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 512

# %% [markdown]
# ### Numerical Features

# %% [markdown]
# ### Log Transform on Target and Maks Penjara Berdasarkan Pasal

# %%
# # LOG TARGET DAN MAKS PENJARA

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(train_df['maks_penjara_berdasarkan_pasal'])
# test_df['maks_penjara_berdasarkan_pasal_log'] = np.log1p(test_df['maks_penjara_berdasarkan_pasal'])

# train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal_log']].values, dtype=tf.float32)

# %%
# LOG TARGET ONLY

# y_train_log = np.log1p(y_train)
# y_test_log = np.log1p(y_test)

# train_numerical = tf.consstant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
# test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=256)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, return_sequences=True))(embedding_layer)
lstm_output_2 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True))(lstm_output)
lstm_output_3 = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(lstm_output_2)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(32, activation='relu')(numerical_input)
numerical_dense_2 = tf.keras.layers.Dense(16, activation='relu')(numerical_dense)

combined = tf.keras.layers.Concatenate()([lstm_output_3, numerical_dense_2])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
# reduce_lr_on_plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', patience=5, factor=0.5)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 512)]        0           []
#
#  embedding (Embedding)          (None, 512, 256)     3815936     ['text_input[0][0]']
#
#  bidirectional (Bidirectional)  (None, 512, 32)      34944       ['embedding[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional_1 (Bidirectional  (None, 512, 64)     16640       ['bidirectional[0][0]']
#  )
#
#  dense (Dense)                  (None, 32)           192         ['numerical_input[0][0]']
#
#  bidirectional_2 (Bidirectional  (None, 128)         66048       ['bidirectional_1[0][0]']
#  )
#
#  dense_1 (Dense)                (None, 16)           528         ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 144)          0           ['bidirectional_2[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 1)            145         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 3,934,433
# Trainable params: 3,934,433
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 22s 157ms/step - loss: 19.7709 - mean_absolute_error: 20.2640 - root_mean_squared_error: 29.7475 - mean_absolute_percentage_error: 101.0137 - val_loss: 16.1839 - val_mean_absolute_error: 16.6782 - val_root_mean_squared_error: 23.2358 - val_mean_absolute_percentage_error: 114.7377
# Epoch 2/100
# 103/103 [==============================] - 15s 146ms/step - loss: 13.5871 - mean_absolute_error: 14.0786 - root_mean_squared_error: 19.6842 - mean_absolute_percentage_error: 115.1122 - val_loss: 12.6127 - val_mean_absolute_error: 13.1023 - val_root_mean_squared_error: 19.4111 - val_mean_absolute_percentage_error: 108.8560
# Epoch 3/100
# 103/103 [==============================] - 15s 145ms/step - loss: 10.4569 - mean_absolute_error: 10.9418 - root_mean_squared_error: 16.5433 - mean_absolute_percentage_error: 90.2642 - val_loss: 11.1229 - val_mean_absolute_error: 11.6094 - val_root_mean_squared_error: 18.0343 - val_mean_absolute_percentage_error: 84.7801
# Epoch 4/100
# 103/103 [==============================] - 15s 143ms/step - loss: 8.8482 - mean_absolute_error: 9.3311 - root_mean_squared_error: 14.7109 - mean_absolute_percentage_error: 73.6926 - val_loss: 10.1384 - val_mean_absolute_error: 10.6205 - val_root_mean_squared_error: 17.1471 - val_mean_absolute_percentage_error: 77.6670
# Epoch 5/100
# 103/103 [==============================] - 15s 143ms/step - loss: 7.6613 - mean_absolute_error: 8.1385 - root_mean_squared_error: 13.4447 - mean_absolute_percentage_error: 62.3136 - val_loss: 9.7091 - val_mean_absolute_error: 10.1902 - val_root_mean_squared_error: 16.8180 - val_mean_absolute_percentage_error: 70.3745
# Epoch 6/100
# 103/103 [==============================] - 15s 142ms/step - loss: 6.4403 - mean_absolute_error: 6.9076 - root_mean_squared_error: 12.1976 - mean_absolute_percentage_error: 50.8856 - val_loss: 9.0782 - val_mean_absolute_error: 9.5539 - val_root_mean_squared_error: 16.4630 - val_mean_absolute_percentage_error: 59.4576
# Epoch 7/100
# 103/103 [==============================] - 15s 143ms/step - loss: 5.6411 - mean_absolute_error: 6.1096 - root_mean_squared_error: 11.3604 - mean_absolute_percentage_error: 42.8927 - val_loss: 8.9594 - val_mean_absolute_error: 9.4353 - val_root_mean_squared_error: 16.2569 - val_mean_absolute_percentage_error: 56.4882
# Epoch 8/100
# 103/103 [==============================] - 15s 142ms/step - loss: 5.0003 - mean_absolute_error: 5.4622 - root_mean_squared_error: 10.6080 - mean_absolute_percentage_error: 35.7752 - val_loss: 8.5304 - val_mean_absolute_error: 9.0003 - val_root_mean_squared_error: 15.5622 - val_mean_absolute_percentage_error: 58.2155
# Epoch 9/100
# 103/103 [==============================] - 15s 142ms/step - loss: 4.4924 - mean_absolute_error: 4.9477 - root_mean_squared_error: 9.9419 - mean_absolute_percentage_error: 31.3137 - val_loss: 8.2617 - val_mean_absolute_error: 8.7395 - val_root_mean_squared_error: 15.7492 - val_mean_absolute_percentage_error: 49.9809
# Epoch 10/100
# 103/103 [==============================] - 15s 146ms/step - loss: 3.9671 - mean_absolute_error: 4.4147 - root_mean_squared_error: 9.3713 - mean_absolute_percentage_error: 26.6325 - val_loss: 7.9757 - val_mean_absolute_error: 8.4472 - val_root_mean_squared_error: 15.2342 - val_mean_absolute_percentage_error: 50.4077
# Epoch 11/100
# 103/103 [==============================] - 15s 149ms/step - loss: 3.5664 - mean_absolute_error: 4.0043 - root_mean_squared_error: 8.9002 - mean_absolute_percentage_error: 23.7463 - val_loss: 7.7124 - val_mean_absolute_error: 8.1747 - val_root_mean_squared_error: 15.0129 - val_mean_absolute_percentage_error: 47.2671
# Epoch 12/100
# 103/103 [==============================] - 15s 143ms/step - loss: 3.3700 - mean_absolute_error: 3.8059 - root_mean_squared_error: 8.6319 - mean_absolute_percentage_error: 22.0775 - val_loss: 7.7287 - val_mean_absolute_error: 8.1963 - val_root_mean_squared_error: 14.9808 - val_mean_absolute_percentage_error: 48.8033
# Epoch 13/100
# 103/103 [==============================] - 15s 142ms/step - loss: 3.1558 - mean_absolute_error: 3.5854 - root_mean_squared_error: 8.4737 - mean_absolute_percentage_error: 19.6317 - val_loss: 7.6124 - val_mean_absolute_error: 8.0833 - val_root_mean_squared_error: 14.6846 - val_mean_absolute_percentage_error: 47.6472
# Epoch 14/100
# 103/103 [==============================] - 15s 142ms/step - loss: 2.8356 - mean_absolute_error: 3.2615 - root_mean_squared_error: 7.9653 - mean_absolute_percentage_error: 17.4439 - val_loss: 7.4630 - val_mean_absolute_error: 7.9151 - val_root_mean_squared_error: 14.6963 - val_mean_absolute_percentage_error: 44.9275
# Epoch 15/100
# 103/103 [==============================] - 15s 143ms/step - loss: 2.5713 - mean_absolute_error: 2.9839 - root_mean_squared_error: 7.5452 - mean_absolute_percentage_error: 16.0935 - val_loss: 7.3372 - val_mean_absolute_error: 7.7953 - val_root_mean_squared_error: 14.5485 - val_mean_absolute_percentage_error: 45.2137
# Epoch 16/100
# 103/103 [==============================] - 15s 144ms/step - loss: 2.4237 - mean_absolute_error: 2.8349 - root_mean_squared_error: 7.2223 - mean_absolute_percentage_error: 15.8052 - val_loss: 7.3005 - val_mean_absolute_error: 7.7558 - val_root_mean_squared_error: 14.5415 - val_mean_absolute_percentage_error: 44.4519
# Epoch 17/100
# 103/103 [==============================] - 15s 144ms/step - loss: 2.3597 - mean_absolute_error: 2.7771 - root_mean_squared_error: 7.0662 - mean_absolute_percentage_error: 15.5891 - val_loss: 7.0544 - val_mean_absolute_error: 7.5040 - val_root_mean_squared_error: 14.1299 - val_mean_absolute_percentage_error: 44.4127
# Epoch 18/100
# 103/103 [==============================] - 15s 145ms/step - loss: 2.1935 - mean_absolute_error: 2.6046 - root_mean_squared_error: 6.7624 - mean_absolute_percentage_error: 14.8765 - val_loss: 7.1484 - val_mean_absolute_error: 7.6123 - val_root_mean_squared_error: 14.1812 - val_mean_absolute_percentage_error: 44.5329
# Epoch 19/100
# 103/103 [==============================] - 16s 153ms/step - loss: 2.0399 - mean_absolute_error: 2.4389 - root_mean_squared_error: 6.5692 - mean_absolute_percentage_error: 13.9280 - val_loss: 6.9853 - val_mean_absolute_error: 7.4320 - val_root_mean_squared_error: 14.1362 - val_mean_absolute_percentage_error: 43.3407
# Epoch 20/100
# 103/103 [==============================] - 17s 165ms/step - loss: 1.9420 - mean_absolute_error: 2.3442 - root_mean_squared_error: 6.3195 - mean_absolute_percentage_error: 13.7218 - val_loss: 6.9398 - val_mean_absolute_error: 7.3866 - val_root_mean_squared_error: 14.0838 - val_mean_absolute_percentage_error: 42.2266
# Epoch 21/100
# 103/103 [==============================] - 17s 166ms/step - loss: 1.7915 - mean_absolute_error: 2.1850 - root_mean_squared_error: 6.0708 - mean_absolute_percentage_error: 12.6927 - val_loss: 7.0996 - val_mean_absolute_error: 7.5590 - val_root_mean_squared_error: 14.1583 - val_mean_absolute_percentage_error: 41.9001
# Epoch 22/100
# 103/103 [==============================] - 17s 165ms/step - loss: 1.7064 - mean_absolute_error: 2.0992 - root_mean_squared_error: 5.8203 - mean_absolute_percentage_error: 12.1316 - val_loss: 6.9409 - val_mean_absolute_error: 7.3850 - val_root_mean_squared_error: 14.0209 - val_mean_absolute_percentage_error: 42.8873
# Epoch 23/100
# 103/103 [==============================] - 17s 164ms/step - loss: 1.5974 - mean_absolute_error: 1.9742 - root_mean_squared_error: 5.6546 - mean_absolute_percentage_error: 11.3600 - val_loss: 6.8597 - val_mean_absolute_error: 7.3071 - val_root_mean_squared_error: 13.9366 - val_mean_absolute_percentage_error: 41.4732
# Epoch 24/100
# 103/103 [==============================] - 17s 166ms/step - loss: 1.5035 - mean_absolute_error: 1.8743 - root_mean_squared_error: 5.5446 - mean_absolute_percentage_error: 10.7201 - val_loss: 6.7474 - val_mean_absolute_error: 7.1860 - val_root_mean_squared_error: 13.7714 - val_mean_absolute_percentage_error: 41.7121
# Epoch 25/100
# 103/103 [==============================] - 17s 165ms/step - loss: 1.4797 - mean_absolute_error: 1.8579 - root_mean_squared_error: 5.4225 - mean_absolute_percentage_error: 10.6834 - val_loss: 6.7572 - val_mean_absolute_error: 7.1991 - val_root_mean_squared_error: 14.0774 - val_mean_absolute_percentage_error: 40.9557
# Epoch 26/100
# 103/103 [==============================] - 17s 165ms/step - loss: 1.4551 - mean_absolute_error: 1.8400 - root_mean_squared_error: 5.3206 - mean_absolute_percentage_error: 10.5881 - val_loss: 6.7175 - val_mean_absolute_error: 7.1592 - val_root_mean_squared_error: 13.7534 - val_mean_absolute_percentage_error: 40.4750
# Epoch 27/100
# 103/103 [==============================] - 17s 165ms/step - loss: 1.3600 - mean_absolute_error: 1.7373 - root_mean_squared_error: 5.1483 - mean_absolute_percentage_error: 9.8126 - val_loss: 6.6064 - val_mean_absolute_error: 7.0515 - val_root_mean_squared_error: 13.6468 - val_mean_absolute_percentage_error: 39.5613
# Epoch 28/100
# 103/103 [==============================] - 18s 179ms/step - loss: 1.2621 - mean_absolute_error: 1.6286 - root_mean_squared_error: 4.9787 - mean_absolute_percentage_error: 9.1107 - val_loss: 6.5428 - val_mean_absolute_error: 6.9799 - val_root_mean_squared_error: 13.6043 - val_mean_absolute_percentage_error: 39.9019
# Epoch 29/100
# 103/103 [==============================] - 15s 146ms/step - loss: 1.2268 - mean_absolute_error: 1.5920 - root_mean_squared_error: 4.8998 - mean_absolute_percentage_error: 8.7765 - val_loss: 6.6169 - val_mean_absolute_error: 7.0660 - val_root_mean_squared_error: 13.6969 - val_mean_absolute_percentage_error: 39.5064
# Epoch 30/100
# 103/103 [==============================] - 15s 143ms/step - loss: 1.2852 - mean_absolute_error: 1.6668 - root_mean_squared_error: 4.9768 - mean_absolute_percentage_error: 9.8414 - val_loss: 6.5944 - val_mean_absolute_error: 7.0337 - val_root_mean_squared_error: 13.6486 - val_mean_absolute_percentage_error: 40.2921
# Epoch 31/100
# 103/103 [==============================] - 15s 144ms/step - loss: 1.2054 - mean_absolute_error: 1.5794 - root_mean_squared_error: 4.8347 - mean_absolute_percentage_error: 8.9743 - val_loss: 6.5010 - val_mean_absolute_error: 6.9421 - val_root_mean_squared_error: 13.5378 - val_mean_absolute_percentage_error: 38.9300
# Epoch 32/100
# 103/103 [==============================] - 15s 143ms/step - loss: 1.1048 - mean_absolute_error: 1.4635 - root_mean_squared_error: 4.6990 - mean_absolute_percentage_error: 8.1026 - val_loss: 6.5174 - val_mean_absolute_error: 6.9514 - val_root_mean_squared_error: 13.6351 - val_mean_absolute_percentage_error: 39.6872
# Epoch 33/100
# 103/103 [==============================] - 15s 144ms/step - loss: 1.0135 - mean_absolute_error: 1.3473 - root_mean_squared_error: 4.5639 - mean_absolute_percentage_error: 7.6874 - val_loss: 6.5339 - val_mean_absolute_error: 6.9536 - val_root_mean_squared_error: 13.7635 - val_mean_absolute_percentage_error: 40.1551
# Epoch 34/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.9886 - mean_absolute_error: 1.3234 - root_mean_squared_error: 4.4514 - mean_absolute_percentage_error: 7.2708 - val_loss: 6.5339 - val_mean_absolute_error: 6.9585 - val_root_mean_squared_error: 13.6491 - val_mean_absolute_percentage_error: 39.5483
# Epoch 35/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.9439 - mean_absolute_error: 1.2839 - root_mean_squared_error: 4.3475 - mean_absolute_percentage_error: 7.3857 - val_loss: 6.3902 - val_mean_absolute_error: 6.8125 - val_root_mean_squared_error: 13.4673 - val_mean_absolute_percentage_error: 37.9577
# Epoch 36/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.9472 - mean_absolute_error: 1.2947 - root_mean_squared_error: 4.3056 - mean_absolute_percentage_error: 7.2902 - val_loss: 6.5345 - val_mean_absolute_error: 6.9698 - val_root_mean_squared_error: 13.7547 - val_mean_absolute_percentage_error: 39.8957
# Epoch 37/100
# 103/103 [==============================] - 15s 146ms/step - loss: 0.8964 - mean_absolute_error: 1.2344 - root_mean_squared_error: 4.1683 - mean_absolute_percentage_error: 6.9197 - val_loss: 6.3088 - val_mean_absolute_error: 6.7306 - val_root_mean_squared_error: 13.2852 - val_mean_absolute_percentage_error: 38.4477
# Epoch 38/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.8670 - mean_absolute_error: 1.1964 - root_mean_squared_error: 4.1904 - mean_absolute_percentage_error: 6.9345 - val_loss: 6.4937 - val_mean_absolute_error: 6.9261 - val_root_mean_squared_error: 13.5491 - val_mean_absolute_percentage_error: 38.2991
# Epoch 39/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.8594 - mean_absolute_error: 1.1902 - root_mean_squared_error: 4.0709 - mean_absolute_percentage_error: 6.7759 - val_loss: 6.4417 - val_mean_absolute_error: 6.8731 - val_root_mean_squared_error: 13.5238 - val_mean_absolute_percentage_error: 38.4213
# Epoch 40/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.7957 - mean_absolute_error: 1.1303 - root_mean_squared_error: 3.9263 - mean_absolute_percentage_error: 6.1490 - val_loss: 6.3423 - val_mean_absolute_error: 6.7674 - val_root_mean_squared_error: 13.4172 - val_mean_absolute_percentage_error: 37.3603
# Epoch 41/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.8194 - mean_absolute_error: 1.1580 - root_mean_squared_error: 4.0471 - mean_absolute_percentage_error: 6.3759 - val_loss: 6.3231 - val_mean_absolute_error: 6.7395 - val_root_mean_squared_error: 13.4620 - val_mean_absolute_percentage_error: 38.9245
# Epoch 42/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.7858 - mean_absolute_error: 1.1116 - root_mean_squared_error: 3.9093 - mean_absolute_percentage_error: 6.0565 - val_loss: 6.3471 - val_mean_absolute_error: 6.7729 - val_root_mean_squared_error: 13.4203 - val_mean_absolute_percentage_error: 38.3172
# Epoch 43/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.7204 - mean_absolute_error: 1.0325 - root_mean_squared_error: 3.9029 - mean_absolute_percentage_error: 5.8974 - val_loss: 6.3153 - val_mean_absolute_error: 6.7400 - val_root_mean_squared_error: 13.4099 - val_mean_absolute_percentage_error: 37.5037
# Epoch 44/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.6915 - mean_absolute_error: 1.0060 - root_mean_squared_error: 3.7343 - mean_absolute_percentage_error: 5.5518 - val_loss: 6.3311 - val_mean_absolute_error: 6.7756 - val_root_mean_squared_error: 13.3551 - val_mean_absolute_percentage_error: 37.8477
# Epoch 45/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.6734 - mean_absolute_error: 0.9862 - root_mean_squared_error: 3.6933 - mean_absolute_percentage_error: 5.2587 - val_loss: 6.3829 - val_mean_absolute_error: 6.8111 - val_root_mean_squared_error: 13.5220 - val_mean_absolute_percentage_error: 38.5979
# Epoch 46/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.7308 - mean_absolute_error: 1.0584 - root_mean_squared_error: 3.7304 - mean_absolute_percentage_error: 5.9049 - val_loss: 6.2543 - val_mean_absolute_error: 6.6785 - val_root_mean_squared_error: 13.3725 - val_mean_absolute_percentage_error: 37.8658
# Epoch 47/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.6511 - mean_absolute_error: 0.9616 - root_mean_squared_error: 3.6317 - mean_absolute_percentage_error: 5.2597 - val_loss: 6.1844 - val_mean_absolute_error: 6.5982 - val_root_mean_squared_error: 13.2760 - val_mean_absolute_percentage_error: 38.1640
# Epoch 48/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.6885 - mean_absolute_error: 1.0187 - root_mean_squared_error: 3.5970 - mean_absolute_percentage_error: 5.8397 - val_loss: 6.3558 - val_mean_absolute_error: 6.7800 - val_root_mean_squared_error: 13.5183 - val_mean_absolute_percentage_error: 38.4975
# Epoch 49/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.6477 - mean_absolute_error: 0.9588 - root_mean_squared_error: 3.6936 - mean_absolute_percentage_error: 5.1678 - val_loss: 6.2381 - val_mean_absolute_error: 6.6613 - val_root_mean_squared_error: 13.3410 - val_mean_absolute_percentage_error: 37.5794
# Epoch 50/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.6247 - mean_absolute_error: 0.9286 - root_mean_squared_error: 3.5281 - mean_absolute_percentage_error: 5.0641 - val_loss: 6.2300 - val_mean_absolute_error: 6.6409 - val_root_mean_squared_error: 13.4231 - val_mean_absolute_percentage_error: 37.3872
# Epoch 51/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.6412 - mean_absolute_error: 0.9467 - root_mean_squared_error: 3.7552 - mean_absolute_percentage_error: 4.8977 - val_loss: 6.2560 - val_mean_absolute_error: 6.6702 - val_root_mean_squared_error: 13.3879 - val_mean_absolute_percentage_error: 37.7584
# Epoch 52/100
# 103/103 [==============================] - 14s 141ms/step - loss: 0.6003 - mean_absolute_error: 0.8977 - root_mean_squared_error: 3.5019 - mean_absolute_percentage_error: 4.7985 - val_loss: 6.2537 - val_mean_absolute_error: 6.6698 - val_root_mean_squared_error: 13.3835 - val_mean_absolute_percentage_error: 38.4356
# Epoch 53/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.5488 - mean_absolute_error: 0.8383 - root_mean_squared_error: 3.3958 - mean_absolute_percentage_error: 4.5612 - val_loss: 6.2278 - val_mean_absolute_error: 6.6418 - val_root_mean_squared_error: 13.3307 - val_mean_absolute_percentage_error: 38.2608
# Epoch 54/100
# 103/103 [==============================] - 15s 141ms/step - loss: 0.5847 - mean_absolute_error: 0.8861 - root_mean_squared_error: 3.3757 - mean_absolute_percentage_error: 4.8013 - val_loss: 6.2317 - val_mean_absolute_error: 6.6633 - val_root_mean_squared_error: 13.2563 - val_mean_absolute_percentage_error: 37.5356
# Epoch 55/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.5623 - mean_absolute_error: 0.8658 - root_mean_squared_error: 3.2485 - mean_absolute_percentage_error: 4.7159 - val_loss: 6.1645 - val_mean_absolute_error: 6.5936 - val_root_mean_squared_error: 13.1156 - val_mean_absolute_percentage_error: 38.0899
# Epoch 56/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.5235 - mean_absolute_error: 0.8173 - root_mean_squared_error: 3.1559 - mean_absolute_percentage_error: 4.3240 - val_loss: 6.1811 - val_mean_absolute_error: 6.6280 - val_root_mean_squared_error: 13.1809 - val_mean_absolute_percentage_error: 36.3616
# Epoch 57/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.5321 - mean_absolute_error: 0.8296 - root_mean_squared_error: 3.1340 - mean_absolute_percentage_error: 4.6032 - val_loss: 6.1523 - val_mean_absolute_error: 6.5693 - val_root_mean_squared_error: 13.1612 - val_mean_absolute_percentage_error: 38.8171
# Epoch 58/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.5408 - mean_absolute_error: 0.8464 - root_mean_squared_error: 3.2381 - mean_absolute_percentage_error: 4.7421 - val_loss: 6.1491 - val_mean_absolute_error: 6.5740 - val_root_mean_squared_error: 13.1482 - val_mean_absolute_percentage_error: 38.3464
# Epoch 59/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.5260 - mean_absolute_error: 0.8246 - root_mean_squared_error: 3.0941 - mean_absolute_percentage_error: 4.8839 - val_loss: 6.1037 - val_mean_absolute_error: 6.5225 - val_root_mean_squared_error: 13.1612 - val_mean_absolute_percentage_error: 36.8261
# Epoch 60/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.4939 - mean_absolute_error: 0.7902 - root_mean_squared_error: 3.0246 - mean_absolute_percentage_error: 4.6149 - val_loss: 6.0932 - val_mean_absolute_error: 6.5009 - val_root_mean_squared_error: 13.1622 - val_mean_absolute_percentage_error: 37.0787
# Epoch 61/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.4486 - mean_absolute_error: 0.7337 - root_mean_squared_error: 2.9442 - mean_absolute_percentage_error: 4.2626 - val_loss: 6.0854 - val_mean_absolute_error: 6.4981 - val_root_mean_squared_error: 13.1153 - val_mean_absolute_percentage_error: 37.2666
# Epoch 62/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.4395 - mean_absolute_error: 0.7273 - root_mean_squared_error: 2.9040 - mean_absolute_percentage_error: 4.1977 - val_loss: 6.1177 - val_mean_absolute_error: 6.5193 - val_root_mean_squared_error: 13.2459 - val_mean_absolute_percentage_error: 37.5357
# Epoch 63/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.4516 - mean_absolute_error: 0.7444 - root_mean_squared_error: 2.8779 - mean_absolute_percentage_error: 4.1818 - val_loss: 6.1290 - val_mean_absolute_error: 6.5408 - val_root_mean_squared_error: 13.1988 - val_mean_absolute_percentage_error: 37.6557
# Epoch 64/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.4400 - mean_absolute_error: 0.7249 - root_mean_squared_error: 2.8049 - mean_absolute_percentage_error: 3.9668 - val_loss: 6.1255 - val_mean_absolute_error: 6.5253 - val_root_mean_squared_error: 13.2578 - val_mean_absolute_percentage_error: 38.1267
# Epoch 65/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.4658 - mean_absolute_error: 0.7517 - root_mean_squared_error: 2.9580 - mean_absolute_percentage_error: 4.3082 - val_loss: 6.8071 - val_mean_absolute_error: 7.2309 - val_root_mean_squared_error: 14.3062 - val_mean_absolute_percentage_error: 46.0821
# Epoch 66/100
# 103/103 [==============================] - 15s 149ms/step - loss: 0.5914 - mean_absolute_error: 0.9142 - root_mean_squared_error: 3.2160 - mean_absolute_percentage_error: 5.2216 - val_loss: 6.2943 - val_mean_absolute_error: 6.7395 - val_root_mean_squared_error: 13.3897 - val_mean_absolute_percentage_error: 38.4380
# Epoch 67/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.4984 - mean_absolute_error: 0.8072 - root_mean_squared_error: 3.1475 - mean_absolute_percentage_error: 4.7536 - val_loss: 6.1976 - val_mean_absolute_error: 6.6274 - val_root_mean_squared_error: 13.2774 - val_mean_absolute_percentage_error: 38.2154
# Epoch 68/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.4132 - mean_absolute_error: 0.7030 - root_mean_squared_error: 2.6862 - mean_absolute_percentage_error: 4.0710 - val_loss: 6.1053 - val_mean_absolute_error: 6.5103 - val_root_mean_squared_error: 13.2570 - val_mean_absolute_percentage_error: 36.5202
# Epoch 69/100
# 103/103 [==============================] - 15s 147ms/step - loss: 0.3919 - mean_absolute_error: 0.6628 - root_mean_squared_error: 2.6439 - mean_absolute_percentage_error: 3.6896 - val_loss: 6.1528 - val_mean_absolute_error: 6.5535 - val_root_mean_squared_error: 13.3488 - val_mean_absolute_percentage_error: 37.9402
# Epoch 70/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.3915 - mean_absolute_error: 0.6724 - root_mean_squared_error: 2.5844 - mean_absolute_percentage_error: 3.7179 - val_loss: 6.1771 - val_mean_absolute_error: 6.5773 - val_root_mean_squared_error: 13.3650 - val_mean_absolute_percentage_error: 38.0489
# Epoch 71/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.3608 - mean_absolute_error: 0.6310 - root_mean_squared_error: 2.5414 - mean_absolute_percentage_error: 3.7436 - val_loss: 6.1840 - val_mean_absolute_error: 6.5835 - val_root_mean_squared_error: 13.4461 - val_mean_absolute_percentage_error: 37.6613
# Epoch 72/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.3631 - mean_absolute_error: 0.6371 - root_mean_squared_error: 2.5055 - mean_absolute_percentage_error: 3.6440 - val_loss: 6.2011 - val_mean_absolute_error: 6.6066 - val_root_mean_squared_error: 13.4861 - val_mean_absolute_percentage_error: 38.3228
# Epoch 73/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.3443 - mean_absolute_error: 0.6078 - root_mean_squared_error: 2.4598 - mean_absolute_percentage_error: 3.4594 - val_loss: 6.1961 - val_mean_absolute_error: 6.5989 - val_root_mean_squared_error: 13.4492 - val_mean_absolute_percentage_error: 37.9342
# Epoch 74/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.3477 - mean_absolute_error: 0.6170 - root_mean_squared_error: 2.4803 - mean_absolute_percentage_error: 3.7025 - val_loss: 6.1804 - val_mean_absolute_error: 6.5792 - val_root_mean_squared_error: 13.4158 - val_mean_absolute_percentage_error: 38.7025
# Epoch 75/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.3111 - mean_absolute_error: 0.5604 - root_mean_squared_error: 2.4127 - mean_absolute_percentage_error: 3.4207 - val_loss: 6.1614 - val_mean_absolute_error: 6.5501 - val_root_mean_squared_error: 13.3634 - val_mean_absolute_percentage_error: 38.4018
# Epoch 76/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.2994 - mean_absolute_error: 0.5451 - root_mean_squared_error: 2.3563 - mean_absolute_percentage_error: 3.1109 - val_loss: 6.1085 - val_mean_absolute_error: 6.5064 - val_root_mean_squared_error: 13.3407 - val_mean_absolute_percentage_error: 37.3383
# Epoch 77/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.3035 - mean_absolute_error: 0.5647 - root_mean_squared_error: 2.3116 - mean_absolute_percentage_error: 3.3252 - val_loss: 6.0941 - val_mean_absolute_error: 6.4940 - val_root_mean_squared_error: 13.2839 - val_mean_absolute_percentage_error: 37.4272
# Epoch 78/100
# 103/103 [==============================] - 15s 148ms/step - loss: 0.2858 - mean_absolute_error: 0.5276 - root_mean_squared_error: 2.2795 - mean_absolute_percentage_error: 2.9838 - val_loss: 6.0838 - val_mean_absolute_error: 6.4774 - val_root_mean_squared_error: 13.2826 - val_mean_absolute_percentage_error: 38.4941
# Epoch 79/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.2798 - mean_absolute_error: 0.5195 - root_mean_squared_error: 2.2710 - mean_absolute_percentage_error: 2.9833 - val_loss: 6.0531 - val_mean_absolute_error: 6.4423 - val_root_mean_squared_error: 13.2211 - val_mean_absolute_percentage_error: 37.2071
# Epoch 80/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.2797 - mean_absolute_error: 0.5312 - root_mean_squared_error: 2.2259 - mean_absolute_percentage_error: 3.0758 - val_loss: 6.0814 - val_mean_absolute_error: 6.4862 - val_root_mean_squared_error: 13.2558 - val_mean_absolute_percentage_error: 38.2150
# Epoch 81/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.2761 - mean_absolute_error: 0.5353 - root_mean_squared_error: 2.1851 - mean_absolute_percentage_error: 3.2028 - val_loss: 6.1529 - val_mean_absolute_error: 6.5887 - val_root_mean_squared_error: 13.2477 - val_mean_absolute_percentage_error: 39.5937
# Epoch 82/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.2758 - mean_absolute_error: 0.5248 - root_mean_squared_error: 2.1718 - mean_absolute_percentage_error: 3.1313 - val_loss: 6.1426 - val_mean_absolute_error: 6.5727 - val_root_mean_squared_error: 13.3047 - val_mean_absolute_percentage_error: 37.8716
# Epoch 83/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.2777 - mean_absolute_error: 0.5333 - root_mean_squared_error: 2.1525 - mean_absolute_percentage_error: 3.0576 - val_loss: 6.1423 - val_mean_absolute_error: 6.5420 - val_root_mean_squared_error: 13.3785 - val_mean_absolute_percentage_error: 37.2545
# Epoch 84/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.2886 - mean_absolute_error: 0.5405 - root_mean_squared_error: 2.1694 - mean_absolute_percentage_error: 2.9956 - val_loss: 6.4303 - val_mean_absolute_error: 6.8504 - val_root_mean_squared_error: 14.8080 - val_mean_absolute_percentage_error: 39.2457
# Epoch 85/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.3994 - mean_absolute_error: 0.6685 - root_mean_squared_error: 3.5339 - mean_absolute_percentage_error: 3.5320 - val_loss: 6.6736 - val_mean_absolute_error: 7.1068 - val_root_mean_squared_error: 15.3235 - val_mean_absolute_percentage_error: 46.3509
# Epoch 86/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.8929 - mean_absolute_error: 1.2480 - root_mean_squared_error: 5.3383 - mean_absolute_percentage_error: 9.6387 - val_loss: 6.3110 - val_mean_absolute_error: 6.7411 - val_root_mean_squared_error: 13.3571 - val_mean_absolute_percentage_error: 39.8471
# Epoch 87/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.5502 - mean_absolute_error: 0.8734 - root_mean_squared_error: 2.7298 - mean_absolute_percentage_error: 5.0758 - val_loss: 6.1682 - val_mean_absolute_error: 6.5981 - val_root_mean_squared_error: 13.3220 - val_mean_absolute_percentage_error: 39.5368
# Epoch 88/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.3680 - mean_absolute_error: 0.6510 - root_mean_squared_error: 2.3180 - mean_absolute_percentage_error: 3.7598 - val_loss: 6.0322 - val_mean_absolute_error: 6.4454 - val_root_mean_squared_error: 13.2280 - val_mean_absolute_percentage_error: 38.5338
# Epoch 89/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.2755 - mean_absolute_error: 0.5219 - root_mean_squared_error: 2.1597 - mean_absolute_percentage_error: 3.0690 - val_loss: 6.0817 - val_mean_absolute_error: 6.4869 - val_root_mean_squared_error: 13.4197 - val_mean_absolute_percentage_error: 38.8325
# Epoch 90/100
# 103/103 [==============================] - 15s 148ms/step - loss: 0.2943 - mean_absolute_error: 0.5311 - root_mean_squared_error: 2.3884 - mean_absolute_percentage_error: 3.0016 - val_loss: 6.0746 - val_mean_absolute_error: 6.4799 - val_root_mean_squared_error: 13.3785 - val_mean_absolute_percentage_error: 38.1964
# Epoch 91/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.2591 - mean_absolute_error: 0.4979 - root_mean_squared_error: 2.0893 - mean_absolute_percentage_error: 2.8234 - val_loss: 6.0161 - val_mean_absolute_error: 6.4098 - val_root_mean_squared_error: 13.3531 - val_mean_absolute_percentage_error: 38.1310
# Epoch 92/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.2659 - mean_absolute_error: 0.5229 - root_mean_squared_error: 2.0601 - mean_absolute_percentage_error: 3.0052 - val_loss: 6.0428 - val_mean_absolute_error: 6.4539 - val_root_mean_squared_error: 13.3117 - val_mean_absolute_percentage_error: 38.4393
# Epoch 93/100
# 103/103 [==============================] - 15s 141ms/step - loss: 0.2389 - mean_absolute_error: 0.4697 - root_mean_squared_error: 1.9982 - mean_absolute_percentage_error: 2.6934 - val_loss: 6.0214 - val_mean_absolute_error: 6.4535 - val_root_mean_squared_error: 13.0640 - val_mean_absolute_percentage_error: 39.2447
# Epoch 94/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.2375 - mean_absolute_error: 0.4635 - root_mean_squared_error: 1.9908 - mean_absolute_percentage_error: 2.5912 - val_loss: 5.9159 - val_mean_absolute_error: 6.3015 - val_root_mean_squared_error: 13.0235 - val_mean_absolute_percentage_error: 37.4967
# Epoch 95/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.2139 - mean_absolute_error: 0.4225 - root_mean_squared_error: 1.9474 - mean_absolute_percentage_error: 2.3626 - val_loss: 5.9591 - val_mean_absolute_error: 6.3403 - val_root_mean_squared_error: 13.1233 - val_mean_absolute_percentage_error: 38.1036
# Epoch 96/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.2048 - mean_absolute_error: 0.4124 - root_mean_squared_error: 1.9019 - mean_absolute_percentage_error: 2.4261 - val_loss: 5.9031 - val_mean_absolute_error: 6.2796 - val_root_mean_squared_error: 13.0326 - val_mean_absolute_percentage_error: 38.0668
# Epoch 97/100
# 103/103 [==============================] - 15s 143ms/step - loss: 0.1983 - mean_absolute_error: 0.4002 - root_mean_squared_error: 1.8895 - mean_absolute_percentage_error: 2.2878 - val_loss: 5.9461 - val_mean_absolute_error: 6.3208 - val_root_mean_squared_error: 13.1535 - val_mean_absolute_percentage_error: 37.9001
# Epoch 98/100
# 103/103 [==============================] - 15s 145ms/step - loss: 0.1882 - mean_absolute_error: 0.3913 - root_mean_squared_error: 1.8843 - mean_absolute_percentage_error: 2.4021 - val_loss: 5.9132 - val_mean_absolute_error: 6.2913 - val_root_mean_squared_error: 13.0738 - val_mean_absolute_percentage_error: 37.7147
# Epoch 99/100
# 103/103 [==============================] - 15s 144ms/step - loss: 0.1906 - mean_absolute_error: 0.4042 - root_mean_squared_error: 1.8262 - mean_absolute_percentage_error: 2.4114 - val_loss: 5.9211 - val_mean_absolute_error: 6.2977 - val_root_mean_squared_error: 13.1024 - val_mean_absolute_percentage_error: 37.6526
# Epoch 100/100
# 103/103 [==============================] - 15s 142ms/step - loss: 0.1972 - mean_absolute_error: 0.4142 - root_mean_squared_error: 1.8193 - mean_absolute_percentage_error: 2.3937 - val_loss: 5.9258 - val_mean_absolute_error: 6.3214 - val_root_mean_squared_error: 13.0792 - val_mean_absolute_percentage_error: 38.0664

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 2s 63ms/step - loss: 5.9258 - mean_absolute_error: 6.3214 - root_mean_squared_error: 13.0792 - mean_absolute_percentage_error: 38.0664
# Model Loss: [5.925780773162842, 6.321356296539307, 13.079180717468262, 38.066410064697266]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [23.772284]

# %%
model_scenario_name = "BiLSTM_3"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 12). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_3\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_3\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_3"
max_len = 512

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted Putusan: [23.772284]
