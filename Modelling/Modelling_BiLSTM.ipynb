# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import tensorflow as tf
import nltk
from nltk.corpus import stopwords
import re
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt
import pickle

from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %% [markdown]
# ## Data Preparation

# %%
df = pd.read_csv('../Data/STAGE 4 FINAL MERGED DATA/STAGE_4_MERGED_FINAL_ENCODED.csv')

# %%
df
# Out:
#       klasifikasi_perkara_encoded  penuntut_umum_encoded  hakim_encoded  \
# 0                               0                      0              0
# 1                               1                      1              1
# 2                               0                      0              2
# 3                               2                      2              1
# 4                               2                      3              1
# ...                           ...                    ...            ...
# 4318                            2                    269            118
# 4319                            0                    257            107
# 4320                            0                    280            107
# 4321                            0                    257            107
# 4322                            0                    280            107
#
#       jumlah_saksi  maks_penjara_berdasarkan_pasal  \
# 0                6                              80
# 1                4                              48
# 2                6                              84
# 3                2                             144
# 4                2                             144
# ...            ...                             ...
# 4318             2                             240
# 4319             2                              84
# 4320             2                              84
# 4321             2                              84
# 4322             2                              84
#
#                                         terdakwa  \
# 0                                 GEDE DARMAYASA
# 1                    IDA BAGUS MADE DARMA WIGUNA
# 2                                 HANDRI JOHANAS
# 3                     I GEDE ARIADI alias BERNAD
# 4                     I GEDE ARIADI alias BERNAD
# ...                                          ...
# 4318  NURUL FIQRI SUDIRMAN als KIKI bin SUDIRMAN
# 4319                          SUPRIADI BIN RATIM
# 4320                          SUPRIADI BIN RATIM
# 4321             ANWAR RURI BIN SYARIFUDIN USMAN
# 4322             ANWAR RURI BIN SYARIFUDIN USMAN
#
#                                      summarized_dakwaan  \
# 0     Terdakwa Gede Darmayasa didakwa telah melakuka...
# 1     Pada bulan Februari dan Maret 2024, terdakwa I...
# 2     Terdakwa Handri Johanes pada Rabu, 24 April 20...
# 3     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# 4     Pada hari Minggu, 14 April 2024 sekitar pukul ...
# ...                                                 ...
# 4318  Pada Jumat, 31 Maret 2023, sekitar pukul 20.30...
# 4319  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4320  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4321  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
# 4322  Pada hari Minggu, 28 Mei 2023, sekitar pukul 1...
#
#       total_pidana_penjara_bulan
# 0                            5.0
# 1                           24.0
# 2                            4.0
# 3                           14.0
# 4                           14.0
# ...                          ...
# 4318                        72.0
# 4319                        16.0
# 4320                        16.0
# 4321                        16.0
# 4322                        16.0
#
# [4323 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4323 entries, 0 to 4322
# Data columns (total 8 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   klasifikasi_perkara_encoded     4323 non-null   int64
#  1   penuntut_umum_encoded           4323 non-null   int64
#  2   hakim_encoded                   4323 non-null   int64
#  3   jumlah_saksi                    4323 non-null   int64
#  4   maks_penjara_berdasarkan_pasal  4323 non-null   int64
#  5   terdakwa                        4323 non-null   object
#  6   summarized_dakwaan              4323 non-null   object
#  7   total_pidana_penjara_bulan      4323 non-null   float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 270.3+ KB

# %% [markdown]
# ### Split Data

# %%
def stratified_split(df: pd.DataFrame, split_size: float = 0.8) -> tuple[pd.DataFrame, pd.DataFrame]:
    unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()
    
    print(unique_groups)
    train_idx, test_idx = [], []
    
    for indices in unique_groups.values():        
        if len(indices) == 1:
            train_idx.extend(indices)
        else:
            train, test = train_test_split(indices, train_size=split_size, random_state=42)
            train_idx.extend(train)
            test_idx.extend(test)
    
    return df.loc[train_idx], df.loc[test_idx]

# %%
train_df, test_df = stratified_split(df)
# Out:
# {(0, 0, 0): [0, 20, 42], (0, 0, 2): [2], (0, 1, 0): [19, 37], (0, 1, 4): [35, 36], (0, 4, 1): [5], (0, 4, 3): [10], (0, 5, 21): [843], (0, 7, 1): [9], (0, 8, 0): [15, 17], (0, 9, 0): [16, 18], (0, 11, 4): [22, 23], (0, 12, 19): [775, 776, 813], (0, 12, 21): [774], (0, 12, 22): [715], (0, 12, 23): [806], (0, 13, 0): [32], (0, 13, 3): [34], (0, 14, 0): [38], (0, 14, 14): [437, 501, 595, 609], (0, 14, 16): [422], (0, 14, 18): [474, 665], (0, 14, 19): [783, 784, 785, 786], (0, 14, 20): [432, 438, 518, 578, 608, 724, 745], (0, 14, 21): [639, 822], (0, 15, 4): [33], (0, 16, 0): [39], (0, 17, 0): [40, 41], (0, 19, 7): [46], (0, 20, 36): [1051], (0, 21, 52): [1612], (0, 21, 54): [1630, 1632], (0, 22, 10): [241, 268, 269, 270, 271, 303], (0, 22, 14): [259, 381, 415, 416, 538, 545, 577, 621], (0, 22, 16): [308, 314, 315, 383, 386, 417], (0, 22, 18): [654, 655, 656], (0, 22, 19): [548, 762], (0, 22, 20): [446, 570, 571, 572, 573, 690, 725], (0, 22, 22): [719], (0, 23, 10): [52, 54], (0, 24, 10): [136, 152, 172], (0, 24, 11): [75, 104], (0, 24, 12): [173], (0, 24, 14): [119], (0, 25, 10): [100, 147, 196, 369], (0, 25, 11): [55], (0, 25, 14): [374, 403, 449, 450], (0, 25, 16): [402], (0, 25, 19): [584, 585, 769], (0, 25, 20): [737], (0, 25, 21): [586, 815, 816, 817, 842], (0, 26, 10): [56], (0, 27, 10): [57, 94], (0, 27, 12): [90], (0, 28, 9): [58], (0, 28, 10): [106, 107, 109], (0, 28, 12): [96, 97], (0, 29, 10): [59, 60, 61], (0, 29, 12): [101, 102], (0, 30, 10): [174], (0, 30, 14): [144, 162, 163, 164, 166, 177], (0, 31, 10): [63, 91, 92, 93], (0, 31, 11): [65], (0, 31, 12): [80, 175, 176], (0, 31, 15): [182], (0, 32, 12): [70, 71], (0, 34, 10): [78], (0, 34, 11): [73, 81, 89], (0, 35, 12): [110, 111], (0, 35, 15): [170], (0, 36, 12): [105, 128], (0, 37, 15): [183], (0, 38, 10): [153], (0, 38, 31): [970, 972], (0, 38, 52): [1523], (0, 39, 10): [134, 294, 360, 387], (0, 39, 14): [260], (0, 39, 16): [291, 320, 329, 365], (0, 39, 19): [722], (0, 40, 10): [141, 165, 178], (0, 40, 12): [112], (0, 40, 14): [120], (0, 41, 10): [289, 312, 316, 348, 349], (0, 41, 14): [186, 187, 420, 421, 574, 587], (0, 41, 16): [304, 305, 306, 331, 346, 347, 362, 363], (0, 41, 17): [388], (0, 41, 18): [442, 657, 664, 711], (0, 41, 19): [495, 604], (0, 41, 20): [493, 636], (0, 41, 21): [700, 701], (0, 42, 10): [206, 212, 261, 264], (0, 42, 12): [142], (0, 42, 13): [288], (0, 45, 12): [133], (0, 46, 10): [211, 242, 243], (0, 46, 12): [145, 236, 237, 238, 239], (0, 46, 14): [149, 151], (0, 47, 10): [352], (0, 47, 16): [324, 325, 326, 384, 385], (0, 49, 12): [179, 195], (0, 51, 14): [148, 150, 430, 533, 554, 555, 556, 590], (0, 51, 18): [651, 652], (0, 51, 19): [425, 426, 429, 547, 580, 635, 643], (0, 51, 20): [448, 480, 481, 513, 514, 530, 531, 607, 622], (0, 51, 21): [628, 647, 771], (0, 53, 10): [199, 250, 251, 252, 253], (0, 53, 12): [200], (0, 53, 14): [232], (0, 53, 16): [265], (0, 54, 10): [330], (0, 54, 16): [296, 389], (0, 54, 17): [366], (0, 55, 10): [198, 282, 283], (0, 55, 12): [201], (0, 55, 17): [364], (0, 56, 10): [380], (0, 56, 14): [327, 328], (0, 56, 16): [338], (0, 57, 14): [221, 222, 223, 224, 517, 614], (0, 57, 19): [459, 460, 461, 509, 510, 511, 632, 781, 782], (0, 57, 20): [433], (0, 57, 21): [645, 746], (0, 57, 23): [810, 834], (0, 57, 45): [1257, 1259], (0, 59, 10): [318, 333, 334, 368], (0, 59, 13): [292], (0, 59, 14): [332, 337, 339, 343, 356, 357, 358, 397, 406, 482, 483], (0, 59, 16): [275, 276, 277, 302, 317, 336, 359, 367], (0, 59, 19): [440, 479, 593, 598], (0, 59, 20): [434, 454, 475, 498, 507, 559, 591, 592, 602, 603, 686], (0, 59, 21): [557], (0, 59, 22): [721], (0, 60, 10): [379], (0, 60, 19): [534, 535, 627, 814], (0, 60, 20): [630], (0, 61, 14): [408, 524, 540], (0, 61, 18): [753, 796], (0, 61, 19): [494, 508, 560, 561, 562, 588], (0, 61, 20): [455, 581], (0, 61, 21): [631, 641], (0, 62, 14): [610], (0, 62, 16): [409], (0, 62, 19): [500, 799, 800], (0, 62, 20): [476], (0, 62, 21): [638], (0, 63, 14): [484, 485], (0, 63, 20): [5 ...
# C:\Users\Kalea\AppData\Local\Temp\ipykernel_38868\635274658.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unique_groups = df.groupby(["klasifikasi_perkara_encoded", "penuntut_umum_encoded", "hakim_encoded"]).apply(lambda x: x.index.tolist()).to_dict()

# %%
jenis_klasifikasi_perkara = train_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Train:  {len(train_df)}")

klasifikasi_perkara_values = train_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Train:  3270
# klasifikasi_perkara_encoded
# 0    1378
# 2    1250
# 3     287
# 4     193
# 1     162
# Name: count, dtype: int64

# %%
jenis_klasifikasi_perkara = test_df['klasifikasi_perkara_encoded'].unique()
jumlah_klasifikasi_perkara = len(jenis_klasifikasi_perkara)
print(f"Jumlah Klasifikasi Perkara: {jumlah_klasifikasi_perkara}")
print(f"Jumlah Data Test:  {len(test_df)}")

klasifikasi_perkara_values = test_df['klasifikasi_perkara_encoded'].value_counts()
print(klasifikasi_perkara_values)
# Out:
# Jumlah Klasifikasi Perkara: 5
# Jumlah Data Test:  1053
# klasifikasi_perkara_encoded
# 0    490
# 2    439
# 4     51
# 3     50
# 1     23
# Name: count, dtype: int64

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Preprocessing

# %%
train_df['concat_text'] = train_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)
test_df['concat_text'] = test_df[['terdakwa', 'summarized_dakwaan']].apply(lambda x: '. '.join(x), axis=1)

# %%
y_train = train_df['total_pidana_penjara_bulan']
y_test = test_df['total_pidana_penjara_bulan']

# %% [markdown]
# ### Normalisasi

# %%
def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z0-9\s\(\)]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

train_df['normalized_text'] = train_df['concat_text'].apply(normalize_text)
test_df['normalized_text'] = test_df['concat_text'].apply(normalize_text)

# %% [markdown]
# ### Stopwords Removal

# %%
stopword_factory = StopWordRemoverFactory()
stop_words = set(stopword_factory.get_stop_words())

def remove_stopwords(text, stop_words):
    return ' '.join([word for word in text.split() if word not in stop_words])

train_df['stopword_removal'] = train_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))
test_df['stopword_removal'] = test_df['normalized_text'].apply(lambda x: remove_stopwords(x, stop_words))

# %% [markdown]
# ### Tokenizer

# %%
# Tokenisasi
tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(train_df['stopword_removal'])
train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal'])
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

# %%
vocab_size = len(tokenizer.word_index) + 1  # 4 + 1 = 5
print("Vocabulary size:", vocab_size)
# Out:
# Vocabulary size: 18318

# %%
# Padding
# max_len = max(len(seq) for seq in train_sequences)
max_len = 1024
X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

# %%
print(max_len)
# Out:
# 1024

# %% [markdown]
# ### Numerical Features

# %%
# TANPA LOG TRANSFORM (gunakan salah satu)

train_numerical = tf.constant(train_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)
test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %% [markdown]
# ### Model Architecture

# %%
text_input = tf.keras.layers.Input(shape=(max_len,), name='text_input')
embedding_layer = tf.keras.layers.Embedding(
    input_dim=len(tokenizer.word_index) + 1,
    output_dim=128 
)(text_input)

lstm_output = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64))(embedding_layer)

numerical_input = tf.keras.layers.Input(shape=(train_numerical.shape[1],), name='numerical_input')
numerical_dense = tf.keras.layers.Dense(64, activation='relu', 
                                      kernel_regularizer=tf.keras.regularizers.l2(0.001))(numerical_input)

combined = tf.keras.layers.Concatenate()([lstm_output, numerical_dense])

output = tf.keras.layers.Dense(1, activation='linear')(combined)

# %%
model = tf.keras.Model(inputs=[text_input, numerical_input], outputs=output)

model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
# model.compile(optimizer=tf.keras.optimizers.Adam(), loss=tf.keras.losses.Huber(), metrics=['mean_absolute_error', tf.keras.metrics.RootMeanSquaredError(), tf.keras.metrics.MeanAbsolutePercentageError()])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  text_input (InputLayer)        [(None, 1024)]       0           []
#
#  embedding (Embedding)          (None, 1024, 128)    2344704     ['text_input[0][0]']
#
#  numerical_input (InputLayer)   [(None, 5)]          0           []
#
#  bidirectional (Bidirectional)  (None, 128)          98816       ['embedding[0][0]']
#
#  dense (Dense)                  (None, 64)           384         ['numerical_input[0][0]']
#
#  concatenate (Concatenate)      (None, 192)          0           ['bidirectional[0][0]',
#                                                                   'dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            193         ['concatenate[0][0]']
#
# ==================================================================================================
# Total params: 2,444,097
# Trainable params: 2,444,097
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit([X_train_texts, train_numerical], y_train, 
                    epochs=100, batch_size=32, validation_data=([X_test_texts, test_numerical], y_test))
# Out:
# Epoch 1/100
# 103/103 [==============================] - 12s 94ms/step - loss: 17.6877 - mean_absolute_error: 18.1744 - root_mean_squared_error: 26.3221 - mean_absolute_percentage_error: 117.6444 - val_loss: 14.1626 - val_mean_absolute_error: 14.6484 - val_root_mean_squared_error: 20.8628 - val_mean_absolute_percentage_error: 121.7259
# Epoch 2/100
# 103/103 [==============================] - 9s 87ms/step - loss: 12.0848 - mean_absolute_error: 12.5671 - root_mean_squared_error: 18.1409 - mean_absolute_percentage_error: 103.1651 - val_loss: 11.7549 - val_mean_absolute_error: 12.2335 - val_root_mean_squared_error: 18.3678 - val_mean_absolute_percentage_error: 98.3519
# Epoch 3/100
# 103/103 [==============================] - 9s 87ms/step - loss: 10.0592 - mean_absolute_error: 10.5372 - root_mean_squared_error: 16.0495 - mean_absolute_percentage_error: 80.1616 - val_loss: 10.6551 - val_mean_absolute_error: 11.1340 - val_root_mean_squared_error: 17.3612 - val_mean_absolute_percentage_error: 84.6456
# Epoch 4/100
# 103/103 [==============================] - 9s 87ms/step - loss: 8.2575 - mean_absolute_error: 8.7303 - root_mean_squared_error: 14.2653 - mean_absolute_percentage_error: 65.5978 - val_loss: 10.3926 - val_mean_absolute_error: 10.8703 - val_root_mean_squared_error: 17.0040 - val_mean_absolute_percentage_error: 80.2348
# Epoch 5/100
# 103/103 [==============================] - 9s 87ms/step - loss: 7.1917 - mean_absolute_error: 7.6609 - root_mean_squared_error: 13.0129 - mean_absolute_percentage_error: 54.8047 - val_loss: 9.5498 - val_mean_absolute_error: 10.0227 - val_root_mean_squared_error: 16.5760 - val_mean_absolute_percentage_error: 63.6526
# Epoch 6/100
# 103/103 [==============================] - 11s 106ms/step - loss: 6.0297 - mean_absolute_error: 6.4921 - root_mean_squared_error: 11.7349 - mean_absolute_percentage_error: 44.6545 - val_loss: 8.9431 - val_mean_absolute_error: 9.4171 - val_root_mean_squared_error: 15.7714 - val_mean_absolute_percentage_error: 59.0780
# Epoch 7/100
# 103/103 [==============================] - 10s 100ms/step - loss: 4.8777 - mean_absolute_error: 5.3326 - root_mean_squared_error: 10.5445 - mean_absolute_percentage_error: 33.4699 - val_loss: 8.5491 - val_mean_absolute_error: 9.0162 - val_root_mean_squared_error: 15.7124 - val_mean_absolute_percentage_error: 51.2798
# Epoch 8/100
# 103/103 [==============================] - 10s 102ms/step - loss: 4.2251 - mean_absolute_error: 4.6702 - root_mean_squared_error: 9.6915 - mean_absolute_percentage_error: 27.9368 - val_loss: 8.4960 - val_mean_absolute_error: 8.9683 - val_root_mean_squared_error: 15.3376 - val_mean_absolute_percentage_error: 56.1118
# Epoch 9/100
# 103/103 [==============================] - 11s 103ms/step - loss: 3.6578 - mean_absolute_error: 4.0979 - root_mean_squared_error: 8.9713 - mean_absolute_percentage_error: 24.5724 - val_loss: 8.0039 - val_mean_absolute_error: 8.4660 - val_root_mean_squared_error: 14.9873 - val_mean_absolute_percentage_error: 47.9463
# Epoch 10/100
# 103/103 [==============================] - 10s 94ms/step - loss: 3.4037 - mean_absolute_error: 3.8410 - root_mean_squared_error: 8.4317 - mean_absolute_percentage_error: 23.4865 - val_loss: 8.0078 - val_mean_absolute_error: 8.4723 - val_root_mean_squared_error: 14.9319 - val_mean_absolute_percentage_error: 47.9420
# Epoch 11/100
# 103/103 [==============================] - 11s 105ms/step - loss: 3.1084 - mean_absolute_error: 3.5434 - root_mean_squared_error: 7.9658 - mean_absolute_percentage_error: 21.6503 - val_loss: 7.8647 - val_mean_absolute_error: 8.3324 - val_root_mean_squared_error: 14.7110 - val_mean_absolute_percentage_error: 49.7598
# Epoch 12/100
# 103/103 [==============================] - 11s 103ms/step - loss: 2.9660 - mean_absolute_error: 3.4032 - root_mean_squared_error: 7.5632 - mean_absolute_percentage_error: 20.7156 - val_loss: 7.6586 - val_mean_absolute_error: 8.1261 - val_root_mean_squared_error: 14.4810 - val_mean_absolute_percentage_error: 48.4245
# Epoch 13/100
# 103/103 [==============================] - 10s 100ms/step - loss: 2.5854 - mean_absolute_error: 3.0140 - root_mean_squared_error: 7.1383 - mean_absolute_percentage_error: 18.6525 - val_loss: 7.6945 - val_mean_absolute_error: 8.1552 - val_root_mean_squared_error: 14.4010 - val_mean_absolute_percentage_error: 50.7609
# Epoch 14/100
# 103/103 [==============================] - 10s 101ms/step - loss: 2.3539 - mean_absolute_error: 2.7719 - root_mean_squared_error: 6.8000 - mean_absolute_percentage_error: 17.6224 - val_loss: 7.4925 - val_mean_absolute_error: 7.9450 - val_root_mean_squared_error: 14.2651 - val_mean_absolute_percentage_error: 48.9372
# Epoch 15/100
# 103/103 [==============================] - 10s 99ms/step - loss: 2.1970 - mean_absolute_error: 2.6159 - root_mean_squared_error: 6.4734 - mean_absolute_percentage_error: 16.3916 - val_loss: 7.5792 - val_mean_absolute_error: 8.0344 - val_root_mean_squared_error: 14.1636 - val_mean_absolute_percentage_error: 49.2624
# Epoch 16/100
# 103/103 [==============================] - 10s 101ms/step - loss: 2.0316 - mean_absolute_error: 2.4433 - root_mean_squared_error: 6.1002 - mean_absolute_percentage_error: 16.0163 - val_loss: 7.2631 - val_mean_absolute_error: 7.7150 - val_root_mean_squared_error: 13.9448 - val_mean_absolute_percentage_error: 45.9225
# Epoch 17/100
# 103/103 [==============================] - 11s 104ms/step - loss: 1.8611 - mean_absolute_error: 2.2635 - root_mean_squared_error: 5.8768 - mean_absolute_percentage_error: 14.3604 - val_loss: 7.2284 - val_mean_absolute_error: 7.6817 - val_root_mean_squared_error: 13.8664 - val_mean_absolute_percentage_error: 47.5723
# Epoch 18/100
# 103/103 [==============================] - 10s 100ms/step - loss: 1.6666 - mean_absolute_error: 2.0620 - root_mean_squared_error: 5.5247 - mean_absolute_percentage_error: 13.0042 - val_loss: 7.1194 - val_mean_absolute_error: 7.5701 - val_root_mean_squared_error: 13.7125 - val_mean_absolute_percentage_error: 46.6881
# Epoch 19/100
# 103/103 [==============================] - 9s 90ms/step - loss: 1.5729 - mean_absolute_error: 1.9679 - root_mean_squared_error: 5.3895 - mean_absolute_percentage_error: 12.2156 - val_loss: 7.0915 - val_mean_absolute_error: 7.5294 - val_root_mean_squared_error: 13.7970 - val_mean_absolute_percentage_error: 47.5276
# Epoch 20/100
# 103/103 [==============================] - 9s 90ms/step - loss: 1.4397 - mean_absolute_error: 1.8257 - root_mean_squared_error: 5.1380 - mean_absolute_percentage_error: 11.1932 - val_loss: 7.1930 - val_mean_absolute_error: 7.6489 - val_root_mean_squared_error: 13.7739 - val_mean_absolute_percentage_error: 47.3657
# Epoch 21/100
# 103/103 [==============================] - 9s 87ms/step - loss: 1.4230 - mean_absolute_error: 1.8182 - root_mean_squared_error: 4.9866 - mean_absolute_percentage_error: 11.3513 - val_loss: 7.1775 - val_mean_absolute_error: 7.6213 - val_root_mean_squared_error: 13.8910 - val_mean_absolute_percentage_error: 47.5887
# Epoch 22/100
# 103/103 [==============================] - 9s 87ms/step - loss: 1.3189 - mean_absolute_error: 1.7076 - root_mean_squared_error: 4.7911 - mean_absolute_percentage_error: 10.4610 - val_loss: 7.0737 - val_mean_absolute_error: 7.5238 - val_root_mean_squared_error: 13.6512 - val_mean_absolute_percentage_error: 47.6046
# Epoch 23/100
# 103/103 [==============================] - 9s 87ms/step - loss: 1.2162 - mean_absolute_error: 1.5958 - root_mean_squared_error: 4.6103 - mean_absolute_percentage_error: 9.6149 - val_loss: 6.9531 - val_mean_absolute_error: 7.4087 - val_root_mean_squared_error: 13.6519 - val_mean_absolute_percentage_error: 44.7447
# Epoch 24/100
# 103/103 [==============================] - 9s 87ms/step - loss: 1.2549 - mean_absolute_error: 1.6500 - root_mean_squared_error: 4.4731 - mean_absolute_percentage_error: 10.1211 - val_loss: 7.0230 - val_mean_absolute_error: 7.4746 - val_root_mean_squared_error: 13.7346 - val_mean_absolute_percentage_error: 44.6306
# Epoch 25/100
# 103/103 [==============================] - 9s 86ms/step - loss: 1.1940 - mean_absolute_error: 1.5856 - root_mean_squared_error: 4.3650 - mean_absolute_percentage_error: 9.5680 - val_loss: 6.8549 - val_mean_absolute_error: 7.3027 - val_root_mean_squared_error: 13.6187 - val_mean_absolute_percentage_error: 43.5861
# Epoch 26/100
# 103/103 [==============================] - 9s 87ms/step - loss: 1.1367 - mean_absolute_error: 1.5289 - root_mean_squared_error: 4.2720 - mean_absolute_percentage_error: 8.8451 - val_loss: 6.8948 - val_mean_absolute_error: 7.3419 - val_root_mean_squared_error: 13.6100 - val_mean_absolute_percentage_error: 44.9339
# Epoch 27/100
# 103/103 [==============================] - 9s 87ms/step - loss: 1.0139 - mean_absolute_error: 1.3848 - root_mean_squared_error: 4.1322 - mean_absolute_percentage_error: 7.8607 - val_loss: 6.8352 - val_mean_absolute_error: 7.2777 - val_root_mean_squared_error: 13.5069 - val_mean_absolute_percentage_error: 44.8000
# Epoch 28/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.9149 - mean_absolute_error: 1.2815 - root_mean_squared_error: 4.0122 - mean_absolute_percentage_error: 7.3850 - val_loss: 6.9234 - val_mean_absolute_error: 7.3734 - val_root_mean_squared_error: 13.4782 - val_mean_absolute_percentage_error: 45.8016
# Epoch 29/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.9287 - mean_absolute_error: 1.3028 - root_mean_squared_error: 3.9637 - mean_absolute_percentage_error: 7.5561 - val_loss: 6.8565 - val_mean_absolute_error: 7.2916 - val_root_mean_squared_error: 13.5205 - val_mean_absolute_percentage_error: 45.2565
# Epoch 30/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.9006 - mean_absolute_error: 1.2692 - root_mean_squared_error: 3.8662 - mean_absolute_percentage_error: 7.4322 - val_loss: 6.8089 - val_mean_absolute_error: 7.2600 - val_root_mean_squared_error: 13.4168 - val_mean_absolute_percentage_error: 43.1430
# Epoch 31/100
# 103/103 [==============================] - 10s 99ms/step - loss: 0.8926 - mean_absolute_error: 1.2618 - root_mean_squared_error: 3.7977 - mean_absolute_percentage_error: 7.0408 - val_loss: 6.8040 - val_mean_absolute_error: 7.2433 - val_root_mean_squared_error: 13.4593 - val_mean_absolute_percentage_error: 43.4861
# Epoch 32/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.8337 - mean_absolute_error: 1.1943 - root_mean_squared_error: 3.7190 - mean_absolute_percentage_error: 6.7096 - val_loss: 6.8668 - val_mean_absolute_error: 7.3054 - val_root_mean_squared_error: 13.4639 - val_mean_absolute_percentage_error: 46.4888
# Epoch 33/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.8568 - mean_absolute_error: 1.2315 - root_mean_squared_error: 3.7027 - mean_absolute_percentage_error: 7.3363 - val_loss: 6.7688 - val_mean_absolute_error: 7.2070 - val_root_mean_squared_error: 13.4391 - val_mean_absolute_percentage_error: 44.0828
# Epoch 34/100
# 103/103 [==============================] - 10s 94ms/step - loss: 0.7996 - mean_absolute_error: 1.1574 - root_mean_squared_error: 3.6097 - mean_absolute_percentage_error: 6.5052 - val_loss: 6.6579 - val_mean_absolute_error: 7.0855 - val_root_mean_squared_error: 13.3530 - val_mean_absolute_percentage_error: 43.6016
# Epoch 35/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.7620 - mean_absolute_error: 1.1177 - root_mean_squared_error: 3.5429 - mean_absolute_percentage_error: 6.2548 - val_loss: 6.6918 - val_mean_absolute_error: 7.1279 - val_root_mean_squared_error: 13.2837 - val_mean_absolute_percentage_error: 43.6654
# Epoch 36/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.7656 - mean_absolute_error: 1.1301 - root_mean_squared_error: 3.4972 - mean_absolute_percentage_error: 6.4544 - val_loss: 6.6399 - val_mean_absolute_error: 7.0694 - val_root_mean_squared_error: 13.2801 - val_mean_absolute_percentage_error: 44.2321
# Epoch 37/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.6912 - mean_absolute_error: 1.0388 - root_mean_squared_error: 3.4280 - mean_absolute_percentage_error: 5.9767 - val_loss: 6.5904 - val_mean_absolute_error: 7.0383 - val_root_mean_squared_error: 13.1216 - val_mean_absolute_percentage_error: 42.9593
# Epoch 38/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.6479 - mean_absolute_error: 0.9832 - root_mean_squared_error: 3.3476 - mean_absolute_percentage_error: 5.3820 - val_loss: 6.7646 - val_mean_absolute_error: 7.2271 - val_root_mean_squared_error: 13.3060 - val_mean_absolute_percentage_error: 43.0027
# Epoch 39/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.6851 - mean_absolute_error: 1.0339 - root_mean_squared_error: 3.3360 - mean_absolute_percentage_error: 5.7856 - val_loss: 6.6043 - val_mean_absolute_error: 7.0325 - val_root_mean_squared_error: 13.1941 - val_mean_absolute_percentage_error: 43.6842
# Epoch 40/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.6616 - mean_absolute_error: 1.0056 - root_mean_squared_error: 3.2832 - mean_absolute_percentage_error: 5.6787 - val_loss: 6.5980 - val_mean_absolute_error: 7.0278 - val_root_mean_squared_error: 13.2500 - val_mean_absolute_percentage_error: 42.7129
# Epoch 41/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.6177 - mean_absolute_error: 0.9579 - root_mean_squared_error: 3.2193 - mean_absolute_percentage_error: 5.4411 - val_loss: 6.5440 - val_mean_absolute_error: 6.9707 - val_root_mean_squared_error: 13.1647 - val_mean_absolute_percentage_error: 43.2471
# Epoch 42/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.6252 - mean_absolute_error: 0.9676 - root_mean_squared_error: 3.2051 - mean_absolute_percentage_error: 5.5090 - val_loss: 6.5412 - val_mean_absolute_error: 6.9886 - val_root_mean_squared_error: 13.0502 - val_mean_absolute_percentage_error: 42.6804
# Epoch 43/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.6123 - mean_absolute_error: 0.9523 - root_mean_squared_error: 3.1515 - mean_absolute_percentage_error: 5.4037 - val_loss: 6.5660 - val_mean_absolute_error: 6.9916 - val_root_mean_squared_error: 13.0865 - val_mean_absolute_percentage_error: 44.2979
# Epoch 44/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.5820 - mean_absolute_error: 0.9138 - root_mean_squared_error: 3.1186 - mean_absolute_percentage_error: 5.0600 - val_loss: 6.5350 - val_mean_absolute_error: 6.9636 - val_root_mean_squared_error: 13.1162 - val_mean_absolute_percentage_error: 42.8819
# Epoch 45/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.5386 - mean_absolute_error: 0.8597 - root_mean_squared_error: 3.0629 - mean_absolute_percentage_error: 4.7526 - val_loss: 6.4874 - val_mean_absolute_error: 6.9242 - val_root_mean_squared_error: 13.0596 - val_mean_absolute_percentage_error: 42.0359
# Epoch 46/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.6297 - mean_absolute_error: 0.9838 - root_mean_squared_error: 3.0540 - mean_absolute_percentage_error: 5.6612 - val_loss: 6.6776 - val_mean_absolute_error: 7.1309 - val_root_mean_squared_error: 13.0847 - val_mean_absolute_percentage_error: 44.1561
# Epoch 47/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.6431 - mean_absolute_error: 0.9940 - root_mean_squared_error: 3.0678 - mean_absolute_percentage_error: 5.6691 - val_loss: 6.5088 - val_mean_absolute_error: 6.9304 - val_root_mean_squared_error: 13.0795 - val_mean_absolute_percentage_error: 44.0837
# Epoch 48/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.5477 - mean_absolute_error: 0.8765 - root_mean_squared_error: 2.9948 - mean_absolute_percentage_error: 4.7596 - val_loss: 6.6664 - val_mean_absolute_error: 7.1161 - val_root_mean_squared_error: 13.1699 - val_mean_absolute_percentage_error: 45.7791
# Epoch 49/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.5721 - mean_absolute_error: 0.9083 - root_mean_squared_error: 2.9728 - mean_absolute_percentage_error: 5.1789 - val_loss: 6.5155 - val_mean_absolute_error: 6.9448 - val_root_mean_squared_error: 13.0900 - val_mean_absolute_percentage_error: 42.8987
# Epoch 50/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.5759 - mean_absolute_error: 0.9174 - root_mean_squared_error: 2.9586 - mean_absolute_percentage_error: 5.1090 - val_loss: 6.8369 - val_mean_absolute_error: 7.3038 - val_root_mean_squared_error: 13.1745 - val_mean_absolute_percentage_error: 47.4894
# Epoch 51/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.6116 - mean_absolute_error: 0.9629 - root_mean_squared_error: 2.9278 - mean_absolute_percentage_error: 5.4885 - val_loss: 6.4708 - val_mean_absolute_error: 6.9055 - val_root_mean_squared_error: 13.0207 - val_mean_absolute_percentage_error: 42.3080
# Epoch 52/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.5583 - mean_absolute_error: 0.8917 - root_mean_squared_error: 2.9480 - mean_absolute_percentage_error: 4.9085 - val_loss: 6.4145 - val_mean_absolute_error: 6.8298 - val_root_mean_squared_error: 12.9847 - val_mean_absolute_percentage_error: 42.3467
# Epoch 53/100
# 103/103 [==============================] - 9s 85ms/step - loss: 0.5128 - mean_absolute_error: 0.8319 - root_mean_squared_error: 2.8776 - mean_absolute_percentage_error: 4.4802 - val_loss: 6.4841 - val_mean_absolute_error: 6.9047 - val_root_mean_squared_error: 13.0813 - val_mean_absolute_percentage_error: 42.5991
# Epoch 54/100
# 103/103 [==============================] - 9s 86ms/step - loss: 0.4768 - mean_absolute_error: 0.7910 - root_mean_squared_error: 2.8169 - mean_absolute_percentage_error: 4.2713 - val_loss: 6.4289 - val_mean_absolute_error: 6.8648 - val_root_mean_squared_error: 13.0231 - val_mean_absolute_percentage_error: 42.5029
# Epoch 55/100
# 103/103 [==============================] - 9s 85ms/step - loss: 0.4546 - mean_absolute_error: 0.7721 - root_mean_squared_error: 2.7680 - mean_absolute_percentage_error: 4.2482 - val_loss: 6.4520 - val_mean_absolute_error: 6.8712 - val_root_mean_squared_error: 13.0827 - val_mean_absolute_percentage_error: 42.7721
# Epoch 56/100
# 103/103 [==============================] - 9s 86ms/step - loss: 0.4661 - mean_absolute_error: 0.7835 - root_mean_squared_error: 2.7538 - mean_absolute_percentage_error: 4.4548 - val_loss: 6.5156 - val_mean_absolute_error: 6.9376 - val_root_mean_squared_error: 13.0994 - val_mean_absolute_percentage_error: 44.3627
# Epoch 57/100
# 103/103 [==============================] - 9s 85ms/step - loss: 0.5030 - mean_absolute_error: 0.8346 - root_mean_squared_error: 2.7526 - mean_absolute_percentage_error: 4.6088 - val_loss: 6.3863 - val_mean_absolute_error: 6.8043 - val_root_mean_squared_error: 12.9387 - val_mean_absolute_percentage_error: 42.1727
# Epoch 58/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.4372 - mean_absolute_error: 0.7465 - root_mean_squared_error: 2.7029 - mean_absolute_percentage_error: 4.0742 - val_loss: 6.5051 - val_mean_absolute_error: 6.9524 - val_root_mean_squared_error: 12.9588 - val_mean_absolute_percentage_error: 43.9313
# Epoch 59/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.4271 - mean_absolute_error: 0.7346 - root_mean_squared_error: 2.6639 - mean_absolute_percentage_error: 4.1632 - val_loss: 6.4661 - val_mean_absolute_error: 6.8881 - val_root_mean_squared_error: 13.0683 - val_mean_absolute_percentage_error: 42.2147
# Epoch 60/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.4331 - mean_absolute_error: 0.7390 - root_mean_squared_error: 2.6466 - mean_absolute_percentage_error: 3.9987 - val_loss: 6.4609 - val_mean_absolute_error: 6.8756 - val_root_mean_squared_error: 13.1127 - val_mean_absolute_percentage_error: 42.2487
# Epoch 61/100
# 103/103 [==============================] - 10s 101ms/step - loss: 0.4221 - mean_absolute_error: 0.7278 - root_mean_squared_error: 2.6123 - mean_absolute_percentage_error: 3.9861 - val_loss: 6.4065 - val_mean_absolute_error: 6.8177 - val_root_mean_squared_error: 13.0348 - val_mean_absolute_percentage_error: 41.8598
# Epoch 62/100
# 103/103 [==============================] - 10s 101ms/step - loss: 0.4125 - mean_absolute_error: 0.7182 - root_mean_squared_error: 2.6009 - mean_absolute_percentage_error: 3.8205 - val_loss: 6.4466 - val_mean_absolute_error: 6.8678 - val_root_mean_squared_error: 13.0029 - val_mean_absolute_percentage_error: 43.0700
# Epoch 63/100
# 103/103 [==============================] - 11s 103ms/step - loss: 0.3967 - mean_absolute_error: 0.6922 - root_mean_squared_error: 2.5616 - mean_absolute_percentage_error: 3.6746 - val_loss: 6.4471 - val_mean_absolute_error: 6.8779 - val_root_mean_squared_error: 13.0791 - val_mean_absolute_percentage_error: 41.4287
# Epoch 64/100
# 103/103 [==============================] - 11s 108ms/step - loss: 0.3939 - mean_absolute_error: 0.6919 - root_mean_squared_error: 2.5271 - mean_absolute_percentage_error: 3.7365 - val_loss: 6.3425 - val_mean_absolute_error: 6.7537 - val_root_mean_squared_error: 12.9355 - val_mean_absolute_percentage_error: 41.5542
# Epoch 65/100
# 103/103 [==============================] - 10s 94ms/step - loss: 0.4175 - mean_absolute_error: 0.7299 - root_mean_squared_error: 2.5141 - mean_absolute_percentage_error: 4.0506 - val_loss: 6.3895 - val_mean_absolute_error: 6.8082 - val_root_mean_squared_error: 12.9616 - val_mean_absolute_percentage_error: 41.6262
# Epoch 66/100
# 103/103 [==============================] - 9s 90ms/step - loss: 0.4270 - mean_absolute_error: 0.7460 - root_mean_squared_error: 2.4890 - mean_absolute_percentage_error: 4.1920 - val_loss: 6.3629 - val_mean_absolute_error: 6.7862 - val_root_mean_squared_error: 12.9282 - val_mean_absolute_percentage_error: 42.3503
# Epoch 67/100
# 103/103 [==============================] - 11s 105ms/step - loss: 0.4690 - mean_absolute_error: 0.7992 - root_mean_squared_error: 2.4966 - mean_absolute_percentage_error: 4.5310 - val_loss: 6.4278 - val_mean_absolute_error: 6.8499 - val_root_mean_squared_error: 13.0924 - val_mean_absolute_percentage_error: 43.7046
# Epoch 68/100
# 103/103 [==============================] - 12s 115ms/step - loss: 0.4210 - mean_absolute_error: 0.7348 - root_mean_squared_error: 2.4460 - mean_absolute_percentage_error: 3.9673 - val_loss: 6.3799 - val_mean_absolute_error: 6.8140 - val_root_mean_squared_error: 12.8911 - val_mean_absolute_percentage_error: 41.2808
# Epoch 69/100
# 103/103 [==============================] - 10s 98ms/step - loss: 0.4145 - mean_absolute_error: 0.7282 - root_mean_squared_error: 2.4626 - mean_absolute_percentage_error: 3.9966 - val_loss: 6.3461 - val_mean_absolute_error: 6.7910 - val_root_mean_squared_error: 12.8578 - val_mean_absolute_percentage_error: 40.8714
# Epoch 70/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.4041 - mean_absolute_error: 0.7146 - root_mean_squared_error: 2.4058 - mean_absolute_percentage_error: 4.0309 - val_loss: 6.4255 - val_mean_absolute_error: 6.8362 - val_root_mean_squared_error: 12.9400 - val_mean_absolute_percentage_error: 43.4590
# Epoch 71/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.4159 - mean_absolute_error: 0.7397 - root_mean_squared_error: 2.3562 - mean_absolute_percentage_error: 4.1866 - val_loss: 6.3239 - val_mean_absolute_error: 6.7387 - val_root_mean_squared_error: 12.8372 - val_mean_absolute_percentage_error: 42.4877
# Epoch 72/100
# 103/103 [==============================] - 9s 92ms/step - loss: 0.3763 - mean_absolute_error: 0.6820 - root_mean_squared_error: 2.3408 - mean_absolute_percentage_error: 3.6535 - val_loss: 6.3414 - val_mean_absolute_error: 6.7584 - val_root_mean_squared_error: 12.9024 - val_mean_absolute_percentage_error: 43.1479
# Epoch 73/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.3527 - mean_absolute_error: 0.6447 - root_mean_squared_error: 2.3006 - mean_absolute_percentage_error: 3.4524 - val_loss: 6.3649 - val_mean_absolute_error: 6.7765 - val_root_mean_squared_error: 12.9208 - val_mean_absolute_percentage_error: 42.9485
# Epoch 74/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.3480 - mean_absolute_error: 0.6417 - root_mean_squared_error: 2.2864 - mean_absolute_percentage_error: 3.5270 - val_loss: 6.4515 - val_mean_absolute_error: 6.8796 - val_root_mean_squared_error: 13.0044 - val_mean_absolute_percentage_error: 43.5877
# Epoch 75/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.3807 - mean_absolute_error: 0.6885 - root_mean_squared_error: 2.2672 - mean_absolute_percentage_error: 3.7695 - val_loss: 6.3569 - val_mean_absolute_error: 6.7865 - val_root_mean_squared_error: 12.8389 - val_mean_absolute_percentage_error: 43.4733
# Epoch 76/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.3786 - mean_absolute_error: 0.6847 - root_mean_squared_error: 2.2467 - mean_absolute_percentage_error: 3.8246 - val_loss: 6.3329 - val_mean_absolute_error: 6.7553 - val_root_mean_squared_error: 12.8210 - val_mean_absolute_percentage_error: 42.4420
# Epoch 77/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.3529 - mean_absolute_error: 0.6490 - root_mean_squared_error: 2.2099 - mean_absolute_percentage_error: 3.6662 - val_loss: 6.2746 - val_mean_absolute_error: 6.6850 - val_root_mean_squared_error: 12.6670 - val_mean_absolute_percentage_error: 42.6077
# Epoch 78/100
# 103/103 [==============================] - 9s 86ms/step - loss: 0.3916 - mean_absolute_error: 0.7130 - root_mean_squared_error: 2.2164 - mean_absolute_percentage_error: 4.1383 - val_loss: 6.3471 - val_mean_absolute_error: 6.7663 - val_root_mean_squared_error: 12.6927 - val_mean_absolute_percentage_error: 42.3869
# Epoch 79/100
# 103/103 [==============================] - 9s 85ms/step - loss: 0.3663 - mean_absolute_error: 0.6781 - root_mean_squared_error: 2.1757 - mean_absolute_percentage_error: 3.8015 - val_loss: 6.2465 - val_mean_absolute_error: 6.6742 - val_root_mean_squared_error: 12.6133 - val_mean_absolute_percentage_error: 41.8028
# Epoch 80/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.3000 - mean_absolute_error: 0.5764 - root_mean_squared_error: 2.1244 - mean_absolute_percentage_error: 3.2084 - val_loss: 6.2709 - val_mean_absolute_error: 6.6906 - val_root_mean_squared_error: 12.6191 - val_mean_absolute_percentage_error: 42.1766
# Epoch 81/100
# 103/103 [==============================] - 10s 93ms/step - loss: 0.2927 - mean_absolute_error: 0.5719 - root_mean_squared_error: 2.0993 - mean_absolute_percentage_error: 3.1691 - val_loss: 6.2234 - val_mean_absolute_error: 6.6455 - val_root_mean_squared_error: 12.5530 - val_mean_absolute_percentage_error: 41.1532
# Epoch 82/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.3156 - mean_absolute_error: 0.6095 - root_mean_squared_error: 2.0804 - mean_absolute_percentage_error: 3.3245 - val_loss: 6.2208 - val_mean_absolute_error: 6.6331 - val_root_mean_squared_error: 12.6408 - val_mean_absolute_percentage_error: 41.7607
# Epoch 83/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.3183 - mean_absolute_error: 0.6135 - root_mean_squared_error: 2.0888 - mean_absolute_percentage_error: 3.3824 - val_loss: 6.2870 - val_mean_absolute_error: 6.7096 - val_root_mean_squared_error: 12.6760 - val_mean_absolute_percentage_error: 43.5162
# Epoch 84/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.3286 - mean_absolute_error: 0.6323 - root_mean_squared_error: 2.0595 - mean_absolute_percentage_error: 3.4330 - val_loss: 6.2427 - val_mean_absolute_error: 6.6723 - val_root_mean_squared_error: 12.6719 - val_mean_absolute_percentage_error: 41.1971
# Epoch 85/100
# 103/103 [==============================] - 9s 88ms/step - loss: 0.3177 - mean_absolute_error: 0.6150 - root_mean_squared_error: 2.0448 - mean_absolute_percentage_error: 3.4241 - val_loss: 6.2459 - val_mean_absolute_error: 6.6526 - val_root_mean_squared_error: 12.6704 - val_mean_absolute_percentage_error: 42.0789
# Epoch 86/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.3411 - mean_absolute_error: 0.6461 - root_mean_squared_error: 2.0656 - mean_absolute_percentage_error: 3.5575 - val_loss: 6.3074 - val_mean_absolute_error: 6.7331 - val_root_mean_squared_error: 12.7033 - val_mean_absolute_percentage_error: 43.5907
# Epoch 87/100
# 103/103 [==============================] - 9s 85ms/step - loss: 0.3738 - mean_absolute_error: 0.6974 - root_mean_squared_error: 2.0877 - mean_absolute_percentage_error: 3.9619 - val_loss: 6.2647 - val_mean_absolute_error: 6.6879 - val_root_mean_squared_error: 12.6866 - val_mean_absolute_percentage_error: 42.5216
# Epoch 88/100
# 103/103 [==============================] - 9s 86ms/step - loss: 0.3823 - mean_absolute_error: 0.7070 - root_mean_squared_error: 2.0471 - mean_absolute_percentage_error: 4.2990 - val_loss: 6.2974 - val_mean_absolute_error: 6.7131 - val_root_mean_squared_error: 12.7871 - val_mean_absolute_percentage_error: 42.1902
# Epoch 89/100
# 103/103 [==============================] - 9s 86ms/step - loss: 0.3668 - mean_absolute_error: 0.6752 - root_mean_squared_error: 2.3347 - mean_absolute_percentage_error: 4.1570 - val_loss: 6.2303 - val_mean_absolute_error: 6.6530 - val_root_mean_squared_error: 12.5847 - val_mean_absolute_percentage_error: 41.7307
# Epoch 90/100
# 103/103 [==============================] - 9s 87ms/step - loss: 0.3237 - mean_absolute_error: 0.6247 - root_mean_squared_error: 1.9809 - mean_absolute_percentage_error: 3.5597 - val_loss: 6.3112 - val_mean_absolute_error: 6.7223 - val_root_mean_squared_error: 12.8139 - val_mean_absolute_percentage_error: 42.9878
# Epoch 91/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.2808 - mean_absolute_error: 0.5597 - root_mean_squared_error: 1.9403 - mean_absolute_percentage_error: 3.1347 - val_loss: 6.2418 - val_mean_absolute_error: 6.6387 - val_root_mean_squared_error: 12.6996 - val_mean_absolute_percentage_error: 42.3792
# Epoch 92/100
# 103/103 [==============================] - 9s 89ms/step - loss: 0.2473 - mean_absolute_error: 0.5076 - root_mean_squared_error: 1.9046 - mean_absolute_percentage_error: 2.7810 - val_loss: 6.3007 - val_mean_absolute_error: 6.7096 - val_root_mean_squared_error: 12.7777 - val_mean_absolute_percentage_error: 43.5234
# Epoch 93/100
# 103/103 [==============================] - 10s 101ms/step - loss: 0.2628 - mean_absolute_error: 0.5303 - root_mean_squared_error: 1.9060 - mean_absolute_percentage_error: 3.0125 - val_loss: 6.1886 - val_mean_absolute_error: 6.5953 - val_root_mean_squared_error: 12.5730 - val_mean_absolute_percentage_error: 41.1724
# Epoch 94/100
# 103/103 [==============================] - 10s 101ms/step - loss: 0.2671 - mean_absolute_error: 0.5422 - root_mean_squared_error: 1.8945 - mean_absolute_percentage_error: 3.0735 - val_loss: 6.2300 - val_mean_absolute_error: 6.6239 - val_root_mean_squared_error: 12.7010 - val_mean_absolute_percentage_error: 41.7991
# Epoch 95/100
# 103/103 [==============================] - 11s 103ms/step - loss: 0.2253 - mean_absolute_error: 0.4662 - root_mean_squared_error: 1.8398 - mean_absolute_percentage_error: 2.5462 - val_loss: 6.2728 - val_mean_absolute_error: 6.6945 - val_root_mean_squared_error: 12.7056 - val_mean_absolute_percentage_error: 41.9076
# Epoch 96/100
# 103/103 [==============================] - 10s 101ms/step - loss: 0.2310 - mean_absolute_error: 0.4853 - root_mean_squared_error: 1.8238 - mean_absolute_percentage_error: 2.7958 - val_loss: 6.2778 - val_mean_absolute_error: 6.6742 - val_root_mean_squared_error: 12.7668 - val_mean_absolute_percentage_error: 42.5601
# Epoch 97/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.2441 - mean_absolute_error: 0.5070 - root_mean_squared_error: 1.8020 - mean_absolute_percentage_error: 2.8717 - val_loss: 6.2083 - val_mean_absolute_error: 6.6062 - val_root_mean_squared_error: 12.7254 - val_mean_absolute_percentage_error: 41.9123
# Epoch 98/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.3166 - mean_absolute_error: 0.6093 - root_mean_squared_error: 1.8639 - mean_absolute_percentage_error: 3.5406 - val_loss: 6.2218 - val_mean_absolute_error: 6.6515 - val_root_mean_squared_error: 12.6719 - val_mean_absolute_percentage_error: 41.5272
# Epoch 99/100
# 103/103 [==============================] - 10s 100ms/step - loss: 0.3123 - mean_absolute_error: 0.6099 - root_mean_squared_error: 1.9710 - mean_absolute_percentage_error: 3.5067 - val_loss: 6.2208 - val_mean_absolute_error: 6.6275 - val_root_mean_squared_error: 12.6845 - val_mean_absolute_percentage_error: 42.0586
# Epoch 100/100
# 103/103 [==============================] - 11s 103ms/step - loss: 0.2767 - mean_absolute_error: 0.5639 - root_mean_squared_error: 1.8048 - mean_absolute_percentage_error: 3.2173 - val_loss: 6.2185 - val_mean_absolute_error: 6.6377 - val_root_mean_squared_error: 12.5469 - val_mean_absolute_percentage_error: 42.8441

# %%
loss = model.evaluate([X_test_texts, test_numerical], y_test)
print(f'Model Loss: {loss}')
# Out:
# 33/33 [==============================] - 1s 43ms/step - loss: 6.2185 - mean_absolute_error: 6.6377 - root_mean_squared_error: 12.5469 - mean_absolute_percentage_error: 42.8441
# Model Loss: [6.218472957611084, 6.637722492218018, 12.546875953674316, 42.844146728515625]

# %%
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Model Mean Absolute Error')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('Model Root Mean Squared Error')
plt.ylabel('Root Mean Squared Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['mean_absolute_percentage_error'])
plt.plot(history.history['val_mean_absolute_percentage_error'])
plt.title('Model MAPE')
plt.ylabel('MAPE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# ### Inference

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 582ms/step
# Predicted Putusan: [14.241256]

# %%
model_scenario_name = "BiLSTM_Baseline"

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'

model.save(model_save_path)

with open(tokenizer_save_path, 'wb') as handle:
    pickle.dump(tokenizer, handle)

with open(history_training_save_path, 'wb') as f:
    pickle.dump(history.history, f)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_Baseline\assets
# INFO:tensorflow:Assets written to: ../Model/BiLSTM_Baseline\assets

# %% [markdown]
# ## Saved Model Inference

# %%
model_scenario_name = "BiLSTM_Baseline"
max_len = 1024

model_save_path = f'../Model/{model_scenario_name}'
tokenizer_save_path = f'../Model/{model_scenario_name}_tokenizer.pkl'
history_training_save_path = f'../Model/{model_scenario_name}_training_history.pkl'
    
loaded_model = tf.keras.models.load_model(model_save_path)

with open(tokenizer_save_path, 'rb') as handle:
    tokenizer = pickle.load(handle)

# %%
# train_sequences = tokenizer.texts_to_sequences(train_df['stopword_removal']))a
test_sequences = tokenizer.texts_to_sequences(test_df['stopword_removal'])

max_len = 1024
# X_train_texts = tf.keras.preprocessing.sequence.pad_sequences(train_sequences, maxlen=max_len, padding='post', truncating='post')
X_test_texts = tf.keras.preprocessing.sequence.pad_sequences(test_sequences, maxlen=max_len, padding='post', truncating='post')

test_numerical = tf.constant(test_df[['klasifikasi_perkara_encoded', 'penuntut_umum_encoded', 'hakim_encoded', 'jumlah_saksi', 'maks_penjara_berdasarkan_pasal']].values, dtype=tf.float32)

# %%
klasifikasi_perkara_encoded = 0
penuntut_umum_encoded = 0
hakim_encoded = 7
jumlah_saksi_inference = 6
maks_penjara_berdasarkan_pasal = 84

inference_text = ["buah sabit gagang kayu buah jare plastik paranet warna hitam uta tali plastik warna biru meter puluh buah kantong plastik kresek uta tali kain warna merah cm dimusnahkan unit mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid beserta kunci kontak lembar stnk mobil merek suzuki st pick up warna hitam dk kc noka mhyesljj nosin gaid nama pemilik an i kadek kondrayasa dikembalikan i gede agu wirayuda buah durian jeni durian kane dikembalikan i wayan sukaren lembar nota pembelian buah durian toko tiara durian dikembalikan komang ayu anggreni bela buah durian jeni durian kane lembar nota pembelian buah durian toko semut durian dikembalikan komang sujana uang tunai rp ratu delapan puluh tujuh ribu rupiah dirampa negara membebankan terdakwa membayar biaya perkara rp ribu rupiah terdakwa gede darmayasa selasa tanggal mei sekira jam wita selasa tanggal mei sekira jam wita sabtu tanggal mei sekira jam wita setidaktidaknya mei setidaktidaknya kebun milik i wayan sukerena banjar desa bunutin kecamatan kintamani kab bangli kebun milik i nyoman susila banjar desa bunutin kecamatan kintamani kab bangli kebun milik i ketut tindih banjar desa pengejaran kecamatan kintamani kab bangli setidaktidaknya daerah hukum pengadilan negeri bangli perbuatan dipandang perbuatan berdiri kejahatan mengambil barang kepunyaan orang maksud dimiliki melawan hukum terdakwa caracara selasa tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd bunutin kec kintamani kab bangli melewati simpang pasar tenten kintamani tujuan memb menawarkan buah durian dipohonnya sesampainya terdakwa brd bunutin kec kintamani kab bangli sekira wita terdakwa pohon durian berbuah kebun milik i wayan sukerena dipinggir jalan raya ds bunutin kec kintamani kab bangli situasi sepi terdakwa melihatlihat buah durian menemukan buah dipetik terdakwa memetik buah durian memanjat pohon durian sabit memotong buah durian pohon bergiliran buah durian terdakwa petik puluh tujuh buahsetelah terkumpul buah durian terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa kendarai buah durian diata mobil terdakwa meninggalkan kebun milik i wayan sukerena perjalanan terdakwa dipinggir jalan raya ds bunutin kintamani pohon durian berbuah terdakwa turun memarkir mobil suzuki carri pick up warna hitam dk kc dipinggir jalan raya berjalan kaki terdakwa kebun milik i nyoman susila brd bunutin kec kintamani kab bangli sekira wita pohon durian berbuah terdakwa memanjat pohon durian pohon bergantian memetik sabit menurunkan buah durian puluh tujuh buah buah durian turun terkumpul terdakwa naikan mobil suzuki carri pick up warna hitam dk kc terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd bunutin kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng dirumah wita terdakwa langsung menjual durian saksi komang ayu anggreni batu barak desa tajun kec kubutambahan kab buleleng puluh buah berat seratu delapan puluh kg harga rp juta ratu enam bela ribu rupiah sisa buah durian puluh tujuh buah terdakwa bawa pulang kerumah kami tanggal mei sekira wita terdakwa menjual durian jeni durian kane komang sujana gudang milik komang sujana puluh buah durian berat kg buah durian hasil mencuri selasa tanggal mei brd bunutin kec kintamani kab bangli buah durian hasil terdakwa memb petani terdakwa jual harga total rp juta ratu ribu rupiah sabtu tanggal mei sekira wita terdakwa berangkat rumah terdakwa br dina pudeh ds tajun kec kubutambahan kab buleleng mobil suzuki carri pick up warna hitam dk kc pergi brd pengejaran kec kintamani kab bangli sesampainya terdakwa brd pengejaran kec kintamani kab bangli sekira wita melewati simpang lampu terdakwa dikebun milik i ketut tindih berlokasi pinggir jalan raya ds pengejaran situasi sepi terdakwa memanjat pohon durian pohon bergantian memetik buah durian sabit buah menjatuhkan buah durian ketanah terdakwa mengumpulkan buah durian terdakwa petik terdakwa menaikan buah durian mobil carri terdakwa bawa buah durian terdakwa tutupi buah durian diata mobil jare plastik warna hitam terdakwa ikat tali plastik warna biru buah durian aman diata mobil terdakwa meninggalkan brd pengejaran kec kintamani kab bangli rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng pulang kerumahnya terdakwa pergi desa tajun menjual buah durian komang ayu anggreni buah harga rp juta ratu delapan puluh ribu rupiah menjual buah durian terdakwa langsung pulang rumah terdakwa br dina pudeh ds tajun kac kubutambahan kab buleleng terdakwa mengambil enam puluh tujuh buah durian kane ijin saksi i wayan sukerena saksi i nyoman susila saksi i ketut tindih memiliki buah durian menjualnya uang hasil penjualan biaya hidup seharihari akibat perbuatan terdakwa mengakibatkan saksi i wayan sukerena mengalami kerugian rp juta ratu puluh ribu rupiah saksi i ketut tindih mengalami kerugian rp juta ratu ribu rupiah saksi i nyoman susila mengalami kerugian rp juta rupiah setidaktidaknya rp ratu puluh rupiah diatur diancam pidana pasal kuhp jo pasal ayat kuhp gede darmayasa"]
inference_numerical_tensor = tf.constant([[klasifikasi_perkara_encoded, penuntut_umum_encoded, hakim_encoded, jumlah_saksi_inference, maks_penjara_berdasarkan_pasal]], dtype=tf.float32)

new_sequences = tokenizer.texts_to_sequences(inference_text)
inference_text = tf.keras.preprocessing.sequence.pad_sequences(new_sequences, maxlen=max_len, padding='post')

predictions = loaded_model.predict([inference_text, inference_numerical_tensor])
print(f'Predicted Putusan: {predictions[0]}')

# pred_log = predictions[0].astype(float)  # Log transformation
# predictions = np.expm1(pred_log)  
# print(f'Predicted Putusan: {predictions}')
# Out:
# 1/1 [==============================] - 1s 570ms/step
# Predicted Putusan: [14.241256]
